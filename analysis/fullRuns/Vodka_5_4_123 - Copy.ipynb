# %% [markdown]
# # Init

# %%
# %load_ext autoreload
# %autoreload 2

# %%
print("CURRENT FOLDER:")
# %pwd
# Out:
# CURRENT FOLDER:
# 'c:\\max\\Google Drive Max\\Max Shared\\Master Data Science\\2020-05 Capstone A\\msds_capstone\\analysis\\fullRuns'

# %%
import os
import glob
import sys
sys.path.append(os.environ['DEV_AUTOTS'])
sys.path.append(os.environ['CAPSTONE_PYTHON_SOURCE'])
folder = os.environ['CAPSTONE_DATA']

# %%
## Sourcing the .py with all the code##
t='"'+os.environ['CAPSTONE_PYTHON_SOURCE']+'\\fullRun\\fullRun.py'+'"'
# %run -i $t
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# Running Auto Timeseries version: 0.0.24

# %% [markdown]
# # Parameters

# %%
#Parameters

ProdCats = ['VODKA']
TOP_PRODUCTS = 5  # How many products to consider in the category
TOP_SIMILAR = 4  # Get TOP_SIMILAR most similar products
RUN_PERIODS = [1,2,3] # this will run AutoTS and Optimzer for speicfic periods (1 = last, 2 = second to last)

CV_NUM = 10         # number of Cross Valudations  10
OPT_CALLS = 100     # number of calls for the optimizer process   100
OPT_RND_STARTS = 20 # number of random calls for the optimizer process  20

LOG_TRANSFORM = True # Take log of 9L cases to smooth out peaks and valleys
ZERO_ADDER = 0.1 

RESAMPLE_FREQ = 'M'


# Pricing changes every 4 weeks
if RESAMPLE_FREQ == 'M':    FORECAST_PERIOD = 1 #last 4 months as test 
if RESAMPLE_FREQ == 'W':    FORECAST_PERIOD = 4 
if RESAMPLE_FREQ == '2W':   FORECAST_PERIOD = 2 

# Seasonal Period
if RESAMPLE_FREQ == 'M':    SEASONAL_PERIOD = 12  # Yearly
if RESAMPLE_FREQ == 'W':    SEASONAL_PERIOD = 13 # Quarterly (we can also take yearly = 52, but SARIMAX becomes too slow)
if RESAMPLE_FREQ == '2W':   SEASONAL_PERIOD = 13 # This becomes problematic --> for quarterly, should we take 6 biweekly periods or 7 bi-weekly periods. Instead I just took half yearly period  

COL_TIME = 'WeekDate'
COL_PREDS = ['9L Cases'] #Demand
COL_PRICE= ['Dollar Sales per 9L Case'] #Price

# %% [markdown]
# # Full Run

# %%
dataRaw = loadDataset(version=4)
ProdCat = 'SUP PREM WHISKEY' #'ECONOMY VODKA'
ChainMasters =  [''] +  dataRaw['Chain Master'].unique().tolist() 
display(ChainMasters,ProdCats)
# Out:
# ['', 'THE BARREL HOUSE', 'WESTERN BEV LIQ TX', 'SPECS']
# ['VODKA']

# %%
(full_models,full_opt,full_summary,full_chain_summary)  = fullRun(ProdCat = ProdCat
                                                           ,ChainMasters = ChainMasters
                                                           ,dataRaw = dataRaw
                                                           ,savePKL=True
                                                           ,saveXLS=True)
# Out:
# ==================================================
# Parameters being used...
# ==================================================
# TOP_PRODUCTS = 5
# TOP_SIMILAR = 2
# RUN_PERIODS = [1, 2, 3]
# ProdCat: SUP PREM WHISKEY
# ChainMasters: ['', 'THE BARREL HOUSE', 'WESTERN BEV LIQ TX', 'SPECS']
#
#
# ========================== (2020-09-12 10:09:48.501955)
# ===== Products List  =====
# ==== SUP PREM WHISKEY ====
# ============  ============
# ==========================
#
#
#
# ========================== (2020-09-12 10:09:53.994155)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 1 ============
# ==========================
#
#
#
# ================== (2020-09-12 10:09:53.994155)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS BLK WHSKY SQ 375M', '4': 'GENTLEMAN JACK WHSKY OL 750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 1.1904761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY SQ 375M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2']
# % of weeks without a purchase: 44.047619047619044
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '2']
# % of weeks without a purchase: 3.571428571428571
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY SQ 375M
# 	Product: GENTLEMAN JACK WHSKY OL 750M
#
#
# ===================== (2020-09-12 10:10:51.608212)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#       lb_stat  lb_pvalue
# 12  17.529696   0.130735
# 24  31.092108   0.151145
# 48  54.922995   0.228882
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12  115.750529  4.333814e-19
# 24  214.169023  1.845834e-32
# 48  308.098428  1.176533e-39
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   76.707883  1.745018e-11
# 24  131.122583  9.711501e-17
# 48  214.957410  5.416649e-23
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  236.849902  7.504140e-44
# 24  313.152234  3.733315e-52
# 48  457.992618  2.867236e-68
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   49.544022  1.679761e-06
# 24   97.459679  8.118215e-11
# 48  147.898014  4.125410e-12
#
# Is Data White Noise: False
#
#
# ==================== (2020-09-12 10:10:51.627211)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (83, 5) (1, 5)
# (83, 5) (1, 5)
# (83, 5) (1, 5)
# (83, 5) (1, 5)
# (83, 5) (1, 5)
#
#
# =============== (2020-09-12 10:10:51.631212)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.043169         []
# 1  1      last   0.324455         []
# 2  2      mean   0.427990         []
# 3  3      mean   0.798321         []
# 4  4      mean   0.375053         []
#
#                                            All RMSEs  \
# 0  [[0.07143315389555474, 0.11332894033533458, 0....
# 1  [[0.3244545696539494, 0.4963154566538675, 0.34...
# 2  [[0.6704496090247218, 0.719929333484661, 0.427...
# 3  [[1.158356517777329, 1.1898741527817909, 0.798...
# 4  [[0.709250053526431, 0.5987185687692762, 0.375...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 4  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-12 10:10:52.343212)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  6.4min remaining:  9.5min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  7.5min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-12 10:18:20.833554)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  5.9min remaining:  8.8min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  6.8min finished
# =================== (2020-09-12 10:25:10.130066)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-12 10:25:10.135068)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 1 ============
# ==========================
#
#
#
# =========================== (2020-09-12 10:25:10.136068)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ============  =============
# ============ 1 ============
# ===========================
#
#
#
# ================== (2020-09-12 10:25:10.138067)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS BLK WHSKY SQ 375M', '4': 'GENTLEMAN JACK WHSKY OL 750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 1.1904761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY SQ 375M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2']
# % of weeks without a purchase: 44.047619047619044
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '2']
# % of weeks without a purchase: 3.571428571428571
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY SQ 375M
# 	Product: GENTLEMAN JACK WHSKY OL 750M
#
#
# ==================== (2020-09-12 10:26:00.763144)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (83, 5) (1, 5)
# (83, 5) (1, 5)
# (83, 5) (1, 5)
# (83, 5) (1, 5)
# (83, 5) (1, 5)
#
#
# ======================== (2020-09-12 10:26:00.769143)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-12 10:26:00.783143)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False, False, False]
#
#
# =============== (2020-09-12 10:26:00.785166)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-12 10:26:00.793176)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-12 10:26:00.793176)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-12 10:26:00.794151)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-12 10:26:00.926144)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-12 10:26:00.930142)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-12 10:27:00.851768)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-12 10:27:01.005769)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-12 10:27:01.006768)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-12 10:27:01.144768)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-12 10:27:01.152769)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-12 10:28:19.312825)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-12 10:28:19.456823)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-12 10:28:19.460824)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 2 ============
# ==========================
#
#
#
# ================== (2020-09-12 10:28:19.461823)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS BLK WHSKY SQ 375M', '4': 'GENTLEMAN JACK WHSKY OL 750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 1.2048192771084338
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY SQ 375M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2']
# % of weeks without a purchase: 44.57831325301205
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '2']
# % of weeks without a purchase: 3.614457831325301
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY SQ 375M
# 	Product: GENTLEMAN JACK WHSKY OL 750M
#
#
# ===================== (2020-09-12 10:29:13.045339)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#       lb_stat  lb_pvalue
# 12  17.074759   0.146807
# 24  30.689164   0.162949
# 48  53.509495   0.271059
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12  113.741522  1.085921e-18
# 24  210.737801  8.608130e-32
# 48  298.546482  6.801454e-38
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   73.433730  7.257343e-11
# 24  127.792143  3.888372e-16
# 48  208.580703  6.624266e-22
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  233.654157  3.467423e-43
# 24  301.956845  6.767463e-50
# 48  453.324573  2.340339e-67
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   48.137860  2.957627e-06
# 24   92.192775  6.231213e-10
# 48  138.240334  1.125182e-10
#
# Is Data White Noise: False
#
#
# ==================== (2020-09-12 10:29:13.072337)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (82, 5) (1, 5)
#
#
# =============== (2020-09-12 10:29:13.079337)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.021557         []
# 1  1      mean   0.323943         []
# 2  2      mean   0.373199         []
# 3  3      mean   0.669609         []
# 4  4      mean   0.351197         []
#
#                                            All RMSEs  \
# 0  [[0.057546587491533165, 0.09126460007014617, 0...
# 1  [[0.3342880201030623, 0.4694144778845947, 0.32...
# 2  [[0.6160411345584191, 0.6054018321634664, 0.37...
# 3  [[1.1334719691929973, 1.0359040362506735, 0.66...
# 4  [[0.7597766030869607, 0.5171871911658599, 0.35...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 4  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-12 10:29:13.637337)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  6.8min remaining: 10.2min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  8.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-12 10:37:16.200007)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  6.5min remaining:  9.8min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  7.1min finished
# =================== (2020-09-12 10:44:24.679347)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-12 10:44:24.688346)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 2 ============
# ==========================
#
#
#
# =========================== (2020-09-12 10:44:24.689345)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ============  =============
# ============ 2 ============
# ===========================
#
#
#
# ================== (2020-09-12 10:44:24.691345)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS BLK WHSKY SQ 375M', '4': 'GENTLEMAN JACK WHSKY OL 750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 1.2048192771084338
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY SQ 375M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2']
# % of weeks without a purchase: 44.57831325301205
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '2']
# % of weeks without a purchase: 3.614457831325301
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY SQ 375M
# 	Product: GENTLEMAN JACK WHSKY OL 750M
#
#
# ==================== (2020-09-12 10:45:13.692037)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (82, 5) (1, 5)
#
#
# ======================== (2020-09-12 10:45:13.703039)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-12 10:45:13.727037)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False, False, False]
#
#
# =============== (2020-09-12 10:45:13.731038)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-12 10:45:13.740038)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-12 10:45:13.741039)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-12 10:45:13.742038)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-12 10:45:13.948038)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-12 10:45:13.955041)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-12 10:46:37.954471)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-12 10:46:38.238473)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-12 10:46:38.239472)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-12 10:46:38.439990)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-12 10:46:38.448991)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-12 10:48:24.470616)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-12 10:48:24.915617)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-12 10:48:24.925618)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 3 ============
# ==========================
#
#
#
# ================== (2020-09-12 10:48:24.926618)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS BLK WHSKY SQ 375M', '4': 'GENTLEMAN JACK WHSKY OL 750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY SQ 375M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2']
# % of weeks without a purchase: 45.1219512195122
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '2']
# % of weeks without a purchase: 3.6585365853658534
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY SQ 375M
# 	Product: GENTLEMAN JACK WHSKY OL 750M
#
#
# ===================== (2020-09-12 10:49:26.462259)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#       lb_stat  lb_pvalue
# 12  16.492825   0.169692
# 24  29.613691   0.197887
# 48  52.235849   0.312831
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12  111.729571  2.720557e-18
# 24  207.460783  3.736074e-31
# 48  291.621010  1.270149e-36
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   72.023277  1.337193e-10
# 24  126.557635  6.490946e-16
# 48  206.128607  1.725436e-21
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  227.003218  8.357786e-42
# 24  289.400873  2.267177e-47
# 48  442.433742  3.108030e-65
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   47.219751  4.270383e-06
# 24   91.282625  8.832443e-10
# 48  138.156566  1.157395e-10
#
# Is Data White Noise: False
#
#
# ==================== (2020-09-12 10:49:26.487259)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (81, 5) (1, 5)
# (81, 5) (1, 5)
# (81, 5) (1, 5)
# (81, 5) (1, 5)
# (81, 5) (1, 5)
#
#
# =============== (2020-09-12 10:49:26.494256)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.033917         []
# 1  1      mean   0.319180         []
# 2  2      mean   0.373056         []
# 3  3      mean   0.627867         []
# 4  4      mean   0.551268         []
#
#                                            All RMSEs  \
# 0  [[0.0872048496772559, 0.1165490736094128, 0.03...
# 1  [[0.35617856342347604, 0.5500854364755055, 0.3...
# 2  [[0.556716035671863, 0.5707857245806156, 0.373...
# 3  [[1.0772290858881073, 1.0184226921157236, 0.62...
# 4  [[0.9705759316336084, 0.7296087664558061, 0.55...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 4  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-12 10:49:27.042257)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  6.1min remaining:  9.1min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  6.9min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-12 10:56:21.952795)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  5.1min remaining:  7.7min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  5.6min finished
# =================== (2020-09-12 11:01:58.746345)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-12 11:01:58.754343)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 3 ============
# ==========================
#
#
#
# =========================== (2020-09-12 11:01:58.754343)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ============  =============
# ============ 3 ============
# ===========================
#
#
#
# ================== (2020-09-12 11:01:58.756348)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS BLK WHSKY SQ 375M', '4': 'GENTLEMAN JACK WHSKY OL 750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY SQ 375M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2']
# % of weeks without a purchase: 45.1219512195122
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '2']
# % of weeks without a purchase: 3.6585365853658534
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY SQ 375M
# 	Product: GENTLEMAN JACK WHSKY OL 750M
#
#
# ==================== (2020-09-12 11:02:43.873763)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (81, 5) (1, 5)
# (81, 5) (1, 5)
# (81, 5) (1, 5)
# (81, 5) (1, 5)
# (81, 5) (1, 5)
#
#
# ======================== (2020-09-12 11:02:43.877763)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-12 11:02:43.890766)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False, False, False]
#
#
# =============== (2020-09-12 11:02:43.892767)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-12 11:02:43.898767)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-12 11:02:43.899767)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-12 11:02:43.900767)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-12 11:02:43.977766)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-12 11:02:43.981763)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-12 11:03:49.442866)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-12 11:03:49.552868)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-12 11:03:49.553868)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-12 11:03:49.700868)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-12 11:03:49.706868)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-12 11:05:22.845475)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-12 11:05:22.983474)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-12 11:05:22.991473)
# ===== Products List  =====
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-12 11:05:24.081994)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 1 ============
# ==========================
#
#
#
# ========================== (2020-09-12 11:05:24.082993)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  750M', '2': 'GENTLEMAN JACK WHSKY OL 750M', '3': 'JACK DANIELS TENN HNY WHSKY  1L', '4': 'GENTLEMAN JACK WHSKY 6PK 1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '4', '1']
# % of weeks without a purchase: 45.23809523809524
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 59.523809523809526
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '4', '1']
# % of weeks without a purchase: 52.38095238095239
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '4']
# % of weeks without a purchase: 48.80952380952381
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY 6PK 1L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '2', '0']
# % of weeks without a purchase: 32.926829268292686
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY 6PK 1L
#
#
# ========================== (2020-09-12 11:06:20.058466)
# ====== WHITE NOISE =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#        lb_stat  lb_pvalue
# 12   24.932218   0.015147
# 24   47.266936   0.003107
# 48  103.010327   0.000007
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  22.956927   0.028094
# 24  26.727008   0.317338
# 48  60.860438   0.100708
#
# Is Data White Noise: True
#        lb_stat  lb_pvalue
# 12   24.646813   0.016588
# 24   50.653838   0.001168
# 48  108.922594   0.000001
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  11.113828   0.519190
# 24  30.880617   0.157255
# 48  53.855113   0.260331
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12   8.641692   0.733192
# 24  19.315056   0.734985
# 48  47.523727   0.492264
#
# Is Data White Noise: True
#
#
# ========================== (2020-09-12 11:06:20.080466)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (83, 5) (1, 5)
# (83, 5) (1, 5)
# (83, 5) (1, 5)
# (83, 5) (1, 5)
# (81, 5) (1, 5)
#
#
# ========================== (2020-09-12 11:06:20.087467)
# ========= NAIVE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#   ID      Best Type  Best RMSE All Naives  \
# 0  0           mean   1.149908         []
# 1  1           mean   0.959053         []
# 2  2           last   0.508452         []
# 3  3  seasonal_last   0.539165         []
# 4  4           mean   0.611153         []
#
#                                            All RMSEs  \
# 0  [[1.3378491195367055, 1.5550765479093094, 1.14...
# 1  [[1.3498152846931788, 1.3498152846931788, 0.95...
# 2  [[0.5084521358062825, 1.227326606712806, 0.861...
# 3  [[0.8388226345645782, 0.5391649362857315, 0.68...
# 4  [[0.7042605406907361, 0.7703384907350979, 0.61...
#
#                        All Types  \
# 0  [[last, seasonal_last, mean]]
# 1  [[last, seasonal_last, mean]]
# 2  [[last, seasonal_last, mean]]
# 3  [[last, seasonal_last, mean]]
# 4  [[last, seasonal_last, mean]]
#
#                                         Best Naive
# 0           NaiveForecaster(sp=4, strategy='mean')
# 1           NaiveForecaster(sp=4, strategy='mean')
# 2                            NaiveForecaster(sp=4)
# 3  NaiveForecaster(sp=4, strategy='seasonal_last')
# 4           NaiveForecaster(sp=4, strategy='mean')
#
#
# ========================== (2020-09-12 11:06:20.625051)
# ====== Multivar P0 =======
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  6.1min remaining:  9.2min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  7.7min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================== (2020-09-12 11:14:05.469012)
# ==== Multivar P0+Sim =====
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  5.5min remaining:  8.2min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  6.7min finished
# ========================== (2020-09-12 11:20:49.372339)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-12 11:20:49.377340)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 1 ============
# ==========================
#
#
#
# =========================== (2020-09-12 11:20:49.378340)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ==== THE BARREL HOUSE =====
# ============ 1 ============
# ===========================
#
#
#
# ========================== (2020-09-12 11:20:49.380339)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  750M', '2': 'GENTLEMAN JACK WHSKY OL 750M', '3': 'JACK DANIELS TENN HNY WHSKY  1L', '4': 'GENTLEMAN JACK WHSKY 6PK 1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '4', '1']
# % of weeks without a purchase: 45.23809523809524
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 59.523809523809526
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '4', '1']
# % of weeks without a purchase: 52.38095238095239
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '4']
# % of weeks without a purchase: 48.80952380952381
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY 6PK 1L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '2', '0']
# % of weeks without a purchase: 32.926829268292686
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY 6PK 1L
#
#
# ========================== (2020-09-12 11:21:43.002364)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (83, 5) (1, 5)
# (83, 5) (1, 5)
# (83, 5) (1, 5)
# (83, 5) (1, 5)
# (81, 5) (1, 5)
#
#
# ========================== (2020-09-12 11:21:43.016366)
# ===== NAIVE FORECAST =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-12 11:21:43.045365)
# ========== MASK ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
# Mask: [False, False, False, False, False]
#
#
# ========================== (2020-09-12 11:21:43.048369)
# ========= SPACE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-12 11:21:43.057368)
# ======= Test Index =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-12 11:21:43.059367)
# ==== GET FUNCTION P0 =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ====================================== (2020-09-12 11:21:43.060364)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ========== THE BARREL HOUSE ==========
# ======================================
#
#
#
# ========================== (2020-09-12 11:21:43.218364)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-12 11:21:43.222364)
# ===== OPTIMIZING P0 ======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-12 11:23:19.489075)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ============================= (2020-09-12 11:23:19.767073)
# ==== GET FUNCTION P0+Sim ====
# ===== THE BARREL HOUSE ======
# =============================
#
#
#
# ========================================== (2020-09-12 11:23:19.768071)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ============ THE BARREL HOUSE ============
# ==========================================
#
#
#
# ========================== (2020-09-12 11:23:20.054074)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# =========================== (2020-09-12 11:23:20.062074)
# ==== OPTIMIZING P0+Sim ====
# ==== THE BARREL HOUSE =====
# ===========================
#
#
#
# ========================== (2020-09-12 11:25:41.103166)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-12 11:25:41.648168)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-12 11:25:41.655166)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 2 ============
# ==========================
#
#
#
# ========================== (2020-09-12 11:25:41.656169)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  750M', '2': 'GENTLEMAN JACK WHSKY OL 750M', '3': 'JACK DANIELS TENN HNY WHSKY  1L', '4': 'GENTLEMAN JACK WHSKY 6PK 1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '4', '1']
# % of weeks without a purchase: 45.78313253012048
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 60.24096385542169
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '4', '1']
# % of weeks without a purchase: 53.01204819277109
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '4']
# % of weeks without a purchase: 49.39759036144578
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY 6PK 1L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '2', '0']
# % of weeks without a purchase: 33.33333333333333
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY 6PK 1L
#
#
# ========================== (2020-09-12 11:26:45.360823)
# ====== WHITE NOISE =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#       lb_stat  lb_pvalue
# 12  23.922535   0.020840
# 24  45.414544   0.005201
# 48  99.152623   0.000020
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  22.542047   0.031875
# 24  26.146223   0.345787
# 48  58.838830   0.135801
#
# Is Data White Noise: True
#        lb_stat  lb_pvalue
# 12   25.814484   0.011401
# 24   50.372270   0.001269
# 48  100.845296   0.000013
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  10.794767   0.546584
# 24  29.686533   0.195359
# 48  53.100408   0.284097
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12   8.057662   0.780608
# 24  17.817943   0.811750
# 48  41.544821   0.733036
#
# Is Data White Noise: True
#
#
# ========================== (2020-09-12 11:26:45.381820)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (80, 5) (1, 5)
#
#
# ========================== (2020-09-12 11:26:45.385821)
# ========= NAIVE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#   ID      Best Type  Best RMSE All Naives  \
# 0  0           last   1.279671         []
# 1  1           mean   0.991773         []
# 2  2           last   0.397118         []
# 3  3  seasonal_last   0.583337         []
# 4  4           mean   0.532525         []
#
#                                            All RMSEs  \
# 0  [[1.2796706251393728, 1.655747949478816, 1.324...
# 1  [[1.3498152846931788, 1.3498152846931788, 0.99...
# 2  [[0.3971180356035492, 1.0727385943033805, 0.73...
# 3  [[0.9401093055023353, 0.5833369983034572, 0.76...
# 4  [[0.5741726496470821, 0.6294921160859183, 0.53...
#
#                        All Types  \
# 0  [[last, seasonal_last, mean]]
# 1  [[last, seasonal_last, mean]]
# 2  [[last, seasonal_last, mean]]
# 3  [[last, seasonal_last, mean]]
# 4  [[last, seasonal_last, mean]]
#
#                                         Best Naive
# 0                            NaiveForecaster(sp=4)
# 1           NaiveForecaster(sp=4, strategy='mean')
# 2                            NaiveForecaster(sp=4)
# 3  NaiveForecaster(sp=4, strategy='seasonal_last')
# 4           NaiveForecaster(sp=4, strategy='mean')
#
#
# ========================== (2020-09-12 11:26:45.913858)
# ====== Multivar P0 =======
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  4.7min remaining:  7.1min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  6.4min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================== (2020-09-12 11:33:12.454757)
# ==== Multivar P0+Sim =====
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  4.5min remaining:  6.7min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  6.1min finished
# ========================== (2020-09-12 11:39:18.491859)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-12 11:39:18.500859)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 2 ============
# ==========================
#
#
#
# =========================== (2020-09-12 11:39:18.501858)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ==== THE BARREL HOUSE =====
# ============ 2 ============
# ===========================
#
#
#
# ========================== (2020-09-12 11:39:18.504860)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  750M', '2': 'GENTLEMAN JACK WHSKY OL 750M', '3': 'JACK DANIELS TENN HNY WHSKY  1L', '4': 'GENTLEMAN JACK WHSKY 6PK 1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '4', '1']
# % of weeks without a purchase: 45.78313253012048
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 60.24096385542169
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '4', '1']
# % of weeks without a purchase: 53.01204819277109
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '4']
# % of weeks without a purchase: 49.39759036144578
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY 6PK 1L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '2', '0']
# % of weeks without a purchase: 33.33333333333333
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY 6PK 1L
#
#
# ========================== (2020-09-12 11:40:06.408114)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (80, 5) (1, 5)
#
#
# ========================== (2020-09-12 11:40:06.420113)
# ===== NAIVE FORECAST =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-12 11:40:06.439114)
# ========== MASK ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
# Mask: [False, False, False, False, False]
#
#
# ========================== (2020-09-12 11:40:06.441112)
# ========= SPACE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-12 11:40:06.450118)
# ======= Test Index =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-12 11:40:06.452117)
# ==== GET FUNCTION P0 =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ====================================== (2020-09-12 11:40:06.453117)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ========== THE BARREL HOUSE ==========
# ======================================
#
#
#
# ========================== (2020-09-12 11:40:06.686115)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-12 11:40:06.691118)
# ===== OPTIMIZING P0 ======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-12 11:41:45.709529)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ============================= (2020-09-12 11:41:45.997529)
# ==== GET FUNCTION P0+Sim ====
# ===== THE BARREL HOUSE ======
# =============================
#
#
#
# ========================================== (2020-09-12 11:41:45.998526)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ============ THE BARREL HOUSE ============
# ==========================================
#
#
#
# ========================== (2020-09-12 11:41:46.267528)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# =========================== (2020-09-12 11:41:46.275529)
# ==== OPTIMIZING P0+Sim ====
# ==== THE BARREL HOUSE =====
# ===========================
#
#
#
# ========================== (2020-09-12 11:43:41.688486)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-12 11:43:41.895483)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-12 11:43:41.903484)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ...
# 3  3      mean   0.067342         []
# 4  4      mean   0.937353         []
#
#                                            All RMSEs  \
# 0  [[0.0935827577097994, 0.10896925774528339, 0.0...
# 1  [[0.17264955504702825, 0.17422646327023725, 0....
# 2  [[0.4363032505606732, 0.3550157822095886, 0.22...
# 3  [[0.09595064453644367, 0.12091221353553756, 0....
# 4  [[1.3999605830522073, 1.1623286518962974, 0.93...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 4  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-12 13:05:35.581020)
# ==== Multivar P0 ====
# ======= SPECS =======
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  4.1min remaining:  6.1min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  5.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-12 13:10:56.496840)
# ==== Multivar P0+Sim ====
# ========= SPECS =========
# =========================
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  3.1min remaining:  4.6min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  4.5min finished
# =================== (2020-09-12 13:15:28.000152)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ========================== (2020-09-12 13:15:28.010153)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ========= SPECS ==========
# =========== 2 ============
# ==========================
#
#
#
# =========================== (2020-09-12 13:15:28.011157)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ========== SPECS ==========
# ============ 2 ============
# ===========================
#
#
#
# ================== (2020-09-12 13:15:28.013154)
# ==== GET DATA ====
# ===== SPECS ======
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS TENN HNY WHSKY  1L', '4': 'GENTLEMAN JACK WHSKY OL 750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 8.433734939759036
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1']
# % of weeks without a purchase: 2.4096385542168677
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '2']
# % of weeks without a purchase: 14.457831325301203
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 750M
#
#
# ==================== (2020-09-12 13:16:25.136671)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (82, 5) (1, 5)
#
#
# ======================== (2020-09-12 13:16:25.141670)
# ==== NAIVE FORECAST ====
# ======== SPECS =========
# ========================
#
#
#
# =============== (2020-09-12 13:16:25.160672)
# ==== MASK =====
# ==== SPECS ====
# ===============
#
# Mask: [False, False, False, False, False]
#
#
# =============== (2020-09-12 13:16:25.163671)
# ==== SPACE ====
# ==== SPECS ====
# ===============
#
#
#
# ==================== (2020-09-12 13:16:25.177670)
# ==== Test Index ====
# ====== SPECS =======
# ====================
#
#
#
# ========================= (2020-09-12 13:16:25.179670)
# ==== GET FUNCTION P0 ====
# ========= SPECS =========
# =========================
#
#
#
# ====================================== (2020-09-12 13:16:25.180672)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# =============== SPECS ================
# ======================================
#
#
#
# =================== (2020-09-12 13:16:25.341670)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ======================= (2020-09-12 13:16:25.347671)
# ==== OPTIMIZING P0 ====
# ======== SPECS ========
# =======================
#
#
#
# =================== (2020-09-12 13:17:42.431186)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ============================= (2020-09-12 13:17:42.580189)
# ==== GET FUNCTION P0+Sim ====
# =========== SPECS ===========
# =============================
#
#
#
# ========================================== (2020-09-12 13:17:42.581187)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ================= SPECS ==================
# ==========================================
#
#
#
# =================== (2020-09-12 13:17:42.717187)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =========================== (2020-09-12 13:17:42.724187)
# ==== OPTIMIZING P0+Sim ====
# ========== SPECS ==========
# ===========================
#
#
#
# =================== (2020-09-12 13:18:44.312188)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =================== (2020-09-12 13:18:44.470188)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ========================== (2020-09-12 13:18:44.478186)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ========= SPECS ==========
# =========== 3 ============
# ==========================
#
#
#
# ================== (2020-09-12 13:18:44.478186)
# ==== GET DATA ====
# ===== SPECS ======
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS TENN HNY WHSKY  1L', '4': 'GENTLEMAN JACK WHSKY OL 750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 8.536585365853659
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1']
# % of weeks without a purchase: 2.4390243902439024
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '2']
# % of weeks without a purchase: 14.634146341463413
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 750M
#
#
# ===================== (2020-09-12 13:19:39.038352)
# ==== WHITE NOISE ====
# ======= SPECS =======
# =====================
#
#       lb_stat  lb_pvalue
# 12  14.591506   0.264539
# 24  25.708961   0.368096
# 48  45.847359   0.561475
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12  28.056071   0.005429
# 24  39.797909   0.022480
# 48  52.199800   0.314062
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12  26.241054   0.009922
# 24  37.090548   0.042858
# 48  54.361071   0.245108
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12   6.530656   0.887010
# 24  11.020075   0.988868
# 48  32.169399   0.961455
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12  25.969942   0.010839
# 24  48.789512   0.002013
# 48  61.783156   0.087302
#
# Is Data White Noise: True
#
#
# ==================== (2020-09-12 13:19:39.066352)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (81, 5) (1, 5)
# (81, 5) (1, 5)
# (81, 5) (1, 5)
# (81, 5) (1, 5)
# (81, 5) (1, 5)
#
#
# =============== (2020-09-12 13:19:39.073351)
# ==== NAIVE ====
# ==== SPECS ====
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.051513         []
# 1  1      mean   0.109428         []
# 2  2      mean   0.221377         []
# 3  3      mean   0.086918         []
# 4  4      mean   0.971923         []
#
#                                            All RMSEs  \
# 0  [[0.12459174747365168, 0.13927072207458754, 0....
# 1  [[0.18390429323643792, 0.17762873456667566, 0....
# 2  [[0.4245652552570759, 0.3288519908859398, 0.22...
# 3  [[0.08808657027865822, 0.126322489261891, 0.08...
# 4  [[1.5669329860994465, 1.1153285005366258, 0.97...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 4  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-12 13:19:39.572351)
# ==== Multivar P0 ====
# ======= SPECS =======
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  4.1min remaining:  6.1min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  5.4min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-12 13:25:01.896265)
# ==== Multivar P0+Sim ====
# ========= SPECS =========
# =========================
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  2.9min remaining:  4.4min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  5.0min finished
# =================== (2020-09-12 13:30:02.588904)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ========================== (2020-09-12 13:30:02.598904)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ========= SPECS ==========
# =========== 3 ============
# ==========================
#
#
#
# =========================== (2020-09-12 13:30:02.598904)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ========== SPECS ==========
# ============ 3 ============
# ===========================
#
#
#
# ================== (2020-09-12 13:30:02.602907)
# ==== GET DATA ====
# ===== SPECS ======
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS TENN HNY WHSKY  1L', '4': 'GENTLEMAN JACK WHSKY OL 750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 8.536585365853659
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1']
# % of weeks without a purchase: 2.4390243902439024
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '2']
# % of weeks without a purchase: 14.634146341463413
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 750M
#
#
# ==================== (2020-09-12 13:31:02.097423)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (81, 5) (1, 5)
# (81, 5) (1, 5)
# (81, 5) (1, 5)
# (81, 5) (1, 5)
# (81, 5) (1, 5)
#
#
# ======================== (2020-09-12 13:31:02.108424)
# ==== NAIVE FORECAST ====
# ======== SPECS =========
# ========================
#
#
#
# =============== (2020-09-12 13:31:02.130423)
# ==== MASK =====
# ==== SPECS ====
# ===============
#
# Mask: [False, False, False, False, False]
#
#
# =============== (2020-09-12 13:31:02.133423)
# ==== SPACE ====
# ==== SPECS ====
# ===============
#
#
#
# ==================== (2020-09-12 13:31:02.141423)
# ==== Test Index ====
# ====== SPECS =======
# ====================
#
#
#
# ========================= (2020-09-12 13:31:02.143423)
# ==== GET FUNCTION P0 ====
# ========= SPECS =========
# =========================
#
#
#
# ====================================== (2020-09-12 13:31:02.144423)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# =============== SPECS ================
# ======================================
#
#
#
# =================== (2020-09-12 13:31:02.315424)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ======================= (2020-09-12 13:31:02.321424)
# ==== OPTIMIZING P0 ====
# ======== SPECS ========
# =======================
#
#
#
# =================== (2020-09-12 13:32:11.094936)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ============================= (2020-09-12 13:32:11.261936)
# ==== GET FUNCTION P0+Sim ====
# =========== SPECS ===========
# =============================
#
#
#
# ========================================== (2020-09-12 13:32:11.262934)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ================= SPECS ==================
# ==========================================
#
#
#
# =================== (2020-09-12 13:32:11.403934)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =========================== (2020-09-12 13:32:11.410937)
# ==== OPTIMIZING P0+Sim ====
# ========== SPECS ==========
# ===========================
#
#
#
# =================== (2020-09-12 13:33:12.954457)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =================== (2020-09-12 13:33:13.174459)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ========================== (2020-09-12 13:33:13.190460)
# ==== Saving to PICKLE ====
# ==== SUP PREM WHISKEY ====
# ==========================
#
# Pickle File  full_models_SUP PREM WHISKEY_Prod5_Sim2_Per123.pkl  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns
# Pickle File  full_opt_SUP PREM WHISKEY_Prod5_Sim2_Per123.pkl  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns
#
#
# ========================== (2020-09-12 13:33:13.411458)
# ==== Saving to EXCEL =====
# ==== SUP PREM WHISKEY ====
# ==========================
#
# EXCEL File  Output_SUP PREM WHISKEY_Prod5_Sim2_Per123.xlsx  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns

# %% [markdown]
# # Print out

# %% [markdown]
# ## Models

# %%
full_models[outputColsModels]
# Out:
#           Chain Master                          Product  Period to Last  \
# 4                          GENTLEMAN JACK WHSKY OL 750M               1
# 9                          GENTLEMAN JACK WHSKY OL 750M               2
# 14                         GENTLEMAN JACK WHSKY OL 750M               3
# 1                         JACK DANIELS BLK WHSKY  1.75L               1
# 6                         JACK DANIELS BLK WHSKY  1.75L               2
# 11                        JACK DANIELS BLK WHSKY  1.75L               3
# 0                            JACK DANIELS BLK WHSKY  1L               1
# 5                            JACK DANIELS BLK WHSKY  1L               2
# 10                           JACK DANIELS BLK WHSKY  1L               3
# 2                          JACK DANIELS BLK WHSKY  750M               1
# 7                          JACK DANIELS BLK WHSKY  750M               2
# 12                         JACK DANIELS BLK WHSKY  750M               3
# 3                        JACK DANIELS BLK WHSKY SQ 375M               1
# 8                        JACK DANIELS BLK WHSKY SQ 375M               2
# 13                       JACK DANIELS BLK WHSKY SQ 375M               3
# 49               SPECS     GENTLEMAN JACK WHSKY OL 750M               1
# 54               SPECS     GENTLEMAN JACK WHSKY OL 750M               2
# 59               SPECS     GENTLEMAN JACK WHSKY OL 750M               3
# 46               SPECS    JACK DANIELS BLK WHSKY  1.75L               1
# 51               SPECS    JACK DANIELS BLK WHSKY  1.75L               2
# 56               SPECS    JACK DANIELS BLK WHSKY  1.75L               3
# 45               SPECS       JACK DANIELS BLK WHSKY  1L               1
# 50               SPECS       JACK DANIELS BLK WHSKY  1L               2
# 55               SPECS       JACK DANIELS BLK WHSKY  1L               3
# 47               SPECS     JACK DANIELS BLK WHSKY  750M               1
# 52               SPECS     JACK DANIELS BLK WHSKY  750M               2
# 57               SPECS     JACK DANIELS BLK WHSKY  750M               3
# 48               SPECS  JACK DANIELS TENN HNY WHSKY  1L               1
# 53               SPECS  JACK DANIELS TENN HNY WHSKY  1L               2
# 58               SPECS  JACK DANIELS TENN HNY WHSKY  1L               3
# 19    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               1
# 24    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               2
# 29    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               3
# 17    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               1
# 22    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               2
# 27    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               3
# 15    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               1
# 20    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               2
# 25    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               3
# 16    THE BARREL HOUSE     JACK DANIELS BLK WHSKY  750M               1
# 21    THE BARREL HOUSE     JACK DANIELS BLK WHSKY  750M               2
# 26    THE BARREL HOUSE     JACK DANIELS BLK WHSKY  750M               3
# 18    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               1
# 23    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               2
# 28    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               3
# 34  WESTERN BEV LIQ TX     GENTLEMAN JACK WHSKY OL 750M               1
# 39  WESTERN BEV LIQ TX     GENTLEMAN JACK WHSKY OL 750M               2
# 44  WESTERN BEV LIQ TX     GENTLEMAN JACK WHSKY OL 750M               3
# 30  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               1
# 35  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               2
# 40  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               3
# 32  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               1
# 37  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               2
# 42  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               3
# 31  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               1
# 36  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               2
# 41  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               3
# 33  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               1
# 38  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               2
# 43  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               3
#
#     White Noise Naive Best Type  Naive Best RMSE P0 Best Model Name  \
# 4         False            mean         0.375053                 ML
# 9         False            mean         0.351197                 ML
# 14        False            mean         0.551268       auto_SARIMAX
# 1         False            last         0.324455       auto_SARIMAX
# 6         False            mean         0.323943       auto_SARIMAX
# 11        False            mean         0.319180       auto_SARIMAX
# 0          True            mean         0.043169            SARIMAX
# 5          True            mean         0.021557                 ML
# 10         True            mean         0.033917                 ML
# 2         False            mean         0.427990            SARIMAX
# 7         False            mean         0.373199            SARIMAX
# 12        False            mean         0.373056            SARIMAX
# 3         False            mean         0.798321                 ML
# 8         False            mean         0.669609                 ML
# 13        False            mean         0.627867       auto_SARIMAX
# 49        False            mean         0.930727                 ML
# 54         True            mean         0.937353                 ML
# 59         True            mean         0.971923            SARIMAX
# 46         True            mean         0.159196            SARIMAX
# 51         True            mean         0.118510            SARIMAX
# 56         True            mean         0.109428            SARIMAX
# 45         True            mean         0.060885            SARIMAX
# 50         True            mean         0.033192                 ML
# 55         True            mean         0.051513                 ML
# 47         True            mean         0.276661       auto_SARIMAX
# 52         True            mean         0.224583                 ML
# 57         True            mean         0.221377                 ML
# 48         True            mean         0.075384            SARIMAX
# 53         True            mean         0.067342            SARIMAX
# 58         True            mean         0.086918                 ML
# 19         True            mean         0.611153                 ML
# 24         True            mean         0.532525                 ML
# 29         True            last         0.514092                 ML
# 17        False            last         0.508452                 ML
# 22        False            last         0.397118                 ML
# 27        False            last         0.575651       auto_SARIMAX
# 15        False            mean         1.149908                 ML
# 20        False            last         1.279671                 ML
# 25        False            last         1.309084                 ML
# 16         True            mean         0.959053                 ML
# 21         True            mean         0.991773                 ML
# 26         True            mean         0.946888                 ML
# 18         True   seasonal_last         0.539165                 ML
# 23         True   seasonal_last         0.583337                 ML
# 28         True   seasonal_last         0.456328                 ML
# 34        False   seasonal_last         0.573136                 ML
# 39        False            mean         0.518960                 ML
# 44        False            mean         0.629861                 ML
# 30        False            mean         1.192388       auto_SARIMAX
# 35        False            mean         1.152468       auto_SARIMAX
# 40        False            last         1.110996       auto_SARIMAX
# 32        False            mean         0.083096                 ML
# 37        False            mean         0.065297                 ML
# 42        False            mean         0.056411            SARIMAX
# 31        False            mean         0.706690            SARIMAX
# 36        False            mean         0.620501            SARIMAX
# 41        False            mean         0.664711                 ML
# 33        False            mean         0.804074       auto_SARIMAX
# 38        False            mean         0.675541            Prophet
# 43        False            mean         0.630851       auto_SARIMAX
#
#     P0 Best Model RMSE P0+Sim Best Model Name  P0+Sim Best Model RMSE
# 4             0.253176                     ML                0.256816
# 9             0.293141           auto_SARIMAX                0.284835
# 14            0.299190           auto_SARIMAX                0.292425
# 1             0.243913           auto_SARIMAX                0.240036
# 6             0.219089           auto_SARIMAX                0.242885
# 11            0.231060                     ML                0.239514
# 0             0.028845                SARIMAX                0.021750
# 5             0.034618                     ML                0.030959
# 10            0.057793                     ML                0.051629
# 2             0.260258           auto_SARIMAX                0.311017
# 7             0.276076           auto_SARIMAX                0.293355
# 12            0.294087           auto_SARIMAX                0.278064
# 3             0.625328                     ML                0.550441
# 8             0.678531                     ML                0.614604
# 13            0.631077           auto_SARIMAX                0.546198
# 49            0.607617                     ML                0.587064
# 54            0.701946                     ML                0.691092
# 59            0.590387           auto_SARIMAX                0.661227
# 46            0.106995                SARIMAX                0.146993
# 51            0.095943                SARIMAX                0.129294
# 56            0.097419                SARIMAX                0.152967
# 45            0.036516                     ML                0.036515
# 50            0.048617                     ML                0.043980
# 55            0.078627                     ML                0.065205
# 47            0.257020           auto_SARIMAX                0.249692
# 52            0.247969                SARIMAX                0.234468
# 57            0.272304           auto_SARIMAX                0.264599
# 48            0.047686                SARIMAX                0.048203
# 53            0.067426                SARIMAX                0.068372
# 58            0.082990                     ML                0.082971
# 19            0.191544                     ML                0.191544
# 24            0.210643                     ML                0.210643
# 29            0.238877                     ML                0.235016
# 17            0.615271                     ML                0.615245
# 22            0.614912                     ML                0.615062
# 27            0.752658           auto_SARIMAX                0.740816
# 15            0.722963                SARIMAX                0.792720
# 20            0.733968                     ML                0.812910
# 25            0.634989                     ML                0.707394
# 16            0.747042                     ML                0.747063
# 21            0.775621                     ML                0.805202
# 26            0.827664                     ML                0.813328
# 18            0.141021                     ML                0.141353
# 23            0.152653                     ML                0.157201
# 28            0.152653                     ML                0.157201
# 34            0.423880                     ML                0.423901
# 39            0.582202                     ML                0.582221
# 44            0.634333                Prophet                0.632916
# 30            0.737526           auto_SARIMAX                0.671420
# 35            0.791896           auto_SARIMAX                0.769547
# 40            0.654468           auto_SARIMAX                0.719308
# 32            0.099956                     ML                0.099927
# 37            0.108532                     ML                0.108481
# 42            0.111910                SARIMAX                0.074185
# 31            0.577988           auto_SARIMAX                0.504248
# 36            0.580915           auto_SARIMAX                0.518207
# 41            0.638930           auto_SARIMAX                0.573150
# 33            0.663140                     ML                0.570431
# 38            0.715019                     ML                0.653154
# 43            0.629432           auto_SARIMAX                0.652129

# %% [markdown]
# ## Optimizer

# %% [markdown]
# ### Summary by Chain

# %%
full_chain_summary
# Out:
#          Chain Master  P0 Non-Opt Revenue  P0 Opt Revenue  P0 Opt Diff  \
# 0                                292522.0        287912.0      -4610.0
# 1               SPECS            222796.0        222969.0        173.0
# 2    THE BARREL HOUSE              5145.0          5217.0         72.0
# 3  WESTERN BEV LIQ TX            121244.0        137371.0      16127.0
#
#    P0 Opt Diff Ratio  P0+Sim Non-Opt Revenue  P0+Sim Opt Revenue  \
# 0           0.984241                272869.0            308160.0
# 1           1.000776                230735.0            764572.0
# 2           1.013994                  7833.0           1438729.0
# 3           1.133013                 93930.0           1577793.0
#
#    P0+Sim Opt Diff  P0+Sim Opt Diff Ratio
# 0          35291.0               1.129333
# 1         533837.0               3.313637
# 2        1430896.0             183.675348
# 3        1483863.0              16.797541

# %%
print("WRITE this value in the summary table in Git hub --->",round(full_chain_summary[full_chain_summary['Chain Master']=='']['P0+Sim Opt Diff Ratio'].item(),4))
# Out:
# WRITE this value in the summary table in Git hub ---> 1.1293

# %% [markdown]
# Link to the Git Hub Summary Table: https://github.com/ngupta23/msds_capstone/issues/84

# %% [markdown]
# ### Summary by Chain and Product

# %%
full_summary
# Out:
#           Chain Master                          Product  P0 Non-Opt Revenue  \
# 0                          GENTLEMAN JACK WHSKY OL 750M              2952.0
# 1                         JACK DANIELS BLK WHSKY  1.75L             78808.0
# 2                            JACK DANIELS BLK WHSKY  1L            162183.0
# 3                          JACK DANIELS BLK WHSKY  750M             47810.0
# 4                        JACK DANIELS BLK WHSKY SQ 375M               769.0
# 5                SPECS     GENTLEMAN JACK WHSKY OL 750M              2764.0
# 6                SPECS    JACK DANIELS BLK WHSKY  1.75L             31102.0
# 7                SPECS       JACK DANIELS BLK WHSKY  1L            163171.0
# 8                SPECS     JACK DANIELS BLK WHSKY  750M             14658.0
# 9                SPECS  JACK DANIELS TENN HNY WHSKY  1L             11101.0
# 10    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L              1157.0
# 11    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               334.0
# 12    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               866.0
# 13    THE BARREL HOUSE     JACK DANIELS BLK WHSKY  750M              1043.0
# 14    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L              1745.0
# 15  WESTERN BEV LIQ TX     GENTLEMAN JACK WHSKY OL 750M              5000.0
# 16  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L             18820.0
# 17  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L             48563.0
# 18  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M             35987.0
# 19  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M             12874.0
#
#     P0 Opt Revenue  P0 Opt Diff  P0 Opt Diff Ratio  P0+Sim Non-Opt Revenue  \
# 0           3171.0        219.0           1.074187                 12309.0
# 1          78694.0       -114.0           0.998553                 51425.0
# 2         160556.0      -1627.0           0.989968                163994.0
# 3          44696.0      -3114.0           0.934867                 44356.0
# 4            795.0         26.0           1.033810                   785.0
# 5           2769.0          5.0           1.001809                   505.0
# 6          29224.0      -1878.0           0.939618                 46794.0
# 7         158304.0      -4867.0           0.970172                162021.0
# 8          22475.0       7817.0           1.533292                 10345.0
# 9          10197.0       -904.0           0.918566                 11070.0
# 10          1176.0         19.0           1.016422                  1157.0
# 11           338.0          4.0           1.011976                   779.0
# 12           857.0         -9.0           0.989607                  3039.0
# 13          1112.0         69.0           1.066155                   869.0
# 14          1734.0        -11.0           0.993696                  1989.0
# 15          5637.0        637.0           1.127400                  4933.0
# 16         29848.0      11028.0           1.585972                 24646.0
# 17         47952.0       -611.0           0.987418                 53166.0
# 18         36506.0        519.0           1.014422                 10896.0
# 19         17428.0       4554.0           1.353736                   289.0
#
#     P0+Sim Opt Revenue  P0+Sim Opt Diff  P0+Sim Opt Diff Ratio
# 0               9611.0          -2698.0               0.780811
# 1              66697.0          15272.0               1.296976
# 2             166651.0           2657.0               1.016202
# 3              64458.0          20102.0               1.453197
# 4                743.0            -42.0               0.946497
# 5                499.0             -6.0               0.988119
# 6             576059.0         529265.0              12.310531
# 7             160932.0          -1089.0               0.993279
# 8              17067.0           6722.0               1.649783
# 9              10015.0          -1055.0               0.904697
# 10              1165.0              8.0               1.006914
# 11              1309.0            530.0               1.680359
# 12           1433452.0        1430413.0             471.685423
# 13               859.0            -10.0               0.988493
# 14              1944.0            -45.0               0.977376
# 15              5499.0            566.0               1.114737
# 16             21851.0          -2795.0               0.886594
# 17             42517.0         -10649.0               0.799703
# 18             11338.0            442.0               1.040565
# 19           1496588.0        1496299.0            5178.505190

# %% [markdown]
# ### P0 Optimizer

# %%
full_opt[outputColsOptP0]
# Out:
#           Chain Master                          Product  Period to Last  \
# 4                          GENTLEMAN JACK WHSKY OL 750M               1
# 9                          GENTLEMAN JACK WHSKY OL 750M               2
# 14                         GENTLEMAN JACK WHSKY OL 750M               3
# 1                         JACK DANIELS BLK WHSKY  1.75L               1
# 6                         JACK DANIELS BLK WHSKY  1.75L               2
# 11                        JACK DANIELS BLK WHSKY  1.75L               3
# 0                            JACK DANIELS BLK WHSKY  1L               1
# 5                            JACK DANIELS BLK WHSKY  1L               2
# 10                           JACK DANIELS BLK WHSKY  1L               3
# 2                          JACK DANIELS BLK WHSKY  750M               1
# 7                          JACK DANIELS BLK WHSKY  750M               2
# 12                         JACK DANIELS BLK WHSKY  750M               3
# 3                        JACK DANIELS BLK WHSKY SQ 375M               1
# 8                        JACK DANIELS BLK WHSKY SQ 375M               2
# 13                       JACK DANIELS BLK WHSKY SQ 375M               3
# 49               SPECS     GENTLEMAN JACK WHSKY OL 750M               1
# 54               SPECS     GENTLEMAN JACK WHSKY OL 750M               2
# 59               SPECS     GENTLEMAN JACK WHSKY OL 750M               3
# 46               SPECS    JACK DANIELS BLK WHSKY  1.75L               1
# 51               SPECS    JACK DANIELS BLK WHSKY  1.75L               2
# 56               SPECS    JACK DANIELS BLK WHSKY  1.75L               3
# 45               SPECS       JACK DANIELS BLK WHSKY  1L               1
# 50               SPECS       JACK DANIELS BLK WHSKY  1L               2
# 55               SPECS       JACK DANIELS BLK WHSKY  1L               3
# 47               SPECS     JACK DANIELS BLK WHSKY  750M               1
# 52               SPECS     JACK DANIELS BLK WHSKY  750M               2
# 57               SPECS     JACK DANIELS BLK WHSKY  750M               3
# 48               SPECS  JACK DANIELS TENN HNY WHSKY  1L               1
# 53               SPECS  JACK DANIELS TENN HNY WHSKY  1L               2
# 58               SPECS  JACK DANIELS TENN HNY WHSKY  1L               3
# 19    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               1
# 24    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               2
# 29    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               3
# 17    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               1
# 22    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               2
# 27    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               3
# 15    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               1
# 20    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               2
# 25    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               3
# 16    THE BARREL HOUSE     JACK DANIELS BLK WHSKY  750M               1
# 21    THE BARREL HOUSE     JACK DANIELS BLK WHSKY  750M               2
# 26    THE BARREL HOUSE     JACK DANIELS BLK WHSKY  750M               3
# 18    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               1
# 23    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               2
# 28    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               3
# 34  WESTERN BEV LIQ TX     GENTLEMAN JACK WHSKY OL 750M               1
# 39  WESTERN BEV LIQ TX     GENTLEMAN JACK WHSKY OL 750M               2
# 44  WESTERN BEV LIQ TX     GENTLEMAN JACK WHSKY OL 750M               3
# 30  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               1
# 35  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               2
# 40  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               3
# 32  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               1
# 37  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               2
# 42  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               3
# 31  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               1
# 36  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               2
# 41  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               3
# 33  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               1
# 38  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               2
# 43  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               3
#
#     P0 Non-Opt Price  P0 Non-Opt Demand  P0 Non-Opt Revenue  \
# 4             245.31                  2                 473
# 9             241.44                  2                 430
# 14            252.77                  8                2049
# 1             185.65                224               41518
# 6             184.71                 91               16867
# 11            182.45                112               20423
# 0             229.81                310               71287
# 5             229.69                196               45027
# 10            230.09                199               45869
# 2             222.36                159               35308
# 7             222.36                 45               10052
# 12            222.36                 11                2450
# 3             188.30                  0                  93
# 8             195.60                  0                  96
# 13            195.60                  3                 580
# 49            241.44                  1                 193
# 54            241.44                  1                 254
# 59            241.44                 10                2317
# 46            185.59                 51                9481
# 51            184.56                 61               11168
# 56            184.94                 57               10453
# 45            229.53                239               54868
# 50            229.53                236               54108
# 55            229.53                236               54195
# 47            222.36                 20                4519
# 52            222.36                 23                5072
# 57            222.36                 23                5067
# 48            229.53                 16                3714
# 53            229.53                 16                3763
# 58            229.53                 16                3624
# 19            286.87                  1                 426
# 24            292.57                  2                 457
# 29            298.08                  1                 274
# 17            274.14                  0                  34
# 22            291.93                  0                  37
# 27            291.93                  1                 263
# 15            239.01                  1                 287
# 20            239.01                  1                 287
# 25            234.05                  1                 292
# 16            222.36                  0                  28
# 21            222.36                  0                  18
# 26            222.36                  4                 997
# 18            239.01                  2                 583
# 23            238.41                  2                 581
# 28            238.41                  2                 581
# 34            241.44                  7                1684
# 39            241.44                  7                1641
# 44            258.00                  6                1675
# 30            185.59                 96               17837
# 35            185.59                  4                 706
# 40            180.46                  2                 277
# 32            230.79                 59               13543
# 37            229.89                 59               13491
# 42            230.98                 93               21529
# 31            222.36                148               32964
# 36            222.36                  8                1783
# 41            222.36                  6                1240
# 33            188.30                  9                1770
# 38            195.60                 56               10948
# 43            195.60                  1                 156
#
#     P0 Non-Opt Chain Master Revenue  P0 Optimal Price  P0 Demand  P0 Revenue  \
# 4                            148679            278.89          2         538
# 9                             72472            243.03          2         433
# 14                            71371            243.61          9        2200
# 1                            148679            184.43        218       40150
# 6                             72472            185.32         93       17148
# 11                            71371            185.32        115       21396
# 0                            148679            229.67        309       70980
# 5                             72472            226.56        196       44413
# 10                            71371            226.54        199       45163
# 2                            148679            218.17        152       33065
# 7                             72472            220.30         43        9428
# 12                            71371            220.30         10        2203
# 3                            148679            224.73          0         111
# 8                             72472            191.02          0          94
# 13                            71371            191.01          3         590
# 49                            72775            273.74          1         219
# 54                            74365            271.19          1         286
# 59                            75658            242.60          9        2264
# 46                            72775            179.69         45        8041
# 51                            74365            183.53         59       10854
# 56                            75658            184.51         56       10329
# 45                            72775            226.86        224       50881
# 50                            74365            229.28        236       54048
# 55                            75658            226.06        236       53375
# 47                            72775            204.37         61       12536
# 52                            74365            216.68         23        4942
# 57                            75658            219.26         23        4997
# 48                            72775            220.33         14        3187
# 53                            74365            226.76         16        3593
# 58                            75658            216.39         16        3417
# 19                             1358            296.39          1         440
# 24                             1380            296.39          2         463
# 29                             2408            296.39          1         273
# 17                             1358            294.20          0          37
# 22                             1380            294.20          0          37
# 27                             2408            294.20          1         264
# 15                             1358            234.70          1         282
# 20                             1380            234.70          1         282
# 25                             2408            234.70          1         293
# 16                             1358            237.05          0          30
# 21                             1380            237.05          0          19
# 26                             2408            237.05          4        1063
# 18                             1358            237.08          2         578
# 23                             1380            237.08          2         578
# 28                             2408            237.08          2         578
# 34                            67798            276.54          7        1928
# 39                            28569            279.60          7        1900
# 44                            24878            278.66          6        1809
# 30                            67798            191.04        152       29049
# 35                            28569            174.94          2         295
# 40                            24878            190.06          3         504
# 32                            67798            221.73         59       13011
# 37                            28569            229.96         59       13495
# 42                            24878            230.67         93       21446
# 31                            67798            218.66        153       33554
# 36                            28569            220.67          8        1777
# 41                            24878            210.59          6        1175
# 33                            67798            184.33         10        1834
# 38                            28569            180.04         86       15449
# 43                            24878            213.94          1         145
#
#     P0 Chain Master Revenue
# 4                    144844
# 9                     71517
# 14                    71552
# 1                    144844
# 6                     71517
# 11                    71552
# 0                    144844
# 5                     71517
# 10                    71552
# 2                    144844
# 7                     71517
# 12                    71552
# 3                    144844
# 8                     71517
# 13                    71552
# 49                    74864
# 54                    73724
# 59                    74382
# 46                    74864
# 51                    73724
# 56                    74382
# 45                    74864
# 50                    73724
# 55                    74382
# 47                    74864
# 52                    73724
# 57                    74382
# 48                    74864
# 53                    73724
# 58                    74382
# 19                     1366
# 24                     1379
# 29                     2470
# 17                     1366
# 22                     1379
# 27                     2470
# 15                     1366
# 20                     1379
# 25                     2470
# 16                     1366
# 21                     1379
# 26                     2470
# 18                     1366
# 23                     1379
# 28                     2470
# 34                    79378
# 39                    32915
# 44                    25079
# 30                    79378
# 35                    32915
# 40                    25079
# 32                    79378
# 37                    32915
# 42                    25079
# 31                    79378
# 36                    32915
# 41                    25079
# 33                    79378
# 38                    32915
# 43                    25079

# %% [markdown]
# ### P0+Sim Optimizer

# %%
full_opt[outputColsOptP0Sim]
# Out:
#           Chain Master                          Product  Period to Last  \
# 4                          GENTLEMAN JACK WHSKY OL 750M               1
# 9                          GENTLEMAN JACK WHSKY OL 750M               2
# 14                         GENTLEMAN JACK WHSKY OL 750M               3
# 1                         JACK DANIELS BLK WHSKY  1.75L               1
# 6                         JACK DANIELS BLK WHSKY  1.75L               2
# 11                        JACK DANIELS BLK WHSKY  1.75L               3
# 0                            JACK DANIELS BLK WHSKY  1L               1
# 5                            JACK DANIELS BLK WHSKY  1L               2
# 10                           JACK DANIELS BLK WHSKY  1L               3
# 2                          JACK DANIELS BLK WHSKY  750M               1
# 7                          JACK DANIELS BLK WHSKY  750M               2
# 12                         JACK DANIELS BLK WHSKY  750M               3
# 3                        JACK DANIELS BLK WHSKY SQ 375M               1
# 8                        JACK DANIELS BLK WHSKY SQ 375M               2
# 13                       JACK DANIELS BLK WHSKY SQ 375M               3
# 49               SPECS     GENTLEMAN JACK WHSKY OL 750M               1
# 54               SPECS     GENTLEMAN JACK WHSKY OL 750M               2
# 59               SPECS     GENTLEMAN JACK WHSKY OL 750M               3
# 46               SPECS    JACK DANIELS BLK WHSKY  1.75L               1
# 51               SPECS    JACK DANIELS BLK WHSKY  1.75L               2
# 56               SPECS    JACK DANIELS BLK WHSKY  1.75L               3
# 45               SPECS       JACK DANIELS BLK WHSKY  1L               1
# 50               SPECS       JACK DANIELS BLK WHSKY  1L               2
# 55               SPECS       JACK DANIELS BLK WHSKY  1L               3
# 47               SPECS     JACK DANIELS BLK WHSKY  750M               1
# 52               SPECS     JACK DANIELS BLK WHSKY  750M               2
# 57               SPECS     JACK DANIELS BLK WHSKY  750M               3
# 48               SPECS  JACK DANIELS TENN HNY WHSKY  1L               1
# 53               SPECS  JACK DANIELS TENN HNY WHSKY  1L               2
# 58               SPECS  JACK DANIELS TENN HNY WHSKY  1L               3
# 19    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               1
# 24    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               2
# 29    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               3
# 17    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               1
# 22    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               2
# 27    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               3
# 15    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               1
# 20    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               2
# 25    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               3
# 16    THE BARREL HOUSE     JACK DANIELS BLK WHSKY  750M               1
# 21    THE BARREL HOUSE     JACK DANIELS BLK WHSKY  750M               2
# 26    THE BARREL HOUSE     JACK DANIELS BLK WHSKY  750M               3
# 18    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               1
# 23    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               2
# 28    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               3
# 34  WESTERN BEV LIQ TX     GENTLEMAN JACK WHSKY OL 750M               1
# 39  WESTERN BEV LIQ TX     GENTLEMAN JACK WHSKY OL 750M               2
# 44  WESTERN BEV LIQ TX     GENTLEMAN JACK WHSKY OL 750M               3
# 30  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               1
# 35  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               2
# 40  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               3
# 32  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               1
# 37  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               2
# 42  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               3
# 31  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               1
# 36  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               2
# 41  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               3
# 33  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               1
# 38  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               2
# 43  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               3
#
#     P0+Sim Non-Opt Price  P0+Sim Non-Opt Demand  P0+Sim Non-Opt Revenue  \
# 4                 245.31                      1                     220
# 9                 241.44                     30                    7176
# 14                252.77                     19                    4913
# 1                 185.65                    149                   27660
# 6                 184.71                     82                   15073
# 11                182.45                     48                    8692
# 0                 229.81                    318                   73098
# 5                 229.69                    196                   45027
# 10                230.09                    199                   45869
# 2                 222.36                     94                   21010
# 7                 222.36                     47                   10373
# 12                222.36                     58                   12973
# 3                 188.30                      0                      87
# 8                 195.60                      0                      91
# 13                195.60                      3                     607
# 49                241.44                      1                     163
# 54                241.44                      1                     188
# 59                241.44                      1                     154
# 46                185.59                     65                   12072
# 51                184.56                    101                   18571
# 56                184.94                     87                   16151
# 45                229.53                    246                   56559
# 50                229.53                    230                   52812
# 55                229.53                    229                   52650
# 47                222.36                     17                    3886
# 52                222.36                     21                    4581
# 57                222.36                      8                    1878
# 48                229.53                     16                    3701
# 53                229.53                     16                    3746
# 58                229.53                     16                    3623
# 19                286.87                      1                     426
# 24                292.57                      2                     457
# 29                298.08                      1                     274
# 17                274.14                      0                      35
# 22                291.93                      0                      37
# 27                291.93                      2                     707
# 15                239.01                     10                    2328
# 20                239.01                      2                     371
# 25                234.05                      1                     340
# 16                222.36                      0                      28
# 21                222.36                      0                      46
# 26                222.36                      4                     795
# 18                239.01                      3                     653
# 23                238.41                      3                     668
# 28                238.41                      3                     668
# 34                241.44                      7                    1684
# 39                241.44                      7                    1641
# 44                258.00                      6                    1608
# 30                185.59                    129                   23867
# 35                185.59                      2                     458
# 40                180.46                      2                     321
# 32                230.79                     59                   13548
# 37                229.89                     59                   13496
# 42                230.98                    113                   26122
# 31                222.36                     32                    7166
# 36                222.36                     11                    2351
# 41                222.36                      6                    1379
# 33                188.30                      1                      97
# 38                195.60                      0                      82
# 43                195.60                      1                     110
#
#     P0+Sim Non-Opt Chain Master Revenue  P0+Sim Optimal Price  P0+Sim Demand  \
# 4                                122075                250.68              1
# 9                                 77740                250.62             22
# 14                                73055                251.10             16
# 1                                122075                171.32            220
# 6                                 77740                171.24            122
# 11                                73055                171.17             48
# 0                                122075                228.80            333
# 5                                 77740                228.79            196
# 10                                73055                228.79            199
# 2                                122075                219.01            142
# 7                                 77740                219.00             72
# 12                                73055                219.00             80
# 3                                122075                186.06              0
# 8                                 77740                186.05              0
# 13                                73055                186.04              3
# 49                                76381                275.23              1
# 54                                79899                275.23              1
# 59                                74455                275.23              0
# 46                                76381                168.09            159
# 51                                79899                167.92           1747
# 56                                74455                167.75           1526
# 45                                76381                227.99            246
# 50                                79899                227.99            230
# 55                                74455                227.99            229
# 47                                76381                223.84             45
# 52                                79899                223.84             11
# 57                                74455                223.84             21
# 48                                76381                223.44             14
# 53                                79899                223.44             15
# 58                                74455                223.44             16
# 19                                 3470                295.26              1
# 24                                 1579                296.39              2
# 29                                 2785                287.68              1
# 17                                 3470                301.08              0
# 22                                 1579                294.20              0
# 27                                 2785                302.16              4
# 15                                 3470                222.60           6436
# 20                                 1579                234.70              2
# 25                                 2785                227.43              1
# 16                                 3470                221.99              0
# 21                                 1579                237.05              0
# 26                                 2785                218.70              4
# 18                                 3470                232.58              3
# 23                                 1579                237.08              3
# 28                                 2785                230.22              3
# 34                                46363                251.29              7
# 39                                18028                258.92              7
# 44                                29540                264.04              8
# 30                                46363                190.96            114
# 35                                18028                174.24              1
# 40                                29540                186.66              0
# 32                                46363                226.37             59
# 37                                18028                225.58             59
# 42                                29540                214.86             74
# 31                                46363                222.51             31
# 36                                18028                224.21             15
# 41                                29540                211.08              5
# 33                                46363                192.69              1
# 38                                18028                229.35              0
# 43                                29540                190.68           7848
#
#     P0+Sim Revenue  P0+Sim Chain Master Revenue
# 4              225                       145265
# 9             5424                        86988
# 14            3962                        75908
# 1            37732                       145265
# 6            20810                        86988
# 11            8155                        75908
# 0            76188                       145265
# 5            44852                        86988
# 10           45611                        75908
# 2            31034                       145265
# 7            15816                        86988
# 12           17608                        75908
# 3               86                       145265
# 8               86                        86988
# 13             571                        75908
# 49             185                        96392
# 54             214                       351601
# 59             100                       316580
# 46           26779                        96392
# 51          293294                       351601
# 56          255986                       316580
# 45           56180                        96392
# 50           52457                       351601
# 55           52295                       316580
# 47           10027                        96392
# 52            2368                       351601
# 57            4672                       316580
# 48            3221                        96392
# 53            3268                       351601
# 58            3526                       316580
# 19             438                      1433897
# 24             463                         1578
# 29             264                         3256
# 17              38                      1433897
# 22              37                         1578
# 27            1234                         3256
# 15         1432757                      1433897
# 20             364                         1578
# 25             331                         3256
# 16              28                      1433897
# 21              49                         1578
# 26             782                         3256
# 18             635                      1433897
# 23             664                         1578
# 28             645                         3256
# 34            1753                        43790
# 39            1760                        18597
# 44            1986                      1515405
# 30           21677                        43790
# 35             153                        18597
# 40              21                      1515405
# 32           13289                        43790
# 37           13242                        18597
# 42           15986                      1515405
# 31            6973                        43790
# 36            3345                        18597
# 41            1020                      1515405
# 33              99                        43790
# 38              96                        18597
# 43         1496393                      1515405

# %% [markdown]
# ### Naive

# %%
full_opt[outputColsOptNaive]
# Out:
#           Chain Master                          Product  Period to Last  \
# 4                          GENTLEMAN JACK WHSKY OL 750M               1
# 9                          GENTLEMAN JACK WHSKY OL 750M               2
# 14                         GENTLEMAN JACK WHSKY OL 750M               3
# 1                         JACK DANIELS BLK WHSKY  1.75L               1
# 6                         JACK DANIELS BLK WHSKY  1.75L               2
# 11                        JACK DANIELS BLK WHSKY  1.75L               3
# 0                            JACK DANIELS BLK WHSKY  1L               1
# 5                            JACK DANIELS BLK WHSKY  1L               2
# 10                           JACK DANIELS BLK WHSKY  1L               3
# 2                          JACK DANIELS BLK WHSKY  750M               1
# 7                          JACK DANIELS BLK WHSKY  750M               2
# 12                         JACK DANIELS BLK WHSKY  750M               3
# 3                        JACK DANIELS BLK WHSKY SQ 375M               1
# 8                        JACK DANIELS BLK WHSKY SQ 375M               2
# 13                       JACK DANIELS BLK WHSKY SQ 375M               3
# 49               SPECS     GENTLEMAN JACK WHSKY OL 750M               1
# 54               SPECS     GENTLEMAN JACK WHSKY OL 750M               2
# 59               SPECS     GENTLEMAN JACK WHSKY OL 750M               3
# 46               SPECS    JACK DANIELS BLK WHSKY  1.75L               1
# 51               SPECS    JACK DANIELS BLK WHSKY  1.75L               2
# 56               SPECS    JACK DANIELS BLK WHSKY  1.75L               3
# 45               SPECS       JACK DANIELS BLK WHSKY  1L               1
# 50               SPECS       JACK DANIELS BLK WHSKY  1L               2
# 55               SPECS       JACK DANIELS BLK WHSKY  1L               3
# 47               SPECS     JACK DANIELS BLK WHSKY  750M               1
# 52               SPECS     JACK DANIELS BLK WHSKY  750M               2
# 57               SPECS     JACK DANIELS BLK WHSKY  750M               3
# 48               SPECS  JACK DANIELS TENN HNY WHSKY  1L               1
# 53               SPECS  JACK DANIELS TENN HNY WHSKY  1L               2
# 58               SPECS  JACK DANIELS TENN HNY WHSKY  1L               3
# 19    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               1
# 24    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               2
# 29    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               3
# 17    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               1
# 22    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               2
# 27    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               3
# 15    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               1
# 20    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               2
# 25    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               3
# 16    THE BARREL HOUSE     JACK DANIELS BLK WHSKY  750M               1
# 21    THE BARREL HOUSE     JACK DANIELS BLK WHSKY  750M               2
# 26    THE BARREL HOUSE     JACK DANIELS BLK WHSKY  750M               3
# 18    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               1
# 23    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               2
# 28    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               3
# 34  WESTERN BEV LIQ TX     GENTLEMAN JACK WHSKY OL 750M               1
# 39  WESTERN BEV LIQ TX     GENTLEMAN JACK WHSKY OL 750M               2
# 44  WESTERN BEV LIQ TX     GENTLEMAN JACK WHSKY OL 750M               3
# 30  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               1
# 35  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               2
# 40  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               3
# 32  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               1
# 37  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               2
# 42  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               3
# 31  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               1
# 36  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               2
# 41  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               3
# 33  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               1
# 38  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               2
# 43  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               3
#
#     Actual Price  Actual Demand  Actual Revenue  Actual Chain Master Revenue  \
# 4     245.305091         110.00        26983.56                    308473.38
# 9     241.440000          25.00         6036.00                     93723.18
# 14    252.770526          19.00         4802.64                    133827.30
# 1     185.650112         389.61        72331.14                    308473.38
# 6     184.710623          40.95         7563.90                     93723.18
# 11    182.449915         263.25        48029.94                    133827.30
# 0     229.811232         589.19       135402.48                    308473.38
# 5     229.687258         301.91        69344.88                     93723.18
# 10    230.085045         316.54        72831.12                    133827.30
# 2     222.360000         225.00        50031.00                    308473.38
# 7     222.360000          30.00         6670.80                     93723.18
# 12    222.360000          20.00         4447.20                    133827.30
# 3     188.295238         126.00        23725.20                    308473.38
# 8     195.600000          21.00         4107.60                     93723.18
# 13    195.600000          19.00         3716.40                    133827.30
# 49    241.440000          42.00        10140.48                    172140.90
# 54    241.440000          12.00         2897.28                     71407.56
# 59    241.440000           6.00         1448.64                     84647.04
# 46    185.589744         176.67        32788.14                    172140.90
# 51    184.564103          35.10         6478.20                     71407.56
# 56    184.935385         117.00        21637.44                     84647.04
# 45    229.533835         476.14       109290.24                    172140.90
# 50    229.533835         240.73        55255.68                     71407.56
# 55    229.533835         238.07        54645.12                     84647.04
# 47    222.360000          69.00        15342.84                    172140.90
# 52    222.360000          14.00         3113.04                     71407.56
# 57    222.360000          16.00         3557.76                     84647.04
# 48    229.533835          19.95         4579.20                    172140.90
# 53    229.533835          15.96         3663.36                     71407.56
# 58    229.533835          14.63         3358.08                     84647.04
# 19    286.874200           4.69         1345.44                      6085.32
# 24    292.567164           1.34          392.04                      1027.80
# 29    298.080000           0.00            0.00                      4669.20
# 17    274.144615          13.00         3563.88                      6085.32
# 22    291.927711           0.00            0.00                      1027.80
# 27    291.927711           0.00            0.00                      4669.20
# 15    239.007519           2.66          635.76                      6085.32
# 20    239.007519           2.66          635.76                      1027.80
# 25    234.045113          19.95         4669.20                      4669.20
# 16    222.360000           1.00          222.36                      6085.32
# 21    222.360000           0.00            0.00                      1027.80
# 26    222.360000           0.00            0.00                      4669.20
# 18    239.007519           1.33          317.88                      6085.32
# 23    238.410000           0.00            0.00                      1027.80
# 28    238.410000           0.00            0.00                      4669.20
# 34    241.440000          55.00        13279.20                    136031.88
# 39    241.440000          13.00         3138.72                     25343.22
# 44    258.000000          13.00         3354.00                     47869.14
# 30    185.589744         210.60        39085.20                    136031.88
# 35    185.589744           5.85         1085.70                     25343.22
# 40    180.461538         146.25        26392.50                     47869.14
# 32    230.786122         110.39        25476.48                    136031.88
# 37    229.894737          58.52        13453.44                     25343.22
# 42    230.977444          58.52        13516.80                     47869.14
# 31    222.360000         155.00        34465.80                    136031.88
# 36    222.360000          16.00         3557.76                     25343.22
# 41    222.360000           4.00          889.44                     47869.14
# 33    188.295238         126.00        23725.20                    136031.88
# 38    195.600000          21.00         4107.60                     25343.22
# 43    195.600000          19.00         3716.40                     47869.14
#
#     Naive Prices  Naive Demand  Naive Revenue  Naive Chain Master Revenue
# 4     245.305091     20.454795    5017.665391                97978.066595
# 9     241.440000     20.399366    4925.222892               119582.879126
# 14    252.770526     20.416642    5160.725338               119397.388108
# 1     185.650112     40.950000    7602.372072                97978.066595
# 6     184.710623    157.916707   29168.893345               119582.879126
# 11    182.449915    156.616296   28574.629873               119397.388108
# 0     229.811232    292.610723   67245.230832                97978.066595
# 5     229.687258    292.497317   67182.906670               119582.879126
# 10    230.085045    292.200494   67230.963638               119397.388108
# 2     222.360000     69.590361   15474.112771                97978.066595
# 7     222.360000     70.073171   15581.470244               119582.879126
# 12    222.360000     70.691358   15718.930370               119397.388108
# 3     188.295238     14.013554    2638.685528                97978.066595
# 8     195.600000     13.928354    2724.385976               119582.879126
# 13    195.600000     13.865741    2712.138889               119397.388108
# 49    241.440000      5.409639    1306.103133                68683.438386
# 54    241.440000      5.329268    1286.698537                68603.539342
# 59    241.440000      5.320988    1284.699259                68422.416608
# 46    185.589744     44.962771    8344.629157                68683.438386
# 51    184.564103     45.083049    8320.712439                68603.539342
# 56    184.935385     44.195185    8173.253570                68422.416608
# 45    229.533835    217.722084   49974.584892                68683.438386
# 50    229.533835    217.441500   49910.181293                68603.539342
# 55    229.533835    217.186827   49851.725260                68422.416608
# 47    222.360000     24.319277    5407.634458                68683.438386
# 52    222.360000     24.445122    5435.617317                68603.539342
# 57    222.360000     24.549383    5458.800741                68422.416608
# 48    229.533835     15.903916    3650.486747                68683.438386
# 53    229.533835     15.903232    3650.329756                68603.539342
# 58    229.533835     15.918951    3653.937778                68422.416608
# 19    286.874200      1.169049     335.370107                 4012.710273
# 24    292.567164      1.166913     341.400281                 6918.393004
# 29    298.080000      0.000000       0.000000                 6492.494231
# 17    274.144615      0.000000       0.000000                 4012.710273
# 22    291.927711      0.000000       0.000000                 6918.393004
# 27    291.927711      0.000000       0.000000                 6492.494231
# 15    239.007519      9.200506    2198.990116                 4012.710273
# 20    239.007519     19.950000    4768.200000                 6918.393004
# 25    234.045113     19.950000    4669.200000                 6492.494231
# 16    222.360000      5.218880    1160.470050                 4012.710273
# 21    222.360000      5.282524    1174.622123                 6918.393004
# 26    222.360000      5.347741    1189.123631                 6492.494231
# 18    239.007519      1.330000     317.880000                 4012.710273
# 23    238.410000      2.660000     634.170600                 6918.393004
# 28    238.410000      2.660000     634.170600                 6492.494231
# 34    241.440000     21.000000    5070.240000                53477.231208
# 39    241.440000     13.147123    3174.241487                51986.613919
# 44    258.000000     13.148962    3392.432325                31634.399535
# 30    185.589744    110.560063   20518.813797                53477.231208
# 35    185.589744    111.902500   20767.956282                51986.613919
# 40    180.461538      0.000000       0.000000                31634.399535
# 32    230.786122     66.489207   15344.786307                53477.231208
# 37    229.894737     66.587593   15308.137076                51986.613919
# 42    230.977444     66.688437   15403.524812                31634.399535
# 31    222.360000     41.041148    9125.909702                53477.231208
# 36    222.360000     41.354163    9195.511573                51986.613919
# 41    222.360000     41.827000    9300.651720                31634.399535
# 33    188.295238     18.149590    3417.481401                53477.231208
# 38    195.600000     18.102083    3540.767500                51986.613919
# 43    195.600000     18.086864    3537.790678                31634.399535
