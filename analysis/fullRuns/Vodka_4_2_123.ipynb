# %% [markdown]
# # Init

# %%
# %load_ext autoreload
# %autoreload 2

# %%
print("CURRENT FOLDER:")
# %pwd
# Out:
# CURRENT FOLDER:
# 'c:\\max\\Google Drive Max\\Max Shared\\Master Data Science\\2020-05 Capstone A\\msds_capstone\\analysis\\fullRuns'

# %%
import os
import glob
import sys
sys.path.append(os.environ['DEV_AUTOTS'])
sys.path.append(os.environ['CAPSTONE_PYTHON_SOURCE'])
folder = os.environ['CAPSTONE_DATA']

# %%
## Sourcing the .py with all the code##
t='"'+os.environ['CAPSTONE_PYTHON_SOURCE']+'\\fullRun\\fullRun.py'+'"'
# %run -i $t
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# Running Auto Timeseries version: 0.0.24

# %% [markdown]
# # Parameters

# %%
#Parameters

ProdCats = ['ECONOMY VODKA']
TOP_PRODUCTS = 4  # How many products to consider in the category
TOP_SIMILAR = 2  # Get TOP_SIMILAR most similar products
RUN_PERIODS = [1,2,3] # this will run AutoTS and Optimzer for speicfic periods (1 = last, 2 = second to last)

CV_NUM = 10         # number of Cross Valudations  10
OPT_CALLS = 100     # number of calls for the optimizer process   100
OPT_RND_STARTS = 20 # number of random calls for the optimizer process  20

LOG_TRANSFORM = True # Take log of 9L cases to smooth out peaks and valleys
ZERO_ADDER = 0.1 

RESAMPLE_FREQ = 'M'


# Pricing changes every 4 weeks
if RESAMPLE_FREQ == 'M':    FORECAST_PERIOD = 1 #last 4 months as test 
if RESAMPLE_FREQ == 'W':    FORECAST_PERIOD = 4 
if RESAMPLE_FREQ == '2W':   FORECAST_PERIOD = 2 

# Seasonal Period
if RESAMPLE_FREQ == 'M':    SEASONAL_PERIOD = 12  # Yearly
if RESAMPLE_FREQ == 'W':    SEASONAL_PERIOD = 13 # Quarterly (we can also take yearly = 52, but SARIMAX becomes too slow)
if RESAMPLE_FREQ == '2W':   SEASONAL_PERIOD = 13 # This becomes problematic --> for quarterly, should we take 6 biweekly periods or 7 bi-weekly periods. Instead I just took half yearly period  

COL_TIME = 'WeekDate'
COL_PREDS = ['9L Cases'] #Demand
COL_PRICE= ['Dollar Sales per 9L Case'] #Price

# %% [markdown]
# # Full Run

# %%
dataRaw = loadDataset(version=4)
ProdCat =ProdCats[0]
ChainMasters =  [''] +  dataRaw['Chain Master'].unique().tolist() 
display(ChainMasters,ProdCats)
# Out:
# ['', 'THE BARREL HOUSE', 'WESTERN BEV LIQ TX', 'SPECS']
# ['ECONOMY VODKA']

# %%
(full_models,full_opt,full_summary,full_chain_summary)  = fullRun(ProdCat = ProdCat
                                                           ,ChainMasters = ChainMasters
                                                           ,dataRaw = dataRaw
                                                           ,savePKL=True
                                                           ,saveXLS=True)
# Out:
# ==================================================
# Parameters being used...
# ==================================================
# TOP_PRODUCTS = 4
# TOP_SIMILAR = 2
# RUN_PERIODS = [1, 2, 3]
# ProdCat: ECONOMY VODKA
# ChainMasters: ['', 'THE BARREL HOUSE', 'WESTERN BEV LIQ TX', 'SPECS']
#
#
# ======================== (2020-09-13 18:46:19.125849)
# ==== Products List  ====
# ==== ECONOMY VODKA =====
# ===========  ===========
# ========================
#
#
#
# ======================= (2020-09-13 18:46:23.616848)
# ======= AUTO-TS =======
# ==== ECONOMY VODKA ====
# ==========  ===========
# ========== 1 ==========
# =======================
#
#
#
# ================== (2020-09-13 18:46:23.619847)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 BLUE PET 375M', '2': 'TEXAS SPIRIT VODKA 80  1.75L', '3': 'TAAKA VODKA 80 PET 1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3', '0']
# % of weeks without a purchase: 1.1904761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '3', '0']
# % of weeks without a purchase: 69.04761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
#
#
# ===================== (2020-09-13 18:47:35.868906)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#        lb_stat     lb_pvalue
# 12  248.948794  2.266370e-46
# 24  282.763358  4.861676e-46
# 48  368.538254  5.288988e-51
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  584.901182  1.773645e-117
# 24  743.424992  1.784213e-141
# 48  947.167628  2.940142e-167
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  474.857092   4.940599e-94
# 24  562.831143  1.385783e-103
# 48  697.054286  5.309923e-116
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  148.350039  1.225106e-25
# 24  166.824771  2.330111e-23
# 48  349.230594  2.409071e-47
#
# Is Data White Noise: False
#
#
# ==================== (2020-09-13 18:47:35.938902)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (83, 5) (1, 5)
# (83, 5) (1, 5)
# (83, 5) (1, 5)
# (83, 5) (1, 5)
#
#
# =============== (2020-09-13 18:47:35.946903)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.083730         []
# 1  1      last   0.050920         []
# 2  2      last   0.000000         []
# 3  3      mean   0.080436         []
#
#                                            All RMSEs  \
# 0  [[0.08522395141312492, 0.11059590470983931, 0....
# 1  [[0.050919719560484134, 0.058483693505752464, ...
# 2                                  [[0.0, 0.0, 0.0]]
# 3  [[0.08442928271847924, 0.10271666862052284, 0....
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 2  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-13 18:47:36.612904)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 20.3min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 20.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-13 19:07:53.059939)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 19.1min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 19.1min finished
# =================== (2020-09-13 19:27:01.847013)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-13 19:27:01.871013)
# ====== OPTIMIZER ======
# ==== ECONOMY VODKA ====
# ==========  ===========
# ========== 1 ==========
# =======================
#
#
#
# =========================== (2020-09-13 19:27:01.872012)
# ==== Running Optimizer ====
# ====== ECONOMY VODKA ======
# ============  =============
# ============ 1 ============
# ===========================
#
#
#
# ================== (2020-09-13 19:27:01.877013)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 BLUE PET 375M', '2': 'TEXAS SPIRIT VODKA 80  1.75L', '3': 'TAAKA VODKA 80 PET 1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3', '0']
# % of weeks without a purchase: 1.1904761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '3', '0']
# % of weeks without a purchase: 69.04761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
#
#
# ==================== (2020-09-13 19:28:03.062055)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (83, 5) (1, 5)
# (83, 5) (1, 5)
# (83, 5) (1, 5)
# (83, 5) (1, 5)
#
#
# ======================== (2020-09-13 19:28:03.069055)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-13 19:28:03.096054)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False, False]
#
#
# =============== (2020-09-13 19:28:03.099054)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-13 19:28:03.109055)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-13 19:28:03.111056)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-13 19:28:03.111056)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-13 19:28:03.426057)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-13 19:28:03.431056)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-13 19:30:11.660052)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-13 19:30:11.955053)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-13 19:30:11.956055)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-13 19:30:12.169053)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-13 19:30:12.175052)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-13 19:32:15.479054)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-13 19:32:15.691053)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-13 19:32:15.697054)
# ======= AUTO-TS =======
# ==== ECONOMY VODKA ====
# ==========  ===========
# ========== 2 ==========
# =======================
#
#
#
# ================== (2020-09-13 19:32:15.698053)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 BLUE PET 375M', '2': 'TEXAS SPIRIT VODKA 80  1.75L', '3': 'TAAKA VODKA 80 PET 1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3', '0']
# % of weeks without a purchase: 1.2048192771084338
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '3', '0']
# % of weeks without a purchase: 68.67469879518072
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
#
#
# ===================== (2020-09-13 19:33:15.484053)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#        lb_stat     lb_pvalue
# 12  247.379998  4.812566e-46
# 24  281.567711  8.439708e-46
# 48  366.781603  1.141278e-50
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  574.606302  2.792191e-115
# 24  727.477625  4.083848e-138
# 48  944.375636  1.109735e-166
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  468.018038   1.404414e-92
# 24  554.010494  9.591640e-102
# 48  696.468177  6.982057e-116
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  144.742513  6.589309e-25
# 24  162.572274  1.476101e-22
# 48  338.164450  2.919586e-45
#
# Is Data White Noise: False
#
#
# ==================== (2020-09-13 19:33:15.511054)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (82, 5) (1, 5)
#
#
# =============== (2020-09-13 19:33:15.517053)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.077936         []
# 1  1      last   0.049104         []
# 2  2      last   0.000000         []
# 3  3      mean   0.087216         []
#
#                                            All RMSEs  \
# 0  [[0.08907681622057902, 0.11385458510024087, 0....
# 1  [[0.04910363192681037, 0.05961976914518541, 0....
# 2                                  [[0.0, 0.0, 0.0]]
# 3  [[0.09339313017889535, 0.10233695646087668, 0....
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 2  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-13 19:33:16.209056)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 17.2min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 17.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-13 19:50:29.402053)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 16.2min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 16.2min finished
# =================== (2020-09-13 20:06:42.680060)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-13 20:06:42.724053)
# ====== OPTIMIZER ======
# ==== ECONOMY VODKA ====
# ==========  ===========
# ========== 2 ==========
# =======================
#
#
#
# =========================== (2020-09-13 20:06:42.725056)
# ==== Running Optimizer ====
# ====== ECONOMY VODKA ======
# ============  =============
# ============ 2 ============
# ===========================
#
#
#
# ================== (2020-09-13 20:06:42.733056)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 BLUE PET 375M', '2': 'TEXAS SPIRIT VODKA 80  1.75L', '3': 'TAAKA VODKA 80 PET 1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3', '0']
# % of weeks without a purchase: 1.2048192771084338
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '3', '0']
# % of weeks without a purchase: 68.67469879518072
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
#
#
# ==================== (2020-09-13 20:07:32.320053)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (82, 5) (1, 5)
#
#
# ======================== (2020-09-13 20:07:32.328052)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-13 20:07:32.344055)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False, False]
#
#
# =============== (2020-09-13 20:07:32.347055)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-13 20:07:32.358054)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-13 20:07:32.359052)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-13 20:07:32.361052)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-13 20:07:33.634053)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-13 20:07:33.640060)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-13 20:15:32.837055)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-13 20:15:35.792054)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-13 20:15:35.793054)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-13 20:15:36.715054)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-13 20:15:36.723054)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-13 20:19:59.640056)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-13 20:19:59.935053)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-13 20:19:59.943054)
# ======= AUTO-TS =======
# ==== ECONOMY VODKA ====
# ==========  ===========
# ========== 3 ==========
# =======================
#
#
#
# ================== (2020-09-13 20:19:59.944056)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 BLUE PET 375M', '2': 'TEXAS SPIRIT VODKA 80  1.75L', '3': 'TAAKA VODKA 80 PET 1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3', '0']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '3', '0']
# % of weeks without a purchase: 68.29268292682927
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
#
#
# ===================== (2020-09-13 20:20:51.730057)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#        lb_stat     lb_pvalue
# 12  243.950101  2.495194e-45
# 24  277.452128  5.626127e-45
# 48  363.173548  5.530118e-50
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  563.083839  8.020215e-113
# 24  710.497889  1.533447e-134
# 48  939.687445  1.031921e-165
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  461.149000   4.046888e-91
# 24  545.150471  6.746748e-100
# 48  696.525463  6.797717e-116
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  141.032457  3.706001e-24
# 24  158.246146  9.582502e-22
# 48  325.345702  7.337201e-43
#
# Is Data White Noise: False
#
#
# ==================== (2020-09-13 20:20:51.756054)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (81, 5) (1, 5)
# (81, 5) (1, 5)
# (81, 5) (1, 5)
# (81, 5) (1, 5)
#
#
# =============== (2020-09-13 20:20:51.763054)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.078022         []
# 1  1      last   0.044826         []
# 2  2      last   0.000000         []
# 3  3      mean   0.076948         []
#
#                                            All RMSEs  \
# 0  [[0.10614956572430416, 0.1364306802567358, 0.0...
# 1  [[0.04482627686032599, 0.061881124720379786, 0...
# 2                                  [[0.0, 0.0, 0.0]]
# 3  [[0.0987077256986276, 0.10351490018633347, 0.0...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 2  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-13 20:20:52.254054)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 12.2min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 12.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-13 20:33:06.465056)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 18.4min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 18.4min finished
# =================== (2020-09-13 20:51:31.959679)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-13 20:51:32.025674)
# ====== OPTIMIZER ======
# ==== ECONOMY VODKA ====
# ==========  ===========
# ========== 3 ==========
# =======================
#
#
#
# =========================== (2020-09-13 20:51:32.025674)
# ==== Running Optimizer ====
# ====== ECONOMY VODKA ======
# ============  =============
# ============ 3 ============
# ===========================
#
#
#
# ================== (2020-09-13 20:51:32.035676)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 BLUE PET 375M', '2': 'TEXAS SPIRIT VODKA 80  1.75L', '3': 'TAAKA VODKA 80 PET 1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3', '0']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '3', '0']
# % of weeks without a purchase: 68.29268292682927
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
#
#
# ==================== (2020-09-13 20:52:29.991674)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (81, 5) (1, 5)
# (81, 5) (1, 5)
# (81, 5) (1, 5)
# (81, 5) (1, 5)
#
#
# ======================== (2020-09-13 20:52:29.998674)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-13 20:52:30.018674)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False, False]
#
#
# =============== (2020-09-13 20:52:30.021675)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-13 20:52:30.033675)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-13 20:52:30.035678)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-13 20:52:30.036678)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-13 20:52:30.426674)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-13 20:52:30.432674)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-13 20:57:44.303675)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-13 20:57:44.904674)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-13 20:57:44.905675)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-13 20:57:45.654674)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-13 20:57:45.661678)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-13 21:03:45.053677)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-13 21:03:45.932676)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-13 21:03:45.941677)
# ===== Products List  =====
# ===== ECONOMY VODKA ======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 21:03:47.360677)
# ======== AUTO-TS =========
# ===== ECONOMY VODKA ======
# ==== THE BARREL HOUSE ====
# =========== 1 ============
# ==========================
#
#
#
# ========================== (2020-09-13 21:03:47.361676)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80 BLUE PET 375M', '1': 'TAAKA VODKA 80 BLUE PET 200M', '2': 'TAAKA VODKA 80  1L', '3': 'DOBRA VODKA  1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2']
# % of weeks without a purchase: 1.694915254237288
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 200M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 1.694915254237288
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1']
# % of weeks without a purchase: 6.779661016949152
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: DOBRA VODKA  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2']
# % of weeks without a purchase: 28.57142857142857
# Log Transforming
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TAAKA VODKA 80 BLUE PET 200M
# 	Product: TAAKA VODKA 80  1L
# 	Product: DOBRA VODKA  1.75L
#
#
# ========================== (2020-09-13 21:04:35.086677)
# ====== WHITE NOISE =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#        lb_stat     lb_pvalue
# 12  141.970557  2.395431e-24
# 24  144.452747  3.527878e-19
# 48  320.340879  6.288716e-42
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  21.978242   0.037764
# 24  27.494357   0.281943
# 48  52.638641   0.299248
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12   44.122049  1.455748e-05
# 24   45.996717  4.431043e-03
# 48  112.281342  4.570812e-07
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  105.152166  5.416764e-17
# 24  119.277224  1.304825e-14
# 48  154.987549  3.429672e-13
#
# Is Data White Noise: False
#
#
# ========================== (2020-09-13 21:04:35.116677)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (58, 5) (1, 5)
# (58, 5) (1, 5)
# (58, 5) (1, 5)
# (83, 5) (1, 5)
#
#
# ========================== (2020-09-13 21:04:35.125676)
# ========= NAIVE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      last   0.068911         []
# 1  1      mean   0.165948         []
# 2  2      mean   0.099268         []
# 3  3      mean   0.531778         []
#
#                                            All RMSEs  \
# 0  [[0.06891113023575937, 0.09474241449242278, 0....
# 1  [[0.2390439979625162, 0.25545500613475297, 0.1...
# 2  [[0.12248442676716172, 0.18448330474563132, 0....
# 3  [[0.5549559305354916, 0.5833145410737691, 0.53...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ========================== (2020-09-13 21:04:35.608677)
# ====== Multivar P0 =======
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 16.7min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 16.7min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================== (2020-09-13 21:21:18.563826)
# ==== Multivar P0+Sim =====
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 14.1min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 14.1min finished
# ========================== (2020-09-13 21:35:26.851827)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 21:35:26.868826)
# ======= OPTIMIZER ========
# ===== ECONOMY VODKA ======
# ==== THE BARREL HOUSE ====
# =========== 1 ============
# ==========================
#
#
#
# =========================== (2020-09-13 21:35:26.869830)
# ==== Running Optimizer ====
# ====== ECONOMY VODKA ======
# ==== THE BARREL HOUSE =====
# ============ 1 ============
# ===========================
#
#
#
# ========================== (2020-09-13 21:35:26.872826)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80 BLUE PET 375M', '1': 'TAAKA VODKA 80 BLUE PET 200M', '2': 'TAAKA VODKA 80  1L', '3': 'DOBRA VODKA  1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2']
# % of weeks without a purchase: 1.694915254237288
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 200M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 1.694915254237288
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1']
# % of weeks without a purchase: 6.779661016949152
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: DOBRA VODKA  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2']
# % of weeks without a purchase: 28.57142857142857
# Log Transforming
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TAAKA VODKA 80 BLUE PET 200M
# 	Product: TAAKA VODKA 80  1L
# 	Product: DOBRA VODKA  1.75L
#
#
# ========================== (2020-09-13 21:36:20.066826)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (58, 5) (1, 5)
# (58, 5) (1, 5)
# (58, 5) (1, 5)
# (83, 5) (1, 5)
#
#
# ========================== (2020-09-13 21:36:20.075826)
# ===== NAIVE FORECAST =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 21:36:20.100826)
# ========== MASK ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
# Mask: [False, False, False, False]
#
#
# ========================== (2020-09-13 21:36:20.103827)
# ========= SPACE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 21:36:20.120825)
# ======= Test Index =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 21:36:20.121826)
# ==== GET FUNCTION P0 =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ====================================== (2020-09-13 21:36:20.122830)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ========== THE BARREL HOUSE ==========
# ======================================
#
#
#
# ========================== (2020-09-13 21:36:20.331824)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 21:36:20.337825)
# ===== OPTIMIZING P0 ======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 21:38:46.055823)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ============================= (2020-09-13 21:38:46.194824)
# ==== GET FUNCTION P0+Sim ====
# ===== THE BARREL HOUSE ======
# =============================
#
#
#
# ========================================== (2020-09-13 21:38:46.195824)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ============ THE BARREL HOUSE ============
# ==========================================
#
#
#
# ========================== (2020-09-13 21:38:46.316824)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# =========================== (2020-09-13 21:38:46.323823)
# ==== OPTIMIZING P0+Sim ====
# ==== THE BARREL HOUSE =====
# ===========================
#
#
#
# ========================== (2020-09-13 21:41:51.101824)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 21:41:51.220826)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 21:41:51.228823)
# ======== AUTO-TS =========
# ===== ECONOMY VODKA ======
# ==== THE BARREL HOUSE ====
# =========== 2 ============
# ==========================
#
#
#
# ========================== (2020-09-13 21:41:51.228823)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80 BLUE PET 375M', '1': 'TAAKA VODKA 80 BLUE PET 200M', '2': 'TAAKA VODKA 80  1L', '3': 'DOBRA VODKA  1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2']
# % of weeks without a purchase: 1.7241379310344827
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 200M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 1.7241379310344827
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1']
# % of weeks without a purchase: 6.896551724137931
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: DOBRA VODKA  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2']
# % of weeks without a purchase: 28.915662650602407
# Log Transforming
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TAAKA VODKA 80 BLUE PET 200M
# 	Product: TAAKA VODKA 80  1L
# 	Product: DOBRA VODKA  1.75L
#
#
# ========================== (2020-09-13 21:42:37.285826)
# ====== WHITE NOISE =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#        lb_stat     lb_pvalue
# 12  137.410866  1.993797e-23
# 24  139.910786  2.418875e-18
# 48  322.778598  2.210050e-42
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  21.669742   0.041392
# 24  27.152575   0.297392
# 48  52.791525   0.294182
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12   42.786664  2.453685e-05
# 24   44.707020  6.307408e-03
# 48  111.872160  5.168754e-07
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  104.052037  8.917711e-17
# 24  118.103635  2.109057e-14
# 48  153.752344  5.308252e-13
#
# Is Data White Noise: False
#
#
# ========================== (2020-09-13 21:42:37.309825)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (57, 5) (1, 5)
# (57, 5) (1, 5)
# (57, 5) (1, 5)
# (82, 5) (1, 5)
#
#
# ========================== (2020-09-13 21:42:37.316827)
# ========= NAIVE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      last   0.055124         []
# 1  1      mean   0.206669         []
# 2  2      mean   0.094367         []
# 3  3      last   0.583315         []
#
#                                            All RMSEs  \
# 0  [[0.055123576776570093, 0.0992941627475532, 0....
# 1  [[0.2776588463567642, 0.2832827480917138, 0.20...
# 2  [[0.1282258925607897, 0.17212401268673627, 0.0...
# 3  [[0.5833145410737691, 0.6936949131693646, 0.59...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 3  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
#
#
# ========================== (2020-09-13 21:42:37.788825)
# ====== Multivar P0 =======
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 21.0min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 21.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================== (2020-09-13 22:03:37.989825)
# ==== Multivar P0+Sim =====
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 13.8min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 13.8min finished
# ========================== (2020-09-13 22:17:25.470352)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:17:25.579354)
# ======= OPTIMIZER ========
# ===== ECONOMY VODKA ======
# ==== THE BARREL HOUSE ====
# =========== 2 ============
# ==========================
#
#
#
# =========================== (2020-09-13 22:17:25.579354)
# ==== Running Optimizer ====
# ====== ECONOMY VODKA ======
# ==== THE BARREL HOUSE =====
# ============ 2 ============
# ===========================
#
#
#
# ========================== (2020-09-13 22:17:25.590351)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80 BLUE PET 375M', '1': 'TAAKA VODKA 80 BLUE PET 200M', '2': 'TAAKA VODKA 80  1L', '3': 'DOBRA VODKA  1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2']
# % of weeks without a purchase: 1.7241379310344827
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 200M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 1.7241379310344827
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1']
# % of weeks without a purchase: 6.896551724137931
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: DOBRA VODKA  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2']
# % of weeks without a purchase: 28.915662650602407
# Log Transforming
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TAAKA VODKA 80 BLUE PET 200M
# 	Product: TAAKA VODKA 80  1L
# 	Product: DOBRA VODKA  1.75L
#
#
# ========================== (2020-09-13 22:18:24.081353)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (57, 5) (1, 5)
# (57, 5) (1, 5)
# (57, 5) (1, 5)
# (82, 5) (1, 5)
#
#
# ========================== (2020-09-13 22:18:24.089355)
# ===== NAIVE FORECAST =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:18:24.123353)
# ========== MASK ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
# Mask: [False, False, False, False]
#
#
# ========================== (2020-09-13 22:18:24.126353)
# ========= SPACE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:18:24.140353)
# ======= Test Index =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:18:24.141353)
# ==== GET FUNCTION P0 =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ====================================== (2020-09-13 22:18:24.146354)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ========== THE BARREL HOUSE ==========
# ======================================
#
#
#
# ========================== (2020-09-13 22:18:24.358355)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:18:24.365356)
# ===== OPTIMIZING P0 ======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:21:11.437355)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ============================= (2020-09-13 22:21:11.784354)
# ==== GET FUNCTION P0+Sim ====
# ===== THE BARREL HOUSE ======
# =============================
#
#
#
# ========================================== (2020-09-13 22:21:11.786354)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ============ THE BARREL HOUSE ============
# ==========================================
#
#
#
# ========================== (2020-09-13 22:21:12.022353)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# =========================== (2020-09-13 22:21:12.030353)
# ==== OPTIMIZING P0+Sim ====
# ==== THE BARREL HOUSE =====
# ===========================
#
#
#
# ========================== (2020-09-13 22:25:17.580354)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:25:17.726351)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:25:17.735352)
# ======== AUTO-TS =========
# ===== ECONOMY VODKA ======
# ==== THE BARREL HOUSE ====
# =========== 3 ============
# ==========================
#
#
#
# ========================== (2020-09-13 22:25:17.736352)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80 BLUE PET 375M', '1': 'TAAKA VODKA 80 BLUE PET 200M', '2': 'TAAKA VODKA 80  1L', '3': 'DOBRA VODKA  1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2']
# % of weeks without a purchase: 1.7543859649122806
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 200M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 1.7543859649122806
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1']
# % of weeks without a purchase: 7.017543859649122
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: DOBRA VODKA  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2']
# % of weeks without a purchase: 28.04878048780488
# Log Transforming
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TAAKA VODKA 80 BLUE PET 200M
# 	Product: TAAKA VODKA 80  1L
# 	Product: DOBRA VODKA  1.75L
#
#
# ========================== (2020-09-13 22:26:07.029355)
# ====== WHITE NOISE =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#        lb_stat     lb_pvalue
# 12  132.810279  1.682218e-22
# 24  135.478653  1.566072e-17
# 48  325.313018  7.441001e-43
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  21.595536   0.042311
# 24  27.028344   0.303134
# 48  54.622321   0.237474
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12   41.613403  3.867933e-05
# 24   43.560865  8.577393e-03
# 48  112.343700  4.485858e-07
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  106.751532  2.621607e-17
# 24  118.126523  2.089419e-14
# 48  160.415924  4.948674e-14
#
# Is Data White Noise: False
#
#
# ========================== (2020-09-13 22:26:07.060354)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (56, 5) (1, 5)
# (56, 5) (1, 5)
# (56, 5) (1, 5)
# (81, 5) (1, 5)
#
#
# ========================== (2020-09-13 22:26:07.069352)
# ========= NAIVE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      last   0.065992         []
# 1  1      mean   0.199992         []
# 2  2      mean   0.093113         []
# 3  3      last   0.472934         []
#
#                                            All RMSEs  \
# 0  [[0.06599226033424141, 0.10595455079040401, 0....
# 1  [[0.24204599505427557, 0.28850466087251886, 0....
# 2  [[0.1186954439315259, 0.17141527417502248, 0.0...
# 3  [[0.4729341689781733, 0.6653363026310875, 0.51...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 3  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
#
#
# ========================== (2020-09-13 22:26:07.637351)
# ====== Multivar P0 =======
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 16.9min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 16.9min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================== (2020-09-13 22:42:59.659359)
# ==== Multivar P0+Sim =====
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 16.9min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 16.9min finished
# ========================== (2020-09-13 22:59:52.424157)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:59:52.491159)
# ======= OPTIMIZER ========
# ===== ECONOMY VODKA ======
# ==== THE BARREL HOUSE ====
# =========== 3 ============
# ==========================
#
#
#
# =========================== (2020-09-13 22:59:52.491159)
# ==== Running Optimizer ====
# ====== ECONOMY VODKA ======
# ==== THE BARREL HOUSE =====
# ============ 3 ============
# ===========================
#
#
#
# ========================== (2020-09-13 22:59:52.501159)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80 BLUE PET 375M', '1': 'TAAKA VODKA 80 BLUE PET 200M', '2': 'TAAKA VODKA 80  1L', '3': 'DOBRA VODKA  1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2']
# % of weeks without a purchase: 1.7543859649122806
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 200M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 1.7543859649122806
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1']
# % of weeks without a purchase: 7.017543859649122
# resampling to  M
#
#
#
# ...
#
#
#
# =============== (2020-09-14 03:41:15.780850)
# ==== MASK =====
# ==== SPECS ====
# ===============
#
# Mask: [False, False, False, False]
#
#
# =============== (2020-09-14 03:41:15.783850)
# ==== SPACE ====
# ==== SPECS ====
# ===============
#
# Min Limit is >= than Max Limit, setting them near median (+-5%)
#
#
# ==================== (2020-09-14 03:41:15.798849)
# ==== Test Index ====
# ====== SPECS =======
# ====================
#
#
#
# ========================= (2020-09-14 03:41:15.799851)
# ==== GET FUNCTION P0 ====
# ========= SPECS =========
# =========================
#
#
#
# ====================================== (2020-09-14 03:41:15.800850)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# =============== SPECS ================
# ======================================
#
#
#
# =================== (2020-09-14 03:41:16.684851)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ======================= (2020-09-14 03:41:16.692852)
# ==== OPTIMIZING P0 ====
# ======== SPECS ========
# =======================
#
#
#
# =================== (2020-09-14 03:44:52.824852)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ============================= (2020-09-14 03:44:53.687859)
# ==== GET FUNCTION P0+Sim ====
# =========== SPECS ===========
# =============================
#
#
#
# ========================================== (2020-09-14 03:44:53.688854)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ================= SPECS ==================
# ==========================================
#
#
#
# =================== (2020-09-14 03:44:54.158849)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =========================== (2020-09-14 03:44:54.165849)
# ==== OPTIMIZING P0+Sim ====
# ========== SPECS ==========
# ===========================
#
#
#
# =================== (2020-09-14 03:48:53.109852)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =================== (2020-09-14 03:48:53.832851)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ======================= (2020-09-14 03:48:53.844850)
# ======= AUTO-TS =======
# ==== ECONOMY VODKA ====
# ======== SPECS ========
# ========== 3 ==========
# =======================
#
#
#
# ================== (2020-09-14 03:48:53.845851)
# ==== GET DATA ====
# ===== SPECS ======
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 PET 1.75L', '2': 'TAAKA VODKA 80 BLUE PET 375M', '3': 'MCCORMICK CHERRY VODKA 60  1L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: MCCORMICK CHERRY VODKA 60  1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1']
# % of weeks without a purchase: 28.39506172839506
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 PET 1.75L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: MCCORMICK CHERRY VODKA 60  1L
#
#
# ===================== (2020-09-14 03:49:45.278850)
# ==== WHITE NOISE ====
# ======= SPECS =======
# =====================
#
#        lb_stat     lb_pvalue
# 12  163.850364  8.614761e-29
# 24  202.851035  2.932294e-30
# 48  302.430383  1.310197e-38
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  203.867388  5.185416e-37
# 24  249.138534  2.445714e-39
# 48  386.780036  1.745507e-54
#
# Is Data White Noise: False
#        lb_stat  lb_pvalue
# 12   41.146569   0.000046
# 24   60.607680   0.000052
# 48  103.105730   0.000007
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  12.395058   0.414496
# 24  22.052180   0.576152
# 48  51.642102   0.333451
#
# Is Data White Noise: True
#
#
# ==================== (2020-09-14 03:49:45.303849)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (81, 5) (1, 5)
# (81, 5) (1, 5)
# (81, 5) (1, 5)
# (80, 5) (1, 5)
#
#
# =============== (2020-09-14 03:49:45.310848)
# ==== NAIVE ====
# ==== SPECS ====
# ===============
#
#   ID      Best Type  Best RMSE All Naives  \
# 0  0           mean   0.107768         []
# 1  1           mean   0.136330         []
# 2  2           mean   0.121653         []
# 3  3  seasonal_last   0.432273         []
#
#                                            All RMSEs  \
# 0  [[0.13456120941276825, 0.187951813296838, 0.10...
# 1  [[0.21541297336857784, 0.22034399791646134, 0....
# 2  [[0.17742034252670738, 0.1589870135780978, 0.1...
# 3  [[0.49069171944604034, 0.4322727246195653, 0.6...
#
#                        All Types  \
# 0  [[last, seasonal_last, mean]]
# 1  [[last, seasonal_last, mean]]
# 2  [[last, seasonal_last, mean]]
# 3  [[last, seasonal_last, mean]]
#
#                                         Best Naive
# 0           NaiveForecaster(sp=4, strategy='mean')
# 1           NaiveForecaster(sp=4, strategy='mean')
# 2           NaiveForecaster(sp=4, strategy='mean')
# 3  NaiveForecaster(sp=4, strategy='seasonal_last')
#
#
# ===================== (2020-09-14 03:49:45.977852)
# ==== Multivar P0 ====
# ======= SPECS =======
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 20.7min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 20.7min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-14 04:10:30.296530)
# ==== Multivar P0+Sim ====
# ========= SPECS =========
# =========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 20.9min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 20.9min finished
# =================== (2020-09-14 04:31:22.600367)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ======================= (2020-09-14 04:31:22.759368)
# ====== OPTIMIZER ======
# ==== ECONOMY VODKA ====
# ======== SPECS ========
# ========== 3 ==========
# =======================
#
#
#
# =========================== (2020-09-14 04:31:22.771369)
# ==== Running Optimizer ====
# ====== ECONOMY VODKA ======
# ========== SPECS ==========
# ============ 3 ============
# ===========================
#
#
#
# ================== (2020-09-14 04:31:22.783368)
# ==== GET DATA ====
# ===== SPECS ======
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 PET 1.75L', '2': 'TAAKA VODKA 80 BLUE PET 375M', '3': 'MCCORMICK CHERRY VODKA 60  1L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: MCCORMICK CHERRY VODKA 60  1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1']
# % of weeks without a purchase: 28.39506172839506
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 PET 1.75L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: MCCORMICK CHERRY VODKA 60  1L
#
#
# ==================== (2020-09-14 04:32:17.047443)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (81, 5) (1, 5)
# (81, 5) (1, 5)
# (81, 5) (1, 5)
# (80, 5) (1, 5)
#
#
# ======================== (2020-09-14 04:32:17.060445)
# ==== NAIVE FORECAST ====
# ======== SPECS =========
# ========================
#
#
#
# =============== (2020-09-14 04:32:17.082444)
# ==== MASK =====
# ==== SPECS ====
# ===============
#
# Mask: [False, False, False, False]
#
#
# =============== (2020-09-14 04:32:17.085443)
# ==== SPACE ====
# ==== SPECS ====
# ===============
#
# Min Limit is >= than Max Limit, setting them near median (+-5%)
#
#
# ==================== (2020-09-14 04:32:17.098444)
# ==== Test Index ====
# ====== SPECS =======
# ====================
#
#
#
# ========================= (2020-09-14 04:32:17.100445)
# ==== GET FUNCTION P0 ====
# ========= SPECS =========
# =========================
#
#
#
# ====================================== (2020-09-14 04:32:17.101444)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# =============== SPECS ================
# ======================================
#
# Building Forecast dataframe. Forecast Period = 1
#
#
# =================== (2020-09-14 04:32:20.789445)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ======================= (2020-09-14 04:32:20.795444)
# ==== OPTIMIZING P0 ====
# ======== SPECS ========
# =======================
#
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
#
#
# =================== (2020-09-14 04:41:09.132808)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
# Building Forecast dataframe. Forecast Period = 1
#
#
# ============================= (2020-09-14 04:41:12.627342)
# ==== GET FUNCTION P0+Sim ====
# =========== SPECS ===========
# =============================
#
#
#
# ========================================== (2020-09-14 04:41:12.628344)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ================= SPECS ==================
# ==========================================
#
#
#
# =================== (2020-09-14 04:41:13.222342)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =========================== (2020-09-14 04:41:13.230342)
# ==== OPTIMIZING P0+Sim ====
# ========== SPECS ==========
# ===========================
#
#
#
# =================== (2020-09-14 04:47:12.472796)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =================== (2020-09-14 04:47:12.887793)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ========================== (2020-09-14 04:47:12.908793)
# ==== Saving to PICKLE ====
# ===== ECONOMY VODKA ======
# ==========================
#
# Pickle File  full_models_ECONOMY VODKA_Prod4_Sim2_Per123.pkl  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns
# Pickle File  full_opt_ECONOMY VODKA_Prod4_Sim2_Per123.pkl  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns
#
#
# ========================= (2020-09-14 04:47:25.461794)
# ==== Saving to EXCEL ====
# ===== ECONOMY VODKA =====
# =========================
#
# EXCEL File  Output_ECONOMY VODKA_Prod4_Sim2_Per123.xlsx  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns

# %% [markdown]
# # Print out

# %% [markdown]
# ## Models

# %%
full_models[outputColsModels]
# Out:
#           Chain Master                        Product  Period to Last  \
# 0                                  TAAKA VODKA 80  1L               1
# 4                                  TAAKA VODKA 80  1L               2
# 8                                  TAAKA VODKA 80  1L               3
# 1                        TAAKA VODKA 80 BLUE PET 375M               1
# 5                        TAAKA VODKA 80 BLUE PET 375M               2
# 9                        TAAKA VODKA 80 BLUE PET 375M               3
# 3                            TAAKA VODKA 80 PET 1.75L               1
# 7                            TAAKA VODKA 80 PET 1.75L               2
# 11                           TAAKA VODKA 80 PET 1.75L               3
# 2                        TEXAS SPIRIT VODKA 80  1.75L               1
# 6                        TEXAS SPIRIT VODKA 80  1.75L               2
# 10                       TEXAS SPIRIT VODKA 80  1.75L               3
# 39               SPECS  MCCORMICK CHERRY VODKA 60  1L               1
# 43               SPECS  MCCORMICK CHERRY VODKA 60  1L               2
# 47               SPECS  MCCORMICK CHERRY VODKA 60  1L               3
# 36               SPECS             TAAKA VODKA 80  1L               1
# 40               SPECS             TAAKA VODKA 80  1L               2
# 44               SPECS             TAAKA VODKA 80  1L               3
# 38               SPECS   TAAKA VODKA 80 BLUE PET 375M               1
# 42               SPECS   TAAKA VODKA 80 BLUE PET 375M               2
# 46               SPECS   TAAKA VODKA 80 BLUE PET 375M               3
# 37               SPECS       TAAKA VODKA 80 PET 1.75L               1
# 41               SPECS       TAAKA VODKA 80 PET 1.75L               2
# 45               SPECS       TAAKA VODKA 80 PET 1.75L               3
# 15    THE BARREL HOUSE             DOBRA VODKA  1.75L               1
# 19    THE BARREL HOUSE             DOBRA VODKA  1.75L               2
# 23    THE BARREL HOUSE             DOBRA VODKA  1.75L               3
# 14    THE BARREL HOUSE             TAAKA VODKA 80  1L               1
# 18    THE BARREL HOUSE             TAAKA VODKA 80  1L               2
# 22    THE BARREL HOUSE             TAAKA VODKA 80  1L               3
# 13    THE BARREL HOUSE   TAAKA VODKA 80 BLUE PET 200M               1
# 17    THE BARREL HOUSE   TAAKA VODKA 80 BLUE PET 200M               2
# 21    THE BARREL HOUSE   TAAKA VODKA 80 BLUE PET 200M               3
# 12    THE BARREL HOUSE   TAAKA VODKA 80 BLUE PET 375M               1
# 16    THE BARREL HOUSE   TAAKA VODKA 80 BLUE PET 375M               2
# 20    THE BARREL HOUSE   TAAKA VODKA 80 BLUE PET 375M               3
# 25  WESTERN BEV LIQ TX             TAAKA VODKA 80  1L               1
# 29  WESTERN BEV LIQ TX             TAAKA VODKA 80  1L               2
# 33  WESTERN BEV LIQ TX             TAAKA VODKA 80  1L               3
# 24  WESTERN BEV LIQ TX   TAAKA VODKA 80 BLUE PET 375M               1
# 28  WESTERN BEV LIQ TX   TAAKA VODKA 80 BLUE PET 375M               2
# 32  WESTERN BEV LIQ TX   TAAKA VODKA 80 BLUE PET 375M               3
# 27  WESTERN BEV LIQ TX       TAAKA VODKA 80 PET 1.75L               1
# 31  WESTERN BEV LIQ TX       TAAKA VODKA 80 PET 1.75L               2
# 35  WESTERN BEV LIQ TX       TAAKA VODKA 80 PET 1.75L               3
# 26  WESTERN BEV LIQ TX   TEXAS SPIRIT VODKA 80  1.75L               1
# 30  WESTERN BEV LIQ TX   TEXAS SPIRIT VODKA 80  1.75L               2
# 34  WESTERN BEV LIQ TX   TEXAS SPIRIT VODKA 80  1.75L               3
#
#     White Noise Naive Best Type  Naive Best RMSE P0 Best Model Name  \
# 0         False            mean         0.083730                 ML
# 4         False            mean         0.077936                 ML
# 8         False            mean         0.078022                 ML
# 1         False            last         0.050920                 ML
# 5         False            last         0.049104            SARIMAX
# 9         False            last         0.044826       auto_SARIMAX
# 3         False            mean         0.080436                 ML
# 7         False            mean         0.087216            SARIMAX
# 11        False            mean         0.076948            SARIMAX
# 2         False            last         0.000000            SARIMAX
# 6         False            last         0.000000            SARIMAX
# 10        False            last         0.000000            SARIMAX
# 39         True   seasonal_last         0.288182       auto_SARIMAX
# 43         True   seasonal_last         0.432273       auto_SARIMAX
# 47         True   seasonal_last         0.432273                 ML
# 36        False            last         0.109601                 ML
# 40        False            last         0.116424                 ML
# 44        False            mean         0.107768                 ML
# 38        False            mean         0.113808            SARIMAX
# 42        False            mean         0.104293            SARIMAX
# 46        False            mean         0.121653       auto_SARIMAX
# 37        False            mean         0.113211            SARIMAX
# 41        False            mean         0.120084                 ML
# 45        False            mean         0.136330            Prophet
# 15        False            mean         0.531778                 ML
# 19        False            last         0.583315                 ML
# 23        False            last         0.472934            SARIMAX
# 14        False            mean         0.099268                 ML
# 18        False            mean         0.094367                 ML
# 22        False            mean         0.093113                 ML
# 13         True            mean         0.165948                 ML
# 17         True            mean         0.206669                 ML
# 21         True            mean         0.199992                 ML
# 12        False            last         0.068911       auto_SARIMAX
# 16        False            last         0.055124       auto_SARIMAX
# 20        False            last         0.065992       auto_SARIMAX
# 25        False            last         0.113461            Prophet
# 29        False            last         0.107550            Prophet
# 33        False            last         0.126205                 ML
# 24        False            last         0.064357                 ML
# 28        False            last         0.062996                 ML
# 32        False            last         0.055440                 ML
# 27        False            last         0.109374       auto_SARIMAX
# 31        False            last         0.122087       auto_SARIMAX
# 35        False            mean         0.137258       auto_SARIMAX
# 26        False            last         0.000000            SARIMAX
# 30        False            last         0.000000            SARIMAX
# 34        False            last         0.000000            SARIMAX
#
#     P0 Best Model RMSE P0+Sim Best Model Name  P0+Sim Best Model RMSE
# 0             0.074880                     ML                0.074880
# 4             0.069895                     ML                0.069895
# 8             0.064195                     ML                0.065336
# 1             0.055895                     ML                0.054949
# 5             0.057594                     ML                0.060788
# 9             0.058057                     ML                0.070431
# 3             0.048723                     ML                0.047932
# 7             0.056825           auto_SARIMAX                0.059034
# 11            0.050590           auto_SARIMAX                0.056480
# 2             0.001320                     ML                0.031958
# 6             0.001044                     ML                0.028594
# 10            0.001135           auto_SARIMAX                0.020843
# 39            0.049483           auto_SARIMAX                0.099230
# 43            0.050417           auto_SARIMAX                0.102318
# 47            0.077907                     ML                0.084609
# 36            0.114726                     ML                0.114726
# 40            0.097598                     ML                0.097598
# 44            0.082030                     ML                0.082030
# 38            0.110920                SARIMAX                0.114843
# 42            0.122456                SARIMAX                0.121894
# 46            0.121268           auto_SARIMAX                0.134661
# 37            0.112525           auto_SARIMAX                0.124934
# 41            0.128680                     ML                0.125681
# 45            0.106713                     ML                0.126139
# 15            0.110073                     ML                0.103591
# 19            0.110073                     ML                0.103591
# 23            0.106258                     ML                0.110778
# 14            0.141781                SARIMAX                0.115253
# 18            0.141624                     ML                0.139746
# 22            0.130413                SARIMAX                0.126367
# 13            0.188430                     ML                0.175243
# 17            0.204441                     ML                0.188277
# 21            0.205818                     ML                0.185964
# 12            0.070390                SARIMAX                0.074834
# 16            0.066565                SARIMAX                0.089647
# 20            0.056497                SARIMAX                0.077147
# 25            0.089950           auto_SARIMAX                0.091008
# 29            0.105715           auto_SARIMAX                0.116920
# 33            0.098518                     ML                0.098565
# 24            0.061341                     ML                0.062604
# 28            0.063986                     ML                0.067332
# 32            0.082589                SARIMAX                0.076721
# 27            0.064250           auto_SARIMAX                0.060286
# 31            0.091435                     ML                0.090734
# 35            0.076854                     ML                0.083041
# 26            0.001320                SARIMAX                0.022063
# 30            0.001044                     ML                0.021971
# 34            0.001135                     ML                0.017556

# %% [markdown]
# ## Optimizer

# %% [markdown]
# ### Summary by Chain

# %%
full_chain_summary
# Out:
#          Chain Master  P0 Non-Opt Revenue  P0 Opt Revenue  P0 Opt Diff  \
# 0                                 32514.0         32488.0        -26.0
# 1               SPECS             15628.0         17440.0       1812.0
# 2    THE BARREL HOUSE              6520.0          6566.0         46.0
# 3  WESTERN BEV LIQ TX             10863.0         19655.0       8792.0
#
#    P0 Opt Diff Ratio  P0+Sim Non-Opt Revenue  P0+Sim Opt Revenue  \
# 0           0.999200                 23690.0             23704.0
# 1           1.115946                 14147.0         342298028.0
# 2           1.007055                  7530.0              7626.0
# 3           1.809353                 17562.0            749023.0
#
#    P0+Sim Opt Diff  P0+Sim Opt Diff Ratio
# 0             14.0               1.000591
# 1      342283881.0           24195.803209
# 2             96.0               1.012749
# 3         731461.0              42.650211

# %%
print("WRITE this value in the summary table in Git hub --->",round(full_chain_summary[full_chain_summary['Chain Master']=='']['P0+Sim Opt Diff Ratio'].item(),4))
# Out:
# WRITE this value in the summary table in Git hub ---> 1.0006

# %% [markdown]
# Link to the Git Hub Summary Table: https://github.com/ngupta23/msds_capstone/issues/84

# %% [markdown]
# ### Summary by Chain and Product

# %%
full_summary
# Out:
#           Chain Master                        Product  P0 Non-Opt Revenue  \
# 0                                  TAAKA VODKA 80  1L             16812.0
# 1                        TAAKA VODKA 80 BLUE PET 375M             10119.0
# 2                            TAAKA VODKA 80 PET 1.75L              5568.0
# 3                        TEXAS SPIRIT VODKA 80  1.75L                15.0
# 4                SPECS  MCCORMICK CHERRY VODKA 60  1L               242.0
# 5                SPECS             TAAKA VODKA 80  1L             12144.0
# 6                SPECS   TAAKA VODKA 80 BLUE PET 375M              1057.0
# 7                SPECS       TAAKA VODKA 80 PET 1.75L              2185.0
# 8     THE BARREL HOUSE             DOBRA VODKA  1.75L               828.0
# 9     THE BARREL HOUSE             TAAKA VODKA 80  1L              1573.0
# 10    THE BARREL HOUSE   TAAKA VODKA 80 BLUE PET 200M              1034.0
# 11    THE BARREL HOUSE   TAAKA VODKA 80 BLUE PET 375M              3085.0
# 12  WESTERN BEV LIQ TX             TAAKA VODKA 80  1L              7507.0
# 13  WESTERN BEV LIQ TX   TAAKA VODKA 80 BLUE PET 375M              1202.0
# 14  WESTERN BEV LIQ TX       TAAKA VODKA 80 PET 1.75L              2139.0
# 15  WESTERN BEV LIQ TX   TEXAS SPIRIT VODKA 80  1.75L                15.0
#
#     P0 Opt Revenue  P0 Opt Diff  P0 Opt Diff Ratio  P0+Sim Non-Opt Revenue  \
# 0          16772.0        -40.0           0.997621                 16711.0
# 1          10119.0          0.0           1.000000                   591.0
# 2           5568.0          0.0           1.000000                  5733.0
# 3             29.0         14.0           1.933333                   655.0
# 4            269.0         27.0           1.111570                   252.0
# 5          12144.0          0.0           1.000000                 12144.0
# 6           1150.0         93.0           1.087985                  1101.0
# 7           3877.0       1692.0           1.774371                   650.0
# 8            850.0         22.0           1.026570                  1099.0
# 9           1595.0         22.0           1.013986                  1980.0
# 10          1036.0          2.0           1.001934                   929.0
# 11          3085.0          0.0           1.000000                  3522.0
# 12         15175.0       7668.0           2.021447                  8486.0
# 13          1202.0          0.0           1.000000                  3328.0
# 14          3249.0       1110.0           1.518934                  5094.0
# 15            29.0         14.0           1.933333                   654.0
#
#     P0+Sim Opt Revenue  P0+Sim Opt Diff  P0+Sim Opt Diff Ratio
# 0              16671.0            -40.0               0.997606
# 1                591.0              0.0               1.000000
# 2               5790.0             57.0               1.009942
# 3                652.0             -3.0               0.995420
# 4                426.0            174.0               1.690476
# 5              12049.0            -95.0               0.992177
# 6          342285002.0      342283901.0          310885.560400
# 7                551.0            -99.0               0.847692
# 8               1135.0             36.0               1.032757
# 9               1830.0           -150.0               0.924242
# 10               929.0              0.0               1.000000
# 11              3732.0            210.0               1.059625
# 12             12953.0           4467.0               1.526396
# 13              3351.0             23.0               1.006911
# 14              5466.0            372.0               1.073027
# 15            727253.0         726599.0            1112.007645

# %% [markdown]
# ### P0 Optimizer

# %%
full_opt[outputColsOptP0]
# Out:
#           Chain Master                        Product  Period to Last  \
# 0                                  TAAKA VODKA 80  1L               1
# 4                                  TAAKA VODKA 80  1L               2
# 8                                  TAAKA VODKA 80  1L               3
# 1                        TAAKA VODKA 80 BLUE PET 375M               1
# 5                        TAAKA VODKA 80 BLUE PET 375M               2
# 9                        TAAKA VODKA 80 BLUE PET 375M               3
# 3                            TAAKA VODKA 80 PET 1.75L               1
# 7                            TAAKA VODKA 80 PET 1.75L               2
# 11                           TAAKA VODKA 80 PET 1.75L               3
# 2                        TEXAS SPIRIT VODKA 80  1.75L               1
# 6                        TEXAS SPIRIT VODKA 80  1.75L               2
# 10                       TEXAS SPIRIT VODKA 80  1.75L               3
# 39               SPECS  MCCORMICK CHERRY VODKA 60  1L               1
# 43               SPECS  MCCORMICK CHERRY VODKA 60  1L               2
# 47               SPECS  MCCORMICK CHERRY VODKA 60  1L               3
# 36               SPECS             TAAKA VODKA 80  1L               1
# 40               SPECS             TAAKA VODKA 80  1L               2
# 44               SPECS             TAAKA VODKA 80  1L               3
# 38               SPECS   TAAKA VODKA 80 BLUE PET 375M               1
# 42               SPECS   TAAKA VODKA 80 BLUE PET 375M               2
# 46               SPECS   TAAKA VODKA 80 BLUE PET 375M               3
# 37               SPECS       TAAKA VODKA 80 PET 1.75L               1
# 41               SPECS       TAAKA VODKA 80 PET 1.75L               2
# 45               SPECS       TAAKA VODKA 80 PET 1.75L               3
# 15    THE BARREL HOUSE             DOBRA VODKA  1.75L               1
# 19    THE BARREL HOUSE             DOBRA VODKA  1.75L               2
# 23    THE BARREL HOUSE             DOBRA VODKA  1.75L               3
# 14    THE BARREL HOUSE             TAAKA VODKA 80  1L               1
# 18    THE BARREL HOUSE             TAAKA VODKA 80  1L               2
# 22    THE BARREL HOUSE             TAAKA VODKA 80  1L               3
# 13    THE BARREL HOUSE   TAAKA VODKA 80 BLUE PET 200M               1
# 17    THE BARREL HOUSE   TAAKA VODKA 80 BLUE PET 200M               2
# 21    THE BARREL HOUSE   TAAKA VODKA 80 BLUE PET 200M               3
# 12    THE BARREL HOUSE   TAAKA VODKA 80 BLUE PET 375M               1
# 16    THE BARREL HOUSE   TAAKA VODKA 80 BLUE PET 375M               2
# 20    THE BARREL HOUSE   TAAKA VODKA 80 BLUE PET 375M               3
# 25  WESTERN BEV LIQ TX             TAAKA VODKA 80  1L               1
# 29  WESTERN BEV LIQ TX             TAAKA VODKA 80  1L               2
# 33  WESTERN BEV LIQ TX             TAAKA VODKA 80  1L               3
# 24  WESTERN BEV LIQ TX   TAAKA VODKA 80 BLUE PET 375M               1
# 28  WESTERN BEV LIQ TX   TAAKA VODKA 80 BLUE PET 375M               2
# 32  WESTERN BEV LIQ TX   TAAKA VODKA 80 BLUE PET 375M               3
# 27  WESTERN BEV LIQ TX       TAAKA VODKA 80 PET 1.75L               1
# 31  WESTERN BEV LIQ TX       TAAKA VODKA 80 PET 1.75L               2
# 35  WESTERN BEV LIQ TX       TAAKA VODKA 80 PET 1.75L               3
# 26  WESTERN BEV LIQ TX   TEXAS SPIRIT VODKA 80  1.75L               1
# 30  WESTERN BEV LIQ TX   TEXAS SPIRIT VODKA 80  1.75L               2
# 34  WESTERN BEV LIQ TX   TEXAS SPIRIT VODKA 80  1.75L               3
#
#     P0 Non-Opt Price  P0 Non-Opt Demand  P0 Non-Opt Revenue  \
# 0              44.42                115                5103
# 4              44.30                107                4750
# 8              44.47                156                6959
# 1              58.56                  3                 189
# 5              58.56                 92                5394
# 9              58.56                 77                4536
# 3              47.03                 49                2298
# 7              47.03                 38                1782
# 11             47.03                 32                1488
# 2              51.18                  0                   5
# 6              51.18                  0                   5
# 10             51.18                  0                   5
# 39             45.74                  1                  65
# 43             45.74                  1                  66
# 47             45.74                  2                 111
# 36             44.30                 98                4348
# 40             44.30                 85                3780
# 44             44.30                 91                4016
# 38             58.56                  6                 370
# 42             58.56                  6                 335
# 46             58.56                  6                 352
# 37             47.03                 13                 594
# 41             47.03                  3                 119
# 45             47.03                 31                1472
# 15             47.03                  8                 361
# 19             49.27                  8                 376
# 23             47.03                  2                  91
# 14             46.89                 11                 519
# 18             44.30                 11                 508
# 22             47.63                 11                 546
# 13             62.80                  6                 378
# 17             62.80                  4                 278
# 21             62.80                  6                 378
# 12             58.56                 18                1055
# 16             58.56                 18                1058
# 20             58.56                 17                 972
# 25             44.30                 74                3275
# 29             44.30                 54                2378
# 33             44.30                 42                1854
# 24             58.56                  6                 368
# 28             58.56                  7                 423
# 32             58.56                  7                 411
# 27             47.03                 16                 760
# 31             47.03                 16                 773
# 35             47.03                 13                 606
# 26             51.18                  0                   5
# 30             51.18                  0                   5
# 34             51.18                  0                   5
#
#     P0 Non-Opt Chain Master Revenue  P0 Optimal Price  P0 Demand  P0 Revenue  \
# 0                              7595             44.30        115        5089
# 4                             11931             44.30        107        4750
# 8                             12988             44.30        156        6933
# 1                              7595             58.56          3         189
# 5                             11931             58.56         92        5394
# 9                             12988             58.56         77        4536
# 3                              7595             47.03         49        2298
# 7                             11931             47.03         38        1782
# 11                            12988             47.03         32        1488
# 2                              7595             46.03          0          10
# 6                             11931             46.03          0           9
# 10                            12988             46.03          0          10
# 39                             5376             45.69          1          65
# 43                             4300             45.69          1          67
# 47                             5951             56.61          2         137
# 36                             5376             44.30         98        4348
# 40                             4300             44.30         85        3780
# 44                             5951             44.30         91        4016
# 38                             5376             61.49          7         409
# 42                             4300             61.49          6         371
# 46                             5951             61.49          6         370
# 37                             5376             47.03         13         594
# 41                             4300             47.02          3         119
# 45                             5951             46.98         67        3164
# 15                             2313             49.27          8         378
# 19                             2219             49.27          8         376
# 23                             1987             46.98          2          96
# 14                             2313             47.04         11         521
# 18                             2219             46.77         11         536
# 22                             1987             46.89         11         538
# 13                             2313             62.93          6         379
# 17                             2219             62.93          4         278
# 21                             1987             62.93          6         379
# 12                             2313             58.56         18        1055
# 16                             2219             58.56         18        1058
# 20                             1987             58.56         17         972
# 25                             4408             43.80        176        7691
# 29                             3579             43.80        129        5630
# 33                             2875             44.30         42        1854
# 24                             4408             58.56          6         368
# 28                             3579             58.56          7         423
# 32                             2875             58.56          7         411
# 27                             4408             46.98         25        1154
# 31                             3579             46.98         25        1175
# 35                             2875             46.98         20         920
# 26                             4408             46.03          0          10
# 30                             3579             46.03          0           9
# 34                             2875             46.03          0          10
#
#     P0 Chain Master Revenue
# 0                      7586
# 4                     11935
# 8                     12967
# 1                      7586
# 5                     11935
# 9                     12967
# 3                      7586
# 7                     11935
# 11                    12967
# 2                      7586
# 6                     11935
# 10                    12967
# 39                     5416
# 43                     4336
# 47                     7687
# 36                     5416
# 40                     4336
# 44                     7687
# 38                     5416
# 42                     4336
# 46                     7687
# 37                     5416
# 41                     4336
# 45                     7687
# 15                     2332
# 19                     2248
# 23                     1984
# 14                     2332
# 18                     2248
# 22                     1984
# 13                     2332
# 17                     2248
# 21                     1984
# 12                     2332
# 16                     2248
# 20                     1984
# 25                     9222
# 29                     7237
# 33                     3195
# 24                     9222
# 28                     7237
# 32                     3195
# 27                     9222
# 31                     7237
# 35                     3195
# 26                     9222
# 30                     7237
# 34                     3195

# %% [markdown]
# ### P0+Sim Optimizer

# %%
full_opt[outputColsOptP0Sim]
# Out:
#           Chain Master                        Product  Period to Last  \
# 0                                  TAAKA VODKA 80  1L               1
# 4                                  TAAKA VODKA 80  1L               2
# 8                                  TAAKA VODKA 80  1L               3
# 1                        TAAKA VODKA 80 BLUE PET 375M               1
# 5                        TAAKA VODKA 80 BLUE PET 375M               2
# 9                        TAAKA VODKA 80 BLUE PET 375M               3
# 3                            TAAKA VODKA 80 PET 1.75L               1
# 7                            TAAKA VODKA 80 PET 1.75L               2
# 11                           TAAKA VODKA 80 PET 1.75L               3
# 2                        TEXAS SPIRIT VODKA 80  1.75L               1
# 6                        TEXAS SPIRIT VODKA 80  1.75L               2
# 10                       TEXAS SPIRIT VODKA 80  1.75L               3
# 39               SPECS  MCCORMICK CHERRY VODKA 60  1L               1
# 43               SPECS  MCCORMICK CHERRY VODKA 60  1L               2
# 47               SPECS  MCCORMICK CHERRY VODKA 60  1L               3
# 36               SPECS             TAAKA VODKA 80  1L               1
# 40               SPECS             TAAKA VODKA 80  1L               2
# 44               SPECS             TAAKA VODKA 80  1L               3
# 38               SPECS   TAAKA VODKA 80 BLUE PET 375M               1
# 42               SPECS   TAAKA VODKA 80 BLUE PET 375M               2
# 46               SPECS   TAAKA VODKA 80 BLUE PET 375M               3
# 37               SPECS       TAAKA VODKA 80 PET 1.75L               1
# 41               SPECS       TAAKA VODKA 80 PET 1.75L               2
# 45               SPECS       TAAKA VODKA 80 PET 1.75L               3
# 15    THE BARREL HOUSE             DOBRA VODKA  1.75L               1
# 19    THE BARREL HOUSE             DOBRA VODKA  1.75L               2
# 23    THE BARREL HOUSE             DOBRA VODKA  1.75L               3
# 14    THE BARREL HOUSE             TAAKA VODKA 80  1L               1
# 18    THE BARREL HOUSE             TAAKA VODKA 80  1L               2
# 22    THE BARREL HOUSE             TAAKA VODKA 80  1L               3
# 13    THE BARREL HOUSE   TAAKA VODKA 80 BLUE PET 200M               1
# 17    THE BARREL HOUSE   TAAKA VODKA 80 BLUE PET 200M               2
# 21    THE BARREL HOUSE   TAAKA VODKA 80 BLUE PET 200M               3
# 12    THE BARREL HOUSE   TAAKA VODKA 80 BLUE PET 375M               1
# 16    THE BARREL HOUSE   TAAKA VODKA 80 BLUE PET 375M               2
# 20    THE BARREL HOUSE   TAAKA VODKA 80 BLUE PET 375M               3
# 25  WESTERN BEV LIQ TX             TAAKA VODKA 80  1L               1
# 29  WESTERN BEV LIQ TX             TAAKA VODKA 80  1L               2
# 33  WESTERN BEV LIQ TX             TAAKA VODKA 80  1L               3
# 24  WESTERN BEV LIQ TX   TAAKA VODKA 80 BLUE PET 375M               1
# 28  WESTERN BEV LIQ TX   TAAKA VODKA 80 BLUE PET 375M               2
# 32  WESTERN BEV LIQ TX   TAAKA VODKA 80 BLUE PET 375M               3
# 27  WESTERN BEV LIQ TX       TAAKA VODKA 80 PET 1.75L               1
# 31  WESTERN BEV LIQ TX       TAAKA VODKA 80 PET 1.75L               2
# 35  WESTERN BEV LIQ TX       TAAKA VODKA 80 PET 1.75L               3
# 26  WESTERN BEV LIQ TX   TEXAS SPIRIT VODKA 80  1.75L               1
# 30  WESTERN BEV LIQ TX   TEXAS SPIRIT VODKA 80  1.75L               2
# 34  WESTERN BEV LIQ TX   TEXAS SPIRIT VODKA 80  1.75L               3
#
#     P0+Sim Non-Opt Price  P0+Sim Non-Opt Demand  P0+Sim Non-Opt Revenue  \
# 0                  44.42                    115                    5103
# 4                  44.30                    107                    4750
# 8                  44.47                    154                    6858
# 1                  58.56                      3                     197
# 5                  58.56                      3                     193
# 9                  58.56                      3                     201
# 3                  47.03                     49                    2324
# 7                  47.03                     37                    1762
# 11                 47.03                     35                    1647
# 2                  51.18                      6                     326
# 6                  51.18                      6                     322
# 10                 51.18                      0                       7
# 39                 45.74                      2                      69
# 43                 45.74                      2                      74
# 47                 45.74                      2                     109
# 36                 44.30                     98                    4348
# 40                 44.30                     85                    3780
# 44                 44.30                     91                    4016
# 38                 58.56                      7                     383
# 42                 58.56                      5                     310
# 46                 58.56                      7                     408
# 37                 47.03                      9                     418
# 41                 47.03                      2                     117
# 45                 47.03                      2                     115
# 15                 47.03                      8                     362
# 19                 49.27                      8                     375
# 23                 47.03                      8                     362
# 14                 46.89                      9                     435
# 18                 44.30                     12                     518
# 22                 47.63                     22                    1027
# 13                 62.80                      5                     328
# 17                 62.80                      5                     304
# 21                 62.80                      5                     297
# 12                 58.56                     24                    1405
# 16                 58.56                     18                    1039
# 20                 58.56                     18                    1078
# 25                 44.30                     78                    3444
# 29                 44.30                     72                    3190
# 33                 44.30                     42                    1852
# 24                 58.56                      6                     375
# 28                 58.56                      7                     423
# 32                 58.56                     43                    2530
# 27                 47.03                     24                    1115
# 31                 47.03                     42                    1985
# 35                 47.03                     42                    1994
# 26                 51.18                      0                       6
# 30                 51.18                      6                     322
# 34                 51.18                      6                     326
#
#     P0+Sim Non-Opt Chain Master Revenue  P0+Sim Optimal Price  P0+Sim Demand  \
# 0                                  7949                 44.30            115
# 4                                  7027                 44.30            107
# 8                                  8713                 44.30            154
# 1                                  7949                 58.56              3
# 5                                  7027                 58.56              3
# 9                                  8713                 58.56              3
# 3                                  7949                 47.03             49
# 7                                  7027                 46.98             40
# 11                                 8713                 46.98             34
# 2                                  7949                 51.18              6
# 6                                  7027                 51.18              6
# 10                                 8713                 51.18              0
# 39                                 5218                 45.69              5
# 43                                 4282                 45.69              2
# 47                                 4648                 56.61              2
# 36                                 5218                 43.80             98
# 40                                 4282                 44.30             85
# 44                                 4648                 43.80             91
# 38                                 5218                 55.63        2665095
# 42                                 4282                 55.63        3487764
# 46                                 4648                 61.49             24
# 37                                 5218                 47.03              7
# 41                                 4282                 47.03              2
# 45                                 4648                 47.03              2
# 15                                 2531                 49.27              8
# 19                                 2237                 49.27              8
# 23                                 2765                 49.27              8
# 14                                 2531                 47.04              9
# 18                                 2237                 46.77             12
# 22                                 2765                 46.89             18
# 13                                 2531                 62.80              5
# 17                                 2237                 62.93              5
# 21                                 2765                 62.80              5
# 12                                 2531                 58.56             24
# 16                                 2237                 58.56             21
# 20                                 2765                 58.56             19
# 25                                 4940                 43.80            130
# 29                                 5920                 43.80            124
# 33                                 6702                 43.80             42
# 24                                 4940                 58.56              6
# 28                                 5920                 58.56              7
# 32                                 6702                 58.56             44
# 27                                 4940                 47.03             32
# 31                                 5920                 47.03             42
# 35                                 6702                 47.03             42
# 26                                 4940                 46.03          15785
# 30                                 5920                 51.18              6
# 34                                 6702                 51.18              6
#
#     P0+Sim Revenue  P0+Sim Chain Master Revenue
# 0             5089                         7935
# 4             4750                         7143
# 8             6832                         8625
# 1              197                         7935
# 5              193                         7143
# 9              201                         8625
# 3             2324                         7935
# 7             1878                         7143
# 11            1588                         8625
# 2              326                         7935
# 6              322                         7143
# 10               4                         8625
# 39             216                    148264057
# 43              75                    194028257
# 47             135                         5715
# 36            4299                    148264057
# 40            3780                    194028257
# 44            3970                         5715
# 38       148259223                    148264057
# 42       194024285                    194028257
# 46            1494                         5715
# 37             319                    148264057
# 41             117                    194028257
# 45             115                         5715
# 15             380                         2572
# 19             375                         2449
# 23             380                         2606
# 14             444                         2572
# 18             547                         2449
# 22             839                         2606
# 13             328                         2572
# 17             304                         2449
# 21             297                         2606
# 12            1420                         2572
# 16            1222                         2449
# 20            1090                         2606
# 25            5711                       734178
# 29            5411                         8141
# 33            1831                         6704
# 24             375                       734178
# 28             423                         8141
# 32            2553                         6704
# 27            1487                       734178
# 31            1985                         8141
# 35            1994                         6704
# 26          726605                       734178
# 30             322                         8141
# 34             326                         6704

# %% [markdown]
# ### Naive

# %%
full_opt[outputColsOptNaive]
# Out:
#           Chain Master                        Product  Period to Last  \
# 0                                  TAAKA VODKA 80  1L               1
# 4                                  TAAKA VODKA 80  1L               2
# 8                                  TAAKA VODKA 80  1L               3
# 1                        TAAKA VODKA 80 BLUE PET 375M               1
# 5                        TAAKA VODKA 80 BLUE PET 375M               2
# 9                        TAAKA VODKA 80 BLUE PET 375M               3
# 3                            TAAKA VODKA 80 PET 1.75L               1
# 7                            TAAKA VODKA 80 PET 1.75L               2
# 11                           TAAKA VODKA 80 PET 1.75L               3
# 2                        TEXAS SPIRIT VODKA 80  1.75L               1
# 6                        TEXAS SPIRIT VODKA 80  1.75L               2
# 10                       TEXAS SPIRIT VODKA 80  1.75L               3
# 39               SPECS  MCCORMICK CHERRY VODKA 60  1L               1
# 43               SPECS  MCCORMICK CHERRY VODKA 60  1L               2
# 47               SPECS  MCCORMICK CHERRY VODKA 60  1L               3
# 36               SPECS             TAAKA VODKA 80  1L               1
# 40               SPECS             TAAKA VODKA 80  1L               2
# 44               SPECS             TAAKA VODKA 80  1L               3
# 38               SPECS   TAAKA VODKA 80 BLUE PET 375M               1
# 42               SPECS   TAAKA VODKA 80 BLUE PET 375M               2
# 46               SPECS   TAAKA VODKA 80 BLUE PET 375M               3
# 37               SPECS       TAAKA VODKA 80 PET 1.75L               1
# 41               SPECS       TAAKA VODKA 80 PET 1.75L               2
# 45               SPECS       TAAKA VODKA 80 PET 1.75L               3
# 15    THE BARREL HOUSE             DOBRA VODKA  1.75L               1
# 19    THE BARREL HOUSE             DOBRA VODKA  1.75L               2
# 23    THE BARREL HOUSE             DOBRA VODKA  1.75L               3
# 14    THE BARREL HOUSE             TAAKA VODKA 80  1L               1
# 18    THE BARREL HOUSE             TAAKA VODKA 80  1L               2
# 22    THE BARREL HOUSE             TAAKA VODKA 80  1L               3
# 13    THE BARREL HOUSE   TAAKA VODKA 80 BLUE PET 200M               1
# 17    THE BARREL HOUSE   TAAKA VODKA 80 BLUE PET 200M               2
# 21    THE BARREL HOUSE   TAAKA VODKA 80 BLUE PET 200M               3
# 12    THE BARREL HOUSE   TAAKA VODKA 80 BLUE PET 375M               1
# 16    THE BARREL HOUSE   TAAKA VODKA 80 BLUE PET 375M               2
# 20    THE BARREL HOUSE   TAAKA VODKA 80 BLUE PET 375M               3
# 25  WESTERN BEV LIQ TX             TAAKA VODKA 80  1L               1
# 29  WESTERN BEV LIQ TX             TAAKA VODKA 80  1L               2
# 33  WESTERN BEV LIQ TX             TAAKA VODKA 80  1L               3
# 24  WESTERN BEV LIQ TX   TAAKA VODKA 80 BLUE PET 375M               1
# 28  WESTERN BEV LIQ TX   TAAKA VODKA 80 BLUE PET 375M               2
# 32  WESTERN BEV LIQ TX   TAAKA VODKA 80 BLUE PET 375M               3
# 27  WESTERN BEV LIQ TX       TAAKA VODKA 80 PET 1.75L               1
# 31  WESTERN BEV LIQ TX       TAAKA VODKA 80 PET 1.75L               2
# 35  WESTERN BEV LIQ TX       TAAKA VODKA 80 PET 1.75L               3
# 26  WESTERN BEV LIQ TX   TEXAS SPIRIT VODKA 80  1.75L               1
# 30  WESTERN BEV LIQ TX   TEXAS SPIRIT VODKA 80  1.75L               2
# 34  WESTERN BEV LIQ TX   TEXAS SPIRIT VODKA 80  1.75L               3
#
#     Actual Price  Actual Demand  Actual Revenue  Actual Chain Master Revenue  \
# 0      44.420127         172.90         7680.24                     14429.10
# 4      44.300752         195.51         8661.24                     14927.46
# 8      44.467025         186.20         8279.76                     15600.06
# 1      58.560000          88.00         5153.28                     14429.10
# 5      58.560000          76.00         4450.56                     14927.46
# 9      58.560000          94.00         5504.64                     15600.06
# 3      47.025641          33.93         1595.58                     14429.10
# 7      47.025641          38.61         1815.66                     14927.46
# 11     47.025641          38.61         1815.66                     15600.06
# 2      51.179487           0.00            0.00                     14429.10
# 6      51.179487           0.00            0.00                     14927.46
# 10     51.179487           0.00            0.00                     15600.06
# 39     45.744361           1.33           60.84                      5754.06
# 43     45.744361           1.33           60.84                      6147.36
# 47     45.744361           1.33           60.84                      5565.24
# 36     44.300752         113.05         5008.20                      5754.06
# 40     44.300752         117.04         5184.96                      6147.36
# 44     44.300752         103.74         4595.76                      5565.24
# 38     58.560000           7.00          409.92                      5754.06
# 42     58.560000           6.00          351.36                      6147.36
# 46     58.560000           8.00          468.48                      5565.24
# 37     47.025641           5.85          275.10                      5754.06
# 41     47.025641          11.70          550.20                      6147.36
# 45     47.025641           9.36          440.16                      5565.24
# 15     47.025641           1.17           55.02                      1819.26
# 19     49.268571           0.00            0.00                      1576.20
# 23     47.025641           1.17           55.02                      2424.18
# 14     46.887218           7.98          374.16                      1819.26
# 18     44.300752           6.65          294.60                      1576.20
# 22     47.626208           9.31          443.40                      2424.18
# 13     62.803738           5.35          336.00                      1819.26
# 17     62.803738           6.42          403.20                      1576.20
# 21     62.803738           6.42          403.20                      2424.18
# 12     58.560000          18.00         1054.08                      1819.26
# 16     58.560000          15.00          878.40                      1576.20
# 20     58.560000          26.00         1522.56                      2424.18
# 25     44.300752          51.87         2297.88                      6922.50
# 29     44.300752          71.82         3181.68                      7227.78
# 33     44.300752          73.15         3240.60                      7634.52
# 24     58.560000          63.00         3689.28                      6922.50
# 28     58.560000          55.00         3220.80                      7227.78
# 32     58.560000          60.00         3513.60                      7634.52
# 27     47.025641          19.89          935.34                      6922.50
# 31     47.025641          17.55          825.30                      7227.78
# 35     47.025641          18.72          880.32                      7634.52
# 26     51.179487           0.00            0.00                      6922.50
# 30     51.179487           0.00            0.00                      7227.78
# 34     51.179487           0.00            0.00                      7634.52
#
#     Naive Prices  Naive Demand  Naive Revenue  Naive Chain Master Revenue
# 0      44.420127    199.948711    8881.747177                14676.651274
# 4      44.300752    200.002841    8860.276255                15703.512596
# 8      44.467025    200.173247    8901.108716                13981.655382
# 1      58.560000     76.000000    4450.560000                14676.651274
# 5      58.560000     94.000000    5504.640000                15703.512596
# 9      58.560000     64.000000    3747.840000                13981.655382
# 3      47.025641     28.587470    1344.344096                14676.651274
# 7      47.025641     28.465244    1338.596341                15703.512596
# 11     47.025641     28.340000    1332.706667                13981.655382
# 2      51.179487      0.000000       0.000000                14676.651274
# 6      51.179487      0.000000       0.000000                15703.512596
# 10     51.179487      0.000000       0.000000                13981.655382
# 39     45.744361      1.330000      60.840000                 5722.948916
# 43     45.744361      1.330000      60.840000                 5128.573171
# 47     45.744361      0.000000       0.000000                 7119.450370
# 36     44.300752    117.040000    5184.960000                 5722.948916
# 40     44.300752    103.740000    4595.760000                 5128.573171
# 44     44.300752    150.175062    6652.868148                 7119.450370
# 38     58.560000      3.801205     222.598554                 5722.948916
# 42     58.560000      3.774390     221.028293                 5128.573171
# 46     58.560000      3.722222     217.973333                 7119.450370
# 37     47.025641      5.413012     254.550361                 5722.948916
# 41     47.025641      5.336341     250.944878                 5128.573171
# 45     47.025641      5.286667     248.608889                 7119.450370
# 15     47.025641      2.974337     139.870120                 1769.838906
# 19     49.268571      1.170000      57.644229                 2313.102291
# 23     47.025641      1.170000      55.020000                 1689.561140
# 14     46.887218      7.452586     349.431034                 1769.838906
# 18     44.300752      7.466667     330.778947                 2313.102291
# 22     47.626208      7.433750     354.041327                 1689.561140
# 13     62.803738      6.403086     402.137751                 1769.838906
# 17     62.803738      6.402789     402.119115                 2313.102291
# 21     62.803738      6.402482     402.099813                 1689.561140
# 12     58.560000     15.000000     878.400000                 1769.838906
# 16     58.560000     26.000000    1522.560000                 2313.102291
# 20     58.560000     15.000000     878.400000                 1689.561140
# 25     44.300752     71.820000    3181.680000                 7227.780000
# 29     44.300752     73.150000    3240.600000                 7634.520000
# 33     44.300752     58.520000    2592.480000                 6008.397037
# 24     58.560000     55.000000    3220.800000                 7227.780000
# 28     58.560000     60.000000    3513.600000                 7634.520000
# 32     58.560000     42.000000    2459.520000                 6008.397037
# 27     47.025641     17.550000     825.300000                 7227.780000
# 31     47.025641     18.720000     880.320000                 7634.520000
# 35     47.025641     20.337778     956.397037                 6008.397037
# 26     51.179487      0.000000       0.000000                 7227.780000
# 30     51.179487      0.000000       0.000000                 7634.520000
# 34     51.179487      0.000000       0.000000                 6008.397037
