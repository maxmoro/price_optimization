# %% [markdown]
# # Init

# %%
# %load_ext autoreload
# %autoreload 2

# %%
print("CURRENT FOLDER:")
# %pwd
# Out:
# CURRENT FOLDER:
# 'c:\\max\\Google Drive Max\\Max Shared\\Master Data Science\\2020-05 Capstone A\\msds_capstone\\analysis\\fullRuns'

# %%
import os
import glob
import sys
sys.path.append(os.environ['DEV_AUTOTS'])
sys.path.append(os.environ['CAPSTONE_PYTHON_SOURCE'])
folder = os.environ['CAPSTONE_DATA']

# %%
## Sourcing the .py with all the code##
t='"'+os.environ['CAPSTONE_PYTHON_SOURCE']+'\\fullRun\\fullRun.py'+'"'
# %run -i $t
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# Running Auto Timeseries version: 0.0.24

# %% [markdown]
# # Parameters

# %%
#Parameters

ProdCats = ['ECONOMY VODKA']
TOP_PRODUCTS = 3  # How many products to consider in the category
TOP_SIMILAR = 1  # Get TOP_SIMILAR most similar products
RUN_PERIODS = [1,2,3] # this will run AutoTS and Optimzer for speicfic periods (1 = last, 2 = second to last)

CV_NUM = 10         # number of Cross Valudations  10
OPT_CALLS = 100     # number of calls for the optimizer process   100
OPT_RND_STARTS = 20 # number of random calls for the optimizer process  20

LOG_TRANSFORM = True # Take log of 9L cases to smooth out peaks and valleys
ZERO_ADDER = 0.1 

RESAMPLE_FREQ = 'M'


# Pricing changes every 4 weeks
if RESAMPLE_FREQ == 'M':    FORECAST_PERIOD = 1 #last 4 months as test 
if RESAMPLE_FREQ == 'W':    FORECAST_PERIOD = 4 
if RESAMPLE_FREQ == '2W':   FORECAST_PERIOD = 2 

# Seasonal Period
if RESAMPLE_FREQ == 'M':    SEASONAL_PERIOD = 12  # Yearly
if RESAMPLE_FREQ == 'W':    SEASONAL_PERIOD = 13 # Quarterly (we can also take yearly = 52, but SARIMAX becomes too slow)
if RESAMPLE_FREQ == '2W':   SEASONAL_PERIOD = 13 # This becomes problematic --> for quarterly, should we take 6 biweekly periods or 7 bi-weekly periods. Instead I just took half yearly period  

COL_TIME = 'WeekDate'
COL_PREDS = ['9L Cases'] #Demand
COL_PRICE= ['Dollar Sales per 9L Case'] #Price

# %% [markdown]
# # Full Run

# %%
dataRaw = loadDataset(version=4)
ProdCat = ProdCats[0]
ChainMasters =  [''] +  dataRaw['Chain Master'].unique().tolist() 
display(ChainMasters,ProdCats)
# Out:
# ['', 'THE BARREL HOUSE', 'WESTERN BEV LIQ TX', 'SPECS']
# ['ECONOMY VODKA']

# %%
(full_models,full_opt,full_summary,full_chain_summary)  = fullRun(ProdCat = ProdCat
                                                           ,ChainMasters = ChainMasters
                                                           ,dataRaw = dataRaw
                                                           ,savePKL=True
                                                           ,saveXLS=True)
# Out:
# ==================================================
# Parameters being used...
# ==================================================
# TOP_PRODUCTS = 3
# TOP_SIMILAR = 1
# RUN_PERIODS = [1, 2, 3]
# ProdCat: ECONOMY VODKA
# ChainMasters: ['', 'THE BARREL HOUSE', 'WESTERN BEV LIQ TX', 'SPECS']
#
#
# ======================== (2020-09-13 23:56:01.385507)
# ==== Products List  ====
# ==== ECONOMY VODKA =====
# ===========  ===========
# ========================
#
#
#
# ======================= (2020-09-13 23:56:06.927510)
# ======= AUTO-TS =======
# ==== ECONOMY VODKA ====
# ==========  ===========
# ========== 1 ==========
# =======================
#
#
#
# ================== (2020-09-13 23:56:06.928509)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 BLUE PET 375M', '2': 'TEXAS SPIRIT VODKA 80  1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 1.1904761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 69.04761904761905
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
#
#
# ===================== (2020-09-13 23:57:00.252505)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#        lb_stat     lb_pvalue
# 12  248.948794  2.266370e-46
# 24  282.763358  4.861676e-46
# 48  368.538254  5.288988e-51
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  584.901182  1.773645e-117
# 24  743.424992  1.784213e-141
# 48  947.167628  2.940142e-167
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  474.857092   4.940599e-94
# 24  562.831143  1.385783e-103
# 48  697.054286  5.309923e-116
#
# Is Data White Noise: False
#
#
# ==================== (2020-09-13 23:57:00.270505)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (83, 4) (1, 4)
# (83, 4) (1, 4)
# (83, 4) (1, 4)
#
#
# =============== (2020-09-13 23:57:00.277507)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean    0.08373         []
# 1  1      last    0.05092         []
# 2  2      last    0.00000         []
#
#                                            All RMSEs  \
# 0  [[0.08522395141312492, 0.11059590470983931, 0....
# 1  [[0.050919719560484134, 0.058483693505752464, ...
# 2                                  [[0.0, 0.0, 0.0]]
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 2  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
#
#
# ===================== (2020-09-13 23:57:00.756507)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed: 25.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-14 00:21:59.566165)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed: 31.3min finished
# =================== (2020-09-14 00:53:15.941107)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-14 00:53:15.953108)
# ====== OPTIMIZER ======
# ==== ECONOMY VODKA ====
# ==========  ===========
# ========== 1 ==========
# =======================
#
#
#
# =========================== (2020-09-14 00:53:15.954109)
# ==== Running Optimizer ====
# ====== ECONOMY VODKA ======
# ============  =============
# ============ 1 ============
# ===========================
#
#
#
# ================== (2020-09-14 00:53:15.958108)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 BLUE PET 375M', '2': 'TEXAS SPIRIT VODKA 80  1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 1.1904761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 69.04761904761905
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
#
#
# ==================== (2020-09-14 00:54:16.634836)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (83, 4) (1, 4)
# (83, 4) (1, 4)
# (83, 4) (1, 4)
#
#
# ======================== (2020-09-14 00:54:16.640837)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-14 00:54:16.671837)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False]
#
#
# =============== (2020-09-14 00:54:16.673837)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-14 00:54:16.681837)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-14 00:54:16.682837)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-14 00:54:16.683836)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-14 00:54:18.807842)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-14 00:54:18.815840)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-14 00:59:11.590303)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-14 00:59:12.127301)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-14 00:59:12.128303)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-14 00:59:13.936304)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-14 00:59:13.943301)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-14 01:05:53.531097)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-14 01:05:53.913096)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-14 01:05:53.918096)
# ======= AUTO-TS =======
# ==== ECONOMY VODKA ====
# ==========  ===========
# ========== 2 ==========
# =======================
#
#
#
# ================== (2020-09-14 01:05:53.919095)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 BLUE PET 375M', '2': 'TEXAS SPIRIT VODKA 80  1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 1.2048192771084338
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 68.67469879518072
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
#
#
# ===================== (2020-09-14 01:06:40.495428)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#        lb_stat     lb_pvalue
# 12  247.379998  4.812566e-46
# 24  281.567711  8.439708e-46
# 48  366.781603  1.141278e-50
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  574.606302  2.792191e-115
# 24  727.477625  4.083848e-138
# 48  944.375636  1.109735e-166
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  468.018038   1.404414e-92
# 24  554.010494  9.591640e-102
# 48  696.468177  6.982057e-116
#
# Is Data White Noise: False
#
#
# ==================== (2020-09-14 01:06:40.525430)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (82, 4) (1, 4)
# (82, 4) (1, 4)
# (82, 4) (1, 4)
#
#
# =============== (2020-09-14 01:06:40.530429)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.077936         []
# 1  1      last   0.049104         []
# 2  2      last   0.000000         []
#
#                                            All RMSEs  \
# 0  [[0.08907681622057902, 0.11385458510024087, 0....
# 1  [[0.04910363192681037, 0.05961976914518541, 0....
# 2                                  [[0.0, 0.0, 0.0]]
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 2  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
#
#
# ===================== (2020-09-14 01:06:41.097427)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed: 21.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-14 01:27:40.008467)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed: 24.8min finished
# =================== (2020-09-14 01:52:30.463548)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-14 01:52:30.516550)
# ====== OPTIMIZER ======
# ==== ECONOMY VODKA ====
# ==========  ===========
# ========== 2 ==========
# =======================
#
#
#
# =========================== (2020-09-14 01:52:30.516550)
# ==== Running Optimizer ====
# ====== ECONOMY VODKA ======
# ============  =============
# ============ 2 ============
# ===========================
#
#
#
# ================== (2020-09-14 01:52:30.526547)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 BLUE PET 375M', '2': 'TEXAS SPIRIT VODKA 80  1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 1.2048192771084338
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 68.67469879518072
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
#
#
# ==================== (2020-09-14 01:53:08.249550)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (82, 4) (1, 4)
# (82, 4) (1, 4)
# (82, 4) (1, 4)
#
#
# ======================== (2020-09-14 01:53:08.257549)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-14 01:53:08.277550)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False]
#
#
# =============== (2020-09-14 01:53:08.280549)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-14 01:53:08.292550)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-14 01:53:08.294550)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-14 01:53:08.295549)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-14 01:53:09.182549)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-14 01:53:09.188549)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-14 02:00:29.761625)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-14 02:00:30.941625)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-14 02:00:30.943625)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-14 02:00:31.836624)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-14 02:00:31.846623)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-14 02:03:51.734670)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-14 02:03:52.152669)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-14 02:03:52.161671)
# ======= AUTO-TS =======
# ==== ECONOMY VODKA ====
# ==========  ===========
# ========== 3 ==========
# =======================
#
#
#
# ================== (2020-09-14 02:03:52.162669)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 BLUE PET 375M', '2': 'TEXAS SPIRIT VODKA 80  1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 68.29268292682927
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
#
#
# ===================== (2020-09-14 02:04:40.263669)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#        lb_stat     lb_pvalue
# 12  243.950101  2.495194e-45
# 24  277.452128  5.626127e-45
# 48  363.173548  5.530118e-50
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  563.083839  8.020215e-113
# 24  710.497889  1.533447e-134
# 48  939.687445  1.031921e-165
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  461.149000   4.046888e-91
# 24  545.150471  6.746748e-100
# 48  696.525463  6.797717e-116
#
# Is Data White Noise: False
#
#
# ==================== (2020-09-14 02:04:40.284667)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (81, 4) (1, 4)
# (81, 4) (1, 4)
# (81, 4) (1, 4)
#
#
# =============== (2020-09-14 02:04:40.290669)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.078022         []
# 1  1      last   0.044826         []
# 2  2      last   0.000000         []
#
#                                            All RMSEs  \
# 0  [[0.10614956572430416, 0.1364306802567358, 0.0...
# 1  [[0.04482627686032599, 0.061881124720379786, 0...
# 2                                  [[0.0, 0.0, 0.0]]
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 2  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
#
#
# ===================== (2020-09-14 02:04:40.740668)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed: 16.5min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-14 02:21:08.861759)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed: 22.9min finished
# =================== (2020-09-14 02:44:03.481758)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-14 02:44:03.540759)
# ====== OPTIMIZER ======
# ==== ECONOMY VODKA ====
# ==========  ===========
# ========== 3 ==========
# =======================
#
#
#
# =========================== (2020-09-14 02:44:03.541759)
# ==== Running Optimizer ====
# ====== ECONOMY VODKA ======
# ============  =============
# ============ 3 ============
# ===========================
#
#
#
# ================== (2020-09-14 02:44:03.552760)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 BLUE PET 375M', '2': 'TEXAS SPIRIT VODKA 80  1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 68.29268292682927
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
#
#
# ==================== (2020-09-14 02:44:39.802760)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (81, 4) (1, 4)
# (81, 4) (1, 4)
# (81, 4) (1, 4)
#
#
# ======================== (2020-09-14 02:44:39.810758)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-14 02:44:39.825757)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False]
#
#
# =============== (2020-09-14 02:44:39.828757)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-14 02:44:39.836757)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-14 02:44:39.837759)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-14 02:44:39.838758)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-14 02:44:41.408758)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-14 02:44:41.414758)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-14 02:48:02.178759)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-14 02:48:02.555758)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-14 02:48:02.556758)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-14 02:48:02.908760)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-14 02:48:02.915759)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-14 02:53:10.003279)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-14 02:53:10.981277)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-14 02:53:10.989277)
# ===== Products List  =====
# ===== ECONOMY VODKA ======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-14 02:53:12.178276)
# ======== AUTO-TS =========
# ===== ECONOMY VODKA ======
# ==== THE BARREL HOUSE ====
# =========== 1 ============
# ==========================
#
#
#
# ========================== (2020-09-14 02:53:12.179277)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80 BLUE PET 375M', '1': 'TAAKA VODKA 80 BLUE PET 200M', '2': 'TAAKA VODKA 80  1L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 1.694915254237288
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 200M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 1.694915254237288
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 6.779661016949152
# Log Transforming
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TAAKA VODKA 80 BLUE PET 200M
# 	Product: TAAKA VODKA 80  1L
#
#
# ========================== (2020-09-14 02:53:46.046277)
# ====== WHITE NOISE =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#        lb_stat     lb_pvalue
# 12  141.970557  2.395431e-24
# 24  144.452747  3.527878e-19
# 48  320.340879  6.288716e-42
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  21.978242   0.037764
# 24  27.494357   0.281943
# 48  52.638641   0.299248
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12   44.122049  1.455748e-05
# 24   45.996717  4.431043e-03
# 48  112.281342  4.570812e-07
#
# Is Data White Noise: False
#
#
# ========================== (2020-09-14 02:53:46.064282)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (58, 4) (1, 4)
# (58, 4) (1, 4)
# (58, 4) (1, 4)
#
#
# ========================== (2020-09-14 02:53:46.069279)
# ========= NAIVE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      last   0.068911         []
# 1  1      mean   0.165948         []
# 2  2      mean   0.099268         []
#
#                                            All RMSEs  \
# 0  [[0.06891113023575937, 0.09474241449242278, 0....
# 1  [[0.2390439979625162, 0.25545500613475297, 0.1...
# 2  [[0.12248442676716172, 0.18448330474563132, 0....
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ========================== (2020-09-14 02:53:46.394280)
# ====== Multivar P0 =======
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed: 19.4min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================== (2020-09-14 03:13:14.941809)
# ==== Multivar P0+Sim =====
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed: 16.9min finished
# ========================== (2020-09-14 03:30:06.410851)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-14 03:30:06.518851)
# ======= OPTIMIZER ========
# ===== ECONOMY VODKA ======
# ==== THE BARREL HOUSE ====
# =========== 1 ============
# ==========================
#
#
#
# =========================== (2020-09-14 03:30:06.519849)
# ==== Running Optimizer ====
# ====== ECONOMY VODKA ======
# ==== THE BARREL HOUSE =====
# ============ 1 ============
# ===========================
#
#
#
# ========================== (2020-09-14 03:30:06.530848)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80 BLUE PET 375M', '1': 'TAAKA VODKA 80 BLUE PET 200M', '2': 'TAAKA VODKA 80  1L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 1.694915254237288
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 200M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 1.694915254237288
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 6.779661016949152
# Log Transforming
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TAAKA VODKA 80 BLUE PET 200M
# 	Product: TAAKA VODKA 80  1L
#
#
# ========================== (2020-09-14 03:30:44.331854)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (58, 4) (1, 4)
# (58, 4) (1, 4)
# (58, 4) (1, 4)
#
#
# ========================== (2020-09-14 03:30:44.340851)
# ===== NAIVE FORECAST =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-14 03:30:44.360852)
# ========== MASK ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
# Mask: [False, False, False]
#
#
# ========================== (2020-09-14 03:30:44.363853)
# ========= SPACE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-14 03:30:44.376853)
# ======= Test Index =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-14 03:30:44.378852)
# ==== GET FUNCTION P0 =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ====================================== (2020-09-14 03:30:44.380851)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ========== THE BARREL HOUSE ==========
# ======================================
#
#
#
# ========================== (2020-09-14 03:30:44.548851)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-14 03:30:44.555853)
# ===== OPTIMIZING P0 ======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-14 03:35:04.844850)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ============================= (2020-09-14 03:35:04.955852)
# ==== GET FUNCTION P0+Sim ====
# ===== THE BARREL HOUSE ======
# =============================
#
#
#
# ========================================== (2020-09-14 03:35:04.956851)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ============ THE BARREL HOUSE ============
# ==========================================
#
#
#
# ========================== (2020-09-14 03:35:05.146849)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# =========================== (2020-09-14 03:35:05.153850)
# ==== OPTIMIZING P0+Sim ====
# ==== THE BARREL HOUSE =====
# ===========================
#
#
#
# ========================== (2020-09-14 03:37:17.836850)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-14 03:37:17.910851)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-14 03:37:17.920851)
# ======== AUTO-TS =========
# ===== ECONOMY VODKA ======
# ==== THE BARREL HOUSE ====
# =========== 2 ============
# ==========================
#
#
#
# ========================== (2020-09-14 03:37:17.920851)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80 BLUE PET 375M', '1': 'TAAKA VODKA 80 BLUE PET 200M', '2': 'TAAKA VODKA 80  1L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 1.7241379310344827
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 200M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 1.7241379310344827
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 6.896551724137931
# Log Transforming
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TAAKA VODKA 80 BLUE PET 200M
# 	Product: TAAKA VODKA 80  1L
#
#
# ========================== (2020-09-14 03:37:50.834851)
# ====== WHITE NOISE =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#        lb_stat     lb_pvalue
# 12  137.410866  1.993797e-23
# 24  139.910786  2.418875e-18
# 48  322.778598  2.210050e-42
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  21.669742   0.041392
# 24  27.152575   0.297392
# 48  52.791525   0.294182
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12   42.786664  2.453685e-05
# 24   44.707020  6.307408e-03
# 48  111.872160  5.168754e-07
#
# Is Data White Noise: False
#
#
# ========================== (2020-09-14 03:37:50.856851)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (57, 4) (1, 4)
# (57, 4) (1, 4)
# (57, 4) (1, 4)
#
#
# ========================== (2020-09-14 03:37:50.862850)
# ========= NAIVE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      last   0.055124         []
# 1  1      mean   0.206669         []
# 2  2      mean   0.094367         []
#
#                                            All RMSEs  \
# 0  [[0.055123576776570093, 0.0992941627475532, 0....
# 1  [[0.2776588463567642, 0.2832827480917138, 0.20...
# 2  [[0.1282258925607897, 0.17212401268673627, 0.0...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ========================== (2020-09-14 03:37:51.227851)
# ====== Multivar P0 =======
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed: 24.7min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================== (2020-09-14 04:02:30.911442)
# ==== Multivar P0+Sim =====
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed: 17.6min finished
# ========================== (2020-09-14 04:20:07.121190)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-14 04:20:07.230190)
# ======= OPTIMIZER ========
# ===== ECONOMY VODKA ======
# ==== THE BARREL HOUSE ====
# =========== 2 ============
# ==========================
#
#
#
# =========================== (2020-09-14 04:20:07.230190)
# ==== Running Optimizer ====
# ====== ECONOMY VODKA ======
# ==== THE BARREL HOUSE =====
# ============ 2 ============
# ===========================
#
#
#
# ========================== (2020-09-14 04:20:07.242190)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80 BLUE PET 375M', '1': 'TAAKA VODKA 80 BLUE PET 200M', '2': 'TAAKA VODKA 80  1L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 1.7241379310344827
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 200M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 1.7241379310344827
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 6.896551724137931
# Log Transforming
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TAAKA VODKA 80 BLUE PET 200M
# 	Product: TAAKA VODKA 80  1L
#
#
# ========================== (2020-09-14 04:20:51.272826)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (57, 4) (1, 4)
# (57, 4) (1, 4)
# (57, 4) (1, 4)
#
#
# ========================== (2020-09-14 04:20:51.280826)
# ===== NAIVE FORECAST =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-14 04:20:51.299828)
# ========== MASK ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
# Mask: [False, False, False]
#
#
# ========================== (2020-09-14 04:20:51.303826)
# ========= SPACE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-14 04:20:51.313828)
# ======= Test Index =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-14 04:20:51.315828)
# ==== GET FUNCTION P0 =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ====================================== (2020-09-14 04:20:51.316827)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ========== THE BARREL HOUSE ==========
# ======================================
#
#
#
# ========================== (2020-09-14 04:20:51.460830)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-14 04:20:51.467829)
# ===== OPTIMIZING P0 ======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-14 04:24:00.951927)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ============================= (2020-09-14 04:24:01.104927)
# ==== GET FUNCTION P0+Sim ====
# ===== THE BARREL HOUSE ======
# =============================
#
#
#
# ========================================== (2020-09-14 04:24:01.105928)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ============ THE BARREL HOUSE ============
# ==========================================
#
#
#
# ========================== (2020-09-14 04:24:01.247926)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# =========================== (2020-09-14 04:24:01.255927)
# ==== OPTIMIZING P0+Sim ====
# ==== THE BARREL HOUSE =====
# ===========================
#
#
#
# ========================== (2020-09-14 04:27:25.266892)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-14 04:27:25.381893)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-14 04:27:25.391894)
# ======== AUTO-TS =========
# ===== ECONOMY VODKA ======
# ==== THE BARREL HOUSE ====
# =========== 3 ============
# ==========================
#
#
#
# ========================== (2020-09-14 04:27:25.392894)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80 BLUE PET 375M', '1': 'TAAKA VODKA 80 BLUE PET 200M', '2': 'TAAKA VODKA 80  1L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 1.7543859649122806
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 200M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 1.7543859649122806
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 7.017543859649122
# Log Transforming
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TAAKA VODKA 80 BLUE PET 200M
# 	Product: TAAKA VODKA 80  1L
#
#
# ========================== (2020-09-14 04:28:05.649893)
# ====== WHITE NOISE =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#        lb_stat     lb_pvalue
# 12  132.810279  1.682218e-22
# 24  135.478653  1.566072e-17
# 48  325.313018  7.441001e-43
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  21.595536   0.042311
# 24  27.028344   0.303134
# 48  54.622321   0.237474
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12   41.613403  3.867933e-05
# 24   43.560865  8.577393e-03
# 48  112.343700  4.485858e-07
#
# Is Data White Noise: False
#
#
# ========================== (2020-09-14 04:28:05.668900)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (56, 4) (1, 4)
# (56, 4) (1, 4)
# (56, 4) (1, 4)
#
#
# ========================== (2020-09-14 04:28:05.674894)
# ========= NAIVE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      last   0.065992         []
# 1  1      mean   0.199992         []
# 2  2      mean   0.093113         []
#
#                                            All RMSEs  \
# 0  [[0.06599226033424141, 0.10595455079040401, 0....
# 1  [[0.24204599505427557, 0.28850466087251886, 0....
# 2  [[0.1186954439315259, 0.17141527417502248, 0.0...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ========================== (2020-09-14 04:28:06.166897)
# ====== Multivar P0 =======
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed: 19.4min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================== (2020-09-14 04:47:28.598927)
# ==== Multivar P0+Sim =====
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  8.7min finished
# ========================== (2020-09-14 04:56:11.006801)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-14 04:56:11.055801)
# ======= OPTIMIZER ========
# ===== ECONOMY VODKA ======
# ==== THE BARREL HOUSE ====
# =========== 3 ============
# ==========================
#
#
#
# =========================== (2020-09-14 04:56:11.056799)
# ==== Running Optimizer ====
# ====== ECONOMY VODKA ======
# ==== THE BARREL HOUSE =====
# ============ 3 ============
# ===========================
#
#
#
# ========================== (2020-09-14 04:56:11.065798)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80 BLUE PET 375M', '1': 'TAAKA VODKA 80 BLUE PET 200M', '2': 'TAAKA VODKA 80  1L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 1.7543859649122806
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 200M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 1.7543859649122806
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 7.017543859649122
# Log Transforming
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TAAKA VODKA 80 BLUE PET 200M
# 	Product: TAAKA VODKA 80  1L
#
#
# ========================== (2020-09-14 04:56:47.459887)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (56, 4) (1, 4)
# (56, 4) (1, 4)
# (56, 4) (1, 4)
#
#
# ========================== (2020-09-14 04:56:47.466889)
# ===== NAIVE FORECAST =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-14 04:56:47.488889)
# ========== MASK ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
# Mask: [False, False, False]
#
#
# ========================== (2020-09-14 04:56:47.491888)
# ========= SPACE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-14 04:56:47.503890)
# ======= Test Index =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-14 04:56:47.504889)
# ==== GET FUNCTION P0 =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ====================================== (2020-09-14 04:56:47.506890)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ========== THE BARREL HOUSE ==========
# ======================================
#
#
#
# ========================== (2020-09-14 04:56:47.648888)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-14 04:56:47.656889)
# ===== OPTIMIZING P0 ======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-14 04:59:17.929996)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ============================= (2020-09-14 04:59:18.047993)
# ==== GET FUNCTION P0+Sim ====
# ===== THE BARREL HOUSE ======
# =============================
#
#
#
# ========================================== (2020-09-14 04:59:18.048993)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ============ THE BARREL HOUSE ============
# ==========================================
#
#
#
# ========================== (2020-09-14 04:59:18.165992)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# =========================== (2020-09-14 04:59:18.173994)
# ==== OPTIMIZING P0+Sim ====
# ==== THE BARREL HOUSE =====
# ===========================
#
#
#
# ========================== (2020-09-14 05:00:53.727582)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-14 05:00:53.860578)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ============================ (2020-09-14 05:00:53.871583)
# ====== Products List  ======
# ====== ECONOMY VODKA =======
# ==== WESTERN BEV LIQ TX ====
# ============================
#
#
#
# ============================ (2020-09-14 05:00:56.949102)
# ========= AUTO-TS ==========
# ====== ECONOMY VODKA =======
# ==== WESTERN BEV LIQ TX ====
# ============ 1 =============
# ============================
#
#
#
# ============================ (2020-09-14 05:00:56.949102)
# ========= GET DATA =========
# ==== WESTERN BEV LIQ TX ====
# ============================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80 BLUE PET 375M', '1': 'TAAKA VODKA 80  1L', '2': 'TEXAS SPIRIT VODKA 80  1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '1']
# % of weeks without a purchase: 69.04761904761905
# Log Transforming
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TAAKA VODKA 80  1L
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
#
#
# ============================ (2020-09-14 05:01:45.262147)
# ======= WHITE NOISE ========
# ==== WESTERN BEV LIQ TX ====
# ============================
#
#        lb_stat     lb_pvalue
# 12  264.265806  1.438480e-49
# 24  280.036227  1.710125e-45
# 48  511.722045  7.821595e-79
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  209.813224  3.058200e-38
# 24  231.847315  6.347549e-36
# 48  296.397370  1.689172e-37
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  474.857092   4.940599e-94
# 24  562.831143  1.385783e-103
# 48  697.054286  5.309923e-116
#
# Is Data White Noise: False
#
#
# ============================ (2020-09-14 05:01:45.288147)
# ======== TEST/TRAIN ========
# ==== WESTERN BEV LIQ TX ====
# ============================
#
# (62, 4) (1, 4)
# (83, 4) (1, 4)
# (83, 4) (1, 4)
#
#
# ============================ (2020-09-14 05:01:45.299148)
# ========== NAIVE ===========
# ==== WESTERN BEV LIQ TX ====
# ============================
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      last   0.064357         []
# 1  1      last   0.113461         []
# 2  2      last   0.000000         []
#
#                                            All RMSEs  \
# 0  [[0.06435744561198575, 0.07354549916258801, 0....
# 1  [[0.11346106499075055, 0.17230450268545236, 0....
# 2                                  [[0.0, 0.0, 0.0]]
#
#                        All Types             Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4)
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4)
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4)
#
#
# ============================ (2020-09-14 05:01:45.884148)
# ======= Multivar P0 ========
# ==== WESTERN BEV LIQ TX ====
# ============================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed: 13.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ============================ (2020-09-14 05:15:00.152520)
# ===== Multivar P0+Sim ======
# ==== WESTERN BEV LIQ TX ====
# ============================
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  9.3min finished
# ============================ (2020-09-14 05:24:18.926691)
# ======== COMPLETED =========
# ==== WESTERN BEV LIQ TX ====
# ============================
#
#
#
# ============================ (2020-09-14 05:24:19.037691)
# ======== OPTIMIZER =========
# ====== ECONOMY VODKA =======
# ==== WESTERN BEV LIQ TX ====
# ============ 1 =============
# ============================
#
#
#
# ============================ (2020-09-14 05:24:19.037691)
# ...
# ==== GET DATA ====
# ===== SPECS ======
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 PET 1.75L', '2': 'TAAKA VODKA 80 BLUE PET 375M'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 1.2048192771084338
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 PET 1.75L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
#
#
# ==================== (2020-09-14 06:27:35.117759)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (82, 4) (1, 4)
# (82, 4) (1, 4)
# (82, 4) (1, 4)
#
#
# ======================== (2020-09-14 06:27:35.124783)
# ==== NAIVE FORECAST ====
# ======== SPECS =========
# ========================
#
#
#
# =============== (2020-09-14 06:27:35.140760)
# ==== MASK =====
# ==== SPECS ====
# ===============
#
# Mask: [False, False, False]
#
#
# =============== (2020-09-14 06:27:35.143762)
# ==== SPACE ====
# ==== SPECS ====
# ===============
#
# Min Limit is >= than Max Limit, setting them near median (+-5%)
#
#
# ==================== (2020-09-14 06:27:35.153758)
# ==== Test Index ====
# ====== SPECS =======
# ====================
#
#
#
# ========================= (2020-09-14 06:27:35.155758)
# ==== GET FUNCTION P0 ====
# ========= SPECS =========
# =========================
#
#
#
# ====================================== (2020-09-14 06:27:35.157758)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# =============== SPECS ================
# ======================================
#
#
#
# =================== (2020-09-14 06:27:35.286755)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ======================= (2020-09-14 06:27:35.292755)
# ==== OPTIMIZING P0 ====
# ======== SPECS ========
# =======================
#
#
#
# =================== (2020-09-14 06:28:20.771522)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ============================= (2020-09-14 06:28:20.880524)
# ==== GET FUNCTION P0+Sim ====
# =========== SPECS ===========
# =============================
#
#
#
# ========================================== (2020-09-14 06:28:20.881525)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ================= SPECS ==================
# ==========================================
#
#
#
# =================== (2020-09-14 06:28:21.020524)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =========================== (2020-09-14 06:28:21.028522)
# ==== OPTIMIZING P0+Sim ====
# ========== SPECS ==========
# ===========================
#
#
#
# =================== (2020-09-14 06:28:57.756518)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =================== (2020-09-14 06:28:57.812523)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ======================= (2020-09-14 06:28:57.818519)
# ======= AUTO-TS =======
# ==== ECONOMY VODKA ====
# ======== SPECS ========
# ========== 3 ==========
# =======================
#
#
#
# ================== (2020-09-14 06:28:57.818519)
# ==== GET DATA ====
# ===== SPECS ======
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 PET 1.75L', '2': 'TAAKA VODKA 80 BLUE PET 375M'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 1.2195121951219512
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 PET 1.75L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
#
#
# ===================== (2020-09-14 06:29:15.532557)
# ==== WHITE NOISE ====
# ======= SPECS =======
# =====================
#
#        lb_stat     lb_pvalue
# 12  163.850364  8.614761e-29
# 24  202.851035  2.932294e-30
# 48  302.430383  1.310197e-38
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  203.867388  5.185416e-37
# 24  249.138534  2.445714e-39
# 48  386.780036  1.745507e-54
#
# Is Data White Noise: False
#        lb_stat  lb_pvalue
# 12   41.146569   0.000046
# 24   60.607680   0.000052
# 48  103.105730   0.000007
#
# Is Data White Noise: False
#
#
# ==================== (2020-09-14 06:29:15.542530)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (81, 4) (1, 4)
# (81, 4) (1, 4)
# (81, 4) (1, 4)
#
#
# =============== (2020-09-14 06:29:15.545527)
# ==== NAIVE ====
# ==== SPECS ====
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.107768         []
# 1  1      mean   0.136330         []
# 2  2      mean   0.121653         []
#
#                                            All RMSEs  \
# 0  [[0.13456120941276825, 0.187951813296838, 0.10...
# 1  [[0.21541297336857784, 0.22034399791646134, 0....
# 2  [[0.17742034252670738, 0.1589870135780978, 0.1...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-14 06:29:15.725519)
# ==== Multivar P0 ====
# ======= SPECS =======
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-14 06:31:31.751990)
# ==== Multivar P0+Sim ====
# ========= SPECS =========
# =========================
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  2.3min finished
# =================== (2020-09-14 06:33:52.583992)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ======================= (2020-09-14 06:33:52.587994)
# ====== OPTIMIZER ======
# ==== ECONOMY VODKA ====
# ======== SPECS ========
# ========== 3 ==========
# =======================
#
#
#
# =========================== (2020-09-14 06:33:52.587994)
# ==== Running Optimizer ====
# ====== ECONOMY VODKA ======
# ========== SPECS ==========
# ============ 3 ============
# ===========================
#
#
#
# ================== (2020-09-14 06:33:52.589994)
# ==== GET DATA ====
# ===== SPECS ======
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 PET 1.75L', '2': 'TAAKA VODKA 80 BLUE PET 375M'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 1.2195121951219512
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 PET 1.75L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
#
#
# ==================== (2020-09-14 06:34:10.120002)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (81, 4) (1, 4)
# (81, 4) (1, 4)
# (81, 4) (1, 4)
#
#
# ======================== (2020-09-14 06:34:10.123993)
# ==== NAIVE FORECAST ====
# ======== SPECS =========
# ========================
#
#
#
# =============== (2020-09-14 06:34:10.136989)
# ==== MASK =====
# ==== SPECS ====
# ===============
#
# Mask: [False, False, False]
#
#
# =============== (2020-09-14 06:34:10.137989)
# ==== SPACE ====
# ==== SPECS ====
# ===============
#
# Min Limit is >= than Max Limit, setting them near median (+-5%)
#
#
# ==================== (2020-09-14 06:34:10.143996)
# ==== Test Index ====
# ====== SPECS =======
# ====================
#
#
#
# ========================= (2020-09-14 06:34:10.143996)
# ==== GET FUNCTION P0 ====
# ========= SPECS =========
# =========================
#
#
#
# ====================================== (2020-09-14 06:34:10.145005)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# =============== SPECS ================
# ======================================
#
# Building Forecast dataframe. Forecast Period = 1
#
#
# =================== (2020-09-14 06:34:11.387962)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ======================= (2020-09-14 06:34:11.390963)
# ==== OPTIMIZING P0 ====
# ======== SPECS ========
# =======================
#
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
#
#
# =================== (2020-09-14 06:36:43.438049)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
# Building Forecast dataframe. Forecast Period = 1
#
#
# ============================= (2020-09-14 06:36:44.662019)
# ==== GET FUNCTION P0+Sim ====
# =========== SPECS ===========
# =============================
#
#
#
# ========================================== (2020-09-14 06:36:44.662019)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ================= SPECS ==================
# ==========================================
#
#
#
# =================== (2020-09-14 06:36:44.732021)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =========================== (2020-09-14 06:36:44.737021)
# ==== OPTIMIZING P0+Sim ====
# ========== SPECS ==========
# ===========================
#
#
#
# =================== (2020-09-14 06:37:17.229048)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =================== (2020-09-14 06:37:17.287020)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ========================== (2020-09-14 06:37:17.300019)
# ==== Saving to PICKLE ====
# ===== ECONOMY VODKA ======
# ==========================
#
# Pickle File  full_models_ECONOMY VODKA_Prod3_Sim1_Per123.pkl  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns
# Pickle File  full_opt_ECONOMY VODKA_Prod3_Sim1_Per123.pkl  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns
#
#
# ========================= (2020-09-14 06:37:17.396021)
# ==== Saving to EXCEL ====
# ===== ECONOMY VODKA =====
# =========================
#
# EXCEL File  Output_ECONOMY VODKA_Prod3_Sim1_Per123.xlsx  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns

# %% [markdown]
# # Print out

# %% [markdown]
# ## Models

# %%
full_models[outputColsModels]
# Out:
#           Chain Master                       Product  Period to Last  \
# 0                                 TAAKA VODKA 80  1L               1
# 3                                 TAAKA VODKA 80  1L               2
# 6                                 TAAKA VODKA 80  1L               3
# 1                       TAAKA VODKA 80 BLUE PET 375M               1
# 4                       TAAKA VODKA 80 BLUE PET 375M               2
# 7                       TAAKA VODKA 80 BLUE PET 375M               3
# 2                       TEXAS SPIRIT VODKA 80  1.75L               1
# 5                       TEXAS SPIRIT VODKA 80  1.75L               2
# 8                       TEXAS SPIRIT VODKA 80  1.75L               3
# 27               SPECS            TAAKA VODKA 80  1L               1
# 30               SPECS            TAAKA VODKA 80  1L               2
# 33               SPECS            TAAKA VODKA 80  1L               3
# 29               SPECS  TAAKA VODKA 80 BLUE PET 375M               1
# 32               SPECS  TAAKA VODKA 80 BLUE PET 375M               2
# 35               SPECS  TAAKA VODKA 80 BLUE PET 375M               3
# 28               SPECS      TAAKA VODKA 80 PET 1.75L               1
# 31               SPECS      TAAKA VODKA 80 PET 1.75L               2
# 34               SPECS      TAAKA VODKA 80 PET 1.75L               3
# 11    THE BARREL HOUSE            TAAKA VODKA 80  1L               1
# 14    THE BARREL HOUSE            TAAKA VODKA 80  1L               2
# 17    THE BARREL HOUSE            TAAKA VODKA 80  1L               3
# 10    THE BARREL HOUSE  TAAKA VODKA 80 BLUE PET 200M               1
# 13    THE BARREL HOUSE  TAAKA VODKA 80 BLUE PET 200M               2
# 16    THE BARREL HOUSE  TAAKA VODKA 80 BLUE PET 200M               3
# 9     THE BARREL HOUSE  TAAKA VODKA 80 BLUE PET 375M               1
# 12    THE BARREL HOUSE  TAAKA VODKA 80 BLUE PET 375M               2
# 15    THE BARREL HOUSE  TAAKA VODKA 80 BLUE PET 375M               3
# 19  WESTERN BEV LIQ TX            TAAKA VODKA 80  1L               1
# 22  WESTERN BEV LIQ TX            TAAKA VODKA 80  1L               2
# 25  WESTERN BEV LIQ TX            TAAKA VODKA 80  1L               3
# 18  WESTERN BEV LIQ TX  TAAKA VODKA 80 BLUE PET 375M               1
# 21  WESTERN BEV LIQ TX  TAAKA VODKA 80 BLUE PET 375M               2
# 24  WESTERN BEV LIQ TX  TAAKA VODKA 80 BLUE PET 375M               3
# 20  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80  1.75L               1
# 23  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80  1.75L               2
# 26  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80  1.75L               3
#
#     White Noise Naive Best Type  Naive Best RMSE P0 Best Model Name  \
# 0         False            mean         0.083730                 ML
# 3         False            mean         0.077936                 ML
# 6         False            mean         0.078022                 ML
# 1         False            last         0.050920                 ML
# 4         False            last         0.049104            SARIMAX
# 7         False            last         0.044826       auto_SARIMAX
# 2         False            last         0.000000            SARIMAX
# 5         False            last         0.000000            SARIMAX
# 8         False            last         0.000000            SARIMAX
# 27        False            last         0.109601                 ML
# 30        False            last         0.116424                 ML
# 33        False            mean         0.107768                 ML
# 29        False            mean         0.113808            SARIMAX
# 32        False            mean         0.104293            SARIMAX
# 35        False            mean         0.121653       auto_SARIMAX
# 28        False            mean         0.113211            SARIMAX
# 31        False            mean         0.120084                 ML
# 34        False            mean         0.136330            Prophet
# 11        False            mean         0.099268                 ML
# 14        False            mean         0.094367                 ML
# 17        False            mean         0.093113                 ML
# 10         True            mean         0.165948                 ML
# 13         True            mean         0.206669                 ML
# 16         True            mean         0.199992                 ML
# 9         False            last         0.068911       auto_SARIMAX
# 12        False            last         0.055124       auto_SARIMAX
# 15        False            last         0.065992       auto_SARIMAX
# 19        False            last         0.113461            Prophet
# 22        False            last         0.107550            Prophet
# 25        False            last         0.126205                 ML
# 18        False            last         0.064357                 ML
# 21        False            last         0.062996                 ML
# 24        False            last         0.055440                 ML
# 20        False            last         0.000000            SARIMAX
# 23        False            last         0.000000            SARIMAX
# 26        False            last         0.000000            SARIMAX
#
#     P0 Best Model RMSE P0+Sim Best Model Name  P0+Sim Best Model RMSE
# 0             0.074880           auto_SARIMAX                0.071642
# 3             0.069895                     ML                0.069895
# 6             0.064195                     ML                0.067228
# 1             0.055895                     ML                0.053028
# 4             0.057594                     ML                0.059788
# 7             0.058057           auto_SARIMAX                0.064649
# 2             0.001320                SARIMAX                0.015293
# 5             0.001044                SARIMAX                0.014780
# 8             0.001135                SARIMAX                0.011036
# 27            0.114726                     ML                0.114726
# 30            0.097598                     ML                0.097598
# 33            0.082030                     ML                0.082030
# 29            0.110920                SARIMAX                0.121613
# 32            0.122456                SARIMAX                0.131562
# 35            0.121268           auto_SARIMAX                0.129285
# 28            0.112525           auto_SARIMAX                0.119632
# 31            0.128680                     ML                0.128494
# 34            0.106713                     ML                0.128970
# 11            0.141781                SARIMAX                0.127688
# 14            0.141624                     ML                0.140611
# 17            0.130413                     ML                0.127396
# 10            0.188430                     ML                0.188429
# 13            0.204441                     ML                0.204441
# 16            0.205818                     ML                0.205817
# 9             0.070390                SARIMAX                0.083409
# 12            0.066565                SARIMAX                0.084708
# 15            0.056497                SARIMAX                0.086670
# 19            0.089950                Prophet                0.091650
# 22            0.105715                Prophet                0.110545
# 25            0.098518                     ML                0.098543
# 18            0.061341                     ML                0.061554
# 21            0.063986                     ML                0.066194
# 24            0.082589           auto_SARIMAX                0.065067
# 20            0.001320                SARIMAX                0.007564
# 23            0.001044                SARIMAX                0.007573
# 26            0.001135                SARIMAX                0.006444

# %% [markdown]
# ## Optimizer

# %% [markdown]
# ### Summary by Chain

# %%
full_chain_summary
# Out:
#          Chain Master  P0 Non-Opt Revenue  P0 Opt Revenue  P0 Opt Diff  \
# 0                                 26946.0         26920.0        -26.0
# 1               SPECS             15386.0         17171.0       1785.0
# 2    THE BARREL HOUSE              5692.0          5716.0         24.0
# 3  WESTERN BEV LIQ TX              8724.0         16406.0       7682.0
#
#    P0 Opt Diff Ratio  P0+Sim Non-Opt Revenue  P0+Sim Opt Revenue  \
# 0           0.999035                 23807.0             33847.0
# 1           1.116015                 13882.0             17675.0
# 2           1.004216                  6288.0              6380.0
# 3           1.880559                 10925.0             21518.0
#
#    P0+Sim Opt Diff  P0+Sim Opt Diff Ratio
# 0          10040.0               1.421725
# 1           3793.0               1.273232
# 2             92.0               1.014631
# 3          10593.0               1.969611

# %%
print("WRITE this value in the summary table in Git hub --->",round(full_chain_summary[full_chain_summary['Chain Master']=='']['P0+Sim Opt Diff Ratio'].item(),4))
# Out:
# WRITE this value in the summary table in Git hub ---> 1.4217

# %% [markdown]
# Link to the Git Hub Summary Table: https://github.com/ngupta23/msds_capstone/issues/84

# %% [markdown]
# ### Summary by Chain and Product

# %%
full_summary
# Out:
#           Chain Master                       Product  P0 Non-Opt Revenue  \
# 0                                 TAAKA VODKA 80  1L             16812.0
# 1                       TAAKA VODKA 80 BLUE PET 375M             10119.0
# 2                       TEXAS SPIRIT VODKA 80  1.75L                15.0
# 3                SPECS            TAAKA VODKA 80  1L             12144.0
# 4                SPECS  TAAKA VODKA 80 BLUE PET 375M              1057.0
# 5                SPECS      TAAKA VODKA 80 PET 1.75L              2185.0
# 6     THE BARREL HOUSE            TAAKA VODKA 80  1L              1573.0
# 7     THE BARREL HOUSE  TAAKA VODKA 80 BLUE PET 200M              1034.0
# 8     THE BARREL HOUSE  TAAKA VODKA 80 BLUE PET 375M              3085.0
# 9   WESTERN BEV LIQ TX            TAAKA VODKA 80  1L              7507.0
# 10  WESTERN BEV LIQ TX  TAAKA VODKA 80 BLUE PET 375M              1202.0
# 11  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80  1.75L                15.0
#
#     P0 Opt Revenue  P0 Opt Diff  P0 Opt Diff Ratio  P0+Sim Non-Opt Revenue  \
# 0          16772.0        -40.0           0.997621                 19208.0
# 1          10119.0          0.0           1.000000                  4583.0
# 2             29.0         14.0           1.933333                    16.0
# 3          12144.0          0.0           1.000000                 12144.0
# 4           1150.0         93.0           1.087985                  1088.0
# 5           3877.0       1692.0           1.774371                   650.0
# 6           1595.0         22.0           1.013986                  1729.0
# 7           1036.0          2.0           1.001934                  1034.0
# 8           3085.0          0.0           1.000000                  3525.0
# 9          15175.0       7668.0           2.021447                  7462.0
# 10          1202.0          0.0           1.000000                  3448.0
# 11            29.0         14.0           1.933333                    15.0
#
#     P0+Sim Opt Revenue  P0+Sim Opt Diff  P0+Sim Opt Diff Ratio
# 0              26338.0           7130.0               1.371200
# 1               7147.0           2564.0               1.559459
# 2                362.0            346.0              22.625000
# 3              12098.0            -46.0               0.996212
# 4               4918.0           3830.0               4.520221
# 5                659.0              9.0               1.013846
# 6               1769.0             40.0               1.023135
# 7               1035.0              1.0               1.000967
# 8               3576.0             51.0               1.014468
# 9              15306.0           7844.0               2.051193
# 10              5513.0           2065.0               1.598898
# 11               699.0            684.0              46.600000

# %% [markdown]
# ### P0 Optimizer

# %%
full_opt[outputColsOptP0]
# Out:
#           Chain Master                       Product  Period to Last  \
# 0                                 TAAKA VODKA 80  1L               1
# 3                                 TAAKA VODKA 80  1L               2
# 6                                 TAAKA VODKA 80  1L               3
# 1                       TAAKA VODKA 80 BLUE PET 375M               1
# 4                       TAAKA VODKA 80 BLUE PET 375M               2
# 7                       TAAKA VODKA 80 BLUE PET 375M               3
# 2                       TEXAS SPIRIT VODKA 80  1.75L               1
# 5                       TEXAS SPIRIT VODKA 80  1.75L               2
# 8                       TEXAS SPIRIT VODKA 80  1.75L               3
# 27               SPECS            TAAKA VODKA 80  1L               1
# 30               SPECS            TAAKA VODKA 80  1L               2
# 33               SPECS            TAAKA VODKA 80  1L               3
# 29               SPECS  TAAKA VODKA 80 BLUE PET 375M               1
# 32               SPECS  TAAKA VODKA 80 BLUE PET 375M               2
# 35               SPECS  TAAKA VODKA 80 BLUE PET 375M               3
# 28               SPECS      TAAKA VODKA 80 PET 1.75L               1
# 31               SPECS      TAAKA VODKA 80 PET 1.75L               2
# 34               SPECS      TAAKA VODKA 80 PET 1.75L               3
# 11    THE BARREL HOUSE            TAAKA VODKA 80  1L               1
# 14    THE BARREL HOUSE            TAAKA VODKA 80  1L               2
# 17    THE BARREL HOUSE            TAAKA VODKA 80  1L               3
# 10    THE BARREL HOUSE  TAAKA VODKA 80 BLUE PET 200M               1
# 13    THE BARREL HOUSE  TAAKA VODKA 80 BLUE PET 200M               2
# 16    THE BARREL HOUSE  TAAKA VODKA 80 BLUE PET 200M               3
# 9     THE BARREL HOUSE  TAAKA VODKA 80 BLUE PET 375M               1
# 12    THE BARREL HOUSE  TAAKA VODKA 80 BLUE PET 375M               2
# 15    THE BARREL HOUSE  TAAKA VODKA 80 BLUE PET 375M               3
# 19  WESTERN BEV LIQ TX            TAAKA VODKA 80  1L               1
# 22  WESTERN BEV LIQ TX            TAAKA VODKA 80  1L               2
# 25  WESTERN BEV LIQ TX            TAAKA VODKA 80  1L               3
# 18  WESTERN BEV LIQ TX  TAAKA VODKA 80 BLUE PET 375M               1
# 21  WESTERN BEV LIQ TX  TAAKA VODKA 80 BLUE PET 375M               2
# 24  WESTERN BEV LIQ TX  TAAKA VODKA 80 BLUE PET 375M               3
# 20  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80  1.75L               1
# 23  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80  1.75L               2
# 26  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80  1.75L               3
#
#     P0 Non-Opt Price  P0 Non-Opt Demand  P0 Non-Opt Revenue  \
# 0              44.42                115                5103
# 3              44.30                107                4750
# 6              44.47                156                6959
# 1              58.56                  3                 189
# 4              58.56                 92                5394
# 7              58.56                 77                4536
# 2              51.18                  0                   5
# 5              51.18                  0                   5
# 8              51.18                  0                   5
# 27             44.30                 98                4348
# 30             44.30                 85                3780
# 33             44.30                 91                4016
# 29             58.56                  6                 370
# 32             58.56                  6                 335
# 35             58.56                  6                 352
# 28             47.03                 13                 594
# 31             47.03                  3                 119
# 34             47.03                 31                1472
# 11             46.89                 11                 519
# 14             44.30                 11                 508
# 17             47.63                 11                 546
# 10             62.80                  6                 378
# 13             62.80                  4                 278
# 16             62.80                  6                 378
# 9              58.56                 18                1055
# 12             58.56                 18                1058
# 15             58.56                 17                 972
# 19             44.30                 74                3275
# 22             44.30                 54                2378
# 25             44.30                 42                1854
# 18             58.56                  6                 368
# 21             58.56                  7                 423
# 24             58.56                  7                 411
# 20             51.18                  0                   5
# 23             51.18                  0                   5
# 26             51.18                  0                   5
#
#     P0 Non-Opt Chain Master Revenue  P0 Optimal Price  P0 Demand  P0 Revenue  \
# 0                              5297             44.30        115        5089
# 3                             10149             44.30        107        4750
# 6                             11500             44.30        156        6933
# 1                              5297             58.56          3         189
# 4                             10149             58.56         92        5394
# 7                             11500             58.56         77        4536
# 2                              5297             46.03          0          10
# 5                             10149             46.03          0           9
# 8                             11500             46.03          0          10
# 27                             5312             44.30         98        4348
# 30                             4234             44.30         85        3780
# 33                             5841             44.30         91        4016
# 29                             5312             61.49          7         409
# 32                             4234             61.49          6         371
# 35                             5841             61.49          6         370
# 28                             5312             47.03         13         594
# 31                             4234             47.03          3         119
# 34                             5841             46.98         67        3164
# 11                             1952             47.04         11         521
# 14                             1843             46.77         11         536
# 17                             1896             46.89         11         538
# 10                             1952             62.93          6         379
# 13                             1843             62.93          4         278
# 16                             1896             62.93          6         379
# 9                              1952             58.56         18        1055
# 12                             1843             58.56         18        1058
# 15                             1896             58.56         17         972
# 19                             3648             43.80        176        7691
# 22                             2806             43.80        129        5630
# 25                             2270             44.30         42        1854
# 18                             3648             58.56          6         368
# 21                             2806             58.56          7         423
# 24                             2270             58.56          7         411
# 20                             3648             46.03          0          10
# 23                             2806             46.03          0           9
# 26                             2270             46.03          0          10
#
#     P0 Chain Master Revenue
# 0                      5288
# 3                     10153
# 6                     11478
# 1                      5288
# 4                     10153
# 7                     11478
# 2                      5288
# 5                     10153
# 8                     11478
# 27                     5351
# 30                     4269
# 33                     7550
# 29                     5351
# 32                     4269
# 35                     7550
# 28                     5351
# 31                     4269
# 34                     7550
# 11                     1955
# 14                     1872
# 17                     1888
# 10                     1955
# 13                     1872
# 16                     1888
# 9                      1955
# 12                     1872
# 15                     1888
# 19                     8068
# 22                     6063
# 25                     2274
# 18                     8068
# 21                     6063
# 24                     2274
# 20                     8068
# 23                     6063
# 26                     2274

# %% [markdown]
# ### P0+Sim Optimizer

# %%
full_opt[outputColsOptP0Sim]
# Out:
#           Chain Master                       Product  Period to Last  \
# 0                                 TAAKA VODKA 80  1L               1
# 3                                 TAAKA VODKA 80  1L               2
# 6                                 TAAKA VODKA 80  1L               3
# 1                       TAAKA VODKA 80 BLUE PET 375M               1
# 4                       TAAKA VODKA 80 BLUE PET 375M               2
# 7                       TAAKA VODKA 80 BLUE PET 375M               3
# 2                       TEXAS SPIRIT VODKA 80  1.75L               1
# 5                       TEXAS SPIRIT VODKA 80  1.75L               2
# 8                       TEXAS SPIRIT VODKA 80  1.75L               3
# 27               SPECS            TAAKA VODKA 80  1L               1
# 30               SPECS            TAAKA VODKA 80  1L               2
# 33               SPECS            TAAKA VODKA 80  1L               3
# 29               SPECS  TAAKA VODKA 80 BLUE PET 375M               1
# 32               SPECS  TAAKA VODKA 80 BLUE PET 375M               2
# 35               SPECS  TAAKA VODKA 80 BLUE PET 375M               3
# 28               SPECS      TAAKA VODKA 80 PET 1.75L               1
# 31               SPECS      TAAKA VODKA 80 PET 1.75L               2
# 34               SPECS      TAAKA VODKA 80 PET 1.75L               3
# 11    THE BARREL HOUSE            TAAKA VODKA 80  1L               1
# 14    THE BARREL HOUSE            TAAKA VODKA 80  1L               2
# 17    THE BARREL HOUSE            TAAKA VODKA 80  1L               3
# 10    THE BARREL HOUSE  TAAKA VODKA 80 BLUE PET 200M               1
# 13    THE BARREL HOUSE  TAAKA VODKA 80 BLUE PET 200M               2
# 16    THE BARREL HOUSE  TAAKA VODKA 80 BLUE PET 200M               3
# 9     THE BARREL HOUSE  TAAKA VODKA 80 BLUE PET 375M               1
# 12    THE BARREL HOUSE  TAAKA VODKA 80 BLUE PET 375M               2
# 15    THE BARREL HOUSE  TAAKA VODKA 80 BLUE PET 375M               3
# 19  WESTERN BEV LIQ TX            TAAKA VODKA 80  1L               1
# 22  WESTERN BEV LIQ TX            TAAKA VODKA 80  1L               2
# 25  WESTERN BEV LIQ TX            TAAKA VODKA 80  1L               3
# 18  WESTERN BEV LIQ TX  TAAKA VODKA 80 BLUE PET 375M               1
# 21  WESTERN BEV LIQ TX  TAAKA VODKA 80 BLUE PET 375M               2
# 24  WESTERN BEV LIQ TX  TAAKA VODKA 80 BLUE PET 375M               3
# 20  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80  1.75L               1
# 23  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80  1.75L               2
# 26  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80  1.75L               3
#
#     P0+Sim Non-Opt Price  P0+Sim Non-Opt Demand  P0+Sim Non-Opt Revenue  \
# 0                  44.42                    171                    7574
# 3                  44.30                    107                    4750
# 6                  44.47                    155                    6884
# 1                  58.56                      3                     196
# 4                  58.56                      3                     196
# 7                  58.56                     72                    4191
# 2                  51.18                      0                       5
# 5                  51.18                      0                       5
# 8                  51.18                      0                       6
# 27                 44.30                     98                    4348
# 30                 44.30                     85                    3780
# 33                 44.30                     91                    4016
# 29                 58.56                      6                     355
# 32                 58.56                      6                     334
# 35                 58.56                      7                     399
# 28                 47.03                      9                     418
# 31                 47.03                      2                     117
# 34                 47.03                      2                     115
# 11                 46.89                     14                     658
# 14                 44.30                     12                     514
# 17                 47.63                     12                     557
# 10                 62.80                      6                     378
# 13                 62.80                      4                     278
# 16                 62.80                      6                     378
# 9                  58.56                     23                    1373
# 12                 58.56                     18                    1065
# 15                 58.56                     19                    1087
# 19                 44.30                     72                    3209
# 22                 44.30                     54                    2399
# 25                 44.30                     42                    1854
# 18                 58.56                      7                     381
# 21                 58.56                      7                     413
# 24                 58.56                     45                    2654
# 20                 51.18                      0                       5
# 23                 51.18                      0                       5
# 26                 51.18                      0                       5
#
#     P0+Sim Non-Opt Chain Master Revenue  P0+Sim Optimal Price  P0+Sim Demand  \
# 0                                  7775                 43.80            338
# 3                                  4951                 44.30            107
# 6                                 11080                 43.80            155
# 1                                  7775                 58.56              3
# 4                                  4951                 58.56              3
# 7                                 11080                 58.56            115
# 2                                  7775                 46.03              0
# 5                                  4951                 46.03              0
# 8                                 11080                 46.03              7
# 27                                 5121                 44.30             98
# 30                                 4231                 44.30             85
# 33                                 4530                 43.80             91
# 29                                 5121                 55.63             32
# 32                                 4231                 55.63             33
# 35                                 4530                 61.49             21
# 28                                 5121                 46.98              9
# 31                                 4231                 47.03              2
# 34                                 4530                 47.03              2
# 11                                 2409                 47.04             14
# 14                                 1857                 46.77             12
# 17                                 2022                 46.89             12
# 10                                 2409                 62.93              6
# 13                                 1857                 62.93              4
# 16                                 2022                 62.80              6
# 9                                  2409                 58.56             24
# 12                                 1857                 58.56             19
# 15                                 2022                 58.56             19
# 19                                 3595                 43.80            177
# 22                                 2817                 43.80            130
# 25                                 4512                 43.80             42
# 18                                 3595                 58.56              7
# 21                                 2817                 58.56              7
# 24                                 4512                 58.56             81
# 20                                 3595                 46.03              7
# 23                                 2817                 46.03              0
# 26                                 4512                 46.03              7
#
#     P0+Sim Revenue  P0+Sim Chain Master Revenue
# 0            14808                        15015
# 3             4750                         4958
# 6             6780                        13875
# 1              196                        15015
# 4              196                         4958
# 7             6755                        13875
# 2               10                        15015
# 5               12                         4958
# 8              340                        13875
# 27            4348                         6528
# 30            3780                         5757
# 33            3970                         5391
# 29            1753                         6528
# 32            1860                         5757
# 35            1305                         5391
# 28             427                         6528
# 31             117                         5757
# 34             115                         5391
# 11             677                         2446
# 14             543                         1920
# 17             549                         2013
# 10             379                         2446
# 13             278                         1920
# 16             378                         2013
# 9             1390                         2446
# 12            1099                         1920
# 15            1087                         2013
# 19            7774                         8498
# 22            5699                         6124
# 25            1833                         6897
# 18             381                         8498
# 21             413                         6124
# 24            4719                         6897
# 20             342                         8498
# 23              12                         6124
# 26             345                         6897

# %% [markdown]
# ### Naive

# %%
full_opt[outputColsOptNaive]
# Out:
#           Chain Master                       Product  Period to Last  \
# 0                                 TAAKA VODKA 80  1L               1
# 3                                 TAAKA VODKA 80  1L               2
# 6                                 TAAKA VODKA 80  1L               3
# 1                       TAAKA VODKA 80 BLUE PET 375M               1
# 4                       TAAKA VODKA 80 BLUE PET 375M               2
# 7                       TAAKA VODKA 80 BLUE PET 375M               3
# 2                       TEXAS SPIRIT VODKA 80  1.75L               1
# 5                       TEXAS SPIRIT VODKA 80  1.75L               2
# 8                       TEXAS SPIRIT VODKA 80  1.75L               3
# 27               SPECS            TAAKA VODKA 80  1L               1
# 30               SPECS            TAAKA VODKA 80  1L               2
# 33               SPECS            TAAKA VODKA 80  1L               3
# 29               SPECS  TAAKA VODKA 80 BLUE PET 375M               1
# 32               SPECS  TAAKA VODKA 80 BLUE PET 375M               2
# 35               SPECS  TAAKA VODKA 80 BLUE PET 375M               3
# 28               SPECS      TAAKA VODKA 80 PET 1.75L               1
# 31               SPECS      TAAKA VODKA 80 PET 1.75L               2
# 34               SPECS      TAAKA VODKA 80 PET 1.75L               3
# 11    THE BARREL HOUSE            TAAKA VODKA 80  1L               1
# 14    THE BARREL HOUSE            TAAKA VODKA 80  1L               2
# 17    THE BARREL HOUSE            TAAKA VODKA 80  1L               3
# 10    THE BARREL HOUSE  TAAKA VODKA 80 BLUE PET 200M               1
# 13    THE BARREL HOUSE  TAAKA VODKA 80 BLUE PET 200M               2
# 16    THE BARREL HOUSE  TAAKA VODKA 80 BLUE PET 200M               3
# 9     THE BARREL HOUSE  TAAKA VODKA 80 BLUE PET 375M               1
# 12    THE BARREL HOUSE  TAAKA VODKA 80 BLUE PET 375M               2
# 15    THE BARREL HOUSE  TAAKA VODKA 80 BLUE PET 375M               3
# 19  WESTERN BEV LIQ TX            TAAKA VODKA 80  1L               1
# 22  WESTERN BEV LIQ TX            TAAKA VODKA 80  1L               2
# 25  WESTERN BEV LIQ TX            TAAKA VODKA 80  1L               3
# 18  WESTERN BEV LIQ TX  TAAKA VODKA 80 BLUE PET 375M               1
# 21  WESTERN BEV LIQ TX  TAAKA VODKA 80 BLUE PET 375M               2
# 24  WESTERN BEV LIQ TX  TAAKA VODKA 80 BLUE PET 375M               3
# 20  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80  1.75L               1
# 23  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80  1.75L               2
# 26  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80  1.75L               3
#
#     Actual Price  Actual Demand  Actual Revenue  Actual Chain Master Revenue  \
# 0      44.420127         172.90         7680.24                     12833.52
# 3      44.300752         195.51         8661.24                     13111.80
# 6      44.467025         186.20         8279.76                     13784.40
# 1      58.560000          88.00         5153.28                     12833.52
# 4      58.560000          76.00         4450.56                     13111.80
# 7      58.560000          94.00         5504.64                     13784.40
# 2      51.179487           0.00            0.00                     12833.52
# 5      51.179487           0.00            0.00                     13111.80
# 8      51.179487           0.00            0.00                     13784.40
# 27     44.300752         113.05         5008.20                      5693.22
# 30     44.300752         117.04         5184.96                      6086.52
# 33     44.300752         103.74         4595.76                      5504.40
# 29     58.560000           7.00          409.92                      5693.22
# 32     58.560000           6.00          351.36                      6086.52
# 35     58.560000           8.00          468.48                      5504.40
# 28     47.025641           5.85          275.10                      5693.22
# 31     47.025641          11.70          550.20                      6086.52
# 34     47.025641           9.36          440.16                      5504.40
# 11     46.887218           7.98          374.16                      1764.24
# 14     44.300752           6.65          294.60                      1576.20
# 17     47.626208           9.31          443.40                      2369.16
# 10     62.803738           5.35          336.00                      1764.24
# 13     62.803738           6.42          403.20                      1576.20
# 16     62.803738           6.42          403.20                      2369.16
# 9      58.560000          18.00         1054.08                      1764.24
# 12     58.560000          15.00          878.40                      1576.20
# 15     58.560000          26.00         1522.56                      2369.16
# 19     44.300752          51.87         2297.88                      5987.16
# 22     44.300752          71.82         3181.68                      6402.48
# 25     44.300752          73.15         3240.60                      6754.20
# 18     58.560000          63.00         3689.28                      5987.16
# 21     58.560000          55.00         3220.80                      6402.48
# 24     58.560000          60.00         3513.60                      6754.20
# 20     51.179487           0.00            0.00                      5987.16
# 23     51.179487           0.00            0.00                      6402.48
# 26     51.179487           0.00            0.00                      6754.20
#
#     Naive Prices  Naive Demand  Naive Revenue  Naive Chain Master Revenue
# 0      44.420127    199.948711    8881.747177                13332.307177
# 3      44.300752    200.002841    8860.276255                14364.916255
# 6      44.467025    200.173247    8901.108716                12648.948716
# 1      58.560000     76.000000    4450.560000                13332.307177
# 4      58.560000     94.000000    5504.640000                14364.916255
# 7      58.560000     64.000000    3747.840000                12648.948716
# 2      51.179487      0.000000       0.000000                13332.307177
# 5      51.179487      0.000000       0.000000                14364.916255
# 8      51.179487      0.000000       0.000000                12648.948716
# 27     44.300752    117.040000    5184.960000                 5662.108916
# 30     44.300752    103.740000    4595.760000                 5067.733171
# 33     44.300752    150.175062    6652.868148                 7119.450370
# 29     58.560000      3.801205     222.598554                 5662.108916
# 32     58.560000      3.774390     221.028293                 5067.733171
# 35     58.560000      3.722222     217.973333                 7119.450370
# 28     47.025641      5.413012     254.550361                 5662.108916
# 31     47.025641      5.336341     250.944878                 5067.733171
# 34     47.025641      5.286667     248.608889                 7119.450370
# 11     46.887218      7.452586     349.431034                 1629.968785
# 14     44.300752      7.466667     330.778947                 2255.458062
# 17     47.626208      7.433750     354.041327                 1634.541140
# 10     62.803738      6.403086     402.137751                 1629.968785
# 13     62.803738      6.402789     402.119115                 2255.458062
# 16     62.803738      6.402482     402.099813                 1634.541140
# 9      58.560000     15.000000     878.400000                 1629.968785
# 12     58.560000     26.000000    1522.560000                 2255.458062
# 15     58.560000     15.000000     878.400000                 1634.541140
# 19     44.300752     71.820000    3181.680000                 6402.480000
# 22     44.300752     73.150000    3240.600000                 6754.200000
# 25     44.300752     58.520000    2592.480000                 5052.000000
# 18     58.560000     55.000000    3220.800000                 6402.480000
# 21     58.560000     60.000000    3513.600000                 6754.200000
# 24     58.560000     42.000000    2459.520000                 5052.000000
# 20     51.179487      0.000000       0.000000                 6402.480000
# 23     51.179487      0.000000       0.000000                 6754.200000
# 26     51.179487      0.000000       0.000000                 5052.000000
