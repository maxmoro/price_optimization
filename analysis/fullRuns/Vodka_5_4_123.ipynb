# %% [markdown]
# # Init

# %%
# %load_ext autoreload
# %autoreload 2

# %%
print("CURRENT FOLDER:")
# %pwd
# Out:
# CURRENT FOLDER:
# 'c:\\max\\Google Drive Max\\Max Shared\\Master Data Science\\2020-05 Capstone A\\msds_capstone\\analysis\\fullRuns'

# %%
import os
import glob
import sys
sys.path.append(os.environ['DEV_AUTOTS'])
sys.path.append(os.environ['CAPSTONE_PYTHON_SOURCE'])
folder = os.environ['CAPSTONE_DATA']

# %%
## Sourcing the .py with all the code##
t='"'+os.environ['CAPSTONE_PYTHON_SOURCE']+'\\fullRun\\fullRun.py'+'"'
# %run -i $t
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# Running Auto Timeseries version: 0.0.24

# %% [markdown]
# # Parameters

# %%
#Parameters

ProdCats = ['ECONOMY VODKA']
TOP_PRODUCTS = 5  # How many products to consider in the category
TOP_SIMILAR = 4  # Get TOP_SIMILAR most similar products
RUN_PERIODS = [1,2,3] # this will run AutoTS and Optimzer for speicfic periods (1 = last, 2 = second to last)

CV_NUM = 10         # number of Cross Valudations  10
OPT_CALLS = 100     # number of calls for the optimizer process   100
OPT_RND_STARTS = 20 # number of random calls for the optimizer process  20

LOG_TRANSFORM = True # Take log of 9L cases to smooth out peaks and valleys
ZERO_ADDER = 0.1 

RESAMPLE_FREQ = 'M'


# Pricing changes every 4 weeks
if RESAMPLE_FREQ == 'M':    FORECAST_PERIOD = 1 #last 4 months as test 
if RESAMPLE_FREQ == 'W':    FORECAST_PERIOD = 4 
if RESAMPLE_FREQ == '2W':   FORECAST_PERIOD = 2 

# Seasonal Period
if RESAMPLE_FREQ == 'M':    SEASONAL_PERIOD = 12  # Yearly
if RESAMPLE_FREQ == 'W':    SEASONAL_PERIOD = 13 # Quarterly (we can also take yearly = 52, but SARIMAX becomes too slow)
if RESAMPLE_FREQ == '2W':   SEASONAL_PERIOD = 13 # This becomes problematic --> for quarterly, should we take 6 biweekly periods or 7 bi-weekly periods. Instead I just took half yearly period  

COL_TIME = 'WeekDate'
COL_PREDS = ['9L Cases'] #Demand
COL_PRICE= ['Dollar Sales per 9L Case'] #Price

# %% [markdown]
# # Full Run

# %%
dataRaw = loadDataset(version=4)
ProdCat =ProdCats[0]
ChainMasters =  [''] +  dataRaw['Chain Master'].unique().tolist() 
display(ChainMasters,ProdCats)
# Out:
# ['', 'THE BARREL HOUSE', 'WESTERN BEV LIQ TX', 'SPECS']
# ['ECONOMY VODKA']

# %%
(full_models,full_opt,full_summary,full_chain_summary)  = fullRun(ProdCat = ProdCat
                                                           ,ChainMasters = ChainMasters
                                                           ,dataRaw = dataRaw
                                                           ,savePKL=True
                                                           ,saveXLS=True)
# Out:
# ==================================================
# Parameters being used...
# ==================================================
# TOP_PRODUCTS = 5
# TOP_SIMILAR = 4
# RUN_PERIODS = [1, 2, 3]
# ProdCat: ECONOMY VODKA
# ChainMasters: ['', 'THE BARREL HOUSE', 'WESTERN BEV LIQ TX', 'SPECS']
#
#
# ======================== (2020-09-13 18:46:39.627850)
# ==== Products List  ====
# ==== ECONOMY VODKA =====
# ===========  ===========
# ========================
#
#
#
# ======================= (2020-09-13 18:46:43.514849)
# ======= AUTO-TS =======
# ==== ECONOMY VODKA ====
# ==========  ===========
# ========== 1 ==========
# =======================
#
#
#
# ================== (2020-09-13 18:46:43.515850)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 BLUE PET 375M', '2': 'TEXAS SPIRIT VODKA 80  1.75L', '3': 'TAAKA VODKA 80 PET 1.75L', '4': 'TEXAS SPIRIT VODKA 80 SAZ NL 1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '1', '4', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3', '0', '4', '2']
# % of weeks without a purchase: 1.1904761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '3', '0', '1', '4']
# % of weeks without a purchase: 69.04761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1', '4', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '3', '1', '2']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
# 	Product: TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
#
#
# ===================== (2020-09-13 18:48:25.587904)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#        lb_stat     lb_pvalue
# 12  248.948794  2.266370e-46
# 24  282.763358  4.861676e-46
# 48  368.538254  5.288988e-51
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  584.901182  1.773645e-117
# 24  743.424992  1.784213e-141
# 48  947.167628  2.940142e-167
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  474.857092   4.940599e-94
# 24  562.831143  1.385783e-103
# 48  697.054286  5.309923e-116
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  148.350039  1.225106e-25
# 24  166.824771  2.330111e-23
# 48  349.230594  2.409071e-47
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  15.781393   0.201455
# 24  33.696053   0.090218
# 48  44.059529   0.635010
#
# Is Data White Noise: True
#
#
# ==================== (2020-09-13 18:48:25.648902)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (83, 7) (1, 7)
# (83, 7) (1, 7)
# (83, 7) (1, 7)
# (83, 7) (1, 7)
# (58, 7) (1, 7)
#
#
# =============== (2020-09-13 18:48:25.659904)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.083730         []
# 1  1      last   0.050920         []
# 2  2      last   0.000000         []
# 3  3      mean   0.080436         []
# 4  4      mean   0.069793         []
#
#                                            All RMSEs  \
# 0  [[0.08522395141312492, 0.11059590470983931, 0....
# 1  [[0.050919719560484134, 0.058483693505752464, ...
# 2                                  [[0.0, 0.0, 0.0]]
# 3  [[0.08442928271847924, 0.10271666862052284, 0....
# 4  [[0.0816329202384487, 0.10985594998750277, 0.0...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 2  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 4  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-13 18:48:26.534904)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed: 10.8min remaining: 16.2min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed: 20.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-13 19:08:41.916937)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  8.2min remaining: 12.3min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed: 18.7min finished
# =================== (2020-09-13 19:27:22.861055)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-13 19:27:22.885056)
# ====== OPTIMIZER ======
# ==== ECONOMY VODKA ====
# ==========  ===========
# ========== 1 ==========
# =======================
#
#
#
# =========================== (2020-09-13 19:27:22.885056)
# ==== Running Optimizer ====
# ====== ECONOMY VODKA ======
# ============  =============
# ============ 1 ============
# ===========================
#
#
#
# ================== (2020-09-13 19:27:22.890056)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 BLUE PET 375M', '2': 'TEXAS SPIRIT VODKA 80  1.75L', '3': 'TAAKA VODKA 80 PET 1.75L', '4': 'TEXAS SPIRIT VODKA 80 SAZ NL 1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '1', '4', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3', '0', '4', '2']
# % of weeks without a purchase: 1.1904761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '3', '0', '1', '4']
# % of weeks without a purchase: 69.04761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1', '4', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '3', '1', '2']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
# 	Product: TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
#
#
# ==================== (2020-09-13 19:28:48.004055)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (83, 7) (1, 7)
# (83, 7) (1, 7)
# (83, 7) (1, 7)
# (83, 7) (1, 7)
# (58, 7) (1, 7)
#
#
# ======================== (2020-09-13 19:28:48.015055)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-13 19:28:48.042054)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False, False, False]
#
#
# =============== (2020-09-13 19:28:48.045056)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-13 19:28:48.064054)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-13 19:28:48.065055)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-13 19:28:48.066055)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-13 19:28:48.277054)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-13 19:28:48.284056)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-13 19:30:57.295054)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-13 19:30:57.632053)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-13 19:30:57.633052)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-13 19:30:58.251053)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-13 19:30:58.262052)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-13 19:35:04.551056)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-13 19:35:07.705054)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-13 19:35:07.712056)
# ======= AUTO-TS =======
# ==== ECONOMY VODKA ====
# ==========  ===========
# ========== 2 ==========
# =======================
#
#
#
# ================== (2020-09-13 19:35:07.713055)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 BLUE PET 375M', '2': 'TEXAS SPIRIT VODKA 80  1.75L', '3': 'TAAKA VODKA 80 PET 1.75L', '4': 'TEXAS SPIRIT VODKA 80 SAZ NL 1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '1', '4', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3', '0', '4', '2']
# % of weeks without a purchase: 1.2048192771084338
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '3', '0', '1', '4']
# % of weeks without a purchase: 68.67469879518072
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1', '4', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '3', '1', '2']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
# 	Product: TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
#
#
# ===================== (2020-09-13 19:36:17.985056)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#        lb_stat     lb_pvalue
# 12  247.379998  4.812566e-46
# 24  281.567711  8.439708e-46
# 48  366.781603  1.141278e-50
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  574.606302  2.792191e-115
# 24  727.477625  4.083848e-138
# 48  944.375636  1.109735e-166
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  468.018038   1.404414e-92
# 24  554.010494  9.591640e-102
# 48  696.468177  6.982057e-116
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  144.742513  6.589309e-25
# 24  162.572274  1.476101e-22
# 48  338.164450  2.919586e-45
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  15.557680   0.212345
# 24  33.693867   0.090259
# 48  45.714515   0.566979
#
# Is Data White Noise: True
#
#
# ==================== (2020-09-13 19:36:18.019055)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (82, 7) (1, 7)
# (82, 7) (1, 7)
# (82, 7) (1, 7)
# (82, 7) (1, 7)
# (57, 7) (1, 7)
#
#
# =============== (2020-09-13 19:36:18.028054)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.077936         []
# 1  1      last   0.049104         []
# 2  2      last   0.000000         []
# 3  3      mean   0.087216         []
# 4  4      mean   0.067484         []
#
#                                            All RMSEs  \
# 0  [[0.08907681622057902, 0.11385458510024087, 0....
# 1  [[0.04910363192681037, 0.05961976914518541, 0....
# 2                                  [[0.0, 0.0, 0.0]]
# 3  [[0.09339313017889535, 0.10233695646087668, 0....
# 4  [[0.09617536421503817, 0.10367899808494474, 0....
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 2  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 4  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-13 19:36:18.721055)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed: 12.9min remaining: 19.3min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed: 19.7min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-13 19:56:03.345060)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed: 14.3min remaining: 21.5min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed: 22.4min finished
# =================== (2020-09-13 20:18:26.054053)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-13 20:18:26.094052)
# ====== OPTIMIZER ======
# ==== ECONOMY VODKA ====
# ==========  ===========
# ========== 2 ==========
# =======================
#
#
#
# =========================== (2020-09-13 20:18:26.094052)
# ==== Running Optimizer ====
# ====== ECONOMY VODKA ======
# ============  =============
# ============ 2 ============
# ===========================
#
#
#
# ================== (2020-09-13 20:18:26.102057)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 BLUE PET 375M', '2': 'TEXAS SPIRIT VODKA 80  1.75L', '3': 'TAAKA VODKA 80 PET 1.75L', '4': 'TEXAS SPIRIT VODKA 80 SAZ NL 1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '1', '4', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3', '0', '4', '2']
# % of weeks without a purchase: 1.2048192771084338
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '3', '0', '1', '4']
# % of weeks without a purchase: 68.67469879518072
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1', '4', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '3', '1', '2']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
# 	Product: TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
#
#
# ==================== (2020-09-13 20:19:36.105057)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (82, 7) (1, 7)
# (82, 7) (1, 7)
# (82, 7) (1, 7)
# (82, 7) (1, 7)
# (57, 7) (1, 7)
#
#
# ======================== (2020-09-13 20:19:36.114054)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-13 20:19:36.139054)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False, False, False]
#
#
# =============== (2020-09-13 20:19:36.143054)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-13 20:19:36.155052)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-13 20:19:36.156053)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-13 20:19:36.158053)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-13 20:19:36.976051)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-13 20:19:36.981057)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-13 20:24:50.583058)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-13 20:24:51.750056)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-13 20:24:51.751056)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-13 20:24:52.699053)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-13 20:24:52.716053)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-13 20:29:01.965056)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-13 20:29:02.678053)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-13 20:29:02.688054)
# ======= AUTO-TS =======
# ==== ECONOMY VODKA ====
# ==========  ===========
# ========== 3 ==========
# =======================
#
#
#
# ================== (2020-09-13 20:29:02.688054)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 BLUE PET 375M', '2': 'TEXAS SPIRIT VODKA 80  1.75L', '3': 'TAAKA VODKA 80 PET 1.75L', '4': 'TEXAS SPIRIT VODKA 80 SAZ NL 1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '1', '4', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3', '0', '4', '2']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '3', '0', '1', '4']
# % of weeks without a purchase: 68.29268292682927
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1', '4', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '3', '1', '2']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
# 	Product: TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
#
#
# ===================== (2020-09-13 20:30:15.723060)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#        lb_stat     lb_pvalue
# 12  243.950101  2.495194e-45
# 24  277.452128  5.626127e-45
# 48  363.173548  5.530118e-50
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  563.083839  8.020215e-113
# 24  710.497889  1.533447e-134
# 48  939.687445  1.031921e-165
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  461.149000   4.046888e-91
# 24  545.150471  6.746748e-100
# 48  696.525463  6.797717e-116
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  141.032457  3.706001e-24
# 24  158.246146  9.582502e-22
# 48  325.345702  7.337201e-43
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  15.076991   0.237253
# 24  32.806008   0.108233
# 48  43.730748   0.648301
#
# Is Data White Noise: True
#
#
# ==================== (2020-09-13 20:30:15.751053)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (81, 7) (1, 7)
# (81, 7) (1, 7)
# (81, 7) (1, 7)
# (81, 7) (1, 7)
# (56, 7) (1, 7)
#
#
# =============== (2020-09-13 20:30:15.759058)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.078022         []
# 1  1      last   0.044826         []
# 2  2      last   0.000000         []
# 3  3      mean   0.076948         []
# 4  4      mean   0.075211         []
#
#                                            All RMSEs  \
# 0  [[0.10614956572430416, 0.1364306802567358, 0.0...
# 1  [[0.04482627686032599, 0.061881124720379786, 0...
# 2                                  [[0.0, 0.0, 0.0]]
# 3  [[0.0987077256986276, 0.10351490018633347, 0.0...
# 4  [[0.10202854443437681, 0.11030437140568901, 0....
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 2  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 4  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-13 20:30:16.294052)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed: 13.2min remaining: 19.8min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed: 20.6min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-13 20:50:51.979677)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed: 14.1min remaining: 21.2min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed: 20.9min finished
# =================== (2020-09-13 21:11:47.993795)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-13 21:11:48.023793)
# ====== OPTIMIZER ======
# ==== ECONOMY VODKA ====
# ==========  ===========
# ========== 3 ==========
# =======================
#
#
#
# =========================== (2020-09-13 21:11:48.024794)
# ==== Running Optimizer ====
# ====== ECONOMY VODKA ======
# ============  =============
# ============ 3 ============
# ===========================
#
#
#
# ================== (2020-09-13 21:11:48.030794)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 BLUE PET 375M', '2': 'TEXAS SPIRIT VODKA 80  1.75L', '3': 'TAAKA VODKA 80 PET 1.75L', '4': 'TEXAS SPIRIT VODKA 80 SAZ NL 1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '1', '4', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3', '0', '4', '2']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '3', '0', '1', '4']
# % of weeks without a purchase: 68.29268292682927
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1', '4', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '3', '1', '2']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
# 	Product: TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
#
#
# ==================== (2020-09-13 21:12:59.691793)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (81, 7) (1, 7)
# (81, 7) (1, 7)
# (81, 7) (1, 7)
# (81, 7) (1, 7)
# (56, 7) (1, 7)
#
#
# ======================== (2020-09-13 21:12:59.702795)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-13 21:12:59.727794)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False, False, False]
#
#
# =============== (2020-09-13 21:12:59.731794)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-13 21:12:59.743797)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-13 21:12:59.744796)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-13 21:12:59.745795)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-13 21:13:00.774798)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-13 21:13:00.781798)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-13 21:19:19.372826)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-13 21:19:20.441824)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-13 21:19:20.442823)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-13 21:19:21.721828)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-13 21:19:21.729825)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-13 21:23:44.018826)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-13 21:23:45.713826)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-13 21:23:45.722826)
# ===== Products List  =====
# ===== ECONOMY VODKA ======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 21:23:46.970826)
# ======== AUTO-TS =========
# ===== ECONOMY VODKA ======
# ==== THE BARREL HOUSE ====
# =========== 1 ============
# ==========================
#
#
#
# ========================== (2020-09-13 21:23:46.970826)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80 BLUE PET 375M', '1': 'TAAKA VODKA 80 BLUE PET 200M', '2': 'TAAKA VODKA 80  1L', '3': 'DOBRA VODKA  1.75L', '4': 'TAAKA VODKA 80 PET 1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2', '4', '3']
# % of weeks without a purchase: 1.694915254237288
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 200M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '4', '3']
# % of weeks without a purchase: 1.694915254237288
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1', '4', '3']
# % of weeks without a purchase: 6.779661016949152
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: DOBRA VODKA  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2', '1', '4']
# % of weeks without a purchase: 28.57142857142857
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '2', '1', '3']
# % of weeks without a purchase: 4.761904761904762
# Log Transforming
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TAAKA VODKA 80 BLUE PET 200M
# 	Product: TAAKA VODKA 80  1L
# 	Product: DOBRA VODKA  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
#
#
# ========================== (2020-09-13 21:24:53.709826)
# ====== WHITE NOISE =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#        lb_stat     lb_pvalue
# 12  141.970557  2.395431e-24
# 24  144.452747  3.527878e-19
# 48  320.340879  6.288716e-42
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  21.978242   0.037764
# 24  27.494357   0.281943
# 48  52.638641   0.299248
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12   44.122049  1.455748e-05
# 24   45.996717  4.431043e-03
# 48  112.281342  4.570812e-07
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  105.152166  5.416764e-17
# 24  119.277224  1.304825e-14
# 48  154.987549  3.429672e-13
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  44.506454   0.000013
# 24  59.456046   0.000076
#
# Is Data White Noise: False
#
#
# ========================== (2020-09-13 21:24:53.739825)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (58, 7) (1, 7)
# (58, 7) (1, 7)
# (58, 7) (1, 7)
# (83, 7) (1, 7)
# (41, 7) (1, 7)
#
#
# ========================== (2020-09-13 21:24:53.747824)
# ========= NAIVE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      last   0.068911         []
# 1  1      mean   0.165948         []
# 2  2      mean   0.099268         []
# 3  3      mean   0.531778         []
# 4  4      mean   0.170241         []
#
#                                            All RMSEs  \
# 0  [[0.06891113023575937, 0.09474241449242278, 0....
# 1  [[0.2390439979625162, 0.25545500613475297, 0.1...
# 2  [[0.12248442676716172, 0.18448330474563132, 0....
# 3  [[0.5549559305354916, 0.5833145410737691, 0.53...
# 4  [[0.2540382357442957, 0.19871113167781246, 0.1...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 4  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ========================== (2020-09-13 21:24:54.442826)
# ====== Multivar P0 =======
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed: 11.2min remaining: 16.8min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed: 17.9min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================== (2020-09-13 21:42:49.110827)
# ==== Multivar P0+Sim =====
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed: 10.6min remaining: 15.9min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed: 14.9min finished
# ========================== (2020-09-13 21:57:42.659826)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 21:57:42.725827)
# ======= OPTIMIZER ========
# ===== ECONOMY VODKA ======
# ==== THE BARREL HOUSE ====
# =========== 1 ============
# ==========================
#
#
#
# =========================== (2020-09-13 21:57:42.726827)
# ==== Running Optimizer ====
# ====== ECONOMY VODKA ======
# ==== THE BARREL HOUSE =====
# ============ 1 ============
# ===========================
#
#
#
# ========================== (2020-09-13 21:57:42.734828)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80 BLUE PET 375M', '1': 'TAAKA VODKA 80 BLUE PET 200M', '2': 'TAAKA VODKA 80  1L', '3': 'DOBRA VODKA  1.75L', '4': 'TAAKA VODKA 80 PET 1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2', '4', '3']
# % of weeks without a purchase: 1.694915254237288
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 200M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '4', '3']
# % of weeks without a purchase: 1.694915254237288
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1', '4', '3']
# % of weeks without a purchase: 6.779661016949152
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: DOBRA VODKA  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2', '1', '4']
# % of weeks without a purchase: 28.57142857142857
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '2', '1', '3']
# % of weeks without a purchase: 4.761904761904762
# Log Transforming
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TAAKA VODKA 80 BLUE PET 200M
# 	Product: TAAKA VODKA 80  1L
# 	Product: DOBRA VODKA  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
#
#
# ========================== (2020-09-13 21:58:48.227826)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (58, 7) (1, 7)
# (58, 7) (1, 7)
# (58, 7) (1, 7)
# (83, 7) (1, 7)
# (41, 7) (1, 7)
#
#
# ========================== (2020-09-13 21:58:48.237825)
# ===== NAIVE FORECAST =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 21:58:48.261825)
# ========== MASK ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
# Mask: [False, False, False, False, False]
#
#
# ========================== (2020-09-13 21:58:48.265826)
# ========= SPACE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
# Min Limit is >= than Max Limit, setting them near median (+-5%)
#
#
# ========================== (2020-09-13 21:58:48.279824)
# ======= Test Index =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 21:58:48.280824)
# ==== GET FUNCTION P0 =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ====================================== (2020-09-13 21:58:48.281823)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ========== THE BARREL HOUSE ==========
# ======================================
#
#
#
# ========================== (2020-09-13 21:58:48.487825)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 21:58:48.493827)
# ===== OPTIMIZING P0 ======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:05:57.433824)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ============================= (2020-09-13 22:05:57.717827)
# ==== GET FUNCTION P0+Sim ====
# ===== THE BARREL HOUSE ======
# =============================
#
#
#
# ========================================== (2020-09-13 22:05:57.718827)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ============ THE BARREL HOUSE ============
# ==========================================
#
#
#
# ========================== (2020-09-13 22:05:57.930825)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# =========================== (2020-09-13 22:05:57.937825)
# ==== OPTIMIZING P0+Sim ====
# ==== THE BARREL HOUSE =====
# ===========================
#
#
#
# ========================== (2020-09-13 22:10:34.121827)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:10:34.381826)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:10:34.392827)
# ======== AUTO-TS =========
# ===== ECONOMY VODKA ======
# ==== THE BARREL HOUSE ====
# =========== 2 ============
# ==========================
#
#
#
# ========================== (2020-09-13 22:10:34.392827)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80 BLUE PET 375M', '1': 'TAAKA VODKA 80 BLUE PET 200M', '2': 'TAAKA VODKA 80  1L', '3': 'DOBRA VODKA  1.75L', '4': 'TAAKA VODKA 80 PET 1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2', '4', '3']
# % of weeks without a purchase: 1.7241379310344827
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 200M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '4', '3']
# % of weeks without a purchase: 1.7241379310344827
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1', '4', '3']
# % of weeks without a purchase: 6.896551724137931
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: DOBRA VODKA  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2', '1', '4']
# % of weeks without a purchase: 28.915662650602407
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '2', '1', '3']
# % of weeks without a purchase: 4.878048780487805
# Log Transforming
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TAAKA VODKA 80 BLUE PET 200M
# 	Product: TAAKA VODKA 80  1L
# 	Product: DOBRA VODKA  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
#
#
# ========================== (2020-09-13 22:11:41.076825)
# ====== WHITE NOISE =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#        lb_stat     lb_pvalue
# 12  137.410866  1.993797e-23
# 24  139.910786  2.418875e-18
# 48  322.778598  2.210050e-42
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  21.669742   0.041392
# 24  27.152575   0.297392
# 48  52.791525   0.294182
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12   42.786664  2.453685e-05
# 24   44.707020  6.307408e-03
# 48  111.872160  5.168754e-07
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  104.052037  8.917711e-17
# 24  118.103635  2.109057e-14
# 48  153.752344  5.308252e-13
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  42.697012   0.000025
# 24  58.885104   0.000092
#
# Is Data White Noise: False
#
#
# ========================== (2020-09-13 22:11:41.104827)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (57, 7) (1, 7)
# (57, 7) (1, 7)
# (57, 7) (1, 7)
# (82, 7) (1, 7)
# (40, 7) (1, 7)
#
#
# ========================== (2020-09-13 22:11:41.109826)
# ========= NAIVE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      last   0.055124         []
# 1  1      mean   0.206669         []
# 2  2      mean   0.094367         []
# 3  3      last   0.583315         []
# 4  4      mean   0.169375         []
#
#                                            All RMSEs  \
# 0  [[0.055123576776570093, 0.0992941627475532, 0....
# 1  [[0.2776588463567642, 0.2832827480917138, 0.20...
# 2  [[0.1282258925607897, 0.17212401268673627, 0.0...
# 3  [[0.5833145410737691, 0.6936949131693646, 0.59...
# 4  [[0.2528394494374266, 0.19871113167781249, 0.1...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 3  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 4  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ========================== (2020-09-13 22:11:41.762826)
# ====== Multivar P0 =======
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed: 13.5min remaining: 20.3min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed: 19.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================== (2020-09-13 22:30:39.450354)
# ==== Multivar P0+Sim =====
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  9.4min remaining: 14.2min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed: 14.0min finished
# ========================== (2020-09-13 22:44:39.338353)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:44:39.416352)
# ======= OPTIMIZER ========
# ===== ECONOMY VODKA ======
# ==== THE BARREL HOUSE ====
# =========== 2 ============
# ==========================
#
#
#
# =========================== (2020-09-13 22:44:39.416352)
# ==== Running Optimizer ====
# ====== ECONOMY VODKA ======
# ==== THE BARREL HOUSE =====
# ============ 2 ============
# ===========================
#
#
#
# ========================== (2020-09-13 22:44:39.425352)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80 BLUE PET 375M', '1': 'TAAKA VODKA 80 BLUE PET 200M', '2': 'TAAKA VODKA 80  1L', '3': 'DOBRA VODKA  1.75L', '4': 'TAAKA VODKA 80 PET 1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2', '4', '3']
# % of weeks without a purchase: 1.7241379310344827
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 200M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '4', '3']
# % of weeks without a purchase: 1.7241379310344827
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1', '4', '3']
# % of weeks without a purchase: 6.896551724137931
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: DOBRA VODKA  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2', '1', '4']
# % of weeks without a purchase: 28.915662650602407
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '2', '1', '3']
# % of weeks without a purchase: 4.878048780487805
# Log Transforming
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TAAKA VODKA 80 BLUE PET 200M
# 	Product: TAAKA VODKA 80  1L
# 	Product: DOBRA VODKA  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
#
#
# ========================== (2020-09-13 22:45:44.276352)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (57, 7) (1, 7)
# (57, 7) (1, 7)
# (57, 7) (1, 7)
# (82, 7) (1, 7)
# (40, 7) (1, 7)
#
#
# ========================== (2020-09-13 22:45:44.286352)
# ===== NAIVE FORECAST =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:45:44.313352)
# ========== MASK ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
# Mask: [False, False, False, False, False]
#
#
# ========================== (2020-09-13 22:45:44.316360)
# ========= SPACE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
# Min Limit is >= than Max Limit, setting them near median (+-5%)
#
#
# ========================== (2020-09-13 22:45:44.331353)
# ======= Test Index =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:45:44.332353)
# ==== GET FUNCTION P0 =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ====================================== (2020-09-13 22:45:44.333352)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ========== THE BARREL HOUSE ==========
# ======================================
#
#
#
# ========================== (2020-09-13 22:45:44.553353)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:45:44.558353)
# ===== OPTIMIZING P0 ======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:50:39.304556)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ============================= (2020-09-13 22:50:39.510554)
# ==== GET FUNCTION P0+Sim ====
# ===== THE BARREL HOUSE ======
# =============================
#
#
#
# ========================================== (2020-09-13 22:50:39.512555)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ============ THE BARREL HOUSE ============
# ==========================================
#
#
#
# ========================== (2020-09-13 22:50:39.736559)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# =========================== (2020-09-13 22:50:39.745556)
# ==== OPTIMIZING P0+Sim ====
# ==== THE BARREL HOUSE =====
# ===========================
#
#
#
# ========================== (2020-09-13 22:55:22.624312)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:55:22.797311)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:55:22.806313)
# ======== AUTO-TS =========
# ===== ECONOMY VODKA ======
# ==== THE BARREL HOUSE ====
# =========== 3 ============
# ==========================
#
#
#
# ========================== (2020-09-13 22:55:22.806313)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ...
# ====== SPECS ======
# ===================
#
#
#
# ============================= (2020-09-14 04:55:01.763811)
# ==== GET FUNCTION P0+Sim ====
# =========== SPECS ===========
# =============================
#
#
#
# ========================================== (2020-09-14 04:55:01.765810)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ================= SPECS ==================
# ==========================================
#
#
#
# =================== (2020-09-14 04:55:02.635812)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =========================== (2020-09-14 04:55:02.642812)
# ==== OPTIMIZING P0+Sim ====
# ========== SPECS ==========
# ===========================
#
#
#
# =================== (2020-09-14 04:59:51.888993)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =================== (2020-09-14 04:59:52.280994)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ======================= (2020-09-14 04:59:52.294997)
# ======= AUTO-TS =======
# ==== ECONOMY VODKA ====
# ======== SPECS ========
# ========== 3 ==========
# =======================
#
#
#
# ================== (2020-09-14 04:59:52.295994)
# ==== GET DATA ====
# ===== SPECS ======
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 PET 1.75L', '2': 'TAAKA VODKA 80 BLUE PET 375M', '3': 'MCCORMICK CHERRY VODKA 60  1L', '4': 'DOBRA VODKA  1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2', '4', '3']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '4', '3']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1', '4', '3']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: MCCORMICK CHERRY VODKA 60  1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1', '2', '4']
# % of weeks without a purchase: 28.39506172839506
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: DOBRA VODKA  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '1', '2', '3']
# % of weeks without a purchase: 14.814814814814813
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 PET 1.75L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: MCCORMICK CHERRY VODKA 60  1L
# 	Product: DOBRA VODKA  1.75L
#
#
# ===================== (2020-09-14 05:01:21.530150)
# ==== WHITE NOISE ====
# ======= SPECS =======
# =====================
#
#        lb_stat     lb_pvalue
# 12  163.850364  8.614761e-29
# 24  202.851035  2.932294e-30
# 48  302.430383  1.310197e-38
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  203.867388  5.185416e-37
# 24  249.138534  2.445714e-39
# 48  386.780036  1.745507e-54
#
# Is Data White Noise: False
#        lb_stat  lb_pvalue
# 12   41.146569   0.000046
# 24   60.607680   0.000052
# 48  103.105730   0.000007
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  12.395058   0.414496
# 24  22.052180   0.576152
# 48  51.642102   0.333451
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12  24.341688   0.018270
# 24  33.409284   0.095728
# 48  82.146329   0.001561
#
# Is Data White Noise: True
#
#
# ==================== (2020-09-14 05:01:21.564149)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (81, 7) (1, 7)
# (81, 7) (1, 7)
# (81, 7) (1, 7)
# (80, 7) (1, 7)
# (80, 7) (1, 7)
#
#
# =============== (2020-09-14 05:01:21.576147)
# ==== NAIVE ====
# ==== SPECS ====
# ===============
#
#   ID      Best Type  Best RMSE All Naives  \
# 0  0           mean   0.107768         []
# 1  1           mean   0.136330         []
# 2  2           mean   0.121653         []
# 3  3  seasonal_last   0.432273         []
# 4  4           mean   0.360263         []
#
#                                            All RMSEs  \
# 0  [[0.13456120941276825, 0.187951813296838, 0.10...
# 1  [[0.21541297336857784, 0.22034399791646134, 0....
# 2  [[0.17742034252670738, 0.1589870135780978, 0.1...
# 3  [[0.49069171944604034, 0.4322727246195653, 0.6...
# 4  [[0.46158729599658893, 0.4079241449775477, 0.3...
#
#                        All Types  \
# 0  [[last, seasonal_last, mean]]
# 1  [[last, seasonal_last, mean]]
# 2  [[last, seasonal_last, mean]]
# 3  [[last, seasonal_last, mean]]
# 4  [[last, seasonal_last, mean]]
#
#                                         Best Naive
# 0           NaiveForecaster(sp=4, strategy='mean')
# 1           NaiveForecaster(sp=4, strategy='mean')
# 2           NaiveForecaster(sp=4, strategy='mean')
# 3  NaiveForecaster(sp=4, strategy='seasonal_last')
# 4           NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-14 05:01:22.236150)
# ==== Multivar P0 ====
# ======= SPECS =======
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed: 10.9min remaining: 16.3min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed: 11.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-14 05:12:34.324034)
# ==== Multivar P0+Sim ====
# ========= SPECS =========
# =========================
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  5.5min remaining:  8.3min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  7.5min finished
# =================== (2020-09-14 05:20:01.813692)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ======================= (2020-09-14 05:20:01.939692)
# ====== OPTIMIZER ======
# ==== ECONOMY VODKA ====
# ======== SPECS ========
# ========== 3 ==========
# =======================
#
#
#
# =========================== (2020-09-14 05:20:01.939692)
# ==== Running Optimizer ====
# ====== ECONOMY VODKA ======
# ========== SPECS ==========
# ============ 3 ============
# ===========================
#
#
#
# ================== (2020-09-14 05:20:01.947692)
# ==== GET DATA ====
# ===== SPECS ======
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 PET 1.75L', '2': 'TAAKA VODKA 80 BLUE PET 375M', '3': 'MCCORMICK CHERRY VODKA 60  1L', '4': 'DOBRA VODKA  1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2', '4', '3']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '4', '3']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1', '4', '3']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: MCCORMICK CHERRY VODKA 60  1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1', '2', '4']
# % of weeks without a purchase: 28.39506172839506
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: DOBRA VODKA  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '1', '2', '3']
# % of weeks without a purchase: 14.814814814814813
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 PET 1.75L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: MCCORMICK CHERRY VODKA 60  1L
# 	Product: DOBRA VODKA  1.75L
#
#
# ==================== (2020-09-14 05:21:16.872695)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (81, 7) (1, 7)
# (81, 7) (1, 7)
# (81, 7) (1, 7)
# (80, 7) (1, 7)
# (80, 7) (1, 7)
#
#
# ======================== (2020-09-14 05:21:16.886691)
# ==== NAIVE FORECAST ====
# ======== SPECS =========
# ========================
#
#
#
# =============== (2020-09-14 05:21:16.919692)
# ==== MASK =====
# ==== SPECS ====
# ===============
#
# Mask: [False, False, False, False, False]
#
#
# =============== (2020-09-14 05:21:16.923693)
# ==== SPACE ====
# ==== SPECS ====
# ===============
#
# Min Limit is >= than Max Limit, setting them near median (+-5%)
#
#
# ==================== (2020-09-14 05:21:16.943691)
# ==== Test Index ====
# ====== SPECS =======
# ====================
#
#
#
# ========================= (2020-09-14 05:21:16.945695)
# ==== GET FUNCTION P0 ====
# ========= SPECS =========
# =========================
#
#
#
# ====================================== (2020-09-14 05:21:16.947694)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# =============== SPECS ================
# ======================================
#
# Building Forecast dataframe. Forecast Period = 1
#
#
# =================== (2020-09-14 05:21:20.160690)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ======================= (2020-09-14 05:21:20.166693)
# ==== OPTIMIZING P0 ====
# ======== SPECS ========
# =======================
#
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
#
#
# =================== (2020-09-14 05:27:47.463693)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
# Building Forecast dataframe. Forecast Period = 1
#
#
# ============================= (2020-09-14 05:27:50.827690)
# ==== GET FUNCTION P0+Sim ====
# =========== SPECS ===========
# =============================
#
#
#
# ========================================== (2020-09-14 05:27:50.830690)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ================= SPECS ==================
# ==========================================
#
#
#
# =================== (2020-09-14 05:27:51.189691)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =========================== (2020-09-14 05:27:51.198695)
# ==== OPTIMIZING P0+Sim ====
# ========== SPECS ==========
# ===========================
#
#
#
# =================== (2020-09-14 05:29:24.684693)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =================== (2020-09-14 05:29:24.958691)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ========================== (2020-09-14 05:29:24.987693)
# ==== Saving to PICKLE ====
# ===== ECONOMY VODKA ======
# ==========================
#
# Pickle File  full_models_ECONOMY VODKA_Prod5_Sim4_Per123.pkl  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns
# Pickle File  full_opt_ECONOMY VODKA_Prod5_Sim4_Per123.pkl  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns
#
#
# ========================= (2020-09-14 05:29:25.341695)
# ==== Saving to EXCEL ====
# ===== ECONOMY VODKA =====
# =========================
#
# EXCEL File  Output_ECONOMY VODKA_Prod5_Sim4_Per123.xlsx  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns

# %% [markdown]
# # Print out

# %% [markdown]
# ## Models

# %%
full_models[outputColsModels]
# Out:
#           Chain Master                             Product  Period to Last  \
# 0                                       TAAKA VODKA 80  1L               1
# 5                                       TAAKA VODKA 80  1L               2
# 10                                      TAAKA VODKA 80  1L               3
# 1                             TAAKA VODKA 80 BLUE PET 375M               1
# 6                             TAAKA VODKA 80 BLUE PET 375M               2
# 11                            TAAKA VODKA 80 BLUE PET 375M               3
# 3                                 TAAKA VODKA 80 PET 1.75L               1
# 8                                 TAAKA VODKA 80 PET 1.75L               2
# 13                                TAAKA VODKA 80 PET 1.75L               3
# 2                             TEXAS SPIRIT VODKA 80  1.75L               1
# 7                             TEXAS SPIRIT VODKA 80  1.75L               2
# 12                            TEXAS SPIRIT VODKA 80  1.75L               3
# 4                       TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               1
# 9                       TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               2
# 14                      TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               3
# 49               SPECS                  DOBRA VODKA  1.75L               1
# 54               SPECS                  DOBRA VODKA  1.75L               2
# 59               SPECS                  DOBRA VODKA  1.75L               3
# 48               SPECS       MCCORMICK CHERRY VODKA 60  1L               1
# 53               SPECS       MCCORMICK CHERRY VODKA 60  1L               2
# 58               SPECS       MCCORMICK CHERRY VODKA 60  1L               3
# 45               SPECS                  TAAKA VODKA 80  1L               1
# 50               SPECS                  TAAKA VODKA 80  1L               2
# 55               SPECS                  TAAKA VODKA 80  1L               3
# 47               SPECS        TAAKA VODKA 80 BLUE PET 375M               1
# 52               SPECS        TAAKA VODKA 80 BLUE PET 375M               2
# 57               SPECS        TAAKA VODKA 80 BLUE PET 375M               3
# 46               SPECS            TAAKA VODKA 80 PET 1.75L               1
# 51               SPECS            TAAKA VODKA 80 PET 1.75L               2
# 56               SPECS            TAAKA VODKA 80 PET 1.75L               3
# 18    THE BARREL HOUSE                  DOBRA VODKA  1.75L               1
# 23    THE BARREL HOUSE                  DOBRA VODKA  1.75L               2
# 28    THE BARREL HOUSE                  DOBRA VODKA  1.75L               3
# 17    THE BARREL HOUSE                  TAAKA VODKA 80  1L               1
# 22    THE BARREL HOUSE                  TAAKA VODKA 80  1L               2
# 27    THE BARREL HOUSE                  TAAKA VODKA 80  1L               3
# 16    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 200M               1
# 21    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 200M               2
# 26    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 200M               3
# 15    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 375M               1
# 20    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 375M               2
# 25    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 375M               3
# 19    THE BARREL HOUSE            TAAKA VODKA 80 PET 1.75L               1
# 24    THE BARREL HOUSE            TAAKA VODKA 80 PET 1.75L               2
# 29    THE BARREL HOUSE            TAAKA VODKA 80 PET 1.75L               3
# 31  WESTERN BEV LIQ TX                  TAAKA VODKA 80  1L               1
# 36  WESTERN BEV LIQ TX                  TAAKA VODKA 80  1L               2
# 41  WESTERN BEV LIQ TX                  TAAKA VODKA 80  1L               3
# 30  WESTERN BEV LIQ TX        TAAKA VODKA 80 BLUE PET 375M               1
# 35  WESTERN BEV LIQ TX        TAAKA VODKA 80 BLUE PET 375M               2
# 40  WESTERN BEV LIQ TX        TAAKA VODKA 80 BLUE PET 375M               3
# 33  WESTERN BEV LIQ TX            TAAKA VODKA 80 PET 1.75L               1
# 38  WESTERN BEV LIQ TX            TAAKA VODKA 80 PET 1.75L               2
# 43  WESTERN BEV LIQ TX            TAAKA VODKA 80 PET 1.75L               3
# 32  WESTERN BEV LIQ TX        TEXAS SPIRIT VODKA 80  1.75L               1
# 37  WESTERN BEV LIQ TX        TEXAS SPIRIT VODKA 80  1.75L               2
# 42  WESTERN BEV LIQ TX        TEXAS SPIRIT VODKA 80  1.75L               3
# 34  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               1
# 39  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               2
# 44  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               3
#
#     White Noise Naive Best Type  Naive Best RMSE P0 Best Model Name  \
# 0         False            mean         0.083730                 ML
# 5         False            mean         0.077936                 ML
# 10        False            mean         0.078022                 ML
# 1         False            last         0.050920                 ML
# 6         False            last         0.049104            SARIMAX
# 11        False            last         0.044826       auto_SARIMAX
# 3         False            mean         0.080436                 ML
# 8         False            mean         0.087216            SARIMAX
# 13        False            mean         0.076948            SARIMAX
# 2         False            last         0.000000            SARIMAX
# 7         False            last         0.000000            SARIMAX
# 12        False            last         0.000000            SARIMAX
# 4          True            mean         0.069793            SARIMAX
# 9          True            mean         0.067484            SARIMAX
# 14         True            mean         0.075211            SARIMAX
# 49         True            mean         0.421833                 ML
# 54         True            mean         0.344666                 ML
# 59         True            mean         0.360263                 ML
# 48         True   seasonal_last         0.288182       auto_SARIMAX
# 53         True   seasonal_last         0.432273       auto_SARIMAX
# 58         True   seasonal_last         0.432273                 ML
# 45        False            last         0.109601                 ML
# 50        False            last         0.116424                 ML
# 55        False            mean         0.107768                 ML
# 47        False            mean         0.113808            SARIMAX
# 52        False            mean         0.104293            SARIMAX
# 57        False            mean         0.121653       auto_SARIMAX
# 46        False            mean         0.113211            SARIMAX
# 51        False            mean         0.120084                 ML
# 56        False            mean         0.136330            Prophet
# 18        False            mean         0.531778                 ML
# 23        False            last         0.583315                 ML
# 28        False            last         0.472934            SARIMAX
# 17        False            mean         0.099268                 ML
# 22        False            mean         0.094367                 ML
# 27        False            mean         0.093113                 ML
# 16         True            mean         0.165948                 ML
# 21         True            mean         0.206669                 ML
# 26         True            mean         0.199992                 ML
# 15        False            last         0.068911       auto_SARIMAX
# 20        False            last         0.055124       auto_SARIMAX
# 25        False            last         0.065992       auto_SARIMAX
# 19        False            mean         0.170241                 ML
# 24        False            mean         0.169375                 ML
# 29        False            mean         0.186769                 ML
# 31        False            last         0.113461            Prophet
# 36        False            last         0.107550            Prophet
# 41        False            last         0.126205                 ML
# 30        False            last         0.064357                 ML
# 35        False            last         0.062996                 ML
# 40        False            last         0.055440                 ML
# 33        False            last         0.109374       auto_SARIMAX
# 38        False            last         0.122087       auto_SARIMAX
# 43        False            mean         0.137258       auto_SARIMAX
# 32        False            last         0.000000            SARIMAX
# 37        False            last         0.000000            SARIMAX
# 42        False            last         0.000000            SARIMAX
# 34         True            mean         0.069793            SARIMAX
# 39         True            mean         0.067484            SARIMAX
# 44         True            mean         0.075211            SARIMAX
#
#     P0 Best Model RMSE P0+Sim Best Model Name  P0+Sim Best Model RMSE
# 0             0.074880                     ML                0.074919
# 5             0.069895                     ML                0.069934
# 10            0.064195                     ML                0.064723
# 1             0.055895                SARIMAX                0.046042
# 6             0.057594                SARIMAX                0.052995
# 11            0.058057                SARIMAX                0.045150
# 3             0.048723                     ML                0.057683
# 8             0.056825           auto_SARIMAX                0.064988
# 13            0.050590           auto_SARIMAX                0.065785
# 2             0.001320                SARIMAX                0.003522
# 7             0.001044                SARIMAX                0.003376
# 12            0.001135                SARIMAX                0.002813
# 4             0.056888                SARIMAX                0.059991
# 9             0.054461                SARIMAX                0.062034
# 14            0.072678                SARIMAX                0.079292
# 49            0.131512                     ML                0.143743
# 54            0.131576                     ML                0.130533
# 59            0.131003                     ML                0.125766
# 48            0.049483                     ML                0.087339
# 53            0.050417                     ML                0.088157
# 58            0.077907                     ML                0.066541
# 45            0.114726                     ML                0.114734
# 50            0.097598                     ML                0.097970
# 55            0.082030                     ML                0.082402
# 47            0.110920                SARIMAX                0.147202
# 52            0.122456                SARIMAX                0.157483
# 57            0.121268                     ML                0.153721
# 46            0.112525                SARIMAX                0.121577
# 51            0.128680                     ML                0.123737
# 56            0.106713                     ML                0.122137
# 18            0.110073                     ML                0.098383
# 23            0.110073                     ML                0.098383
# 28            0.106258                     ML                0.105613
# 17            0.141781                SARIMAX                0.090807
# 22            0.141624                SARIMAX                0.110621
# 27            0.130413                SARIMAX                0.119353
# 16            0.188430                     ML                0.175243
# 21            0.204441                     ML                0.188277
# 26            0.205818                     ML                0.185964
# 15            0.070390                SARIMAX                0.055217
# 20            0.066565                SARIMAX                0.091013
# 25            0.056497                SARIMAX                0.077676
# 19            0.159083                     ML                0.147372
# 24            0.194023                     ML                0.190020
# 29            0.187915                     ML                0.183913
# 31            0.089950           auto_SARIMAX                0.084156
# 36            0.105715           auto_SARIMAX                0.111647
# 41            0.098518                     ML                0.098594
# 30            0.061341                     ML                0.060409
# 35            0.063986                     ML                0.067082
# 40            0.082589           auto_SARIMAX                0.066629
# 33            0.064250           auto_SARIMAX                0.060286
# 38            0.091435           auto_SARIMAX                0.082509
# 43            0.076854                     ML                0.087608
# 32            0.001320                SARIMAX                0.004703
# 37            0.001044                SARIMAX                0.004742
# 42            0.001135                SARIMAX                0.005082
# 34            0.056888                     ML                0.062031
# 39            0.054461                SARIMAX                0.076330
# 44            0.072678                     ML                0.089955

# %% [markdown]
# ## Optimizer

# %% [markdown]
# ### Summary by Chain

# %%
full_chain_summary
# Out:
#          Chain Master  P0 Non-Opt Revenue  P0 Opt Revenue  P0 Opt Diff  \
# 0                                 34918.0         34892.0        -26.0
# 1               SPECS             15956.0         17778.0       1822.0
# 2    THE BARREL HOUSE              6806.0          6861.0         55.0
# 3  WESTERN BEV LIQ TX             13267.0         22059.0       8792.0
#
#    P0 Opt Diff Ratio  P0+Sim Non-Opt Revenue  P0+Sim Opt Revenue  \
# 0           0.999255                 36692.0        3.745500e+04
# 1           1.114189                 15016.0        1.079851e+09
# 2           1.008081                  7775.0        1.165300e+04
# 3           1.662697                 19363.0        2.771500e+04
#
#    P0+Sim Opt Diff  P0+Sim Opt Diff Ratio
# 0     7.630000e+02               1.020795
# 1     1.079836e+09           71913.335509
# 2     3.878000e+03               1.498778
# 3     8.352000e+03               1.431338

# %%
print("WRITE this value in the summary table in Git hub --->",round(full_chain_summary[full_chain_summary['Chain Master']=='']['P0+Sim Opt Diff Ratio'].item(),4))
# Out:
# WRITE this value in the summary table in Git hub ---> 1.0208

# %% [markdown]
# Link to the Git Hub Summary Table: https://github.com/ngupta23/msds_capstone/issues/84

# %% [markdown]
# ### Summary by Chain and Product

# %%
full_summary
# Out:
#           Chain Master                             Product  \
# 0                                       TAAKA VODKA 80  1L
# 1                             TAAKA VODKA 80 BLUE PET 375M
# 2                                 TAAKA VODKA 80 PET 1.75L
# 3                             TEXAS SPIRIT VODKA 80  1.75L
# 4                       TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
# 5                SPECS                  DOBRA VODKA  1.75L
# 6                SPECS       MCCORMICK CHERRY VODKA 60  1L
# 7                SPECS                  TAAKA VODKA 80  1L
# 8                SPECS        TAAKA VODKA 80 BLUE PET 375M
# 9                SPECS            TAAKA VODKA 80 PET 1.75L
# 10    THE BARREL HOUSE                  DOBRA VODKA  1.75L
# 11    THE BARREL HOUSE                  TAAKA VODKA 80  1L
# 12    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 200M
# 13    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 375M
# 14    THE BARREL HOUSE            TAAKA VODKA 80 PET 1.75L
# 15  WESTERN BEV LIQ TX                  TAAKA VODKA 80  1L
# 16  WESTERN BEV LIQ TX        TAAKA VODKA 80 BLUE PET 375M
# 17  WESTERN BEV LIQ TX            TAAKA VODKA 80 PET 1.75L
# 18  WESTERN BEV LIQ TX        TEXAS SPIRIT VODKA 80  1.75L
# 19  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
#
#     P0 Non-Opt Revenue  P0 Opt Revenue  P0 Opt Diff  P0 Opt Diff Ratio  \
# 0              16812.0         16772.0        -40.0           0.997621
# 1              10119.0         10119.0          0.0           1.000000
# 2               5568.0          5568.0          0.0           1.000000
# 3                 15.0            29.0         14.0           1.933333
# 4               2404.0          2404.0          0.0           1.000000
# 5                328.0           338.0         10.0           1.030488
# 6                242.0           269.0         27.0           1.111570
# 7              12144.0         12144.0          0.0           1.000000
# 8               1057.0          1150.0         93.0           1.087985
# 9               2185.0          3877.0       1692.0           1.774371
# 10               828.0           850.0         22.0           1.026570
# 11              1573.0          1595.0         22.0           1.013986
# 12              1034.0          1036.0          2.0           1.001934
# 13              3085.0          3085.0          0.0           1.000000
# 14               286.0           295.0          9.0           1.031469
# 15              7507.0         15175.0       7668.0           2.021447
# 16              1202.0          1202.0          0.0           1.000000
# 17              2139.0          3249.0       1110.0           1.518934
# 18                15.0            29.0         14.0           1.933333
# 19              2404.0          2404.0          0.0           1.000000
#
#     P0+Sim Non-Opt Revenue  P0+Sim Opt Revenue  P0+Sim Opt Diff  \
# 0                  16696.0        1.665600e+04    -4.000000e+01
# 1                  11703.0        1.277400e+04     1.071000e+03
# 2                   5850.0        5.666000e+03    -1.840000e+02
# 3                     15.0        1.800000e+01     3.000000e+00
# 4                   2428.0        2.341000e+03    -8.700000e+01
# 5                    317.0        3.170000e+02     0.000000e+00
# 6                    342.0        3.690000e+02     2.700000e+01
# 7                  12894.0        1.289400e+04     0.000000e+00
# 8                    781.0        1.079234e+09     1.079233e+09
# 9                    682.0        6.029300e+05     6.022480e+05
# 10                  1069.0        1.052000e+03    -1.700000e+01
# 11                  1562.0        5.335000e+03     3.773000e+03
# 12                   929.0        9.300000e+02     1.000000e+00
# 13                  3920.0        4.031000e+03     1.110000e+02
# 14                   295.0        3.050000e+02     1.000000e+01
# 15                  9255.0        1.443800e+04     5.183000e+03
# 16                  3904.0        6.176000e+03     2.272000e+03
# 17                  3927.0        4.887000e+03     9.600000e+02
# 18                    15.0        2.100000e+01     6.000000e+00
# 19                  2262.0        2.193000e+03    -6.900000e+01
#
#     P0+Sim Opt Diff Ratio
# 0            9.976042e-01
# 1            1.091515e+00
# 2            9.685470e-01
# 3            1.200000e+00
# 4            9.641680e-01
# 5            1.000000e+00
# 6            1.078947e+00
# 7            1.000000e+00
# 8            1.381862e+06
# 9            8.840616e+02
# 10           9.840973e-01
# 11           3.415493e+00
# 12           1.001076e+00
# 13           1.028316e+00
# 14           1.033898e+00
# 15           1.560022e+00
# 16           1.581967e+00
# 17           1.244461e+00
# 18           1.400000e+00
# 19           9.694960e-01

# %% [markdown]
# ### P0 Optimizer

# %%
full_opt[outputColsOptP0]
# Out:
#           Chain Master                             Product  Period to Last  \
# 0                                       TAAKA VODKA 80  1L               1
# 5                                       TAAKA VODKA 80  1L               2
# 10                                      TAAKA VODKA 80  1L               3
# 1                             TAAKA VODKA 80 BLUE PET 375M               1
# 6                             TAAKA VODKA 80 BLUE PET 375M               2
# 11                            TAAKA VODKA 80 BLUE PET 375M               3
# 3                                 TAAKA VODKA 80 PET 1.75L               1
# 8                                 TAAKA VODKA 80 PET 1.75L               2
# 13                                TAAKA VODKA 80 PET 1.75L               3
# 2                             TEXAS SPIRIT VODKA 80  1.75L               1
# 7                             TEXAS SPIRIT VODKA 80  1.75L               2
# 12                            TEXAS SPIRIT VODKA 80  1.75L               3
# 4                       TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               1
# 9                       TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               2
# 14                      TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               3
# 49               SPECS                  DOBRA VODKA  1.75L               1
# 54               SPECS                  DOBRA VODKA  1.75L               2
# 59               SPECS                  DOBRA VODKA  1.75L               3
# 48               SPECS       MCCORMICK CHERRY VODKA 60  1L               1
# 53               SPECS       MCCORMICK CHERRY VODKA 60  1L               2
# 58               SPECS       MCCORMICK CHERRY VODKA 60  1L               3
# 45               SPECS                  TAAKA VODKA 80  1L               1
# 50               SPECS                  TAAKA VODKA 80  1L               2
# 55               SPECS                  TAAKA VODKA 80  1L               3
# 47               SPECS        TAAKA VODKA 80 BLUE PET 375M               1
# 52               SPECS        TAAKA VODKA 80 BLUE PET 375M               2
# 57               SPECS        TAAKA VODKA 80 BLUE PET 375M               3
# 46               SPECS            TAAKA VODKA 80 PET 1.75L               1
# 51               SPECS            TAAKA VODKA 80 PET 1.75L               2
# 56               SPECS            TAAKA VODKA 80 PET 1.75L               3
# 18    THE BARREL HOUSE                  DOBRA VODKA  1.75L               1
# 23    THE BARREL HOUSE                  DOBRA VODKA  1.75L               2
# 28    THE BARREL HOUSE                  DOBRA VODKA  1.75L               3
# 17    THE BARREL HOUSE                  TAAKA VODKA 80  1L               1
# 22    THE BARREL HOUSE                  TAAKA VODKA 80  1L               2
# 27    THE BARREL HOUSE                  TAAKA VODKA 80  1L               3
# 16    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 200M               1
# 21    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 200M               2
# 26    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 200M               3
# 15    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 375M               1
# 20    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 375M               2
# 25    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 375M               3
# 19    THE BARREL HOUSE            TAAKA VODKA 80 PET 1.75L               1
# 24    THE BARREL HOUSE            TAAKA VODKA 80 PET 1.75L               2
# 29    THE BARREL HOUSE            TAAKA VODKA 80 PET 1.75L               3
# 31  WESTERN BEV LIQ TX                  TAAKA VODKA 80  1L               1
# 36  WESTERN BEV LIQ TX                  TAAKA VODKA 80  1L               2
# 41  WESTERN BEV LIQ TX                  TAAKA VODKA 80  1L               3
# 30  WESTERN BEV LIQ TX        TAAKA VODKA 80 BLUE PET 375M               1
# 35  WESTERN BEV LIQ TX        TAAKA VODKA 80 BLUE PET 375M               2
# 40  WESTERN BEV LIQ TX        TAAKA VODKA 80 BLUE PET 375M               3
# 33  WESTERN BEV LIQ TX            TAAKA VODKA 80 PET 1.75L               1
# 38  WESTERN BEV LIQ TX            TAAKA VODKA 80 PET 1.75L               2
# 43  WESTERN BEV LIQ TX            TAAKA VODKA 80 PET 1.75L               3
# 32  WESTERN BEV LIQ TX        TEXAS SPIRIT VODKA 80  1.75L               1
# 37  WESTERN BEV LIQ TX        TEXAS SPIRIT VODKA 80  1.75L               2
# 42  WESTERN BEV LIQ TX        TEXAS SPIRIT VODKA 80  1.75L               3
# 34  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               1
# 39  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               2
# 44  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               3
#
#     P0 Non-Opt Price  P0 Non-Opt Demand  P0 Non-Opt Revenue  \
# 0              44.42                115                5103
# 5              44.30                107                4750
# 10             44.47                156                6959
# 1              58.56                  3                 189
# 6              58.56                 92                5394
# 11             58.56                 77                4536
# 3              47.03                 49                2298
# 8              47.03                 38                1782
# 13             47.03                 32                1488
# 2              51.18                  0                   5
# 7              51.18                  0                   5
# 12             51.18                  0                   5
# 4              46.97                 18                 865
# 9              46.97                 17                 780
# 14             46.97                 16                 759
# 49             49.27                  2                 112
# 54             47.03                  2                 107
# 59             47.03                  2                 109
# 48             45.74                  1                  65
# 53             45.74                  1                  66
# 58             45.74                  2                 111
# 45             44.30                 98                4348
# 50             44.30                 85                3780
# 55             44.30                 91                4016
# 47             58.56                  6                 370
# 52             58.56                  6                 335
# 57             58.56                  6                 352
# 46             47.03                 13                 594
# 51             47.03                  3                 119
# 56             47.03                 31                1472
# 18             47.03                  8                 361
# 23             49.27                  8                 376
# 28             47.03                  2                  91
# 17             46.89                 11                 519
# 22             44.30                 11                 508
# 27             47.63                 11                 546
# 16             62.80                  6                 378
# 21             62.80                  4                 278
# 26             62.80                  6                 378
# 15             58.56                 18                1055
# 20             58.56                 18                1058
# 25             58.56                 17                 972
# 19             47.03                  2                  73
# 24             47.03                  2                 105
# 29             47.03                  2                 108
# 31             44.30                 74                3275
# 36             44.30                 54                2378
# 41             44.30                 42                1854
# 30             58.56                  6                 368
# 35             58.56                  7                 423
# 40             58.56                  7                 411
# 33             47.03                 16                 760
# 38             47.03                 16                 773
# 43             47.03                 13                 606
# 32             51.18                  0                   5
# 37             51.18                  0                   5
# 42             51.18                  0                   5
# 34             46.97                 18                 865
# 39             46.97                 17                 780
# 44             46.97                 16                 759
#
#     P0 Non-Opt Chain Master Revenue  P0 Optimal Price  P0 Demand  P0 Revenue  \
# 0                              8461             44.30        115        5089
# 5                             12711             44.30        107        4750
# 10                            13747             44.30        156        6933
# 1                              8461             58.56          3         189
# 6                             12711             58.56         92        5394
# 11                            13747             58.56         77        4536
# 3                              8461             47.03         49        2298
# 8                             12711             47.03         38        1782
# 13                            13747             47.03         32        1488
# 2                              8461             46.03          0          10
# 7                             12711             46.03          0           9
# 12                            13747             46.03          0          10
# 4                              8461             46.97         18         865
# 9                             12711             46.97         17         780
# 14                            13747             46.97         16         759
# 49                             5488             49.27          2         112
# 54                             4407             49.27          2         112
# 59                             6060             49.27          2         114
# 48                             5488             45.69          1          65
# 53                             4407             45.69          1          67
# 58                             6060             56.61          2         137
# 45                             5488             44.30         98        4348
# 50                             4407             44.30         85        3780
# 55                             6060             44.30         91        4016
# 47                             5488             61.49          7         409
# 52                             4407             61.49          6         371
# 57                             6060             61.49          6         370
# 46                             5488             47.03         13         594
# 51                             4407             46.98          3         119
# 56                             6060             46.98         67        3164
# 18                             2386             49.27          8         378
# 23                             2325             49.27          8         376
# 28                             2095             46.98          2          96
# 17                             2386             47.04         11         521
# 22                             2325             46.77         11         536
# 27                             2095             46.89         11         538
# 16                             2386             62.93          6         379
# 21                             2325             62.93          4         278
# 26                             2095             62.93          6         379
# 15                             2386             58.56         18        1055
# 20                             2325             58.56         18        1058
# 25                             2095             58.56         17         972
# 19                             2386             49.38          2          76
# 24                             2325             49.38          2         111
# 29                             2095             47.03          2         108
# 31                             5273             43.80        176        7691
# 36                             4359             43.80        129        5630
# 41                             3634             44.30         42        1854
# 30                             5273             58.56          6         368
# 35                             4359             58.56          7         423
# 40                             3634             58.56          7         411
# 33                             5273             46.98         25        1154
# 38                             4359             46.98         25        1175
# 43                             3634             46.98         20         920
# 32                             5273             46.03          0          10
# 37                             4359             46.03          0           9
# 42                             3634             46.03          0          10
# 34                             5273             46.97         18         865
# 39                             4359             46.97         17         780
# 44                             3634             46.97         16         759
#
#     P0 Chain Master Revenue
# 0                      8451
# 5                     12715
# 10                    13726
# 1                      8451
# 6                     12715
# 11                    13726
# 3                      8451
# 8                     12715
# 13                    13726
# 2                      8451
# 7                     12715
# 12                    13726
# 4                      8451
# 9                     12715
# 14                    13726
# 49                     5528
# 54                     4448
# 59                     7801
# 48                     5528
# 53                     4448
# 58                     7801
# 45                     5528
# 50                     4448
# 55                     7801
# 47                     5528
# 52                     4448
# 57                     7801
# 46                     5528
# 51                     4448
# 56                     7801
# 18                     2409
# 23                     2359
# 28                     2092
# 17                     2409
# 22                     2359
# 27                     2092
# 16                     2409
# 21                     2359
# 26                     2092
# 15                     2409
# 20                     2359
# 25                     2092
# 19                     2409
# 24                     2359
# 29                     2092
# 31                    10088
# 36                     8017
# 41                     3953
# 30                    10088
# 35                     8017
# 40                     3953
# 33                    10088
# 38                     8017
# 43                     3953
# 32                    10088
# 37                     8017
# 42                     3953
# 34                    10088
# 39                     8017
# 44                     3953

# %% [markdown]
# ### P0+Sim Optimizer

# %%
full_opt[outputColsOptP0Sim]
# Out:
#           Chain Master                             Product  Period to Last  \
# 0                                       TAAKA VODKA 80  1L               1
# 5                                       TAAKA VODKA 80  1L               2
# 10                                      TAAKA VODKA 80  1L               3
# 1                             TAAKA VODKA 80 BLUE PET 375M               1
# 6                             TAAKA VODKA 80 BLUE PET 375M               2
# 11                            TAAKA VODKA 80 BLUE PET 375M               3
# 3                                 TAAKA VODKA 80 PET 1.75L               1
# 8                                 TAAKA VODKA 80 PET 1.75L               2
# 13                                TAAKA VODKA 80 PET 1.75L               3
# 2                             TEXAS SPIRIT VODKA 80  1.75L               1
# 7                             TEXAS SPIRIT VODKA 80  1.75L               2
# 12                            TEXAS SPIRIT VODKA 80  1.75L               3
# 4                       TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               1
# 9                       TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               2
# 14                      TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               3
# 49               SPECS                  DOBRA VODKA  1.75L               1
# 54               SPECS                  DOBRA VODKA  1.75L               2
# 59               SPECS                  DOBRA VODKA  1.75L               3
# 48               SPECS       MCCORMICK CHERRY VODKA 60  1L               1
# 53               SPECS       MCCORMICK CHERRY VODKA 60  1L               2
# 58               SPECS       MCCORMICK CHERRY VODKA 60  1L               3
# 45               SPECS                  TAAKA VODKA 80  1L               1
# 50               SPECS                  TAAKA VODKA 80  1L               2
# 55               SPECS                  TAAKA VODKA 80  1L               3
# 47               SPECS        TAAKA VODKA 80 BLUE PET 375M               1
# 52               SPECS        TAAKA VODKA 80 BLUE PET 375M               2
# 57               SPECS        TAAKA VODKA 80 BLUE PET 375M               3
# 46               SPECS            TAAKA VODKA 80 PET 1.75L               1
# 51               SPECS            TAAKA VODKA 80 PET 1.75L               2
# 56               SPECS            TAAKA VODKA 80 PET 1.75L               3
# 18    THE BARREL HOUSE                  DOBRA VODKA  1.75L               1
# 23    THE BARREL HOUSE                  DOBRA VODKA  1.75L               2
# 28    THE BARREL HOUSE                  DOBRA VODKA  1.75L               3
# 17    THE BARREL HOUSE                  TAAKA VODKA 80  1L               1
# 22    THE BARREL HOUSE                  TAAKA VODKA 80  1L               2
# 27    THE BARREL HOUSE                  TAAKA VODKA 80  1L               3
# 16    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 200M               1
# 21    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 200M               2
# 26    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 200M               3
# 15    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 375M               1
# 20    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 375M               2
# 25    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 375M               3
# 19    THE BARREL HOUSE            TAAKA VODKA 80 PET 1.75L               1
# 24    THE BARREL HOUSE            TAAKA VODKA 80 PET 1.75L               2
# 29    THE BARREL HOUSE            TAAKA VODKA 80 PET 1.75L               3
# 31  WESTERN BEV LIQ TX                  TAAKA VODKA 80  1L               1
# 36  WESTERN BEV LIQ TX                  TAAKA VODKA 80  1L               2
# 41  WESTERN BEV LIQ TX                  TAAKA VODKA 80  1L               3
# 30  WESTERN BEV LIQ TX        TAAKA VODKA 80 BLUE PET 375M               1
# 35  WESTERN BEV LIQ TX        TAAKA VODKA 80 BLUE PET 375M               2
# 40  WESTERN BEV LIQ TX        TAAKA VODKA 80 BLUE PET 375M               3
# 33  WESTERN BEV LIQ TX            TAAKA VODKA 80 PET 1.75L               1
# 38  WESTERN BEV LIQ TX            TAAKA VODKA 80 PET 1.75L               2
# 43  WESTERN BEV LIQ TX            TAAKA VODKA 80 PET 1.75L               3
# 32  WESTERN BEV LIQ TX        TEXAS SPIRIT VODKA 80  1.75L               1
# 37  WESTERN BEV LIQ TX        TEXAS SPIRIT VODKA 80  1.75L               2
# 42  WESTERN BEV LIQ TX        TEXAS SPIRIT VODKA 80  1.75L               3
# 34  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               1
# 39  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               2
# 44  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               3
#
#     P0+Sim Non-Opt Price  P0+Sim Non-Opt Demand  P0+Sim Non-Opt Revenue  \
# 0                  44.42                    115                    5103
# 5                  44.30                    107                    4750
# 10                 44.47                    154                    6843
# 1                  58.56                     55                    3244
# 6                  58.56                     63                    3708
# 11                 58.56                     81                    4751
# 3                  47.03                     50                    2350
# 8                  47.03                     37                    1729
# 13                 47.03                     38                    1771
# 2                  51.18                      0                       5
# 7                  51.18                      0                       5
# 12                 51.18                      0                       5
# 4                  46.97                     19                     879
# 9                  46.97                     17                     782
# 14                 46.97                     16                     767
# 49                 49.27                      2                     108
# 54                 47.03                      2                     103
# 59                 47.03                      2                     106
# 48                 45.74                      2                     114
# 53                 45.74                      2                     114
# 58                 45.74                      2                     114
# 45                 44.30                     98                    4348
# 50                 44.30                     96                    4233
# 55                 44.30                     97                    4313
# 47                 58.56                      5                     283
# 52                 58.56                      6                     336
# 57                 58.56                      3                     162
# 46                 47.03                     10                     466
# 51                 47.03                      2                     108
# 56                 47.03                      2                     108
# 18                 47.03                      7                     349
# 23                 49.27                      8                     371
# 28                 47.03                      7                     349
# 17                 46.89                     11                     512
# 22                 44.30                      9                     401
# 27                 47.63                     14                     649
# 16                 62.80                      5                     328
# 21                 62.80                      5                     304
# 26                 62.80                      5                     297
# 15                 58.56                     26                    1522
# 20                 58.56                     21                    1220
# 25                 58.56                     20                    1178
# 19                 47.03                      2                      82
# 24                 47.03                      2                     105
# 29                 47.03                      2                     108
# 31                 44.30                     78                    3444
# 36                 44.30                     89                    3959
# 41                 44.30                     42                    1852
# 30                 58.56                      6                     349
# 35                 58.56                      6                     378
# 40                 58.56                     54                    3177
# 33                 47.03                     24                    1115
# 38                 47.03                     19                     899
# 43                 47.03                     41                    1913
# 32                 51.18                      0                       5
# 37                 51.18                      0                       5
# 42                 51.18                      0                       5
# 34                 46.97                     16                     746
# 39                 46.97                     16                     770
# 44                 46.97                     16                     746
#
#     P0+Sim Non-Opt Chain Master Revenue  P0+Sim Optimal Price  P0+Sim Demand  \
# 0                                 11581                 44.30            115
# 5                                 10974                 44.30            107
# 10                                14138                 44.30            154
# 1                                 11581                 58.56             71
# 6                                 10974                 58.56             68
# 11                                14138                 58.56             79
# 3                                 11581                 47.03             50
# 8                                 10974                 46.98             39
# 13                                14138                 47.03             32
# 2                                 11581                 46.03              0
# 7                                 10974                 46.03              0
# 12                                14138                 46.03              0
# 4                                 11581                 46.97             18
# 9                                 10974                 46.97             16
# 14                                14138                 46.97             15
# 49                                 5319                 46.98              2
# 54                                 4894                 46.98              2
# 59                                 4803                 49.27              2
# 48                                 5319                 45.69              2
# 53                                 4894                 45.69              2
# 58                                 4803                 56.61              2
# 45                                 5319                 44.30             98
# 50                                 4894                 44.30             96
# 55                                 4803                 44.30             97
# 47                                 5319                 55.63        9531083
# 52                                 4894                 55.63        9869132
# 57                                 4803                 61.49              3
# 46                                 5319                 47.03          12816
# 51                                 4894                 47.03              2
# 56                                 4803                 47.03              2
# 18                                 2793                 46.98              7
# 23                                 2400                 46.98              8
# 28                                 2581                 46.98              7
# 17                                 2793                 47.04             49
# 22                                 2400                 46.77             53
# 27                                 2581                 46.89             12
# 16                                 2793                 62.80              5
# 21                                 2400                 62.80              5
# 26                                 2581                 62.93              5
# 15                                 2793                 58.56             26
# 20                                 2400                 58.56             22
# 25                                 2581                 58.56             21
# 19                                 2793                 49.38              2
# 24                                 2400                 49.38              2
# 29                                 2581                 47.03              2
# 31                                 5658                 43.80            135
# 36                                 6011                 43.80            153
# 41                                 7693                 43.80             42
# 30                                 5658                 58.56              6
# 35                                 6011                 58.56              6
# 40                                 7693                 58.56             93
# 33                                 5658                 47.03             32
# 38                                 6011                 47.03             32
# 43                                 7693                 47.03             41
# 32                                 5658                 46.03              0
# 37                                 6011                 51.18              0
# 42                                 7693                 51.18              0
# 34                                 5658                 46.97             16
# 39                                 6011                 46.97             15
# 44                                 7693                 46.97             16
#
#     P0+Sim Revenue  P0+Sim Chain Master Revenue
# 0             5089                        12449
# 5             4750                        11308
# 10            6817                        13698
# 1             4156                        12449
# 6             3967                        11308
# 11            4651                        13698
# 3             2350                        12449
# 8             1815                        11308
# 13            1501                        13698
# 2                6                        12449
# 7                6                        11308
# 12               6                        13698
# 4              848                        12449
# 9              771                        11308
# 14             722                        13698
# 49             103                    530821407
# 54             103                    549024395
# 59             111                         4843
# 48             114                    530821407
# 53             114                    549024395
# 58             141                         4843
# 45            4348                    530821407
# 50            4233                    549024395
# 55            4313                         4843
# 47       530214128                    530821407
# 52       549019838                    549024395
# 57             170                         4843
# 46          602714                    530821407
# 51             108                    549024395
# 56             108                         4843
# 18             349                         4619
# 23             354                         4505
# 28             349                         2530
# 17            2313                         4619
# 22            2464                         4505
# 27             558                         2530
# 16             328                         4619
# 21             304                         4505
# 26             298                         2530
# 15            1542                         4619
# 20            1272                         4505
# 25            1217                         2530
# 19              86                         4619
# 24             111                         4505
# 29             108                         2530
# 31            5893                         8483
# 36            6714                         9286
# 41            1831                         9945
# 30             349                         8483
# 35             378                         9286
# 40            5449                         9945
# 33            1487                         8483
# 38            1487                         9286
# 43            1913                         9945
# 32               9                         8483
# 37               6                         9286
# 42               6                         9945
# 34             746                         8483
# 39             701                         9286
# 44             746                         9945

# %% [markdown]
# ### Naive

# %%
full_opt[outputColsOptNaive]
# Out:
#           Chain Master                             Product  Period to Last  \
# 0                                       TAAKA VODKA 80  1L               1
# 5                                       TAAKA VODKA 80  1L               2
# 10                                      TAAKA VODKA 80  1L               3
# 1                             TAAKA VODKA 80 BLUE PET 375M               1
# 6                             TAAKA VODKA 80 BLUE PET 375M               2
# 11                            TAAKA VODKA 80 BLUE PET 375M               3
# 3                                 TAAKA VODKA 80 PET 1.75L               1
# 8                                 TAAKA VODKA 80 PET 1.75L               2
# 13                                TAAKA VODKA 80 PET 1.75L               3
# 2                             TEXAS SPIRIT VODKA 80  1.75L               1
# 7                             TEXAS SPIRIT VODKA 80  1.75L               2
# 12                            TEXAS SPIRIT VODKA 80  1.75L               3
# 4                       TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               1
# 9                       TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               2
# 14                      TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               3
# 49               SPECS                  DOBRA VODKA  1.75L               1
# 54               SPECS                  DOBRA VODKA  1.75L               2
# 59               SPECS                  DOBRA VODKA  1.75L               3
# 48               SPECS       MCCORMICK CHERRY VODKA 60  1L               1
# 53               SPECS       MCCORMICK CHERRY VODKA 60  1L               2
# 58               SPECS       MCCORMICK CHERRY VODKA 60  1L               3
# 45               SPECS                  TAAKA VODKA 80  1L               1
# 50               SPECS                  TAAKA VODKA 80  1L               2
# 55               SPECS                  TAAKA VODKA 80  1L               3
# 47               SPECS        TAAKA VODKA 80 BLUE PET 375M               1
# 52               SPECS        TAAKA VODKA 80 BLUE PET 375M               2
# 57               SPECS        TAAKA VODKA 80 BLUE PET 375M               3
# 46               SPECS            TAAKA VODKA 80 PET 1.75L               1
# 51               SPECS            TAAKA VODKA 80 PET 1.75L               2
# 56               SPECS            TAAKA VODKA 80 PET 1.75L               3
# 18    THE BARREL HOUSE                  DOBRA VODKA  1.75L               1
# 23    THE BARREL HOUSE                  DOBRA VODKA  1.75L               2
# 28    THE BARREL HOUSE                  DOBRA VODKA  1.75L               3
# 17    THE BARREL HOUSE                  TAAKA VODKA 80  1L               1
# 22    THE BARREL HOUSE                  TAAKA VODKA 80  1L               2
# 27    THE BARREL HOUSE                  TAAKA VODKA 80  1L               3
# 16    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 200M               1
# 21    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 200M               2
# 26    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 200M               3
# 15    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 375M               1
# 20    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 375M               2
# 25    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 375M               3
# 19    THE BARREL HOUSE            TAAKA VODKA 80 PET 1.75L               1
# 24    THE BARREL HOUSE            TAAKA VODKA 80 PET 1.75L               2
# 29    THE BARREL HOUSE            TAAKA VODKA 80 PET 1.75L               3
# 31  WESTERN BEV LIQ TX                  TAAKA VODKA 80  1L               1
# 36  WESTERN BEV LIQ TX                  TAAKA VODKA 80  1L               2
# 41  WESTERN BEV LIQ TX                  TAAKA VODKA 80  1L               3
# 30  WESTERN BEV LIQ TX        TAAKA VODKA 80 BLUE PET 375M               1
# 35  WESTERN BEV LIQ TX        TAAKA VODKA 80 BLUE PET 375M               2
# 40  WESTERN BEV LIQ TX        TAAKA VODKA 80 BLUE PET 375M               3
# 33  WESTERN BEV LIQ TX            TAAKA VODKA 80 PET 1.75L               1
# 38  WESTERN BEV LIQ TX            TAAKA VODKA 80 PET 1.75L               2
# 43  WESTERN BEV LIQ TX            TAAKA VODKA 80 PET 1.75L               3
# 32  WESTERN BEV LIQ TX        TEXAS SPIRIT VODKA 80  1.75L               1
# 37  WESTERN BEV LIQ TX        TEXAS SPIRIT VODKA 80  1.75L               2
# 42  WESTERN BEV LIQ TX        TEXAS SPIRIT VODKA 80  1.75L               3
# 34  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               1
# 39  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               2
# 44  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               3
#
#     Actual Price  Actual Demand  Actual Revenue  Actual Chain Master Revenue  \
# 0      44.420127         172.90         7680.24                     15253.50
# 5      44.300752         195.51         8661.24                     15806.82
# 10     44.467025         186.20         8279.76                     16314.54
# 1      58.560000          88.00         5153.28                     15253.50
# 6      58.560000          76.00         4450.56                     15806.82
# 11     58.560000          94.00         5504.64                     16314.54
# 3      47.025641          33.93         1595.58                     15253.50
# 8      47.025641          38.61         1815.66                     15806.82
# 13     47.025641          38.61         1815.66                     16314.54
# 2      51.179487           0.00            0.00                     15253.50
# 7      51.179487           0.00            0.00                     15806.82
# 12     51.179487           0.00            0.00                     16314.54
# 4      46.974359          17.55          824.40                     15253.50
# 9      46.974359          18.72          879.36                     15806.82
# 14     46.974359          15.21          714.48                     16314.54
# 49     49.268571           0.00            0.00                      5754.06
# 54     47.025641           1.17           55.02                      6202.38
# 59     47.025641           1.17           55.02                      5620.26
# 48     45.744361           1.33           60.84                      5754.06
# 53     45.744361           1.33           60.84                      6202.38
# 58     45.744361           1.33           60.84                      5620.26
# 45     44.300752         113.05         5008.20                      5754.06
# 50     44.300752         117.04         5184.96                      6202.38
# 55     44.300752         103.74         4595.76                      5620.26
# 47     58.560000           7.00          409.92                      5754.06
# 52     58.560000           6.00          351.36                      6202.38
# 57     58.560000           8.00          468.48                      5620.26
# 46     47.025641           5.85          275.10                      5754.06
# 51     47.025641          11.70          550.20                      6202.38
# 56     47.025641           9.36          440.16                      5620.26
# 18     47.025641           1.17           55.02                      2204.40
# 23     49.268571           0.00            0.00                      2016.36
# 28     47.025641           1.17           55.02                      2919.36
# 17     46.887218           7.98          374.16                      2204.40
# 22     44.300752           6.65          294.60                      2016.36
# 27     47.626208           9.31          443.40                      2919.36
# 16     62.803738           5.35          336.00                      2204.40
# 21     62.803738           6.42          403.20                      2016.36
# 26     62.803738           6.42          403.20                      2919.36
# 15     58.560000          18.00         1054.08                      2204.40
# 20     58.560000          15.00          878.40                      2016.36
# 25     58.560000          26.00         1522.56                      2919.36
# 19     47.025641           8.19          385.14                      2204.40
# 24     47.025641           9.36          440.16                      2016.36
# 29     47.025641          10.53          495.18                      2919.36
# 31     44.300752          51.87         2297.88                      7746.90
# 36     44.300752          71.82         3181.68                      8107.14
# 41     44.300752          73.15         3240.60                      8349.00
# 30     58.560000          63.00         3689.28                      7746.90
# 35     58.560000          55.00         3220.80                      8107.14
# 40     58.560000          60.00         3513.60                      8349.00
# 33     47.025641          19.89          935.34                      7746.90
# 38     47.025641          17.55          825.30                      8107.14
# 43     47.025641          18.72          880.32                      8349.00
# 32     51.179487           0.00            0.00                      7746.90
# 37     51.179487           0.00            0.00                      8107.14
# 42     51.179487           0.00            0.00                      8349.00
# 34     46.974359          17.55          824.40                      7746.90
# 39     46.974359          18.72          879.36                      8107.14
# 44     46.974359          15.21          714.48                      8349.00
#
#     Naive Prices  Naive Demand  Naive Revenue  Naive Chain Master Revenue
# 0      44.420127    199.948711    8881.747177                15449.881619
# 5      44.300752    200.002841    8860.276255                16474.881017
# 10     44.467025    200.173247    8901.108716                14754.039668
# 1      58.560000     76.000000    4450.560000                15449.881619
# 6      58.560000     94.000000    5504.640000                16474.881017
# 11     58.560000     64.000000    3747.840000                14754.039668
# 3      47.025641     28.587470    1344.344096                15449.881619
# 8      47.025641     28.465244    1338.596341                16474.881017
# 13     47.025641     28.340000    1332.706667                14754.039668
# 2      51.179487      0.000000       0.000000                15449.881619
# 7      51.179487      0.000000       0.000000                16474.881017
# 12     51.179487      0.000000       0.000000                14754.039668
# 4      46.974359     16.460690     773.230345                15449.881619
# 9      46.974359     16.421053     771.368421                16474.881017
# 14     46.974359     16.442679     772.384286                14754.039668
# 49     49.268571      2.268659     111.773565                 5834.722481
# 54     47.025641      2.282222     107.322963                 5235.896134
# 59     47.025641      2.296125     107.976750                 7227.427120
# 48     45.744361      1.330000      60.840000                 5834.722481
# 53     45.744361      1.330000      60.840000                 5235.896134
# 58     45.744361      0.000000       0.000000                 7227.427120
# 45     44.300752    117.040000    5184.960000                 5834.722481
# 50     44.300752    103.740000    4595.760000                 5235.896134
# 55     44.300752    150.175062    6652.868148                 7227.427120
# 47     58.560000      3.801205     222.598554                 5834.722481
# 52     58.560000      3.774390     221.028293                 5235.896134
# 57     58.560000      3.722222     217.973333                 7227.427120
# 46     47.025641      5.413012     254.550361                 5834.722481
# 51     47.025641      5.336341     250.944878                 5235.896134
# 56     47.025641      5.286667     248.608889                 7227.427120
# 18     47.025641      2.974337     139.870120                 2044.938906
# 23     49.268571      1.170000      57.644229                 2584.075791
# 28     47.025641      1.170000      55.020000                 1954.785755
# 17     46.887218      7.452586     349.431034                 2044.938906
# 22     44.300752      7.466667     330.778947                 2584.075791
# 27     47.626208      7.433750     354.041327                 1954.785755
# 16     62.803738      6.403086     402.137751                 2044.938906
# 21     62.803738      6.402789     402.119115                 2584.075791
# 26     62.803738      6.402482     402.099813                 1954.785755
# 15     58.560000     15.000000     878.400000                 2044.938906
# 20     58.560000     26.000000    1522.560000                 2584.075791
# 25     58.560000     15.000000     878.400000                 1954.785755
# 19     47.025641      5.850000     275.100000                 2044.938906
# 24     47.025641      5.762250     270.973500                 2584.075791
# 29     47.025641      5.640000     265.224615                 1954.785755
# 31     44.300752     71.820000    3181.680000                 8001.010345
# 36     44.300752     73.150000    3240.600000                 8405.888421
# 41     44.300752     58.520000    2592.480000                 6780.781323
# 30     58.560000     55.000000    3220.800000                 8001.010345
# 35     58.560000     60.000000    3513.600000                 8405.888421
# 40     58.560000     42.000000    2459.520000                 6780.781323
# 33     47.025641     17.550000     825.300000                 8001.010345
# 38     47.025641     18.720000     880.320000                 8405.888421
# 43     47.025641     20.337778     956.397037                 6780.781323
# 32     51.179487      0.000000       0.000000                 8001.010345
# 37     51.179487      0.000000       0.000000                 8405.888421
# 42     51.179487      0.000000       0.000000                 6780.781323
# 34     46.974359     16.460690     773.230345                 8001.010345
# 39     46.974359     16.421053     771.368421                 8405.888421
# 44     46.974359     16.442679     772.384286                 6780.781323
