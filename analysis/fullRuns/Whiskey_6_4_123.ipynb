# %% [markdown]
# # Init

# %%
# %load_ext autoreload
# %autoreload 2

# %%
print("CURRENT FOLDER:")
# %pwd
# Out:
# CURRENT FOLDER:
# 'c:\\max\\Google Drive Max\\Max Shared\\Master Data Science\\2020-05 Capstone A\\msds_capstone\\analysis\\fullRuns'

# %%
import os
import glob
import sys
sys.path.append(os.environ['DEV_AUTOTS'])
sys.path.append(os.environ['CAPSTONE_PYTHON_SOURCE'])
folder = os.environ['CAPSTONE_DATA']

# %%
## Sourcing the .py with all the code##
t='"'+os.environ['CAPSTONE_PYTHON_SOURCE']+'\\fullRun\\fullRun.py'+'"'
# %run -i $t
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# Running Auto Timeseries version: 0.0.24

# %% [markdown]
# # Parameters

# %%
#Parameters

ProdCats = ['SUP PREM WHISKEY']
TOP_PRODUCTS = 6  # How many products to consider in the category
TOP_SIMILAR = 4  # Get TOP_SIMILAR most similar products
RUN_PERIODS = [1,2,3] # this will run AutoTS and Optimzer for speicfic periods (1 = last, 2 = second to last)

CV_NUM = 10         # number of Cross Valudations  10
OPT_CALLS = 100     # number of calls for the optimizer process   100
OPT_RND_STARTS = 20 # number of random calls for the optimizer process  20

LOG_TRANSFORM = True # Take log of 9L cases to smooth out peaks and valleys
ZERO_ADDER = 0.1 

RESAMPLE_FREQ = 'M'


# Pricing changes every 4 weeks
if RESAMPLE_FREQ == 'M':    FORECAST_PERIOD = 1 #last 4 months as test 
if RESAMPLE_FREQ == 'W':    FORECAST_PERIOD = 4 
if RESAMPLE_FREQ == '2W':   FORECAST_PERIOD = 2 

# Seasonal Period
if RESAMPLE_FREQ == 'M':    SEASONAL_PERIOD = 12  # Yearly
if RESAMPLE_FREQ == 'W':    SEASONAL_PERIOD = 13 # Quarterly (we can also take yearly = 52, but SARIMAX becomes too slow)
if RESAMPLE_FREQ == '2W':   SEASONAL_PERIOD = 13 # This becomes problematic --> for quarterly, should we take 6 biweekly periods or 7 bi-weekly periods. Instead I just took half yearly period  

COL_TIME = 'WeekDate'
COL_PREDS = ['9L Cases'] #Demand
COL_PRICE= ['Dollar Sales per 9L Case'] #Price

# %% [markdown]
# # Full Run

# %%
dataRaw = loadDataset(version=4)
ProdCat = 'SUP PREM WHISKEY' #'ECONOMY VODKA'
ChainMasters =  [''] +  dataRaw['Chain Master'].unique().tolist() 
display(ChainMasters,ProdCats)
# Out:
# ['', 'THE BARREL HOUSE', 'WESTERN BEV LIQ TX', 'SPECS']
# ['SUP PREM WHISKEY']

# %%
(full_models,full_opt,full_summary,full_chain_summary)  = fullRun(ProdCat = ProdCat
                                                           ,ChainMasters = ChainMasters
                                                           ,dataRaw = dataRaw
                                                           ,savePKL=True
                                                           ,saveXLS=True)
# Out:
# ==================================================
# Parameters being used...
# ==================================================
# TOP_PRODUCTS = 6
# TOP_SIMILAR = 4
# RUN_PERIODS = [1, 2, 3]
# ProdCat: SUP PREM WHISKEY
# ChainMasters: ['', 'THE BARREL HOUSE', 'WESTERN BEV LIQ TX', 'SPECS']
#
#
# ========================== (2020-09-02 16:59:50.672706)
# ===== Products List  =====
# ==== SUP PREM WHISKEY ====
# ============  ============
# ==========================
#
#
#
# ========================== (2020-09-02 16:59:58.779935)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 1 ============
# ==========================
#
#
#
# ================== (2020-09-02 16:59:58.779935)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS BLK WHSKY SQ 375M', '4': 'GENTLEMAN JACK WHSKY OL 750M', '5': 'JACK DANIELS TENN HNY WHSKY  750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2', '5', '4']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '5', '4']
# % of weeks without a purchase: 1.1904761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1', '5', '4']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY SQ 375M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2', '1', '5']
# % of weeks without a purchase: 44.047619047619044
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '2', '1', '5']
# % of weeks without a purchase: 3.571428571428571
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['5', '0', '2', '1', '4']
# % of weeks without a purchase: 1.1904761904761905
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY SQ 375M
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: JACK DANIELS TENN HNY WHSKY  750M
#
#
# ===================== (2020-09-02 17:01:34.833903)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#       lb_stat  lb_pvalue
# 12  17.529696   0.130735
# 24  31.092108   0.151145
# 48  54.922995   0.228882
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12  115.750529  4.333814e-19
# 24  214.169023  1.845834e-32
# 48  308.098428  1.176533e-39
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   76.707883  1.745018e-11
# 24  131.122583  9.711501e-17
# 48  214.957410  5.416649e-23
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  236.849902  7.504140e-44
# 24  313.152234  3.733315e-52
# 48  457.992618  2.867236e-68
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   49.544022  1.679761e-06
# 24   97.459679  8.118215e-11
# 48  147.898014  4.125410e-12
#
# Is Data White Noise: False
#        lb_stat  lb_pvalue
# 12   49.490158   0.000002
# 24   66.726873   0.000007
# 48  103.663568   0.000006
#
# Is Data White Noise: False
#
#
# ==================== (2020-09-02 17:01:34.872901)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (83, 7) (1, 7)
# (83, 7) (1, 7)
# (83, 7) (1, 7)
# (83, 7) (1, 7)
# (83, 7) (1, 7)
# (83, 7) (1, 7)
#
#
# =============== (2020-09-02 17:01:34.881902)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.043169         []
# 1  1      last   0.324455         []
# 2  2      mean   0.427990         []
# 3  3      mean   0.798321         []
# 4  4      mean   0.375053         []
# 5  5      mean   0.331289         []
#
#                                            All RMSEs  \
# 0  [[0.07143315389555474, 0.11332894033533458, 0....
# 1  [[0.3244545696539494, 0.4963154566538675, 0.34...
# 2  [[0.6704496090247218, 0.719929333484661, 0.427...
# 3  [[1.158356517777329, 1.1898741527817909, 0.798...
# 4  [[0.709250053526431, 0.5987185687692762, 0.375...
# 5  [[0.4266712461186655, 0.5029048428928397, 0.33...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 4  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 5  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-02 17:01:35.753903)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:  7.8min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-02 17:09:22.784954)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:  7.6min finished
# =================== (2020-09-02 17:17:01.842194)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-02 17:17:01.848194)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 1 ============
# ==========================
#
#
#
# =========================== (2020-09-02 17:17:01.848194)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ============  =============
# ============ 1 ============
# ===========================
#
#
#
# ================== (2020-09-02 17:17:01.850193)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS BLK WHSKY SQ 375M', '4': 'GENTLEMAN JACK WHSKY OL 750M', '5': 'JACK DANIELS TENN HNY WHSKY  750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2', '5', '4']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '5', '4']
# % of weeks without a purchase: 1.1904761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1', '5', '4']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY SQ 375M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2', '1', '5']
# % of weeks without a purchase: 44.047619047619044
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '2', '1', '5']
# % of weeks without a purchase: 3.571428571428571
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['5', '0', '2', '1', '4']
# % of weeks without a purchase: 1.1904761904761905
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY SQ 375M
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: JACK DANIELS TENN HNY WHSKY  750M
#
#
# ==================== (2020-09-02 17:18:13.817225)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (83, 7) (1, 7)
# (83, 7) (1, 7)
# (83, 7) (1, 7)
# (83, 7) (1, 7)
# (83, 7) (1, 7)
# (83, 7) (1, 7)
#
#
# ======================== (2020-09-02 17:18:13.826223)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-02 17:18:13.849224)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False, False, False, False]
#
#
# =============== (2020-09-02 17:18:13.852224)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-02 17:18:13.862225)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-02 17:18:13.864226)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-02 17:18:13.866230)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-02 17:18:14.094224)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-02 17:18:14.100222)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-02 17:19:31.436091)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-02 17:19:31.626090)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-02 17:19:31.627091)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-02 17:19:31.812091)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-02 17:19:31.820090)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-02 17:20:46.564969)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-02 17:20:46.746967)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-02 17:20:46.752967)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 2 ============
# ==========================
#
#
#
# ================== (2020-09-02 17:20:46.752967)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS BLK WHSKY SQ 375M', '4': 'GENTLEMAN JACK WHSKY OL 750M', '5': 'JACK DANIELS TENN HNY WHSKY  750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2', '5', '4']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '5', '4']
# % of weeks without a purchase: 1.2048192771084338
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1', '5', '4']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY SQ 375M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2', '1', '5']
# % of weeks without a purchase: 44.57831325301205
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '2', '1', '5']
# % of weeks without a purchase: 3.614457831325301
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['5', '0', '2', '1', '4']
# % of weeks without a purchase: 1.2048192771084338
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY SQ 375M
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: JACK DANIELS TENN HNY WHSKY  750M
#
#
# ===================== (2020-09-02 17:21:53.680832)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#       lb_stat  lb_pvalue
# 12  17.074759   0.146807
# 24  30.689164   0.162949
# 48  53.509495   0.271059
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12  113.741522  1.085921e-18
# 24  210.737801  8.608130e-32
# 48  298.546482  6.801454e-38
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   73.433730  7.257343e-11
# 24  127.792143  3.888372e-16
# 48  208.580703  6.624266e-22
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  233.654157  3.467423e-43
# 24  301.956845  6.767463e-50
# 48  453.324573  2.340339e-67
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   48.137860  2.957627e-06
# 24   92.192775  6.231213e-10
# 48  138.240334  1.125182e-10
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  47.318792   0.000004
# 24  63.733683   0.000019
# 48  96.796590   0.000039
#
# Is Data White Noise: False
#
#
# ==================== (2020-09-02 17:21:53.708834)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (82, 7) (1, 7)
# (82, 7) (1, 7)
# (82, 7) (1, 7)
# (82, 7) (1, 7)
# (82, 7) (1, 7)
# (82, 7) (1, 7)
#
#
# =============== (2020-09-02 17:21:53.711833)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.021557         []
# 1  1      mean   0.323943         []
# 2  2      mean   0.373199         []
# 3  3      mean   0.669609         []
# 4  4      mean   0.351197         []
# 5  5      mean   0.292008         []
#
#                                            All RMSEs  \
# 0  [[0.057546587491533165, 0.09126460007014617, 0...
# 1  [[0.3342880201030623, 0.4694144778845947, 0.32...
# 2  [[0.6160411345584191, 0.6054018321634664, 0.37...
# 3  [[1.1334719691929973, 1.0359040362506735, 0.66...
# 4  [[0.7597766030869607, 0.5171871911658599, 0.35...
# 5  [[0.36197066832875546, 0.45975278514505347, 0....
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 4  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 5  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-02 17:21:54.306861)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:  6.5min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-02 17:28:25.014258)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:  7.4min finished
# =================== (2020-09-02 17:35:51.787847)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-02 17:35:51.795848)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 2 ============
# ==========================
#
#
#
# =========================== (2020-09-02 17:35:51.796847)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ============  =============
# ============ 2 ============
# ===========================
#
#
#
# ================== (2020-09-02 17:35:51.798849)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS BLK WHSKY SQ 375M', '4': 'GENTLEMAN JACK WHSKY OL 750M', '5': 'JACK DANIELS TENN HNY WHSKY  750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2', '5', '4']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '5', '4']
# % of weeks without a purchase: 1.2048192771084338
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1', '5', '4']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY SQ 375M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2', '1', '5']
# % of weeks without a purchase: 44.57831325301205
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '2', '1', '5']
# % of weeks without a purchase: 3.614457831325301
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['5', '0', '2', '1', '4']
# % of weeks without a purchase: 1.2048192771084338
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY SQ 375M
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: JACK DANIELS TENN HNY WHSKY  750M
#
#
# ==================== (2020-09-02 17:37:16.308941)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (82, 7) (1, 7)
# (82, 7) (1, 7)
# (82, 7) (1, 7)
# (82, 7) (1, 7)
# (82, 7) (1, 7)
# (82, 7) (1, 7)
#
#
# ======================== (2020-09-02 17:37:16.320941)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-02 17:37:16.349940)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False, False, False, False]
#
#
# =============== (2020-09-02 17:37:16.353941)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-02 17:37:16.370938)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-02 17:37:16.371941)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-02 17:37:16.373937)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-02 17:37:17.082375)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-02 17:37:17.089377)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-02 17:39:08.552687)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-02 17:39:08.790686)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-02 17:39:08.792689)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-02 17:39:08.991685)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-02 17:39:08.998684)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-02 17:40:50.149911)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-02 17:40:50.381911)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-02 17:40:50.392910)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 3 ============
# ==========================
#
#
#
# ================== (2020-09-02 17:40:50.393907)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS BLK WHSKY SQ 375M', '4': 'GENTLEMAN JACK WHSKY OL 750M', '5': 'JACK DANIELS TENN HNY WHSKY  750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2', '5', '4']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '5', '4']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1', '5', '4']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY SQ 375M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2', '1', '5']
# % of weeks without a purchase: 45.1219512195122
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '2', '1', '5']
# % of weeks without a purchase: 3.6585365853658534
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['5', '0', '2', '1', '4']
# % of weeks without a purchase: 1.2195121951219512
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY SQ 375M
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: JACK DANIELS TENN HNY WHSKY  750M
#
#
# ===================== (2020-09-02 17:42:24.958407)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#       lb_stat  lb_pvalue
# 12  16.492825   0.169692
# 24  29.613691   0.197887
# 48  52.235849   0.312831
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12  111.729571  2.720557e-18
# 24  207.460783  3.736074e-31
# 48  291.621010  1.270149e-36
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   72.023277  1.337193e-10
# 24  126.557635  6.490946e-16
# 48  206.128607  1.725436e-21
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  227.003218  8.357786e-42
# 24  289.400873  2.267177e-47
# 48  442.433742  3.108030e-65
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   47.219751  4.270383e-06
# 24   91.282625  8.832443e-10
# 48  138.156566  1.157395e-10
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  46.707130   0.000005
# 24  62.887857   0.000025
# 48  95.530579   0.000054
#
# Is Data White Noise: False
#
#
# ==================== (2020-09-02 17:42:25.001402)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (81, 7) (1, 7)
# (81, 7) (1, 7)
# (81, 7) (1, 7)
# (81, 7) (1, 7)
# (81, 7) (1, 7)
# (81, 7) (1, 7)
#
#
# =============== (2020-09-02 17:42:25.008405)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.033917         []
# 1  1      mean   0.319180         []
# 2  2      mean   0.373056         []
# 3  3      mean   0.627867         []
# 4  4      mean   0.551268         []
# 5  5      mean   0.281831         []
#
#                                            All RMSEs  \
# 0  [[0.0872048496772559, 0.1165490736094128, 0.03...
# 1  [[0.35617856342347604, 0.5500854364755055, 0.3...
# 2  [[0.556716035671863, 0.5707857245806156, 0.373...
# 3  [[1.0772290858881073, 1.0184226921157236, 0.62...
# 4  [[0.9705759316336084, 0.7296087664558061, 0.55...
# 5  [[0.3130277566239726, 0.4417526743478506, 0.28...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 4  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 5  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-02 17:42:25.968404)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:  7.4min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-02 17:49:47.326680)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:  9.0min finished
# =================== (2020-09-02 17:58:45.186021)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-02 17:58:45.193020)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 3 ============
# ==========================
#
#
#
# =========================== (2020-09-02 17:58:45.194020)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ============  =============
# ============ 3 ============
# ===========================
#
#
#
# ================== (2020-09-02 17:58:45.197020)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS BLK WHSKY SQ 375M', '4': 'GENTLEMAN JACK WHSKY OL 750M', '5': 'JACK DANIELS TENN HNY WHSKY  750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2', '5', '4']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '5', '4']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1', '5', '4']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY SQ 375M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2', '1', '5']
# % of weeks without a purchase: 45.1219512195122
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '2', '1', '5']
# % of weeks without a purchase: 3.6585365853658534
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['5', '0', '2', '1', '4']
# % of weeks without a purchase: 1.2195121951219512
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY SQ 375M
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: JACK DANIELS TENN HNY WHSKY  750M
#
#
# ==================== (2020-09-02 18:00:14.641140)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (81, 7) (1, 7)
# (81, 7) (1, 7)
# (81, 7) (1, 7)
# (81, 7) (1, 7)
# (81, 7) (1, 7)
# (81, 7) (1, 7)
#
#
# ======================== (2020-09-02 18:00:14.649141)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-02 18:00:14.672139)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False, False, False, False]
#
#
# =============== (2020-09-02 18:00:14.674138)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-02 18:00:14.686140)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-02 18:00:14.687138)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-02 18:00:14.688138)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-02 18:00:14.863139)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-02 18:00:14.870141)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-02 18:01:30.378048)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-02 18:01:30.527174)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-02 18:01:30.528175)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-02 18:01:30.641696)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-02 18:01:30.648694)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-02 18:02:45.039305)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-02 18:02:45.194339)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-02 18:02:45.203340)
# ===== Products List  =====
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-02 18:02:46.277389)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 1 ============
# ==========================
#
#
#
# ========================== (2020-09-02 18:02:46.278389)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  750M', '2': 'JACK DANIELS BLK WHSKY FLSK PET 375M', '3': 'GENTLEMAN JACK WHSKY OL 750M', '4': 'JACK DANIELS TENN HNY WHSKY  1L', '5': 'GENTLEMAN JACK WHSKY 6PK 1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '5', '1', '2', '4']
# % of weeks without a purchase: 45.23809523809524
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '3', '5', '4']
# % of weeks without a purchase: 59.523809523809526
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY FLSK PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '5', '3', '4']
# % of weeks without a purchase: 44.26229508196721
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '5', '1', '0', '2']
# % of weeks without a purchase: 52.38095238095239
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '5', '1', '3']
# % of weeks without a purchase: 48.80952380952381
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY 6PK 1L
# --------------------------------------------------
# Exogenous Price Columns: ['5', '3', '0', '4', '1']
# % of weeks without a purchase: 32.926829268292686
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY FLSK PET 375M
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY 6PK 1L
#
#
# ========================== (2020-09-02 18:03:59.422794)
# ====== WHITE NOISE =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#        lb_stat  lb_pvalue
# 12   24.932218   0.015147
# 24   47.266936   0.003107
# 48  103.010327   0.000007
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  22.956927   0.028094
# 24  26.727008   0.317338
# 48  60.860438   0.100708
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12  15.263994   0.227316
# 24  18.177829   0.794298
# 48  34.440208   0.929390
#
# Is Data White Noise: True
#        lb_stat  lb_pvalue
# 12   24.646813   0.016588
# 24   50.653838   0.001168
# 48  108.922594   0.000001
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  11.113828   0.519190
# 24  30.880617   0.157255
# 48  53.855113   0.260331
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12   8.641692   0.733192
# 24  19.315056   0.734985
# 48  47.523727   0.492264
#
# Is Data White Noise: True
#
#
# ========================== (2020-09-02 18:03:59.453815)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (83, 7) (1, 7)
# (83, 7) (1, 7)
# (60, 7) (1, 7)
# (83, 7) (1, 7)
# (83, 7) (1, 7)
# (81, 7) (1, 7)
#
#
# ========================== (2020-09-02 18:03:59.464836)
# ========= NAIVE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#   ID      Best Type  Best RMSE All Naives  \
# 0  0           mean   1.149908         []
# 1  1           mean   0.959053         []
# 2  2           mean   0.800468         []
# 3  3           last   0.508452         []
# 4  4  seasonal_last   0.539165         []
# 5  5           mean   0.611153         []
#
#                                            All RMSEs  \
# 0  [[1.3378491195367055, 1.5550765479093094, 1.14...
# 1  [[1.3498152846931788, 1.3498152846931788, 0.95...
# 2  [[1.2112000548336292, 1.071290691653706, 0.800...
# 3  [[0.5084521358062825, 1.227326606712806, 0.861...
# 4  [[0.8388226345645782, 0.5391649362857315, 0.68...
# 5  [[0.7042605406907361, 0.7703384907350979, 0.61...
#
#                        All Types  \
# 0  [[last, seasonal_last, mean]]
# 1  [[last, seasonal_last, mean]]
# 2  [[last, seasonal_last, mean]]
# 3  [[last, seasonal_last, mean]]
# 4  [[last, seasonal_last, mean]]
# 5  [[last, seasonal_last, mean]]
#
#                                         Best Naive
# 0           NaiveForecaster(sp=4, strategy='mean')
# 1           NaiveForecaster(sp=4, strategy='mean')
# 2           NaiveForecaster(sp=4, strategy='mean')
# 3                            NaiveForecaster(sp=4)
# 4  NaiveForecaster(sp=4, strategy='seasonal_last')
# 5           NaiveForecaster(sp=4, strategy='mean')
#
#
# ========================== (2020-09-02 18:04:00.266023)
# ====== Multivar P0 =======
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:  5.8min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================== (2020-09-02 18:09:45.554945)
# ==== Multivar P0+Sim =====
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:  5.9min finished
# ========================== (2020-09-02 18:15:39.354946)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-02 18:15:39.364944)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 1 ============
# ==========================
#
#
#
# =========================== (2020-09-02 18:15:39.364944)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ==== THE BARREL HOUSE =====
# ============ 1 ============
# ===========================
#
#
#
# ========================== (2020-09-02 18:15:39.367944)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  750M', '2': 'JACK DANIELS BLK WHSKY FLSK PET 375M', '3': 'GENTLEMAN JACK WHSKY OL 750M', '4': 'JACK DANIELS TENN HNY WHSKY  1L', '5': 'GENTLEMAN JACK WHSKY 6PK 1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '5', '1', '2', '4']
# % of weeks without a purchase: 45.23809523809524
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '3', '5', '4']
# % of weeks without a purchase: 59.523809523809526
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY FLSK PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '5', '3', '4']
# % of weeks without a purchase: 44.26229508196721
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '5', '1', '0', '2']
# % of weeks without a purchase: 52.38095238095239
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '5', '1', '3']
# % of weeks without a purchase: 48.80952380952381
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY 6PK 1L
# --------------------------------------------------
# Exogenous Price Columns: ['5', '3', '0', '4', '1']
# % of weeks without a purchase: 32.926829268292686
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY FLSK PET 375M
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY 6PK 1L
#
#
# ========================== (2020-09-02 18:16:56.318944)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (83, 7) (1, 7)
# (83, 7) (1, 7)
# (60, 7) (1, 7)
# (83, 7) (1, 7)
# (83, 7) (1, 7)
# (81, 7) (1, 7)
#
#
# ========================== (2020-09-02 18:16:56.324943)
# ===== NAIVE FORECAST =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-02 18:16:56.347944)
# ========== MASK ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
# Mask: [False, False, False, False, False, False]
#
#
# ========================== (2020-09-02 18:16:56.348943)
# ========= SPACE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-02 18:16:56.356944)
# ======= Test Index =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-02 18:16:56.358944)
# ==== GET FUNCTION P0 =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ====================================== (2020-09-02 18:16:56.358944)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ========== THE BARREL HOUSE ==========
# ======================================
#
#
#
# ========================== (2020-09-02 18:16:56.543975)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-02 18:16:56.549945)
# ===== OPTIMIZING P0 ======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-02 18:18:01.729944)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ============================= (2020-09-02 18:18:01.974946)
# ==== GET FUNCTION P0+Sim ====
# ===== THE BARREL HOUSE ======
# =============================
#
#
#
# ========================================== (2020-09-02 18:18:01.975946)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ============ THE BARREL HOUSE ============
# ==========================================
#
#
#
# ========================== (2020-09-02 18:18:02.198943)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# =========================== (2020-09-02 18:18:02.206944)
# ==== OPTIMIZING P0+Sim ====
# ==== THE BARREL HOUSE =====
# ===========================
#
#
#
# ========================== (2020-09-02 18:20:03.739945)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-02 18:20:04.025943)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-02 18:20:04.034943)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 2 ============
# ==========================
#
#
#
# ========================== (2020-09-02 18:20:04.035943)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  750M', '2': 'JACK DANIELS BLK WHSKY FLSK PET 375M', '3': 'GENTLEMAN JACK WHSKY OL 750M', '4': 'JACK DANIELS TENN HNY WHSKY  1L', '5': 'GENTLEMAN JACK WHSKY 6PK 1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '5', '1', '2', '4']
# % of weeks without a purchase: 45.78313253012048
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '3', '5', '4']
# % of weeks without a purchase: 60.24096385542169
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY FLSK PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '5', '3', '4']
# % of weeks without a purchase: 45.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '5', '1', '0', '2']
# % of weeks without a purchase: 53.01204819277109
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '5', '1', '3']
# % of weeks without a purchase: 49.39759036144578
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY 6PK 1L
# --------------------------------------------------
# Exogenous Price Columns: ['5', '3', '0', '4', '1']
# % of weeks without a purchase: 33.33333333333333
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY FLSK PET 375M
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY 6PK 1L
#
#
# ========================== (2020-09-02 18:21:17.532945)
# ====== WHITE NOISE =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#       lb_stat  lb_pvalue
# 12  23.922535   0.020840
# 24  45.414544   0.005201
# 48  99.152623   0.000020
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  22.542047   0.031875
# 24  26.146223   0.345787
# 48  58.838830   0.135801
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12  15.197282   0.230825
# 24  17.646388   0.819818
# 48  34.217328   0.933162
#
# Is Data White Noise: True
#        lb_stat  lb_pvalue
# 12   25.814484   0.011401
# 24   50.372270   0.001269
# 48  100.845296   0.000013
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  10.794767   0.546584
# 24  29.686533   0.195359
# 48  53.100408   0.284097
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12   8.057662   0.780608
# 24  17.817943   0.811750
# 48  41.544821   0.733036
#
# Is Data White Noise: True
#
#
# ========================== (2020-09-02 18:21:17.550944)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (82, 7) (1, 7)
# (82, 7) (1, 7)
# (59, 7) (1, 7)
# (82, 7) (1, 7)
# (82, 7) (1, 7)
# (80, 7) (1, 7)
#
#
# ========================== (2020-09-02 18:21:17.553943)
# ========= NAIVE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#   ID      Best Type  Best RMSE All Naives  \
# 0  0           last   1.279671         []
# 1  1           mean   0.991773         []
# 2  2           mean   0.875579         []
# 3  3           last   0.397118         []
# 4  4  seasonal_last   0.583337         []
# 5  5           mean   0.532525         []
#
#                                            All RMSEs  \
# 0  [[1.2796706251393728, 1.655747949478816, 1.324...
# 1  [[1.3498152846931788, 1.3498152846931788, 0.99...
# 2  [[1.366635291344289, 1.2267259281643654, 0.875...
# 3  [[0.3971180356035492, 1.0727385943033805, 0.73...
# 4  [[0.9401093055023353, 0.5833369983034572, 0.76...
# 5  [[0.5741726496470821, 0.6294921160859183, 0.53...
#
#                        All Types  \
# 0  [[last, seasonal_last, mean]]
# 1  [[last, seasonal_last, mean]]
# 2  [[last, seasonal_last, mean]]
# 3  [[last, seasonal_last, mean]]
# 4  [[last, seasonal_last, mean]]
# 5  [[last, seasonal_last, mean]]
#
#                                         Best Naive
# 0                            NaiveForecaster(sp=4)
# 1           NaiveForecaster(sp=4, strategy='mean')
# 2           NaiveForecaster(sp=4, strategy='mean')
# 3                            NaiveForecaster(sp=4)
# 4  NaiveForecaster(sp=4, strategy='seasonal_last')
# 5           NaiveForecaster(sp=4, strategy='mean')
#
#
# ========================== (2020-09-02 18:21:18.028944)
# ====== Multivar P0 =======
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:  5.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================== (2020-09-02 18:26:31.754946)
# ==== Multivar P0+Sim =====
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:  4.7min finished
# ========================== (2020-09-02 18:31:15.994976)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-02 18:31:15.999976)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 2 ============
# ==========================
#
#
#
# =========================== (2020-09-02 18:31:15.999976)
# ==== Running Optimizer ====
# ...
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
#
#
# =================== (2020-09-02 19:52:25.168967)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
# Building Forecast dataframe. Forecast Period = 1
#
#
# =================== (2020-09-02 19:52:26.678989)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ========================== (2020-09-02 19:52:26.683988)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ========= SPECS ==========
# =========== 3 ============
# ==========================
#
#
#
# ================== (2020-09-02 19:52:26.684988)
# ==== GET DATA ====
# ===== SPECS ======
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS TENN HNY WHSKY  1L', '4': 'GENTLEMAN JACK WHSKY OL 750M', '5': 'JACK DANIELS TENN FIRE LIQ  1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '1', '2', '5']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '3', '5']
# % of weeks without a purchase: 8.536585365853659
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1', '3', '5']
# % of weeks without a purchase: 2.4390243902439024
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1', '2', '5']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '2', '3', '1']
# % of weeks without a purchase: 14.634146341463413
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN FIRE LIQ  1L
# --------------------------------------------------
# Exogenous Price Columns: ['5', '0', '3', '1', '2']
# % of weeks without a purchase: 1.6129032258064515
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: JACK DANIELS TENN FIRE LIQ  1L
#
#
# ===================== (2020-09-02 19:53:10.964969)
# ==== WHITE NOISE ====
# ======= SPECS =======
# =====================
#
#       lb_stat  lb_pvalue
# 12  14.591506   0.264539
# 24  25.708961   0.368096
# 48  45.847359   0.561475
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12  28.056071   0.005429
# 24  39.797909   0.022480
# 48  52.199800   0.314062
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12  26.241054   0.009922
# 24  37.090548   0.042858
# 48  54.361071   0.245108
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12   6.530656   0.887010
# 24  11.020075   0.988868
# 48  32.169399   0.961455
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12  25.969942   0.010839
# 24  48.789512   0.002013
# 48  61.783156   0.087302
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12  13.223117   0.353034
# 24  24.203764   0.449996
# 48  33.984078   0.936958
#
# Is Data White Noise: True
#
#
# ==================== (2020-09-02 19:53:10.988964)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (81, 7) (1, 7)
# (81, 7) (1, 7)
# (81, 7) (1, 7)
# (81, 7) (1, 7)
# (81, 7) (1, 7)
# (61, 7) (1, 7)
#
#
# =============== (2020-09-02 19:53:10.990968)
# ==== NAIVE ====
# ==== SPECS ====
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.051513         []
# 1  1      mean   0.109428         []
# 2  2      mean   0.221377         []
# 3  3      mean   0.086918         []
# 4  4      mean   0.971923         []
# 5  5      mean   0.193278         []
#
#                                            All RMSEs  \
# 0  [[0.12459174747365168, 0.13927072207458754, 0....
# 1  [[0.18390429323643792, 0.17762873456667566, 0....
# 2  [[0.4245652552570759, 0.3288519908859398, 0.22...
# 3  [[0.08808657027865822, 0.126322489261891, 0.08...
# 4  [[1.5669329860994465, 1.1153285005366258, 0.97...
# 5  [[0.19491087349701358, 0.22262168304966376, 0....
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 4  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 5  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-02 19:53:11.392964)
# ==== Multivar P0 ====
# ======= SPECS =======
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:  3.7min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-02 19:56:54.981088)
# ==== Multivar P0+Sim ====
# ========= SPECS =========
# =========================
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:  4.0min finished
# =================== (2020-09-02 20:00:56.708087)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ========================== (2020-09-02 20:00:56.714055)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ========= SPECS ==========
# =========== 3 ============
# ==========================
#
#
#
# =========================== (2020-09-02 20:00:56.714055)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ========== SPECS ==========
# ============ 3 ============
# ===========================
#
#
#
# ================== (2020-09-02 20:00:56.716059)
# ==== GET DATA ====
# ===== SPECS ======
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS TENN HNY WHSKY  1L', '4': 'GENTLEMAN JACK WHSKY OL 750M', '5': 'JACK DANIELS TENN FIRE LIQ  1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '1', '2', '5']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '3', '5']
# % of weeks without a purchase: 8.536585365853659
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1', '3', '5']
# % of weeks without a purchase: 2.4390243902439024
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1', '2', '5']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '2', '3', '1']
# % of weeks without a purchase: 14.634146341463413
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN FIRE LIQ  1L
# --------------------------------------------------
# Exogenous Price Columns: ['5', '0', '3', '1', '2']
# % of weeks without a purchase: 1.6129032258064515
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: JACK DANIELS TENN FIRE LIQ  1L
#
#
# ==================== (2020-09-02 20:01:41.671056)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (81, 7) (1, 7)
# (81, 7) (1, 7)
# (81, 7) (1, 7)
# (81, 7) (1, 7)
# (81, 7) (1, 7)
# (61, 7) (1, 7)
#
#
# ======================== (2020-09-02 20:01:41.676086)
# ==== NAIVE FORECAST ====
# ======== SPECS =========
# ========================
#
#
#
# =============== (2020-09-02 20:01:41.691086)
# ==== MASK =====
# ==== SPECS ====
# ===============
#
# Mask: [False, False, False, False, False, False]
#
#
# =============== (2020-09-02 20:01:41.693087)
# ==== SPACE ====
# ==== SPECS ====
# ===============
#
#
#
# ==================== (2020-09-02 20:01:41.700085)
# ==== Test Index ====
# ====== SPECS =======
# ====================
#
#
#
# ========================= (2020-09-02 20:01:41.701086)
# ==== GET FUNCTION P0 ====
# ========= SPECS =========
# =========================
#
#
#
# ====================================== (2020-09-02 20:01:41.701086)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# =============== SPECS ================
# ======================================
#
#
#
# =================== (2020-09-02 20:01:41.815058)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ======================= (2020-09-02 20:01:41.819058)
# ==== OPTIMIZING P0 ====
# ======== SPECS ========
# =======================
#
#
#
# =================== (2020-09-02 20:02:36.955055)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ============================= (2020-09-02 20:02:37.077058)
# ==== GET FUNCTION P0+Sim ====
# =========== SPECS ===========
# =============================
#
#
#
# ========================================== (2020-09-02 20:02:37.078055)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ================= SPECS ==================
# ==========================================
#
#
#
# =================== (2020-09-02 20:02:37.249056)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =========================== (2020-09-02 20:02:37.257059)
# ==== OPTIMIZING P0+Sim ====
# ========== SPECS ==========
# ===========================
#
#
#
# =================== (2020-09-02 20:03:39.356056)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =================== (2020-09-02 20:03:39.507055)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ========================== (2020-09-02 20:03:39.516058)
# ==== Saving to PICKLE ====
# ==== SUP PREM WHISKEY ====
# ==========================
#
# Pickle File  full_models_SUP PREM WHISKEY_Prod6_Sim4_Per123.pkl  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns
# Pickle File  full_opt_SUP PREM WHISKEY_Prod6_Sim4_Per123.pkl  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns
#
#
# ========================== (2020-09-02 20:03:39.700060)
# ==== Saving to EXCEL =====
# ==== SUP PREM WHISKEY ====
# ==========================
#
# EXCEL File  Output_SUP PREM WHISKEY_Prod6_Sim4_Per123.xlsx  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns

# %% [markdown]
# # Print out

# %% [markdown]
# ## Models

# %%
full_models[outputColsModels]
# Out:
#           Chain Master                            Product  Period to Last  \
# 4                            GENTLEMAN JACK WHSKY OL 750M               1
# 10                           GENTLEMAN JACK WHSKY OL 750M               2
# 16                           GENTLEMAN JACK WHSKY OL 750M               3
# 1                           JACK DANIELS BLK WHSKY  1.75L               1
# 7                           JACK DANIELS BLK WHSKY  1.75L               2
# ..                 ...                                ...             ...
# 45  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY SQ 375M               2
# 51  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY SQ 375M               3
# 41  WESTERN BEV LIQ TX  JACK DANIELS TENN HNY WHSKY  750M               1
# 47  WESTERN BEV LIQ TX  JACK DANIELS TENN HNY WHSKY  750M               2
# 53  WESTERN BEV LIQ TX  JACK DANIELS TENN HNY WHSKY  750M               3
#
#     White Noise Naive Best Type  Naive Best RMSE P0 Best Model Name  \
# 4         False            mean         0.375053                 ML
# 10        False            mean         0.351197                 ML
# 16        False            mean         0.551268       auto_SARIMAX
# 1         False            last         0.324455       auto_SARIMAX
# 7         False            mean         0.323943       auto_SARIMAX
# ..          ...             ...              ...                ...
# 45        False            mean         0.675541            Prophet
# 51        False            mean         0.630851       auto_SARIMAX
# 41        False            mean         0.584296                 ML
# 47        False            mean         0.541200                 ML
# 53        False            mean         0.573054                 ML
#
#     P0 Best Model RMSE P0+Sim Best Model Name  P0+Sim Best Model RMSE
# 4             0.253176                     ML                0.256816
# 10            0.293141           auto_SARIMAX                0.298755
# 16            0.299190           auto_SARIMAX                0.303763
# 1             0.243913           auto_SARIMAX                0.243525
# 7             0.219089           auto_SARIMAX                0.247446
# ..                 ...                    ...                     ...
# 45            0.715019           auto_SARIMAX                0.770981
# 51            0.629432           auto_SARIMAX                0.637309
# 41            0.443034                     ML                0.460945
# 47            0.462096                     ML                0.462493
# 53            0.352702                     ML                0.385172
#
# [72 rows x 10 columns]

# %% [markdown]
# ## Optimizer

# %% [markdown]
# ### Summary by Chain

# %%
full_chain_summary
# Out:
#          Chain Master  P0 Non-Opt Revenue  P0 Opt Revenue  P0 Opt Diff  \
# 0                                305952.0        303110.0      -2842.0
# 1               SPECS            228031.0        230638.0       2607.0
# 2    THE BARREL HOUSE              5649.0          5709.0         60.0
# 3  WESTERN BEV LIQ TX            136985.0        155120.0      18135.0
#
#    P0 Opt Diff Ratio  P0+Sim Non-Opt Revenue  P0+Sim Opt Revenue  \
# 0           0.990711                343256.0            496992.0
# 1           1.011433                215462.0            237222.0
# 2           1.010621                 11269.0             32343.0
# 3           1.132387                198801.0          47727042.0
#
#    P0+Sim Opt Diff  P0+Sim Opt Diff Ratio
# 0         153736.0               1.447876
# 1          21760.0               1.100992
# 2          21074.0               2.870086
# 3       47528241.0             240.074456

# %%
print("WRITE this value in the summary table in Git hub --->",round(full_chain_summary[full_chain_summary['Chain Master']=='']['P0+Sim Opt Diff Ratio'].item(),4))
# Out:
# WRITE this value in the summary table in Git hub ---> 1.4479

# %% [markdown]
# Link to the Git Hub Summary Table: https://github.com/ngupta23/msds_capstone/issues/84

# %% [markdown]
# ### Summary by Chain and Product

# %%
full_summary
# Out:
#           Chain Master                               Product  \
# 0                               GENTLEMAN JACK WHSKY OL 750M
# 1                              JACK DANIELS BLK WHSKY  1.75L
# 2                                 JACK DANIELS BLK WHSKY  1L
# 3                               JACK DANIELS BLK WHSKY  750M
# 4                             JACK DANIELS BLK WHSKY SQ 375M
# 5                          JACK DANIELS TENN HNY WHSKY  750M
# 6                SPECS          GENTLEMAN JACK WHSKY OL 750M
# 7                SPECS         JACK DANIELS BLK WHSKY  1.75L
# 8                SPECS            JACK DANIELS BLK WHSKY  1L
# 9                SPECS          JACK DANIELS BLK WHSKY  750M
# 10               SPECS        JACK DANIELS TENN FIRE LIQ  1L
# 11               SPECS       JACK DANIELS TENN HNY WHSKY  1L
# 12    THE BARREL HOUSE           GENTLEMAN JACK WHSKY 6PK 1L
# 13    THE BARREL HOUSE          GENTLEMAN JACK WHSKY OL 750M
# 14    THE BARREL HOUSE            JACK DANIELS BLK WHSKY  1L
# 15    THE BARREL HOUSE          JACK DANIELS BLK WHSKY  750M
# 16    THE BARREL HOUSE  JACK DANIELS BLK WHSKY FLSK PET 375M
# 17    THE BARREL HOUSE       JACK DANIELS TENN HNY WHSKY  1L
# 18  WESTERN BEV LIQ TX          GENTLEMAN JACK WHSKY OL 750M
# 19  WESTERN BEV LIQ TX         JACK DANIELS BLK WHSKY  1.75L
# 20  WESTERN BEV LIQ TX            JACK DANIELS BLK WHSKY  1L
# 21  WESTERN BEV LIQ TX          JACK DANIELS BLK WHSKY  750M
# 22  WESTERN BEV LIQ TX        JACK DANIELS BLK WHSKY SQ 375M
# 23  WESTERN BEV LIQ TX     JACK DANIELS TENN HNY WHSKY  750M
#
#     P0 Non-Opt Revenue  P0 Opt Revenue  P0 Opt Diff  P0 Opt Diff Ratio  \
# 0               2952.0          2910.0        -42.0           0.985772
# 1              78808.0         78349.0       -459.0           0.994176
# 2             162183.0        160281.0      -1902.0           0.988273
# 3              47810.0         46119.0      -1691.0           0.964631
# 4                769.0           765.0         -4.0           0.994798
# 5              13430.0         14686.0       1256.0           1.093522
# 6               2764.0          2240.0       -524.0           0.810420
# 7              31102.0         29443.0      -1659.0           0.946659
# 8             163171.0        161650.0      -1521.0           0.990678
# 9              14658.0         22170.0       7512.0           1.512485
# 10              5235.0          5107.0       -128.0           0.975549
# 11             11101.0         10028.0      -1073.0           0.903342
# 12              1157.0          1171.0         14.0           1.012100
# 13               334.0           336.0          2.0           1.005988
# 14               866.0           843.0        -23.0           0.973441
# 15              1043.0          1118.0         75.0           1.071908
# 16               504.0           514.0         10.0           1.019841
# 17              1745.0          1727.0        -18.0           0.989685
# 18              5000.0          5259.0        259.0           1.051800
# 19             18820.0         31245.0      12425.0           1.660202
# 20             48563.0         48105.0       -458.0           0.990569
# 21             35987.0         37410.0       1423.0           1.039542
# 22             12874.0         16932.0       4058.0           1.315209
# 23             15741.0         16169.0        428.0           1.027190
#
#     P0+Sim Non-Opt Revenue  P0+Sim Opt Revenue  P0+Sim Opt Diff  \
# 0                  11949.0              9744.0          -2205.0
# 1                  52076.0             77067.0          24991.0
# 2                 216956.0            295626.0          78670.0
# 3                  45435.0             93409.0          47974.0
# 4                   3047.0              6668.0           3621.0
# 5                  13793.0             14478.0            685.0
# 6                    980.0             33830.0          32850.0
# 7                  22985.0             21961.0          -1024.0
# 8                 161001.0            154608.0          -6393.0
# 9                  14725.0             13088.0          -1637.0
# 10                  4710.0              4573.0           -137.0
# 11                 11061.0              9162.0          -1899.0
# 12                  1040.0              1045.0              5.0
# 13                   729.0               358.0           -371.0
# 14                  1343.0             22688.0          21345.0
# 15                  4325.0              4610.0            285.0
# 16                  1636.0              1519.0           -117.0
# 17                  2196.0              2123.0            -73.0
# 18                  2989.0              2940.0            -49.0
# 19                134121.0          34630025.0       34495904.0
# 20                 40569.0             37876.0          -2693.0
# 21                 14685.0           1390105.0        1375420.0
# 22                  1017.0          11660945.0       11659928.0
# 23                  5420.0              5151.0           -269.0
#
#     P0+Sim Opt Diff Ratio
# 0                0.815466
# 1                1.479895
# 2                1.362608
# 3                2.055882
# 4                2.188382
# 5                1.049663
# 6               34.520408
# 7                0.955449
# 8                0.960292
# 9                0.888829
# 10               0.970913
# 11               0.828316
# 12               1.004808
# 13               0.491084
# 14              16.893522
# 15               1.065896
# 16               0.928484
# 17               0.966758
# 18               0.983607
# 19             258.199872
# 20               0.933619
# 21              94.661559
# 22           11466.022616
# 23               0.950369

# %% [markdown]
# ### P0 Optimizer

# %%
full_opt[outputColsOptP0]
# Out:
#           Chain Master                            Product  Period to Last  \
# 4                            GENTLEMAN JACK WHSKY OL 750M               1
# 10                           GENTLEMAN JACK WHSKY OL 750M               2
# 16                           GENTLEMAN JACK WHSKY OL 750M               3
# 1                           JACK DANIELS BLK WHSKY  1.75L               1
# 7                           JACK DANIELS BLK WHSKY  1.75L               2
# ..                 ...                                ...             ...
# 45  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY SQ 375M               2
# 51  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY SQ 375M               3
# 41  WESTERN BEV LIQ TX  JACK DANIELS TENN HNY WHSKY  750M               1
# 47  WESTERN BEV LIQ TX  JACK DANIELS TENN HNY WHSKY  750M               2
# 53  WESTERN BEV LIQ TX  JACK DANIELS TENN HNY WHSKY  750M               3
#
#     P0 Non-Opt Price  P0 Non-Opt Demand  P0 Non-Opt Revenue  \
# 4             245.31                  2                 473
# 10            241.44                  2                 430
# 16            252.77                  8                2049
# 1             185.65                224               41518
# 7             184.71                 91               16867
# ..               ...                ...                 ...
# 45            195.60                 56               10948
# 51            195.60                  1                 156
# 41            203.04                  2                 339
# 47            203.04                  8                1584
# 53            222.36                 62               13818
#
#     P0 Non-Opt Chain Master Revenue  P0 Optimal Price  P0 Demand  P0 Revenue  \
# 4                            152835            252.84          2         488
# 10                            77507            257.88          2         459
# 16                            75611            258.26          8        1963
# 1                            152835            183.80        215       39469
# 7                             77507            185.73         93       17341
# ..                              ...               ...        ...         ...
# 45                            30153            180.24         85       15381
# 51                            38696            196.59          1         156
# 41                            68137            198.55          2         332
# 47                            30153            211.69          8        1652
# 53                            38696            228.26         62       14185
#
#     P0 Chain Master Revenue
# 4                    148205
# 10                    78598
# 16                    76307
# 1                    148205
# 7                     78598
# ..                      ...
# 45                    34980
# 51                    39107
# 41                    81032
# 47                    34980
# 53                    39107
#
# [72 rows x 11 columns]

# %% [markdown]
# ### P0+Sim Optimizer

# %%
full_opt[outputColsOptP0Sim]
# Out:
#           Chain Master                            Product  Period to Last  \
# 4                            GENTLEMAN JACK WHSKY OL 750M               1
# 10                           GENTLEMAN JACK WHSKY OL 750M               2
# 16                           GENTLEMAN JACK WHSKY OL 750M               3
# 1                           JACK DANIELS BLK WHSKY  1.75L               1
# 7                           JACK DANIELS BLK WHSKY  1.75L               2
# ..                 ...                                ...             ...
# 45  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY SQ 375M               2
# 51  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY SQ 375M               3
# 41  WESTERN BEV LIQ TX  JACK DANIELS TENN HNY WHSKY  750M               1
# 47  WESTERN BEV LIQ TX  JACK DANIELS TENN HNY WHSKY  750M               2
# 53  WESTERN BEV LIQ TX  JACK DANIELS TENN HNY WHSKY  750M               3
#
#     P0+Sim Non-Opt Price  P0+Sim Non-Opt Demand  P0+Sim Non-Opt Revenue  \
# 4                 245.31                      1                     220
# 10                241.44                     30                    7297
# 16                252.77                     18                    4432
# 1                 185.65                    163                   30179
# 7                 184.71                     68                   12588
# ..                   ...                    ...                     ...
# 45                195.60                      4                     766
# 51                195.60                      1                     154
# 41                203.04                     10                    2059
# 47                203.04                     10                    2059
# 53                222.36                      6                    1302
#
#     P0+Sim Non-Opt Chain Master Revenue  P0+Sim Optimal Price  P0+Sim Demand  \
# 4                                130332                268.38              1
# 10                               105979                268.36             22
# 16                               106945                268.59             14
# 1                                130332                169.93            307
# 7                                105979                169.85             95
# ..                                  ...                   ...            ...
# 45                                30769                195.47          22964
# 51                                57979                217.45          32982
# 41                               110052                197.46             10
# 47                                30769                196.35             10
# 53                                57979                197.46              6
#
#     P0+Sim Revenue  P0+Sim Chain Master Revenue
# 4              241                       219594
# 10            5805                       151910
# 16            3698                       125485
# 1            52235                       219594
# 7            16170                       151910
# ..             ...                          ...
# 45         4488859                      5894331
# 51         7171974                     41036504
# 41            2003                       796207
# 47            1992                      5894331
# 53            1156                     41036504
#
# [72 rows x 11 columns]

# %% [markdown]
# ### Naive

# %%
full_opt[outputColsOptNaive]
# Out:
#           Chain Master                            Product  Period to Last  \
# 4                            GENTLEMAN JACK WHSKY OL 750M               1
# 10                           GENTLEMAN JACK WHSKY OL 750M               2
# 16                           GENTLEMAN JACK WHSKY OL 750M               3
# 1                           JACK DANIELS BLK WHSKY  1.75L               1
# 7                           JACK DANIELS BLK WHSKY  1.75L               2
# ..                 ...                                ...             ...
# 45  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY SQ 375M               2
# 51  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY SQ 375M               3
# 41  WESTERN BEV LIQ TX  JACK DANIELS TENN HNY WHSKY  750M               1
# 47  WESTERN BEV LIQ TX  JACK DANIELS TENN HNY WHSKY  750M               2
# 53  WESTERN BEV LIQ TX  JACK DANIELS TENN HNY WHSKY  750M               3
#
#     Actual Price  Actual Demand  Actual Revenue  Actual Chain Master Revenue  \
# 4     245.305091         110.00        26983.56                    325791.06
# 10    241.440000          25.00         6036.00                     97005.06
# 16    252.770526          19.00         4802.64                    135877.02
# 1     185.650112         389.61        72331.14                    325791.06
# 7     184.710623          40.95         7563.90                     97005.06
# ..           ...            ...             ...                          ...
# 45    195.600000          21.00         4107.60                     27779.70
# 51    195.600000          19.00         3716.40                     48091.50
# 41    203.040000          50.00        10152.00                    146183.88
# 47    203.040000          12.00         2436.48                     27779.70
# 53    222.360000           1.00          222.36                     48091.50
#
#     Naive Prices  Naive Demand  Naive Revenue  Naive Chain Master Revenue
# 4     245.305091     20.454795    5017.665391               103389.269701
# 10    241.440000     20.399366    4925.222892               124927.403196
# 16    252.770526     20.416642    5160.725338               124778.750832
# 1     185.650112     40.950000    7602.372072               103389.269701
# 7     184.710623    157.916707   29168.893345               124927.403196
# ..           ...           ...            ...                         ...
# 45    195.600000     18.102083    3540.767500                55360.091330
# 51    195.600000     18.086864    3537.790678                35371.741314
# 41    203.040000     16.559241    3362.188285                56839.419493
# 47    203.040000     16.614841    3373.477411                55360.091330
# 53    222.360000     16.807617    3737.341779                35371.741314
#
# [72 rows x 11 columns]
