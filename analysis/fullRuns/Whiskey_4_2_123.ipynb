# %% [markdown]
# # Init

# %%
# %load_ext autoreload
# %autoreload 2

# %%
print("CURRENT FOLDER:")
# %pwd
# Out:
# CURRENT FOLDER:
# 'c:\\max\\Google Drive Max\\Max Shared\\Master Data Science\\2020-05 Capstone A\\msds_capstone\\analysis\\fullRuns'

# %%
import os
import glob
import sys
sys.path.append(os.environ['DEV_AUTOTS'])
sys.path.append(os.environ['CAPSTONE_PYTHON_SOURCE'])
folder = os.environ['CAPSTONE_DATA']

# %%
## Sourcing the .py with all the code##
t='"'+os.environ['CAPSTONE_PYTHON_SOURCE']+'\\fullRun\\fullRun.py'+'"'
# %run -i $t
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# Running Auto Timeseries version: 0.0.24

# %% [markdown]
# # Parameters

# %%
#Parameters

ProdCats = ['SUP PREM WHISKEY']
TOP_PRODUCTS = 4  # How many products to consider in the category
TOP_SIMILAR = 2   # Get TOP_SIMILAR most similar products
RUN_PERIODS = [1,2,3] # this will run AutoTS and Optimzer for speicfic periods (1 = last, 2 = second to last)

CV_NUM = 10         # number of Cross Valudations  10
OPT_CALLS = 100     # number of calls for the optimizer process   100
OPT_RND_STARTS = 20 # number of random calls for the optimizer process  20

LOG_TRANSFORM = True # Take log of 9L cases to smooth out peaks and valleys
ZERO_ADDER = 0.1 

RESAMPLE_FREQ = 'M'


# Pricing changes every 4 weeks
if RESAMPLE_FREQ == 'M':    FORECAST_PERIOD = 1 #last 4 months as test 
if RESAMPLE_FREQ == 'W':    FORECAST_PERIOD = 4 
if RESAMPLE_FREQ == '2W':   FORECAST_PERIOD = 2 

# Seasonal Period
if RESAMPLE_FREQ == 'M':    SEASONAL_PERIOD = 12  # Yearly
if RESAMPLE_FREQ == 'W':    SEASONAL_PERIOD = 13 # Quarterly (we can also take yearly = 52, but SARIMAX becomes too slow)
if RESAMPLE_FREQ == '2W':   SEASONAL_PERIOD = 13 # This becomes problematic --> for quarterly, should we take 6 biweekly periods or 7 bi-weekly periods. Instead I just took half yearly period  

COL_TIME = 'WeekDate'
COL_PREDS = ['9L Cases'] #Demand
COL_PRICE= ['Dollar Sales per 9L Case'] #Price

# %% [markdown]
# # Full Run

# %%
dataRaw = loadDataset(version=4)
ProdCat = 'SUP PREM WHISKEY' #'ECONOMY VODKA'
ChainMasters =  [''] +  dataRaw['Chain Master'].unique().tolist() 
display(ChainMasters,ProdCats)
# Out:
# ['', 'THE BARREL HOUSE', 'WESTERN BEV LIQ TX', 'SPECS']
# ['SUP PREM WHISKEY']

# %%
(full_models,full_opt,full_summary,full_chain_summary)  = fullRun(ProdCat = ProdCat
                                                           ,ChainMasters = ChainMasters
                                                           ,dataRaw = dataRaw
                                                           ,savePKL=True
                                                           ,saveXLS=True)
# Out:
# ==================================================
# Parameters being used...
# ==================================================
# TOP_PRODUCTS = 4
# TOP_SIMILAR = 2
# RUN_PERIODS = [1, 2, 3]
# ProdCat: SUP PREM WHISKEY
# ChainMasters: ['', 'THE BARREL HOUSE', 'WESTERN BEV LIQ TX', 'SPECS']
#
#
# ========================== (2020-09-01 11:26:57.374227)
# ===== Products List  =====
# ==== SUP PREM WHISKEY ====
# ============  ============
# ==========================
#
#
#
# ========================== (2020-09-01 11:27:02.896675)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 1 ============
# ==========================
#
#
#
# ================== (2020-09-01 11:27:02.897676)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS BLK WHSKY SQ 375M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 1.1904761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY SQ 375M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2']
# % of weeks without a purchase: 44.047619047619044
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY SQ 375M
#
#
# ===================== (2020-09-01 11:27:45.549592)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#       lb_stat  lb_pvalue
# 12  17.529696   0.130735
# 24  31.092108   0.151145
# 48  54.922995   0.228882
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12  115.750529  4.333814e-19
# 24  214.169023  1.845834e-32
# 48  308.098428  1.176533e-39
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   76.707883  1.745018e-11
# 24  131.122583  9.711501e-17
# 48  214.957410  5.416649e-23
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  236.849902  7.504140e-44
# 24  313.152234  3.733315e-52
# 48  457.992618  2.867236e-68
#
# Is Data White Noise: False
#
#
# ==================== (2020-09-01 11:27:45.577590)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (83, 5) (1, 5)
# (83, 5) (1, 5)
# (83, 5) (1, 5)
# (83, 5) (1, 5)
#
#
# =============== (2020-09-01 11:27:45.585591)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.043169         []
# 1  1      last   0.324455         []
# 2  2      mean   0.427990         []
# 3  3      mean   0.798321         []
#
#                                            All RMSEs  \
# 0  [[0.07143315389555474, 0.11332894033533458, 0....
# 1  [[0.3244545696539494, 0.4963154566538675, 0.34...
# 2  [[0.6704496090247218, 0.719929333484661, 0.427...
# 3  [[1.158356517777329, 1.1898741527817909, 0.798...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-01 11:27:46.006596)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  5.8min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  5.8min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-01 11:33:35.492273)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  6.0min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  6.0min finished
# =================== (2020-09-01 11:39:33.588929)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-01 11:39:33.593931)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 1 ============
# ==========================
#
#
#
# =========================== (2020-09-01 11:39:33.593931)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ============  =============
# ============ 1 ============
# ===========================
#
#
#
# ================== (2020-09-01 11:39:33.598932)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS BLK WHSKY SQ 375M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 1.1904761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY SQ 375M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2']
# % of weeks without a purchase: 44.047619047619044
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY SQ 375M
#
#
# ==================== (2020-09-01 11:40:26.671657)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (83, 5) (1, 5)
# (83, 5) (1, 5)
# (83, 5) (1, 5)
# (83, 5) (1, 5)
#
#
# ======================== (2020-09-01 11:40:26.680658)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-01 11:40:26.699658)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False, False]
#
#
# =============== (2020-09-01 11:40:26.702656)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-01 11:40:26.711655)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-01 11:40:26.713655)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-01 11:40:26.714657)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-01 11:40:26.906654)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-01 11:40:26.912654)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-01 11:41:57.263097)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-01 11:41:57.362098)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-01 11:41:57.363096)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-01 11:41:57.459096)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-01 11:41:57.465095)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-01 11:43:00.099987)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-01 11:43:00.196989)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-01 11:43:00.202988)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 2 ============
# ==========================
#
#
#
# ================== (2020-09-01 11:43:00.202988)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS BLK WHSKY SQ 375M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 1.2048192771084338
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY SQ 375M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2']
# % of weeks without a purchase: 44.57831325301205
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY SQ 375M
#
#
# ===================== (2020-09-01 11:43:39.023787)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#       lb_stat  lb_pvalue
# 12  17.074759   0.146807
# 24  30.689164   0.162949
# 48  53.509495   0.271059
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12  113.741522  1.085921e-18
# 24  210.737801  8.608130e-32
# 48  298.546482  6.801454e-38
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   73.433730  7.257343e-11
# 24  127.792143  3.888372e-16
# 48  208.580703  6.624266e-22
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  233.654157  3.467423e-43
# 24  301.956845  6.767463e-50
# 48  453.324573  2.340339e-67
#
# Is Data White Noise: False
#
#
# ==================== (2020-09-01 11:43:39.037313)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (82, 5) (1, 5)
#
#
# =============== (2020-09-01 11:43:39.040310)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.021557         []
# 1  1      mean   0.323943         []
# 2  2      mean   0.373199         []
# 3  3      mean   0.669609         []
#
#                                            All RMSEs  \
# 0  [[0.057546587491533165, 0.09126460007014617, 0...
# 1  [[0.3342880201030623, 0.4694144778845947, 0.32...
# 2  [[0.6160411345584191, 0.6054018321634664, 0.37...
# 3  [[1.1334719691929973, 1.0359040362506735, 0.66...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-01 11:43:39.435129)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  6.6min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  6.6min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-01 11:50:17.194337)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  6.5min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  6.5min finished
# =================== (2020-09-01 11:56:47.225255)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-01 11:56:47.233254)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 2 ============
# ==========================
#
#
#
# =========================== (2020-09-01 11:56:47.233254)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ============  =============
# ============ 2 ============
# ===========================
#
#
#
# ================== (2020-09-01 11:56:47.236256)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS BLK WHSKY SQ 375M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 1.2048192771084338
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY SQ 375M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2']
# % of weeks without a purchase: 44.57831325301205
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY SQ 375M
#
#
# ==================== (2020-09-01 11:57:36.168058)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (82, 5) (1, 5)
#
#
# ======================== (2020-09-01 11:57:36.176577)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-01 11:57:36.193578)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False, False]
#
#
# =============== (2020-09-01 11:57:36.197576)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-01 11:57:36.208577)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-01 11:57:36.209577)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-01 11:57:36.210577)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-01 11:57:36.471609)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-01 11:57:36.477608)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-01 11:59:24.889926)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-01 11:59:25.068926)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-01 11:59:25.069926)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-01 11:59:25.246924)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-01 11:59:25.253928)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-01 12:00:58.374064)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-01 12:00:58.525064)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-01 12:00:58.534064)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 3 ============
# ==========================
#
#
#
# ================== (2020-09-01 12:00:58.534064)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS BLK WHSKY SQ 375M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY SQ 375M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2']
# % of weeks without a purchase: 45.1219512195122
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY SQ 375M
#
#
# ===================== (2020-09-01 12:01:46.141240)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#       lb_stat  lb_pvalue
# 12  16.492825   0.169692
# 24  29.613691   0.197887
# 48  52.235849   0.312831
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12  111.729571  2.720557e-18
# 24  207.460783  3.736074e-31
# 48  291.621010  1.270149e-36
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   72.023277  1.337193e-10
# 24  126.557635  6.490946e-16
# 48  206.128607  1.725436e-21
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  227.003218  8.357786e-42
# 24  289.400873  2.267177e-47
# 48  442.433742  3.108030e-65
#
# Is Data White Noise: False
#
#
# ==================== (2020-09-01 12:01:46.169235)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (81, 5) (1, 5)
# (81, 5) (1, 5)
# (81, 5) (1, 5)
# (81, 5) (1, 5)
#
#
# =============== (2020-09-01 12:01:46.177237)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.033917         []
# 1  1      mean   0.319180         []
# 2  2      mean   0.373056         []
# 3  3      mean   0.627867         []
#
#                                            All RMSEs  \
# 0  [[0.0872048496772559, 0.1165490736094128, 0.03...
# 1  [[0.35617856342347604, 0.5500854364755055, 0.3...
# 2  [[0.556716035671863, 0.5707857245806156, 0.373...
# 3  [[1.0772290858881073, 1.0184226921157236, 0.62...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-01 12:01:46.689238)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  7.1min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  7.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-01 12:08:55.443914)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  6.2min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  6.2min finished
# =================== (2020-09-01 12:15:04.892347)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-01 12:15:04.901345)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 3 ============
# ==========================
#
#
#
# =========================== (2020-09-01 12:15:04.902347)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ============  =============
# ============ 3 ============
# ===========================
#
#
#
# ================== (2020-09-01 12:15:04.905345)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS BLK WHSKY SQ 375M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY SQ 375M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2']
# % of weeks without a purchase: 45.1219512195122
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY SQ 375M
#
#
# ==================== (2020-09-01 12:16:02.270424)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (81, 5) (1, 5)
# (81, 5) (1, 5)
# (81, 5) (1, 5)
# (81, 5) (1, 5)
#
#
# ======================== (2020-09-01 12:16:02.279422)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-01 12:16:02.300422)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False, False]
#
#
# =============== (2020-09-01 12:16:02.303422)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-01 12:16:02.312424)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-01 12:16:02.314423)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-01 12:16:02.315426)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-01 12:16:02.495423)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-01 12:16:02.502424)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-01 12:17:18.762335)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-01 12:17:18.895337)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-01 12:17:18.896333)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-01 12:17:19.056336)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-01 12:17:19.064335)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-01 12:18:26.589243)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-01 12:18:26.710790)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-01 12:18:26.717790)
# ===== Products List  =====
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:18:27.661122)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 1 ============
# ==========================
#
#
#
# ========================== (2020-09-01 12:18:27.662121)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'GENTLEMAN JACK WHSKY OL 750M', '2': 'JACK DANIELS TENN HNY WHSKY  1L', '3': 'GENTLEMAN JACK WHSKY 6PK 1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '2']
# % of weeks without a purchase: 45.23809523809524
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3', '0']
# % of weeks without a purchase: 52.38095238095239
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '3']
# % of weeks without a purchase: 48.80952380952381
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY 6PK 1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '1', '0']
# % of weeks without a purchase: 32.926829268292686
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY 6PK 1L
#
#
# ========================== (2020-09-01 12:19:09.874767)
# ====== WHITE NOISE =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#        lb_stat  lb_pvalue
# 12   24.932218   0.015147
# 24   47.266936   0.003107
# 48  103.010327   0.000007
#
# Is Data White Noise: False
#        lb_stat  lb_pvalue
# 12   24.646813   0.016588
# 24   50.653838   0.001168
# 48  108.922594   0.000001
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  11.113828   0.519190
# 24  30.880617   0.157255
# 48  53.855113   0.260331
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12   8.641692   0.733192
# 24  19.315056   0.734985
# 48  47.523727   0.492264
#
# Is Data White Noise: True
#
#
# ========================== (2020-09-01 12:19:09.888767)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (83, 5) (1, 5)
# (83, 5) (1, 5)
# (83, 5) (1, 5)
# (81, 5) (1, 5)
#
#
# ========================== (2020-09-01 12:19:09.891768)
# ========= NAIVE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#   ID      Best Type  Best RMSE All Naives  \
# 0  0           mean   1.149908         []
# 1  1           last   0.508452         []
# 2  2  seasonal_last   0.539165         []
# 3  3           mean   0.611153         []
#
#                                            All RMSEs  \
# 0  [[1.3378491195367055, 1.5550765479093094, 1.14...
# 1  [[0.5084521358062825, 1.227326606712806, 0.861...
# 2  [[0.8388226345645782, 0.5391649362857315, 0.68...
# 3  [[0.7042605406907361, 0.7703384907350979, 0.61...
#
#                        All Types  \
# 0  [[last, seasonal_last, mean]]
# 1  [[last, seasonal_last, mean]]
# 2  [[last, seasonal_last, mean]]
# 3  [[last, seasonal_last, mean]]
#
#                                         Best Naive
# 0           NaiveForecaster(sp=4, strategy='mean')
# 1                            NaiveForecaster(sp=4)
# 2  NaiveForecaster(sp=4, strategy='seasonal_last')
# 3           NaiveForecaster(sp=4, strategy='mean')
#
#
# ========================== (2020-09-01 12:19:10.302767)
# ====== Multivar P0 =======
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  5.8min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  5.8min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================== (2020-09-01 12:24:59.586646)
# ==== Multivar P0+Sim =====
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  5.6min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  5.6min finished
# ========================== (2020-09-01 12:30:35.777431)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:30:35.785431)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 1 ============
# ==========================
#
#
#
# =========================== (2020-09-01 12:30:35.785431)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ==== THE BARREL HOUSE =====
# ============ 1 ============
# ===========================
#
#
#
# ========================== (2020-09-01 12:30:35.788431)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'GENTLEMAN JACK WHSKY OL 750M', '2': 'JACK DANIELS TENN HNY WHSKY  1L', '3': 'GENTLEMAN JACK WHSKY 6PK 1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '2']
# % of weeks without a purchase: 45.23809523809524
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3', '0']
# % of weeks without a purchase: 52.38095238095239
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '3']
# % of weeks without a purchase: 48.80952380952381
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY 6PK 1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '1', '0']
# % of weeks without a purchase: 32.926829268292686
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY 6PK 1L
#
#
# ========================== (2020-09-01 12:31:21.763719)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (83, 5) (1, 5)
# (83, 5) (1, 5)
# (83, 5) (1, 5)
# (81, 5) (1, 5)
#
#
# ========================== (2020-09-01 12:31:21.772719)
# ===== NAIVE FORECAST =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:31:21.787719)
# ========== MASK ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
# Mask: [False, False, False, False]
#
#
# ========================== (2020-09-01 12:31:21.790719)
# ========= SPACE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:31:21.798720)
# ======= Test Index =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:31:21.799718)
# ==== GET FUNCTION P0 =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ====================================== (2020-09-01 12:31:21.800720)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ========== THE BARREL HOUSE ==========
# ======================================
#
#
#
# ========================== (2020-09-01 12:31:21.960722)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:31:21.967721)
# ===== OPTIMIZING P0 ======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:32:39.053873)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ============================= (2020-09-01 12:32:39.210873)
# ==== GET FUNCTION P0+Sim ====
# ===== THE BARREL HOUSE ======
# =============================
#
#
#
# ========================================== (2020-09-01 12:32:39.211873)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ============ THE BARREL HOUSE ============
# ==========================================
#
#
#
# ========================== (2020-09-01 12:32:39.345873)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# =========================== (2020-09-01 12:32:39.351874)
# ==== OPTIMIZING P0+Sim ====
# ==== THE BARREL HOUSE =====
# ===========================
#
#
#
# ========================== (2020-09-01 12:33:39.488984)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:33:39.626984)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:33:39.634983)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 2 ============
# ==========================
#
#
#
# ========================== (2020-09-01 12:33:39.634983)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'GENTLEMAN JACK WHSKY OL 750M', '2': 'JACK DANIELS TENN HNY WHSKY  1L', '3': 'GENTLEMAN JACK WHSKY 6PK 1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '2']
# % of weeks without a purchase: 45.78313253012048
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3', '0']
# % of weeks without a purchase: 53.01204819277109
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '3']
# % of weeks without a purchase: 49.39759036144578
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY 6PK 1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '1', '0']
# % of weeks without a purchase: 33.33333333333333
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY 6PK 1L
#
#
# ========================== (2020-09-01 12:34:24.830862)
# ====== WHITE NOISE =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#       lb_stat  lb_pvalue
# 12  23.922535   0.020840
# 24  45.414544   0.005201
# 48  99.152623   0.000020
#
# Is Data White Noise: False
#        lb_stat  lb_pvalue
# 12   25.814484   0.011401
# 24   50.372270   0.001269
# 48  100.845296   0.000013
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  10.794767   0.546584
# 24  29.686533   0.195359
# 48  53.100408   0.284097
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12   8.057662   0.780608
# 24  17.817943   0.811750
# 48  41.544821   0.733036
#
# Is Data White Noise: True
#
#
# ========================== (2020-09-01 12:34:24.854863)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (80, 5) (1, 5)
#
#
# ========================== (2020-09-01 12:34:24.862863)
# ========= NAIVE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#   ID      Best Type  Best RMSE All Naives  \
# 0  0           last   1.279671         []
# 1  1           last   0.397118         []
# 2  2  seasonal_last   0.583337         []
# 3  3           mean   0.532525         []
#
#                                            All RMSEs  \
# 0  [[1.2796706251393728, 1.655747949478816, 1.324...
# 1  [[0.3971180356035492, 1.0727385943033805, 0.73...
# 2  [[0.9401093055023353, 0.5833369983034572, 0.76...
# 3  [[0.5741726496470821, 0.6294921160859183, 0.53...
#
#                        All Types  \
# 0  [[last, seasonal_last, mean]]
# 1  [[last, seasonal_last, mean]]
# 2  [[last, seasonal_last, mean]]
# 3  [[last, seasonal_last, mean]]
#
#                                         Best Naive
# 0                            NaiveForecaster(sp=4)
# 1                            NaiveForecaster(sp=4)
# 2  NaiveForecaster(sp=4, strategy='seasonal_last')
# 3           NaiveForecaster(sp=4, strategy='mean')
#
#
# ========================== (2020-09-01 12:34:25.456862)
# ====== Multivar P0 =======
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  5.6min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  5.6min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================== (2020-09-01 12:40:01.590074)
# ==== Multivar P0+Sim =====
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  5.5min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  5.5min finished
# ========================== (2020-09-01 12:45:34.257313)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:45:34.267312)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 2 ============
# ==========================
#
#
#
# =========================== (2020-09-01 12:45:34.268311)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ==== THE BARREL HOUSE =====
# ============ 2 ============
# ===========================
#
#
#
# ========================== (2020-09-01 12:45:34.271310)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'GENTLEMAN JACK WHSKY OL 750M', '2': 'JACK DANIELS TENN HNY WHSKY  1L', '3': 'GENTLEMAN JACK WHSKY 6PK 1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '2']
# % of weeks without a purchase: 45.78313253012048
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3', '0']
# % of weeks without a purchase: 53.01204819277109
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '3']
# % of weeks without a purchase: 49.39759036144578
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY 6PK 1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '1', '0']
# % of weeks without a purchase: 33.33333333333333
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY 6PK 1L
#
#
# ========================== (2020-09-01 12:46:13.891312)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (80, 5) (1, 5)
#
#
# ========================== (2020-09-01 12:46:13.899314)
# ===== NAIVE FORECAST =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:46:13.914311)
# ========== MASK ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
# Mask: [False, False, False, False]
#
#
# ========================== (2020-09-01 12:46:13.916310)
# ========= SPACE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:46:13.926310)
# ======= Test Index =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:46:13.927315)
# ==== GET FUNCTION P0 =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ====================================== (2020-09-01 12:46:13.928324)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ========== THE BARREL HOUSE ==========
# ======================================
#
#
#
# ========================== (2020-09-01 12:46:14.075310)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:46:14.079311)
# ===== OPTIMIZING P0 ======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:47:15.067495)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ============================= (2020-09-01 12:47:15.262193)
# ==== GET FUNCTION P0+Sim ====
# ===== THE BARREL HOUSE ======
# =============================
#
#
#
# ========================================== (2020-09-01 12:47:15.263189)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ============ THE BARREL HOUSE ============
# ==========================================
#
#
#
# ========================== (2020-09-01 12:47:15.457061)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# =========================== (2020-09-01 12:47:15.462058)
# ==== OPTIMIZING P0+Sim ====
# ==== THE BARREL HOUSE =====
# ===========================
#
#
#
# ========================== (2020-09-01 12:48:14.392665)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:48:14.559931)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:48:14.565931)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 3 ============
# ==========================
#
#
#
# ========================== (2020-09-01 12:48:14.566931)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'GENTLEMAN JACK WHSKY OL 750M', '2': 'JACK DANIELS TENN HNY WHSKY  1L', '3': 'GENTLEMAN JACK WHSKY 6PK 1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '2']
# % of weeks without a purchase: 46.34146341463415
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3', '0']
# % of weeks without a purchase: 52.4390243902439
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '3']
# % of weeks without a purchase: 48.78048780487805
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY 6PK 1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '1', '0']
# % of weeks without a purchase: 33.75
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY 6PK 1L
#
#
# ========================== (2020-09-01 12:48:56.535960)
# ====== WHITE NOISE =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#       lb_stat  lb_pvalue
# 12  22.966606   0.028011
# 24  43.950059   0.007733
# 48  96.983960   0.000037
#
# Is Data White Noise: False
#        lb_stat  lb_pvalue
# 12   27.402860   0.006758
# 24   51.649912   0.000869
# 48  103.761135   0.000006
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  10.052476   0.611357
# 24  29.222626   0.211865
# 48  50.699491   0.367565
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12   7.723903   0.806317
# 24  17.026775   0.847518
# 48  40.563386   0.768264
#
# Is Data White Noise: True
#
#
# ========================== (2020-09-01 12:48:56.559962)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (81, 5) (1, 5)
# (81, 5) (1, 5)
# (81, 5) (1, 5)
# (79, 5) (1, 5)
#
#
# ========================== (2020-09-01 12:48:56.567965)
# ========= NAIVE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#   ID      Best Type  Best RMSE All Naives  \
# 0  0           last   1.309084         []
# 1  1           last   0.575651         []
# 2  2  seasonal_last   0.456328         []
# 3  3           last   0.514092         []
#
#                                            All RMSEs  \
# 0  [[1.3090836993967807, 1.5116570412722945, 1.34...
# 1  [[0.5756510191046259, 0.8723064569251162, 0.77...
# 2  [[0.9401093055023353, 0.4563275126911478, 0.73...
# 3  [[0.5140918075121166, 0.680195528305364, 0.545...
#
#                        All Types  \
# 0  [[last, seasonal_last, mean]]
# 1  [[last, seasonal_last, mean]]
# 2  [[last, seasonal_last, mean]]
# 3  [[last, seasonal_last, mean]]
#
#                                         Best Naive
# 0                            NaiveForecaster(sp=4)
# 1                            NaiveForecaster(sp=4)
# 2  NaiveForecaster(sp=4, strategy='seasonal_last')
# 3                            NaiveForecaster(sp=4)
#
#
# ========================== (2020-09-01 12:48:57.055963)
# ====== Multivar P0 =======
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  5.7min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  5.7min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================== (2020-09-01 12:54:37.350183)
# ==== Multivar P0+Sim =====
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  5.7min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  5.7min finished
# ========================== (2020-09-01 13:00:19.716605)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 13:00:19.722604)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 3 ============
# ==========================
#
#
#
# =========================== (2020-09-01 13:00:19.722604)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ==== THE BARREL HOUSE =====
# ============ 3 ============
# ===========================
#
#
#
# ========================== (2020-09-01 13:00:19.724602)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# ...
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
#
#
# ===================== (2020-09-01 14:07:33.336922)
# ==== WHITE NOISE ====
# ======= SPECS =======
# =====================
#
#       lb_stat  lb_pvalue
# 12  15.010561   0.240859
# 24  26.255626   0.340323
# 48  46.813983   0.521457
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12  28.602170   0.004512
# 24  40.565661   0.018579
# 48  53.111411   0.283742
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12  26.462991   0.009225
# 24  37.259357   0.041220
# 48  54.606396   0.237935
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12   6.590230   0.883464
# 24  11.084958   0.988393
# 48  32.593075   0.956498
#
# Is Data White Noise: True
#
#
# ==================== (2020-09-01 14:07:33.353950)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (82, 5) (1, 5)
#
#
# =============== (2020-09-01 14:07:33.355924)
# ==== NAIVE ====
# ==== SPECS ====
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.033192         []
# 1  1      mean   0.118510         []
# 2  2      mean   0.224583         []
# 3  3      mean   0.067342         []
#
#                                            All RMSEs  \
# 0  [[0.0935827577097994, 0.10896925774528339, 0.0...
# 1  [[0.17264955504702825, 0.17422646327023725, 0....
# 2  [[0.4363032505606732, 0.3550157822095886, 0.22...
# 3  [[0.09595064453644367, 0.12091221353553756, 0....
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-01 14:07:33.647951)
# ==== Multivar P0 ====
# ======= SPECS =======
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  3.5min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  3.5min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-01 14:11:05.054107)
# ==== Multivar P0+Sim ====
# ========= SPECS =========
# =========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  3.1min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  3.1min finished
# =================== (2020-09-01 14:14:13.546774)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ========================== (2020-09-01 14:14:13.553770)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ========= SPECS ==========
# =========== 2 ============
# ==========================
#
#
#
# =========================== (2020-09-01 14:14:13.553770)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ========== SPECS ==========
# ============ 2 ============
# ===========================
#
#
#
# ================== (2020-09-01 14:14:13.556773)
# ==== GET DATA ====
# ===== SPECS ======
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS TENN HNY WHSKY  1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 8.433734939759036
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1']
# % of weeks without a purchase: 2.4096385542168677
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
#
#
# ==================== (2020-09-01 14:14:43.020774)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (82, 5) (1, 5)
#
#
# ======================== (2020-09-01 14:14:43.024775)
# ==== NAIVE FORECAST ====
# ======== SPECS =========
# ========================
#
#
#
# =============== (2020-09-01 14:14:43.039770)
# ==== MASK =====
# ==== SPECS ====
# ===============
#
# Mask: [False, False, False, False]
#
#
# =============== (2020-09-01 14:14:43.041774)
# ==== SPACE ====
# ==== SPECS ====
# ===============
#
#
#
# ==================== (2020-09-01 14:14:43.050772)
# ==== Test Index ====
# ====== SPECS =======
# ====================
#
#
#
# ========================= (2020-09-01 14:14:43.051775)
# ==== GET FUNCTION P0 ====
# ========= SPECS =========
# =========================
#
#
#
# ====================================== (2020-09-01 14:14:43.051775)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# =============== SPECS ================
# ======================================
#
#
#
# =================== (2020-09-01 14:14:43.145770)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ======================= (2020-09-01 14:14:43.148770)
# ==== OPTIMIZING P0 ====
# ======== SPECS ========
# =======================
#
#
#
# =================== (2020-09-01 14:15:31.613771)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ============================= (2020-09-01 14:15:31.704772)
# ==== GET FUNCTION P0+Sim ====
# =========== SPECS ===========
# =============================
#
#
#
# ========================================== (2020-09-01 14:15:31.705773)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ================= SPECS ==================
# ==========================================
#
#
#
# =================== (2020-09-01 14:15:31.775770)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =========================== (2020-09-01 14:15:31.780773)
# ==== OPTIMIZING P0+Sim ====
# ========== SPECS ==========
# ===========================
#
#
#
# =================== (2020-09-01 14:16:17.468244)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =================== (2020-09-01 14:16:17.537244)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ========================== (2020-09-01 14:16:17.542271)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ========= SPECS ==========
# =========== 3 ============
# ==========================
#
#
#
# ================== (2020-09-01 14:16:17.542271)
# ==== GET DATA ====
# ===== SPECS ======
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS TENN HNY WHSKY  1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 8.536585365853659
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1']
# % of weeks without a purchase: 2.4390243902439024
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
#
#
# ===================== (2020-09-01 14:16:45.380273)
# ==== WHITE NOISE ====
# ======= SPECS =======
# =====================
#
#       lb_stat  lb_pvalue
# 12  14.591506   0.264539
# 24  25.708961   0.368096
# 48  45.847359   0.561475
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12  28.056071   0.005429
# 24  39.797909   0.022480
# 48  52.199800   0.314062
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12  26.241054   0.009922
# 24  37.090548   0.042858
# 48  54.361071   0.245108
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12   6.530656   0.887010
# 24  11.020075   0.988868
# 48  32.169399   0.961455
#
# Is Data White Noise: True
#
#
# ==================== (2020-09-01 14:16:45.391274)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (81, 5) (1, 5)
# (81, 5) (1, 5)
# (81, 5) (1, 5)
# (81, 5) (1, 5)
#
#
# =============== (2020-09-01 14:16:45.395245)
# ==== NAIVE ====
# ==== SPECS ====
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.051513         []
# 1  1      mean   0.109428         []
# 2  2      mean   0.221377         []
# 3  3      mean   0.086918         []
#
#                                            All RMSEs  \
# 0  [[0.12459174747365168, 0.13927072207458754, 0....
# 1  [[0.18390429323643792, 0.17762873456667566, 0....
# 2  [[0.4245652552570759, 0.3288519908859398, 0.22...
# 3  [[0.08808657027865822, 0.126322489261891, 0.08...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-01 14:16:45.672243)
# ==== Multivar P0 ====
# ======= SPECS =======
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  2.8min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  2.8min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-01 14:19:33.489625)
# ==== Multivar P0+Sim ====
# ========= SPECS =========
# =========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  3.0min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  3.0min finished
# =================== (2020-09-01 14:22:32.867615)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ========================== (2020-09-01 14:22:32.872645)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ========= SPECS ==========
# =========== 3 ============
# ==========================
#
#
#
# =========================== (2020-09-01 14:22:32.872645)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ========== SPECS ==========
# ============ 3 ============
# ===========================
#
#
#
# ================== (2020-09-01 14:22:32.873643)
# ==== GET DATA ====
# ===== SPECS ======
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS TENN HNY WHSKY  1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 8.536585365853659
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1']
# % of weeks without a purchase: 2.4390243902439024
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
#
#
# ==================== (2020-09-01 14:22:59.826613)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (81, 5) (1, 5)
# (81, 5) (1, 5)
# (81, 5) (1, 5)
# (81, 5) (1, 5)
#
#
# ======================== (2020-09-01 14:22:59.829641)
# ==== NAIVE FORECAST ====
# ======== SPECS =========
# ========================
#
#
#
# =============== (2020-09-01 14:22:59.839640)
# ==== MASK =====
# ==== SPECS ====
# ===============
#
# Mask: [False, False, False, False]
#
#
# =============== (2020-09-01 14:22:59.841640)
# ==== SPACE ====
# ==== SPECS ====
# ===============
#
#
#
# ==================== (2020-09-01 14:22:59.846640)
# ==== Test Index ====
# ====== SPECS =======
# ====================
#
#
#
# ========================= (2020-09-01 14:22:59.847653)
# ==== GET FUNCTION P0 ====
# ========= SPECS =========
# =========================
#
#
#
# ====================================== (2020-09-01 14:22:59.847653)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# =============== SPECS ================
# ======================================
#
#
#
# =================== (2020-09-01 14:22:59.961611)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ======================= (2020-09-01 14:22:59.967611)
# ==== OPTIMIZING P0 ====
# ======== SPECS ========
# =======================
#
#
#
# =================== (2020-09-01 14:23:47.759610)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ============================= (2020-09-01 14:23:47.860610)
# ==== GET FUNCTION P0+Sim ====
# =========== SPECS ===========
# =============================
#
#
#
# ========================================== (2020-09-01 14:23:47.860610)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ================= SPECS ==================
# ==========================================
#
#
#
# =================== (2020-09-01 14:23:47.942639)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =========================== (2020-09-01 14:23:47.948611)
# ==== OPTIMIZING P0+Sim ====
# ========== SPECS ==========
# ===========================
#
#
#
# =================== (2020-09-01 14:24:35.753130)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =================== (2020-09-01 14:24:35.842128)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ========================== (2020-09-01 14:24:35.852127)
# ==== Saving to PICKLE ====
# ==== SUP PREM WHISKEY ====
# ==========================
#
# Pickle File  full_models_SUP PREM WHISKEY_Prod4_Sim2_Per123.pkl  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns
# Pickle File  full_opt_SUP PREM WHISKEY_Prod4_Sim2_Per123.pkl  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns
#
#
# ========================== (2020-09-01 14:24:35.984156)
# ==== Saving to EXCEL =====
# ==== SUP PREM WHISKEY ====
# ==========================
#
# EXCEL File  Output_SUP PREM WHISKEY_Prod4_Sim2_Per123.xlsx  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns

# %% [markdown]
# # Print out

# %% [markdown]
# ## Models

# %%
full_models[outputColsModels]
# Out:
#           Chain Master                          Product  Period to Last  \
# 1                         JACK DANIELS BLK WHSKY  1.75L               1
# 5                         JACK DANIELS BLK WHSKY  1.75L               2
# 9                         JACK DANIELS BLK WHSKY  1.75L               3
# 0                            JACK DANIELS BLK WHSKY  1L               1
# 4                            JACK DANIELS BLK WHSKY  1L               2
# 8                            JACK DANIELS BLK WHSKY  1L               3
# 2                          JACK DANIELS BLK WHSKY  750M               1
# 6                          JACK DANIELS BLK WHSKY  750M               2
# 10                         JACK DANIELS BLK WHSKY  750M               3
# 3                        JACK DANIELS BLK WHSKY SQ 375M               1
# 7                        JACK DANIELS BLK WHSKY SQ 375M               2
# 11                       JACK DANIELS BLK WHSKY SQ 375M               3
# 37               SPECS    JACK DANIELS BLK WHSKY  1.75L               1
# 41               SPECS    JACK DANIELS BLK WHSKY  1.75L               2
# 45               SPECS    JACK DANIELS BLK WHSKY  1.75L               3
# 36               SPECS       JACK DANIELS BLK WHSKY  1L               1
# 40               SPECS       JACK DANIELS BLK WHSKY  1L               2
# 44               SPECS       JACK DANIELS BLK WHSKY  1L               3
# 38               SPECS     JACK DANIELS BLK WHSKY  750M               1
# 42               SPECS     JACK DANIELS BLK WHSKY  750M               2
# 46               SPECS     JACK DANIELS BLK WHSKY  750M               3
# 39               SPECS  JACK DANIELS TENN HNY WHSKY  1L               1
# 43               SPECS  JACK DANIELS TENN HNY WHSKY  1L               2
# 47               SPECS  JACK DANIELS TENN HNY WHSKY  1L               3
# 15    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               1
# 19    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               2
# 23    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               3
# 13    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               1
# 17    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               2
# 21    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               3
# 12    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               1
# 16    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               2
# 20    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               3
# 14    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               1
# 18    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               2
# 22    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               3
# 24  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               1
# 28  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               2
# 32  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               3
# 26  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               1
# 30  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               2
# 34  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               3
# 25  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               1
# 29  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               2
# 33  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               3
# 27  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               1
# 31  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               2
# 35  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               3
#
#     White Noise Naive Best Type  Naive Best RMSE P0 Best Model Name  \
# 1         False            last         0.324455       auto_SARIMAX
# 5         False            mean         0.323943       auto_SARIMAX
# 9         False            mean         0.319180       auto_SARIMAX
# 0          True            mean         0.043169            SARIMAX
# 4          True            mean         0.021557                 ML
# 8          True            mean         0.033917                 ML
# 2         False            mean         0.427990            SARIMAX
# 6         False            mean         0.373199            SARIMAX
# 10        False            mean         0.373056            SARIMAX
# 3         False            mean         0.798321                 ML
# 7         False            mean         0.669609                 ML
# 11        False            mean         0.627867       auto_SARIMAX
# 37         True            mean         0.159196            SARIMAX
# 41         True            mean         0.118510            SARIMAX
# 45         True            mean         0.109428            SARIMAX
# 36         True            mean         0.060885            SARIMAX
# 40         True            mean         0.033192                 ML
# 44         True            mean         0.051513                 ML
# 38         True            mean         0.276661       auto_SARIMAX
# 42         True            mean         0.224583                 ML
# 46         True            mean         0.221377                 ML
# 39         True            mean         0.075384            SARIMAX
# 43         True            mean         0.067342            SARIMAX
# 47         True            mean         0.086918                 ML
# 15         True            mean         0.611153                 ML
# 19         True            mean         0.532525                 ML
# 23         True            last         0.514092                 ML
# 13        False            last         0.508452                 ML
# 17        False            last         0.397118                 ML
# 21        False            last         0.575651       auto_SARIMAX
# 12        False            mean         1.149908                 ML
# 16        False            last         1.279671                 ML
# 20        False            last         1.309084                 ML
# 14         True   seasonal_last         0.539165                 ML
# 18         True   seasonal_last         0.583337                 ML
# 22         True   seasonal_last         0.456328                 ML
# 24        False            mean         1.192388       auto_SARIMAX
# 28        False            mean         1.152468       auto_SARIMAX
# 32        False            last         1.110996       auto_SARIMAX
# 26        False            mean         0.083096                 ML
# 30        False            mean         0.065297                 ML
# 34        False            mean         0.056411            SARIMAX
# 25        False            mean         0.706690            SARIMAX
# 29        False            mean         0.620501            SARIMAX
# 33        False            mean         0.664711                 ML
# 27        False            mean         0.804074       auto_SARIMAX
# 31        False            mean         0.675541            Prophet
# 35        False            mean         0.630851       auto_SARIMAX
#
#     P0 Best Model RMSE P0+Sim Best Model Name  P0+Sim Best Model RMSE
# 1             0.243913           auto_SARIMAX                0.240036
# 5             0.219089           auto_SARIMAX                0.242885
# 9             0.231060                     ML                0.239514
# 0             0.028845                SARIMAX                0.021750
# 4             0.034618                     ML                0.030959
# 8             0.057793                     ML                0.051629
# 2             0.260258           auto_SARIMAX                0.311017
# 6             0.276076           auto_SARIMAX                0.293355
# 10            0.294087           auto_SARIMAX                0.278064
# 3             0.625328                     ML                0.550441
# 7             0.678531                     ML                0.614604
# 11            0.631077           auto_SARIMAX                0.546198
# 37            0.106995                SARIMAX                0.146993
# 41            0.095943                SARIMAX                0.129294
# 45            0.097419                SARIMAX                0.152967
# 36            0.036516                     ML                0.036515
# 40            0.048617                     ML                0.043980
# 44            0.078627                     ML                0.065205
# 38            0.257020           auto_SARIMAX                0.249692
# 42            0.247969                SARIMAX                0.234468
# 46            0.272304           auto_SARIMAX                0.264599
# 39            0.047686                SARIMAX                0.048203
# 43            0.067426                SARIMAX                0.068372
# 47            0.082990                     ML                0.082971
# 15            0.191544                     ML                0.191544
# 19            0.210643                     ML                0.210643
# 23            0.238877                     ML                0.235016
# 13            0.615271                     ML                0.615889
# 17            0.614912                     ML                0.615411
# 21            0.752658           auto_SARIMAX                0.780690
# 12            0.722963           auto_SARIMAX                0.728144
# 16            0.733968                     ML                0.751184
# 20            0.634989                     ML                0.678164
# 14            0.141021                     ML                0.141353
# 18            0.152653                     ML                0.157201
# 22            0.152653                     ML                0.157201
# 24            0.737526           auto_SARIMAX                0.671420
# 28            0.791896           auto_SARIMAX                0.769547
# 32            0.654468           auto_SARIMAX                0.719308
# 26            0.099956                     ML                0.099927
# 30            0.108532                     ML                0.108481
# 34            0.111910                SARIMAX                0.074185
# 25            0.577988           auto_SARIMAX                0.504248
# 29            0.580915           auto_SARIMAX                0.518207
# 33            0.638930           auto_SARIMAX                0.573150
# 27            0.663140                     ML                0.570431
# 31            0.715019                     ML                0.653154
# 35            0.629432           auto_SARIMAX                0.652129

# %% [markdown]
# ## Optimizer

# %% [markdown]
# ### Summary by Chain

# %%
full_chain_summary
# Out:
#          Chain Master  P0 Non-Opt Revenue  P0 Opt Revenue  P0 Opt Diff  \
# 0                                289570.0        288490.0      -1080.0
# 1               SPECS            220032.0        225619.0       5587.0
# 2    THE BARREL HOUSE              4102.0          4103.0          1.0
# 3  WESTERN BEV LIQ TX            116244.0        133381.0      17137.0
#
#    P0 Opt Diff Ratio  P0+Sim Non-Opt Revenue  P0+Sim Opt Revenue  \
# 0           0.996270                260560.0            301111.0
# 1           1.025392                230230.0            843262.0
# 2           1.000244                  4408.0             68072.0
# 3           1.147423                 88997.0           1686069.0
#
#    P0+Sim Opt Diff  P0+Sim Opt Diff Ratio
# 0          40551.0               1.155630
# 1         613032.0               3.662694
# 2          63664.0              15.442831
# 3        1597072.0              18.945234

# %%
print("WRITE this value in the summary table in Git hub --->",round(full_chain_summary[full_chain_summary['Chain Master']=='']['P0+Sim Opt Diff Ratio'].item(),4))
# Out:
# WRITE this value in the summary table in Git hub ---> 1.1556

# %% [markdown]
# Link to the Git Hub Summary Table: https://github.com/ngupta23/msds_capstone/issues/84

# %% [markdown]
# ### Summary by Chain and Product

# %%
full_summary
# Out:
#           Chain Master                          Product  P0 Non-Opt Revenue  \
# 0                         JACK DANIELS BLK WHSKY  1.75L             78808.0
# 1                            JACK DANIELS BLK WHSKY  1L            162183.0
# 2                          JACK DANIELS BLK WHSKY  750M             47810.0
# 3                        JACK DANIELS BLK WHSKY SQ 375M               769.0
# 4                SPECS    JACK DANIELS BLK WHSKY  1.75L             31102.0
# 5                SPECS       JACK DANIELS BLK WHSKY  1L            163171.0
# 6                SPECS     JACK DANIELS BLK WHSKY  750M             14658.0
# 7                SPECS  JACK DANIELS TENN HNY WHSKY  1L             11101.0
# 8     THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L              1157.0
# 9     THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               334.0
# 10    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               866.0
# 11    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L              1745.0
# 12  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L             18820.0
# 13  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L             48563.0
# 14  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M             35987.0
# 15  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M             12874.0
#
#     P0 Opt Revenue  P0 Opt Diff  P0 Opt Diff Ratio  P0+Sim Non-Opt Revenue  \
# 0          80639.0       1831.0           1.023234                 51425.0
# 1         161246.0       -937.0           0.994223                163994.0
# 2          45858.0      -1952.0           0.959172                 44356.0
# 3            747.0        -22.0           0.971391                   785.0
# 4          30562.0       -540.0           0.982638                 46794.0
# 5         162677.0       -494.0           0.996973                162021.0
# 6          21915.0       7257.0           1.495088                 10345.0
# 7          10465.0       -636.0           0.942708                 11070.0
# 8           1176.0         19.0           1.016422                  1157.0
# 9            341.0          7.0           1.020958                   444.0
# 10           855.0        -11.0           0.987298                   818.0
# 11          1731.0        -14.0           0.991977                  1989.0
# 12         31029.0      12209.0           1.648725                 24646.0
# 13         48341.0       -222.0           0.995429                 53166.0
# 14         36817.0        830.0           1.023064                 10896.0
# 15         17194.0       4320.0           1.335560                   289.0
#
#     P0+Sim Opt Revenue  P0+Sim Opt Diff  P0+Sim Opt Diff Ratio
# 0              66144.0          14719.0               1.286223
# 1             171304.0           7310.0               1.044575
# 2              62913.0          18557.0               1.418365
# 3                750.0            -35.0               0.955414
# 4             654497.0         607703.0              13.986772
# 5             161172.0           -849.0               0.994760
# 6              17615.0           7270.0               1.702755
# 7               9978.0          -1092.0               0.901355
# 8               1167.0             10.0               1.008643
# 9                651.0            207.0               1.466216
# 10             64304.0          63486.0              78.611247
# 11              1950.0            -39.0               0.980392
# 12             27173.0           2527.0               1.102532
# 13             43825.0          -9341.0               0.824305
# 14             11460.0            564.0               1.051762
# 15           1603611.0        1603322.0            5548.826990

# %% [markdown]
# ### P0 Optimizer

# %%
full_opt[outputColsOptP0]
# Out:
#           Chain Master                          Product  Period to Last  \
# 1                         JACK DANIELS BLK WHSKY  1.75L               1
# 5                         JACK DANIELS BLK WHSKY  1.75L               2
# 9                         JACK DANIELS BLK WHSKY  1.75L               3
# 0                            JACK DANIELS BLK WHSKY  1L               1
# 4                            JACK DANIELS BLK WHSKY  1L               2
# 8                            JACK DANIELS BLK WHSKY  1L               3
# 2                          JACK DANIELS BLK WHSKY  750M               1
# 6                          JACK DANIELS BLK WHSKY  750M               2
# 10                         JACK DANIELS BLK WHSKY  750M               3
# 3                        JACK DANIELS BLK WHSKY SQ 375M               1
# 7                        JACK DANIELS BLK WHSKY SQ 375M               2
# 11                       JACK DANIELS BLK WHSKY SQ 375M               3
# 37               SPECS    JACK DANIELS BLK WHSKY  1.75L               1
# 41               SPECS    JACK DANIELS BLK WHSKY  1.75L               2
# 45               SPECS    JACK DANIELS BLK WHSKY  1.75L               3
# 36               SPECS       JACK DANIELS BLK WHSKY  1L               1
# 40               SPECS       JACK DANIELS BLK WHSKY  1L               2
# 44               SPECS       JACK DANIELS BLK WHSKY  1L               3
# 38               SPECS     JACK DANIELS BLK WHSKY  750M               1
# 42               SPECS     JACK DANIELS BLK WHSKY  750M               2
# 46               SPECS     JACK DANIELS BLK WHSKY  750M               3
# 39               SPECS  JACK DANIELS TENN HNY WHSKY  1L               1
# 43               SPECS  JACK DANIELS TENN HNY WHSKY  1L               2
# 47               SPECS  JACK DANIELS TENN HNY WHSKY  1L               3
# 15    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               1
# 19    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               2
# 23    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               3
# 13    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               1
# 17    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               2
# 21    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               3
# 12    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               1
# 16    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               2
# 20    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               3
# 14    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               1
# 18    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               2
# 22    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               3
# 24  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               1
# 28  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               2
# 32  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               3
# 26  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               1
# 30  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               2
# 34  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               3
# 25  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               1
# 29  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               2
# 33  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               3
# 27  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               1
# 31  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               2
# 35  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               3
#
#     P0 Non-Opt Price  P0 Non-Opt Demand  P0 Non-Opt Revenue  \
# 1             185.65                224               41518
# 5             184.71                 91               16867
# 9             182.45                112               20423
# 0             229.81                310               71287
# 4             229.69                196               45027
# 8             230.09                199               45869
# 2             222.36                159               35308
# 6             222.36                 45               10052
# 10            222.36                 11                2450
# 3             188.30                  0                  93
# 7             195.60                  0                  96
# 11            195.60                  3                 580
# 37            185.59                 51                9481
# 41            184.56                 61               11168
# 45            184.94                 57               10453
# 36            229.53                239               54868
# 40            229.53                236               54108
# 44            229.53                236               54195
# 38            222.36                 20                4519
# 42            222.36                 23                5072
# 46            222.36                 23                5067
# 39            229.53                 16                3714
# 43            229.53                 16                3763
# 47            229.53                 16                3624
# 15            286.87                  1                 426
# 19            292.57                  2                 457
# 23            298.08                  1                 274
# 13            274.14                  0                  34
# 17            291.93                  0                  37
# 21            291.93                  1                 263
# 12            239.01                  1                 287
# 16            239.01                  1                 287
# 20            234.05                  1                 292
# 14            239.01                  2                 583
# 18            238.41                  2                 581
# 22            238.41                  2                 581
# 24            185.59                 96               17837
# 28            185.59                  4                 706
# 32            180.46                  2                 277
# 26            230.79                 59               13543
# 30            229.89                 59               13491
# 34            230.98                 93               21529
# 25            222.36                148               32964
# 29            222.36                  8                1783
# 33            222.36                  6                1240
# 27            188.30                  9                1770
# 31            195.60                 56               10948
# 35            195.60                  1                 156
#
#     P0 Non-Opt Chain Master Revenue  P0 Optimal Price  P0 Demand  P0 Revenue  \
# 1                            148206            185.80        224       41691
# 5                             72043            185.81         94       17380
# 9                             69322            185.82        116       21568
# 0                            148206            229.45        307       70524
# 4                             72043            229.45        196       44980
# 8                             69322            229.45        199       45742
# 2                            148206            220.34        155       34211
# 6                             72043            220.34         43        9439
# 10                            69322            220.33         10        2208
# 3                            148206            215.82          0         106
# 7                             72043            215.81          0         106
# 11                            69322            215.81          2         535
# 37                            72582            182.70         48        8747
# 41                            74111            185.07         61       11324
# 45                            73340            185.06         57       10491
# 36                            72582            229.36        238       54598
# 40                            74111            229.06        236       53996
# 44                            73340            229.06        236       54083
# 38                            72582            205.27         58       11914
# 42                            74111            219.36         23        5003
# 46                            73340            219.31         23        4998
# 39                            72582            225.86         15        3495
# 43                            74111            224.02         15        3433
# 47                            73340            224.02         16        3537
# 15                             1330            296.11          1         440
# 19                             1362            296.11          2         463
# 23                             1411            296.11          1         273
# 13                             1330            299.57          0          38
# 17                             1362            299.57          0          38
# 21                             1411            299.57          1         265
# 12                             1330            234.36          1         281
# 16                             1362            234.36          1         281
# 20                             1411            234.36          1         293
# 14                             1330            236.70          2         577
# 18                             1362            236.70          2         577
# 22                             1411            236.70          2         577
# 24                            66115            191.23        155       29556
# 28                            26928            189.33          5         959
# 32                            23203            190.37          3         514
# 26                            66115            229.42         59       13463
# 30                            26928            228.07         59       13384
# 34                            23203            230.85         93       21494
# 25                            66115            216.66        156       33873
# 29                            26928            219.31          8        1772
# 33                            23203            210.18          6        1172
# 27                            66115            186.27         10        1803
# 31                            26928            180.65         84       15246
# 35                            23203            213.20          1         145
#
#     P0 Chain Master Revenue
# 1                    146532
# 5                     71906
# 9                     70052
# 0                    146532
# 4                     71906
# 8                     70052
# 2                    146532
# 6                     71906
# 10                    70052
# 3                    146532
# 7                     71906
# 11                    70052
# 37                    78753
# 41                    73757
# 45                    73108
# 36                    78753
# 40                    73757
# 44                    73108
# 38                    78753
# 42                    73757
# 46                    73108
# 39                    78753
# 43                    73757
# 47                    73108
# 15                     1336
# 19                     1359
# 23                     1408
# 13                     1336
# 17                     1359
# 21                     1408
# 12                     1336
# 16                     1359
# 20                     1408
# 14                     1336
# 18                     1359
# 22                     1408
# 24                    78695
# 28                    31361
# 32                    23326
# 26                    78695
# 30                    31361
# 34                    23326
# 25                    78695
# 29                    31361
# 33                    23326
# 27                    78695
# 31                    31361
# 35                    23326

# %% [markdown]
# ### P0+Sim Optimizer

# %%
full_opt[outputColsOptP0Sim]
# Out:
#           Chain Master                          Product  Period to Last  \
# 1                         JACK DANIELS BLK WHSKY  1.75L               1
# 5                         JACK DANIELS BLK WHSKY  1.75L               2
# 9                         JACK DANIELS BLK WHSKY  1.75L               3
# 0                            JACK DANIELS BLK WHSKY  1L               1
# 4                            JACK DANIELS BLK WHSKY  1L               2
# 8                            JACK DANIELS BLK WHSKY  1L               3
# 2                          JACK DANIELS BLK WHSKY  750M               1
# 6                          JACK DANIELS BLK WHSKY  750M               2
# 10                         JACK DANIELS BLK WHSKY  750M               3
# 3                        JACK DANIELS BLK WHSKY SQ 375M               1
# 7                        JACK DANIELS BLK WHSKY SQ 375M               2
# 11                       JACK DANIELS BLK WHSKY SQ 375M               3
# 37               SPECS    JACK DANIELS BLK WHSKY  1.75L               1
# 41               SPECS    JACK DANIELS BLK WHSKY  1.75L               2
# 45               SPECS    JACK DANIELS BLK WHSKY  1.75L               3
# 36               SPECS       JACK DANIELS BLK WHSKY  1L               1
# 40               SPECS       JACK DANIELS BLK WHSKY  1L               2
# 44               SPECS       JACK DANIELS BLK WHSKY  1L               3
# 38               SPECS     JACK DANIELS BLK WHSKY  750M               1
# 42               SPECS     JACK DANIELS BLK WHSKY  750M               2
# 46               SPECS     JACK DANIELS BLK WHSKY  750M               3
# 39               SPECS  JACK DANIELS TENN HNY WHSKY  1L               1
# 43               SPECS  JACK DANIELS TENN HNY WHSKY  1L               2
# 47               SPECS  JACK DANIELS TENN HNY WHSKY  1L               3
# 15    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               1
# 19    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               2
# 23    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               3
# 13    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               1
# 17    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               2
# 21    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               3
# 12    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               1
# 16    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               2
# 20    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               3
# 14    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               1
# 18    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               2
# 22    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               3
# 24  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               1
# 28  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               2
# 32  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               3
# 26  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               1
# 30  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               2
# 34  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               3
# 25  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               1
# 29  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               2
# 33  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               3
# 27  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               1
# 31  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               2
# 35  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               3
#
#     P0+Sim Non-Opt Price  P0+Sim Non-Opt Demand  P0+Sim Non-Opt Revenue  \
# 1                 185.65                    149                   27660
# 5                 184.71                     82                   15073
# 9                 182.45                     48                    8692
# 0                 229.81                    318                   73098
# 4                 229.69                    196                   45027
# 8                 230.09                    199                   45869
# 2                 222.36                     94                   21010
# 6                 222.36                     47                   10373
# 10                222.36                     58                   12973
# 3                 188.30                      0                      87
# 7                 195.60                      0                      91
# 11                195.60                      3                     607
# 37                185.59                     65                   12072
# 41                184.56                    101                   18571
# 45                184.94                     87                   16151
# 36                229.53                    246                   56559
# 40                229.53                    230                   52812
# 44                229.53                    229                   52650
# 38                222.36                     17                    3886
# 42                222.36                     21                    4581
# 46                222.36                      8                    1878
# 39                229.53                     16                    3701
# 43                229.53                     16                    3746
# 47                229.53                     16                    3623
# 15                286.87                      1                     426
# 19                292.57                      2                     457
# 23                298.08                      1                     274
# 13                274.14                      0                      35
# 17                291.93                      0                      37
# 21                291.93                      1                     372
# 12                239.01                      1                     219
# 16                239.01                      1                     315
# 20                234.05                      1                     284
# 14                239.01                      3                     653
# 18                238.41                      3                     668
# 22                238.41                      3                     668
# 24                185.59                    129                   23867
# 28                185.59                      2                     458
# 32                180.46                      2                     321
# 26                230.79                     59                   13548
# 30                229.89                     59                   13496
# 34                230.98                    113                   26122
# 25                222.36                     32                    7166
# 29                222.36                     11                    2351
# 33                222.36                      6                    1379
# 27                188.30                      1                      97
# 31                195.60                      0                      82
# 35                195.60                      1                     110
#
#     P0+Sim Non-Opt Chain Master Revenue  P0+Sim Optimal Price  P0+Sim Demand  \
# 1                                121855                169.93            208
# 5                                 70564                175.30            128
# 9                                 68142                175.25             48
# 0                                121855                228.75            352
# 4                                 70564                229.47            196
# 8                                 68142                229.46            199
# 2                                121855                224.13            136
# 6                                 70564                211.59             71
# 10                                68142                211.57             83
# 3                                121855                213.21              0
# 7                                 70564                217.36              0
# 11                                68142                217.36              3
# 37                                76218                167.58            167
# 41                                79711                167.40           2001
# 45                                74301                167.22           1743
# 36                                76218                228.33            246
# 40                                79711                228.33            230
# 44                                74301                228.33            229
# 38                                76218                224.05             47
# 42                                79711                224.05             10
# 46                                74301                224.05             22
# 39                                76218                223.21             14
# 43                                79711                223.21             15
# 47                                74301                223.21             16
# 15                                 1333                296.79              1
# 19                                 1477                296.11              2
# 23                                 1598                286.65              1
# 13                                 1333                286.58              0
# 17                                 1477                299.57              0
# 21                                 1598                301.93              2
# 12                                 1333                223.07            286
# 16                                 1477                234.36              1
# 20                                 1598                224.17              1
# 14                                 1333                229.79              3
# 18                                 1477                236.70              3
# 22                                 1598                235.20              3
# 24                                44679                191.03            141
# 28                                16387                176.47              2
# 32                                27932                182.14              0
# 26                                44679                226.99             59
# 30                                16387                230.55             59
# 34                                27932                214.83             79
# 25                                44679                224.24             33
# 29                                16387                224.39             13
# 33                                27932                211.03              5
# 27                                44679                215.81              1
# 31                                16387                208.63              0
# 35                                27932                181.43           8838
#
#     P0+Sim Revenue  P0+Sim Chain Master Revenue
# 1            35336                       146478
# 5            22459                        82468
# 9             8349                        72164
# 0            80574                       146478
# 4            44984                        82468
# 8            45746                        72164
# 2            30469                       146478
# 6            14925                        82468
# 10           17519                        72164
# 3               99                       146478
# 7              101                        82468
# 11             550                        72164
# 37           27980                        97876
# 41          334985                       393100
# 45          291532                       352284
# 36           56263                        97876
# 40           52535                       393100
# 44           52374                       352284
# 38           10430                        97876
# 42            2329                       393100
# 46            4856                       352284
# 39            3204                        97876
# 43            3251                       393100
# 47            3523                       352284
# 15             441                        64827
# 19             463                         1473
# 23             263                         1771
# 13              36                        64827
# 17              38                         1473
# 21             577                         1771
# 12           63723                        64827
# 16             309                         1473
# 20             272                         1771
# 14             628                        64827
# 18             663                         1473
# 22             659                         1771
# 24           26891                        47724
# 28             267                        16850
# 32              15                      1621495
# 26           13325                        47724
# 30           13534                        16850
# 34           16966                      1621495
# 25            7397                        47724
# 29            2961                        16850
# 33            1102                      1621495
# 27             111                        47724
# 31              88                        16850
# 35         1603412                      1621495

# %% [markdown]
# ### Naive

# %%
full_opt[outputColsOptNaive]
# Out:
#           Chain Master                          Product  Period to Last  \
# 1                         JACK DANIELS BLK WHSKY  1.75L               1
# 5                         JACK DANIELS BLK WHSKY  1.75L               2
# 9                         JACK DANIELS BLK WHSKY  1.75L               3
# 0                            JACK DANIELS BLK WHSKY  1L               1
# 4                            JACK DANIELS BLK WHSKY  1L               2
# 8                            JACK DANIELS BLK WHSKY  1L               3
# 2                          JACK DANIELS BLK WHSKY  750M               1
# 6                          JACK DANIELS BLK WHSKY  750M               2
# 10                         JACK DANIELS BLK WHSKY  750M               3
# 3                        JACK DANIELS BLK WHSKY SQ 375M               1
# 7                        JACK DANIELS BLK WHSKY SQ 375M               2
# 11                       JACK DANIELS BLK WHSKY SQ 375M               3
# 37               SPECS    JACK DANIELS BLK WHSKY  1.75L               1
# 41               SPECS    JACK DANIELS BLK WHSKY  1.75L               2
# 45               SPECS    JACK DANIELS BLK WHSKY  1.75L               3
# 36               SPECS       JACK DANIELS BLK WHSKY  1L               1
# 40               SPECS       JACK DANIELS BLK WHSKY  1L               2
# 44               SPECS       JACK DANIELS BLK WHSKY  1L               3
# 38               SPECS     JACK DANIELS BLK WHSKY  750M               1
# 42               SPECS     JACK DANIELS BLK WHSKY  750M               2
# 46               SPECS     JACK DANIELS BLK WHSKY  750M               3
# 39               SPECS  JACK DANIELS TENN HNY WHSKY  1L               1
# 43               SPECS  JACK DANIELS TENN HNY WHSKY  1L               2
# 47               SPECS  JACK DANIELS TENN HNY WHSKY  1L               3
# 15    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               1
# 19    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               2
# 23    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               3
# 13    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               1
# 17    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               2
# 21    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               3
# 12    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               1
# 16    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               2
# 20    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               3
# 14    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               1
# 18    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               2
# 22    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               3
# 24  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               1
# 28  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               2
# 32  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               3
# 26  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               1
# 30  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               2
# 34  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               3
# 25  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               1
# 29  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               2
# 33  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               3
# 27  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               1
# 31  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               2
# 35  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               3
#
#     Actual Price  Actual Demand  Actual Revenue  Actual Chain Master Revenue  \
# 1     185.650112         389.61        72331.14                    281489.82
# 5     184.710623          40.95         7563.90                     87687.18
# 9     182.449915         263.25        48029.94                    129024.66
# 0     229.811232         589.19       135402.48                    281489.82
# 4     229.687258         301.91        69344.88                     87687.18
# 8     230.085045         316.54        72831.12                    129024.66
# 2     222.360000         225.00        50031.00                    281489.82
# 6     222.360000          30.00         6670.80                     87687.18
# 10    222.360000          20.00         4447.20                    129024.66
# 3     188.295238         126.00        23725.20                    281489.82
# 7     195.600000          21.00         4107.60                     87687.18
# 11    195.600000          19.00         3716.40                    129024.66
# 37    185.589744         176.67        32788.14                    162000.42
# 41    184.564103          35.10         6478.20                     68510.28
# 45    184.935385         117.00        21637.44                     83198.40
# 36    229.533835         476.14       109290.24                    162000.42
# 40    229.533835         240.73        55255.68                     68510.28
# 44    229.533835         238.07        54645.12                     83198.40
# 38    222.360000          69.00        15342.84                    162000.42
# 42    222.360000          14.00         3113.04                     68510.28
# 46    222.360000          16.00         3557.76                     83198.40
# 39    229.533835          19.95         4579.20                    162000.42
# 43    229.533835          15.96         3663.36                     68510.28
# 47    229.533835          14.63         3358.08                     83198.40
# 15    286.874200           4.69         1345.44                      5862.96
# 19    292.567164           1.34          392.04                      1027.80
# 23    298.080000           0.00            0.00                      4669.20
# 13    274.144615          13.00         3563.88                      5862.96
# 17    291.927711           0.00            0.00                      1027.80
# 21    291.927711           0.00            0.00                      4669.20
# 12    239.007519           2.66          635.76                      5862.96
# 16    239.007519           2.66          635.76                      1027.80
# 20    234.045113          19.95         4669.20                      4669.20
# 14    239.007519           1.33          317.88                      5862.96
# 18    238.410000           0.00            0.00                      1027.80
# 22    238.410000           0.00            0.00                      4669.20
# 24    185.589744         210.60        39085.20                    122752.68
# 28    185.589744           5.85         1085.70                     22204.50
# 32    180.461538         146.25        26392.50                     44515.14
# 26    230.786122         110.39        25476.48                    122752.68
# 30    229.894737          58.52        13453.44                     22204.50
# 34    230.977444          58.52        13516.80                     44515.14
# 25    222.360000         155.00        34465.80                    122752.68
# 29    222.360000          16.00         3557.76                     22204.50
# 33    222.360000           4.00          889.44                     44515.14
# 27    188.295238         126.00        23725.20                    122752.68
# 31    195.600000          21.00         4107.60                     22204.50
# 35    195.600000          19.00         3716.40                     44515.14
#
#     Naive Prices  Naive Demand  Naive Revenue  Naive Chain Master Revenue
# 1     185.650112     40.950000    7602.372072                92960.401203
# 5     184.710623    157.916707   29168.893345               114657.656235
# 9     182.449915    156.616296   28574.629873               114236.662771
# 0     229.811232    292.610723   67245.230832                92960.401203
# 4     229.687258    292.497317   67182.906670               114657.656235
# 8     230.085045    292.200494   67230.963638               114236.662771
# 2     222.360000     69.590361   15474.112771                92960.401203
# 6     222.360000     70.073171   15581.470244               114657.656235
# 10    222.360000     70.691358   15718.930370               114236.662771
# 3     188.295238     14.013554    2638.685528                92960.401203
# 7     195.600000     13.928354    2724.385976               114657.656235
# 11    195.600000     13.865741    2712.138889               114236.662771
# 37    185.589744     44.962771    8344.629157                67377.335254
# 41    184.564103     45.083049    8320.712439                67316.840805
# 45    184.935385     44.195185    8173.253570                67137.717349
# 36    229.533835    217.722084   49974.584892                67377.335254
# 40    229.533835    217.441500   49910.181293                67316.840805
# 44    229.533835    217.186827   49851.725260                67137.717349
# 38    222.360000     24.319277    5407.634458                67377.335254
# 42    222.360000     24.445122    5435.617317                67316.840805
# 46    222.360000     24.549383    5458.800741                67137.717349
# 39    229.533835     15.903916    3650.486747                67377.335254
# 43    229.533835     15.903232    3650.329756                67316.840805
# 47    229.533835     15.918951    3653.937778                67137.717349
# 15    286.874200      1.169049     335.370107                 2852.240223
# 19    292.567164      1.166913     341.400281                 5743.770881
# 23    298.080000      0.000000       0.000000                 5303.370600
# 13    274.144615      0.000000       0.000000                 2852.240223
# 17    291.927711      0.000000       0.000000                 5743.770881
# 21    291.927711      0.000000       0.000000                 5303.370600
# 12    239.007519      9.200506    2198.990116                 2852.240223
# 16    239.007519     19.950000    4768.200000                 5743.770881
# 20    234.045113     19.950000    4669.200000                 5303.370600
# 14    239.007519      1.330000     317.880000                 2852.240223
# 18    238.410000      2.660000     634.170600                 5743.770881
# 22    238.410000      2.660000     634.170600                 5303.370600
# 24    185.589744    110.560063   20518.813797                48406.991208
# 28    185.589744    111.902500   20767.956282                48812.372432
# 32    180.461538      0.000000       0.000000                28241.967210
# 26    230.786122     66.489207   15344.786307                48406.991208
# 30    229.894737     66.587593   15308.137076                48812.372432
# 34    230.977444     66.688437   15403.524812                28241.967210
# 25    222.360000     41.041148    9125.909702                48406.991208
# 29    222.360000     41.354163    9195.511573                48812.372432
# 33    222.360000     41.827000    9300.651720                28241.967210
# 27    188.295238     18.149590    3417.481401                48406.991208
# 31    195.600000     18.102083    3540.767500                48812.372432
# 35    195.600000     18.086864    3537.790678                28241.967210
