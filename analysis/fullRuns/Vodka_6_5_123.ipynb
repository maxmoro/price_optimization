# %% [markdown]
# # Init

# %%
# %load_ext autoreload
# %autoreload 2

# %%
print("CURRENT FOLDER:")
# %pwd
# Out:
# CURRENT FOLDER:
# 'c:\\max\\Google Drive Max\\Max Shared\\Master Data Science\\2020-05 Capstone A\\msds_capstone\\analysis\\fullRuns'

# %%
import os
import glob
import sys
sys.path.append(os.environ['DEV_AUTOTS'])
sys.path.append(os.environ['CAPSTONE_PYTHON_SOURCE'])
folder = os.environ['CAPSTONE_DATA']

# %%
## Sourcing the .py with all the code##
t='"'+os.environ['CAPSTONE_PYTHON_SOURCE']+'\\fullRun\\fullRun.py'+'"'
# %run -i $t
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# Running Auto Timeseries version: 0.0.24

# %% [markdown]
# # Parameters

# %%
#Parameters

ProdCats = ['ECONOMY VODKA']
TOP_PRODUCTS = 6  # How many products to consider in the category
TOP_SIMILAR = 5  # Get TOP_SIMILAR most similar products
RUN_PERIODS = [1,2,3] # this will run AutoTS and Optimzer for speicfic periods (1 = last, 2 = second to last)

CV_NUM = 10         # number of Cross Valudations  10
OPT_CALLS = 100     # number of calls for the optimizer process   100
OPT_RND_STARTS = 20 # number of random calls for the optimizer process  20

LOG_TRANSFORM = True # Take log of 9L cases to smooth out peaks and valleys
ZERO_ADDER = 0.1 

RESAMPLE_FREQ = 'M'


# Pricing changes every 4 weeks
if RESAMPLE_FREQ == 'M':    FORECAST_PERIOD = 1 #last 4 months as test 
if RESAMPLE_FREQ == 'W':    FORECAST_PERIOD = 4 
if RESAMPLE_FREQ == '2W':   FORECAST_PERIOD = 2 

# Seasonal Period
if RESAMPLE_FREQ == 'M':    SEASONAL_PERIOD = 12  # Yearly
if RESAMPLE_FREQ == 'W':    SEASONAL_PERIOD = 13 # Quarterly (we can also take yearly = 52, but SARIMAX becomes too slow)
if RESAMPLE_FREQ == '2W':   SEASONAL_PERIOD = 13 # This becomes problematic --> for quarterly, should we take 6 biweekly periods or 7 bi-weekly periods. Instead I just took half yearly period  

COL_TIME = 'WeekDate'
COL_PREDS = ['9L Cases'] #Demand
COL_PRICE= ['Dollar Sales per 9L Case'] #Price

# %% [markdown]
# # Full Run

# %%
dataRaw = loadDataset(version=4)
ProdCat =ProdCats[0]
ChainMasters =  [''] +  dataRaw['Chain Master'].unique().tolist() 
display(ChainMasters,ProdCats)
# Out:
# ['', 'THE BARREL HOUSE', 'WESTERN BEV LIQ TX', 'SPECS']
# ['ECONOMY VODKA']

# %%
(full_models,full_opt,full_summary,full_chain_summary)  = fullRun(ProdCat = ProdCat
                                                           ,ChainMasters = ChainMasters
                                                           ,dataRaw = dataRaw
                                                           ,savePKL=True
                                                           ,saveXLS=True)
# Out:
# ==================================================
# Parameters being used...
# ==================================================
# TOP_PRODUCTS = 6
# TOP_SIMILAR = 5
# RUN_PERIODS = [1, 2, 3]
# ProdCat: ECONOMY VODKA
# ChainMasters: ['', 'THE BARREL HOUSE', 'WESTERN BEV LIQ TX', 'SPECS']
#
#
# ======================== (2020-09-14 21:10:02.819305)
# ==== Products List  ====
# ==== ECONOMY VODKA =====
# ===========  ===========
# ========================
#
#
#
# ======================= (2020-09-14 21:10:04.736309)
# ======= AUTO-TS =======
# ==== ECONOMY VODKA ====
# ==========  ===========
# ========== 1 ==========
# =======================
#
#
#
# ================== (2020-09-14 21:10:04.737309)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 BLUE PET 375M', '2': 'TEXAS SPIRIT VODKA 80  1.75L', '3': 'TAAKA VODKA 80 PET 1.75L', '4': 'TEXAS SPIRIT VODKA 80 SAZ NL 1.75L', '5': 'MCCORMICK CHERRY VODKA 60  1L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '1', '5', '4', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3', '0', '4', '5', '2']
# % of weeks without a purchase: 1.1904761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '3', '0', '5', '1', '4']
# % of weeks without a purchase: 69.04761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1', '5', '4', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '3', '1', '5', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: MCCORMICK CHERRY VODKA 60  1L
# --------------------------------------------------
# Exogenous Price Columns: ['5', '0', '3', '1', '4', '2']
# % of weeks without a purchase: 2.380952380952381
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
# 	Product: TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
# 	Product: MCCORMICK CHERRY VODKA 60  1L
#
#
# ===================== (2020-09-14 21:11:05.472421)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#        lb_stat     lb_pvalue
# 12  248.948794  2.266370e-46
# 24  282.763358  4.861676e-46
# 48  368.538254  5.288988e-51
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  584.901182  1.773645e-117
# 24  743.424992  1.784213e-141
# 48  947.167628  2.940142e-167
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  474.857092   4.940599e-94
# 24  562.831143  1.385783e-103
# 48  697.054286  5.309923e-116
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  148.350039  1.225106e-25
# 24  166.824771  2.330111e-23
# 48  349.230594  2.409071e-47
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  15.781393   0.201455
# 24  33.696053   0.090218
# 48  44.059529   0.635010
#
# Is Data White Noise: True
#        lb_stat      lb_pvalue
# 12  364.862447   1.021979e-70
# 24  473.331951   5.651816e-85
# 48  630.257398  1.686053e-102
#
# Is Data White Noise: False
#
#
# ==================== (2020-09-14 21:11:05.498420)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (83, 8) (1, 8)
# (83, 8) (1, 8)
# (83, 8) (1, 8)
# (83, 8) (1, 8)
# (58, 8) (1, 8)
# (83, 8) (1, 8)
#
#
# =============== (2020-09-14 21:11:05.505419)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.083730         []
# 1  1      last   0.050920         []
# 2  2      last   0.000000         []
# 3  3      mean   0.080436         []
# 4  4      mean   0.069793         []
# 5  5      mean   0.505081         []
#
#                                            All RMSEs  \
# 0  [[0.08522395141312492, 0.11059590470983931, 0....
# 1  [[0.050919719560484134, 0.058483693505752464, ...
# 2                                  [[0.0, 0.0, 0.0]]
# 3  [[0.08442928271847924, 0.10271666862052284, 0....
# 4  [[0.0816329202384487, 0.10985594998750277, 0.0...
# 5  [[0.7481943751644972, 0.6854742255160569, 0.50...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 2  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 4  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 5  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-14 21:11:06.156418)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:  7.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-14 21:18:06.733397)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:  7.3min finished
# =================== (2020-09-14 21:25:23.301243)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-14 21:25:23.304245)
# ====== OPTIMIZER ======
# ==== ECONOMY VODKA ====
# ==========  ===========
# ========== 1 ==========
# =======================
#
#
#
# =========================== (2020-09-14 21:25:23.304245)
# ==== Running Optimizer ====
# ====== ECONOMY VODKA ======
# ============  =============
# ============ 1 ============
# ===========================
#
#
#
# ================== (2020-09-14 21:25:23.306244)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 BLUE PET 375M', '2': 'TEXAS SPIRIT VODKA 80  1.75L', '3': 'TAAKA VODKA 80 PET 1.75L', '4': 'TEXAS SPIRIT VODKA 80 SAZ NL 1.75L', '5': 'MCCORMICK CHERRY VODKA 60  1L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '1', '5', '4', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3', '0', '4', '5', '2']
# % of weeks without a purchase: 1.1904761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '3', '0', '5', '1', '4']
# % of weeks without a purchase: 69.04761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1', '5', '4', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '3', '1', '5', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: MCCORMICK CHERRY VODKA 60  1L
# --------------------------------------------------
# Exogenous Price Columns: ['5', '0', '3', '1', '4', '2']
# % of weeks without a purchase: 2.380952380952381
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
# 	Product: TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
# 	Product: MCCORMICK CHERRY VODKA 60  1L
#
#
# ==================== (2020-09-14 21:26:20.520243)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (83, 8) (1, 8)
# (83, 8) (1, 8)
# (83, 8) (1, 8)
# (83, 8) (1, 8)
# (58, 8) (1, 8)
# (83, 8) (1, 8)
#
#
# ======================== (2020-09-14 21:26:20.525243)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-14 21:26:20.541243)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False, False, False, False]
#
#
# =============== (2020-09-14 21:26:20.543247)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-14 21:26:20.550243)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-14 21:26:20.551244)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-14 21:26:20.552244)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
# Building Forecast dataframe. Forecast Period = 1
#
#
# =================== (2020-09-14 21:26:22.542243)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-14 21:26:22.548242)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
#
#
# =================== (2020-09-14 21:30:16.966247)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
# Building Forecast dataframe. Forecast Period = 1
#
#
# ============================= (2020-09-14 21:30:18.830246)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-14 21:30:18.831246)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
# Building Forecast dataframe. Forecast Period = 1
#
#
# =================== (2020-09-14 21:30:20.658246)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-14 21:30:20.662244)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
#
#
# =================== (2020-09-14 21:34:31.242249)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
# Building Forecast dataframe. Forecast Period = 1
#
#
# =================== (2020-09-14 21:34:34.171243)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-14 21:34:34.177245)
# ======= AUTO-TS =======
# ==== ECONOMY VODKA ====
# ==========  ===========
# ========== 2 ==========
# =======================
#
#
#
# ================== (2020-09-14 21:34:34.179243)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 BLUE PET 375M', '2': 'TEXAS SPIRIT VODKA 80  1.75L', '3': 'TAAKA VODKA 80 PET 1.75L', '4': 'TEXAS SPIRIT VODKA 80 SAZ NL 1.75L', '5': 'MCCORMICK CHERRY VODKA 60  1L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '1', '5', '4', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3', '0', '4', '5', '2']
# % of weeks without a purchase: 1.2048192771084338
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '3', '0', '5', '1', '4']
# % of weeks without a purchase: 68.67469879518072
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1', '5', '4', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '3', '1', '5', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: MCCORMICK CHERRY VODKA 60  1L
# --------------------------------------------------
# Exogenous Price Columns: ['5', '0', '3', '1', '4', '2']
# % of weeks without a purchase: 2.4096385542168677
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
# 	Product: TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
# 	Product: MCCORMICK CHERRY VODKA 60  1L
#
#
# ===================== (2020-09-14 21:36:04.844242)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#        lb_stat     lb_pvalue
# 12  247.379998  4.812566e-46
# 24  281.567711  8.439708e-46
# 48  366.781603  1.141278e-50
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  574.606302  2.792191e-115
# 24  727.477625  4.083848e-138
# 48  944.375636  1.109735e-166
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  468.018038   1.404414e-92
# 24  554.010494  9.591640e-102
# 48  696.468177  6.982057e-116
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  144.742513  6.589309e-25
# 24  162.572274  1.476101e-22
# 48  338.164450  2.919586e-45
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  15.557680   0.212345
# 24  33.693867   0.090259
# 48  45.714515   0.566979
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12  349.158924  2.110730e-67
# 24  450.216159  3.416680e-80
# 48  607.499271  6.348168e-98
#
# Is Data White Noise: False
#
#
# ==================== (2020-09-14 21:36:04.874243)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (82, 8) (1, 8)
# (82, 8) (1, 8)
# (82, 8) (1, 8)
# (82, 8) (1, 8)
# (57, 8) (1, 8)
# (82, 8) (1, 8)
#
#
# =============== (2020-09-14 21:36:04.882245)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.077936         []
# 1  1      last   0.049104         []
# 2  2      last   0.000000         []
# 3  3      mean   0.087216         []
# 4  4      mean   0.067484         []
# 5  5      mean   0.529060         []
#
#                                            All RMSEs  \
# 0  [[0.08907681622057902, 0.11385458510024087, 0....
# 1  [[0.04910363192681037, 0.05961976914518541, 0....
# 2                                  [[0.0, 0.0, 0.0]]
# 3  [[0.09339313017889535, 0.10233695646087668, 0....
# 4  [[0.09617536421503817, 0.10367899808494474, 0....
# 5  [[0.731864668557586, 0.6977018233691613, 0.529...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 2  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 4  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 5  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-14 21:36:05.632244)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:  6.4min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-14 21:42:27.068034)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:  6.2min finished
# =================== (2020-09-14 21:48:38.656037)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-14 21:48:38.666039)
# ====== OPTIMIZER ======
# ==== ECONOMY VODKA ====
# ==========  ===========
# ========== 2 ==========
# =======================
#
#
#
# =========================== (2020-09-14 21:48:38.667037)
# ==== Running Optimizer ====
# ====== ECONOMY VODKA ======
# ============  =============
# ============ 2 ============
# ===========================
#
#
#
# ================== (2020-09-14 21:48:38.671038)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 BLUE PET 375M', '2': 'TEXAS SPIRIT VODKA 80  1.75L', '3': 'TAAKA VODKA 80 PET 1.75L', '4': 'TEXAS SPIRIT VODKA 80 SAZ NL 1.75L', '5': 'MCCORMICK CHERRY VODKA 60  1L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '1', '5', '4', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3', '0', '4', '5', '2']
# % of weeks without a purchase: 1.2048192771084338
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '3', '0', '5', '1', '4']
# % of weeks without a purchase: 68.67469879518072
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1', '5', '4', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '3', '1', '5', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: MCCORMICK CHERRY VODKA 60  1L
# --------------------------------------------------
# Exogenous Price Columns: ['5', '0', '3', '1', '4', '2']
# % of weeks without a purchase: 2.4096385542168677
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
# 	Product: TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
# 	Product: MCCORMICK CHERRY VODKA 60  1L
#
#
# ==================== (2020-09-14 21:50:07.263034)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (82, 8) (1, 8)
# (82, 8) (1, 8)
# (82, 8) (1, 8)
# (82, 8) (1, 8)
# (57, 8) (1, 8)
# (82, 8) (1, 8)
#
#
# ======================== (2020-09-14 21:50:07.269033)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-14 21:50:07.284033)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False, False, False, False]
#
#
# =============== (2020-09-14 21:50:07.287033)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-14 21:50:07.296031)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-14 21:50:07.296031)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-14 21:50:07.297032)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
# Building Forecast dataframe. Forecast Period = 1
#
#
# =================== (2020-09-14 21:50:09.084035)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-14 21:50:09.091033)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
#
#
# =================== (2020-09-14 21:54:01.110035)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
# Building Forecast dataframe. Forecast Period = 1
#
#
# ============================= (2020-09-14 21:54:02.879037)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-14 21:54:02.879037)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
# Building Forecast dataframe. Forecast Period = 1
#
#
# =================== (2020-09-14 21:54:04.907034)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-14 21:54:04.911033)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
#
#
# =================== (2020-09-14 21:58:57.042035)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
# Building Forecast dataframe. Forecast Period = 1
#
#
# =================== (2020-09-14 21:59:00.113033)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-14 21:59:00.123035)
# ======= AUTO-TS =======
# ==== ECONOMY VODKA ====
# ==========  ===========
# ========== 3 ==========
# =======================
#
#
#
# ================== (2020-09-14 21:59:00.124035)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 BLUE PET 375M', '2': 'TEXAS SPIRIT VODKA 80  1.75L', '3': 'TAAKA VODKA 80 PET 1.75L', '4': 'TEXAS SPIRIT VODKA 80 SAZ NL 1.75L', '5': 'MCCORMICK CHERRY VODKA 60  1L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '1', '5', '4', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3', '0', '4', '5', '2']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '3', '0', '5', '1', '4']
# % of weeks without a purchase: 68.29268292682927
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1', '5', '4', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '3', '1', '5', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: MCCORMICK CHERRY VODKA 60  1L
# --------------------------------------------------
# Exogenous Price Columns: ['5', '0', '3', '1', '4', '2']
# % of weeks without a purchase: 2.4390243902439024
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
# 	Product: TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
# 	Product: MCCORMICK CHERRY VODKA 60  1L
#
#
# ===================== (2020-09-14 22:00:26.490036)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#        lb_stat     lb_pvalue
# 12  243.950101  2.495194e-45
# 24  277.452128  5.626127e-45
# 48  363.173548  5.530118e-50
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  563.083839  8.020215e-113
# 24  710.497889  1.533447e-134
# 48  939.687445  1.031921e-165
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  461.149000   4.046888e-91
# 24  545.150471  6.746748e-100
# 48  696.525463  6.797717e-116
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  141.032457  3.706001e-24
# 24  158.246146  9.582502e-22
# 48  325.345702  7.337201e-43
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  15.076991   0.237253
# 24  32.806008   0.108233
# 48  43.730748   0.648301
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12  337.665270  5.597513e-65
# 24  434.334102  6.480209e-77
# 48  589.828511  2.218218e-94
#
# Is Data White Noise: False
#
#
# ==================== (2020-09-14 22:00:26.529036)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (81, 8) (1, 8)
# (81, 8) (1, 8)
# (81, 8) (1, 8)
# (81, 8) (1, 8)
# (56, 8) (1, 8)
# (81, 8) (1, 8)
#
#
# =============== (2020-09-14 22:00:26.539035)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.078022         []
# 1  1      last   0.044826         []
# 2  2      last   0.000000         []
# 3  3      mean   0.076948         []
# 4  4      mean   0.075211         []
# 5  5      mean   0.500304         []
#
#                                            All RMSEs  \
# 0  [[0.10614956572430416, 0.1364306802567358, 0.0...
# 1  [[0.04482627686032599, 0.061881124720379786, 0...
# 2                                  [[0.0, 0.0, 0.0]]
# 3  [[0.0987077256986276, 0.10351490018633347, 0.0...
# 4  [[0.10202854443437681, 0.11030437140568901, 0....
# 5  [[0.731864668557586, 0.5650867970284427, 0.500...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 2  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 4  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 5  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-14 22:00:27.246034)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:  5.6min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-14 22:06:02.356034)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:  5.2min finished
# =================== (2020-09-14 22:11:16.783034)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-14 22:11:16.790038)
# ====== OPTIMIZER ======
# ==== ECONOMY VODKA ====
# ==========  ===========
# ========== 3 ==========
# =======================
#
#
#
# =========================== (2020-09-14 22:11:16.791037)
# ==== Running Optimizer ====
# ====== ECONOMY VODKA ======
# ============  =============
# ============ 3 ============
# ===========================
#
#
#
# ================== (2020-09-14 22:11:16.794034)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 BLUE PET 375M', '2': 'TEXAS SPIRIT VODKA 80  1.75L', '3': 'TAAKA VODKA 80 PET 1.75L', '4': 'TEXAS SPIRIT VODKA 80 SAZ NL 1.75L', '5': 'MCCORMICK CHERRY VODKA 60  1L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '1', '5', '4', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3', '0', '4', '5', '2']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '3', '0', '5', '1', '4']
# % of weeks without a purchase: 68.29268292682927
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1', '5', '4', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
# ...
# ======= AUTO-TS =======
# ==== ECONOMY VODKA ====
# ======== SPECS ========
# ========== 3 ==========
# =======================
#
#
#
# ================== (2020-09-15 00:35:11.296740)
# ==== GET DATA ====
# ===== SPECS ======
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 PET 1.75L', '2': 'TAAKA VODKA 80 BLUE PET 375M', '3': 'MCCORMICK CHERRY VODKA 60  1L', '4': 'DOBRA VODKA  1.75L', '5': 'TAAKA VODKA 80 PET 750M'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2', '4', '5', '3']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '5', '4', '3']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1', '5', '4', '3']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: MCCORMICK CHERRY VODKA 60  1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1', '2', '4', '5']
# % of weeks without a purchase: 28.39506172839506
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: DOBRA VODKA  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '1', '2', '5', '3']
# % of weeks without a purchase: 14.814814814814813
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 750M
# --------------------------------------------------
# Exogenous Price Columns: ['5', '0', '2', '1', '4', '3']
# % of weeks without a purchase: 13.414634146341465
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 PET 1.75L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: MCCORMICK CHERRY VODKA 60  1L
# 	Product: DOBRA VODKA  1.75L
# 	Product: TAAKA VODKA 80 PET 750M
#
#
# ===================== (2020-09-15 00:36:36.977742)
# ==== WHITE NOISE ====
# ======= SPECS =======
# =====================
#
#        lb_stat     lb_pvalue
# 12  163.850364  8.614761e-29
# 24  202.851035  2.932294e-30
# 48  302.430383  1.310197e-38
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  203.867388  5.185416e-37
# 24  249.138534  2.445714e-39
# 48  386.780036  1.745507e-54
#
# Is Data White Noise: False
#        lb_stat  lb_pvalue
# 12   41.146569   0.000046
# 24   60.607680   0.000052
# 48  103.105730   0.000007
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  12.395058   0.414496
# 24  22.052180   0.576152
# 48  51.642102   0.333451
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12  24.341688   0.018270
# 24  33.409284   0.095728
# 48  82.146329   0.001561
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12  27.838764   0.005840
# 24  39.452800   0.024465
# 48  83.863366   0.001042
#
# Is Data White Noise: False
#
#
# ==================== (2020-09-15 00:36:37.000742)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (81, 8) (1, 8)
# (81, 8) (1, 8)
# (81, 8) (1, 8)
# (80, 8) (1, 8)
# (80, 8) (1, 8)
# (81, 8) (1, 8)
#
#
# =============== (2020-09-15 00:36:37.010743)
# ==== NAIVE ====
# ==== SPECS ====
# ===============
#
#   ID      Best Type  Best RMSE All Naives  \
# 0  0           mean   0.107768         []
# 1  1           mean   0.136330         []
# 2  2           mean   0.121653         []
# 3  3  seasonal_last   0.432273         []
# 4  4           mean   0.360263         []
# 5  5           mean   0.278380         []
#
#                                            All RMSEs  \
# 0  [[0.13456120941276825, 0.187951813296838, 0.10...
# 1  [[0.21541297336857784, 0.22034399791646134, 0....
# 2  [[0.17742034252670738, 0.1589870135780978, 0.1...
# 3  [[0.49069171944604034, 0.4322727246195653, 0.6...
# 4  [[0.46158729599658893, 0.4079241449775477, 0.3...
# 5  [[0.4967985559518649, 0.38180432777086104, 0.2...
#
#                        All Types  \
# 0  [[last, seasonal_last, mean]]
# 1  [[last, seasonal_last, mean]]
# 2  [[last, seasonal_last, mean]]
# 3  [[last, seasonal_last, mean]]
# 4  [[last, seasonal_last, mean]]
# 5  [[last, seasonal_last, mean]]
#
#                                         Best Naive
# 0           NaiveForecaster(sp=4, strategy='mean')
# 1           NaiveForecaster(sp=4, strategy='mean')
# 2           NaiveForecaster(sp=4, strategy='mean')
# 3  NaiveForecaster(sp=4, strategy='seasonal_last')
# 4           NaiveForecaster(sp=4, strategy='mean')
# 5           NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-15 00:36:37.583745)
# ==== Multivar P0 ====
# ======= SPECS =======
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:  4.8min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-15 00:41:25.351749)
# ==== Multivar P0+Sim ====
# ========= SPECS =========
# =========================
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:  5.0min finished
# =================== (2020-09-15 00:46:26.837845)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ======================= (2020-09-15 00:46:26.843845)
# ====== OPTIMIZER ======
# ==== ECONOMY VODKA ====
# ======== SPECS ========
# ========== 3 ==========
# =======================
#
#
#
# =========================== (2020-09-15 00:46:26.843845)
# ==== Running Optimizer ====
# ====== ECONOMY VODKA ======
# ========== SPECS ==========
# ============ 3 ============
# ===========================
#
#
#
# ================== (2020-09-15 00:46:26.845844)
# ==== GET DATA ====
# ===== SPECS ======
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 PET 1.75L', '2': 'TAAKA VODKA 80 BLUE PET 375M', '3': 'MCCORMICK CHERRY VODKA 60  1L', '4': 'DOBRA VODKA  1.75L', '5': 'TAAKA VODKA 80 PET 750M'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2', '4', '5', '3']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '5', '4', '3']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1', '5', '4', '3']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: MCCORMICK CHERRY VODKA 60  1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1', '2', '4', '5']
# % of weeks without a purchase: 28.39506172839506
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: DOBRA VODKA  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '1', '2', '5', '3']
# % of weeks without a purchase: 14.814814814814813
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 750M
# --------------------------------------------------
# Exogenous Price Columns: ['5', '0', '2', '1', '4', '3']
# % of weeks without a purchase: 13.414634146341465
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 PET 1.75L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: MCCORMICK CHERRY VODKA 60  1L
# 	Product: DOBRA VODKA  1.75L
# 	Product: TAAKA VODKA 80 PET 750M
#
#
# ==================== (2020-09-15 00:47:30.130281)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (81, 8) (1, 8)
# (81, 8) (1, 8)
# (81, 8) (1, 8)
# (80, 8) (1, 8)
# (80, 8) (1, 8)
# (81, 8) (1, 8)
#
#
# ======================== (2020-09-15 00:47:30.138252)
# ==== NAIVE FORECAST ====
# ======== SPECS =========
# ========================
#
#
#
# =============== (2020-09-15 00:47:30.159251)
# ==== MASK =====
# ==== SPECS ====
# ===============
#
# Mask: [False, False, False, False, False, False]
#
#
# =============== (2020-09-15 00:47:30.161278)
# ==== SPACE ====
# ==== SPECS ====
# ===============
#
# Min Limit is >= than Max Limit, setting them near median (+-5%)
#
#
# ==================== (2020-09-15 00:47:30.173253)
# ==== Test Index ====
# ====== SPECS =======
# ====================
#
#
#
# ========================= (2020-09-15 00:47:30.174250)
# ==== GET FUNCTION P0 ====
# ========= SPECS =========
# =========================
#
#
#
# ====================================== (2020-09-15 00:47:30.176251)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# =============== SPECS ================
# ======================================
#
# Building Forecast dataframe. Forecast Period = 1
#
#
# =================== (2020-09-15 00:47:32.114248)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ======================= (2020-09-15 00:47:32.118247)
# ==== OPTIMIZING P0 ====
# ======== SPECS ========
# =======================
#
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
#
#
# =================== (2020-09-15 00:50:50.132769)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
# Building Forecast dataframe. Forecast Period = 1
#
#
# ============================= (2020-09-15 00:50:51.853771)
# ==== GET FUNCTION P0+Sim ====
# =========== SPECS ===========
# =============================
#
#
#
# ========================================== (2020-09-15 00:50:51.854775)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ================= SPECS ==================
# ==========================================
#
#
#
# =================== (2020-09-15 00:50:52.061773)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =========================== (2020-09-15 00:50:52.069772)
# ==== OPTIMIZING P0+Sim ====
# ========== SPECS ==========
# ===========================
#
#
#
# =================== (2020-09-15 00:52:00.309081)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =================== (2020-09-15 00:52:00.542081)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ========================== (2020-09-15 00:52:00.562080)
# ==== Saving to PICKLE ====
# ===== ECONOMY VODKA ======
# ==========================
#
# Pickle File  full_models_ECONOMY VODKA_Prod6_Sim5_Per123.pkl  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns
# Pickle File  full_opt_ECONOMY VODKA_Prod6_Sim5_Per123.pkl  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns
#
#
# ========================= (2020-09-15 00:52:00.766107)
# ==== Saving to EXCEL ====
# ===== ECONOMY VODKA =====
# =========================
#
# EXCEL File  Output_ECONOMY VODKA_Prod6_Sim5_Per123.xlsx  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns

# %% [markdown]
# # Print out

# %% [markdown]
# ## Models

# %%
full_models[outputColsModels]
# Out:
#           Chain Master                             Product  Period to Last  \
# 5                            MCCORMICK CHERRY VODKA 60  1L               1
# 11                           MCCORMICK CHERRY VODKA 60  1L               2
# 17                           MCCORMICK CHERRY VODKA 60  1L               3
# 0                                       TAAKA VODKA 80  1L               1
# 6                                       TAAKA VODKA 80  1L               2
# ..                 ...                                 ...             ...
# 44  WESTERN BEV LIQ TX        TEXAS SPIRIT VODKA 80  1.75L               2
# 50  WESTERN BEV LIQ TX        TEXAS SPIRIT VODKA 80  1.75L               3
# 40  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               1
# 46  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               2
# 52  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               3
#
#     White Noise Naive Best Type  Naive Best RMSE P0 Best Model Name  \
# 5         False            mean         0.505081            Prophet
# 11        False            mean         0.529060            Prophet
# 17        False            mean         0.500304            Prophet
# 0         False            mean         0.083730                 ML
# 6         False            mean         0.077936                 ML
# ..          ...             ...              ...                ...
# 44        False            last         0.000000            SARIMAX
# 50        False            last         0.000000            SARIMAX
# 40         True            mean         0.069793            SARIMAX
# 46         True            mean         0.067484            SARIMAX
# 52         True            mean         0.075211            SARIMAX
#
#     P0 Best Model RMSE P0+Sim Best Model Name  P0+Sim Best Model RMSE
# 5             0.261072                Prophet                0.341375
# 11            0.235425                Prophet                0.292265
# 17            0.237860                Prophet                0.298056
# 0             0.074880                     ML                0.075753
# 6             0.069895                     ML                0.070768
# ..                 ...                    ...                     ...
# 44            0.001044                SARIMAX                0.007276
# 50            0.001135                SARIMAX                0.006283
# 40            0.056888                SARIMAX                0.056625
# 46            0.054461                SARIMAX                0.046772
# 52            0.072678                SARIMAX                0.067555
#
# [72 rows x 10 columns]

# %% [markdown]
# ## Optimizer

# %% [markdown]
# ### Summary by Chain

# %%
full_chain_summary
# Out:
#          Chain Master  P0 Non-Opt Revenue  P0 Opt Revenue  P0 Opt Diff  \
# 0                                 35323.0         35301.0        -22.0
# 1               SPECS             16084.0         18534.0       2450.0
# 2    THE BARREL HOUSE              7869.0          7929.0         60.0
# 3  WESTERN BEV LIQ TX             14755.0         23547.0       8792.0
#
#    P0 Opt Diff Ratio  P0+Sim Non-Opt Revenue  P0+Sim Opt Revenue  \
# 0           0.999377                 31046.0        2.961100e+04
# 1           1.152325                 15622.0        1.214036e+09
# 2           1.007625                  6699.0        1.476100e+04
# 3           1.595866                 23198.0        2.668200e+04
#
#    P0+Sim Opt Diff  P0+Sim Opt Diff Ratio
# 0    -1.435000e+03               0.953778
# 1     1.214020e+09           77713.216234
# 2     8.062000e+03               2.203463
# 3     3.484000e+03               1.150185

# %%
print("WRITE this value in the summary table in Git hub --->",round(full_chain_summary[full_chain_summary['Chain Master']=='']['P0+Sim Opt Diff Ratio'].item(),4))
# Out:
# WRITE this value in the summary table in Git hub ---> 0.9538

# %% [markdown]
# Link to the Git Hub Summary Table: https://github.com/ngupta23/msds_capstone/issues/84

# %% [markdown]
# ### Summary by Chain and Product

# %%
full_summary
# Out:
#           Chain Master                             Product  \
# 0                            MCCORMICK CHERRY VODKA 60  1L
# 1                                       TAAKA VODKA 80  1L
# 2                             TAAKA VODKA 80 BLUE PET 375M
# 3                                 TAAKA VODKA 80 PET 1.75L
# 4                             TEXAS SPIRIT VODKA 80  1.75L
# 5                       TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
# 6                SPECS                  DOBRA VODKA  1.75L
# 7                SPECS       MCCORMICK CHERRY VODKA 60  1L
# 8                SPECS                  TAAKA VODKA 80  1L
# 9                SPECS        TAAKA VODKA 80 BLUE PET 375M
# 10               SPECS            TAAKA VODKA 80 PET 1.75L
# 11               SPECS             TAAKA VODKA 80 PET 750M
# 12    THE BARREL HOUSE                  DOBRA VODKA  1.75L
# 13    THE BARREL HOUSE               STROYSKI VODKA  1.75L
# 14    THE BARREL HOUSE                  TAAKA VODKA 80  1L
# 15    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 200M
# 16    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 375M
# 17    THE BARREL HOUSE            TAAKA VODKA 80 PET 1.75L
# 18  WESTERN BEV LIQ TX       MCCORMICK CHERRY VODKA 60  1L
# 19  WESTERN BEV LIQ TX                  TAAKA VODKA 80  1L
# 20  WESTERN BEV LIQ TX        TAAKA VODKA 80 BLUE PET 375M
# 21  WESTERN BEV LIQ TX            TAAKA VODKA 80 PET 1.75L
# 22  WESTERN BEV LIQ TX        TEXAS SPIRIT VODKA 80  1.75L
# 23  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
#
#     P0 Non-Opt Revenue  P0 Opt Revenue  P0 Opt Diff  P0 Opt Diff Ratio  \
# 0                405.0           409.0          4.0           1.009877
# 1              16812.0         16772.0        -40.0           0.997621
# 2              10119.0         10119.0          0.0           1.000000
# 3               5568.0          5568.0          0.0           1.000000
# 4                 15.0            29.0         14.0           1.933333
# 5               2404.0          2404.0          0.0           1.000000
# 6                328.0           338.0         10.0           1.030488
# 7                242.0           269.0         27.0           1.111570
# 8              12144.0         12144.0          0.0           1.000000
# 9               1057.0          1150.0         93.0           1.087985
# 10              2185.0          3877.0       1692.0           1.774371
# 11               128.0           756.0        628.0           5.906250
# 12               828.0           850.0         22.0           1.026570
# 13              1063.0          1068.0          5.0           1.004704
# 14              1573.0          1595.0         22.0           1.013986
# 15              1034.0          1036.0          2.0           1.001934
# 16              3085.0          3085.0          0.0           1.000000
# 17               286.0           295.0          9.0           1.031469
# 18              1488.0          1488.0          0.0           1.000000
# 19              7507.0         15175.0       7668.0           2.021447
# 20              1202.0          1202.0          0.0           1.000000
# 21              2139.0          3249.0       1110.0           1.518934
# 22                15.0            29.0         14.0           1.933333
# 23              2404.0          2404.0          0.0           1.000000
#
#     P0+Sim Non-Opt Revenue  P0+Sim Opt Revenue  P0+Sim Opt Diff  \
# 0                    355.0        2.640000e+02    -9.100000e+01
# 1                  16502.0        1.646300e+04    -3.900000e+01
# 2                   6903.0        5.880000e+03    -1.023000e+03
# 3                   5344.0        5.058000e+03    -2.860000e+02
# 4                     15.0        1.700000e+01     2.000000e+00
# 5                   1927.0        1.929000e+03     2.000000e+00
# 6                    327.0        3.220000e+02    -5.000000e+00
# 7                    292.0        2.750000e+02    -1.700000e+01
# 8                  13372.0        1.284500e+04    -5.270000e+02
# 9                    823.0        1.213173e+09     1.213173e+09
# 10                   654.0        8.444690e+05     8.438150e+05
# 11                   154.0        4.601000e+03     4.447000e+03
# 12                  1097.0        1.114000e+03     1.700000e+01
# 13                   919.0        9.220000e+02     3.000000e+00
# 14                  1793.0        1.818000e+03     2.500000e+01
# 15                   929.0        9.300000e+02     1.000000e+00
# 16                  1669.0        9.675000e+03     8.006000e+03
# 17                   292.0        3.020000e+02     1.000000e+01
# 18                  1488.0        1.202000e+03    -2.860000e+02
# 19                  6617.0        9.314000e+03     2.697000e+03
# 20                  9325.0        9.386000e+03     6.100000e+01
# 21                  3595.0        4.523000e+03     9.280000e+02
# 22                    15.0        1.700000e+01     2.000000e+00
# 23                  2158.0        2.240000e+03     8.200000e+01
#
#     P0+Sim Opt Diff Ratio
# 0            7.436620e-01
# 1            9.976367e-01
# 2            8.518036e-01
# 3            9.464820e-01
# 4            1.133333e+00
# 5            1.001038e+00
# 6            9.847095e-01
# 7            9.417808e-01
# 8            9.605893e-01
# 9            1.474087e+06
# 10           1.291237e+03
# 11           2.987662e+01
# 12           1.015497e+00
# 13           1.003264e+00
# 14           1.013943e+00
# 15           1.001076e+00
# 16           5.796884e+00
# 17           1.034247e+00
# 18           8.077957e-01
# 19           1.407587e+00
# 20           1.006542e+00
# 21           1.258136e+00
# 22           1.133333e+00
# 23           1.037998e+00

# %% [markdown]
# ### P0 Optimizer

# %%
full_opt[outputColsOptP0]
# Out:
#           Chain Master                             Product  Period to Last  \
# 5                            MCCORMICK CHERRY VODKA 60  1L               1
# 11                           MCCORMICK CHERRY VODKA 60  1L               2
# 17                           MCCORMICK CHERRY VODKA 60  1L               3
# 0                                       TAAKA VODKA 80  1L               1
# 6                                       TAAKA VODKA 80  1L               2
# ..                 ...                                 ...             ...
# 44  WESTERN BEV LIQ TX        TEXAS SPIRIT VODKA 80  1.75L               2
# 50  WESTERN BEV LIQ TX        TEXAS SPIRIT VODKA 80  1.75L               3
# 40  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               1
# 46  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               2
# 52  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               3
#
#     P0 Non-Opt Price  P0 Non-Opt Demand  P0 Non-Opt Revenue  \
# 5              45.74                  3                 123
# 11             45.74                  2                  84
# 17             45.74                  4                 198
# 0              44.42                115                5103
# 6              44.30                107                4750
# ..               ...                ...                 ...
# 44             51.18                  0                   5
# 50             51.18                  0                   5
# 40             46.97                 18                 865
# 46             46.97                 17                 780
# 52             46.97                 16                 759
#
#     P0 Non-Opt Chain Master Revenue  P0 Optimal Price  P0 Demand  P0 Revenue  \
# 5                              8583             45.69          3         124
# 11                            12794             45.69          2          85
# 17                            13945             45.69          4         200
# 0                              8583             44.30        115        5089
# 6                             12794             44.30        107        4750
# ..                              ...               ...        ...         ...
# 44                             4853             46.03          0           9
# 50                             4144             46.03          0          10
# 40                             5757             46.97         18         865
# 46                             4853             46.97         17         780
# 52                             4144             46.97         16         759
#
#     P0 Chain Master Revenue
# 5                      8576
# 11                    12800
# 17                    13926
# 0                      8576
# 6                     12800
# ..                      ...
# 44                     8512
# 50                     4463
# 40                    10572
# 46                     8512
# 52                     4463
#
# [72 rows x 11 columns]

# %% [markdown]
# ### P0+Sim Optimizer

# %%
full_opt[outputColsOptP0Sim]
# Out:
#           Chain Master                             Product  Period to Last  \
# 5                            MCCORMICK CHERRY VODKA 60  1L               1
# 11                           MCCORMICK CHERRY VODKA 60  1L               2
# 17                           MCCORMICK CHERRY VODKA 60  1L               3
# 0                                       TAAKA VODKA 80  1L               1
# 6                                       TAAKA VODKA 80  1L               2
# ..                 ...                                 ...             ...
# 44  WESTERN BEV LIQ TX        TEXAS SPIRIT VODKA 80  1.75L               2
# 50  WESTERN BEV LIQ TX        TEXAS SPIRIT VODKA 80  1.75L               3
# 40  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               1
# 46  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               2
# 52  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               3
#
#     P0+Sim Non-Opt Price  P0+Sim Non-Opt Demand  P0+Sim Non-Opt Revenue  \
# 5                  45.74                      2                     105
# 11                 45.74                      1                      68
# 17                 45.74                      4                     182
# 0                  44.42                    103                    4574
# 6                  44.30                    107                    4750
# ..                   ...                    ...                     ...
# 44                 51.18                      0                       5
# 50                 51.18                      0                       5
# 40                 46.97                     16                     775
# 46                 46.97                     15                     718
# 52                 46.97                     14                     665
#
#     P0+Sim Non-Opt Chain Master Revenue  P0+Sim Optimal Price  P0+Sim Demand  \
# 5                                  6975                 45.69              1
# 11                                 7513                 45.69              1
# 17                                16558                 45.69              4
# 0                                  6975                 44.30            103
# 6                                  7513                 44.30            107
# ..                                  ...                   ...            ...
# 44                                 7950                 46.03              0
# 50                                 6460                 46.03              0
# 40                                 8789                 46.97             15
# 46                                 7950                 46.97             17
# 52                                 6460                 46.97             16
#
#     P0+Sim Revenue  P0+Sim Chain Master Revenue
# 5               59                         6816
# 11              40                         7659
# 17             165                        15137
# 0             4562                         6816
# 6             4750                         7659
# ..             ...                          ...
# 44               7                         8983
# 50               4                         7457
# 40             691                        10241
# 46             800                         8983
# 52             749                         7457
#
# [72 rows x 11 columns]

# %% [markdown]
# ### Naive

# %%
full_opt[outputColsOptNaive]
# Out:
#           Chain Master                             Product  Period to Last  \
# 5                            MCCORMICK CHERRY VODKA 60  1L               1
# 11                           MCCORMICK CHERRY VODKA 60  1L               2
# 17                           MCCORMICK CHERRY VODKA 60  1L               3
# 0                                       TAAKA VODKA 80  1L               1
# 6                                       TAAKA VODKA 80  1L               2
# ..                 ...                                 ...             ...
# 44  WESTERN BEV LIQ TX        TEXAS SPIRIT VODKA 80  1.75L               2
# 50  WESTERN BEV LIQ TX        TEXAS SPIRIT VODKA 80  1.75L               3
# 40  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               1
# 46  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               2
# 52  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               3
#
#     Actual Price  Actual Demand  Actual Revenue  Actual Chain Master Revenue  \
# 5      45.744361           1.33           60.84                     15314.34
# 11     45.744361           3.99          182.52                     15989.34
# 17     45.744361           3.99          182.52                     16497.06
# 0      44.420127         172.90         7680.24                     15314.34
# 6      44.300752         195.51         8661.24                     15989.34
# ..           ...            ...             ...                          ...
# 44     51.179487           0.00            0.00                      8107.14
# 50     51.179487           0.00            0.00                      8349.00
# 40     46.974359          17.55          824.40                      7746.90
# 46     46.974359          18.72          879.36                      8107.14
# 52     46.974359          15.21          714.48                      8349.00
#
#     Naive Prices  Naive Demand  Naive Revenue  Naive Chain Master Revenue
# 5      45.744361     10.505157     480.551676                15930.433295
# 11     45.744361     10.584610     484.186209                16959.067226
# 17     45.744361     10.666025     487.910483                15241.950151
# 0      44.420127    199.948711    8881.747177                15930.433295
# 6      44.300752    200.002841    8860.276255                16959.067226
# ..           ...           ...            ...                         ...
# 44     51.179487      0.000000       0.000000                 8405.888421
# 50     51.179487      0.000000       0.000000                 6780.781323
# 40     46.974359     16.460690     773.230345                 8001.010345
# 46     46.974359     16.421053     771.368421                 8405.888421
# 52     46.974359     16.442679     772.384286                 6780.781323
#
# [72 rows x 11 columns]
