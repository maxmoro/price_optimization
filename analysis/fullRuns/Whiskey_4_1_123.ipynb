# %% [markdown]
# # Init

# %%
# %load_ext autoreload
# %autoreload 2

# %%
print("CURRENT FOLDER:")
# %pwd
# Out:
# CURRENT FOLDER:
# 'c:\\max\\Google Drive Max\\Max Shared\\Master Data Science\\2020-05 Capstone A\\msds_capstone\\analysis\\fullRuns'

# %%
import os
import glob
import sys
sys.path.append(os.environ['DEV_AUTOTS'])
sys.path.append(os.environ['CAPSTONE_PYTHON_SOURCE'])
folder = os.environ['CAPSTONE_DATA']

# %%
## Sourcing the .py with all the code##
t='"'+os.environ['CAPSTONE_PYTHON_SOURCE']+'\\fullRun\\fullRun.py'+'"'
# %run -i $t
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# Running Auto Timeseries version: 0.0.24

# %% [markdown]
# # Parameters

# %%
#Parameters

ProdCats = ['SUP PREM WHISKEY']
TOP_PRODUCTS = 4  # How many products to consider in the category
TOP_SIMILAR = 1   # Get TOP_SIMILAR most similar products
RUN_PERIODS = [1,2,3] # this will run AutoTS and Optimzer for speicfic periods (1 = last, 2 = second to last)

CV_NUM = 10         # number of Cross Valudations  10
OPT_CALLS = 100     # number of calls for the optimizer process   100
OPT_RND_STARTS = 20 # number of random calls for the optimizer process  20

LOG_TRANSFORM = True # Take log of 9L cases to smooth out peaks and valleys
ZERO_ADDER = 0.1 

RESAMPLE_FREQ = 'M'


# Pricing changes every 4 weeks
if RESAMPLE_FREQ == 'M':    FORECAST_PERIOD = 1 #last 4 months as test 
if RESAMPLE_FREQ == 'W':    FORECAST_PERIOD = 4 
if RESAMPLE_FREQ == '2W':   FORECAST_PERIOD = 2 

# Seasonal Period
if RESAMPLE_FREQ == 'M':    SEASONAL_PERIOD = 12  # Yearly
if RESAMPLE_FREQ == 'W':    SEASONAL_PERIOD = 13 # Quarterly (we can also take yearly = 52, but SARIMAX becomes too slow)
if RESAMPLE_FREQ == '2W':   SEASONAL_PERIOD = 13 # This becomes problematic --> for quarterly, should we take 6 biweekly periods or 7 bi-weekly periods. Instead I just took half yearly period  

COL_TIME = 'WeekDate'
COL_PREDS = ['9L Cases'] #Demand
COL_PRICE= ['Dollar Sales per 9L Case'] #Price

# %% [markdown]
# # Full Run

# %%
dataRaw = loadDataset(version=4)
ProdCat = 'SUP PREM WHISKEY' #'ECONOMY VODKA'
ChainMasters =  [''] +  dataRaw['Chain Master'].unique().tolist() 
display(ChainMasters,ProdCats)
# Out:
# ['', 'THE BARREL HOUSE', 'WESTERN BEV LIQ TX', 'SPECS']
# ['SUP PREM WHISKEY']

# %%
(full_models,full_opt,full_summary,full_chain_summary)  = fullRun(ProdCat = ProdCat
                                                           ,ChainMasters = ChainMasters
                                                           ,dataRaw = dataRaw
                                                           ,savePKL=True
                                                           ,saveXLS=True)
# Out:
# ==================================================
# Parameters being used...
# ==================================================
# TOP_PRODUCTS = 4
# TOP_SIMILAR = 1
# RUN_PERIODS = [1, 2, 3]
# ProdCat: SUP PREM WHISKEY
# ChainMasters: ['', 'THE BARREL HOUSE', 'WESTERN BEV LIQ TX', 'SPECS']
#
#
# ========================== (2020-09-01 14:36:46.077671)
# ===== Products List  =====
# ==== SUP PREM WHISKEY ====
# ============  ============
# ==========================
#
#
#
# ========================== (2020-09-01 14:36:49.904138)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 1 ============
# ==========================
#
#
#
# ================== (2020-09-01 14:36:49.904138)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS BLK WHSKY SQ 375M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 1.1904761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY SQ 375M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0']
# % of weeks without a purchase: 44.047619047619044
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY SQ 375M
#
#
# ===================== (2020-09-01 14:37:15.804310)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#       lb_stat  lb_pvalue
# 12  17.529696   0.130735
# 24  31.092108   0.151145
# 48  54.922995   0.228882
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12  115.750529  4.333814e-19
# 24  214.169023  1.845834e-32
# 48  308.098428  1.176533e-39
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   76.707883  1.745018e-11
# 24  131.122583  9.711501e-17
# 48  214.957410  5.416649e-23
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  236.849902  7.504140e-44
# 24  313.152234  3.733315e-52
# 48  457.992618  2.867236e-68
#
# Is Data White Noise: False
#
#
# ==================== (2020-09-01 14:37:15.819352)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (83, 4) (1, 4)
# (83, 4) (1, 4)
# (83, 4) (1, 4)
# (83, 4) (1, 4)
#
#
# =============== (2020-09-01 14:37:15.822323)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.043169         []
# 1  1      last   0.324455         []
# 2  2      mean   0.427990         []
# 3  3      mean   0.798321         []
#
#                                            All RMSEs  \
# 0  [[0.07143315389555474, 0.11332894033533458, 0....
# 1  [[0.3244545696539494, 0.4963154566538675, 0.34...
# 2  [[0.6704496090247218, 0.719929333484661, 0.427...
# 3  [[1.158356517777329, 1.1898741527817909, 0.798...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-01 14:37:16.091648)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  3.7min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  3.7min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-01 14:40:57.751984)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  4.5min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  4.5min finished
# =================== (2020-09-01 14:45:30.493262)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-01 14:45:30.496260)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 1 ============
# ==========================
#
#
#
# =========================== (2020-09-01 14:45:30.496260)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ============  =============
# ============ 1 ============
# ===========================
#
#
#
# ================== (2020-09-01 14:45:30.499261)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS BLK WHSKY SQ 375M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 1.1904761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY SQ 375M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0']
# % of weeks without a purchase: 44.047619047619044
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY SQ 375M
#
#
# ==================== (2020-09-01 14:46:02.335848)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (83, 4) (1, 4)
# (83, 4) (1, 4)
# (83, 4) (1, 4)
# (83, 4) (1, 4)
#
#
# ======================== (2020-09-01 14:46:02.339846)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-01 14:46:02.350847)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False, False]
#
#
# =============== (2020-09-01 14:46:02.352849)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-01 14:46:02.358877)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-01 14:46:02.359874)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-01 14:46:02.360849)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-01 14:46:02.443697)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-01 14:46:02.448693)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-01 14:46:54.774628)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-01 14:46:54.865626)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-01 14:46:54.866625)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-01 14:46:54.944623)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-01 14:46:54.950623)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-01 14:47:41.536396)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-01 14:47:41.610396)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-01 14:47:41.613397)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 2 ============
# ==========================
#
#
#
# ================== (2020-09-01 14:47:41.613397)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS BLK WHSKY SQ 375M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 1.2048192771084338
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY SQ 375M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0']
# % of weeks without a purchase: 44.57831325301205
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY SQ 375M
#
#
# ===================== (2020-09-01 14:48:06.312940)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#       lb_stat  lb_pvalue
# 12  17.074759   0.146807
# 24  30.689164   0.162949
# 48  53.509495   0.271059
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12  113.741522  1.085921e-18
# 24  210.737801  8.608130e-32
# 48  298.546482  6.801454e-38
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   73.433730  7.257343e-11
# 24  127.792143  3.888372e-16
# 48  208.580703  6.624266e-22
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  233.654157  3.467423e-43
# 24  301.956845  6.767463e-50
# 48  453.324573  2.340339e-67
#
# Is Data White Noise: False
#
#
# ==================== (2020-09-01 14:48:06.325940)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (82, 4) (1, 4)
# (82, 4) (1, 4)
# (82, 4) (1, 4)
# (82, 4) (1, 4)
#
#
# =============== (2020-09-01 14:48:06.328974)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.021557         []
# 1  1      mean   0.323943         []
# 2  2      mean   0.373199         []
# 3  3      mean   0.669609         []
#
#                                            All RMSEs  \
# 0  [[0.057546587491533165, 0.09126460007014617, 0...
# 1  [[0.3342880201030623, 0.4694144778845947, 0.32...
# 2  [[0.6160411345584191, 0.6054018321634664, 0.37...
# 3  [[1.1334719691929973, 1.0359040362506735, 0.66...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-01 14:48:06.636943)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  3.5min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  3.5min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-01 14:51:38.966600)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  3.9min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  3.9min finished
# =================== (2020-09-01 14:55:33.464712)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-01 14:55:33.469707)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 2 ============
# ==========================
#
#
#
# =========================== (2020-09-01 14:55:33.469707)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ============  =============
# ============ 2 ============
# ===========================
#
#
#
# ================== (2020-09-01 14:55:33.471679)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS BLK WHSKY SQ 375M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 1.2048192771084338
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY SQ 375M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0']
# % of weeks without a purchase: 44.57831325301205
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY SQ 375M
#
#
# ==================== (2020-09-01 14:56:04.426655)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (82, 4) (1, 4)
# (82, 4) (1, 4)
# (82, 4) (1, 4)
# (82, 4) (1, 4)
#
#
# ======================== (2020-09-01 14:56:04.439686)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-01 14:56:04.455684)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False, False]
#
#
# =============== (2020-09-01 14:56:04.457684)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-01 14:56:04.465653)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-01 14:56:04.466654)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-01 14:56:04.466654)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-01 14:56:04.604334)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-01 14:56:04.612332)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-01 14:56:51.744303)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-01 14:56:51.857303)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-01 14:56:51.858304)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-01 14:56:51.970303)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-01 14:56:51.978304)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-01 14:57:46.075736)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-01 14:57:46.174738)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-01 14:57:46.178738)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 3 ============
# ==========================
#
#
#
# ================== (2020-09-01 14:57:46.178738)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS BLK WHSKY SQ 375M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY SQ 375M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0']
# % of weeks without a purchase: 45.1219512195122
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY SQ 375M
#
#
# ===================== (2020-09-01 14:58:13.403360)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#       lb_stat  lb_pvalue
# 12  16.492825   0.169692
# 24  29.613691   0.197887
# 48  52.235849   0.312831
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12  111.729571  2.720557e-18
# 24  207.460783  3.736074e-31
# 48  291.621010  1.270149e-36
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   72.023277  1.337193e-10
# 24  126.557635  6.490946e-16
# 48  206.128607  1.725436e-21
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  227.003218  8.357786e-42
# 24  289.400873  2.267177e-47
# 48  442.433742  3.108030e-65
#
# Is Data White Noise: False
#
#
# ==================== (2020-09-01 14:58:13.420364)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (81, 4) (1, 4)
# (81, 4) (1, 4)
# (81, 4) (1, 4)
# (81, 4) (1, 4)
#
#
# =============== (2020-09-01 14:58:13.423364)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.033917         []
# 1  1      mean   0.319180         []
# 2  2      mean   0.373056         []
# 3  3      mean   0.627867         []
#
#                                            All RMSEs  \
# 0  [[0.0872048496772559, 0.1165490736094128, 0.03...
# 1  [[0.35617856342347604, 0.5500854364755055, 0.3...
# 2  [[0.556716035671863, 0.5707857245806156, 0.373...
# 3  [[1.0772290858881073, 1.0184226921157236, 0.62...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-01 14:58:13.754393)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  3.8min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  3.8min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-01 15:01:59.387299)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  4.2min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  4.2min finished
# =================== (2020-09-01 15:06:11.106858)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-01 15:06:11.113859)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 3 ============
# ==========================
#
#
#
# =========================== (2020-09-01 15:06:11.113859)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ============  =============
# ============ 3 ============
# ===========================
#
#
#
# ================== (2020-09-01 15:06:11.115858)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS BLK WHSKY SQ 375M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY SQ 375M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0']
# % of weeks without a purchase: 45.1219512195122
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY SQ 375M
#
#
# ==================== (2020-09-01 15:06:38.765478)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (81, 4) (1, 4)
# (81, 4) (1, 4)
# (81, 4) (1, 4)
# (81, 4) (1, 4)
#
#
# ======================== (2020-09-01 15:06:38.768506)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-01 15:06:38.780481)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False, False]
#
#
# =============== (2020-09-01 15:06:38.783476)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-01 15:06:38.789509)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-01 15:06:38.789509)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-01 15:06:38.790507)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-01 15:06:38.859480)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-01 15:06:38.866506)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-01 15:07:25.237305)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-01 15:07:25.311304)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-01 15:07:25.311304)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-01 15:07:25.368302)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-01 15:07:25.372304)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-01 15:08:12.790258)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-01 15:08:12.856287)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-01 15:08:12.861287)
# ===== Products List  =====
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 15:08:13.652681)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 1 ============
# ==========================
#
#
#
# ========================== (2020-09-01 15:08:13.652681)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'GENTLEMAN JACK WHSKY OL 750M', '2': 'JACK DANIELS TENN HNY WHSKY  1L', '3': 'GENTLEMAN JACK WHSKY 6PK 1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3']
# % of weeks without a purchase: 45.23809523809524
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3']
# % of weeks without a purchase: 52.38095238095239
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 48.80952380952381
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY 6PK 1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '1']
# % of weeks without a purchase: 32.926829268292686
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY 6PK 1L
#
#
# ========================== (2020-09-01 15:08:38.033081)
# ====== WHITE NOISE =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#        lb_stat  lb_pvalue
# 12   24.932218   0.015147
# 24   47.266936   0.003107
# 48  103.010327   0.000007
#
# Is Data White Noise: False
#        lb_stat  lb_pvalue
# 12   24.646813   0.016588
# 24   50.653838   0.001168
# 48  108.922594   0.000001
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  11.113828   0.519190
# 24  30.880617   0.157255
# 48  53.855113   0.260331
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12   8.641692   0.733192
# 24  19.315056   0.734985
# 48  47.523727   0.492264
#
# Is Data White Noise: True
#
#
# ========================== (2020-09-01 15:08:38.044079)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (83, 4) (1, 4)
# (83, 4) (1, 4)
# (83, 4) (1, 4)
# (81, 4) (1, 4)
#
#
# ========================== (2020-09-01 15:08:38.047080)
# ========= NAIVE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#   ID      Best Type  Best RMSE All Naives  \
# 0  0           mean   1.149908         []
# 1  1           last   0.508452         []
# 2  2  seasonal_last   0.539165         []
# 3  3           mean   0.611153         []
#
#                                            All RMSEs  \
# 0  [[1.3378491195367055, 1.5550765479093094, 1.14...
# 1  [[0.5084521358062825, 1.227326606712806, 0.861...
# 2  [[0.8388226345645782, 0.5391649362857315, 0.68...
# 3  [[0.7042605406907361, 0.7703384907350979, 0.61...
#
#                        All Types  \
# 0  [[last, seasonal_last, mean]]
# 1  [[last, seasonal_last, mean]]
# 2  [[last, seasonal_last, mean]]
# 3  [[last, seasonal_last, mean]]
#
#                                         Best Naive
# 0           NaiveForecaster(sp=4, strategy='mean')
# 1                            NaiveForecaster(sp=4)
# 2  NaiveForecaster(sp=4, strategy='seasonal_last')
# 3           NaiveForecaster(sp=4, strategy='mean')
#
#
# ========================== (2020-09-01 15:08:38.313081)
# ====== Multivar P0 =======
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  3.8min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  3.8min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================== (2020-09-01 15:12:25.246453)
# ==== Multivar P0+Sim =====
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  4.3min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  4.3min finished
# ========================== (2020-09-01 15:16:40.851980)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 15:16:40.856964)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 1 ============
# ==========================
#
#
#
# =========================== (2020-09-01 15:16:40.856964)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ==== THE BARREL HOUSE =====
# ============ 1 ============
# ===========================
#
#
#
# ========================== (2020-09-01 15:16:40.858983)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'GENTLEMAN JACK WHSKY OL 750M', '2': 'JACK DANIELS TENN HNY WHSKY  1L', '3': 'GENTLEMAN JACK WHSKY 6PK 1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3']
# % of weeks without a purchase: 45.23809523809524
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3']
# % of weeks without a purchase: 52.38095238095239
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 48.80952380952381
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY 6PK 1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '1']
# % of weeks without a purchase: 32.926829268292686
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY 6PK 1L
#
#
# ========================== (2020-09-01 15:17:18.472362)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (83, 4) (1, 4)
# (83, 4) (1, 4)
# (83, 4) (1, 4)
# (81, 4) (1, 4)
#
#
# ========================== (2020-09-01 15:17:18.476333)
# ===== NAIVE FORECAST =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 15:17:18.487335)
# ========== MASK ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
# Mask: [False, False, False, False]
#
#
# ========================== (2020-09-01 15:17:18.489335)
# ========= SPACE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 15:17:18.494335)
# ======= Test Index =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 15:17:18.495335)
# ==== GET FUNCTION P0 =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ====================================== (2020-09-01 15:17:18.495335)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ========== THE BARREL HOUSE ==========
# ======================================
#
#
#
# ========================== (2020-09-01 15:17:18.611339)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 15:17:18.618335)
# ===== OPTIMIZING P0 ======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 15:18:16.113703)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ============================= (2020-09-01 15:18:16.259702)
# ==== GET FUNCTION P0+Sim ====
# ===== THE BARREL HOUSE ======
# =============================
#
#
#
# ========================================== (2020-09-01 15:18:16.260702)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ============ THE BARREL HOUSE ============
# ==========================================
#
#
#
# ========================== (2020-09-01 15:18:16.370706)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# =========================== (2020-09-01 15:18:16.374705)
# ==== OPTIMIZING P0+Sim ====
# ==== THE BARREL HOUSE =====
# ===========================
#
#
#
# ========================== (2020-09-01 15:19:07.925844)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 15:19:08.131036)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 15:19:08.137033)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 2 ============
# ==========================
#
#
#
# ========================== (2020-09-01 15:19:08.137033)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'GENTLEMAN JACK WHSKY OL 750M', '2': 'JACK DANIELS TENN HNY WHSKY  1L', '3': 'GENTLEMAN JACK WHSKY 6PK 1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3']
# % of weeks without a purchase: 45.78313253012048
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3']
# % of weeks without a purchase: 53.01204819277109
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 49.39759036144578
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY 6PK 1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '1']
# % of weeks without a purchase: 33.33333333333333
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY 6PK 1L
#
#
# ========================== (2020-09-01 15:19:43.978377)
# ====== WHITE NOISE =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#       lb_stat  lb_pvalue
# 12  23.922535   0.020840
# 24  45.414544   0.005201
# 48  99.152623   0.000020
#
# Is Data White Noise: False
#        lb_stat  lb_pvalue
# 12   25.814484   0.011401
# 24   50.372270   0.001269
# 48  100.845296   0.000013
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  10.794767   0.546584
# 24  29.686533   0.195359
# 48  53.100408   0.284097
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12   8.057662   0.780608
# 24  17.817943   0.811750
# 48  41.544821   0.733036
#
# Is Data White Noise: True
#
#
# ========================== (2020-09-01 15:19:43.998795)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (82, 4) (1, 4)
# (82, 4) (1, 4)
# (82, 4) (1, 4)
# (80, 4) (1, 4)
#
#
# ========================== (2020-09-01 15:19:44.002793)
# ========= NAIVE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#   ID      Best Type  Best RMSE All Naives  \
# 0  0           last   1.279671         []
# 1  1           last   0.397118         []
# 2  2  seasonal_last   0.583337         []
# 3  3           mean   0.532525         []
#
#                                            All RMSEs  \
# 0  [[1.2796706251393728, 1.655747949478816, 1.324...
# 1  [[0.3971180356035492, 1.0727385943033805, 0.73...
# 2  [[0.9401093055023353, 0.5833369983034572, 0.76...
# 3  [[0.5741726496470821, 0.6294921160859183, 0.53...
#
#                        All Types  \
# 0  [[last, seasonal_last, mean]]
# 1  [[last, seasonal_last, mean]]
# 2  [[last, seasonal_last, mean]]
# 3  [[last, seasonal_last, mean]]
#
#                                         Best Naive
# 0                            NaiveForecaster(sp=4)
# 1                            NaiveForecaster(sp=4)
# 2  NaiveForecaster(sp=4, strategy='seasonal_last')
# 3           NaiveForecaster(sp=4, strategy='mean')
#
#
# ========================== (2020-09-01 15:19:44.394111)
# ====== Multivar P0 =======
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  4.8min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  4.8min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================== (2020-09-01 15:24:31.074495)
# ==== Multivar P0+Sim =====
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  5.2min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  5.2min finished
# ========================== (2020-09-01 15:29:42.165523)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 15:29:42.174043)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 2 ============
# ==========================
#
#
#
# =========================== (2020-09-01 15:29:42.175043)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ==== THE BARREL HOUSE =====
# ============ 2 ============
# ===========================
#
#
#
# ========================== (2020-09-01 15:29:42.177043)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'GENTLEMAN JACK WHSKY OL 750M', '2': 'JACK DANIELS TENN HNY WHSKY  1L', '3': 'GENTLEMAN JACK WHSKY 6PK 1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3']
# % of weeks without a purchase: 45.78313253012048
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3']
# % of weeks without a purchase: 53.01204819277109
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 49.39759036144578
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY 6PK 1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '1']
# % of weeks without a purchase: 33.33333333333333
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY 6PK 1L
#
#
# ========================== (2020-09-01 15:30:27.369097)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (82, 4) (1, 4)
# (82, 4) (1, 4)
# (82, 4) (1, 4)
# (80, 4) (1, 4)
#
#
# ========================== (2020-09-01 15:30:27.378100)
# ===== NAIVE FORECAST =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 15:30:27.398098)
# ========== MASK ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
# Mask: [False, False, False, False]
#
#
# ========================== (2020-09-01 15:30:27.400099)
# ========= SPACE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 15:30:27.408098)
# ======= Test Index =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 15:30:27.409097)
# ==== GET FUNCTION P0 =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ====================================== (2020-09-01 15:30:27.409097)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ========== THE BARREL HOUSE ==========
# ======================================
#
#
#
# ========================== (2020-09-01 15:30:27.636100)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 15:30:27.646098)
# ===== OPTIMIZING P0 ======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 15:31:38.566410)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ============================= (2020-09-01 15:31:38.822408)
# ==== GET FUNCTION P0+Sim ====
# ===== THE BARREL HOUSE ======
# =============================
#
#
#
# ========================================== (2020-09-01 15:31:38.824408)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ============ THE BARREL HOUSE ============
# ==========================================
#
#
#
# ========================== (2020-09-01 15:31:39.085408)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# =========================== (2020-09-01 15:31:39.091407)
# ==== OPTIMIZING P0+Sim ====
# ==== THE BARREL HOUSE =====
# ===========================
#
#
#
# ========================== (2020-09-01 15:32:48.028464)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 15:32:48.255500)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 15:32:48.263495)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 3 ============
# ==========================
#
#
#
# ========================== (2020-09-01 15:32:48.264495)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'GENTLEMAN JACK WHSKY OL 750M', '2': 'JACK DANIELS TENN HNY WHSKY  1L', '3': 'GENTLEMAN JACK WHSKY 6PK 1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3']
# % of weeks without a purchase: 46.34146341463415
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3']
# % of weeks without a purchase: 52.4390243902439
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 48.78048780487805
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY 6PK 1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '1']
# % of weeks without a purchase: 33.75
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY 6PK 1L
#
#
# ========================== (2020-09-01 15:33:38.607247)
# ====== WHITE NOISE =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#       lb_stat  lb_pvalue
# 12  22.966606   0.028011
# 24  43.950059   0.007733
# 48  96.983960   0.000037
#
# Is Data White Noise: False
#        lb_stat  lb_pvalue
# 12   27.402860   0.006758
# 24   51.649912   0.000869
# 48  103.761135   0.000006
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  10.052476   0.611357
# 24  29.222626   0.211865
# 48  50.699491   0.367565
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12   7.723903   0.806317
# 24  17.026775   0.847518
# 48  40.563386   0.768264
#
# Is Data White Noise: True
#
#
# ========================== (2020-09-01 15:33:38.626228)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (81, 4) (1, 4)
# (81, 4) (1, 4)
# (81, 4) (1, 4)
# (79, 4) (1, 4)
#
#
# ========================== (2020-09-01 15:33:38.632220)
# ========= NAIVE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#   ID      Best Type  Best RMSE All Naives  \
# 0  0           last   1.309084         []
# 1  1           last   0.575651         []
# 2  2  seasonal_last   0.456328         []
# 3  3           last   0.514092         []
#
#                                            All RMSEs  \
# 0  [[1.3090836993967807, 1.5116570412722945, 1.34...
# 1  [[0.5756510191046259, 0.8723064569251162, 0.77...
# 2  [[0.9401093055023353, 0.4563275126911478, 0.73...
# 3  [[0.5140918075121166, 0.680195528305364, 0.545...
#
#                        All Types  \
# 0  [[last, seasonal_last, mean]]
# 1  [[last, seasonal_last, mean]]
# 2  [[last, seasonal_last, mean]]
# 3  [[last, seasonal_last, mean]]
#
#                                         Best Naive
# 0                            NaiveForecaster(sp=4)
# 1                            NaiveForecaster(sp=4)
# 2  NaiveForecaster(sp=4, strategy='seasonal_last')
# 3                            NaiveForecaster(sp=4)
#
#
# ========================== (2020-09-01 15:33:39.259971)
# ====== Multivar P0 =======
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  7.1min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  7.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================== (2020-09-01 15:40:44.615712)
# ==== Multivar P0+Sim =====
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  5.4min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  5.4min finished
# ========================== (2020-09-01 15:46:09.782820)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 15:46:09.790824)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 3 ============
# ==========================
#
#
#
# =========================== (2020-09-01 15:46:09.790824)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ==== THE BARREL HOUSE =====
# ============ 3 ============
# ===========================
#
#
#
# ========================== (2020-09-01 15:46:09.793823)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'GENTLEMAN JACK WHSKY OL 750M', '2': 'JACK DANIELS TENN HNY WHSKY  1L', '3': 'GENTLEMAN JACK WHSKY 6PK 1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3']
# ...
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 2.4096385542168677
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
#
#
# ===================== (2020-09-01 16:37:03.953685)
# ==== WHITE NOISE ====
# ======= SPECS =======
# =====================
#
#       lb_stat  lb_pvalue
# 12  15.010561   0.240859
# 24  26.255626   0.340323
# 48  46.813983   0.521457
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12  28.602170   0.004512
# 24  40.565661   0.018579
# 48  53.111411   0.283742
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12  26.462991   0.009225
# 24  37.259357   0.041220
# 48  54.606396   0.237935
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12   6.590230   0.883464
# 24  11.084958   0.988393
# 48  32.593075   0.956498
#
# Is Data White Noise: True
#
#
# ==================== (2020-09-01 16:37:03.964661)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (82, 4) (1, 4)
# (82, 4) (1, 4)
# (82, 4) (1, 4)
# (82, 4) (1, 4)
#
#
# =============== (2020-09-01 16:37:03.967688)
# ==== NAIVE ====
# ==== SPECS ====
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.033192         []
# 1  1      mean   0.118510         []
# 2  2      mean   0.224583         []
# 3  3      mean   0.067342         []
#
#                                            All RMSEs  \
# 0  [[0.0935827577097994, 0.10896925774528339, 0.0...
# 1  [[0.17264955504702825, 0.17422646327023725, 0....
# 2  [[0.4363032505606732, 0.3550157822095886, 0.22...
# 3  [[0.09595064453644367, 0.12091221353553756, 0....
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-01 16:37:04.212661)
# ==== Multivar P0 ====
# ======= SPECS =======
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  2.8min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  2.8min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-01 16:39:51.735691)
# ==== Multivar P0+Sim ====
# ========= SPECS =========
# =========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  2.9min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  2.9min finished
# =================== (2020-09-01 16:42:44.997666)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ========================== (2020-09-01 16:42:45.002662)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ========= SPECS ==========
# =========== 2 ============
# ==========================
#
#
#
# =========================== (2020-09-01 16:42:45.003661)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ========== SPECS ==========
# ============ 2 ============
# ===========================
#
#
#
# ================== (2020-09-01 16:42:45.005693)
# ==== GET DATA ====
# ===== SPECS ======
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS TENN HNY WHSKY  1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 8.433734939759036
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 2.4096385542168677
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
#
#
# ==================== (2020-09-01 16:43:09.945690)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (82, 4) (1, 4)
# (82, 4) (1, 4)
# (82, 4) (1, 4)
# (82, 4) (1, 4)
#
#
# ======================== (2020-09-01 16:43:09.948689)
# ==== NAIVE FORECAST ====
# ======== SPECS =========
# ========================
#
#
#
# =============== (2020-09-01 16:43:09.959690)
# ==== MASK =====
# ==== SPECS ====
# ===============
#
# Mask: [False, False, False, False]
#
#
# =============== (2020-09-01 16:43:09.960694)
# ==== SPACE ====
# ==== SPECS ====
# ===============
#
#
#
# ==================== (2020-09-01 16:43:09.965691)
# ==== Test Index ====
# ====== SPECS =======
# ====================
#
#
#
# ========================= (2020-09-01 16:43:09.966693)
# ==== GET FUNCTION P0 ====
# ========= SPECS =========
# =========================
#
#
#
# ====================================== (2020-09-01 16:43:09.966693)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# =============== SPECS ================
# ======================================
#
#
#
# =================== (2020-09-01 16:43:10.046663)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ======================= (2020-09-01 16:43:10.050690)
# ==== OPTIMIZING P0 ====
# ======== SPECS ========
# =======================
#
#
#
# =================== (2020-09-01 16:43:54.867663)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ============================= (2020-09-01 16:43:54.979660)
# ==== GET FUNCTION P0+Sim ====
# =========== SPECS ===========
# =============================
#
#
#
# ========================================== (2020-09-01 16:43:54.979660)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ================= SPECS ==================
# ==========================================
#
#
#
# =================== (2020-09-01 16:43:55.043661)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =========================== (2020-09-01 16:43:55.049659)
# ==== OPTIMIZING P0+Sim ====
# ========== SPECS ==========
# ===========================
#
#
#
# =================== (2020-09-01 16:44:41.426661)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =================== (2020-09-01 16:44:41.501660)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ========================== (2020-09-01 16:44:41.508692)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ========= SPECS ==========
# =========== 3 ============
# ==========================
#
#
#
# ================== (2020-09-01 16:44:41.508692)
# ==== GET DATA ====
# ===== SPECS ======
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS TENN HNY WHSKY  1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 8.536585365853659
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 2.4390243902439024
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
#
#
# ===================== (2020-09-01 16:45:06.789661)
# ==== WHITE NOISE ====
# ======= SPECS =======
# =====================
#
#       lb_stat  lb_pvalue
# 12  14.591506   0.264539
# 24  25.708961   0.368096
# 48  45.847359   0.561475
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12  28.056071   0.005429
# 24  39.797909   0.022480
# 48  52.199800   0.314062
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12  26.241054   0.009922
# 24  37.090548   0.042858
# 48  54.361071   0.245108
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12   6.530656   0.887010
# 24  11.020075   0.988868
# 48  32.169399   0.961455
#
# Is Data White Noise: True
#
#
# ==================== (2020-09-01 16:45:06.799685)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (81, 4) (1, 4)
# (81, 4) (1, 4)
# (81, 4) (1, 4)
# (81, 4) (1, 4)
#
#
# =============== (2020-09-01 16:45:06.801686)
# ==== NAIVE ====
# ==== SPECS ====
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.051513         []
# 1  1      mean   0.109428         []
# 2  2      mean   0.221377         []
# 3  3      mean   0.086918         []
#
#                                            All RMSEs  \
# 0  [[0.12459174747365168, 0.13927072207458754, 0....
# 1  [[0.18390429323643792, 0.17762873456667566, 0....
# 2  [[0.4245652552570759, 0.3288519908859398, 0.22...
# 3  [[0.08808657027865822, 0.126322489261891, 0.08...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-01 16:45:07.048665)
# ==== Multivar P0 ====
# ======= SPECS =======
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  2.7min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  2.7min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-01 16:47:49.209679)
# ==== Multivar P0+Sim ====
# ========= SPECS =========
# =========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  2.9min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  2.9min finished
# =================== (2020-09-01 16:50:41.855709)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ========================== (2020-09-01 16:50:41.861678)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ========= SPECS ==========
# =========== 3 ============
# ==========================
#
#
#
# =========================== (2020-09-01 16:50:41.861678)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ========== SPECS ==========
# ============ 3 ============
# ===========================
#
#
#
# ================== (2020-09-01 16:50:41.863683)
# ==== GET DATA ====
# ===== SPECS ======
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS TENN HNY WHSKY  1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 8.536585365853659
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 2.4390243902439024
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
#
#
# ==================== (2020-09-01 16:51:06.879701)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (81, 4) (1, 4)
# (81, 4) (1, 4)
# (81, 4) (1, 4)
# (81, 4) (1, 4)
#
#
# ======================== (2020-09-01 16:51:06.883677)
# ==== NAIVE FORECAST ====
# ======== SPECS =========
# ========================
#
#
#
# =============== (2020-09-01 16:51:06.893702)
# ==== MASK =====
# ==== SPECS ====
# ===============
#
# Mask: [False, False, False, False]
#
#
# =============== (2020-09-01 16:51:06.894680)
# ==== SPACE ====
# ==== SPECS ====
# ===============
#
#
#
# ==================== (2020-09-01 16:51:06.900678)
# ==== Test Index ====
# ====== SPECS =======
# ====================
#
#
#
# ========================= (2020-09-01 16:51:06.900678)
# ==== GET FUNCTION P0 ====
# ========= SPECS =========
# =========================
#
#
#
# ====================================== (2020-09-01 16:51:06.901677)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# =============== SPECS ================
# ======================================
#
#
#
# =================== (2020-09-01 16:51:06.993677)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ======================= (2020-09-01 16:51:06.996676)
# ==== OPTIMIZING P0 ====
# ======== SPECS ========
# =======================
#
#
#
# =================== (2020-09-01 16:51:53.132678)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ============================= (2020-09-01 16:51:53.231680)
# ==== GET FUNCTION P0+Sim ====
# =========== SPECS ===========
# =============================
#
#
#
# ========================================== (2020-09-01 16:51:53.231680)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ================= SPECS ==================
# ==========================================
#
#
#
# =================== (2020-09-01 16:51:53.315678)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =========================== (2020-09-01 16:51:53.319676)
# ==== OPTIMIZING P0+Sim ====
# ========== SPECS ==========
# ===========================
#
#
#
# =================== (2020-09-01 16:52:34.327679)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =================== (2020-09-01 16:52:34.409677)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ========================== (2020-09-01 16:52:34.418681)
# ==== Saving to PICKLE ====
# ==== SUP PREM WHISKEY ====
# ==========================
#
# Pickle File  full_models_SUP PREM WHISKEY_Prod4_Sim1_Per123.pkl  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns
# Pickle File  full_opt_SUP PREM WHISKEY_Prod4_Sim1_Per123.pkl  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns
#
#
# ========================== (2020-09-01 16:52:34.552711)
# ==== Saving to EXCEL =====
# ==== SUP PREM WHISKEY ====
# ==========================
#
# EXCEL File  Output_SUP PREM WHISKEY_Prod4_Sim1_Per123.xlsx  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns

# %% [markdown]
# # Print out

# %% [markdown]
# ## Models

# %%
full_models[outputColsModels]
# Out:
#           Chain Master                          Product  Period to Last  \
# 1                         JACK DANIELS BLK WHSKY  1.75L               1
# 5                         JACK DANIELS BLK WHSKY  1.75L               2
# 9                         JACK DANIELS BLK WHSKY  1.75L               3
# 0                            JACK DANIELS BLK WHSKY  1L               1
# 4                            JACK DANIELS BLK WHSKY  1L               2
# 8                            JACK DANIELS BLK WHSKY  1L               3
# 2                          JACK DANIELS BLK WHSKY  750M               1
# 6                          JACK DANIELS BLK WHSKY  750M               2
# 10                         JACK DANIELS BLK WHSKY  750M               3
# 3                        JACK DANIELS BLK WHSKY SQ 375M               1
# 7                        JACK DANIELS BLK WHSKY SQ 375M               2
# 11                       JACK DANIELS BLK WHSKY SQ 375M               3
# 37               SPECS    JACK DANIELS BLK WHSKY  1.75L               1
# 41               SPECS    JACK DANIELS BLK WHSKY  1.75L               2
# 45               SPECS    JACK DANIELS BLK WHSKY  1.75L               3
# 36               SPECS       JACK DANIELS BLK WHSKY  1L               1
# 40               SPECS       JACK DANIELS BLK WHSKY  1L               2
# 44               SPECS       JACK DANIELS BLK WHSKY  1L               3
# 38               SPECS     JACK DANIELS BLK WHSKY  750M               1
# 42               SPECS     JACK DANIELS BLK WHSKY  750M               2
# 46               SPECS     JACK DANIELS BLK WHSKY  750M               3
# 39               SPECS  JACK DANIELS TENN HNY WHSKY  1L               1
# 43               SPECS  JACK DANIELS TENN HNY WHSKY  1L               2
# 47               SPECS  JACK DANIELS TENN HNY WHSKY  1L               3
# 15    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               1
# 19    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               2
# 23    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               3
# 13    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               1
# 17    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               2
# 21    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               3
# 12    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               1
# 16    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               2
# 20    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               3
# 14    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               1
# 18    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               2
# 22    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               3
# 24  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               1
# 28  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               2
# 32  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               3
# 26  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               1
# 30  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               2
# 34  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               3
# 25  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               1
# 29  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               2
# 33  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               3
# 27  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               1
# 31  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               2
# 35  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               3
#
#     White Noise Naive Best Type  Naive Best RMSE P0 Best Model Name  \
# 1         False            last         0.324455       auto_SARIMAX
# 5         False            mean         0.323943       auto_SARIMAX
# 9         False            mean         0.319180       auto_SARIMAX
# 0          True            mean         0.043169            SARIMAX
# 4          True            mean         0.021557                 ML
# 8          True            mean         0.033917                 ML
# 2         False            mean         0.427990            SARIMAX
# 6         False            mean         0.373199            SARIMAX
# 10        False            mean         0.373056            SARIMAX
# 3         False            mean         0.798321                 ML
# 7         False            mean         0.669609                 ML
# 11        False            mean         0.627867       auto_SARIMAX
# 37         True            mean         0.159196            SARIMAX
# 41         True            mean         0.118510            SARIMAX
# 45         True            mean         0.109428            SARIMAX
# 36         True            mean         0.060885            SARIMAX
# 40         True            mean         0.033192                 ML
# 44         True            mean         0.051513                 ML
# 38         True            mean         0.276661       auto_SARIMAX
# 42         True            mean         0.224583                 ML
# 46         True            mean         0.221377                 ML
# 39         True            mean         0.075384            SARIMAX
# 43         True            mean         0.067342            SARIMAX
# 47         True            mean         0.086918                 ML
# 15         True            mean         0.611153                 ML
# 19         True            mean         0.532525                 ML
# 23         True            last         0.514092                 ML
# 13        False            last         0.508452                 ML
# 17        False            last         0.397118                 ML
# 21        False            last         0.575651       auto_SARIMAX
# 12        False            mean         1.149908                 ML
# 16        False            last         1.279671                 ML
# 20        False            last         1.309084                 ML
# 14         True   seasonal_last         0.539165                 ML
# 18         True   seasonal_last         0.583337                 ML
# 22         True   seasonal_last         0.456328                 ML
# 24        False            mean         1.192388       auto_SARIMAX
# 28        False            mean         1.152468       auto_SARIMAX
# 32        False            last         1.110996       auto_SARIMAX
# 26        False            mean         0.083096                 ML
# 30        False            mean         0.065297                 ML
# 34        False            mean         0.056411            SARIMAX
# 25        False            mean         0.706690            SARIMAX
# 29        False            mean         0.620501            SARIMAX
# 33        False            mean         0.664711                 ML
# 27        False            mean         0.804074       auto_SARIMAX
# 31        False            mean         0.675541            Prophet
# 35        False            mean         0.630851       auto_SARIMAX
#
#     P0 Best Model RMSE P0+Sim Best Model Name  P0+Sim Best Model RMSE
# 1             0.243913           auto_SARIMAX                0.183695
# 5             0.219089           auto_SARIMAX                0.161965
# 9             0.231060           auto_SARIMAX                0.188390
# 0             0.028845                SARIMAX                0.028235
# 4             0.034618                     ML                0.030985
# 8             0.057793                     ML                0.051656
# 2             0.260258           auto_SARIMAX                0.278248
# 6             0.276076                SARIMAX                0.285331
# 10            0.294087                SARIMAX                0.216242
# 3             0.625328                     ML                0.537189
# 7             0.678531                     ML                0.601043
# 11            0.631077           auto_SARIMAX                0.590020
# 37            0.106995                SARIMAX                0.129265
# 41            0.095943                SARIMAX                0.118246
# 45            0.097419                SARIMAX                0.109773
# 36            0.036516                     ML                0.037170
# 40            0.048617                     ML                0.049254
# 44            0.078627                     ML                0.075456
# 38            0.257020                     ML                0.263908
# 42            0.247969                SARIMAX                0.244295
# 46            0.272304                SARIMAX                0.245099
# 39            0.047686                SARIMAX                0.047646
# 43            0.067426                SARIMAX                0.067468
# 47            0.082990                     ML                0.082974
# 15            0.191544                     ML                0.191544
# 19            0.210643                     ML                0.210643
# 23            0.238877                     ML                0.248062
# 13            0.615271                     ML                0.615231
# 17            0.614912                     ML                0.614905
# 21            0.752658                     ML                0.741559
# 12            0.722963                     ML                0.798112
# 16            0.733968                     ML                0.802404
# 20            0.634989                     ML                0.700241
# 14            0.141021                     ML                0.140948
# 18            0.152653                     ML                0.162604
# 22            0.152653                     ML                0.162604
# 24            0.737526                Prophet                0.739690
# 28            0.791896                Prophet                0.832619
# 32            0.654468           auto_SARIMAX                0.746904
# 26            0.099956           auto_SARIMAX                0.094864
# 30            0.108532           auto_SARIMAX                0.099369
# 34            0.111910                SARIMAX                0.108810
# 25            0.577988           auto_SARIMAX                0.624688
# 29            0.580915                Prophet                0.607293
# 33            0.638930                Prophet                0.606517
# 27            0.663140                     ML                0.630593
# 31            0.715019                     ML                0.633543
# 35            0.629432           auto_SARIMAX                0.672598

# %% [markdown]
# ## Optimizer

# %% [markdown]
# ### Summary by Chain

# %%
full_chain_summary
# Out:
#          Chain Master  P0 Non-Opt Revenue  P0 Opt Revenue  P0 Opt Diff  \
# 0                                289570.0        288490.0      -1080.0
# 1               SPECS            220032.0        225619.0       5587.0
# 2    THE BARREL HOUSE              4102.0          4103.0          1.0
# 3  WESTERN BEV LIQ TX            116244.0        133381.0      17137.0
#
#    P0 Opt Diff Ratio  P0+Sim Non-Opt Revenue  P0+Sim Opt Revenue  \
# 0           0.996270                301446.0            390764.0
# 1           1.025392                218006.0            290327.0
# 2           1.000244                  4259.0              4258.0
# 3           1.147423                 89569.0           1313817.0
#
#    P0+Sim Opt Diff  P0+Sim Opt Diff Ratio
# 0          89318.0               1.296299
# 1          72321.0               1.331739
# 2             -1.0               0.999765
# 3        1224248.0              14.668211

# %%
print("WRITE this value in the summary table in Git hub --->",round(full_chain_summary[full_chain_summary['Chain Master']=='']['P0+Sim Opt Diff Ratio'].item(),4))
# Out:
# WRITE this value in the summary table in Git hub ---> 1.2963

# %% [markdown]
# Link to the Git Hub Summary Table: https://github.com/ngupta23/msds_capstone/issues/84

# %% [markdown]
# ### Summary by Chain and Product

# %%
full_summary
# Out:
#           Chain Master                          Product  P0 Non-Opt Revenue  \
# 0                         JACK DANIELS BLK WHSKY  1.75L             78808.0
# 1                            JACK DANIELS BLK WHSKY  1L            162183.0
# 2                          JACK DANIELS BLK WHSKY  750M             47810.0
# 3                        JACK DANIELS BLK WHSKY SQ 375M               769.0
# 4                SPECS    JACK DANIELS BLK WHSKY  1.75L             31102.0
# 5                SPECS       JACK DANIELS BLK WHSKY  1L            163171.0
# 6                SPECS     JACK DANIELS BLK WHSKY  750M             14658.0
# 7                SPECS  JACK DANIELS TENN HNY WHSKY  1L             11101.0
# 8     THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L              1157.0
# 9     THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               334.0
# 10    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               866.0
# 11    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L              1745.0
# 12  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L             18820.0
# 13  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L             48563.0
# 14  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M             35987.0
# 15  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M             12874.0
#
#     P0 Opt Revenue  P0 Opt Diff  P0 Opt Diff Ratio  P0+Sim Non-Opt Revenue  \
# 0          80639.0       1831.0           1.023234                 90240.0
# 1         161246.0       -937.0           0.994223                161504.0
# 2          45858.0      -1952.0           0.959172                 48937.0
# 3            747.0        -22.0           0.971391                   765.0
# 4          30562.0       -540.0           0.982638                 29714.0
# 5         162677.0       -494.0           0.996973                161911.0
# 6          21915.0       7257.0           1.495088                 15284.0
# 7          10465.0       -636.0           0.942708                 11097.0
# 8           1176.0         19.0           1.016422                  1321.0
# 9            341.0          7.0           1.020958                   200.0
# 10           855.0        -11.0           0.987298                   871.0
# 11          1731.0        -14.0           0.991977                  1867.0
# 12         31029.0      12209.0           1.648725                 13371.0
# 13         48341.0       -222.0           0.995429                 49276.0
# 14         36817.0        830.0           1.023064                 26700.0
# 15         17194.0       4320.0           1.335560                   222.0
#
#     P0+Sim Opt Revenue  P0+Sim Opt Diff  P0+Sim Opt Diff Ratio
# 0             178456.0          88216.0               1.977571
# 1             162706.0           1202.0               1.007443
# 2              48861.0            -76.0               0.998447
# 3                741.0            -24.0               0.968627
# 4             114000.0          84286.0               3.836575
# 5             153069.0          -8842.0               0.945390
# 6              13142.0          -2142.0               0.859853
# 7              10116.0           -981.0               0.911598
# 8               1338.0             17.0               1.012869
# 9                209.0              9.0               1.045000
# 10               859.0            -12.0               0.986223
# 11              1852.0            -15.0               0.991966
# 12            118285.0         104914.0               8.846384
# 13             56076.0           6800.0               1.137998
# 14            848375.0         821675.0              31.774345
# 15            291081.0         290859.0            1311.175676

# %% [markdown]
# ### P0 Optimizer

# %%
full_opt[outputColsOptP0]
# Out:
#           Chain Master                          Product  Period to Last  \
# 1                         JACK DANIELS BLK WHSKY  1.75L               1
# 5                         JACK DANIELS BLK WHSKY  1.75L               2
# 9                         JACK DANIELS BLK WHSKY  1.75L               3
# 0                            JACK DANIELS BLK WHSKY  1L               1
# 4                            JACK DANIELS BLK WHSKY  1L               2
# 8                            JACK DANIELS BLK WHSKY  1L               3
# 2                          JACK DANIELS BLK WHSKY  750M               1
# 6                          JACK DANIELS BLK WHSKY  750M               2
# 10                         JACK DANIELS BLK WHSKY  750M               3
# 3                        JACK DANIELS BLK WHSKY SQ 375M               1
# 7                        JACK DANIELS BLK WHSKY SQ 375M               2
# 11                       JACK DANIELS BLK WHSKY SQ 375M               3
# 37               SPECS    JACK DANIELS BLK WHSKY  1.75L               1
# 41               SPECS    JACK DANIELS BLK WHSKY  1.75L               2
# 45               SPECS    JACK DANIELS BLK WHSKY  1.75L               3
# 36               SPECS       JACK DANIELS BLK WHSKY  1L               1
# 40               SPECS       JACK DANIELS BLK WHSKY  1L               2
# 44               SPECS       JACK DANIELS BLK WHSKY  1L               3
# 38               SPECS     JACK DANIELS BLK WHSKY  750M               1
# 42               SPECS     JACK DANIELS BLK WHSKY  750M               2
# 46               SPECS     JACK DANIELS BLK WHSKY  750M               3
# 39               SPECS  JACK DANIELS TENN HNY WHSKY  1L               1
# 43               SPECS  JACK DANIELS TENN HNY WHSKY  1L               2
# 47               SPECS  JACK DANIELS TENN HNY WHSKY  1L               3
# 15    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               1
# 19    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               2
# 23    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               3
# 13    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               1
# 17    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               2
# 21    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               3
# 12    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               1
# 16    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               2
# 20    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               3
# 14    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               1
# 18    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               2
# 22    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               3
# 24  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               1
# 28  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               2
# 32  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               3
# 26  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               1
# 30  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               2
# 34  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               3
# 25  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               1
# 29  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               2
# 33  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               3
# 27  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               1
# 31  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               2
# 35  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               3
#
#     P0 Non-Opt Price  P0 Non-Opt Demand  P0 Non-Opt Revenue  \
# 1             185.65                224               41518
# 5             184.71                 91               16867
# 9             182.45                112               20423
# 0             229.81                310               71287
# 4             229.69                196               45027
# 8             230.09                199               45869
# 2             222.36                159               35308
# 6             222.36                 45               10052
# 10            222.36                 11                2450
# 3             188.30                  0                  93
# 7             195.60                  0                  96
# 11            195.60                  3                 580
# 37            185.59                 51                9481
# 41            184.56                 61               11168
# 45            184.94                 57               10453
# 36            229.53                239               54868
# 40            229.53                236               54108
# 44            229.53                236               54195
# 38            222.36                 20                4519
# 42            222.36                 23                5072
# 46            222.36                 23                5067
# 39            229.53                 16                3714
# 43            229.53                 16                3763
# 47            229.53                 16                3624
# 15            286.87                  1                 426
# 19            292.57                  2                 457
# 23            298.08                  1                 274
# 13            274.14                  0                  34
# 17            291.93                  0                  37
# 21            291.93                  1                 263
# 12            239.01                  1                 287
# 16            239.01                  1                 287
# 20            234.05                  1                 292
# 14            239.01                  2                 583
# 18            238.41                  2                 581
# 22            238.41                  2                 581
# 24            185.59                 96               17837
# 28            185.59                  4                 706
# 32            180.46                  2                 277
# 26            230.79                 59               13543
# 30            229.89                 59               13491
# 34            230.98                 93               21529
# 25            222.36                148               32964
# 29            222.36                  8                1783
# 33            222.36                  6                1240
# 27            188.30                  9                1770
# 31            195.60                 56               10948
# 35            195.60                  1                 156
#
#     P0 Non-Opt Chain Master Revenue  P0 Optimal Price  P0 Demand  P0 Revenue  \
# 1                            148206            185.80        224       41691
# 5                             72043            185.81         94       17380
# 9                             69322            185.82        116       21568
# 0                            148206            229.45        307       70524
# 4                             72043            229.45        196       44980
# 8                             69322            229.45        199       45742
# 2                            148206            220.34        155       34211
# 6                             72043            220.34         43        9439
# 10                            69322            220.33         10        2208
# 3                            148206            215.82          0         106
# 7                             72043            215.81          0         106
# 11                            69322            215.81          2         535
# 37                            72582            182.70         48        8747
# 41                            74111            185.07         61       11324
# 45                            73340            185.06         57       10491
# 36                            72582            229.36        238       54598
# 40                            74111            229.06        236       53996
# 44                            73340            229.06        236       54083
# 38                            72582            205.27         58       11914
# 42                            74111            219.36         23        5003
# 46                            73340            219.31         23        4998
# 39                            72582            225.86         15        3495
# 43                            74111            224.02         15        3433
# 47                            73340            224.02         16        3537
# 15                             1330            296.11          1         440
# 19                             1362            296.11          2         463
# 23                             1411            296.11          1         273
# 13                             1330            299.57          0          38
# 17                             1362            299.57          0          38
# 21                             1411            299.57          1         265
# 12                             1330            234.36          1         281
# 16                             1362            234.36          1         281
# 20                             1411            234.36          1         293
# 14                             1330            236.70          2         577
# 18                             1362            236.70          2         577
# 22                             1411            236.70          2         577
# 24                            66115            191.23        155       29556
# 28                            26928            189.33          5         959
# 32                            23203            190.37          3         514
# 26                            66115            229.42         59       13463
# 30                            26928            228.07         59       13384
# 34                            23203            230.85         93       21494
# 25                            66115            216.66        156       33873
# 29                            26928            219.31          8        1772
# 33                            23203            210.18          6        1172
# 27                            66115            186.27         10        1803
# 31                            26928            180.65         84       15246
# 35                            23203            213.20          1         145
#
#     P0 Chain Master Revenue
# 1                    146532
# 5                     71906
# 9                     70052
# 0                    146532
# 4                     71906
# 8                     70052
# 2                    146532
# 6                     71906
# 10                    70052
# 3                    146532
# 7                     71906
# 11                    70052
# 37                    78753
# 41                    73757
# 45                    73108
# 36                    78753
# 40                    73757
# 44                    73108
# 38                    78753
# 42                    73757
# 46                    73108
# 39                    78753
# 43                    73757
# 47                    73108
# 15                     1336
# 19                     1359
# 23                     1408
# 13                     1336
# 17                     1359
# 21                     1408
# 12                     1336
# 16                     1359
# 20                     1408
# 14                     1336
# 18                     1359
# 22                     1408
# 24                    78695
# 28                    31361
# 32                    23326
# 26                    78695
# 30                    31361
# 34                    23326
# 25                    78695
# 29                    31361
# 33                    23326
# 27                    78695
# 31                    31361
# 35                    23326

# %% [markdown]
# ### P0+Sim Optimizer

# %%
full_opt[outputColsOptP0Sim]
# Out:
#           Chain Master                          Product  Period to Last  \
# 1                         JACK DANIELS BLK WHSKY  1.75L               1
# 5                         JACK DANIELS BLK WHSKY  1.75L               2
# 9                         JACK DANIELS BLK WHSKY  1.75L               3
# 0                            JACK DANIELS BLK WHSKY  1L               1
# 4                            JACK DANIELS BLK WHSKY  1L               2
# 8                            JACK DANIELS BLK WHSKY  1L               3
# 2                          JACK DANIELS BLK WHSKY  750M               1
# 6                          JACK DANIELS BLK WHSKY  750M               2
# 10                         JACK DANIELS BLK WHSKY  750M               3
# 3                        JACK DANIELS BLK WHSKY SQ 375M               1
# 7                        JACK DANIELS BLK WHSKY SQ 375M               2
# 11                       JACK DANIELS BLK WHSKY SQ 375M               3
# 37               SPECS    JACK DANIELS BLK WHSKY  1.75L               1
# 41               SPECS    JACK DANIELS BLK WHSKY  1.75L               2
# 45               SPECS    JACK DANIELS BLK WHSKY  1.75L               3
# 36               SPECS       JACK DANIELS BLK WHSKY  1L               1
# 40               SPECS       JACK DANIELS BLK WHSKY  1L               2
# 44               SPECS       JACK DANIELS BLK WHSKY  1L               3
# 38               SPECS     JACK DANIELS BLK WHSKY  750M               1
# 42               SPECS     JACK DANIELS BLK WHSKY  750M               2
# 46               SPECS     JACK DANIELS BLK WHSKY  750M               3
# 39               SPECS  JACK DANIELS TENN HNY WHSKY  1L               1
# 43               SPECS  JACK DANIELS TENN HNY WHSKY  1L               2
# 47               SPECS  JACK DANIELS TENN HNY WHSKY  1L               3
# 15    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               1
# 19    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               2
# 23    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               3
# 13    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               1
# 17    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               2
# 21    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               3
# 12    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               1
# 16    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               2
# 20    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               3
# 14    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               1
# 18    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               2
# 22    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               3
# 24  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               1
# 28  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               2
# 32  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               3
# 26  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               1
# 30  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               2
# 34  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               3
# 25  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               1
# 29  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               2
# 33  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               3
# 27  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               1
# 31  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               2
# 35  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               3
#
#     P0+Sim Non-Opt Price  P0+Sim Non-Opt Demand  P0+Sim Non-Opt Revenue  \
# 1                 185.65                    186                   34602
# 5                 184.71                     98                   18109
# 9                 182.45                    206                   37529
# 0                 229.81                    307                   70608
# 4                 229.69                    196                   45027
# 8                 230.09                    199                   45869
# 2                 222.36                    133                   29472
# 6                 222.36                     35                    7848
# 10                222.36                     52                   11617
# 3                 188.30                      0                      93
# 7                 195.60                      0                      96
# 11                195.60                      3                     576
# 37                185.59                     47                    8749
# 41                184.56                     65                   11947
# 45                184.94                     49                    9018
# 36                229.53                    246                   56559
# 40                229.53                    230                   52705
# 44                229.53                    229                   52647
# 38                222.36                     23                    5030
# 42                222.36                     29                    6357
# 46                222.36                     18                    3897
# 39                229.53                     16                    3713
# 43                229.53                     16                    3761
# 47                229.53                     16                    3623
# 15                286.87                      1                     426
# 19                292.57                      2                     457
# 23                298.08                      1                     438
# 13                274.14                      0                      34
# 17                291.93                      0                      37
# 21                291.93                      0                     129
# 12                239.01                      1                     287
# 16                239.01                      1                     287
# 20                234.05                      1                     297
# 14                239.01                      3                     608
# 18                238.41                      3                     626
# 22                238.41                      3                     633
# 24                185.59                     60                   11159
# 28                185.59                     11                    1955
# 32                180.46                      1                     257
# 26                230.79                     59                   13685
# 30                229.89                     61                   13973
# 34                230.98                     94                   21618
# 25                222.36                     21                    4775
# 29                222.36                     30                    6564
# 33                222.36                     69                   15361
# 27                188.30                      1                      96
# 31                195.60                      0                      58
# 35                195.60                      0                      68
#
#     P0+Sim Non-Opt Chain Master Revenue  P0+Sim Optimal Price  P0+Sim Demand  \
# 1                                134775                169.93            411
# 5                                 71081                169.85            220
# 9                                 95591                169.77            420
# 0                                134775                228.75            316
# 4                                 71081                228.75            196
# 8                                 95591                228.74            199
# 2                                134775                224.13            126
# 6                                 71081                224.14             38
# 10                                95591                224.15             54
# 3                                134775                213.21              0
# 7                                 71081                213.20              0
# 11                                95591                213.20              2
# 37                                74051                185.28             90
# 41                                74770                167.40            469
# 45                                69186                184.53            102
# 36                                74051                212.79            246
# 40                                74770                228.33            230
# 44                                69186                210.17            229
# 38                                74051                223.69             23
# 42                                74770                224.05             27
# 46                                69186                215.32             10
# 39                                74051                221.81             15
# 43                                74770                223.21             15
# 47                                69186                219.38             16
# 15                                 1355                296.11              1
# 19                                 1407                296.11              2
# 23                                 1496                296.11              1
# 13                                 1355                299.57              0
# 17                                 1407                299.57              0
# 21                                 1496                299.57              0
# 12                                 1355                234.36              1
# 16                                 1407                234.36              1
# 20                                 1496                234.36              1
# 14                                 1355                236.70              3
# 18                                 1407                236.70              3
# 22                                 1496                236.70              3
# 24                                29714                183.85            549
# 28                                22550                184.66             94
# 32                                37305                182.14              0
# 26                                29714                214.58            105
# 30                                22550                214.79             68
# 34                                37305                214.83             89
# 25                                29714                214.36             23
# 29                                22550                210.46            656
# 33                                37305                211.03           3342
# 27                                29714                216.08              1
# 31                                22550                208.21              0
# 35                                37305                181.43           1603
#
#     P0+Sim Revenue  P0+Sim Chain Master Revenue
# 1            69785                       170319
# 5            37291                        90823
# 9            71380                       129624
# 0            72263                       170319
# 4            44842                        90823
# 8            45601                       129624
# 2            28166                       170319
# 6             8584                        90823
# 10           12111                       129624
# 3              105                       170319
# 7              105                        90823
# 11             531                       129624
# 37           16588                        77352
# 41           78544                       140343
# 45           18868                        72632
# 36           52434                        77352
# 40           52429                       140343
# 44           48206                        72632
# 38            5060                        77352
# 42            5987                       140343
# 46            2095                        72632
# 39            3269                        77352
# 43            3384                       140343
# 47            3463                        72632
# 15             440                         1361
# 19             463                         1403
# 23             435                         1492
# 13              38                         1361
# 17              38                         1403
# 21             133                         1492
# 12             281                         1361
# 16             281                         1403
# 20             297                         1492
# 14             602                         1361
# 18             622                         1403
# 22             628                         1492
# 24          100872                       128362
# 28           17391                       170193
# 32              22                      1015262
# 26           22469                       128362
# 30           14584                       170193
# 34           19023                      1015262
# 25            4911                       128362
# 29          138156                       170193
# 33          705308                      1015262
# 27             110                       128362
# 31              62                       170193
# 35          290909                      1015262

# %% [markdown]
# ### Naive

# %%
full_opt[outputColsOptNaive]
# Out:
#           Chain Master                          Product  Period to Last  \
# 1                         JACK DANIELS BLK WHSKY  1.75L               1
# 5                         JACK DANIELS BLK WHSKY  1.75L               2
# 9                         JACK DANIELS BLK WHSKY  1.75L               3
# 0                            JACK DANIELS BLK WHSKY  1L               1
# 4                            JACK DANIELS BLK WHSKY  1L               2
# 8                            JACK DANIELS BLK WHSKY  1L               3
# 2                          JACK DANIELS BLK WHSKY  750M               1
# 6                          JACK DANIELS BLK WHSKY  750M               2
# 10                         JACK DANIELS BLK WHSKY  750M               3
# 3                        JACK DANIELS BLK WHSKY SQ 375M               1
# 7                        JACK DANIELS BLK WHSKY SQ 375M               2
# 11                       JACK DANIELS BLK WHSKY SQ 375M               3
# 37               SPECS    JACK DANIELS BLK WHSKY  1.75L               1
# 41               SPECS    JACK DANIELS BLK WHSKY  1.75L               2
# 45               SPECS    JACK DANIELS BLK WHSKY  1.75L               3
# 36               SPECS       JACK DANIELS BLK WHSKY  1L               1
# 40               SPECS       JACK DANIELS BLK WHSKY  1L               2
# 44               SPECS       JACK DANIELS BLK WHSKY  1L               3
# 38               SPECS     JACK DANIELS BLK WHSKY  750M               1
# 42               SPECS     JACK DANIELS BLK WHSKY  750M               2
# 46               SPECS     JACK DANIELS BLK WHSKY  750M               3
# 39               SPECS  JACK DANIELS TENN HNY WHSKY  1L               1
# 43               SPECS  JACK DANIELS TENN HNY WHSKY  1L               2
# 47               SPECS  JACK DANIELS TENN HNY WHSKY  1L               3
# 15    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               1
# 19    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               2
# 23    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               3
# 13    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               1
# 17    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               2
# 21    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               3
# 12    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               1
# 16    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               2
# 20    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               3
# 14    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               1
# 18    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               2
# 22    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               3
# 24  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               1
# 28  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               2
# 32  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               3
# 26  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               1
# 30  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               2
# 34  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               3
# 25  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               1
# 29  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               2
# 33  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               3
# 27  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               1
# 31  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               2
# 35  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               3
#
#     Actual Price  Actual Demand  Actual Revenue  Actual Chain Master Revenue  \
# 1     185.650112         389.61        72331.14                    281489.82
# 5     184.710623          40.95         7563.90                     87687.18
# 9     182.449915         263.25        48029.94                    129024.66
# 0     229.811232         589.19       135402.48                    281489.82
# 4     229.687258         301.91        69344.88                     87687.18
# 8     230.085045         316.54        72831.12                    129024.66
# 2     222.360000         225.00        50031.00                    281489.82
# 6     222.360000          30.00         6670.80                     87687.18
# 10    222.360000          20.00         4447.20                    129024.66
# 3     188.295238         126.00        23725.20                    281489.82
# 7     195.600000          21.00         4107.60                     87687.18
# 11    195.600000          19.00         3716.40                    129024.66
# 37    185.589744         176.67        32788.14                    162000.42
# 41    184.564103          35.10         6478.20                     68510.28
# 45    184.935385         117.00        21637.44                     83198.40
# 36    229.533835         476.14       109290.24                    162000.42
# 40    229.533835         240.73        55255.68                     68510.28
# 44    229.533835         238.07        54645.12                     83198.40
# 38    222.360000          69.00        15342.84                    162000.42
# 42    222.360000          14.00         3113.04                     68510.28
# 46    222.360000          16.00         3557.76                     83198.40
# 39    229.533835          19.95         4579.20                    162000.42
# 43    229.533835          15.96         3663.36                     68510.28
# 47    229.533835          14.63         3358.08                     83198.40
# 15    286.874200           4.69         1345.44                      5862.96
# 19    292.567164           1.34          392.04                      1027.80
# 23    298.080000           0.00            0.00                      4669.20
# 13    274.144615          13.00         3563.88                      5862.96
# 17    291.927711           0.00            0.00                      1027.80
# 21    291.927711           0.00            0.00                      4669.20
# 12    239.007519           2.66          635.76                      5862.96
# 16    239.007519           2.66          635.76                      1027.80
# 20    234.045113          19.95         4669.20                      4669.20
# 14    239.007519           1.33          317.88                      5862.96
# 18    238.410000           0.00            0.00                      1027.80
# 22    238.410000           0.00            0.00                      4669.20
# 24    185.589744         210.60        39085.20                    122752.68
# 28    185.589744           5.85         1085.70                     22204.50
# 32    180.461538         146.25        26392.50                     44515.14
# 26    230.786122         110.39        25476.48                    122752.68
# 30    229.894737          58.52        13453.44                     22204.50
# 34    230.977444          58.52        13516.80                     44515.14
# 25    222.360000         155.00        34465.80                    122752.68
# 29    222.360000          16.00         3557.76                     22204.50
# 33    222.360000           4.00          889.44                     44515.14
# 27    188.295238         126.00        23725.20                    122752.68
# 31    195.600000          21.00         4107.60                     22204.50
# 35    195.600000          19.00         3716.40                     44515.14
#
#     Naive Prices  Naive Demand  Naive Revenue  Naive Chain Master Revenue
# 1     185.650112     40.950000    7602.372072                92960.401203
# 5     184.710623    157.916707   29168.893345               114657.656235
# 9     182.449915    156.616296   28574.629873               114236.662771
# 0     229.811232    292.610723   67245.230832                92960.401203
# 4     229.687258    292.497317   67182.906670               114657.656235
# 8     230.085045    292.200494   67230.963638               114236.662771
# 2     222.360000     69.590361   15474.112771                92960.401203
# 6     222.360000     70.073171   15581.470244               114657.656235
# 10    222.360000     70.691358   15718.930370               114236.662771
# 3     188.295238     14.013554    2638.685528                92960.401203
# 7     195.600000     13.928354    2724.385976               114657.656235
# 11    195.600000     13.865741    2712.138889               114236.662771
# 37    185.589744     44.962771    8344.629157                67377.335254
# 41    184.564103     45.083049    8320.712439                67316.840805
# 45    184.935385     44.195185    8173.253570                67137.717349
# 36    229.533835    217.722084   49974.584892                67377.335254
# 40    229.533835    217.441500   49910.181293                67316.840805
# 44    229.533835    217.186827   49851.725260                67137.717349
# 38    222.360000     24.319277    5407.634458                67377.335254
# 42    222.360000     24.445122    5435.617317                67316.840805
# 46    222.360000     24.549383    5458.800741                67137.717349
# 39    229.533835     15.903916    3650.486747                67377.335254
# 43    229.533835     15.903232    3650.329756                67316.840805
# 47    229.533835     15.918951    3653.937778                67137.717349
# 15    286.874200      1.169049     335.370107                 2852.240223
# 19    292.567164      1.166913     341.400281                 5743.770881
# 23    298.080000      0.000000       0.000000                 5303.370600
# 13    274.144615      0.000000       0.000000                 2852.240223
# 17    291.927711      0.000000       0.000000                 5743.770881
# 21    291.927711      0.000000       0.000000                 5303.370600
# 12    239.007519      9.200506    2198.990116                 2852.240223
# 16    239.007519     19.950000    4768.200000                 5743.770881
# 20    234.045113     19.950000    4669.200000                 5303.370600
# 14    239.007519      1.330000     317.880000                 2852.240223
# 18    238.410000      2.660000     634.170600                 5743.770881
# 22    238.410000      2.660000     634.170600                 5303.370600
# 24    185.589744    110.560063   20518.813797                48406.991208
# 28    185.589744    111.902500   20767.956282                48812.372432
# 32    180.461538      0.000000       0.000000                28241.967210
# 26    230.786122     66.489207   15344.786307                48406.991208
# 30    229.894737     66.587593   15308.137076                48812.372432
# 34    230.977444     66.688437   15403.524812                28241.967210
# 25    222.360000     41.041148    9125.909702                48406.991208
# 29    222.360000     41.354163    9195.511573                48812.372432
# 33    222.360000     41.827000    9300.651720                28241.967210
# 27    188.295238     18.149590    3417.481401                48406.991208
# 31    195.600000     18.102083    3540.767500                48812.372432
# 35    195.600000     18.086864    3537.790678                28241.967210
