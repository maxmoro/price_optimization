# %% [markdown]
# # Init

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
print("CURRENT FOLDER:")
# %pwd
# Out:
# CURRENT FOLDER:
# 'c:\\max\\Google Drive Max\\Max Shared\\Master Data Science\\2020-05 Capstone A\\msds_capstone\\analysis\\fullRuns'

# %%
import os
import glob
import sys
sys.path.append(os.environ['DEV_AUTOTS'])
sys.path.append(os.environ['CAPSTONE_PYTHON_SOURCE'])
folder = os.environ['CAPSTONE_DATA']

# %%
## Sourcing the .py with all the code##
t='"'+os.environ['CAPSTONE_PYTHON_SOURCE']+'\\fullRun\\fullRun.py'+'"'
# %run -i $t
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Parameters

# %%
#Parameters

ProdCats = ['SUP PREM WHISKEY']
TOP_PRODUCTS = 4  # How many products to consider in the category
TOP_SIMILAR = 3   # Get TOP_SIMILAR most similar products
RUN_PERIODS = [1,2,3] # this will run AutoTS and Optimzer for speicfic periods (1 = last, 2 = second to last)

CV_NUM = 10         # number of Cross Valudations  10
OPT_CALLS = 100     # number of calls for the optimizer process   100
OPT_RND_STARTS = 20 # number of random calls for the optimizer process  20

LOG_TRANSFORM = True # Take log of 9L cases to smooth out peaks and valleys
ZERO_ADDER = 0.1 

RESAMPLE_FREQ = 'M'


# Pricing changes every 4 weeks
if RESAMPLE_FREQ == 'M':    FORECAST_PERIOD = 1 #last 4 months as test 
if RESAMPLE_FREQ == 'W':    FORECAST_PERIOD = 4 
if RESAMPLE_FREQ == '2W':   FORECAST_PERIOD = 2 

# Seasonal Period
if RESAMPLE_FREQ == 'M':    SEASONAL_PERIOD = 12  # Yearly
if RESAMPLE_FREQ == 'W':    SEASONAL_PERIOD = 13 # Quarterly (we can also take yearly = 52, but SARIMAX becomes too slow)
if RESAMPLE_FREQ == '2W':   SEASONAL_PERIOD = 13 # This becomes problematic --> for quarterly, should we take 6 biweekly periods or 7 bi-weekly periods. Instead I just took half yearly period  

COL_TIME = 'WeekDate'
COL_PREDS = ['9L Cases'] #Demand
COL_PRICE= ['Dollar Sales per 9L Case'] #Price

# %% [markdown]
# # Full Run

# %%
dataRaw = loadDataset(version=4)
ProdCat = 'SUP PREM WHISKEY' #'ECONOMY VODKA'
ChainMasters =  [''] +  dataRaw['Chain Master'].unique().tolist() 
display(ChainMasters,ProdCats)
# Out:
# ['', 'THE BARREL HOUSE', 'WESTERN BEV LIQ TX', 'SPECS']
# ['SUP PREM WHISKEY']

# %%
(full_models,full_opt,full_summary,full_chain_summary)  = fullRun(ProdCat = ProdCat
                                                           ,ChainMasters = ChainMasters
                                                           ,dataRaw = dataRaw
                                                           ,savePKL=True
                                                           ,saveXLS=True)
# Out:
# ==================================================
# Parameters being used...
# ==================================================
# TOP_PRODUCTS = 4
# TOP_SIMILAR = 3
# RUN_PERIODS = [1, 2, 3]
# ProdCat: SUP PREM WHISKEY
# ChainMasters: ['', 'THE BARREL HOUSE', 'WESTERN BEV LIQ TX', 'SPECS']
#
#
# ========================== (2020-09-01 08:06:38.370712)
# ===== Products List  =====
# ==== SUP PREM WHISKEY ====
# ============  ============
# ==========================
#
#
#
# ========================== (2020-09-01 08:06:41.979712)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 1 ============
# ==========================
#
#
#
# ================== (2020-09-01 08:06:41.980713)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS BLK WHSKY SQ 375M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2', '3']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '3']
# % of weeks without a purchase: 1.1904761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1', '3']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY SQ 375M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2', '1']
# % of weeks without a purchase: 44.047619047619044
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY SQ 375M
#
#
# ===================== (2020-09-01 08:07:11.312279)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#       lb_stat  lb_pvalue
# 12  17.529696   0.130735
# 24  31.092108   0.151145
# 48  54.922995   0.228882
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12  115.750529  4.333814e-19
# 24  214.169023  1.845834e-32
# 48  308.098428  1.176533e-39
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   76.707883  1.745018e-11
# 24  131.122583  9.711501e-17
# 48  214.957410  5.416649e-23
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  236.849902  7.504140e-44
# 24  313.152234  3.733315e-52
# 48  457.992618  2.867236e-68
#
# Is Data White Noise: False
#
#
# ==================== (2020-09-01 08:07:11.326281)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (83, 6) (1, 6)
# (83, 6) (1, 6)
# (83, 6) (1, 6)
# (83, 6) (1, 6)
#
#
# =============== (2020-09-01 08:07:11.331282)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.043169         []
# 1  1      last   0.324455         []
# 2  2      mean   0.427990         []
# 3  3      mean   0.798321         []
#
#                                            All RMSEs  \
# 0  [[0.07143315389555474, 0.11332894033533458, 0....
# 1  [[0.3244545696539494, 0.4963154566538675, 0.34...
# 2  [[0.6704496090247218, 0.719929333484661, 0.427...
# 3  [[1.158356517777329, 1.1898741527817909, 0.798...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-01 08:07:11.575278)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  6.1min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  6.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-01 08:13:19.443861)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  6.0min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  6.0min finished
# =================== (2020-09-01 08:19:22.390435)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-01 08:19:22.395433)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 1 ============
# ==========================
#
#
#
# =========================== (2020-09-01 08:19:22.395433)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ============  =============
# ============ 1 ============
# ===========================
#
#
#
# ================== (2020-09-01 08:19:22.399433)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS BLK WHSKY SQ 375M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2', '3']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '3']
# % of weeks without a purchase: 1.1904761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1', '3']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY SQ 375M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2', '1']
# % of weeks without a purchase: 44.047619047619044
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY SQ 375M
#
#
# ==================== (2020-09-01 08:20:12.105552)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (83, 6) (1, 6)
# (83, 6) (1, 6)
# (83, 6) (1, 6)
# (83, 6) (1, 6)
#
#
# ======================== (2020-09-01 08:20:12.112552)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-01 08:20:12.127582)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False, False]
#
#
# =============== (2020-09-01 08:20:12.129550)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-01 08:20:12.136582)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-01 08:20:12.137549)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-01 08:20:12.137549)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-01 08:20:12.242550)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-01 08:20:12.249553)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-01 08:21:09.802076)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-01 08:21:09.888076)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-01 08:21:09.889077)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-01 08:21:09.981078)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-01 08:21:09.989079)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-01 08:22:02.746106)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-01 08:22:02.838076)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-01 08:22:02.843077)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 2 ============
# ==========================
#
#
#
# ================== (2020-09-01 08:22:02.843077)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS BLK WHSKY SQ 375M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2', '3']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '3']
# % of weeks without a purchase: 1.2048192771084338
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1', '3']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY SQ 375M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2', '1']
# % of weeks without a purchase: 44.57831325301205
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY SQ 375M
#
#
# ===================== (2020-09-01 08:22:39.995079)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#       lb_stat  lb_pvalue
# 12  17.074759   0.146807
# 24  30.689164   0.162949
# 48  53.509495   0.271059
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12  113.741522  1.085921e-18
# 24  210.737801  8.608130e-32
# 48  298.546482  6.801454e-38
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   73.433730  7.257343e-11
# 24  127.792143  3.888372e-16
# 48  208.580703  6.624266e-22
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  233.654157  3.467423e-43
# 24  301.956845  6.767463e-50
# 48  453.324573  2.340339e-67
#
# Is Data White Noise: False
#
#
# ==================== (2020-09-01 08:22:40.018079)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (82, 6) (1, 6)
# (82, 6) (1, 6)
# (82, 6) (1, 6)
# (82, 6) (1, 6)
#
#
# =============== (2020-09-01 08:22:40.021077)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.021557         []
# 1  1      mean   0.323943         []
# 2  2      mean   0.373199         []
# 3  3      mean   0.669609         []
#
#                                            All RMSEs  \
# 0  [[0.057546587491533165, 0.09126460007014617, 0...
# 1  [[0.3342880201030623, 0.4694144778845947, 0.32...
# 2  [[0.6160411345584191, 0.6054018321634664, 0.37...
# 3  [[1.1334719691929973, 1.0359040362506735, 0.66...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-01 08:22:40.420078)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  4.9min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  4.9min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-01 08:27:34.750166)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  5.4min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  5.4min finished
# =================== (2020-09-01 08:32:58.527014)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-01 08:32:58.534010)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 2 ============
# ==========================
#
#
#
# =========================== (2020-09-01 08:32:58.535009)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ============  =============
# ============ 2 ============
# ===========================
#
#
#
# ================== (2020-09-01 08:32:58.537008)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS BLK WHSKY SQ 375M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2', '3']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '3']
# % of weeks without a purchase: 1.2048192771084338
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1', '3']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY SQ 375M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2', '1']
# % of weeks without a purchase: 44.57831325301205
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY SQ 375M
#
#
# ==================== (2020-09-01 08:33:38.041010)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (82, 6) (1, 6)
# (82, 6) (1, 6)
# (82, 6) (1, 6)
# (82, 6) (1, 6)
#
#
# ======================== (2020-09-01 08:33:38.050011)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-01 08:33:38.070009)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False, False]
#
#
# =============== (2020-09-01 08:33:38.072011)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-01 08:33:38.080011)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-01 08:33:38.082011)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-01 08:33:38.083010)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-01 08:33:38.194011)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-01 08:33:38.199008)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-01 08:34:36.575942)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-01 08:34:36.686943)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-01 08:34:36.687943)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-01 08:34:36.796941)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-01 08:34:36.800941)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-01 08:35:28.707186)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-01 08:35:28.833187)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-01 08:35:28.842185)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 3 ============
# ==========================
#
#
#
# ================== (2020-09-01 08:35:28.842185)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS BLK WHSKY SQ 375M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2', '3']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '3']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1', '3']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY SQ 375M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2', '1']
# % of weeks without a purchase: 45.1219512195122
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY SQ 375M
#
#
# ===================== (2020-09-01 08:36:05.345185)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#       lb_stat  lb_pvalue
# 12  16.492825   0.169692
# 24  29.613691   0.197887
# 48  52.235849   0.312831
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12  111.729571  2.720557e-18
# 24  207.460783  3.736074e-31
# 48  291.621010  1.270149e-36
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   72.023277  1.337193e-10
# 24  126.557635  6.490946e-16
# 48  206.128607  1.725436e-21
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  227.003218  8.357786e-42
# 24  289.400873  2.267177e-47
# 48  442.433742  3.108030e-65
#
# Is Data White Noise: False
#
#
# ==================== (2020-09-01 08:36:05.370184)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (81, 6) (1, 6)
# (81, 6) (1, 6)
# (81, 6) (1, 6)
# (81, 6) (1, 6)
#
#
# =============== (2020-09-01 08:36:05.377186)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.033917         []
# 1  1      mean   0.319180         []
# 2  2      mean   0.373056         []
# 3  3      mean   0.627867         []
#
#                                            All RMSEs  \
# 0  [[0.0872048496772559, 0.1165490736094128, 0.03...
# 1  [[0.35617856342347604, 0.5500854364755055, 0.3...
# 2  [[0.556716035671863, 0.5707857245806156, 0.373...
# 3  [[1.0772290858881073, 1.0184226921157236, 0.62...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-01 08:36:05.753738)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  4.3min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  4.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-01 08:40:22.836422)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  5.8min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  5.8min finished
# =================== (2020-09-01 08:46:11.002120)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-01 08:46:11.014120)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 3 ============
# ==========================
#
#
#
# =========================== (2020-09-01 08:46:11.015121)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ============  =============
# ============ 3 ============
# ===========================
#
#
#
# ================== (2020-09-01 08:46:11.018120)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS BLK WHSKY SQ 375M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2', '3']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '3']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1', '3']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY SQ 375M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2', '1']
# % of weeks without a purchase: 45.1219512195122
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY SQ 375M
#
#
# ==================== (2020-09-01 08:46:53.445927)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (81, 6) (1, 6)
# (81, 6) (1, 6)
# (81, 6) (1, 6)
# (81, 6) (1, 6)
#
#
# ======================== (2020-09-01 08:46:53.452928)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-01 08:46:53.467932)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False, False]
#
#
# =============== (2020-09-01 08:46:53.469928)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-01 08:46:53.474928)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-01 08:46:53.475928)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-01 08:46:53.476929)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-01 08:46:53.544927)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-01 08:46:53.549927)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-01 08:47:47.514026)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-01 08:47:47.668026)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-01 08:47:47.669026)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-01 08:47:47.820028)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-01 08:47:47.827028)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-01 08:48:45.924252)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-01 08:48:46.005252)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-01 08:48:46.012252)
# ===== Products List  =====
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 08:48:46.729677)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 1 ============
# ==========================
#
#
#
# ========================== (2020-09-01 08:48:46.729677)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'GENTLEMAN JACK WHSKY OL 750M', '2': 'JACK DANIELS TENN HNY WHSKY  1L', '3': 'GENTLEMAN JACK WHSKY 6PK 1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '2', '1']
# % of weeks without a purchase: 45.23809523809524
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3', '0', '2']
# % of weeks without a purchase: 52.38095238095239
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '3', '1']
# % of weeks without a purchase: 48.80952380952381
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY 6PK 1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '1', '0', '2']
# % of weeks without a purchase: 32.926829268292686
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY 6PK 1L
#
#
# ========================== (2020-09-01 08:49:14.807168)
# ====== WHITE NOISE =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#        lb_stat  lb_pvalue
# 12   24.932218   0.015147
# 24   47.266936   0.003107
# 48  103.010327   0.000007
#
# Is Data White Noise: False
#        lb_stat  lb_pvalue
# 12   24.646813   0.016588
# 24   50.653838   0.001168
# 48  108.922594   0.000001
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  11.113828   0.519190
# 24  30.880617   0.157255
# 48  53.855113   0.260331
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12   8.641692   0.733192
# 24  19.315056   0.734985
# 48  47.523727   0.492264
#
# Is Data White Noise: True
#
#
# ========================== (2020-09-01 08:49:14.818169)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (83, 6) (1, 6)
# (83, 6) (1, 6)
# (83, 6) (1, 6)
# (81, 6) (1, 6)
#
#
# ========================== (2020-09-01 08:49:14.820169)
# ========= NAIVE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#   ID      Best Type  Best RMSE All Naives  \
# 0  0           mean   1.149908         []
# 1  1           last   0.508452         []
# 2  2  seasonal_last   0.539165         []
# 3  3           mean   0.611153         []
#
#                                            All RMSEs  \
# 0  [[1.3378491195367055, 1.5550765479093094, 1.14...
# 1  [[0.5084521358062825, 1.227326606712806, 0.861...
# 2  [[0.8388226345645782, 0.5391649362857315, 0.68...
# 3  [[0.7042605406907361, 0.7703384907350979, 0.61...
#
#                        All Types  \
# 0  [[last, seasonal_last, mean]]
# 1  [[last, seasonal_last, mean]]
# 2  [[last, seasonal_last, mean]]
# 3  [[last, seasonal_last, mean]]
#
#                                         Best Naive
# 0           NaiveForecaster(sp=4, strategy='mean')
# 1                            NaiveForecaster(sp=4)
# 2  NaiveForecaster(sp=4, strategy='seasonal_last')
# 3           NaiveForecaster(sp=4, strategy='mean')
#
#
# ========================== (2020-09-01 08:49:15.063172)
# ====== Multivar P0 =======
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  4.2min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  4.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================== (2020-09-01 08:53:30.151422)
# ==== Multivar P0+Sim =====
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  5.8min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  5.8min finished
# ========================== (2020-09-01 08:59:16.538664)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 08:59:16.546665)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 1 ============
# ==========================
#
#
#
# =========================== (2020-09-01 08:59:16.546665)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ==== THE BARREL HOUSE =====
# ============ 1 ============
# ===========================
#
#
#
# ========================== (2020-09-01 08:59:16.549664)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'GENTLEMAN JACK WHSKY OL 750M', '2': 'JACK DANIELS TENN HNY WHSKY  1L', '3': 'GENTLEMAN JACK WHSKY 6PK 1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '2', '1']
# % of weeks without a purchase: 45.23809523809524
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3', '0', '2']
# % of weeks without a purchase: 52.38095238095239
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '3', '1']
# % of weeks without a purchase: 48.80952380952381
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY 6PK 1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '1', '0', '2']
# % of weeks without a purchase: 32.926829268292686
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY 6PK 1L
#
#
# ========================== (2020-09-01 08:59:59.774668)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (83, 6) (1, 6)
# (83, 6) (1, 6)
# (83, 6) (1, 6)
# (81, 6) (1, 6)
#
#
# ========================== (2020-09-01 08:59:59.782662)
# ===== NAIVE FORECAST =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 08:59:59.798662)
# ========== MASK ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
# Mask: [False, False, False, False]
#
#
# ========================== (2020-09-01 08:59:59.801662)
# ========= SPACE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 08:59:59.810663)
# ======= Test Index =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 08:59:59.811664)
# ==== GET FUNCTION P0 =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ====================================== (2020-09-01 08:59:59.812664)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ========== THE BARREL HOUSE ==========
# ======================================
#
#
#
# ========================== (2020-09-01 08:59:59.985697)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 08:59:59.991697)
# ===== OPTIMIZING P0 ======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 09:01:02.969768)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ============================= (2020-09-01 09:01:03.136773)
# ==== GET FUNCTION P0+Sim ====
# ===== THE BARREL HOUSE ======
# =============================
#
#
#
# ========================================== (2020-09-01 09:01:03.137768)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ============ THE BARREL HOUSE ============
# ==========================================
#
#
#
# ========================== (2020-09-01 09:01:03.283800)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# =========================== (2020-09-01 09:01:03.289799)
# ==== OPTIMIZING P0+Sim ====
# ==== THE BARREL HOUSE =====
# ===========================
#
#
#
# ========================== (2020-09-01 09:01:55.790627)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 09:01:55.922628)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 09:01:55.929627)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 2 ============
# ==========================
#
#
#
# ========================== (2020-09-01 09:01:55.929627)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'GENTLEMAN JACK WHSKY OL 750M', '2': 'JACK DANIELS TENN HNY WHSKY  1L', '3': 'GENTLEMAN JACK WHSKY 6PK 1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '2', '1']
# % of weeks without a purchase: 45.78313253012048
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3', '0', '2']
# % of weeks without a purchase: 53.01204819277109
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '3', '1']
# % of weeks without a purchase: 49.39759036144578
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY 6PK 1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '1', '0', '2']
# % of weeks without a purchase: 33.33333333333333
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY 6PK 1L
#
#
# ========================== (2020-09-01 09:02:25.362627)
# ====== WHITE NOISE =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#       lb_stat  lb_pvalue
# 12  23.922535   0.020840
# 24  45.414544   0.005201
# 48  99.152623   0.000020
#
# Is Data White Noise: False
#        lb_stat  lb_pvalue
# 12   25.814484   0.011401
# 24   50.372270   0.001269
# 48  100.845296   0.000013
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  10.794767   0.546584
# 24  29.686533   0.195359
# 48  53.100408   0.284097
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12   8.057662   0.780608
# 24  17.817943   0.811750
# 48  41.544821   0.733036
#
# Is Data White Noise: True
#
#
# ========================== (2020-09-01 09:02:25.374630)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (82, 6) (1, 6)
# (82, 6) (1, 6)
# (82, 6) (1, 6)
# (80, 6) (1, 6)
#
#
# ========================== (2020-09-01 09:02:25.378630)
# ========= NAIVE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#   ID      Best Type  Best RMSE All Naives  \
# 0  0           last   1.279671         []
# 1  1           last   0.397118         []
# 2  2  seasonal_last   0.583337         []
# 3  3           mean   0.532525         []
#
#                                            All RMSEs  \
# 0  [[1.2796706251393728, 1.655747949478816, 1.324...
# 1  [[0.3971180356035492, 1.0727385943033805, 0.73...
# 2  [[0.9401093055023353, 0.5833369983034572, 0.76...
# 3  [[0.5741726496470821, 0.6294921160859183, 0.53...
#
#                        All Types  \
# 0  [[last, seasonal_last, mean]]
# 1  [[last, seasonal_last, mean]]
# 2  [[last, seasonal_last, mean]]
# 3  [[last, seasonal_last, mean]]
#
#                                         Best Naive
# 0                            NaiveForecaster(sp=4)
# 1                            NaiveForecaster(sp=4)
# 2  NaiveForecaster(sp=4, strategy='seasonal_last')
# 3           NaiveForecaster(sp=4, strategy='mean')
#
#
# ========================== (2020-09-01 09:02:25.660633)
# ====== Multivar P0 =======
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  4.0min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  4.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================== (2020-09-01 09:06:22.827900)
# ==== Multivar P0+Sim =====
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  5.1min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  5.1min finished
# ========================== (2020-09-01 09:11:29.193563)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 09:11:29.198562)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 2 ============
# ==========================
#
#
#
# =========================== (2020-09-01 09:11:29.198562)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ==== THE BARREL HOUSE =====
# ============ 2 ============
# ===========================
#
#
#
# ========================== (2020-09-01 09:11:29.200562)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'GENTLEMAN JACK WHSKY OL 750M', '2': 'JACK DANIELS TENN HNY WHSKY  1L', '3': 'GENTLEMAN JACK WHSKY 6PK 1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '2', '1']
# % of weeks without a purchase: 45.78313253012048
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3', '0', '2']
# % of weeks without a purchase: 53.01204819277109
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '3', '1']
# % of weeks without a purchase: 49.39759036144578
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY 6PK 1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '1', '0', '2']
# % of weeks without a purchase: 33.33333333333333
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY 6PK 1L
#
#
# ========================== (2020-09-01 09:12:09.363922)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (82, 6) (1, 6)
# (82, 6) (1, 6)
# (82, 6) (1, 6)
# (80, 6) (1, 6)
#
#
# ========================== (2020-09-01 09:12:09.369927)
# ===== NAIVE FORECAST =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 09:12:09.383924)
# ========== MASK ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
# Mask: [False, False, False, False]
#
#
# ========================== (2020-09-01 09:12:09.386924)
# ========= SPACE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 09:12:09.395921)
# ======= Test Index =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 09:12:09.396922)
# ==== GET FUNCTION P0 =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ====================================== (2020-09-01 09:12:09.396922)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ========== THE BARREL HOUSE ==========
# ======================================
#
#
#
# ========================== (2020-09-01 09:12:09.549924)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 09:12:09.556924)
# ===== OPTIMIZING P0 ======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 09:13:05.818925)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ============================= (2020-09-01 09:13:05.986925)
# ==== GET FUNCTION P0+Sim ====
# ===== THE BARREL HOUSE ======
# =============================
#
#
#
# ========================================== (2020-09-01 09:13:05.987926)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ============ THE BARREL HOUSE ============
# ==========================================
#
#
#
# ========================== (2020-09-01 09:13:06.144925)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# =========================== (2020-09-01 09:13:06.150925)
# ==== OPTIMIZING P0+Sim ====
# ==== THE BARREL HOUSE =====
# ===========================
#
#
#
# ========================== (2020-09-01 09:14:01.659676)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 09:14:01.800674)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 09:14:01.808674)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 3 ============
# ==========================
#
#
#
# ========================== (2020-09-01 09:14:01.808674)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'GENTLEMAN JACK WHSKY OL 750M', '2': 'JACK DANIELS TENN HNY WHSKY  1L', '3': 'GENTLEMAN JACK WHSKY 6PK 1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '2', '1']
# % of weeks without a purchase: 46.34146341463415
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3', '0', '2']
# % of weeks without a purchase: 52.4390243902439
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '3', '1']
# % of weeks without a purchase: 48.78048780487805
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY 6PK 1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '1', '0', '2']
# % of weeks without a purchase: 33.75
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY 6PK 1L
#
#
# ========================== (2020-09-01 09:14:38.985577)
# ====== WHITE NOISE =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#       lb_stat  lb_pvalue
# 12  22.966606   0.028011
# 24  43.950059   0.007733
# 48  96.983960   0.000037
#
# Is Data White Noise: False
#        lb_stat  lb_pvalue
# 12   27.402860   0.006758
# 24   51.649912   0.000869
# 48  103.761135   0.000006
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  10.052476   0.611357
# 24  29.222626   0.211865
# 48  50.699491   0.367565
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12   7.723903   0.806317
# 24  17.026775   0.847518
# 48  40.563386   0.768264
#
# Is Data White Noise: True
#
#
# ========================== (2020-09-01 09:14:39.004576)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (81, 6) (1, 6)
# (81, 6) (1, 6)
# (81, 6) (1, 6)
# (79, 6) (1, 6)
#
#
# ========================== (2020-09-01 09:14:39.008573)
# ========= NAIVE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#   ID      Best Type  Best RMSE All Naives  \
# 0  0           last   1.309084         []
# 1  1           last   0.575651         []
# 2  2  seasonal_last   0.456328         []
# 3  3           last   0.514092         []
#
#                                            All RMSEs  \
# 0  [[1.3090836993967807, 1.5116570412722945, 1.34...
# 1  [[0.5756510191046259, 0.8723064569251162, 0.77...
# 2  [[0.9401093055023353, 0.4563275126911478, 0.73...
# 3  [[0.5140918075121166, 0.680195528305364, 0.545...
#
#                        All Types  \
# 0  [[last, seasonal_last, mean]]
# 1  [[last, seasonal_last, mean]]
# 2  [[last, seasonal_last, mean]]
# 3  [[last, seasonal_last, mean]]
#
#                                         Best Naive
# 0                            NaiveForecaster(sp=4)
# 1                            NaiveForecaster(sp=4)
# 2  NaiveForecaster(sp=4, strategy='seasonal_last')
# 3                            NaiveForecaster(sp=4)
#
#
# ========================== (2020-09-01 09:14:39.279576)
# ====== Multivar P0 =======
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  3.8min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  3.8min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================== (2020-09-01 09:18:27.486123)
# ==== Multivar P0+Sim =====
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  4.7min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  4.7min finished
# ========================== (2020-09-01 09:23:10.825844)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 09:23:10.830845)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 3 ============
# ==========================
#
#
#
# =========================== (2020-09-01 09:23:10.831846)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ==== THE BARREL HOUSE =====
# ============ 3 ============
# ===========================
#
#
#
# ========================== (2020-09-01 09:23:10.833851)
# ...
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1', '2']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
#
#
# ===================== (2020-09-01 10:20:39.441579)
# ==== WHITE NOISE ====
# ======= SPECS =======
# =====================
#
#       lb_stat  lb_pvalue
# 12  15.010561   0.240859
# 24  26.255626   0.340323
# 48  46.813983   0.521457
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12  28.602170   0.004512
# 24  40.565661   0.018579
# 48  53.111411   0.283742
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12  26.462991   0.009225
# 24  37.259357   0.041220
# 48  54.606396   0.237935
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12   6.590230   0.883464
# 24  11.084958   0.988393
# 48  32.593075   0.956498
#
# Is Data White Noise: True
#
#
# ==================== (2020-09-01 10:20:39.457580)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (82, 6) (1, 6)
# (82, 6) (1, 6)
# (82, 6) (1, 6)
# (82, 6) (1, 6)
#
#
# =============== (2020-09-01 10:20:39.464579)
# ==== NAIVE ====
# ==== SPECS ====
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.033192         []
# 1  1      mean   0.118510         []
# 2  2      mean   0.224583         []
# 3  3      mean   0.067342         []
#
#                                            All RMSEs  \
# 0  [[0.0935827577097994, 0.10896925774528339, 0.0...
# 1  [[0.17264955504702825, 0.17422646327023725, 0....
# 2  [[0.4363032505606732, 0.3550157822095886, 0.22...
# 3  [[0.09595064453644367, 0.12091221353553756, 0....
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-01 10:20:39.843581)
# ==== Multivar P0 ====
# ======= SPECS =======
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  4.5min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  4.5min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-01 10:25:09.518481)
# ==== Multivar P0+Sim ====
# ========= SPECS =========
# =========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  3.4min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  3.4min finished
# =================== (2020-09-01 10:28:31.717002)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ========================== (2020-09-01 10:28:31.726000)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ========= SPECS ==========
# =========== 2 ============
# ==========================
#
#
#
# =========================== (2020-09-01 10:28:31.727001)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ========== SPECS ==========
# ============ 2 ============
# ===========================
#
#
#
# ================== (2020-09-01 10:28:31.730002)
# ==== GET DATA ====
# ===== SPECS ======
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS TENN HNY WHSKY  1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '1', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '3']
# % of weeks without a purchase: 8.433734939759036
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1', '3']
# % of weeks without a purchase: 2.4096385542168677
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1', '2']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
#
#
# ==================== (2020-09-01 10:29:05.136404)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (82, 6) (1, 6)
# (82, 6) (1, 6)
# (82, 6) (1, 6)
# (82, 6) (1, 6)
#
#
# ======================== (2020-09-01 10:29:05.142406)
# ==== NAIVE FORECAST ====
# ======== SPECS =========
# ========================
#
#
#
# =============== (2020-09-01 10:29:05.161408)
# ==== MASK =====
# ==== SPECS ====
# ===============
#
# Mask: [False, False, False, False]
#
#
# =============== (2020-09-01 10:29:05.163407)
# ==== SPACE ====
# ==== SPECS ====
# ===============
#
#
#
# ==================== (2020-09-01 10:29:05.175406)
# ==== Test Index ====
# ====== SPECS =======
# ====================
#
#
#
# ========================= (2020-09-01 10:29:05.176408)
# ==== GET FUNCTION P0 ====
# ========= SPECS =========
# =========================
#
#
#
# ====================================== (2020-09-01 10:29:05.177405)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# =============== SPECS ================
# ======================================
#
#
#
# =================== (2020-09-01 10:29:05.285404)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ======================= (2020-09-01 10:29:05.290404)
# ==== OPTIMIZING P0 ====
# ======== SPECS ========
# =======================
#
#
#
# =================== (2020-09-01 10:29:57.140937)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ============================= (2020-09-01 10:29:57.259447)
# ==== GET FUNCTION P0+Sim ====
# =========== SPECS ===========
# =============================
#
#
#
# ========================================== (2020-09-01 10:29:57.260447)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ================= SPECS ==================
# ==========================================
#
#
#
# =================== (2020-09-01 10:29:57.352957)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =========================== (2020-09-01 10:29:57.357957)
# ==== OPTIMIZING P0+Sim ====
# ========== SPECS ==========
# ===========================
#
#
#
# =================== (2020-09-01 10:31:06.044369)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =================== (2020-09-01 10:31:06.189367)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ========================== (2020-09-01 10:31:06.197369)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ========= SPECS ==========
# =========== 3 ============
# ==========================
#
#
#
# ================== (2020-09-01 10:31:06.198369)
# ==== GET DATA ====
# ===== SPECS ======
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS TENN HNY WHSKY  1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '1', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '3']
# % of weeks without a purchase: 8.536585365853659
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1', '3']
# % of weeks without a purchase: 2.4390243902439024
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1', '2']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
#
#
# ===================== (2020-09-01 10:31:36.295581)
# ==== WHITE NOISE ====
# ======= SPECS =======
# =====================
#
#       lb_stat  lb_pvalue
# 12  14.591506   0.264539
# 24  25.708961   0.368096
# 48  45.847359   0.561475
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12  28.056071   0.005429
# 24  39.797909   0.022480
# 48  52.199800   0.314062
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12  26.241054   0.009922
# 24  37.090548   0.042858
# 48  54.361071   0.245108
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12   6.530656   0.887010
# 24  11.020075   0.988868
# 48  32.169399   0.961455
#
# Is Data White Noise: True
#
#
# ==================== (2020-09-01 10:31:36.305607)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (81, 6) (1, 6)
# (81, 6) (1, 6)
# (81, 6) (1, 6)
# (81, 6) (1, 6)
#
#
# =============== (2020-09-01 10:31:36.307607)
# ==== NAIVE ====
# ==== SPECS ====
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.051513         []
# 1  1      mean   0.109428         []
# 2  2      mean   0.221377         []
# 3  3      mean   0.086918         []
#
#                                            All RMSEs  \
# 0  [[0.12459174747365168, 0.13927072207458754, 0....
# 1  [[0.18390429323643792, 0.17762873456667566, 0....
# 2  [[0.4245652552570759, 0.3288519908859398, 0.22...
# 3  [[0.08808657027865822, 0.126322489261891, 0.08...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-01 10:31:36.559607)
# ==== Multivar P0 ====
# ======= SPECS =======
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  4.3min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  4.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-01 10:35:55.327672)
# ==== Multivar P0+Sim ====
# ========= SPECS =========
# =========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  4.9min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  4.9min finished
# =================== (2020-09-01 10:40:47.415257)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ========================== (2020-09-01 10:40:47.427258)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ========= SPECS ==========
# =========== 3 ============
# ==========================
#
#
#
# =========================== (2020-09-01 10:40:47.428259)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ========== SPECS ==========
# ============ 3 ============
# ===========================
#
#
#
# ================== (2020-09-01 10:40:47.431258)
# ==== GET DATA ====
# ===== SPECS ======
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS TENN HNY WHSKY  1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '1', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '3']
# % of weeks without a purchase: 8.536585365853659
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1', '3']
# % of weeks without a purchase: 2.4390243902439024
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1', '2']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
#
#
# ==================== (2020-09-01 10:41:27.380877)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (81, 6) (1, 6)
# (81, 6) (1, 6)
# (81, 6) (1, 6)
# (81, 6) (1, 6)
#
#
# ======================== (2020-09-01 10:41:27.384877)
# ==== NAIVE FORECAST ====
# ======== SPECS =========
# ========================
#
#
#
# =============== (2020-09-01 10:41:27.396905)
# ==== MASK =====
# ==== SPECS ====
# ===============
#
# Mask: [False, False, False, False]
#
#
# =============== (2020-09-01 10:41:27.397905)
# ==== SPACE ====
# ==== SPECS ====
# ===============
#
#
#
# ==================== (2020-09-01 10:41:27.402876)
# ==== Test Index ====
# ====== SPECS =======
# ====================
#
#
#
# ========================= (2020-09-01 10:41:27.403905)
# ==== GET FUNCTION P0 ====
# ========= SPECS =========
# =========================
#
#
#
# ====================================== (2020-09-01 10:41:27.403905)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# =============== SPECS ================
# ======================================
#
#
#
# =================== (2020-09-01 10:41:27.518875)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ======================= (2020-09-01 10:41:27.523874)
# ==== OPTIMIZING P0 ====
# ======== SPECS ========
# =======================
#
#
#
# =================== (2020-09-01 10:42:21.741207)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ============================= (2020-09-01 10:42:21.883211)
# ==== GET FUNCTION P0+Sim ====
# =========== SPECS ===========
# =============================
#
#
#
# ========================================== (2020-09-01 10:42:21.884210)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ================= SPECS ==================
# ==========================================
#
#
#
# =================== (2020-09-01 10:42:22.021209)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =========================== (2020-09-01 10:42:22.026209)
# ==== OPTIMIZING P0+Sim ====
# ========== SPECS ==========
# ===========================
#
#
#
# =================== (2020-09-01 10:43:19.382455)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =================== (2020-09-01 10:43:19.513455)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ========================== (2020-09-01 10:43:19.526454)
# ==== Saving to PICKLE ====
# ==== SUP PREM WHISKEY ====
# ==========================
#
# Pickle File  full_models_SUP PREM WHISKEY_Prod4_Sim3_Per123.pkl  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns
# Pickle File  full_opt_SUP PREM WHISKEY_Prod4_Sim3_Per123.pkl  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns
#
#
# ========================== (2020-09-01 10:43:19.785457)
# ==== Saving to EXCEL =====
# ==== SUP PREM WHISKEY ====
# ==========================
#
# EXCEL File  Output_SUP PREM WHISKEY_Prod4_Sim3_Per123.xlsx  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns

# %% [markdown]
# # Print out

# %% [markdown]
# ## Models

# %%
full_models[outputColsModels]
# Out:
#           Chain Master                          Product  Period to Last  \
# 1                         JACK DANIELS BLK WHSKY  1.75L               1
# 5                         JACK DANIELS BLK WHSKY  1.75L               2
# 9                         JACK DANIELS BLK WHSKY  1.75L               3
# 0                            JACK DANIELS BLK WHSKY  1L               1
# 4                            JACK DANIELS BLK WHSKY  1L               2
# 8                            JACK DANIELS BLK WHSKY  1L               3
# 2                          JACK DANIELS BLK WHSKY  750M               1
# 6                          JACK DANIELS BLK WHSKY  750M               2
# 10                         JACK DANIELS BLK WHSKY  750M               3
# 3                        JACK DANIELS BLK WHSKY SQ 375M               1
# 7                        JACK DANIELS BLK WHSKY SQ 375M               2
# 11                       JACK DANIELS BLK WHSKY SQ 375M               3
# 37               SPECS    JACK DANIELS BLK WHSKY  1.75L               1
# 41               SPECS    JACK DANIELS BLK WHSKY  1.75L               2
# 45               SPECS    JACK DANIELS BLK WHSKY  1.75L               3
# 36               SPECS       JACK DANIELS BLK WHSKY  1L               1
# 40               SPECS       JACK DANIELS BLK WHSKY  1L               2
# 44               SPECS       JACK DANIELS BLK WHSKY  1L               3
# 38               SPECS     JACK DANIELS BLK WHSKY  750M               1
# 42               SPECS     JACK DANIELS BLK WHSKY  750M               2
# 46               SPECS     JACK DANIELS BLK WHSKY  750M               3
# 39               SPECS  JACK DANIELS TENN HNY WHSKY  1L               1
# 43               SPECS  JACK DANIELS TENN HNY WHSKY  1L               2
# 47               SPECS  JACK DANIELS TENN HNY WHSKY  1L               3
# 15    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               1
# 19    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               2
# 23    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               3
# 13    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               1
# 17    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               2
# 21    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               3
# 12    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               1
# 16    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               2
# 20    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               3
# 14    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               1
# 18    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               2
# 22    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               3
# 24  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               1
# 28  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               2
# 32  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               3
# 26  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               1
# 30  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               2
# 34  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               3
# 25  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               1
# 29  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               2
# 33  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               3
# 27  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               1
# 31  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               2
# 35  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               3
#
#     White Noise Naive Best Type  Naive Best RMSE P0 Best Model Name  \
# 1         False            last         0.324455       auto_SARIMAX
# 5         False            mean         0.323943       auto_SARIMAX
# 9         False            mean         0.319180       auto_SARIMAX
# 0          True            mean         0.043169            SARIMAX
# 4          True            mean         0.021557                 ML
# 8          True            mean         0.033917                 ML
# 2         False            mean         0.427990            SARIMAX
# 6         False            mean         0.373199            SARIMAX
# 10        False            mean         0.373056            SARIMAX
# 3         False            mean         0.798321                 ML
# 7         False            mean         0.669609                 ML
# 11        False            mean         0.627867       auto_SARIMAX
# 37         True            mean         0.159196            SARIMAX
# 41         True            mean         0.118510            SARIMAX
# 45         True            mean         0.109428            SARIMAX
# 36         True            mean         0.060885            SARIMAX
# 40         True            mean         0.033192                 ML
# 44         True            mean         0.051513                 ML
# 38         True            mean         0.276661       auto_SARIMAX
# 42         True            mean         0.224583                 ML
# 46         True            mean         0.221377                 ML
# 39         True            mean         0.075384            SARIMAX
# 43         True            mean         0.067342            SARIMAX
# 47         True            mean         0.086918                 ML
# 15         True            mean         0.611153                 ML
# 19         True            mean         0.532525                 ML
# 23         True            last         0.514092                 ML
# 13        False            last         0.508452                 ML
# 17        False            last         0.397118                 ML
# 21        False            last         0.575651       auto_SARIMAX
# 12        False            mean         1.149908                 ML
# 16        False            last         1.279671                 ML
# 20        False            last         1.309084                 ML
# 14         True   seasonal_last         0.539165                 ML
# 18         True   seasonal_last         0.583337                 ML
# 22         True   seasonal_last         0.456328                 ML
# 24        False            mean         1.192388       auto_SARIMAX
# 28        False            mean         1.152468       auto_SARIMAX
# 32        False            last         1.110996       auto_SARIMAX
# 26        False            mean         0.083096                 ML
# 30        False            mean         0.065297                 ML
# 34        False            mean         0.056411            SARIMAX
# 25        False            mean         0.706690            SARIMAX
# 29        False            mean         0.620501            SARIMAX
# 33        False            mean         0.664711                 ML
# 27        False            mean         0.804074       auto_SARIMAX
# 31        False            mean         0.675541            Prophet
# 35        False            mean         0.630851       auto_SARIMAX
#
#     P0 Best Model RMSE P0+Sim Best Model Name  P0+Sim Best Model RMSE
# 1             0.243913           auto_SARIMAX                0.236237
# 5             0.219089           auto_SARIMAX                0.223775
# 9             0.231060                     ML                0.238561
# 0             0.028845                SARIMAX                0.021230
# 4             0.034618                     ML                0.036141
# 8             0.057793                     ML                0.054234
# 2             0.260258           auto_SARIMAX                0.308287
# 6             0.276076           auto_SARIMAX                0.295070
# 10            0.294087           auto_SARIMAX                0.289036
# 3             0.625328                     ML                0.584085
# 7             0.678531                     ML                0.594279
# 11            0.631077           auto_SARIMAX                0.571778
# 37            0.106995                SARIMAX                0.163505
# 41            0.095943                SARIMAX                0.158750
# 45            0.097419                     ML                0.159388
# 36            0.036516                SARIMAX                0.034398
# 40            0.048617                     ML                0.041928
# 44            0.078627                     ML                0.065592
# 38            0.257020                SARIMAX                0.230702
# 42            0.247969                     ML                0.247967
# 46            0.272304                SARIMAX                0.271980
# 39            0.047686                SARIMAX                0.045467
# 43            0.067426                SARIMAX                0.067274
# 47            0.082990                     ML                0.082969
# 15            0.191544                     ML                0.171918
# 19            0.210643                     ML                0.192975
# 23            0.238877                     ML                0.219354
# 13            0.615271                     ML                0.615777
# 17            0.614912                     ML                0.615355
# 21            0.752658                     ML                0.798380
# 12            0.722963           auto_SARIMAX                0.709832
# 16            0.733968           auto_SARIMAX                0.776495
# 20            0.634989                     ML                0.702651
# 14            0.141021                     ML                0.146706
# 18            0.152653                     ML                0.157425
# 22            0.152653                     ML                0.157425
# 24            0.737526                SARIMAX                0.564726
# 28            0.791896           auto_SARIMAX                0.868290
# 32            0.654468           auto_SARIMAX                0.695890
# 26            0.099956                     ML                0.099867
# 30            0.108532                     ML                0.108429
# 34            0.111910                SARIMAX                0.102361
# 25            0.577988           auto_SARIMAX                0.500462
# 29            0.580915           auto_SARIMAX                0.500238
# 33            0.638930           auto_SARIMAX                0.485975
# 27            0.663140                     ML                0.606512
# 31            0.715019                Prophet                0.644290
# 35            0.629432           auto_SARIMAX                0.584066

# %% [markdown]
# ## Optimizer

# %% [markdown]
# ### Summary by Chain

# %%
full_chain_summary
# Out:
#          Chain Master  P0 Non-Opt Revenue  P0 Opt Revenue  P0 Opt Diff  \
# 0                                289570.0        288490.0      -1080.0
# 1               SPECS            220032.0        225619.0       5587.0
# 2    THE BARREL HOUSE              4102.0          4103.0          1.0
# 3  WESTERN BEV LIQ TX            116244.0        133381.0      17137.0
#
#    P0 Opt Diff Ratio  P0+Sim Non-Opt Revenue  P0+Sim Opt Revenue  \
# 0           0.996270                285833.0            335131.0
# 1           1.025392                220232.0            571227.0
# 2           1.000244                  4292.0             49250.0
# 3           1.147423                102952.0          40487926.0
#
#    P0+Sim Opt Diff  P0+Sim Opt Diff Ratio
# 0          49298.0               1.172471
# 1         350995.0               2.593751
# 2          44958.0              11.474837
# 3       40384974.0             393.269932

# %%
print("WRITE this value in the summary table in Git hub --->",round(full_chain_summary[full_chain_summary['Chain Master']=='']['P0+Sim Opt Diff Ratio'].item(),4))
# Out:
# WRITE this value in the summary table in Git hub ---> 1.1725

# %% [markdown]
# Link to the Git Hub Summary Table: https://github.com/ngupta23/msds_capstone/issues/84

# %% [markdown]
# ### Summary by Chain and Product

# %%
full_summary
# Out:
#           Chain Master                          Product  P0 Non-Opt Revenue  \
# 0                         JACK DANIELS BLK WHSKY  1.75L             78808.0
# 1                            JACK DANIELS BLK WHSKY  1L            162183.0
# 2                          JACK DANIELS BLK WHSKY  750M             47810.0
# 3                        JACK DANIELS BLK WHSKY SQ 375M               769.0
# 4                SPECS    JACK DANIELS BLK WHSKY  1.75L             31102.0
# 5                SPECS       JACK DANIELS BLK WHSKY  1L            163171.0
# 6                SPECS     JACK DANIELS BLK WHSKY  750M             14658.0
# 7                SPECS  JACK DANIELS TENN HNY WHSKY  1L             11101.0
# 8     THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L              1157.0
# 9     THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               334.0
# 10    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               866.0
# 11    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L              1745.0
# 12  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L             18820.0
# 13  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L             48563.0
# 14  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M             35987.0
# 15  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M             12874.0
#
#     P0 Opt Revenue  P0 Opt Diff  P0 Opt Diff Ratio  P0+Sim Non-Opt Revenue  \
# 0          80639.0       1831.0           1.023234                 58078.0
# 1         161246.0       -937.0           0.994223                182202.0
# 2          45858.0      -1952.0           0.959172                 44663.0
# 3            747.0        -22.0           0.971391                   890.0
# 4          30562.0       -540.0           0.982638                 33481.0
# 5         162677.0       -494.0           0.996973                159885.0
# 6          21915.0       7257.0           1.495088                 15745.0
# 7          10465.0       -636.0           0.942708                 11121.0
# 8           1176.0         19.0           1.016422                   791.0
# 9            341.0          7.0           1.020958                   109.0
# 10           855.0        -11.0           0.987298                  1411.0
# 11          1731.0        -14.0           0.991977                  1981.0
# 12         31029.0      12209.0           1.648725                 26378.0
# 13         48341.0       -222.0           0.995429                 54899.0
# 14         36817.0        830.0           1.023064                 13356.0
# 15         17194.0       4320.0           1.335560                  8319.0
#
#     P0+Sim Opt Revenue  P0+Sim Opt Diff  P0+Sim Opt Diff Ratio
# 0              91263.0          33185.0               1.571387
# 1             185450.0           3248.0               1.017826
# 2              57596.0          12933.0               1.289569
# 3                822.0            -68.0               0.923596
# 4             377978.0         344497.0              11.289328
# 5             158158.0          -1727.0               0.989198
# 6              24890.0           9145.0               1.580819
# 7              10201.0           -920.0               0.917274
# 8                800.0              9.0               1.011378
# 9                107.0             -2.0               0.981651
# 10             46420.0          45009.0              32.898653
# 11              1923.0            -58.0               0.970722
# 12          39640663.0       39614285.0            1502.792592
# 13             47698.0          -7201.0               0.868832
# 14             11365.0          -1991.0               0.850928
# 15            788200.0         779881.0              94.746965

# %% [markdown]
# ### P0 Optimizer

# %%
full_opt[outputColsOptP0]
# Out:
#           Chain Master                          Product  Period to Last  \
# 1                         JACK DANIELS BLK WHSKY  1.75L               1
# 5                         JACK DANIELS BLK WHSKY  1.75L               2
# 9                         JACK DANIELS BLK WHSKY  1.75L               3
# 0                            JACK DANIELS BLK WHSKY  1L               1
# 4                            JACK DANIELS BLK WHSKY  1L               2
# 8                            JACK DANIELS BLK WHSKY  1L               3
# 2                          JACK DANIELS BLK WHSKY  750M               1
# 6                          JACK DANIELS BLK WHSKY  750M               2
# 10                         JACK DANIELS BLK WHSKY  750M               3
# 3                        JACK DANIELS BLK WHSKY SQ 375M               1
# 7                        JACK DANIELS BLK WHSKY SQ 375M               2
# 11                       JACK DANIELS BLK WHSKY SQ 375M               3
# 37               SPECS    JACK DANIELS BLK WHSKY  1.75L               1
# 41               SPECS    JACK DANIELS BLK WHSKY  1.75L               2
# 45               SPECS    JACK DANIELS BLK WHSKY  1.75L               3
# 36               SPECS       JACK DANIELS BLK WHSKY  1L               1
# 40               SPECS       JACK DANIELS BLK WHSKY  1L               2
# 44               SPECS       JACK DANIELS BLK WHSKY  1L               3
# 38               SPECS     JACK DANIELS BLK WHSKY  750M               1
# 42               SPECS     JACK DANIELS BLK WHSKY  750M               2
# 46               SPECS     JACK DANIELS BLK WHSKY  750M               3
# 39               SPECS  JACK DANIELS TENN HNY WHSKY  1L               1
# 43               SPECS  JACK DANIELS TENN HNY WHSKY  1L               2
# 47               SPECS  JACK DANIELS TENN HNY WHSKY  1L               3
# 15    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               1
# 19    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               2
# 23    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               3
# 13    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               1
# 17    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               2
# 21    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               3
# 12    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               1
# 16    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               2
# 20    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               3
# 14    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               1
# 18    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               2
# 22    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               3
# 24  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               1
# 28  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               2
# 32  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               3
# 26  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               1
# 30  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               2
# 34  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               3
# 25  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               1
# 29  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               2
# 33  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               3
# 27  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               1
# 31  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               2
# 35  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               3
#
#     P0 Non-Opt Price  P0 Non-Opt Demand  P0 Non-Opt Revenue  \
# 1             185.65                224               41518
# 5             184.71                 91               16867
# 9             182.45                112               20423
# 0             229.81                310               71287
# 4             229.69                196               45027
# 8             230.09                199               45869
# 2             222.36                159               35308
# 6             222.36                 45               10052
# 10            222.36                 11                2450
# 3             188.30                  0                  93
# 7             195.60                  0                  96
# 11            195.60                  3                 580
# 37            185.59                 51                9481
# 41            184.56                 61               11168
# 45            184.94                 57               10453
# 36            229.53                239               54868
# 40            229.53                236               54108
# 44            229.53                236               54195
# 38            222.36                 20                4519
# 42            222.36                 23                5072
# 46            222.36                 23                5067
# 39            229.53                 16                3714
# 43            229.53                 16                3763
# 47            229.53                 16                3624
# 15            286.87                  1                 426
# 19            292.57                  2                 457
# 23            298.08                  1                 274
# 13            274.14                  0                  34
# 17            291.93                  0                  37
# 21            291.93                  1                 263
# 12            239.01                  1                 287
# 16            239.01                  1                 287
# 20            234.05                  1                 292
# 14            239.01                  2                 583
# 18            238.41                  2                 581
# 22            238.41                  2                 581
# 24            185.59                 96               17837
# 28            185.59                  4                 706
# 32            180.46                  2                 277
# 26            230.79                 59               13543
# 30            229.89                 59               13491
# 34            230.98                 93               21529
# 25            222.36                148               32964
# 29            222.36                  8                1783
# 33            222.36                  6                1240
# 27            188.30                  9                1770
# 31            195.60                 56               10948
# 35            195.60                  1                 156
#
#     P0 Non-Opt Chain Master Revenue  P0 Optimal Price  P0 Demand  P0 Revenue  \
# 1                            148206            185.80        224       41691
# 5                             72043            185.81         94       17380
# 9                             69322            185.82        116       21568
# 0                            148206            229.45        307       70524
# 4                             72043            229.45        196       44980
# 8                             69322            229.45        199       45742
# 2                            148206            220.34        155       34211
# 6                             72043            220.34         43        9439
# 10                            69322            220.33         10        2208
# 3                            148206            215.82          0         106
# 7                             72043            215.81          0         106
# 11                            69322            215.81          2         535
# 37                            72582            182.70         48        8747
# 41                            74111            185.07         61       11324
# 45                            73340            185.06         57       10491
# 36                            72582            229.36        238       54598
# 40                            74111            229.06        236       53996
# 44                            73340            229.06        236       54083
# 38                            72582            205.27         58       11914
# 42                            74111            219.36         23        5003
# 46                            73340            219.31         23        4998
# 39                            72582            225.86         15        3495
# 43                            74111            224.02         15        3433
# 47                            73340            224.02         16        3537
# 15                             1330            296.11          1         440
# 19                             1362            296.11          2         463
# 23                             1411            296.11          1         273
# 13                             1330            299.57          0          38
# 17                             1362            299.57          0          38
# 21                             1411            299.57          1         265
# 12                             1330            234.36          1         281
# 16                             1362            234.36          1         281
# 20                             1411            234.36          1         293
# 14                             1330            236.70          2         577
# 18                             1362            236.70          2         577
# 22                             1411            236.70          2         577
# 24                            66115            191.23        155       29556
# 28                            26928            189.33          5         959
# 32                            23203            190.37          3         514
# 26                            66115            229.42         59       13463
# 30                            26928            228.07         59       13384
# 34                            23203            230.85         93       21494
# 25                            66115            216.66        156       33873
# 29                            26928            219.31          8        1772
# 33                            23203            210.18          6        1172
# 27                            66115            186.27         10        1803
# 31                            26928            180.65         84       15246
# 35                            23203            213.20          1         145
#
#     P0 Chain Master Revenue
# 1                    146532
# 5                     71906
# 9                     70052
# 0                    146532
# 4                     71906
# 8                     70052
# 2                    146532
# 6                     71906
# 10                    70052
# 3                    146532
# 7                     71906
# 11                    70052
# 37                    78753
# 41                    73757
# 45                    73108
# 36                    78753
# 40                    73757
# 44                    73108
# 38                    78753
# 42                    73757
# 46                    73108
# 39                    78753
# 43                    73757
# 47                    73108
# 15                     1336
# 19                     1359
# 23                     1408
# 13                     1336
# 17                     1359
# 21                     1408
# 12                     1336
# 16                     1359
# 20                     1408
# 14                     1336
# 18                     1359
# 22                     1408
# 24                    78695
# 28                    31361
# 32                    23326
# 26                    78695
# 30                    31361
# 34                    23326
# 25                    78695
# 29                    31361
# 33                    23326
# 27                    78695
# 31                    31361
# 35                    23326

# %% [markdown]
# ### P0+Sim Optimizer

# %%
full_opt[outputColsOptP0Sim]
# Out:
#           Chain Master                          Product  Period to Last  \
# 1                         JACK DANIELS BLK WHSKY  1.75L               1
# 5                         JACK DANIELS BLK WHSKY  1.75L               2
# 9                         JACK DANIELS BLK WHSKY  1.75L               3
# 0                            JACK DANIELS BLK WHSKY  1L               1
# 4                            JACK DANIELS BLK WHSKY  1L               2
# 8                            JACK DANIELS BLK WHSKY  1L               3
# 2                          JACK DANIELS BLK WHSKY  750M               1
# 6                          JACK DANIELS BLK WHSKY  750M               2
# 10                         JACK DANIELS BLK WHSKY  750M               3
# 3                        JACK DANIELS BLK WHSKY SQ 375M               1
# 7                        JACK DANIELS BLK WHSKY SQ 375M               2
# 11                       JACK DANIELS BLK WHSKY SQ 375M               3
# 37               SPECS    JACK DANIELS BLK WHSKY  1.75L               1
# 41               SPECS    JACK DANIELS BLK WHSKY  1.75L               2
# 45               SPECS    JACK DANIELS BLK WHSKY  1.75L               3
# 36               SPECS       JACK DANIELS BLK WHSKY  1L               1
# 40               SPECS       JACK DANIELS BLK WHSKY  1L               2
# 44               SPECS       JACK DANIELS BLK WHSKY  1L               3
# 38               SPECS     JACK DANIELS BLK WHSKY  750M               1
# 42               SPECS     JACK DANIELS BLK WHSKY  750M               2
# 46               SPECS     JACK DANIELS BLK WHSKY  750M               3
# 39               SPECS  JACK DANIELS TENN HNY WHSKY  1L               1
# 43               SPECS  JACK DANIELS TENN HNY WHSKY  1L               2
# 47               SPECS  JACK DANIELS TENN HNY WHSKY  1L               3
# 15    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               1
# 19    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               2
# 23    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               3
# 13    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               1
# 17    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               2
# 21    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               3
# 12    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               1
# 16    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               2
# 20    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               3
# 14    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               1
# 18    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               2
# 22    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               3
# 24  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               1
# 28  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               2
# 32  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               3
# 26  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               1
# 30  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               2
# 34  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               3
# 25  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               1
# 29  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               2
# 33  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               3
# 27  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               1
# 31  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               2
# 35  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               3
#
#     P0+Sim Non-Opt Price  P0+Sim Non-Opt Demand  P0+Sim Non-Opt Revenue  \
# 1                 185.65                    169                   31310
# 5                 184.71                     90                   16657
# 9                 182.45                     55                   10111
# 0                 229.81                    315                   72463
# 4                 229.69                    239                   54987
# 8                 230.09                    238                   54752
# 2                 222.36                     95                   21197
# 6                 222.36                     46                   10265
# 10                222.36                     59                   13201
# 3                 188.30                      1                     111
# 7                 195.60                      1                     116
# 11                195.60                      3                     663
# 37                185.59                     61                   11394
# 41                184.56                     79                   14493
# 45                184.94                     41                    7594
# 36                229.53                    242                   55565
# 40                229.53                    227                   52097
# 44                229.53                    228                   52223
# 38                222.36                     31                    6931
# 42                222.36                     23                    5072
# 46                222.36                     17                    3742
# 39                229.53                     16                    3731
# 43                229.53                     16                    3768
# 47                229.53                     16                    3622
# 15                286.87                      1                     256
# 19                292.57                      1                     266
# 23                298.08                      1                     269
# 13                274.14                      0                      35
# 17                291.93                      0                      37
# 21                291.93                      0                      37
# 12                239.01                      3                     614
# 16                239.01                      2                     407
# 20                234.05                      2                     390
# 14                239.01                      3                     650
# 18                238.41                      3                     662
# 22                238.41                      3                     669
# 24                185.59                    134                   24907
# 28                185.59                      6                    1132
# 32                180.46                      2                     339
# 26                230.79                     59                   13549
# 30                229.89                     59                   13497
# 34                230.98                    121                   27853
# 25                222.36                     38                    8432
# 29                222.36                     10                    2319
# 33                222.36                     12                    2605
# 27                188.30                      1                     107
# 31                195.60                     42                    8138
# 35                195.60                      0                      74
#
#     P0+Sim Non-Opt Chain Master Revenue  P0+Sim Optimal Price  P0+Sim Demand  \
# 1                                125081                175.35            310
# 5                                 82024                175.30            155
# 9                                 78727                175.25             55
# 0                                125081                229.47            331
# 4                                 82024                229.47            239
# 8                                 78727                229.46            238
# 2                                125081                211.62            131
# 6                                 82024                211.59             63
# 10                                78727                211.57             78
# 3                                125081                217.37              1
# 7                                 82024                217.36              1
# 11                                78727                217.36              3
# 37                                77621                167.58            926
# 41                                75430                167.40           1290
# 45                                67182                167.22             41
# 36                                77621                228.33            238
# 40                                75430                228.33            227
# 44                                67182                228.33            228
# 38                                77621                224.05             42
# 42                                75430                224.05             23
# 46                                67182                224.05             46
# 39                                77621                223.21             15
# 43                                75430                223.21             15
# 47                                67182                223.21             16
# 15                                 1555                297.19              1
# 19                                 1372                297.19              1
# 23                                 1365                293.70              1
# 13                                 1555                283.19              0
# 17                                 1372                283.19              0
# 21                                 1365                279.92              0
# 12                                 1555                230.26            160
# 16                                 1372                230.26             40
# 20                                 1365                234.10              2
# 14                                 1555                228.03              3
# 18                                 1372                228.03              3
# 22                                 1365                238.92              3
# 24                                46995                190.35         208249
# 28                                25086                180.95              2
# 32                                30871                182.14              0
# 26                                46995                215.25             59
# 30                                25086                230.54             59
# 34                                30871                214.83            100
# 25                                46995                222.04             36
# 29                                25086                211.03              7
# 33                                30871                211.03              9
# 27                                46995                208.74              1
# 31                                25086                192.51             85
# 35                                30871                181.43           4254
#
#     P0+Sim Revenue  P0+Sim Chain Master Revenue
# 1            54428                       158129
# 5            27123                        95568
# 9             9712                        81432
# 0            75911                       158129
# 4            54934                        95568
# 8            54605                        81432
# 2            27661                       158129
# 6            13383                        95568
# 10           16552                        81432
# 3              129                       158129
# 7              129                        95568
# 11             564                        81432
# 37          155162                       222243
# 41          215949                       276239
# 45            6867                        72744
# 36           54385                       222243
# 40           51824                       276239
# 44           51949                        72744
# 38            9373                       222243
# 42            5111                       276239
# 46           10406                        72744
# 39            3322                       222243
# 43            3356                       276239
# 47            3523                        72744
# 15             265                        37730
# 19             270                        10160
# 23             265                         1361
# 13              36                        37730
# 17              36                        10160
# 21              35                         1361
# 12           36809                        37730
# 16            9221                        10160
# 20             390                         1361
# 14             620                        37730
# 18             633                        10160
# 22             670                         1361
# 24        39640232                     39661043
# 28             412                        31686
# 32              19                       795196
# 26           12637                     39661043
# 30           13535                        31686
# 34           21526                       795196
# 25            8055                     39661043
# 29            1389                        31686
# 33            1921                       795196
# 27             119                     39661043
# 31           16351                        31686
# 35          771730                       795196

# %% [markdown]
# ### Naive

# %%
full_opt[outputColsOptNaive]
# Out:
#           Chain Master                          Product  Period to Last  \
# 1                         JACK DANIELS BLK WHSKY  1.75L               1
# 5                         JACK DANIELS BLK WHSKY  1.75L               2
# 9                         JACK DANIELS BLK WHSKY  1.75L               3
# 0                            JACK DANIELS BLK WHSKY  1L               1
# 4                            JACK DANIELS BLK WHSKY  1L               2
# 8                            JACK DANIELS BLK WHSKY  1L               3
# 2                          JACK DANIELS BLK WHSKY  750M               1
# 6                          JACK DANIELS BLK WHSKY  750M               2
# 10                         JACK DANIELS BLK WHSKY  750M               3
# 3                        JACK DANIELS BLK WHSKY SQ 375M               1
# 7                        JACK DANIELS BLK WHSKY SQ 375M               2
# 11                       JACK DANIELS BLK WHSKY SQ 375M               3
# 37               SPECS    JACK DANIELS BLK WHSKY  1.75L               1
# 41               SPECS    JACK DANIELS BLK WHSKY  1.75L               2
# 45               SPECS    JACK DANIELS BLK WHSKY  1.75L               3
# 36               SPECS       JACK DANIELS BLK WHSKY  1L               1
# 40               SPECS       JACK DANIELS BLK WHSKY  1L               2
# 44               SPECS       JACK DANIELS BLK WHSKY  1L               3
# 38               SPECS     JACK DANIELS BLK WHSKY  750M               1
# 42               SPECS     JACK DANIELS BLK WHSKY  750M               2
# 46               SPECS     JACK DANIELS BLK WHSKY  750M               3
# 39               SPECS  JACK DANIELS TENN HNY WHSKY  1L               1
# 43               SPECS  JACK DANIELS TENN HNY WHSKY  1L               2
# 47               SPECS  JACK DANIELS TENN HNY WHSKY  1L               3
# 15    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               1
# 19    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               2
# 23    THE BARREL HOUSE      GENTLEMAN JACK WHSKY 6PK 1L               3
# 13    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               1
# 17    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               2
# 21    THE BARREL HOUSE     GENTLEMAN JACK WHSKY OL 750M               3
# 12    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               1
# 16    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               2
# 20    THE BARREL HOUSE       JACK DANIELS BLK WHSKY  1L               3
# 14    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               1
# 18    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               2
# 22    THE BARREL HOUSE  JACK DANIELS TENN HNY WHSKY  1L               3
# 24  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               1
# 28  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               2
# 32  WESTERN BEV LIQ TX    JACK DANIELS BLK WHSKY  1.75L               3
# 26  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               1
# 30  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               2
# 34  WESTERN BEV LIQ TX       JACK DANIELS BLK WHSKY  1L               3
# 25  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               1
# 29  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               2
# 33  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  750M               3
# 27  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               1
# 31  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               2
# 35  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY SQ 375M               3
#
#     Actual Price  Actual Demand  Actual Revenue  Actual Chain Master Revenue  \
# 1     185.650112         389.61        72331.14                    281489.82
# 5     184.710623          40.95         7563.90                     87687.18
# 9     182.449915         263.25        48029.94                    129024.66
# 0     229.811232         589.19       135402.48                    281489.82
# 4     229.687258         301.91        69344.88                     87687.18
# 8     230.085045         316.54        72831.12                    129024.66
# 2     222.360000         225.00        50031.00                    281489.82
# 6     222.360000          30.00         6670.80                     87687.18
# 10    222.360000          20.00         4447.20                    129024.66
# 3     188.295238         126.00        23725.20                    281489.82
# 7     195.600000          21.00         4107.60                     87687.18
# 11    195.600000          19.00         3716.40                    129024.66
# 37    185.589744         176.67        32788.14                    162000.42
# 41    184.564103          35.10         6478.20                     68510.28
# 45    184.935385         117.00        21637.44                     83198.40
# 36    229.533835         476.14       109290.24                    162000.42
# 40    229.533835         240.73        55255.68                     68510.28
# 44    229.533835         238.07        54645.12                     83198.40
# 38    222.360000          69.00        15342.84                    162000.42
# 42    222.360000          14.00         3113.04                     68510.28
# 46    222.360000          16.00         3557.76                     83198.40
# 39    229.533835          19.95         4579.20                    162000.42
# 43    229.533835          15.96         3663.36                     68510.28
# 47    229.533835          14.63         3358.08                     83198.40
# 15    286.874200           4.69         1345.44                      5862.96
# 19    292.567164           1.34          392.04                      1027.80
# 23    298.080000           0.00            0.00                      4669.20
# 13    274.144615          13.00         3563.88                      5862.96
# 17    291.927711           0.00            0.00                      1027.80
# 21    291.927711           0.00            0.00                      4669.20
# 12    239.007519           2.66          635.76                      5862.96
# 16    239.007519           2.66          635.76                      1027.80
# 20    234.045113          19.95         4669.20                      4669.20
# 14    239.007519           1.33          317.88                      5862.96
# 18    238.410000           0.00            0.00                      1027.80
# 22    238.410000           0.00            0.00                      4669.20
# 24    185.589744         210.60        39085.20                    122752.68
# 28    185.589744           5.85         1085.70                     22204.50
# 32    180.461538         146.25        26392.50                     44515.14
# 26    230.786122         110.39        25476.48                    122752.68
# 30    229.894737          58.52        13453.44                     22204.50
# 34    230.977444          58.52        13516.80                     44515.14
# 25    222.360000         155.00        34465.80                    122752.68
# 29    222.360000          16.00         3557.76                     22204.50
# 33    222.360000           4.00          889.44                     44515.14
# 27    188.295238         126.00        23725.20                    122752.68
# 31    195.600000          21.00         4107.60                     22204.50
# 35    195.600000          19.00         3716.40                     44515.14
#
#     Naive Prices  Naive Demand  Naive Revenue  Naive Chain Master Revenue
# 1     185.650112     40.950000    7602.372072                92960.401203
# 5     184.710623    157.916707   29168.893345               114657.656235
# 9     182.449915    156.616296   28574.629873               114236.662771
# 0     229.811232    292.610723   67245.230832                92960.401203
# 4     229.687258    292.497317   67182.906670               114657.656235
# 8     230.085045    292.200494   67230.963638               114236.662771
# 2     222.360000     69.590361   15474.112771                92960.401203
# 6     222.360000     70.073171   15581.470244               114657.656235
# 10    222.360000     70.691358   15718.930370               114236.662771
# 3     188.295238     14.013554    2638.685528                92960.401203
# 7     195.600000     13.928354    2724.385976               114657.656235
# 11    195.600000     13.865741    2712.138889               114236.662771
# 37    185.589744     44.962771    8344.629157                67377.335254
# 41    184.564103     45.083049    8320.712439                67316.840805
# 45    184.935385     44.195185    8173.253570                67137.717349
# 36    229.533835    217.722084   49974.584892                67377.335254
# 40    229.533835    217.441500   49910.181293                67316.840805
# 44    229.533835    217.186827   49851.725260                67137.717349
# 38    222.360000     24.319277    5407.634458                67377.335254
# 42    222.360000     24.445122    5435.617317                67316.840805
# 46    222.360000     24.549383    5458.800741                67137.717349
# 39    229.533835     15.903916    3650.486747                67377.335254
# 43    229.533835     15.903232    3650.329756                67316.840805
# 47    229.533835     15.918951    3653.937778                67137.717349
# 15    286.874200      1.169049     335.370107                 2852.240223
# 19    292.567164      1.166913     341.400281                 5743.770881
# 23    298.080000      0.000000       0.000000                 5303.370600
# 13    274.144615      0.000000       0.000000                 2852.240223
# 17    291.927711      0.000000       0.000000                 5743.770881
# 21    291.927711      0.000000       0.000000                 5303.370600
# 12    239.007519      9.200506    2198.990116                 2852.240223
# 16    239.007519     19.950000    4768.200000                 5743.770881
# 20    234.045113     19.950000    4669.200000                 5303.370600
# 14    239.007519      1.330000     317.880000                 2852.240223
# 18    238.410000      2.660000     634.170600                 5743.770881
# 22    238.410000      2.660000     634.170600                 5303.370600
# 24    185.589744    110.560063   20518.813797                48406.991208
# 28    185.589744    111.902500   20767.956282                48812.372432
# 32    180.461538      0.000000       0.000000                28241.967210
# 26    230.786122     66.489207   15344.786307                48406.991208
# 30    229.894737     66.587593   15308.137076                48812.372432
# 34    230.977444     66.688437   15403.524812                28241.967210
# 25    222.360000     41.041148    9125.909702                48406.991208
# 29    222.360000     41.354163    9195.511573                48812.372432
# 33    222.360000     41.827000    9300.651720                28241.967210
# 27    188.295238     18.149590    3417.481401                48406.991208
# 31    195.600000     18.102083    3540.767500                48812.372432
# 35    195.600000     18.086864    3537.790678                28241.967210
