# %% [markdown]
# # Init

# %%
# %load_ext autoreload
# %autoreload 2

# %%
print("CURRENT FOLDER:")
# %pwd
# Out:
# CURRENT FOLDER:
# 'c:\\max\\Google Drive Max\\Max Shared\\Master Data Science\\2020-05 Capstone A\\msds_capstone\\analysis\\fullRuns'

# %%
import os
import glob
import sys
sys.path.append(os.environ['DEV_AUTOTS'])
sys.path.append(os.environ['CAPSTONE_PYTHON_SOURCE'])
folder = os.environ['CAPSTONE_DATA']

# %%
## Sourcing the .py with all the code##
t='"'+os.environ['CAPSTONE_PYTHON_SOURCE']+'\\fullRun\\fullRun.py'+'"'
# %run -i $t
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# Running Auto Timeseries version: 0.0.24

# %% [markdown]
# # Parameters

# %%
#Parameters

ProdCats = ['SUP PREM WHISKEY']
TOP_PRODUCTS = 3  # How many products to consider in the category
TOP_SIMILAR = 1   # Get TOP_SIMILAR most similar products
RUN_PERIODS = [1,2,3] # this will run AutoTS and Optimzer for speicfic periods (1 = last, 2 = second to last)

CV_NUM = 10         # number of Cross Valudations  10
OPT_CALLS = 100     # number of calls for the optimizer process   100
OPT_RND_STARTS = 20 # number of random calls for the optimizer process  20

LOG_TRANSFORM = True # Take log of 9L cases to smooth out peaks and valleys
ZERO_ADDER = 0.1 

RESAMPLE_FREQ = 'M'


# Pricing changes every 4 weeks
if RESAMPLE_FREQ == 'M':    FORECAST_PERIOD = 1 #last 4 months as test 
if RESAMPLE_FREQ == 'W':    FORECAST_PERIOD = 4 
if RESAMPLE_FREQ == '2W':   FORECAST_PERIOD = 2 

# Seasonal Period
if RESAMPLE_FREQ == 'M':    SEASONAL_PERIOD = 12  # Yearly
if RESAMPLE_FREQ == 'W':    SEASONAL_PERIOD = 13 # Quarterly (we can also take yearly = 52, but SARIMAX becomes too slow)
if RESAMPLE_FREQ == '2W':   SEASONAL_PERIOD = 13 # This becomes problematic --> for quarterly, should we take 6 biweekly periods or 7 bi-weekly periods. Instead I just took half yearly period  

COL_TIME = 'WeekDate'
COL_PREDS = ['9L Cases'] #Demand
COL_PRICE= ['Dollar Sales per 9L Case'] #Price

# %% [markdown]
# # Full Run

# %%
dataRaw = loadDataset(version=4)
ProdCat = 'SUP PREM WHISKEY' #'ECONOMY VODKA'
ChainMasters =  [''] +  dataRaw['Chain Master'].unique().tolist() 
display(ChainMasters,ProdCats)
# Out:
# ['', 'THE BARREL HOUSE', 'WESTERN BEV LIQ TX', 'SPECS']
# ['SUP PREM WHISKEY']

# %%
(full_models,full_opt,full_summary,full_chain_summary)  = fullRun(ProdCat = ProdCat
                                                           ,ChainMasters = ChainMasters
                                                           ,dataRaw = dataRaw
                                                           ,savePKL=True
                                                           ,saveXLS=True)
# Out:
# ==================================================
# Parameters being used...
# ==================================================
# TOP_PRODUCTS = 3
# TOP_SIMILAR = 1
# RUN_PERIODS = [1, 2, 3]
# ProdCat: SUP PREM WHISKEY
# ChainMasters: ['', 'THE BARREL HOUSE', 'WESTERN BEV LIQ TX', 'SPECS']
#
#
# ========================== (2020-09-01 10:55:01.244435)
# ===== Products List  =====
# ==== SUP PREM WHISKEY ====
# ============  ============
# ==========================
#
#
#
# ========================== (2020-09-01 10:55:07.304435)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 1 ============
# ==========================
#
#
#
# ================== (2020-09-01 10:55:07.304435)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 1.1904761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
#
#
# ===================== (2020-09-01 10:55:36.853955)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#       lb_stat  lb_pvalue
# 12  17.529696   0.130735
# 24  31.092108   0.151145
# 48  54.922995   0.228882
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12  115.750529  4.333814e-19
# 24  214.169023  1.845834e-32
# 48  308.098428  1.176533e-39
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   76.707883  1.745018e-11
# 24  131.122583  9.711501e-17
# 48  214.957410  5.416649e-23
#
# Is Data White Noise: False
#
#
# ==================== (2020-09-01 10:55:36.865954)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (83, 4) (1, 4)
# (83, 4) (1, 4)
# (83, 4) (1, 4)
#
#
# =============== (2020-09-01 10:55:36.869954)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.043169         []
# 1  1      last   0.324455         []
# 2  2      mean   0.427990         []
#
#                                            All RMSEs  \
# 0  [[0.07143315389555474, 0.11332894033533458, 0....
# 1  [[0.3244545696539494, 0.4963154566538675, 0.34...
# 2  [[0.6704496090247218, 0.719929333484661, 0.427...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-01 10:55:37.167955)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  4.4min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-01 11:00:00.442190)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  5.2min finished
# =================== (2020-09-01 11:05:09.689721)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-01 11:05:09.694721)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 1 ============
# ==========================
#
#
#
# =========================== (2020-09-01 11:05:09.695721)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ============  =============
# ============ 1 ============
# ===========================
#
#
#
# ================== (2020-09-01 11:05:09.698722)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 1.1904761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
#
#
# ==================== (2020-09-01 11:05:50.050129)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (83, 4) (1, 4)
# (83, 4) (1, 4)
# (83, 4) (1, 4)
#
#
# ======================== (2020-09-01 11:05:50.054127)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-01 11:05:50.067127)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False]
#
#
# =============== (2020-09-01 11:05:50.069127)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-01 11:05:50.076127)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-01 11:05:50.085128)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-01 11:05:50.087128)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-01 11:05:51.887700)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-01 11:05:51.893703)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-01 11:09:03.829761)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-01 11:09:03.897758)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-01 11:09:03.898758)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-01 11:09:03.954758)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-01 11:09:03.961757)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-01 11:10:10.658806)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-01 11:10:11.047805)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-01 11:10:11.052805)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 2 ============
# ==========================
#
#
#
# ================== (2020-09-01 11:10:11.052805)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 1.2048192771084338
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
#
#
# ===================== (2020-09-01 11:10:48.577877)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#       lb_stat  lb_pvalue
# 12  17.074759   0.146807
# 24  30.689164   0.162949
# 48  53.509495   0.271059
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12  113.741522  1.085921e-18
# 24  210.737801  8.608130e-32
# 48  298.546482  6.801454e-38
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   73.433730  7.257343e-11
# 24  127.792143  3.888372e-16
# 48  208.580703  6.624266e-22
#
# Is Data White Noise: False
#
#
# ==================== (2020-09-01 11:10:48.594875)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (82, 4) (1, 4)
# (82, 4) (1, 4)
# (82, 4) (1, 4)
#
#
# =============== (2020-09-01 11:10:48.600875)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.021557         []
# 1  1      mean   0.323943         []
# 2  2      mean   0.373199         []
#
#                                            All RMSEs  \
# 0  [[0.057546587491533165, 0.09126460007014617, 0...
# 1  [[0.3342880201030623, 0.4694144778845947, 0.32...
# 2  [[0.6160411345584191, 0.6054018321634664, 0.37...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-01 11:10:49.025876)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  6.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-01 11:17:01.975109)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  4.3min finished
# =================== (2020-09-01 11:21:19.692208)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-01 11:21:19.696209)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 2 ============
# ==========================
#
#
#
# =========================== (2020-09-01 11:21:19.697209)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ============  =============
# ============ 2 ============
# ===========================
#
#
#
# ================== (2020-09-01 11:21:19.699210)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 1.2048192771084338
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
#
#
# ==================== (2020-09-01 11:21:43.352363)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (82, 4) (1, 4)
# (82, 4) (1, 4)
# (82, 4) (1, 4)
#
#
# ======================== (2020-09-01 11:21:43.359334)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-01 11:21:43.369365)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False]
#
#
# =============== (2020-09-01 11:21:43.370367)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-01 11:21:43.375334)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-01 11:21:43.376334)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-01 11:21:43.377335)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-01 11:21:43.434334)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-01 11:21:43.439334)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-01 11:22:22.428582)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-01 11:22:22.497707)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-01 11:22:22.498707)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-01 11:22:22.570706)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-01 11:22:22.577709)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-01 11:23:13.418915)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-01 11:23:13.513916)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-01 11:23:13.522917)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 3 ============
# ==========================
#
#
#
# ================== (2020-09-01 11:23:13.522917)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
#
#
# ===================== (2020-09-01 11:23:40.732442)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#       lb_stat  lb_pvalue
# 12  16.492825   0.169692
# 24  29.613691   0.197887
# 48  52.235849   0.312831
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12  111.729571  2.720557e-18
# 24  207.460783  3.736074e-31
# 48  291.621010  1.270149e-36
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   72.023277  1.337193e-10
# 24  126.557635  6.490946e-16
# 48  206.128607  1.725436e-21
#
# Is Data White Noise: False
#
#
# ==================== (2020-09-01 11:23:40.740441)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (81, 4) (1, 4)
# (81, 4) (1, 4)
# (81, 4) (1, 4)
#
#
# =============== (2020-09-01 11:23:40.743441)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.033917         []
# 1  1      mean   0.319180         []
# 2  2      mean   0.373056         []
#
#                                            All RMSEs  \
# 0  [[0.0872048496772559, 0.1165490736094128, 0.03...
# 1  [[0.35617856342347604, 0.5500854364755055, 0.3...
# 2  [[0.556716035671863, 0.5707857245806156, 0.373...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-01 11:23:40.972441)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  4.5min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-01 11:28:12.981221)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  5.8min finished
# =================== (2020-09-01 11:34:00.785834)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-01 11:34:00.794835)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 3 ============
# ==========================
#
#
#
# =========================== (2020-09-01 11:34:00.795835)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ============  =============
# ============ 3 ============
# ===========================
#
#
#
# ================== (2020-09-01 11:34:00.798833)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
#
#
# ==================== (2020-09-01 11:34:33.824356)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (81, 4) (1, 4)
# (81, 4) (1, 4)
# (81, 4) (1, 4)
#
#
# ======================== (2020-09-01 11:34:33.831356)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-01 11:34:33.845355)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False]
#
#
# =============== (2020-09-01 11:34:33.847355)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-01 11:34:33.854355)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-01 11:34:33.855354)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-01 11:34:33.856356)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-01 11:34:34.237354)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-01 11:34:34.243355)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-01 11:36:58.019243)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-01 11:36:58.110241)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-01 11:36:58.111243)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-01 11:36:58.187761)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-01 11:36:58.193760)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-01 11:39:01.693642)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-01 11:39:01.829835)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-01 11:39:01.839825)
# ===== Products List  =====
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 11:39:03.239266)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 1 ============
# ==========================
#
#
#
# ========================== (2020-09-01 11:39:03.240268)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'GENTLEMAN JACK WHSKY OL 750M', '2': 'GENTLEMAN JACK WHSKY 6PK 1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '2']
# % of weeks without a purchase: 45.23809523809524
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '2']
# % of weeks without a purchase: 52.38095238095239
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY 6PK 1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '1']
# % of weeks without a purchase: 32.926829268292686
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: GENTLEMAN JACK WHSKY 6PK 1L
#
#
# ========================== (2020-09-01 11:39:43.524708)
# ====== WHITE NOISE =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#        lb_stat  lb_pvalue
# 12   24.932218   0.015147
# 24   47.266936   0.003107
# 48  103.010327   0.000007
#
# Is Data White Noise: False
#        lb_stat  lb_pvalue
# 12   24.646813   0.016588
# 24   50.653838   0.001168
# 48  108.922594   0.000001
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12   8.641692   0.733192
# 24  19.315056   0.734985
# 48  47.523727   0.492264
#
# Is Data White Noise: True
#
#
# ========================== (2020-09-01 11:39:43.539708)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (83, 4) (1, 4)
# (83, 4) (1, 4)
# (81, 4) (1, 4)
#
#
# ========================== (2020-09-01 11:39:43.543708)
# ========= NAIVE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   1.149908         []
# 1  1      last   0.508452         []
# 2  2      mean   0.611153         []
#
#                                            All RMSEs  \
# 0  [[1.3378491195367055, 1.5550765479093094, 1.14...
# 1  [[0.5084521358062825, 1.227326606712806, 0.861...
# 2  [[0.7042605406907361, 0.7703384907350979, 0.61...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ========================== (2020-09-01 11:39:43.944400)
# ====== Multivar P0 =======
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  5.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================== (2020-09-01 11:44:56.774031)
# ==== Multivar P0+Sim =====
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  7.4min finished
# ========================== (2020-09-01 11:52:19.527310)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 11:52:19.534310)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 1 ============
# ==========================
#
#
#
# =========================== (2020-09-01 11:52:19.535311)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ==== THE BARREL HOUSE =====
# ============ 1 ============
# ===========================
#
#
#
# ========================== (2020-09-01 11:52:19.537312)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'GENTLEMAN JACK WHSKY OL 750M', '2': 'GENTLEMAN JACK WHSKY 6PK 1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '2']
# % of weeks without a purchase: 45.23809523809524
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '2']
# % of weeks without a purchase: 52.38095238095239
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY 6PK 1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '1']
# % of weeks without a purchase: 32.926829268292686
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: GENTLEMAN JACK WHSKY 6PK 1L
#
#
# ========================== (2020-09-01 11:52:58.323183)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (83, 4) (1, 4)
# (83, 4) (1, 4)
# (81, 4) (1, 4)
#
#
# ========================== (2020-09-01 11:52:58.330184)
# ===== NAIVE FORECAST =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 11:52:58.349187)
# ========== MASK ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
# Mask: [False, False, False]
#
#
# ========================== (2020-09-01 11:52:58.352182)
# ========= SPACE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 11:52:58.360711)
# ======= Test Index =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 11:52:58.362707)
# ==== GET FUNCTION P0 =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ====================================== (2020-09-01 11:52:58.363705)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ========== THE BARREL HOUSE ==========
# ======================================
#
#
#
# ========================== (2020-09-01 11:52:58.539708)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 11:52:58.547710)
# ===== OPTIMIZING P0 ======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 11:54:33.953538)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ============================= (2020-09-01 11:54:34.095540)
# ==== GET FUNCTION P0+Sim ====
# ===== THE BARREL HOUSE ======
# =============================
#
#
#
# ========================================== (2020-09-01 11:54:34.096540)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ============ THE BARREL HOUSE ============
# ==========================================
#
#
#
# ========================== (2020-09-01 11:54:34.266539)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# =========================== (2020-09-01 11:54:34.274539)
# ==== OPTIMIZING P0+Sim ====
# ==== THE BARREL HOUSE =====
# ===========================
#
#
#
# ========================== (2020-09-01 11:56:04.087431)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 11:56:04.229433)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 11:56:04.237433)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 2 ============
# ==========================
#
#
#
# ========================== (2020-09-01 11:56:04.238434)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'GENTLEMAN JACK WHSKY OL 750M', '2': 'GENTLEMAN JACK WHSKY 6PK 1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '2']
# % of weeks without a purchase: 45.78313253012048
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '2']
# % of weeks without a purchase: 53.01204819277109
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY 6PK 1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '1']
# % of weeks without a purchase: 33.33333333333333
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: GENTLEMAN JACK WHSKY 6PK 1L
#
#
# ========================== (2020-09-01 11:56:38.571736)
# ====== WHITE NOISE =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#       lb_stat  lb_pvalue
# 12  23.922535   0.020840
# 24  45.414544   0.005201
# 48  99.152623   0.000020
#
# Is Data White Noise: False
#        lb_stat  lb_pvalue
# 12   25.814484   0.011401
# 24   50.372270   0.001269
# 48  100.845296   0.000013
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12   8.057662   0.780608
# 24  17.817943   0.811750
# 48  41.544821   0.733036
#
# Is Data White Noise: True
#
#
# ========================== (2020-09-01 11:56:38.592253)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (82, 4) (1, 4)
# (82, 4) (1, 4)
# (80, 4) (1, 4)
#
#
# ========================== (2020-09-01 11:56:38.597255)
# ========= NAIVE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      last   1.279671         []
# 1  1      last   0.397118         []
# 2  2      mean   0.532525         []
#
#                                            All RMSEs  \
# 0  [[1.2796706251393728, 1.655747949478816, 1.324...
# 1  [[0.3971180356035492, 1.0727385943033805, 0.73...
# 2  [[0.5741726496470821, 0.6294921160859183, 0.53...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 1  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ========================== (2020-09-01 11:56:39.010254)
# ====== Multivar P0 =======
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  5.9min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================== (2020-09-01 12:02:33.119157)
# ==== Multivar P0+Sim =====
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  6.4min finished
# ========================== (2020-09-01 12:08:57.350300)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:08:57.356301)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 2 ============
# ==========================
#
#
#
# =========================== (2020-09-01 12:08:57.357299)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ==== THE BARREL HOUSE =====
# ============ 2 ============
# ===========================
#
#
#
# ========================== (2020-09-01 12:08:57.359299)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'GENTLEMAN JACK WHSKY OL 750M', '2': 'GENTLEMAN JACK WHSKY 6PK 1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '2']
# % of weeks without a purchase: 45.78313253012048
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '2']
# % of weeks without a purchase: 53.01204819277109
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY 6PK 1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '1']
# % of weeks without a purchase: 33.33333333333333
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: GENTLEMAN JACK WHSKY 6PK 1L
#
#
# ========================== (2020-09-01 12:09:32.910471)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (82, 4) (1, 4)
# (82, 4) (1, 4)
# (80, 4) (1, 4)
#
#
# ========================== (2020-09-01 12:09:32.915470)
# ===== NAIVE FORECAST =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:09:32.931473)
# ========== MASK ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
# Mask: [False, False, False]
#
#
# ========================== (2020-09-01 12:09:32.934474)
# ========= SPACE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:09:32.941473)
# ======= Test Index =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:09:32.943472)
# ==== GET FUNCTION P0 =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ====================================== (2020-09-01 12:09:32.944472)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ========== THE BARREL HOUSE ==========
# ======================================
#
#
#
# ========================== (2020-09-01 12:09:33.083470)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:09:33.089470)
# ===== OPTIMIZING P0 ======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:11:02.204685)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ============================= (2020-09-01 12:11:02.395685)
# ==== GET FUNCTION P0+Sim ====
# ===== THE BARREL HOUSE ======
# =============================
#
#
#
# ========================================== (2020-09-01 12:11:02.397682)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ============ THE BARREL HOUSE ============
# ==========================================
#
#
#
# ========================== (2020-09-01 12:11:02.534682)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# =========================== (2020-09-01 12:11:02.540684)
# ==== OPTIMIZING P0+Sim ====
# ==== THE BARREL HOUSE =====
# ===========================
#
#
#
# ========================== (2020-09-01 12:12:43.841636)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:12:43.995081)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:12:44.005079)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 3 ============
# ==========================
#
#
#
# ========================== (2020-09-01 12:12:44.006080)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'GENTLEMAN JACK WHSKY OL 750M', '2': 'GENTLEMAN JACK WHSKY 6PK 1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '2']
# % of weeks without a purchase: 46.34146341463415
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '2']
# % of weeks without a purchase: 52.4390243902439
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY 6PK 1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '1']
# % of weeks without a purchase: 33.75
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: GENTLEMAN JACK WHSKY 6PK 1L
#
#
# ========================== (2020-09-01 12:13:23.154440)
# ====== WHITE NOISE =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#       lb_stat  lb_pvalue
# 12  22.966606   0.028011
# 24  43.950059   0.007733
# 48  96.983960   0.000037
#
# Is Data White Noise: False
#        lb_stat  lb_pvalue
# 12   27.402860   0.006758
# 24   51.649912   0.000869
# 48  103.761135   0.000006
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12   7.723903   0.806317
# 24  17.026775   0.847518
# 48  40.563386   0.768264
#
# Is Data White Noise: True
#
#
# ========================== (2020-09-01 12:13:23.174963)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (81, 4) (1, 4)
# (81, 4) (1, 4)
# (79, 4) (1, 4)
#
#
# ========================== (2020-09-01 12:13:23.181962)
# ========= NAIVE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      last   1.309084         []
# 1  1      last   0.575651         []
# 2  2      last   0.514092         []
#
#                                            All RMSEs  \
# 0  [[1.3090836993967807, 1.5116570412722945, 1.34...
# 1  [[0.5756510191046259, 0.8723064569251162, 0.77...
# 2  [[0.5140918075121166, 0.680195528305364, 0.545...
#
#                        All Types             Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4)
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4)
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4)
#
#
# ========================== (2020-09-01 12:13:23.663545)
# ====== Multivar P0 =======
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  6.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================== (2020-09-01 12:19:39.780252)
# ==== Multivar P0+Sim =====
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  5.7min finished
# ========================== (2020-09-01 12:25:24.757303)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:25:24.767301)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 3 ============
# ==========================
#
#
#
# =========================== (2020-09-01 12:25:24.767301)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ==== THE BARREL HOUSE =====
# ============ 3 ============
# ===========================
#
#
#
# ========================== (2020-09-01 12:25:24.771301)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'GENTLEMAN JACK WHSKY OL 750M', '2': 'GENTLEMAN JACK WHSKY 6PK 1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '2']
# % of weeks without a purchase: 46.34146341463415
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '2']
# % of weeks without a purchase: 52.4390243902439
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY 6PK 1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '1']
# % of weeks without a purchase: 33.75
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: GENTLEMAN JACK WHSKY 6PK 1L
#
#
# ========================== (2020-09-01 12:25:59.142607)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (81, 4) (1, 4)
# (81, 4) (1, 4)
# (79, 4) (1, 4)
#
#
# ========================== (2020-09-01 12:25:59.148605)
# ===== NAIVE FORECAST =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:25:59.161605)
# ========== MASK ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
# Mask: [False, False, False]
#
#
# ========================== (2020-09-01 12:25:59.163607)
# ========= SPACE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:25:59.169606)
# ======= Test Index =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:25:59.170605)
# ==== GET FUNCTION P0 =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ====================================== (2020-09-01 12:25:59.171604)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ========== THE BARREL HOUSE ==========
# ======================================
#
#
#
# ========================== (2020-09-01 12:25:59.359606)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:25:59.365606)
# ===== OPTIMIZING P0 ======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:27:53.261226)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ============================= (2020-09-01 12:27:53.405768)
# ==== GET FUNCTION P0+Sim ====
# ===== THE BARREL HOUSE ======
# =============================
#
#
#
# ========================================== (2020-09-01 12:27:53.407292)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ============ THE BARREL HOUSE ============
# ==========================================
#
#
#
# ========================== (2020-09-01 12:27:53.529913)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# =========================== (2020-09-01 12:27:53.535913)
# ==== OPTIMIZING P0+Sim ====
# ==== THE BARREL HOUSE =====
# ===========================
#
#
#
# ========================== (2020-09-01 12:29:23.903522)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:29:24.077520)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ============================ (2020-09-01 12:29:24.085521)
# ====== Products List  ======
# ===== SUP PREM WHISKEY =====
# ==== WESTERN BEV LIQ TX ====
# ============================
#
#
#
# ============================ (2020-09-01 12:29:27.811519)
# ========= AUTO-TS ==========
# ===== SUP PREM WHISKEY =====
# ==== WESTERN BEV LIQ TX ====
# ============ 1 =============
# ============================
#
#
#
# ============================ (2020-09-01 12:29:27.812520)
# ========= GET DATA =========
# ==== WESTERN BEV LIQ TX ====
# ============================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1.75L', '1': 'JACK DANIELS BLK WHSKY  750M', '2': 'JACK DANIELS BLK WHSKY  1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '2']
# % of weeks without a purchase: 17.5
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '2']
# % of weeks without a purchase: 13.414634146341465
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '1']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY  1L
#
#
# ============================ (2020-09-01 12:29:59.167039)
# ======= WHITE NOISE ========
# ==== WESTERN BEV LIQ TX ====
# ============================
#
#        lb_stat      lb_pvalue
# 12  230.533574   1.544168e-42
# 24  440.855949   2.925831e-78
# 48  689.590939  1.731957e-114
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   77.815839  1.075181e-11
# 24  136.909527  8.579214e-18
# 48  201.387337  1.088599e-20
#
# Is Data White Noise: False
#       lb_stat     lb_pvalue
# 12  59.487140  2.799051e-08
# 24  75.433349  3.193517e-07
# 48  84.194254  9.632108e-04
#
# Is Data White Noise: False
#
#
# ============================ (2020-09-01 12:29:59.185040)
# ======== TEST/TRAIN ========
# ==== WESTERN BEV LIQ TX ====
# ============================
#
# (79, 4) (1, 4)
# (81, 4) (1, 4)
# (82, 4) (1, 4)
#
#
# ============================ (2020-09-01 12:29:59.190040)
# ========== NAIVE ===========
# ==== WESTERN BEV LIQ TX ====
# ============================
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   1.192388         []
# 1  1      mean   0.706690         []
# 2  2      mean   0.083096         []
#
#                                            All RMSEs  \
# 0  [[1.209792431243374, 1.8312196882995284, 1.192...
# 1  [[1.1305923379415006, 1.2624589917738127, 0.70...
# 2  [[0.12236276035592478, 0.0844886828891572, 0.0...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ============================ (2020-09-01 12:29:59.604397)
# ======= Multivar P0 ========
# ==== WESTERN BEV LIQ TX ====
# ============================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  5.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ============================ (2020-09-01 12:35:11.324202)
# ===== Multivar P0+Sim ======
# ==== WESTERN BEV LIQ TX ====
# ============================
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  6.0min finished
# ============================ (2020-09-01 12:41:09.085702)
# ======== COMPLETED =========
# ==== WESTERN BEV LIQ TX ====
# ============================
#
#
#
# ============================ (2020-09-01 12:41:09.093703)
# ======== OPTIMIZER =========
# ...
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ======================= (2020-09-01 13:44:15.351678)
# ==== OPTIMIZING P0 ====
# ======== SPECS ========
# =======================
#
#
#
# =================== (2020-09-01 13:46:24.715918)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ============================= (2020-09-01 13:46:24.851536)
# ==== GET FUNCTION P0+Sim ====
# =========== SPECS ===========
# =============================
#
#
#
# ========================================== (2020-09-01 13:46:24.852538)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ================= SPECS ==================
# ==========================================
#
#
#
# =================== (2020-09-01 13:46:25.087059)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =========================== (2020-09-01 13:46:25.099061)
# ==== OPTIMIZING P0+Sim ====
# ========== SPECS ==========
# ===========================
#
#
#
# =================== (2020-09-01 13:47:48.061477)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =================== (2020-09-01 13:47:48.335478)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ========================== (2020-09-01 13:47:48.345476)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ========= SPECS ==========
# =========== 2 ============
# ==========================
#
#
#
# ================== (2020-09-01 13:47:48.346478)
# ==== GET DATA ====
# ===== SPECS ======
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 8.433734939759036
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 2.4096385542168677
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
#
#
# ===================== (2020-09-01 13:48:29.223455)
# ==== WHITE NOISE ====
# ======= SPECS =======
# =====================
#
#       lb_stat  lb_pvalue
# 12  15.010561   0.240859
# 24  26.255626   0.340323
# 48  46.813983   0.521457
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12  28.602170   0.004512
# 24  40.565661   0.018579
# 48  53.111411   0.283742
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12  26.462991   0.009225
# 24  37.259357   0.041220
# 48  54.606396   0.237935
#
# Is Data White Noise: True
#
#
# ==================== (2020-09-01 13:48:29.244456)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (82, 4) (1, 4)
# (82, 4) (1, 4)
# (82, 4) (1, 4)
#
#
# =============== (2020-09-01 13:48:29.251453)
# ==== NAIVE ====
# ==== SPECS ====
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.033192         []
# 1  1      mean   0.118510         []
# 2  2      mean   0.224583         []
#
#                                            All RMSEs  \
# 0  [[0.0935827577097994, 0.10896925774528339, 0.0...
# 1  [[0.17264955504702825, 0.17422646327023725, 0....
# 2  [[0.4363032505606732, 0.3550157822095886, 0.22...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-01 13:48:29.740454)
# ==== Multivar P0 ====
# ======= SPECS =======
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  6.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-01 13:54:34.792492)
# ==== Multivar P0+Sim ====
# ========= SPECS =========
# =========================
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  4.0min finished
# =================== (2020-09-01 13:58:33.062648)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ========================== (2020-09-01 13:58:33.070648)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ========= SPECS ==========
# =========== 2 ============
# ==========================
#
#
#
# =========================== (2020-09-01 13:58:33.071648)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ========== SPECS ==========
# ============ 2 ============
# ===========================
#
#
#
# ================== (2020-09-01 13:58:33.074646)
# ==== GET DATA ====
# ===== SPECS ======
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 8.433734939759036
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 2.4096385542168677
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
#
#
# ==================== (2020-09-01 13:58:56.823090)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (82, 4) (1, 4)
# (82, 4) (1, 4)
# (82, 4) (1, 4)
#
#
# ======================== (2020-09-01 13:58:56.827087)
# ==== NAIVE FORECAST ====
# ======== SPECS =========
# ========================
#
#
#
# =============== (2020-09-01 13:58:56.836091)
# ==== MASK =====
# ==== SPECS ====
# ===============
#
# Mask: [False, False, False]
#
#
# =============== (2020-09-01 13:58:56.838092)
# ==== SPACE ====
# ==== SPECS ====
# ===============
#
#
#
# ==================== (2020-09-01 13:58:56.842091)
# ==== Test Index ====
# ====== SPECS =======
# ====================
#
#
#
# ========================= (2020-09-01 13:58:56.843092)
# ==== GET FUNCTION P0 ====
# ========= SPECS =========
# =========================
#
#
#
# ====================================== (2020-09-01 13:58:56.843092)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# =============== SPECS ================
# ======================================
#
#
#
# =================== (2020-09-01 13:58:56.927088)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ======================= (2020-09-01 13:58:56.931089)
# ==== OPTIMIZING P0 ====
# ======== SPECS ========
# =======================
#
#
#
# =================== (2020-09-01 13:59:44.122621)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ============================= (2020-09-01 13:59:44.237621)
# ==== GET FUNCTION P0+Sim ====
# =========== SPECS ===========
# =============================
#
#
#
# ========================================== (2020-09-01 13:59:44.238621)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ================= SPECS ==================
# ==========================================
#
#
#
# =================== (2020-09-01 13:59:44.312621)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =========================== (2020-09-01 13:59:44.321626)
# ==== OPTIMIZING P0+Sim ====
# ========== SPECS ==========
# ===========================
#
#
#
# =================== (2020-09-01 14:00:32.400536)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =================== (2020-09-01 14:00:32.469534)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ========================== (2020-09-01 14:00:32.476535)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ========= SPECS ==========
# =========== 3 ============
# ==========================
#
#
#
# ================== (2020-09-01 14:00:32.476535)
# ==== GET DATA ====
# ===== SPECS ======
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 8.536585365853659
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 2.4390243902439024
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
#
#
# ===================== (2020-09-01 14:00:59.985573)
# ==== WHITE NOISE ====
# ======= SPECS =======
# =====================
#
#       lb_stat  lb_pvalue
# 12  14.591506   0.264539
# 24  25.708961   0.368096
# 48  45.847359   0.561475
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12  28.056071   0.005429
# 24  39.797909   0.022480
# 48  52.199800   0.314062
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12  26.241054   0.009922
# 24  37.090548   0.042858
# 48  54.361071   0.245108
#
# Is Data White Noise: True
#
#
# ==================== (2020-09-01 14:00:59.997574)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (81, 4) (1, 4)
# (81, 4) (1, 4)
# (81, 4) (1, 4)
#
#
# =============== (2020-09-01 14:01:00.000572)
# ==== NAIVE ====
# ==== SPECS ====
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.051513         []
# 1  1      mean   0.109428         []
# 2  2      mean   0.221377         []
#
#                                            All RMSEs  \
# 0  [[0.12459174747365168, 0.13927072207458754, 0....
# 1  [[0.18390429323643792, 0.17762873456667566, 0....
# 2  [[0.4245652552570759, 0.3288519908859398, 0.22...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-01 14:01:00.353575)
# ==== Multivar P0 ====
# ======= SPECS =======
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  3.6min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-01 14:04:38.513552)
# ==== Multivar P0+Sim ====
# ========= SPECS =========
# =========================
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  3.7min finished
# =================== (2020-09-01 14:08:19.847927)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ========================== (2020-09-01 14:08:19.855924)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ========= SPECS ==========
# =========== 3 ============
# ==========================
#
#
#
# =========================== (2020-09-01 14:08:19.855924)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ========== SPECS ==========
# ============ 3 ============
# ===========================
#
#
#
# ================== (2020-09-01 14:08:19.858924)
# ==== GET DATA ====
# ===== SPECS ======
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 8.536585365853659
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 2.4390243902439024
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
#
#
# ==================== (2020-09-01 14:08:48.117922)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (81, 4) (1, 4)
# (81, 4) (1, 4)
# (81, 4) (1, 4)
#
#
# ======================== (2020-09-01 14:08:48.124925)
# ==== NAIVE FORECAST ====
# ======== SPECS =========
# ========================
#
#
#
# =============== (2020-09-01 14:08:48.135921)
# ==== MASK =====
# ==== SPECS ====
# ===============
#
# Mask: [False, False, False]
#
#
# =============== (2020-09-01 14:08:48.138923)
# ==== SPACE ====
# ==== SPECS ====
# ===============
#
#
#
# ==================== (2020-09-01 14:08:48.142921)
# ==== Test Index ====
# ====== SPECS =======
# ====================
#
#
#
# ========================= (2020-09-01 14:08:48.142921)
# ==== GET FUNCTION P0 ====
# ========= SPECS =========
# =========================
#
#
#
# ====================================== (2020-09-01 14:08:48.143922)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# =============== SPECS ================
# ======================================
#
#
#
# =================== (2020-09-01 14:08:48.234924)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ======================= (2020-09-01 14:08:48.239922)
# ==== OPTIMIZING P0 ====
# ======== SPECS ========
# =======================
#
#
#
# =================== (2020-09-01 14:09:40.675924)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ============================= (2020-09-01 14:09:40.776922)
# ==== GET FUNCTION P0+Sim ====
# =========== SPECS ===========
# =============================
#
#
#
# ========================================== (2020-09-01 14:09:40.777922)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ================= SPECS ==================
# ==========================================
#
#
#
# =================== (2020-09-01 14:09:40.858923)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =========================== (2020-09-01 14:09:40.865923)
# ==== OPTIMIZING P0+Sim ====
# ========== SPECS ==========
# ===========================
#
#
#
# =================== (2020-09-01 14:10:27.486380)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =================== (2020-09-01 14:10:27.561377)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ========================== (2020-09-01 14:10:27.576379)
# ==== Saving to PICKLE ====
# ==== SUP PREM WHISKEY ====
# ==========================
#
# Pickle File  full_models_SUP PREM WHISKEY_Prod3_Sim1_Per123.pkl  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns
# Pickle File  full_opt_SUP PREM WHISKEY_Prod3_Sim1_Per123.pkl  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns
#
#
# ========================== (2020-09-01 14:10:27.719378)
# ==== Saving to EXCEL =====
# ==== SUP PREM WHISKEY ====
# ==========================
#
# EXCEL File  Output_SUP PREM WHISKEY_Prod3_Sim1_Per123.xlsx  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns

# %% [markdown]
# # Print out

# %% [markdown]
# ## Models

# %%
full_models[outputColsModels]
# Out:
#           Chain Master                        Product  Period to Last  \
# 1                       JACK DANIELS BLK WHSKY  1.75L               1
# 4                       JACK DANIELS BLK WHSKY  1.75L               2
# 7                       JACK DANIELS BLK WHSKY  1.75L               3
# 0                          JACK DANIELS BLK WHSKY  1L               1
# 3                          JACK DANIELS BLK WHSKY  1L               2
# 6                          JACK DANIELS BLK WHSKY  1L               3
# 2                        JACK DANIELS BLK WHSKY  750M               1
# 5                        JACK DANIELS BLK WHSKY  750M               2
# 8                        JACK DANIELS BLK WHSKY  750M               3
# 28               SPECS  JACK DANIELS BLK WHSKY  1.75L               1
# 31               SPECS  JACK DANIELS BLK WHSKY  1.75L               2
# 34               SPECS  JACK DANIELS BLK WHSKY  1.75L               3
# 27               SPECS     JACK DANIELS BLK WHSKY  1L               1
# 30               SPECS     JACK DANIELS BLK WHSKY  1L               2
# 33               SPECS     JACK DANIELS BLK WHSKY  1L               3
# 29               SPECS   JACK DANIELS BLK WHSKY  750M               1
# 32               SPECS   JACK DANIELS BLK WHSKY  750M               2
# 35               SPECS   JACK DANIELS BLK WHSKY  750M               3
# 11    THE BARREL HOUSE    GENTLEMAN JACK WHSKY 6PK 1L               1
# 14    THE BARREL HOUSE    GENTLEMAN JACK WHSKY 6PK 1L               2
# 17    THE BARREL HOUSE    GENTLEMAN JACK WHSKY 6PK 1L               3
# 10    THE BARREL HOUSE   GENTLEMAN JACK WHSKY OL 750M               1
# 13    THE BARREL HOUSE   GENTLEMAN JACK WHSKY OL 750M               2
# 16    THE BARREL HOUSE   GENTLEMAN JACK WHSKY OL 750M               3
# 9     THE BARREL HOUSE     JACK DANIELS BLK WHSKY  1L               1
# 12    THE BARREL HOUSE     JACK DANIELS BLK WHSKY  1L               2
# 15    THE BARREL HOUSE     JACK DANIELS BLK WHSKY  1L               3
# 18  WESTERN BEV LIQ TX  JACK DANIELS BLK WHSKY  1.75L               1
# 21  WESTERN BEV LIQ TX  JACK DANIELS BLK WHSKY  1.75L               2
# 24  WESTERN BEV LIQ TX  JACK DANIELS BLK WHSKY  1.75L               3
# 20  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  1L               1
# 23  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  1L               2
# 26  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  1L               3
# 19  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY  750M               1
# 22  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY  750M               2
# 25  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY  750M               3
#
#     White Noise Naive Best Type  Naive Best RMSE P0 Best Model Name  \
# 1         False            last         0.324455       auto_SARIMAX
# 4         False            mean         0.323943       auto_SARIMAX
# 7         False            mean         0.319180       auto_SARIMAX
# 0          True            mean         0.043169            SARIMAX
# 3          True            mean         0.021557                 ML
# 6          True            mean         0.033917                 ML
# 2         False            mean         0.427990            SARIMAX
# 5         False            mean         0.373199            SARIMAX
# 8         False            mean         0.373056            SARIMAX
# 28         True            mean         0.159196            SARIMAX
# 31         True            mean         0.118510            SARIMAX
# 34         True            mean         0.109428            SARIMAX
# 27         True            mean         0.060885            SARIMAX
# 30         True            mean         0.033192                 ML
# 33         True            mean         0.051513                 ML
# 29         True            mean         0.276661       auto_SARIMAX
# 32         True            mean         0.224583                 ML
# 35         True            mean         0.221377                 ML
# 11         True            mean         0.611153                 ML
# 14         True            mean         0.532525                 ML
# 17         True            last         0.514092                 ML
# 10        False            last         0.508452                 ML
# 13        False            last         0.397118                 ML
# 16        False            last         0.575651       auto_SARIMAX
# 9         False            mean         1.149908                 ML
# 12        False            last         1.279671                 ML
# 15        False            last         1.309084                 ML
# 18        False            mean         1.192388       auto_SARIMAX
# 21        False            mean         1.152468       auto_SARIMAX
# 24        False            last         1.110996       auto_SARIMAX
# 20        False            mean         0.083096                 ML
# 23        False            mean         0.065297                 ML
# 26        False            mean         0.056411            SARIMAX
# 19        False            mean         0.706690            SARIMAX
# 22        False            mean         0.620501            SARIMAX
# 25        False            mean         0.664711                 ML
#
#     P0 Best Model RMSE P0+Sim Best Model Name  P0+Sim Best Model RMSE
# 1             0.243913           auto_SARIMAX                0.183695
# 4             0.219089           auto_SARIMAX                0.161965
# 7             0.231060           auto_SARIMAX                0.188390
# 0             0.028845                SARIMAX                0.028235
# 3             0.034618                     ML                0.030985
# 6             0.057793                     ML                0.051656
# 2             0.260258           auto_SARIMAX                0.278248
# 5             0.276076                SARIMAX                0.285331
# 8             0.294087                SARIMAX                0.216242
# 28            0.106995                SARIMAX                0.129265
# 31            0.095943                SARIMAX                0.118246
# 34            0.097419                SARIMAX                0.109773
# 27            0.036516                     ML                0.039430
# 30            0.048617                     ML                0.051806
# 33            0.078627                     ML                0.078344
# 29            0.257020                     ML                0.263908
# 32            0.247969                SARIMAX                0.244295
# 35            0.272304                SARIMAX                0.245099
# 11            0.191544                     ML                0.191544
# 14            0.210643                     ML                0.210643
# 17            0.238877                     ML                0.248062
# 10            0.615271                     ML                0.615231
# 13            0.614912                     ML                0.614905
# 16            0.752658                     ML                0.741559
# 9             0.722963                     ML                0.798112
# 12            0.733968                     ML                0.802404
# 15            0.634989                     ML                0.700241
# 18            0.737526                Prophet                0.739690
# 21            0.791896                Prophet                0.832619
# 24            0.654468           auto_SARIMAX                0.746904
# 20            0.099956           auto_SARIMAX                0.094864
# 23            0.108532           auto_SARIMAX                0.099369
# 26            0.111910                SARIMAX                0.108810
# 19            0.577988           auto_SARIMAX                0.624688
# 22            0.580915                Prophet                0.607293
# 25            0.638930                Prophet                0.606517

# %% [markdown]
# ## Optimizer

# %% [markdown]
# ### Summary by Chain

# %%
full_chain_summary
# Out:
#          Chain Master  P0 Non-Opt Revenue  P0 Opt Revenue  P0 Opt Diff  \
# 0                                288801.0        285207.0      -3594.0
# 1               SPECS            208931.0        211882.0       2951.0
# 2    THE BARREL HOUSE              2357.0          2371.0         14.0
# 3  WESTERN BEV LIQ TX            103370.0        116096.0      12726.0
#
#    P0 Opt Diff Ratio  P0+Sim Non-Opt Revenue  P0+Sim Opt Revenue  \
# 0           0.987555                300681.0            390023.0
# 1           1.014124                203039.0            277611.0
# 2           1.005940                  2392.0              2404.0
# 3           1.123111                 89347.0            934714.0
#
#    P0+Sim Opt Diff  P0+Sim Opt Diff Ratio
# 0          89342.0               1.297132
# 1          74572.0               1.367279
# 2             12.0               1.005017
# 3         845367.0              10.461616

# %%
print("WRITE this value in the summary table in Git hub --->",round(full_chain_summary[full_chain_summary['Chain Master']=='']['P0+Sim Opt Diff Ratio'].item(),4))
# Out:
# WRITE this value in the summary table in Git hub ---> 1.2971

# %% [markdown]
# Link to the Git Hub Summary Table: https://github.com/ngupta23/msds_capstone/issues/84

# %% [markdown]
# ### Summary by Chain and Product

# %%
full_summary
# Out:
#           Chain Master                        Product  P0 Non-Opt Revenue  \
# 0                       JACK DANIELS BLK WHSKY  1.75L             78808.0
# 1                          JACK DANIELS BLK WHSKY  1L            162183.0
# 2                        JACK DANIELS BLK WHSKY  750M             47810.0
# 3                SPECS  JACK DANIELS BLK WHSKY  1.75L             31102.0
# 4                SPECS     JACK DANIELS BLK WHSKY  1L            163171.0
# 5                SPECS   JACK DANIELS BLK WHSKY  750M             14658.0
# 6     THE BARREL HOUSE    GENTLEMAN JACK WHSKY 6PK 1L              1157.0
# 7     THE BARREL HOUSE   GENTLEMAN JACK WHSKY OL 750M               334.0
# 8     THE BARREL HOUSE     JACK DANIELS BLK WHSKY  1L               866.0
# 9   WESTERN BEV LIQ TX  JACK DANIELS BLK WHSKY  1.75L             18820.0
# 10  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  1L             48563.0
# 11  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY  750M             35987.0
#
#     P0 Opt Revenue  P0 Opt Diff  P0 Opt Diff Ratio  P0+Sim Non-Opt Revenue  \
# 0          79490.0        682.0           1.008654                 90240.0
# 1         159256.0      -2927.0           0.981952                161504.0
# 2          46461.0      -1349.0           0.971784                 48937.0
# 3          28542.0      -2560.0           0.917690                 29714.0
# 4         162670.0       -501.0           0.996930                158041.0
# 5          20670.0       6012.0           1.410151                 15284.0
# 6           1181.0         24.0           1.020743                  1321.0
# 7            340.0          6.0           1.017964                   200.0
# 8            850.0        -16.0           0.981524                   871.0
# 9          30927.0      12107.0           1.643305                 13371.0
# 10         48459.0       -104.0           0.997858                 49276.0
# 11         36710.0        723.0           1.020091                 26700.0
#
#     P0+Sim Opt Revenue  P0+Sim Opt Diff  P0+Sim Opt Diff Ratio
# 0             178456.0          88216.0               1.977571
# 1             162706.0           1202.0               1.007443
# 2              48861.0            -76.0               0.998447
# 3             115430.0          85716.0               3.884701
# 4             149047.0          -8994.0               0.943091
# 5              13134.0          -2150.0               0.859330
# 6               1344.0             23.0               1.017411
# 7                208.0              8.0               1.040000
# 8                852.0            -19.0               0.978186
# 9             117873.0         104502.0               8.815571
# 10             56033.0           6757.0               1.137126
# 11            760808.0         734108.0              28.494682

# %% [markdown]
# ### P0 Optimizer

# %%
full_opt[outputColsOptP0]
# Out:
#           Chain Master                        Product  Period to Last  \
# 1                       JACK DANIELS BLK WHSKY  1.75L               1
# 4                       JACK DANIELS BLK WHSKY  1.75L               2
# 7                       JACK DANIELS BLK WHSKY  1.75L               3
# 0                          JACK DANIELS BLK WHSKY  1L               1
# 3                          JACK DANIELS BLK WHSKY  1L               2
# 6                          JACK DANIELS BLK WHSKY  1L               3
# 2                        JACK DANIELS BLK WHSKY  750M               1
# 5                        JACK DANIELS BLK WHSKY  750M               2
# 8                        JACK DANIELS BLK WHSKY  750M               3
# 28               SPECS  JACK DANIELS BLK WHSKY  1.75L               1
# 31               SPECS  JACK DANIELS BLK WHSKY  1.75L               2
# 34               SPECS  JACK DANIELS BLK WHSKY  1.75L               3
# 27               SPECS     JACK DANIELS BLK WHSKY  1L               1
# 30               SPECS     JACK DANIELS BLK WHSKY  1L               2
# 33               SPECS     JACK DANIELS BLK WHSKY  1L               3
# 29               SPECS   JACK DANIELS BLK WHSKY  750M               1
# 32               SPECS   JACK DANIELS BLK WHSKY  750M               2
# 35               SPECS   JACK DANIELS BLK WHSKY  750M               3
# 11    THE BARREL HOUSE    GENTLEMAN JACK WHSKY 6PK 1L               1
# 14    THE BARREL HOUSE    GENTLEMAN JACK WHSKY 6PK 1L               2
# 17    THE BARREL HOUSE    GENTLEMAN JACK WHSKY 6PK 1L               3
# 10    THE BARREL HOUSE   GENTLEMAN JACK WHSKY OL 750M               1
# 13    THE BARREL HOUSE   GENTLEMAN JACK WHSKY OL 750M               2
# 16    THE BARREL HOUSE   GENTLEMAN JACK WHSKY OL 750M               3
# 9     THE BARREL HOUSE     JACK DANIELS BLK WHSKY  1L               1
# 12    THE BARREL HOUSE     JACK DANIELS BLK WHSKY  1L               2
# 15    THE BARREL HOUSE     JACK DANIELS BLK WHSKY  1L               3
# 18  WESTERN BEV LIQ TX  JACK DANIELS BLK WHSKY  1.75L               1
# 21  WESTERN BEV LIQ TX  JACK DANIELS BLK WHSKY  1.75L               2
# 24  WESTERN BEV LIQ TX  JACK DANIELS BLK WHSKY  1.75L               3
# 20  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  1L               1
# 23  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  1L               2
# 26  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  1L               3
# 19  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY  750M               1
# 22  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY  750M               2
# 25  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY  750M               3
#
#     P0 Non-Opt Price  P0 Non-Opt Demand  P0 Non-Opt Revenue  \
# 1             185.65                224               41518
# 4             184.71                 91               16867
# 7             182.45                112               20423
# 0             229.81                310               71287
# 3             229.69                196               45027
# 6             230.09                199               45869
# 2             222.36                159               35308
# 5             222.36                 45               10052
# 8             222.36                 11                2450
# 28            185.59                 51                9481
# 31            184.56                 61               11168
# 34            184.94                 57               10453
# 27            229.53                239               54868
# 30            229.53                236               54108
# 33            229.53                236               54195
# 29            222.36                 20                4519
# 32            222.36                 23                5072
# 35            222.36                 23                5067
# 11            286.87                  1                 426
# 14            292.57                  2                 457
# 17            298.08                  1                 274
# 10            274.14                  0                  34
# 13            291.93                  0                  37
# 16            291.93                  1                 263
# 9             239.01                  1                 287
# 12            239.01                  1                 287
# 15            234.05                  1                 292
# 18            185.59                 96               17837
# 21            185.59                  4                 706
# 24            180.46                  2                 277
# 20            230.79                 59               13543
# 23            229.89                 59               13491
# 26            230.98                 93               21529
# 19            222.36                148               32964
# 22            222.36                  8                1783
# 25            222.36                  6                1240
#
#     P0 Non-Opt Chain Master Revenue  P0 Optimal Price  P0 Demand  P0 Revenue  \
# 1                            148113            184.51        218       40243
# 4                             71946            186.17         94       17552
# 7                             68742            186.18        117       21695
# 0                            148113            229.20        305       69999
# 3                             71946            225.75        196       44255
# 6                             68742            225.73        199       45002
# 2                            148113            219.15        153       33580
# 5                             71946            223.21         46       10321
# 8                             68742            223.21         11        2560
# 28                            68868            177.62         43        7589
# 31                            70348            183.63         59       10882
# 34                            69716            183.61         55       10071
# 27                            68868            229.44        238       54715
# 30                            70348            228.80        236       53934
# 33                            69716            228.80        236       54021
# 29                            68868            207.11         52       10736
# 32                            70348            217.89         23        4970
# 35                            69716            217.82         23        4964
# 11                              747            297.92          1         442
# 14                              781            297.92          2         465
# 17                              830            297.34          1         274
# 10                              747            294.64          0          37
# 13                              781            294.64          0          37
# 16                              830            302.61          1         266
# 9                               747            232.97          1         280
# 12                              781            232.97          1         280
# 15                              830            232.14          1         290
# 18                            64344            191.16        154       29368
# 21                            15980            190.38          5        1045
# 24                            23047            190.37          3         514
# 20                            64344            228.66         59       13418
# 23                            15980            230.85         59       13547
# 26                            23047            230.85         93       21494
# 19                            64344            217.14        156       33798
# 22                            15980            210.37          8        1740
# 25                            23047            210.18          6        1172
#
#     P0 Chain Master Revenue
# 1                    143822
# 4                     72128
# 7                     69257
# 0                    143822
# 3                     72128
# 6                     69257
# 2                    143822
# 5                     72128
# 8                     69257
# 28                    73040
# 31                    69787
# 34                    69056
# 27                    73040
# 30                    69787
# 33                    69056
# 29                    73040
# 32                    69787
# 35                    69056
# 11                      759
# 14                      782
# 17                      830
# 10                      759
# 13                      782
# 16                      830
# 9                       759
# 12                      782
# 15                      830
# 18                    76584
# 21                    16332
# 24                    23181
# 20                    76584
# 23                    16332
# 26                    23181
# 19                    76584
# 22                    16332
# 25                    23181

# %% [markdown]
# ### P0+Sim Optimizer

# %%
full_opt[outputColsOptP0Sim]
# Out:
#           Chain Master                        Product  Period to Last  \
# 1                       JACK DANIELS BLK WHSKY  1.75L               1
# 4                       JACK DANIELS BLK WHSKY  1.75L               2
# 7                       JACK DANIELS BLK WHSKY  1.75L               3
# 0                          JACK DANIELS BLK WHSKY  1L               1
# 3                          JACK DANIELS BLK WHSKY  1L               2
# 6                          JACK DANIELS BLK WHSKY  1L               3
# 2                        JACK DANIELS BLK WHSKY  750M               1
# 5                        JACK DANIELS BLK WHSKY  750M               2
# 8                        JACK DANIELS BLK WHSKY  750M               3
# 28               SPECS  JACK DANIELS BLK WHSKY  1.75L               1
# 31               SPECS  JACK DANIELS BLK WHSKY  1.75L               2
# 34               SPECS  JACK DANIELS BLK WHSKY  1.75L               3
# 27               SPECS     JACK DANIELS BLK WHSKY  1L               1
# 30               SPECS     JACK DANIELS BLK WHSKY  1L               2
# 33               SPECS     JACK DANIELS BLK WHSKY  1L               3
# 29               SPECS   JACK DANIELS BLK WHSKY  750M               1
# 32               SPECS   JACK DANIELS BLK WHSKY  750M               2
# 35               SPECS   JACK DANIELS BLK WHSKY  750M               3
# 11    THE BARREL HOUSE    GENTLEMAN JACK WHSKY 6PK 1L               1
# 14    THE BARREL HOUSE    GENTLEMAN JACK WHSKY 6PK 1L               2
# 17    THE BARREL HOUSE    GENTLEMAN JACK WHSKY 6PK 1L               3
# 10    THE BARREL HOUSE   GENTLEMAN JACK WHSKY OL 750M               1
# 13    THE BARREL HOUSE   GENTLEMAN JACK WHSKY OL 750M               2
# 16    THE BARREL HOUSE   GENTLEMAN JACK WHSKY OL 750M               3
# 9     THE BARREL HOUSE     JACK DANIELS BLK WHSKY  1L               1
# 12    THE BARREL HOUSE     JACK DANIELS BLK WHSKY  1L               2
# 15    THE BARREL HOUSE     JACK DANIELS BLK WHSKY  1L               3
# 18  WESTERN BEV LIQ TX  JACK DANIELS BLK WHSKY  1.75L               1
# 21  WESTERN BEV LIQ TX  JACK DANIELS BLK WHSKY  1.75L               2
# 24  WESTERN BEV LIQ TX  JACK DANIELS BLK WHSKY  1.75L               3
# 20  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  1L               1
# 23  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  1L               2
# 26  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  1L               3
# 19  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY  750M               1
# 22  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY  750M               2
# 25  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY  750M               3
#
#     P0+Sim Non-Opt Price  P0+Sim Non-Opt Demand  P0+Sim Non-Opt Revenue  \
# 1                 185.65                    186                   34602
# 4                 184.71                     98                   18109
# 7                 182.45                    206                   37529
# 0                 229.81                    307                   70608
# 3                 229.69                    196                   45027
# 6                 230.09                    199                   45869
# 2                 222.36                    133                   29472
# 5                 222.36                     35                    7848
# 8                 222.36                     52                   11617
# 28                185.59                     47                    8749
# 31                184.56                     65                   11947
# 34                184.94                     49                    9018
# 27                229.53                    246                   56559
# 30                229.53                    221                   50737
# 33                229.53                    221                   50745
# 29                222.36                     23                    5030
# 32                222.36                     29                    6357
# 35                222.36                     18                    3897
# 11                286.87                      1                     426
# 14                292.57                      2                     457
# 17                298.08                      1                     438
# 10                274.14                      0                      34
# 13                291.93                      0                      37
# 16                291.93                      0                     129
# 9                 239.01                      1                     287
# 12                239.01                      1                     287
# 15                234.05                      1                     297
# 18                185.59                     60                   11159
# 21                185.59                     11                    1955
# 24                180.46                      1                     257
# 20                230.79                     59                   13685
# 23                229.89                     61                   13973
# 26                230.98                     94                   21618
# 19                222.36                     21                    4775
# 22                222.36                     30                    6564
# 25                222.36                     69                   15361
#
#     P0+Sim Non-Opt Chain Master Revenue  P0+Sim Optimal Price  P0+Sim Demand  \
# 1                                134683                169.93            411
# 4                                 70984                169.85            220
# 7                                 95015                169.77            420
# 0                                134683                228.75            316
# 3                                 70984                228.75            196
# 6                                 95015                228.74            199
# 2                                134683                224.13            126
# 5                                 70984                224.14             38
# 8                                 95015                224.15             54
# 28                                70338                185.12             95
# 31                                69041                167.40            469
# 34                                63660                185.11            104
# 27                                70338                210.89            246
# 30                                69041                228.33            221
# 33                                63660                210.82            221
# 29                                70338                208.94             23
# 32                                69041                224.05             27
# 35                                63660                208.59             12
# 11                                  747                297.92              1
# 14                                  780                297.92              2
# 17                                  863                297.34              1
# 10                                  747                294.64              0
# 13                                  780                294.64              0
# 16                                  863                302.61              0
# 9                                   747                232.97              1
# 12                                  780                232.97              1
# 15                                  863                232.14              1
# 18                                29619                184.88            550
# 21                                22492                179.30             90
# 24                                37237                185.76              0
# 20                                29619                214.52             98
# 23                                22492                215.22             66
# 26                                37237                214.63             97
# 19                                29619                219.18             26
# 22                                22492                212.30            572
# 25                                37237                216.74           2924
#
#     P0+Sim Revenue  P0+Sim Chain Master Revenue
# 1            69785                       170214
# 4            37291                        90717
# 7            71380                       129093
# 0            72263                       170214
# 3            44842                        90717
# 6            45601                       129093
# 2            28166                       170214
# 5             8584                        90717
# 8            12111                       129093
# 28           17667                        74360
# 31           78544                       135002
# 34           19219                        68248
# 27           51967                        74360
# 30           50471                       135002
# 33           46609                        68248
# 29            4726                        74360
# 32            5987                       135002
# 35            2421                        68248
# 11             442                          759
# 14             465                          782
# 17             437                          865
# 10              37                          759
# 13              37                          782
# 16             134                          865
# 9              279                          759
# 12             279                          782
# 15             294                          865
# 18          101690                       128361
# 21           16156                       151915
# 24              27                       654439
# 20           21066                       128361
# 23           14242                       151915
# 26           20725                       654439
# 19            5605                       128361
# 22          121517                       151915
# 25          633686                       654439

# %% [markdown]
# ### Naive

# %%
full_opt[outputColsOptNaive]
# Out:
#           Chain Master                        Product  Period to Last  \
# 1                       JACK DANIELS BLK WHSKY  1.75L               1
# 4                       JACK DANIELS BLK WHSKY  1.75L               2
# 7                       JACK DANIELS BLK WHSKY  1.75L               3
# 0                          JACK DANIELS BLK WHSKY  1L               1
# 3                          JACK DANIELS BLK WHSKY  1L               2
# 6                          JACK DANIELS BLK WHSKY  1L               3
# 2                        JACK DANIELS BLK WHSKY  750M               1
# 5                        JACK DANIELS BLK WHSKY  750M               2
# 8                        JACK DANIELS BLK WHSKY  750M               3
# 28               SPECS  JACK DANIELS BLK WHSKY  1.75L               1
# 31               SPECS  JACK DANIELS BLK WHSKY  1.75L               2
# 34               SPECS  JACK DANIELS BLK WHSKY  1.75L               3
# 27               SPECS     JACK DANIELS BLK WHSKY  1L               1
# 30               SPECS     JACK DANIELS BLK WHSKY  1L               2
# 33               SPECS     JACK DANIELS BLK WHSKY  1L               3
# 29               SPECS   JACK DANIELS BLK WHSKY  750M               1
# 32               SPECS   JACK DANIELS BLK WHSKY  750M               2
# 35               SPECS   JACK DANIELS BLK WHSKY  750M               3
# 11    THE BARREL HOUSE    GENTLEMAN JACK WHSKY 6PK 1L               1
# 14    THE BARREL HOUSE    GENTLEMAN JACK WHSKY 6PK 1L               2
# 17    THE BARREL HOUSE    GENTLEMAN JACK WHSKY 6PK 1L               3
# 10    THE BARREL HOUSE   GENTLEMAN JACK WHSKY OL 750M               1
# 13    THE BARREL HOUSE   GENTLEMAN JACK WHSKY OL 750M               2
# 16    THE BARREL HOUSE   GENTLEMAN JACK WHSKY OL 750M               3
# 9     THE BARREL HOUSE     JACK DANIELS BLK WHSKY  1L               1
# 12    THE BARREL HOUSE     JACK DANIELS BLK WHSKY  1L               2
# 15    THE BARREL HOUSE     JACK DANIELS BLK WHSKY  1L               3
# 18  WESTERN BEV LIQ TX  JACK DANIELS BLK WHSKY  1.75L               1
# 21  WESTERN BEV LIQ TX  JACK DANIELS BLK WHSKY  1.75L               2
# 24  WESTERN BEV LIQ TX  JACK DANIELS BLK WHSKY  1.75L               3
# 20  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  1L               1
# 23  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  1L               2
# 26  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  1L               3
# 19  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY  750M               1
# 22  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY  750M               2
# 25  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY  750M               3
#
#     Actual Price  Actual Demand  Actual Revenue  Actual Chain Master Revenue  \
# 1     185.650112         389.61        72331.14                    257764.62
# 4     184.710623          40.95         7563.90                     83579.58
# 7     182.449915         263.25        48029.94                    125308.26
# 0     229.811232         589.19       135402.48                    257764.62
# 3     229.687258         301.91        69344.88                     83579.58
# 6     230.085045         316.54        72831.12                    125308.26
# 2     222.360000         225.00        50031.00                    257764.62
# 5     222.360000          30.00         6670.80                     83579.58
# 8     222.360000          20.00         4447.20                    125308.26
# 28    185.589744         176.67        32788.14                    157421.22
# 31    184.564103          35.10         6478.20                     64846.92
# 34    184.935385         117.00        21637.44                     79840.32
# 27    229.533835         476.14       109290.24                    157421.22
# 30    229.533835         240.73        55255.68                     64846.92
# 33    229.533835         238.07        54645.12                     79840.32
# 29    222.360000          69.00        15342.84                    157421.22
# 32    222.360000          14.00         3113.04                     64846.92
# 35    222.360000          16.00         3557.76                     79840.32
# 11    286.874200           4.69         1345.44                      5545.08
# 14    292.567164           1.34          392.04                      1027.80
# 17    298.080000           0.00            0.00                      4669.20
# 10    274.144615          13.00         3563.88                      5545.08
# 13    291.927711           0.00            0.00                      1027.80
# 16    291.927711           0.00            0.00                      4669.20
# 9     239.007519           2.66          635.76                      5545.08
# 12    239.007519           2.66          635.76                      1027.80
# 15    234.045113          19.95         4669.20                      4669.20
# 18    185.589744         210.60        39085.20                     99027.48
# 21    185.589744           5.85         1085.70                     18096.90
# 24    180.461538         146.25        26392.50                     40798.74
# 20    230.786122         110.39        25476.48                     99027.48
# 23    229.894737          58.52        13453.44                     18096.90
# 26    230.977444          58.52        13516.80                     40798.74
# 19    222.360000         155.00        34465.80                     99027.48
# 22    222.360000          16.00         3557.76                     18096.90
# 25    222.360000           4.00          889.44                     40798.74
#
#     Naive Prices  Naive Demand  Naive Revenue  Naive Chain Master Revenue
# 1     185.650112     40.950000    7602.372072                90321.715676
# 4     184.710623    157.916707   29168.893345               111933.270259
# 7     182.449915    156.616296   28574.629873               111524.523882
# 0     229.811232    292.610723   67245.230832                90321.715676
# 3     229.687258    292.497317   67182.906670               111933.270259
# 6     230.085045    292.200494   67230.963638               111524.523882
# 2     222.360000     69.590361   15474.112771                90321.715676
# 5     222.360000     70.073171   15581.470244               111933.270259
# 8     222.360000     70.691358   15718.930370               111524.523882
# 28    185.589744     44.962771    8344.629157                63726.848507
# 31    184.564103     45.083049    8320.712439                63666.511049
# 34    184.935385     44.195185    8173.253570                63483.779571
# 27    229.533835    217.722084   49974.584892                63726.848507
# 30    229.533835    217.441500   49910.181293                63666.511049
# 33    229.533835    217.186827   49851.725260                63483.779571
# 29    222.360000     24.319277    5407.634458                63726.848507
# 32    222.360000     24.445122    5435.617317                63666.511049
# 35    222.360000     24.549383    5458.800741                63483.779571
# 11    286.874200      1.169049     335.370107                 2534.360223
# 14    292.567164      1.166913     341.400281                 5109.600281
# 17    298.080000      0.000000       0.000000                 4669.200000
# 10    274.144615      0.000000       0.000000                 2534.360223
# 13    291.927711      0.000000       0.000000                 5109.600281
# 16    291.927711      0.000000       0.000000                 4669.200000
# 9     239.007519      9.200506    2198.990116                 2534.360223
# 12    239.007519     19.950000    4768.200000                 5109.600281
# 15    234.045113     19.950000    4669.200000                 4669.200000
# 18    185.589744    110.560063   20518.813797                44989.509807
# 21    185.589744    111.902500   20767.956282                45271.604932
# 24    180.461538      0.000000       0.000000                24704.176532
# 20    230.786122     66.489207   15344.786307                44989.509807
# 23    229.894737     66.587593   15308.137076                45271.604932
# 26    230.977444     66.688437   15403.524812                24704.176532
# 19    222.360000     41.041148    9125.909702                44989.509807
# 22    222.360000     41.354163    9195.511573                45271.604932
# 25    222.360000     41.827000    9300.651720                24704.176532
