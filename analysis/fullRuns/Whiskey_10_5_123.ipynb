# %% [markdown]
# # Init

# %%
# %load_ext autoreload
# %autoreload 2

# %%
print("CURRENT FOLDER:")
# %pwd
# Out:
# CURRENT FOLDER:
# 'c:\\max\\Google Drive Max\\Max Shared\\Master Data Science\\2020-05 Capstone A\\msds_capstone\\analysis\\fullRuns'

# %%
import os
import glob
import sys
sys.path.append(os.environ['DEV_AUTOTS'])
sys.path.append(os.environ['CAPSTONE_PYTHON_SOURCE'])
folder = os.environ['CAPSTONE_DATA']

# %%
## Sourcing the .py with all the code##
t='"'+os.environ['CAPSTONE_PYTHON_SOURCE']+'\\fullRun\\fullRun.py'+'"'
# %run -i $t
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# Running Auto Timeseries version: 0.0.24

# %% [markdown]
# # Parameters

# %%
#Parameters

ProdCats = ['SUP PREM WHISKEY']
TOP_PRODUCTS = 10  # How many products to consider in the category
TOP_SIMILAR = 5   # Get TOP_SIMILAR most similar products
RUN_PERIODS = [1,2,3] # this will run AutoTS and Optimzer for speicfic periods (1 = last, 2 = second to last)

CV_NUM = 10         # number of Cross Valudations  10
OPT_CALLS = 100     # number of calls for the optimizer process   100
OPT_RND_STARTS = 20 # number of random calls for the optimizer process  20

LOG_TRANSFORM = True # Take log of 9L cases to smooth out peaks and valleys
ZERO_ADDER = 0.1 

RESAMPLE_FREQ = 'M'


# Pricing changes every 4 weeks
if RESAMPLE_FREQ == 'M':    FORECAST_PERIOD = 1 #last 4 months as test 
if RESAMPLE_FREQ == 'W':    FORECAST_PERIOD = 4 
if RESAMPLE_FREQ == '2W':   FORECAST_PERIOD = 2 

# Seasonal Period
if RESAMPLE_FREQ == 'M':    SEASONAL_PERIOD = 12  # Yearly
if RESAMPLE_FREQ == 'W':    SEASONAL_PERIOD = 13 # Quarterly (we can also take yearly = 52, but SARIMAX becomes too slow)
if RESAMPLE_FREQ == '2W':   SEASONAL_PERIOD = 13 # This becomes problematic --> for quarterly, should we take 6 biweekly periods or 7 bi-weekly periods. Instead I just took half yearly period  

COL_TIME = 'WeekDate'
COL_PREDS = ['9L Cases'] #Demand
COL_PRICE= ['Dollar Sales per 9L Case'] #Price

# %% [markdown]
# # Full Run

# %%
dataRaw = loadDataset(version=4)
ProdCat = 'SUP PREM WHISKEY' #'ECONOMY VODKA'
ChainMasters =  [''] +  dataRaw['Chain Master'].unique().tolist() 
display(ChainMasters,ProdCats)
# Out:
# ['', 'THE BARREL HOUSE', 'WESTERN BEV LIQ TX', 'SPECS']
# ['SUP PREM WHISKEY']

# %%
(full_models,full_opt,full_summary,full_chain_summary)  = fullRun(ProdCat = ProdCat
                                                           ,ChainMasters = ChainMasters
                                                           ,dataRaw = dataRaw
                                                           ,savePKL=True
                                                           ,saveXLS=True)
# Out:
# ==================================================
# Parameters being used...
# ==================================================
# TOP_PRODUCTS = 10
# TOP_SIMILAR = 5
# RUN_PERIODS = [1, 2, 3]
# ProdCat: SUP PREM WHISKEY
# ChainMasters: ['', 'THE BARREL HOUSE', 'WESTERN BEV LIQ TX', 'SPECS']
#
#
# ========================== (2020-09-01 21:44:09.733163)
# ===== Products List  =====
# ==== SUP PREM WHISKEY ====
# ============  ============
# ==========================
#
#
#
# ========================== (2020-09-01 21:44:14.502371)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 1 ============
# ==========================
#
#
#
# ================== (2020-09-01 21:44:14.503369)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS BLK WHSKY SQ 375M', '4': 'GENTLEMAN JACK WHSKY OL 750M', '5': 'JACK DANIELS TENN HNY WHSKY  750M', '6': 'BUFFALO TRACE BOURBON  1L', '7': 'JACK DANIELS TENN HNY WHSKY  1L', '8': 'GENTLEMAN JACK WHSKY OL 1.75L', '9': 'JACK DANIELS BLK WHSKY FLSK PET 375M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '7', '1', '2', '5', '4']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '7', '5', '4']
# % of weeks without a purchase: 1.1904761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1', '5', '7', '4']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY SQ 375M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2', '1', '7', '5']
# % of weeks without a purchase: 44.047619047619044
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '2', '1', '7', '5']
# % of weeks without a purchase: 3.571428571428571
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['5', '0', '2', '7', '1', '4']
# % of weeks without a purchase: 1.1904761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: BUFFALO TRACE BOURBON  1L
# --------------------------------------------------
# Exogenous Price Columns: ['6', '0', '7', '2', '5', '1']
# % of weeks without a purchase: 13.333333333333334
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['7', '0', '5', '1', '2', '4']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['8', '0', '4', '1', '2', '7']
# % of weeks without a purchase: 1.1904761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY FLSK PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['9', '0', '2', '1', '7', '5']
# % of weeks without a purchase: 1.5873015873015872
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY SQ 375M
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: JACK DANIELS TENN HNY WHSKY  750M
# 	Product: BUFFALO TRACE BOURBON  1L
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 1.75L
# 	Product: JACK DANIELS BLK WHSKY FLSK PET 375M
#
#
# ===================== (2020-09-01 21:46:14.528462)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#       lb_stat  lb_pvalue
# 12  17.529696   0.130735
# 24  31.092108   0.151145
# 48  54.922995   0.228882
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12  115.750529  4.333814e-19
# 24  214.169023  1.845834e-32
# 48  308.098428  1.176533e-39
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   76.707883  1.745018e-11
# 24  131.122583  9.711501e-17
# 48  214.957410  5.416649e-23
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  236.849902  7.504140e-44
# 24  313.152234  3.733315e-52
# 48  457.992618  2.867236e-68
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   49.544022  1.679761e-06
# 24   97.459679  8.118215e-11
# 48  147.898014  4.125410e-12
#
# Is Data White Noise: False
#        lb_stat  lb_pvalue
# 12   49.490158   0.000002
# 24   66.726873   0.000007
# 48  103.663568   0.000006
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   53.512575  3.338512e-07
# 24   57.880975  1.264081e-04
# 48  133.606052  5.297457e-10
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  11.717530   0.468624
# 24  19.454209   0.727353
# 48  40.094964   0.784306
#
# Is Data White Noise: True
#        lb_stat  lb_pvalue
# 12   26.822642   0.008194
# 24   64.641977   0.000014
# 48  106.234137   0.000003
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  14.595563   0.264302
# 24  19.206363   0.740896
# 48  34.931252   0.920570
#
# Is Data White Noise: True
#
#
# ==================== (2020-09-01 21:46:14.567467)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (83, 8) (1, 8)
# (83, 8) (1, 8)
# (83, 8) (1, 8)
# (83, 8) (1, 8)
# (83, 8) (1, 8)
# (83, 8) (1, 8)
# (59, 8) (1, 8)
# (83, 8) (1, 8)
# (83, 8) (1, 8)
# (62, 8) (1, 8)
#
#
# =============== (2020-09-01 21:46:14.573438)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.043169         []
# 1  1      last   0.324455         []
# 2  2      mean   0.427990         []
# 3  3      mean   0.798321         []
# 4  4      mean   0.375053         []
# 5  5      mean   0.331289         []
# 6  6      mean   0.468984         []
# 7  7      mean   0.070339         []
# 8  8      mean   0.301564         []
# 9  9      mean   0.403528         []
#
#                                            All RMSEs  \
# 0  [[0.07143315389555474, 0.11332894033533458, 0....
# 1  [[0.3244545696539494, 0.4963154566538675, 0.34...
# 2  [[0.6704496090247218, 0.719929333484661, 0.427...
# 3  [[1.158356517777329, 1.1898741527817909, 0.798...
# 4  [[0.709250053526431, 0.5987185687692762, 0.375...
# 5  [[0.4266712461186655, 0.5029048428928397, 0.33...
# 6  [[0.6093647562879705, 0.49123690440583534, 0.4...
# 7  [[0.09312711586895281, 0.10078604303746068, 0....
# 8  [[0.5958099402689613, 0.412896919773484, 0.301...
# 9  [[0.6007898366828848, 0.7741138131853138, 0.40...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 4  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 5  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 6  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 7  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 8  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 9  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-01 21:46:15.334438)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of  10 | elapsed:  4.9min remaining:  3.3min
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  6.8min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-01 21:53:02.482702)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   6 out of  10 | elapsed:  5.3min remaining:  3.5min
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  7.4min finished
# =================== (2020-09-01 22:00:29.043127)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-01 22:00:29.046127)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 1 ============
# ==========================
#
#
#
# =========================== (2020-09-01 22:00:29.046127)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ============  =============
# ============ 1 ============
# ===========================
#
#
#
# ================== (2020-09-01 22:00:29.048127)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS BLK WHSKY SQ 375M', '4': 'GENTLEMAN JACK WHSKY OL 750M', '5': 'JACK DANIELS TENN HNY WHSKY  750M', '6': 'BUFFALO TRACE BOURBON  1L', '7': 'JACK DANIELS TENN HNY WHSKY  1L', '8': 'GENTLEMAN JACK WHSKY OL 1.75L', '9': 'JACK DANIELS BLK WHSKY FLSK PET 375M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '7', '1', '2', '5', '4']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '7', '5', '4']
# % of weeks without a purchase: 1.1904761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1', '5', '7', '4']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY SQ 375M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2', '1', '7', '5']
# % of weeks without a purchase: 44.047619047619044
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '2', '1', '7', '5']
# % of weeks without a purchase: 3.571428571428571
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['5', '0', '2', '7', '1', '4']
# % of weeks without a purchase: 1.1904761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: BUFFALO TRACE BOURBON  1L
# --------------------------------------------------
# Exogenous Price Columns: ['6', '0', '7', '2', '5', '1']
# % of weeks without a purchase: 13.333333333333334
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['7', '0', '5', '1', '2', '4']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['8', '0', '4', '1', '2', '7']
# % of weeks without a purchase: 1.1904761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY FLSK PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['9', '0', '2', '1', '7', '5']
# % of weeks without a purchase: 1.5873015873015872
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY SQ 375M
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: JACK DANIELS TENN HNY WHSKY  750M
# 	Product: BUFFALO TRACE BOURBON  1L
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 1.75L
# 	Product: JACK DANIELS BLK WHSKY FLSK PET 375M
#
#
# ==================== (2020-09-01 22:01:55.548074)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (83, 8) (1, 8)
# (83, 8) (1, 8)
# (83, 8) (1, 8)
# (83, 8) (1, 8)
# (83, 8) (1, 8)
# (83, 8) (1, 8)
# (59, 8) (1, 8)
# (83, 8) (1, 8)
# (83, 8) (1, 8)
# (62, 8) (1, 8)
#
#
# ======================== (2020-09-01 22:01:55.554074)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-01 22:01:55.582073)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False, False, False, False, False, False, False, False]
#
#
# =============== (2020-09-01 22:01:55.585077)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-01 22:01:55.600074)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-01 22:01:55.601074)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-01 22:01:55.602073)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-01 22:01:55.941105)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-01 22:01:55.946075)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-01 22:03:19.582885)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-01 22:03:19.900768)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-01 22:03:19.901769)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
# Building Forecast dataframe. Forecast Period = 1
#
#
# =================== (2020-09-01 22:03:21.846321)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-01 22:03:21.852351)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
#
#
# =================== (2020-09-01 22:07:24.015250)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
# Building Forecast dataframe. Forecast Period = 1
#
#
# =================== (2020-09-01 22:07:25.672253)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-01 22:07:25.678258)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 2 ============
# ==========================
#
#
#
# ================== (2020-09-01 22:07:25.679256)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS BLK WHSKY SQ 375M', '4': 'GENTLEMAN JACK WHSKY OL 750M', '5': 'JACK DANIELS TENN HNY WHSKY  750M', '6': 'BUFFALO TRACE BOURBON  1L', '7': 'JACK DANIELS TENN HNY WHSKY  1L', '8': 'GENTLEMAN JACK WHSKY OL 1.75L', '9': 'JACK DANIELS BLK WHSKY FLSK PET 375M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '7', '1', '2', '5', '4']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '7', '5', '4']
# % of weeks without a purchase: 1.2048192771084338
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1', '5', '7', '4']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY SQ 375M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2', '1', '7', '5']
# % of weeks without a purchase: 44.57831325301205
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '2', '1', '7', '5']
# % of weeks without a purchase: 3.614457831325301
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['5', '0', '2', '7', '1', '4']
# % of weeks without a purchase: 1.2048192771084338
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: BUFFALO TRACE BOURBON  1L
# --------------------------------------------------
# Exogenous Price Columns: ['6', '0', '7', '2', '5', '1']
# % of weeks without a purchase: 13.559322033898304
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['7', '0', '5', '1', '2', '4']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['8', '0', '4', '1', '2', '7']
# % of weeks without a purchase: 1.2048192771084338
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY FLSK PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['9', '0', '2', '1', '7', '5']
# % of weeks without a purchase: 1.6129032258064515
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY SQ 375M
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: JACK DANIELS TENN HNY WHSKY  750M
# 	Product: BUFFALO TRACE BOURBON  1L
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 1.75L
# 	Product: JACK DANIELS BLK WHSKY FLSK PET 375M
#
#
# ===================== (2020-09-01 22:08:40.942282)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#       lb_stat  lb_pvalue
# 12  17.074759   0.146807
# 24  30.689164   0.162949
# 48  53.509495   0.271059
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12  113.741522  1.085921e-18
# 24  210.737801  8.608130e-32
# 48  298.546482  6.801454e-38
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   73.433730  7.257343e-11
# 24  127.792143  3.888372e-16
# 48  208.580703  6.624266e-22
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  233.654157  3.467423e-43
# 24  301.956845  6.767463e-50
# 48  453.324573  2.340339e-67
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   48.137860  2.957627e-06
# 24   92.192775  6.231213e-10
# 48  138.240334  1.125182e-10
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  47.318792   0.000004
# 24  63.733683   0.000019
# 48  96.796590   0.000039
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   51.599658  7.298676e-07
# 24   55.912882  2.355085e-04
# 48  139.708451  6.851854e-11
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  10.917807   0.535976
# 24  20.241977   0.682935
# 48  41.607980   0.730700
#
# Is Data White Noise: True
#        lb_stat  lb_pvalue
# 12   24.962861   0.015000
# 24   58.642255   0.000099
# 48  100.303143   0.000015
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  13.749620   0.316982
# 24  18.272607   0.789588
# 48  35.753352   0.904199
#
# Is Data White Noise: True
#
#
# ==================== (2020-09-01 22:08:40.968281)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (82, 8) (1, 8)
# (82, 8) (1, 8)
# (82, 8) (1, 8)
# (82, 8) (1, 8)
# (82, 8) (1, 8)
# (82, 8) (1, 8)
# (58, 8) (1, 8)
# (82, 8) (1, 8)
# (82, 8) (1, 8)
# (61, 8) (1, 8)
#
#
# =============== (2020-09-01 22:08:40.971278)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID      Best Type  Best RMSE All Naives  \
# 0  0           mean   0.021557         []
# 1  1           mean   0.323943         []
# 2  2           mean   0.373199         []
# 3  3           mean   0.669609         []
# 4  4           mean   0.351197         []
# 5  5           mean   0.292008         []
# 6  6  seasonal_last   0.320055         []
# 7  7           mean   0.075939         []
# 8  8           mean   0.256755         []
# 9  9           mean   0.387178         []
#
#                                            All RMSEs  \
# 0  [[0.057546587491533165, 0.09126460007014617, 0...
# 1  [[0.3342880201030623, 0.4694144778845947, 0.32...
# 2  [[0.6160411345584191, 0.6054018321634664, 0.37...
# 3  [[1.1334719691929973, 1.0359040362506735, 0.66...
# 4  [[0.7597766030869607, 0.5171871911658599, 0.35...
# 5  [[0.36197066832875546, 0.45975278514505347, 0....
# 6  [[0.6447224099207042, 0.32005535677580016, 0.4...
# 7  [[0.07920528551520736, 0.134308122480242, 0.07...
# 8  [[0.615020633646095, 0.2903263592035776, 0.256...
# 9  [[0.6121709505188404, 0.6813556585054468, 0.38...
#
#                        All Types  \
# 0  [[last, seasonal_last, mean]]
# 1  [[last, seasonal_last, mean]]
# 2  [[last, seasonal_last, mean]]
# 3  [[last, seasonal_last, mean]]
# 4  [[last, seasonal_last, mean]]
# 5  [[last, seasonal_last, mean]]
# 6  [[last, seasonal_last, mean]]
# 7  [[last, seasonal_last, mean]]
# 8  [[last, seasonal_last, mean]]
# 9  [[last, seasonal_last, mean]]
#
#                                         Best Naive
# 0           NaiveForecaster(sp=4, strategy='mean')
# 1           NaiveForecaster(sp=4, strategy='mean')
# 2           NaiveForecaster(sp=4, strategy='mean')
# 3           NaiveForecaster(sp=4, strategy='mean')
# 4           NaiveForecaster(sp=4, strategy='mean')
# 5           NaiveForecaster(sp=4, strategy='mean')
# 6  NaiveForecaster(sp=4, strategy='seasonal_last')
# 7           NaiveForecaster(sp=4, strategy='mean')
# 8           NaiveForecaster(sp=4, strategy='mean')
# 9           NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-01 22:08:41.594278)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of  10 | elapsed:  4.5min remaining:  3.0min
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  6.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-01 22:14:42.457623)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   6 out of  10 | elapsed:  5.0min remaining:  3.3min
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  6.7min finished
# =================== (2020-09-01 22:21:24.956114)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-01 22:21:24.961115)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 2 ============
# ==========================
#
#
#
# =========================== (2020-09-01 22:21:24.961115)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ============  =============
# ============ 2 ============
# ===========================
#
#
#
# ================== (2020-09-01 22:21:24.963116)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS BLK WHSKY SQ 375M', '4': 'GENTLEMAN JACK WHSKY OL 750M', '5': 'JACK DANIELS TENN HNY WHSKY  750M', '6': 'BUFFALO TRACE BOURBON  1L', '7': 'JACK DANIELS TENN HNY WHSKY  1L', '8': 'GENTLEMAN JACK WHSKY OL 1.75L', '9': 'JACK DANIELS BLK WHSKY FLSK PET 375M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '7', '1', '2', '5', '4']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '7', '5', '4']
# % of weeks without a purchase: 1.2048192771084338
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1', '5', '7', '4']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY SQ 375M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2', '1', '7', '5']
# % of weeks without a purchase: 44.57831325301205
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '2', '1', '7', '5']
# % of weeks without a purchase: 3.614457831325301
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['5', '0', '2', '7', '1', '4']
# % of weeks without a purchase: 1.2048192771084338
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: BUFFALO TRACE BOURBON  1L
# --------------------------------------------------
# Exogenous Price Columns: ['6', '0', '7', '2', '5', '1']
# % of weeks without a purchase: 13.559322033898304
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['7', '0', '5', '1', '2', '4']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['8', '0', '4', '1', '2', '7']
# % of weeks without a purchase: 1.2048192771084338
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY FLSK PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['9', '0', '2', '1', '7', '5']
# % of weeks without a purchase: 1.6129032258064515
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY SQ 375M
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: JACK DANIELS TENN HNY WHSKY  750M
# 	Product: BUFFALO TRACE BOURBON  1L
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 1.75L
# 	Product: JACK DANIELS BLK WHSKY FLSK PET 375M
#
#
# ==================== (2020-09-01 22:22:40.167686)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (82, 8) (1, 8)
# (82, 8) (1, 8)
# (82, 8) (1, 8)
# (82, 8) (1, 8)
# (82, 8) (1, 8)
# (82, 8) (1, 8)
# (58, 8) (1, 8)
# (82, 8) (1, 8)
# (82, 8) (1, 8)
# (61, 8) (1, 8)
#
#
# ======================== (2020-09-01 22:22:40.174656)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-01 22:22:40.197686)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False, False, False, False, False, False, False, False]
#
#
# =============== (2020-09-01 22:22:40.200658)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-01 22:22:40.211688)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-01 22:22:40.212660)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-01 22:22:40.212660)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
# Building Forecast dataframe. Forecast Period = 1
#
#
# =================== (2020-09-01 22:22:41.752661)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-01 22:22:41.759658)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
#
#
# =================== (2020-09-01 22:26:04.276982)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
# Building Forecast dataframe. Forecast Period = 1
#
#
# ============================= (2020-09-01 22:26:06.008985)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-01 22:26:06.009992)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-01 22:26:06.297983)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-01 22:26:06.304985)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-01 22:27:25.483984)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-01 22:27:25.736982)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-01 22:27:25.745989)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 3 ============
# ==========================
#
#
#
# ================== (2020-09-01 22:27:25.745989)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS BLK WHSKY SQ 375M', '4': 'GENTLEMAN JACK WHSKY OL 750M', '5': 'JACK DANIELS TENN HNY WHSKY  750M', '6': 'BUFFALO TRACE BOURBON  1L', '7': 'JACK DANIELS TENN HNY WHSKY  1L', '8': 'GENTLEMAN JACK WHSKY OL 1.75L', '9': 'JACK DANIELS BLK WHSKY FLSK PET 375M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '7', '1', '2', '5', '4']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '7', '5', '4']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1', '5', '7', '4']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY SQ 375M
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2', '1', '7', '5']
# % of weeks without a purchase: 45.1219512195122
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '2', '1', '7', '5']
# % of weeks without a purchase: 3.6585365853658534
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['5', '0', '2', '7', '1', '4']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: BUFFALO TRACE BOURBON  1L
# --------------------------------------------------
# Exogenous Price Columns: ['6', '0', '7', '2', '5', '1']
# % of weeks without a purchase: 13.793103448275861
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['7', '0', '5', '1', '2', '4']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['8', '0', '4', '1', '2', '7']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY FLSK PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['9', '0', '2', '1', '7', '5']
# % of weeks without a purchase: 1.639344262295082
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY SQ 375M
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: JACK DANIELS TENN HNY WHSKY  750M
# 	Product: BUFFALO TRACE BOURBON  1L
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 1.75L
# 	Product: JACK DANIELS BLK WHSKY FLSK PET 375M
#
#
# ===================== (2020-09-01 22:28:40.850867)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#       lb_stat  lb_pvalue
# 12  16.492825   0.169692
# 24  29.613691   0.197887
# 48  52.235849   0.312831
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12  111.729571  2.720557e-18
# 24  207.460783  3.736074e-31
# 48  291.621010  1.270149e-36
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   72.023277  1.337193e-10
# 24  126.557635  6.490946e-16
# 48  206.128607  1.725436e-21
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  227.003218  8.357786e-42
# 24  289.400873  2.267177e-47
# 48  442.433742  3.108030e-65
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   47.219751  4.270383e-06
# 24   91.282625  8.832443e-10
# 48  138.156566  1.157395e-10
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  46.707130   0.000005
# 24  62.887857   0.000025
# 48  95.530579   0.000054
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   49.259046  1.884392e-06
# 24   53.659351  4.731507e-04
# 48  143.199378  2.086462e-11
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  10.610457   0.562564
# 24  19.712438   0.713006
# 48  41.138565   0.747869
#
# Is Data White Noise: True
#        lb_stat  lb_pvalue
# 12   24.750366   0.016051
# 24   59.872338   0.000067
# 48  103.008554   0.000007
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  13.796568   0.313887
# 24  18.756122   0.764867
# 48  37.128364   0.872240
#
# Is Data White Noise: True
#
#
# ==================== (2020-09-01 22:28:40.885895)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (81, 8) (1, 8)
# (81, 8) (1, 8)
# (81, 8) (1, 8)
# (81, 8) (1, 8)
# (81, 8) (1, 8)
# (81, 8) (1, 8)
# (57, 8) (1, 8)
# (81, 8) (1, 8)
# (81, 8) (1, 8)
# (60, 8) (1, 8)
#
#
# =============== (2020-09-01 22:28:40.888895)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID      Best Type  Best RMSE All Naives  \
# 0  0           mean   0.033917         []
# 1  1           mean   0.319180         []
# 2  2           mean   0.373056         []
# 3  3           mean   0.627867         []
# 4  4           mean   0.551268         []
# 5  5           mean   0.281831         []
# 6  6  seasonal_last   0.307464         []
# 7  7           last   0.074001         []
# 8  8           mean   0.328149         []
# 9  9           mean   0.378260         []
#
#                                            All RMSEs  \
# 0  [[0.0872048496772559, 0.1165490736094128, 0.03...
# 1  [[0.35617856342347604, 0.5500854364755055, 0.3...
# 2  [[0.556716035671863, 0.5707857245806156, 0.373...
# 3  [[1.0772290858881073, 1.0184226921157236, 0.62...
# 4  [[0.9705759316336084, 0.7296087664558061, 0.55...
# 5  [[0.3130277566239726, 0.4417526743478506, 0.28...
# 6  [[0.6321315049651657, 0.3074644518202616, 0.51...
# 7  [[0.07400100126212747, 0.13803073754777462, 0....
# 8  [[0.7345980219621095, 0.3942146318947128, 0.32...
# 9  [[0.6539674551718653, 0.6619491954986887, 0.37...
#
#                        All Types  \
# 0  [[last, seasonal_last, mean]]
# 1  [[last, seasonal_last, mean]]
# 2  [[last, seasonal_last, mean]]
# 3  [[last, seasonal_last, mean]]
# 4  [[last, seasonal_last, mean]]
# 5  [[last, seasonal_last, mean]]
# 6  [[last, seasonal_last, mean]]
# 7  [[last, seasonal_last, mean]]
# 8  [[last, seasonal_last, mean]]
# 9  [[last, seasonal_last, mean]]
#
#                                         Best Naive
# 0           NaiveForecaster(sp=4, strategy='mean')
# 1           NaiveForecaster(sp=4, strategy='mean')
# 2           NaiveForecaster(sp=4, strategy='mean')
# 3           NaiveForecaster(sp=4, strategy='mean')
# 4           NaiveForecaster(sp=4, strategy='mean')
# 5           NaiveForecaster(sp=4, strategy='mean')
# 6  NaiveForecaster(sp=4, strategy='seasonal_last')
# 7                            NaiveForecaster(sp=4)
# 8           NaiveForecaster(sp=4, strategy='mean')
# 9           NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-01 22:28:41.539867)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of  10 | elapsed:  4.3min remaining:  2.9min
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  5.9min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-01 22:34:34.773791)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# ...
#       lb_stat  lb_pvalue
# 12  13.223117   0.353034
# 24  24.203764   0.449996
# 48  33.984078   0.936958
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12   7.997747   0.785306
# 24  12.308672   0.976202
# 48  46.228586   0.545678
#
# Is Data White Noise: True
#        lb_stat      lb_pvalue
# 12  400.307561   3.257510e-78
# 24  496.736258   7.935608e-90
# 48  739.523098  1.236271e-124
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  23.650932   0.022681
# 24  33.931909   0.085887
# 48  49.252189   0.422826
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12  12.955833   0.372259
# 24  27.936131   0.262743
# 48  47.958747   0.474524
#
# Is Data White Noise: True
#
#
# ==================== (2020-09-02 01:48:18.334433)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (81, 8) (1, 8)
# (81, 8) (1, 8)
# (81, 8) (1, 8)
# (81, 8) (1, 8)
# (81, 8) (1, 8)
# (61, 8) (1, 8)
# (81, 8) (1, 8)
# (81, 8) (1, 8)
# (81, 8) (1, 8)
# (81, 8) (1, 8)
#
#
# =============== (2020-09-02 01:48:18.337433)
# ==== NAIVE ====
# ==== SPECS ====
# ===============
#
#   ID      Best Type  Best RMSE All Naives  \
# 0  0           mean   0.051513         []
# 1  1           mean   0.109428         []
# 2  2           mean   0.221377         []
# 3  3           mean   0.086918         []
# 4  4           mean   0.971923         []
# 5  5           mean   0.193278         []
# 6  6  seasonal_last   0.417606         []
# 7  7           last   0.000000         []
# 8  8           mean   0.938839         []
# 9  9           mean   0.154943         []
#
#                                            All RMSEs  \
# 0  [[0.12459174747365168, 0.13927072207458754, 0....
# 1  [[0.18390429323643792, 0.17762873456667566, 0....
# 2  [[0.4245652552570759, 0.3288519908859398, 0.22...
# 3  [[0.08808657027865822, 0.126322489261891, 0.08...
# 4  [[1.5669329860994465, 1.1153285005366258, 0.97...
# 5  [[0.19491087349701358, 0.22262168304966376, 0....
# 6  [[0.696024405859472, 0.4176059589555762, 0.593...
# 7                                  [[0.0, 0.0, 0.0]]
# 8  [[1.510531949156824, 1.0286939035988636, 0.938...
# 9  [[0.19431061984901815, 0.19336168929772085, 0....
#
#                        All Types  \
# 0  [[last, seasonal_last, mean]]
# 1  [[last, seasonal_last, mean]]
# 2  [[last, seasonal_last, mean]]
# 3  [[last, seasonal_last, mean]]
# 4  [[last, seasonal_last, mean]]
# 5  [[last, seasonal_last, mean]]
# 6  [[last, seasonal_last, mean]]
# 7  [[last, seasonal_last, mean]]
# 8  [[last, seasonal_last, mean]]
# 9  [[last, seasonal_last, mean]]
#
#                                         Best Naive
# 0           NaiveForecaster(sp=4, strategy='mean')
# 1           NaiveForecaster(sp=4, strategy='mean')
# 2           NaiveForecaster(sp=4, strategy='mean')
# 3           NaiveForecaster(sp=4, strategy='mean')
# 4           NaiveForecaster(sp=4, strategy='mean')
# 5           NaiveForecaster(sp=4, strategy='mean')
# 6  NaiveForecaster(sp=4, strategy='seasonal_last')
# 7                            NaiveForecaster(sp=4)
# 8           NaiveForecaster(sp=4, strategy='mean')
# 9           NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-02 01:48:19.055433)
# ==== Multivar P0 ====
# ======= SPECS =======
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of  10 | elapsed:  4.3min remaining:  2.9min
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  5.8min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-02 01:54:08.189517)
# ==== Multivar P0+Sim ====
# ========= SPECS =========
# =========================
# [Parallel(n_jobs=-1)]: Done   6 out of  10 | elapsed:  4.5min remaining:  3.0min
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  6.3min finished
# =================== (2020-09-02 02:00:27.600766)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ========================== (2020-09-02 02:00:27.606766)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ========= SPECS ==========
# =========== 3 ============
# ==========================
#
#
#
# =========================== (2020-09-02 02:00:27.606766)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ========== SPECS ==========
# ============ 3 ============
# ===========================
#
#
#
# ================== (2020-09-02 02:00:27.608766)
# ==== GET DATA ====
# ===== SPECS ======
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M', '3': 'JACK DANIELS TENN HNY WHSKY  1L', '4': 'GENTLEMAN JACK WHSKY OL 750M', '5': 'JACK DANIELS TENN FIRE LIQ  1L', '6': 'BUFFALO TRACE BBN BRL  750M', '7': 'WILD TURKEY 101  1L', '8': 'GENTLEMAN JACK WHSKY OL 1.75L', '9': 'JACK DANIELS TENN HNY WHSKY  750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '1', '2', '9', '5']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '3', '9', '5']
# % of weeks without a purchase: 8.536585365853659
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1', '3', '9', '5']
# % of weeks without a purchase: 2.4390243902439024
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1', '2', '9', '5']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0', '2', '3', '1', '8']
# % of weeks without a purchase: 14.634146341463413
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN FIRE LIQ  1L
# --------------------------------------------------
# Exogenous Price Columns: ['5', '0', '3', '1', '2', '9']
# % of weeks without a purchase: 1.6129032258064515
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: BUFFALO TRACE BBN BRL  750M
# --------------------------------------------------
# Exogenous Price Columns: ['6', '0', '3', '2', '1', '9']
# % of weeks without a purchase: 10.975609756097562
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: WILD TURKEY 101  1L
# --------------------------------------------------
# Exogenous Price Columns: ['7', '0', '3', '2', '1', '9']
# % of weeks without a purchase: 43.90243902439025
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['8', '0', '3', '1', '2', '9']
# % of weeks without a purchase: 13.414634146341465
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS TENN HNY WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['9', '0', '3', '2', '1', '5']
# % of weeks without a purchase: 3.6585365853658534
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS TENN HNY WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: JACK DANIELS TENN FIRE LIQ  1L
# 	Product: BUFFALO TRACE BBN BRL  750M
# 	Product: WILD TURKEY 101  1L
# 	Product: GENTLEMAN JACK WHSKY OL 1.75L
# 	Product: JACK DANIELS TENN HNY WHSKY  750M
#
#
# ==================== (2020-09-02 02:01:45.198826)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (81, 8) (1, 8)
# (81, 8) (1, 8)
# (81, 8) (1, 8)
# (81, 8) (1, 8)
# (81, 8) (1, 8)
# (61, 8) (1, 8)
# (81, 8) (1, 8)
# (81, 8) (1, 8)
# (81, 8) (1, 8)
# (81, 8) (1, 8)
#
#
# ======================== (2020-09-02 02:01:45.204825)
# ==== NAIVE FORECAST ====
# ======== SPECS =========
# ========================
#
#
#
# =============== (2020-09-02 02:01:45.227827)
# ==== MASK =====
# ==== SPECS ====
# ===============
#
# Mask: [False, False, False, False, False, False, False, False, False, False]
#
#
# =============== (2020-09-02 02:01:45.230823)
# ==== SPACE ====
# ==== SPECS ====
# ===============
#
#
#
# ==================== (2020-09-02 02:01:45.242825)
# ==== Test Index ====
# ====== SPECS =======
# ====================
#
#
#
# ========================= (2020-09-02 02:01:45.243826)
# ==== GET FUNCTION P0 ====
# ========= SPECS =========
# =========================
#
#
#
# ====================================== (2020-09-02 02:01:45.244827)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# =============== SPECS ================
# ======================================
#
#
#
# =================== (2020-09-02 02:01:45.415824)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ======================= (2020-09-02 02:01:45.419822)
# ==== OPTIMIZING P0 ====
# ======== SPECS ========
# =======================
#
#
#
# =================== (2020-09-02 02:02:48.146824)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ============================= (2020-09-02 02:02:48.357824)
# ==== GET FUNCTION P0+Sim ====
# =========== SPECS ===========
# =============================
#
#
#
# ========================================== (2020-09-02 02:02:48.358823)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ================= SPECS ==================
# ==========================================
#
# Building Forecast dataframe. Forecast Period = 1
#
#
# =================== (2020-09-02 02:02:49.955823)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =========================== (2020-09-02 02:02:49.959824)
# ==== OPTIMIZING P0+Sim ====
# ========== SPECS ==========
# ===========================
#
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
#
#
# =================== (2020-09-02 02:06:44.601824)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
# Building Forecast dataframe. Forecast Period = 1
#
#
# =================== (2020-09-02 02:06:46.145853)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ========================== (2020-09-02 02:06:46.157825)
# ==== Saving to PICKLE ====
# ==== SUP PREM WHISKEY ====
# ==========================
#
# Pickle File  full_models_SUP PREM WHISKEY_Prod10_Sim5_Per123.pkl  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns
# Pickle File  full_opt_SUP PREM WHISKEY_Prod10_Sim5_Per123.pkl  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns
#
#
# ========================== (2020-09-02 02:06:46.395851)
# ==== Saving to EXCEL =====
# ==== SUP PREM WHISKEY ====
# ==========================
#
# EXCEL File  Output_SUP PREM WHISKEY_Prod10_Sim5_Per123.xlsx  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns

# %% [markdown]
# # Print out

# %% [markdown]
# ## Models

# %%
full_models[outputColsModels]
# Out:
#           Chain Master                             Product  Period to Last  \
# 6                                BUFFALO TRACE BOURBON  1L               1
# 16                               BUFFALO TRACE BOURBON  1L               2
# 26                               BUFFALO TRACE BOURBON  1L               3
# 8                            GENTLEMAN JACK WHSKY OL 1.75L               1
# 18                           GENTLEMAN JACK WHSKY OL 1.75L               2
# ..                 ...                                 ...             ...
# 76  WESTERN BEV LIQ TX  JACK DANIELS TENN HNY WHSKY  1.75L               2
# 86  WESTERN BEV LIQ TX  JACK DANIELS TENN HNY WHSKY  1.75L               3
# 65  WESTERN BEV LIQ TX   JACK DANIELS TENN HNY WHSKY  750M               1
# 75  WESTERN BEV LIQ TX   JACK DANIELS TENN HNY WHSKY  750M               2
# 85  WESTERN BEV LIQ TX   JACK DANIELS TENN HNY WHSKY  750M               3
#
#     White Noise Naive Best Type  Naive Best RMSE P0 Best Model Name  \
# 6         False            mean         0.468984       auto_SARIMAX
# 16        False   seasonal_last         0.320055            Prophet
# 26        False   seasonal_last         0.307464            Prophet
# 8         False            mean         0.301564                 ML
# 18        False            mean         0.256755                 ML
# ..          ...             ...              ...                ...
# 76        False            mean         0.703667                 ML
# 86        False            mean         0.777799                 ML
# 65        False            mean         0.584296                 ML
# 75        False            mean         0.541200                 ML
# 85        False            mean         0.573054                 ML
#
#     P0 Best Model RMSE P0+Sim Best Model Name  P0+Sim Best Model RMSE
# 6             0.550420                Prophet                0.540562
# 16            0.560149                     ML                0.612573
# 26            0.528133                     ML                0.584607
# 8             0.221765                     ML                0.201406
# 18            0.232719                     ML                0.224064
# ..                 ...                    ...                     ...
# 76            0.604228                     ML                0.493787
# 86            0.639708                     ML                0.520116
# 65            0.443034                     ML                0.460872
# 75            0.462096                     ML                0.462364
# 85            0.352702                     ML                0.367212
#
# [120 rows x 10 columns]

# %% [markdown]
# ## Optimizer

# %% [markdown]
# ### Summary by Chain

# %%
full_chain_summary
# Out:
#          Chain Master  P0 Non-Opt Revenue  P0 Opt Revenue  P0 Opt Diff  \
# 0                                335103.0        328319.0      -6784.0
# 1               SPECS            238375.0        241917.0       3542.0
# 2    THE BARREL HOUSE              8887.0          8845.0        -42.0
# 3  WESTERN BEV LIQ TX            143730.0        160236.0      16506.0
#
#    P0 Opt Diff Ratio  P0+Sim Non-Opt Revenue  P0+Sim Opt Revenue  \
# 0           0.979755                404181.0           2465560.0
# 1           1.014859                235270.0            633825.0
# 2           0.995274                 17829.0             20091.0
# 3           1.114840                100073.0           2497703.0
#
#    P0+Sim Opt Diff  P0+Sim Opt Diff Ratio
# 0        2061379.0               6.100138
# 1         398555.0               2.694032
# 2           2262.0               1.126872
# 3        2397630.0              24.958810

# %%
print("WRITE this value in the summary table in Git hub --->",round(full_chain_summary[full_chain_summary['Chain Master']=='']['P0+Sim Opt Diff Ratio'].item(),4))
# Out:
# WRITE this value in the summary table in Git hub ---> 6.1001

# %% [markdown]
# Link to the Git Hub Summary Table: https://github.com/ngupta23/msds_capstone/issues/84

# %% [markdown]
# ### Summary by Chain and Product

# %%
full_summary
# Out:
#           Chain Master                               Product  \
# 0                                  BUFFALO TRACE BOURBON  1L
# 1                              GENTLEMAN JACK WHSKY OL 1.75L
# 2                               GENTLEMAN JACK WHSKY OL 750M
# 3                              JACK DANIELS BLK WHSKY  1.75L
# 4                                 JACK DANIELS BLK WHSKY  1L
# 5                               JACK DANIELS BLK WHSKY  750M
# 6                       JACK DANIELS BLK WHSKY FLSK PET 375M
# 7                             JACK DANIELS BLK WHSKY SQ 375M
# 8                            JACK DANIELS TENN HNY WHSKY  1L
# 9                          JACK DANIELS TENN HNY WHSKY  750M
# 10               SPECS           BUFFALO TRACE BBN BRL  750M
# 11               SPECS         GENTLEMAN JACK WHSKY OL 1.75L
# 12               SPECS          GENTLEMAN JACK WHSKY OL 750M
# 13               SPECS         JACK DANIELS BLK WHSKY  1.75L
# 14               SPECS            JACK DANIELS BLK WHSKY  1L
# 15               SPECS          JACK DANIELS BLK WHSKY  750M
# 16               SPECS        JACK DANIELS TENN FIRE LIQ  1L
# 17               SPECS       JACK DANIELS TENN HNY WHSKY  1L
# 18               SPECS     JACK DANIELS TENN HNY WHSKY  750M
# 19               SPECS                   WILD TURKEY 101  1L
# 20    THE BARREL HOUSE           GENTLEMAN JACK WHSKY 6PK 1L
# 21    THE BARREL HOUSE         GENTLEMAN JACK WHSKY OL 1.75L
# 22    THE BARREL HOUSE          GENTLEMAN JACK WHSKY OL 750M
# 23    THE BARREL HOUSE         JACK DANIELS BLK WHSKY  1.75L
# 24    THE BARREL HOUSE            JACK DANIELS BLK WHSKY  1L
# 25    THE BARREL HOUSE          JACK DANIELS BLK WHSKY  750M
# 26    THE BARREL HOUSE  JACK DANIELS BLK WHSKY FLSK PET 375M
# 27    THE BARREL HOUSE        JACK DANIELS BLK WHSKY LSE 50M
# 28    THE BARREL HOUSE       JACK DANIELS TENN HNY WHSKY  1L
# 29    THE BARREL HOUSE     JACK DANIELS TENN HNY WHSKY  750M
# 30  WESTERN BEV LIQ TX           BUFFALO TRACE BBN BRL  750M
# 31  WESTERN BEV LIQ TX         GENTLEMAN JACK WHSKY OL 1.75L
# 32  WESTERN BEV LIQ TX          GENTLEMAN JACK WHSKY OL 750M
# 33  WESTERN BEV LIQ TX         JACK DANIELS BLK WHSKY  1.75L
# 34  WESTERN BEV LIQ TX            JACK DANIELS BLK WHSKY  1L
# 35  WESTERN BEV LIQ TX          JACK DANIELS BLK WHSKY  750M
# 36  WESTERN BEV LIQ TX  JACK DANIELS BLK WHSKY FLSK PET 375M
# 37  WESTERN BEV LIQ TX        JACK DANIELS BLK WHSKY SQ 375M
# 38  WESTERN BEV LIQ TX    JACK DANIELS TENN HNY WHSKY  1.75L
# 39  WESTERN BEV LIQ TX     JACK DANIELS TENN HNY WHSKY  750M
#
#     P0 Non-Opt Revenue  P0 Opt Revenue  P0 Opt Diff  P0 Opt Diff Ratio  \
# 0               4591.0          2798.0      -1793.0           0.609453
# 1               1280.0          1228.0        -52.0           0.959375
# 2               2952.0          2976.0         24.0           1.008130
# 3              78808.0         75517.0      -3291.0           0.958240
# 4             162183.0        160933.0      -1250.0           0.992293
# 5              47810.0         45158.0      -2652.0           0.944530
# 6               9491.0         10283.0        792.0           1.083447
# 7                769.0           691.0        -78.0           0.898570
# 8              13789.0         14474.0        685.0           1.049677
# 9              13430.0         14261.0        831.0           1.061876
# 10              2363.0          2340.0        -23.0           0.990267
# 11              1879.0          1645.0       -234.0           0.875466
# 12              2764.0          2385.0       -379.0           0.862880
# 13             31102.0         31279.0        177.0           1.005691
# 14            163171.0        161016.0      -2155.0           0.986793
# 15             14658.0         21121.0       6463.0           1.440920
# 16              5235.0          5040.0       -195.0           0.962751
# 17             11101.0         10944.0       -157.0           0.985857
# 18              3815.0          3877.0         62.0           1.016252
# 19              2287.0          2270.0        -17.0           0.992567
# 20              1157.0          1154.0         -3.0           0.997407
# 21              2213.0          2183.0        -30.0           0.986444
# 22               334.0           339.0          5.0           1.014970
# 23                73.0            72.0         -1.0           0.986301
# 24               866.0           853.0        -13.0           0.984988
# 25              1043.0          1108.0         65.0           1.062320
# 26               504.0           493.0        -11.0           0.978175
# 27               867.0           866.0         -1.0           0.998847
# 28              1745.0          1700.0        -45.0           0.974212
# 29                85.0            77.0         -8.0           0.905882
# 30               720.0           673.0        -47.0           0.934722
# 31              1351.0          1346.0         -5.0           0.996299
# 32              5000.0          5636.0        636.0           1.127200
# 33             18820.0         29865.0      11045.0           1.586876
# 34             48563.0         48004.0       -559.0           0.988489
# 35             35987.0         36606.0        619.0           1.017201
# 36              2185.0          2260.0         75.0           1.034325
# 37             12874.0         17186.0       4312.0           1.334939
# 38              2489.0          2483.0         -6.0           0.997589
# 39             15741.0         16177.0        436.0           1.027698
#
#     P0+Sim Non-Opt Revenue  P0+Sim Opt Revenue  P0+Sim Opt Diff  \
# 0                  29131.0           2071675.0        2042544.0
# 1                   1454.0              1445.0             -9.0
# 2                   6675.0             18165.0          11490.0
# 3                  64135.0             66200.0           2065.0
# 4                 209406.0            215787.0           6381.0
# 5                  50705.0             53172.0           2467.0
# 6                  11451.0             11804.0            353.0
# 7                   2912.0               698.0          -2214.0
# 8                  14854.0             13177.0          -1677.0
# 9                  13458.0             13437.0            -21.0
# 10                  2408.0              2078.0           -330.0
# 11                  3332.0            108031.0         104699.0
# 12                 10574.0            299904.0         289330.0
# 13                 21925.0             20095.0          -1830.0
# 14                156596.0            149786.0          -6810.0
# 15                 19931.0             35131.0          15200.0
# 16                  4089.0              4078.0            -11.0
# 17                 11049.0              9470.0          -1579.0
# 18                  3838.0              3783.0            -55.0
# 19                  1528.0              1469.0            -59.0
# 20                   792.0               788.0             -4.0
# 21                  3036.0              4092.0           1056.0
# 22                   524.0               537.0             13.0
# 23                   226.0              1077.0            851.0
# 24                  3810.0              3605.0           -205.0
# 25                  5375.0              5774.0            399.0
# 26                  1047.0              1272.0            225.0
# 27                   921.0               920.0             -1.0
# 28                  2013.0              1950.0            -63.0
# 29                    85.0                76.0             -9.0
# 30                   901.0               675.0           -226.0
# 31                  2581.0              2473.0           -108.0
# 32                  5003.0              5285.0            282.0
# 33                 30651.0           1297274.0        1266623.0
# 34                 40565.0             37758.0          -2807.0
# 35                 10982.0             20382.0           9400.0
# 36                  2302.0              2307.0              5.0
# 37                  1779.0           1126249.0        1124470.0
# 38                   854.0               816.0            -38.0
# 39                  4455.0              4484.0             29.0
#
#     P0+Sim Opt Diff Ratio
# 0               71.115822
# 1                0.993810
# 2                2.721348
# 3                1.032198
# 4                1.030472
# 5                1.048654
# 6                1.030827
# 7                0.239698
# 8                0.887101
# 9                0.998440
# 10               0.862957
# 11              32.422269
# 12              28.362398
# 13               0.916534
# 14               0.956512
# 15               1.762631
# 16               0.997310
# 17               0.857091
# 18               0.985670
# 19               0.961387
# 20               0.994949
# 21               1.347826
# 22               1.024809
# 23               4.765487
# 24               0.946194
# 25               1.074233
# 26               1.214900
# 27               0.998914
# 28               0.968703
# 29               0.894118
# 30               0.749168
# 31               0.958156
# 32               1.056366
# 33              42.324035
# 34               0.930802
# 35               1.855946
# 36               1.002172
# 37             633.079820
# 38               0.955504
# 39               1.006510

# %% [markdown]
# ### P0 Optimizer

# %%
full_opt[outputColsOptP0]
# Out:
#           Chain Master                             Product  Period to Last  \
# 6                                BUFFALO TRACE BOURBON  1L               1
# 16                               BUFFALO TRACE BOURBON  1L               2
# 26                               BUFFALO TRACE BOURBON  1L               3
# 8                            GENTLEMAN JACK WHSKY OL 1.75L               1
# 18                           GENTLEMAN JACK WHSKY OL 1.75L               2
# ..                 ...                                 ...             ...
# 76  WESTERN BEV LIQ TX  JACK DANIELS TENN HNY WHSKY  1.75L               2
# 86  WESTERN BEV LIQ TX  JACK DANIELS TENN HNY WHSKY  1.75L               3
# 65  WESTERN BEV LIQ TX   JACK DANIELS TENN HNY WHSKY  750M               1
# 75  WESTERN BEV LIQ TX   JACK DANIELS TENN HNY WHSKY  750M               2
# 85  WESTERN BEV LIQ TX   JACK DANIELS TENN HNY WHSKY  750M               3
#
#     P0 Non-Opt Price  P0 Non-Opt Demand  P0 Non-Opt Revenue  \
# 6             206.72                 14                2826
# 16            205.71                  3                 612
# 26            206.18                  6                1153
# 8             218.44                  2                 413
# 18            214.62                  2                 417
# ..               ...                ...                 ...
# 76            185.59                  5                 837
# 86            180.46                  5                 813
# 65            203.04                  2                 339
# 75            203.04                  8                1584
# 85            222.36                 62               13818
#
#     P0 Non-Opt Chain Master Revenue  P0 Optimal Price  P0 Demand  P0 Revenue  \
# 6                            164199            203.90          7        1518
# 16                            86920            204.75          2         457
# 26                            83984            205.10          4         823
# 8                            164199            213.98          2         405
# 18                            86920            213.16          2         414
# ..                              ...               ...        ...         ...
# 76                            32215            183.68          5         829
# 86                            40575            182.00          5         820
# 65                            70941            196.74          2         329
# 75                            32215            215.64          8        1682
# 85                            40575            227.95         62       14166
#
#     P0 Chain Master Revenue
# 6                    159142
# 16                    85807
# 26                    83371
# 8                    159142
# 18                    85807
# ..                      ...
# 76                    36552
# 86                    40777
# 65                    82908
# 75                    36552
# 85                    40777
#
# [120 rows x 11 columns]

# %% [markdown]
# ### P0+Sim Optimizer

# %%
full_opt[outputColsOptP0Sim]
# Out:
#           Chain Master                             Product  Period to Last  \
# 6                                BUFFALO TRACE BOURBON  1L               1
# 16                               BUFFALO TRACE BOURBON  1L               2
# 26                               BUFFALO TRACE BOURBON  1L               3
# 8                            GENTLEMAN JACK WHSKY OL 1.75L               1
# 18                           GENTLEMAN JACK WHSKY OL 1.75L               2
# ..                 ...                                 ...             ...
# 76  WESTERN BEV LIQ TX  JACK DANIELS TENN HNY WHSKY  1.75L               2
# 86  WESTERN BEV LIQ TX  JACK DANIELS TENN HNY WHSKY  1.75L               3
# 65  WESTERN BEV LIQ TX   JACK DANIELS TENN HNY WHSKY  750M               1
# 75  WESTERN BEV LIQ TX   JACK DANIELS TENN HNY WHSKY  750M               2
# 85  WESTERN BEV LIQ TX   JACK DANIELS TENN HNY WHSKY  750M               3
#
#     P0+Sim Non-Opt Price  P0+Sim Non-Opt Demand  P0+Sim Non-Opt Revenue  \
# 6                 206.72                    139                   28673
# 16                205.71                      1                     235
# 26                206.18                      1                     223
# 8                 218.44                      2                     479
# 18                214.62                      2                     483
# ..                   ...                    ...                     ...
# 76                185.59                      2                     291
# 86                180.46                      2                     294
# 65                203.04                     10                    2048
# 75                203.04                     10                    2048
# 85                222.36                      2                     359
#
#     P0+Sim Non-Opt Chain Master Revenue  P0+Sim Optimal Price  P0+Sim Demand  \
# 6                                165564                204.98          10105
# 16                               112080                203.56              1
# 26                               126535                204.20              1
# 8                                165564                217.45              2
# 18                               112080                217.16              2
# ..                                  ...                   ...            ...
# 76                                29274                171.62              2
# 86                                19975                171.62              2
# 65                                50820                204.10             10
# 75                                29274                207.34             10
# 85                                19975                207.34              2
#
#     P0+Sim Revenue  P0+Sim Chain Master Revenue
# 6          2071222                      2189106
# 16             232                       127644
# 26             221                       148810
# 8              477                      2189106
# 18             489                       127644
# ..             ...                          ...
# 76             269                       579011
# 86             279                       876903
# 65            2059                      1041788
# 75            2091                       579011
# 85             334                       876903
#
# [120 rows x 11 columns]

# %% [markdown]
# ### Naive

# %%
full_opt[outputColsOptNaive]
# Out:
#           Chain Master                             Product  Period to Last  \
# 6                                BUFFALO TRACE BOURBON  1L               1
# 16                               BUFFALO TRACE BOURBON  1L               2
# 26                               BUFFALO TRACE BOURBON  1L               3
# 8                            GENTLEMAN JACK WHSKY OL 1.75L               1
# 18                           GENTLEMAN JACK WHSKY OL 1.75L               2
# ..                 ...                                 ...             ...
# 76  WESTERN BEV LIQ TX  JACK DANIELS TENN HNY WHSKY  1.75L               2
# 86  WESTERN BEV LIQ TX  JACK DANIELS TENN HNY WHSKY  1.75L               3
# 65  WESTERN BEV LIQ TX   JACK DANIELS TENN HNY WHSKY  750M               1
# 75  WESTERN BEV LIQ TX   JACK DANIELS TENN HNY WHSKY  750M               2
# 85  WESTERN BEV LIQ TX   JACK DANIELS TENN HNY WHSKY  750M               3
#
#     Actual Price  Actual Demand  Actual Revenue  Actual Chain Master Revenue  \
# 6     206.723172          14.63         3024.36                    356575.50
# 16    205.714286          10.64         2188.80                    109326.96
# 26    206.176692          21.28         4387.44                    149321.52
# 8     218.436725          72.54        15845.40                    356575.50
# 18    214.615385          19.89         4268.70                    109326.96
# ..           ...            ...             ...                          ...
# 76    185.589744           3.51          651.42                     33884.52
# 86    180.461538           2.34          422.28                     52534.68
# 65    203.040000          50.00        10152.00                    159283.74
# 75    203.040000          12.00         2436.48                     33884.52
# 85    222.360000           1.00          222.36                     52534.68
#
#     Naive Prices  Naive Demand  Naive Revenue  Naive Chain Master Revenue
# 6     206.723172      6.738305    1392.963798               115155.925659
# 16    205.714286      0.000000       0.000000               135363.961956
# 26    206.176692     19.950000    4113.225000               138763.987818
# 8     218.436725     13.450301    2938.039740               115155.925659
# 18    214.615385     13.371768    2869.787195               135363.961956
# ..           ...           ...            ...                         ...
# 76    185.589744      9.213148    1709.865802                60605.668288
# 86    180.461538      9.299062    1678.123125                40683.853134
# 65    203.040000     16.559241    3362.188285                65454.783209
# 75    203.040000     16.614841    3373.477411                60605.668288
# 85    222.360000     16.807617    3737.341779                40683.853134
#
# [120 rows x 11 columns]
