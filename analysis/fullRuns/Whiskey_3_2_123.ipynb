# %% [markdown]
# # Init

# %%
# %load_ext autoreload
# %autoreload 2

# %%
print("CURRENT FOLDER:")
# %pwd
# Out:
# CURRENT FOLDER:
# 'c:\\max\\Google Drive Max\\Max Shared\\Master Data Science\\2020-05 Capstone A\\msds_capstone\\analysis\\fullRuns'

# %%
import os
import glob
import sys
sys.path.append(os.environ['DEV_AUTOTS'])
sys.path.append(os.environ['CAPSTONE_PYTHON_SOURCE'])
folder = os.environ['CAPSTONE_DATA']

# %%
## Sourcing the .py with all the code##
t='"'+os.environ['CAPSTONE_PYTHON_SOURCE']+'\\fullRun\\fullRun.py'+'"'
# %run -i $t
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# Running Auto Timeseries version: 0.0.24

# %% [markdown]
# # Parameters

# %%
#Parameters

ProdCats = ['SUP PREM WHISKEY']
TOP_PRODUCTS = 3  # How many products to consider in the category
TOP_SIMILAR = 2   # Get TOP_SIMILAR most similar products
RUN_PERIODS = [1,2,3] # this will run AutoTS and Optimzer for speicfic periods (1 = last, 2 = second to last)

CV_NUM = 10         # number of Cross Valudations  10
OPT_CALLS = 100     # number of calls for the optimizer process   100
OPT_RND_STARTS = 20 # number of random calls for the optimizer process  20

LOG_TRANSFORM = True # Take log of 9L cases to smooth out peaks and valleys
ZERO_ADDER = 0.1 

RESAMPLE_FREQ = 'M'


# Pricing changes every 4 weeks
if RESAMPLE_FREQ == 'M':    FORECAST_PERIOD = 1 #last 4 months as test 
if RESAMPLE_FREQ == 'W':    FORECAST_PERIOD = 4 
if RESAMPLE_FREQ == '2W':   FORECAST_PERIOD = 2 

# Seasonal Period
if RESAMPLE_FREQ == 'M':    SEASONAL_PERIOD = 12  # Yearly
if RESAMPLE_FREQ == 'W':    SEASONAL_PERIOD = 13 # Quarterly (we can also take yearly = 52, but SARIMAX becomes too slow)
if RESAMPLE_FREQ == '2W':   SEASONAL_PERIOD = 13 # This becomes problematic --> for quarterly, should we take 6 biweekly periods or 7 bi-weekly periods. Instead I just took half yearly period  

COL_TIME = 'WeekDate'
COL_PREDS = ['9L Cases'] #Demand
COL_PRICE= ['Dollar Sales per 9L Case'] #Price

# %% [markdown]
# # Full Run

# %%
dataRaw = loadDataset(version=4)
ProdCat = 'SUP PREM WHISKEY' #'ECONOMY VODKA'
ChainMasters =  [''] +  dataRaw['Chain Master'].unique().tolist() 
display(ChainMasters,ProdCats)
# Out:
# ['', 'THE BARREL HOUSE', 'WESTERN BEV LIQ TX', 'SPECS']
# ['SUP PREM WHISKEY']

# %%
(full_models,full_opt,full_summary,full_chain_summary)  = fullRun(ProdCat = ProdCat
                                                           ,ChainMasters = ChainMasters
                                                           ,dataRaw = dataRaw
                                                           ,savePKL=True
                                                           ,saveXLS=True)
# Out:
# ==================================================
# Parameters being used...
# ==================================================
# TOP_PRODUCTS = 3
# TOP_SIMILAR = 2
# RUN_PERIODS = [1, 2, 3]
# ProdCat: SUP PREM WHISKEY
# ChainMasters: ['', 'THE BARREL HOUSE', 'WESTERN BEV LIQ TX', 'SPECS']
#
#
# ========================== (2020-09-01 10:49:44.922200)
# ===== Products List  =====
# ==== SUP PREM WHISKEY ====
# ============  ============
# ==========================
#
#
#
# ========================== (2020-09-01 10:49:50.325235)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 1 ============
# ==========================
#
#
#
# ================== (2020-09-01 10:49:50.325235)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 1.1904761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
#
#
# ===================== (2020-09-01 10:50:19.476669)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#       lb_stat  lb_pvalue
# 12  17.529696   0.130735
# 24  31.092108   0.151145
# 48  54.922995   0.228882
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12  115.750529  4.333814e-19
# 24  214.169023  1.845834e-32
# 48  308.098428  1.176533e-39
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   76.707883  1.745018e-11
# 24  131.122583  9.711501e-17
# 48  214.957410  5.416649e-23
#
# Is Data White Noise: False
#
#
# ==================== (2020-09-01 10:50:19.494670)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (83, 5) (1, 5)
# (83, 5) (1, 5)
# (83, 5) (1, 5)
#
#
# =============== (2020-09-01 10:50:19.499670)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.043169         []
# 1  1      last   0.324455         []
# 2  2      mean   0.427990         []
#
#                                            All RMSEs  \
# 0  [[0.07143315389555474, 0.11332894033533458, 0....
# 1  [[0.3244545696539494, 0.4963154566538675, 0.34...
# 2  [[0.6704496090247218, 0.719929333484661, 0.427...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-01 10:50:19.790670)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  4.4min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-01 10:54:41.108958)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  4.7min finished
# =================== (2020-09-01 10:59:22.500217)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-01 10:59:22.505216)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 1 ============
# ==========================
#
#
#
# =========================== (2020-09-01 10:59:22.505216)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ============  =============
# ============ 1 ============
# ===========================
#
#
#
# ================== (2020-09-01 10:59:22.508214)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 1.1904761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
#
#
# ==================== (2020-09-01 10:59:57.528733)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (83, 5) (1, 5)
# (83, 5) (1, 5)
# (83, 5) (1, 5)
#
#
# ======================== (2020-09-01 10:59:57.538731)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-01 10:59:57.552729)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False]
#
#
# =============== (2020-09-01 10:59:57.555732)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-01 10:59:57.562731)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-01 10:59:57.564732)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-01 10:59:57.565730)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-01 10:59:57.653729)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-01 10:59:57.660729)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-01 11:01:07.856657)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-01 11:01:07.912657)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-01 11:01:07.912657)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-01 11:01:08.032172)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-01 11:01:08.038172)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-01 11:02:09.048396)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-01 11:02:09.104394)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-01 11:02:09.108394)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 2 ============
# ==========================
#
#
#
# ================== (2020-09-01 11:02:09.109395)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 1.2048192771084338
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
#
#
# ===================== (2020-09-01 11:02:40.129928)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#       lb_stat  lb_pvalue
# 12  17.074759   0.146807
# 24  30.689164   0.162949
# 48  53.509495   0.271059
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12  113.741522  1.085921e-18
# 24  210.737801  8.608130e-32
# 48  298.546482  6.801454e-38
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   73.433730  7.257343e-11
# 24  127.792143  3.888372e-16
# 48  208.580703  6.624266e-22
#
# Is Data White Noise: False
#
#
# ==================== (2020-09-01 11:02:40.144935)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (82, 5) (1, 5)
#
#
# =============== (2020-09-01 11:02:40.149932)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.021557         []
# 1  1      mean   0.323943         []
# 2  2      mean   0.373199         []
#
#                                            All RMSEs  \
# 0  [[0.057546587491533165, 0.09126460007014617, 0...
# 1  [[0.3342880201030623, 0.4694144778845947, 0.32...
# 2  [[0.6160411345584191, 0.6054018321634664, 0.37...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-01 11:02:40.441932)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  6.8min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-01 11:09:27.784164)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  5.9min finished
# =================== (2020-09-01 11:15:22.615672)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-01 11:15:22.623673)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 2 ============
# ==========================
#
#
#
# =========================== (2020-09-01 11:15:22.623673)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ============  =============
# ============ 2 ============
# ===========================
#
#
#
# ================== (2020-09-01 11:15:22.626675)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 1.2048192771084338
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
#
#
# ==================== (2020-09-01 11:15:49.864764)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (82, 5) (1, 5)
#
#
# ======================== (2020-09-01 11:15:49.871767)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-01 11:15:49.883764)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False]
#
#
# =============== (2020-09-01 11:15:49.885764)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-01 11:15:49.892767)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-01 11:15:49.894766)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-01 11:15:49.895766)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-01 11:15:49.966764)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-01 11:15:49.972764)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-01 11:16:35.983431)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-01 11:16:36.058432)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-01 11:16:36.059430)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-01 11:16:36.130431)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-01 11:16:36.136431)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-01 11:17:46.759158)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-01 11:17:46.836156)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-01 11:17:46.843157)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 3 ============
# ==========================
#
#
#
# ================== (2020-09-01 11:17:46.843157)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
#
#
# ===================== (2020-09-01 11:18:21.688201)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#       lb_stat  lb_pvalue
# 12  16.492825   0.169692
# 24  29.613691   0.197887
# 48  52.235849   0.312831
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12  111.729571  2.720557e-18
# 24  207.460783  3.736074e-31
# 48  291.621010  1.270149e-36
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   72.023277  1.337193e-10
# 24  126.557635  6.490946e-16
# 48  206.128607  1.725436e-21
#
# Is Data White Noise: False
#
#
# ==================== (2020-09-01 11:18:21.704202)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (81, 5) (1, 5)
# (81, 5) (1, 5)
# (81, 5) (1, 5)
#
#
# =============== (2020-09-01 11:18:21.708203)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.033917         []
# 1  1      mean   0.319180         []
# 2  2      mean   0.373056         []
#
#                                            All RMSEs  \
# 0  [[0.0872048496772559, 0.1165490736094128, 0.03...
# 1  [[0.35617856342347604, 0.5500854364755055, 0.3...
# 2  [[0.556716035671863, 0.5707857245806156, 0.373...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-01 11:18:22.085204)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  4.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-01 11:22:30.803856)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  4.5min finished
# =================== (2020-09-01 11:27:00.399222)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-01 11:27:00.406222)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ============  ============
# =========== 3 ============
# ==========================
#
#
#
# =========================== (2020-09-01 11:27:00.407222)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ============  =============
# ============ 3 ============
# ===========================
#
#
#
# ================== (2020-09-01 11:27:00.409224)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
#
#
# ==================== (2020-09-01 11:27:32.913367)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (81, 5) (1, 5)
# (81, 5) (1, 5)
# (81, 5) (1, 5)
#
#
# ======================== (2020-09-01 11:27:32.919364)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-01 11:27:32.934363)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False]
#
#
# =============== (2020-09-01 11:27:32.935365)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-01 11:27:32.941366)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-01 11:27:32.942364)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-01 11:27:32.943393)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-01 11:27:33.020365)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-01 11:27:33.027364)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-01 11:28:28.379367)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-01 11:28:28.618365)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-01 11:28:28.619365)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-01 11:28:28.837367)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-01 11:28:28.844366)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-01 11:29:57.398271)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-01 11:29:57.958270)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-01 11:29:57.967267)
# ===== Products List  =====
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 11:29:58.978268)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 1 ============
# ==========================
#
#
#
# ========================== (2020-09-01 11:29:58.980270)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'GENTLEMAN JACK WHSKY OL 750M', '2': 'GENTLEMAN JACK WHSKY 6PK 1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '2', '1']
# % of weeks without a purchase: 45.23809523809524
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '2', '0']
# % of weeks without a purchase: 52.38095238095239
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY 6PK 1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '1', '0']
# % of weeks without a purchase: 32.926829268292686
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: GENTLEMAN JACK WHSKY 6PK 1L
#
#
# ========================== (2020-09-01 11:30:32.335575)
# ====== WHITE NOISE =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#        lb_stat  lb_pvalue
# 12   24.932218   0.015147
# 24   47.266936   0.003107
# 48  103.010327   0.000007
#
# Is Data White Noise: False
#        lb_stat  lb_pvalue
# 12   24.646813   0.016588
# 24   50.653838   0.001168
# 48  108.922594   0.000001
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12   8.641692   0.733192
# 24  19.315056   0.734985
# 48  47.523727   0.492264
#
# Is Data White Noise: True
#
#
# ========================== (2020-09-01 11:30:32.353575)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (83, 5) (1, 5)
# (83, 5) (1, 5)
# (81, 5) (1, 5)
#
#
# ========================== (2020-09-01 11:30:32.360576)
# ========= NAIVE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   1.149908         []
# 1  1      last   0.508452         []
# 2  2      mean   0.611153         []
#
#                                            All RMSEs  \
# 0  [[1.3378491195367055, 1.5550765479093094, 1.14...
# 1  [[0.5084521358062825, 1.227326606712806, 0.861...
# 2  [[0.7042605406907361, 0.7703384907350979, 0.61...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ========================== (2020-09-01 11:30:32.744572)
# ====== Multivar P0 =======
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  6.6min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================== (2020-09-01 11:37:06.283304)
# ==== Multivar P0+Sim =====
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  6.3min finished
# ========================== (2020-09-01 11:43:23.505389)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 11:43:23.510389)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 1 ============
# ==========================
#
#
#
# =========================== (2020-09-01 11:43:23.510389)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ==== THE BARREL HOUSE =====
# ============ 1 ============
# ===========================
#
#
#
# ========================== (2020-09-01 11:43:23.511390)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'GENTLEMAN JACK WHSKY OL 750M', '2': 'GENTLEMAN JACK WHSKY 6PK 1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '2', '1']
# % of weeks without a purchase: 45.23809523809524
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '2', '0']
# % of weeks without a purchase: 52.38095238095239
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY 6PK 1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '1', '0']
# % of weeks without a purchase: 32.926829268292686
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: GENTLEMAN JACK WHSKY 6PK 1L
#
#
# ========================== (2020-09-01 11:43:56.660287)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (83, 5) (1, 5)
# (83, 5) (1, 5)
# (81, 5) (1, 5)
#
#
# ========================== (2020-09-01 11:43:56.666805)
# ===== NAIVE FORECAST =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 11:43:56.680806)
# ========== MASK ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
# Mask: [False, False, False]
#
#
# ========================== (2020-09-01 11:43:56.683807)
# ========= SPACE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 11:43:56.689804)
# ======= Test Index =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 11:43:56.691805)
# ==== GET FUNCTION P0 =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ====================================== (2020-09-01 11:43:56.692805)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ========== THE BARREL HOUSE ==========
# ======================================
#
#
#
# ========================== (2020-09-01 11:43:56.817456)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 11:43:56.823983)
# ===== OPTIMIZING P0 ======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 11:45:12.872468)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ============================= (2020-09-01 11:45:13.011467)
# ==== GET FUNCTION P0+Sim ====
# ===== THE BARREL HOUSE ======
# =============================
#
#
#
# ========================================== (2020-09-01 11:45:13.012466)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ============ THE BARREL HOUSE ============
# ==========================================
#
#
#
# ========================== (2020-09-01 11:45:13.157468)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# =========================== (2020-09-01 11:45:13.165465)
# ==== OPTIMIZING P0+Sim ====
# ==== THE BARREL HOUSE =====
# ===========================
#
#
#
# ========================== (2020-09-01 11:48:07.997140)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 11:48:08.151664)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 11:48:08.160186)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 2 ============
# ==========================
#
#
#
# ========================== (2020-09-01 11:48:08.161184)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'GENTLEMAN JACK WHSKY OL 750M', '2': 'GENTLEMAN JACK WHSKY 6PK 1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '2', '1']
# % of weeks without a purchase: 45.78313253012048
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '2', '0']
# % of weeks without a purchase: 53.01204819277109
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY 6PK 1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '1', '0']
# % of weeks without a purchase: 33.33333333333333
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: GENTLEMAN JACK WHSKY 6PK 1L
#
#
# ========================== (2020-09-01 11:48:50.119595)
# ====== WHITE NOISE =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#       lb_stat  lb_pvalue
# 12  23.922535   0.020840
# 24  45.414544   0.005201
# 48  99.152623   0.000020
#
# Is Data White Noise: False
#        lb_stat  lb_pvalue
# 12   25.814484   0.011401
# 24   50.372270   0.001269
# 48  100.845296   0.000013
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12   8.057662   0.780608
# 24  17.817943   0.811750
# 48  41.544821   0.733036
#
# Is Data White Noise: True
#
#
# ========================== (2020-09-01 11:48:50.135595)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (80, 5) (1, 5)
#
#
# ========================== (2020-09-01 11:48:50.139595)
# ========= NAIVE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      last   1.279671         []
# 1  1      last   0.397118         []
# 2  2      mean   0.532525         []
#
#                                            All RMSEs  \
# 0  [[1.2796706251393728, 1.655747949478816, 1.324...
# 1  [[0.3971180356035492, 1.0727385943033805, 0.73...
# 2  [[0.5741726496470821, 0.6294921160859183, 0.53...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 1  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ========================== (2020-09-01 11:48:50.568314)
# ====== Multivar P0 =======
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  6.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================== (2020-09-01 11:54:54.762704)
# ==== Multivar P0+Sim =====
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  6.0min finished
# ========================== (2020-09-01 12:00:52.505017)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:00:52.513017)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 2 ============
# ==========================
#
#
#
# =========================== (2020-09-01 12:00:52.514018)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ==== THE BARREL HOUSE =====
# ============ 2 ============
# ===========================
#
#
#
# ========================== (2020-09-01 12:00:52.517019)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'GENTLEMAN JACK WHSKY OL 750M', '2': 'GENTLEMAN JACK WHSKY 6PK 1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '2', '1']
# % of weeks without a purchase: 45.78313253012048
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '2', '0']
# % of weeks without a purchase: 53.01204819277109
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY 6PK 1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '1', '0']
# % of weeks without a purchase: 33.33333333333333
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: GENTLEMAN JACK WHSKY 6PK 1L
#
#
# ========================== (2020-09-01 12:01:28.633619)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (80, 5) (1, 5)
#
#
# ========================== (2020-09-01 12:01:28.639619)
# ===== NAIVE FORECAST =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:01:28.655623)
# ========== MASK ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
# Mask: [False, False, False]
#
#
# ========================== (2020-09-01 12:01:28.658620)
# ========= SPACE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:01:28.666619)
# ======= Test Index =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:01:28.668622)
# ==== GET FUNCTION P0 =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ====================================== (2020-09-01 12:01:28.669621)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ========== THE BARREL HOUSE ==========
# ======================================
#
#
#
# ========================== (2020-09-01 12:01:28.813621)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:01:28.820624)
# ===== OPTIMIZING P0 ======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:02:44.961260)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ============================= (2020-09-01 12:02:45.145371)
# ==== GET FUNCTION P0+Sim ====
# ===== THE BARREL HOUSE ======
# =============================
#
#
#
# ========================================== (2020-09-01 12:02:45.149372)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ============ THE BARREL HOUSE ============
# ==========================================
#
#
#
# ========================== (2020-09-01 12:02:45.325096)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# =========================== (2020-09-01 12:02:45.332647)
# ==== OPTIMIZING P0+Sim ====
# ==== THE BARREL HOUSE =====
# ===========================
#
#
#
# ========================== (2020-09-01 12:04:07.649496)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:04:07.831929)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:04:07.839932)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 3 ============
# ==========================
#
#
#
# ========================== (2020-09-01 12:04:07.840930)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'GENTLEMAN JACK WHSKY OL 750M', '2': 'GENTLEMAN JACK WHSKY 6PK 1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '2', '1']
# % of weeks without a purchase: 46.34146341463415
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '2', '0']
# % of weeks without a purchase: 52.4390243902439
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY 6PK 1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '1', '0']
# % of weeks without a purchase: 33.75
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: GENTLEMAN JACK WHSKY 6PK 1L
#
#
# ========================== (2020-09-01 12:04:45.357679)
# ====== WHITE NOISE =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#       lb_stat  lb_pvalue
# 12  22.966606   0.028011
# 24  43.950059   0.007733
# 48  96.983960   0.000037
#
# Is Data White Noise: False
#        lb_stat  lb_pvalue
# 12   27.402860   0.006758
# 24   51.649912   0.000869
# 48  103.761135   0.000006
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12   7.723903   0.806317
# 24  17.026775   0.847518
# 48  40.563386   0.768264
#
# Is Data White Noise: True
#
#
# ========================== (2020-09-01 12:04:45.372679)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (81, 5) (1, 5)
# (81, 5) (1, 5)
# (79, 5) (1, 5)
#
#
# ========================== (2020-09-01 12:04:45.378681)
# ========= NAIVE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      last   1.309084         []
# 1  1      last   0.575651         []
# 2  2      last   0.514092         []
#
#                                            All RMSEs  \
# 0  [[1.3090836993967807, 1.5116570412722945, 1.34...
# 1  [[0.5756510191046259, 0.8723064569251162, 0.77...
# 2  [[0.5140918075121166, 0.680195528305364, 0.545...
#
#                        All Types             Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4)
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4)
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4)
#
#
# ========================== (2020-09-01 12:04:45.715681)
# ====== Multivar P0 =======
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  6.7min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================== (2020-09-01 12:11:29.728423)
# ==== Multivar P0+Sim =====
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  6.3min finished
# ========================== (2020-09-01 12:17:49.923469)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:17:49.932469)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ==== THE BARREL HOUSE ====
# =========== 3 ============
# ==========================
#
#
#
# =========================== (2020-09-01 12:17:49.932469)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ==== THE BARREL HOUSE =====
# ============ 3 ============
# ===========================
#
#
#
# ========================== (2020-09-01 12:17:49.935469)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'GENTLEMAN JACK WHSKY OL 750M', '2': 'GENTLEMAN JACK WHSKY 6PK 1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '2', '1']
# % of weeks without a purchase: 46.34146341463415
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY OL 750M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '2', '0']
# % of weeks without a purchase: 52.4390243902439
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: GENTLEMAN JACK WHSKY 6PK 1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '1', '0']
# % of weeks without a purchase: 33.75
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: GENTLEMAN JACK WHSKY OL 750M
# 	Product: GENTLEMAN JACK WHSKY 6PK 1L
#
#
# ========================== (2020-09-01 12:18:24.562927)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (81, 5) (1, 5)
# (81, 5) (1, 5)
# (79, 5) (1, 5)
#
#
# ========================== (2020-09-01 12:18:24.570928)
# ===== NAIVE FORECAST =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:18:24.585449)
# ========== MASK ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
# Mask: [False, False, False]
#
#
# ========================== (2020-09-01 12:18:24.587969)
# ========= SPACE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:18:24.594971)
# ======= Test Index =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:18:24.595969)
# ==== GET FUNCTION P0 =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ====================================== (2020-09-01 12:18:24.597970)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ========== THE BARREL HOUSE ==========
# ======================================
#
#
#
# ========================== (2020-09-01 12:18:24.714007)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:18:24.720006)
# ===== OPTIMIZING P0 ======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:19:11.921818)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ============================= (2020-09-01 12:19:12.025329)
# ==== GET FUNCTION P0+Sim ====
# ===== THE BARREL HOUSE ======
# =============================
#
#
#
# ========================================== (2020-09-01 12:19:12.026329)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ============ THE BARREL HOUSE ============
# ==========================================
#
#
#
# ========================== (2020-09-01 12:19:12.200331)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# =========================== (2020-09-01 12:19:12.207330)
# ==== OPTIMIZING P0+Sim ====
# ==== THE BARREL HOUSE =====
# ===========================
#
#
#
# ========================== (2020-09-01 12:20:11.828486)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-01 12:20:11.979482)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ============================ (2020-09-01 12:20:11.988482)
# ====== Products List  ======
# ===== SUP PREM WHISKEY =====
# ==== WESTERN BEV LIQ TX ====
# ============================
#
#
#
# ============================ (2020-09-01 12:20:16.107583)
# ========= AUTO-TS ==========
# ===== SUP PREM WHISKEY =====
# ==== WESTERN BEV LIQ TX ====
# ============ 1 =============
# ============================
#
#
#
# ============================ (2020-09-01 12:20:16.108583)
# ========= GET DATA =========
# ==== WESTERN BEV LIQ TX ====
# ============================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1.75L', '1': 'JACK DANIELS BLK WHSKY  750M', '2': 'JACK DANIELS BLK WHSKY  1L'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '2', '1']
# % of weeks without a purchase: 17.5
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '2', '0']
# % of weeks without a purchase: 13.414634146341465
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '1', '0']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
# 	Product: JACK DANIELS BLK WHSKY  1L
#
#
# ============================ (2020-09-01 12:20:55.012284)
# ======= WHITE NOISE ========
# ==== WESTERN BEV LIQ TX ====
# ============================
#
#        lb_stat      lb_pvalue
# 12  230.533574   1.544168e-42
# 24  440.855949   2.925831e-78
# 48  689.590939  1.731957e-114
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12   77.815839  1.075181e-11
# 24  136.909527  8.579214e-18
# 48  201.387337  1.088599e-20
#
# Is Data White Noise: False
#       lb_stat     lb_pvalue
# 12  59.487140  2.799051e-08
# 24  75.433349  3.193517e-07
# 48  84.194254  9.632108e-04
#
# Is Data White Noise: False
#
#
# ============================ (2020-09-01 12:20:55.030288)
# ======== TEST/TRAIN ========
# ==== WESTERN BEV LIQ TX ====
# ============================
#
# (79, 5) (1, 5)
# (81, 5) (1, 5)
# (82, 5) (1, 5)
#
#
# ============================ (2020-09-01 12:20:55.035286)
# ========== NAIVE ===========
# ==== WESTERN BEV LIQ TX ====
# ============================
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   1.192388         []
# 1  1      mean   0.706690         []
# 2  2      mean   0.083096         []
#
#                                            All RMSEs  \
# 0  [[1.209792431243374, 1.8312196882995284, 1.192...
# 1  [[1.1305923379415006, 1.2624589917738127, 0.70...
# 2  [[0.12236276035592478, 0.0844886828891572, 0.0...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ============================ (2020-09-01 12:20:55.442285)
# ======= Multivar P0 ========
# ==== WESTERN BEV LIQ TX ====
# ============================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  6.6min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ============================ (2020-09-01 12:27:32.281357)
# ===== Multivar P0+Sim ======
# ==== WESTERN BEV LIQ TX ====
# ============================
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  5.6min finished
# ============================ (2020-09-01 12:33:08.357656)
# ...
# ===================
#
#
#
# ======================= (2020-09-01 13:19:24.086086)
# ==== OPTIMIZING P0 ====
# ======== SPECS ========
# =======================
#
#
#
# =================== (2020-09-01 13:20:20.217862)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ============================= (2020-09-01 13:20:20.329095)
# ==== GET FUNCTION P0+Sim ====
# =========== SPECS ===========
# =============================
#
#
#
# ========================================== (2020-09-01 13:20:20.330094)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ================= SPECS ==================
# ==========================================
#
#
#
# =================== (2020-09-01 13:20:20.401138)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =========================== (2020-09-01 13:20:20.408137)
# ==== OPTIMIZING P0+Sim ====
# ========== SPECS ==========
# ===========================
#
#
#
# =================== (2020-09-01 13:22:10.168225)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =================== (2020-09-01 13:22:10.752225)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ========================== (2020-09-01 13:22:10.761222)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ========= SPECS ==========
# =========== 2 ============
# ==========================
#
#
#
# ================== (2020-09-01 13:22:10.762222)
# ==== GET DATA ====
# ===== SPECS ======
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 8.433734939759036
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1']
# % of weeks without a purchase: 2.4096385542168677
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
#
#
# ===================== (2020-09-01 13:22:48.897224)
# ==== WHITE NOISE ====
# ======= SPECS =======
# =====================
#
#       lb_stat  lb_pvalue
# 12  15.010561   0.240859
# 24  26.255626   0.340323
# 48  46.813983   0.521457
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12  28.602170   0.004512
# 24  40.565661   0.018579
# 48  53.111411   0.283742
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12  26.462991   0.009225
# 24  37.259357   0.041220
# 48  54.606396   0.237935
#
# Is Data White Noise: True
#
#
# ==================== (2020-09-01 13:22:48.915227)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (82, 5) (1, 5)
#
#
# =============== (2020-09-01 13:22:48.922224)
# ==== NAIVE ====
# ==== SPECS ====
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.033192         []
# 1  1      mean   0.118510         []
# 2  2      mean   0.224583         []
#
#                                            All RMSEs  \
# 0  [[0.0935827577097994, 0.10896925774528339, 0.0...
# 1  [[0.17264955504702825, 0.17422646327023725, 0....
# 2  [[0.4363032505606732, 0.3550157822095886, 0.22...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-01 13:22:49.274223)
# ==== Multivar P0 ====
# ======= SPECS =======
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  5.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-01 13:28:08.915243)
# ==== Multivar P0+Sim ====
# ========= SPECS =========
# =========================
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  5.2min finished
# =================== (2020-09-01 13:33:20.342412)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ========================== (2020-09-01 13:33:20.348920)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ========= SPECS ==========
# =========== 2 ============
# ==========================
#
#
#
# =========================== (2020-09-01 13:33:20.348920)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ========== SPECS ==========
# ============ 2 ============
# ===========================
#
#
#
# ================== (2020-09-01 13:33:20.350920)
# ==== GET DATA ====
# ===== SPECS ======
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 8.433734939759036
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1']
# % of weeks without a purchase: 2.4096385542168677
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
#
#
# ==================== (2020-09-01 13:33:54.792616)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (82, 5) (1, 5)
# (82, 5) (1, 5)
# (82, 5) (1, 5)
#
#
# ======================== (2020-09-01 13:33:54.800183)
# ==== NAIVE FORECAST ====
# ======== SPECS =========
# ========================
#
#
#
# =============== (2020-09-01 13:33:54.816180)
# ==== MASK =====
# ==== SPECS ====
# ===============
#
# Mask: [False, False, False]
#
#
# =============== (2020-09-01 13:33:54.819181)
# ==== SPACE ====
# ==== SPECS ====
# ===============
#
#
#
# ==================== (2020-09-01 13:33:54.827775)
# ==== Test Index ====
# ====== SPECS =======
# ====================
#
#
#
# ========================= (2020-09-01 13:33:54.828776)
# ==== GET FUNCTION P0 ====
# ========= SPECS =========
# =========================
#
#
#
# ====================================== (2020-09-01 13:33:54.829775)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# =============== SPECS ================
# ======================================
#
#
#
# =================== (2020-09-01 13:33:54.956296)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ======================= (2020-09-01 13:33:54.963297)
# ==== OPTIMIZING P0 ====
# ======== SPECS ========
# =======================
#
#
#
# =================== (2020-09-01 13:35:04.095204)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ============================= (2020-09-01 13:35:04.242249)
# ==== GET FUNCTION P0+Sim ====
# =========== SPECS ===========
# =============================
#
#
#
# ========================================== (2020-09-01 13:35:04.243249)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ================= SPECS ==================
# ==========================================
#
#
#
# =================== (2020-09-01 13:35:04.442771)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =========================== (2020-09-01 13:35:04.450812)
# ==== OPTIMIZING P0+Sim ====
# ========== SPECS ==========
# ===========================
#
#
#
# =================== (2020-09-01 13:36:06.902778)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =================== (2020-09-01 13:36:07.006778)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ========================== (2020-09-01 13:36:07.015777)
# ======== AUTO-TS =========
# ==== SUP PREM WHISKEY ====
# ========= SPECS ==========
# =========== 3 ============
# ==========================
#
#
#
# ================== (2020-09-01 13:36:07.016779)
# ==== GET DATA ====
# ===== SPECS ======
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 8.536585365853659
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1']
# % of weeks without a purchase: 2.4390243902439024
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
#
#
# ===================== (2020-09-01 13:36:40.138601)
# ==== WHITE NOISE ====
# ======= SPECS =======
# =====================
#
#       lb_stat  lb_pvalue
# 12  14.591506   0.264539
# 24  25.708961   0.368096
# 48  45.847359   0.561475
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12  28.056071   0.005429
# 24  39.797909   0.022480
# 48  52.199800   0.314062
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12  26.241054   0.009922
# 24  37.090548   0.042858
# 48  54.361071   0.245108
#
# Is Data White Noise: True
#
#
# ==================== (2020-09-01 13:36:40.155601)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (81, 5) (1, 5)
# (81, 5) (1, 5)
# (81, 5) (1, 5)
#
#
# =============== (2020-09-01 13:36:40.160601)
# ==== NAIVE ====
# ==== SPECS ====
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.051513         []
# 1  1      mean   0.109428         []
# 2  2      mean   0.221377         []
#
#                                            All RMSEs  \
# 0  [[0.12459174747365168, 0.13927072207458754, 0....
# 1  [[0.18390429323643792, 0.17762873456667566, 0....
# 2  [[0.4245652552570759, 0.3288519908859398, 0.22...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-01 13:36:40.463168)
# ==== Multivar P0 ====
# ======= SPECS =======
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  4.4min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-01 13:41:05.249417)
# ==== Multivar P0+Sim ====
# ========= SPECS =========
# =========================
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  5.9min finished
# =================== (2020-09-01 13:46:59.661285)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ========================== (2020-09-01 13:46:59.673284)
# ======= OPTIMIZER ========
# ==== SUP PREM WHISKEY ====
# ========= SPECS ==========
# =========== 3 ============
# ==========================
#
#
#
# =========================== (2020-09-01 13:46:59.674283)
# ==== Running Optimizer ====
# ==== SUP PREM WHISKEY =====
# ========== SPECS ==========
# ============ 3 ============
# ===========================
#
#
#
# ================== (2020-09-01 13:46:59.678286)
# ==== GET DATA ====
# ===== SPECS ======
# ==================
#
# resampling to  M
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2']
# % of weeks without a purchase: 8.536585365853659
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1']
# % of weeks without a purchase: 2.4390243902439024
# Log Transforming
# 	Product: JACK DANIELS BLK WHSKY  1L
# 	Product: JACK DANIELS BLK WHSKY  1.75L
# 	Product: JACK DANIELS BLK WHSKY  750M
#
#
# ==================== (2020-09-01 13:47:43.097961)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (81, 5) (1, 5)
# (81, 5) (1, 5)
# (81, 5) (1, 5)
#
#
# ======================== (2020-09-01 13:47:43.107957)
# ==== NAIVE FORECAST ====
# ======== SPECS =========
# ========================
#
#
#
# =============== (2020-09-01 13:47:43.126959)
# ==== MASK =====
# ==== SPECS ====
# ===============
#
# Mask: [False, False, False]
#
#
# =============== (2020-09-01 13:47:43.129957)
# ==== SPACE ====
# ==== SPECS ====
# ===============
#
#
#
# ==================== (2020-09-01 13:47:43.138960)
# ==== Test Index ====
# ====== SPECS =======
# ====================
#
#
#
# ========================= (2020-09-01 13:47:43.139958)
# ==== GET FUNCTION P0 ====
# ========= SPECS =========
# =========================
#
#
#
# ====================================== (2020-09-01 13:47:43.141957)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# =============== SPECS ================
# ======================================
#
#
#
# =================== (2020-09-01 13:47:43.352960)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ======================= (2020-09-01 13:47:43.360959)
# ==== OPTIMIZING P0 ====
# ======== SPECS ========
# =======================
#
#
#
# =================== (2020-09-01 13:50:11.134861)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ============================= (2020-09-01 13:50:11.547860)
# ==== GET FUNCTION P0+Sim ====
# =========== SPECS ===========
# =============================
#
#
#
# ========================================== (2020-09-01 13:50:11.548860)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ================= SPECS ==================
# ==========================================
#
#
#
# =================== (2020-09-01 13:50:11.638858)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =========================== (2020-09-01 13:50:11.646863)
# ==== OPTIMIZING P0+Sim ====
# ========== SPECS ==========
# ===========================
#
#
#
# =================== (2020-09-01 13:52:42.742053)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =================== (2020-09-01 13:52:42.864094)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ========================== (2020-09-01 13:52:42.879092)
# ==== Saving to PICKLE ====
# ==== SUP PREM WHISKEY ====
# ==========================
#
# Pickle File  full_models_SUP PREM WHISKEY_Prod3_Sim2_Per123.pkl  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns
# Pickle File  full_opt_SUP PREM WHISKEY_Prod3_Sim2_Per123.pkl  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns
#
#
# ========================== (2020-09-01 13:52:43.025094)
# ==== Saving to EXCEL =====
# ==== SUP PREM WHISKEY ====
# ==========================
#
# EXCEL File  Output_SUP PREM WHISKEY_Prod3_Sim2_Per123.xlsx  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns

# %% [markdown]
# # Print out

# %% [markdown]
# ## Models

# %%
full_models[outputColsModels]
# Out:
#           Chain Master                        Product  Period to Last  \
# 1                       JACK DANIELS BLK WHSKY  1.75L               1
# 4                       JACK DANIELS BLK WHSKY  1.75L               2
# 7                       JACK DANIELS BLK WHSKY  1.75L               3
# 0                          JACK DANIELS BLK WHSKY  1L               1
# 3                          JACK DANIELS BLK WHSKY  1L               2
# 6                          JACK DANIELS BLK WHSKY  1L               3
# 2                        JACK DANIELS BLK WHSKY  750M               1
# 5                        JACK DANIELS BLK WHSKY  750M               2
# 8                        JACK DANIELS BLK WHSKY  750M               3
# 28               SPECS  JACK DANIELS BLK WHSKY  1.75L               1
# 31               SPECS  JACK DANIELS BLK WHSKY  1.75L               2
# 34               SPECS  JACK DANIELS BLK WHSKY  1.75L               3
# 27               SPECS     JACK DANIELS BLK WHSKY  1L               1
# 30               SPECS     JACK DANIELS BLK WHSKY  1L               2
# 33               SPECS     JACK DANIELS BLK WHSKY  1L               3
# 29               SPECS   JACK DANIELS BLK WHSKY  750M               1
# 32               SPECS   JACK DANIELS BLK WHSKY  750M               2
# 35               SPECS   JACK DANIELS BLK WHSKY  750M               3
# 11    THE BARREL HOUSE    GENTLEMAN JACK WHSKY 6PK 1L               1
# 14    THE BARREL HOUSE    GENTLEMAN JACK WHSKY 6PK 1L               2
# 17    THE BARREL HOUSE    GENTLEMAN JACK WHSKY 6PK 1L               3
# 10    THE BARREL HOUSE   GENTLEMAN JACK WHSKY OL 750M               1
# 13    THE BARREL HOUSE   GENTLEMAN JACK WHSKY OL 750M               2
# 16    THE BARREL HOUSE   GENTLEMAN JACK WHSKY OL 750M               3
# 9     THE BARREL HOUSE     JACK DANIELS BLK WHSKY  1L               1
# 12    THE BARREL HOUSE     JACK DANIELS BLK WHSKY  1L               2
# 15    THE BARREL HOUSE     JACK DANIELS BLK WHSKY  1L               3
# 18  WESTERN BEV LIQ TX  JACK DANIELS BLK WHSKY  1.75L               1
# 21  WESTERN BEV LIQ TX  JACK DANIELS BLK WHSKY  1.75L               2
# 24  WESTERN BEV LIQ TX  JACK DANIELS BLK WHSKY  1.75L               3
# 20  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  1L               1
# 23  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  1L               2
# 26  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  1L               3
# 19  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY  750M               1
# 22  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY  750M               2
# 25  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY  750M               3
#
#     White Noise Naive Best Type  Naive Best RMSE P0 Best Model Name  \
# 1         False            last         0.324455       auto_SARIMAX
# 4         False            mean         0.323943       auto_SARIMAX
# 7         False            mean         0.319180       auto_SARIMAX
# 0          True            mean         0.043169            SARIMAX
# 3          True            mean         0.021557                 ML
# 6          True            mean         0.033917                 ML
# 2         False            mean         0.427990            SARIMAX
# 5         False            mean         0.373199            SARIMAX
# 8         False            mean         0.373056            SARIMAX
# 28         True            mean         0.159196            SARIMAX
# 31         True            mean         0.118510            SARIMAX
# 34         True            mean         0.109428            SARIMAX
# 27         True            mean         0.060885            SARIMAX
# 30         True            mean         0.033192                 ML
# 33         True            mean         0.051513                 ML
# 29         True            mean         0.276661       auto_SARIMAX
# 32         True            mean         0.224583                 ML
# 35         True            mean         0.221377                 ML
# 11         True            mean         0.611153                 ML
# 14         True            mean         0.532525                 ML
# 17         True            last         0.514092                 ML
# 10        False            last         0.508452                 ML
# 13        False            last         0.397118                 ML
# 16        False            last         0.575651       auto_SARIMAX
# 9         False            mean         1.149908                 ML
# 12        False            last         1.279671                 ML
# 15        False            last         1.309084                 ML
# 18        False            mean         1.192388       auto_SARIMAX
# 21        False            mean         1.152468       auto_SARIMAX
# 24        False            last         1.110996       auto_SARIMAX
# 20        False            mean         0.083096                 ML
# 23        False            mean         0.065297                 ML
# 26        False            mean         0.056411            SARIMAX
# 19        False            mean         0.706690            SARIMAX
# 22        False            mean         0.620501            SARIMAX
# 25        False            mean         0.664711                 ML
#
#     P0 Best Model RMSE P0+Sim Best Model Name  P0+Sim Best Model RMSE
# 1             0.243913           auto_SARIMAX                0.240036
# 4             0.219089           auto_SARIMAX                0.242885
# 7             0.231060                     ML                0.239514
# 0             0.028845                SARIMAX                0.021750
# 3             0.034618                     ML                0.030959
# 6             0.057793                     ML                0.051629
# 2             0.260258           auto_SARIMAX                0.311017
# 5             0.276076           auto_SARIMAX                0.293355
# 8             0.294087           auto_SARIMAX                0.278064
# 28            0.106995                SARIMAX                0.146993
# 31            0.095943                SARIMAX                0.129294
# 34            0.097419                SARIMAX                0.152967
# 27            0.036516                SARIMAX                0.033183
# 30            0.048617                     ML                0.039109
# 33            0.078627                     ML                0.065028
# 29            0.257020           auto_SARIMAX                0.249692
# 32            0.247969                SARIMAX                0.234468
# 35            0.272304           auto_SARIMAX                0.264599
# 11            0.191544                     ML                0.191544
# 14            0.210643                     ML                0.210643
# 17            0.238877                     ML                0.235016
# 10            0.615271                     ML                0.615889
# 13            0.614912                     ML                0.615411
# 16            0.752658           auto_SARIMAX                0.780690
# 9             0.722963                     ML                1.026340
# 12            0.733968                     ML                1.031876
# 15            0.634989                     ML                0.850978
# 18            0.737526           auto_SARIMAX                0.671420
# 21            0.791896           auto_SARIMAX                0.769547
# 24            0.654468           auto_SARIMAX                0.719308
# 20            0.099956                     ML                0.099927
# 23            0.108532                     ML                0.108481
# 26            0.111910                SARIMAX                0.074185
# 19            0.577988           auto_SARIMAX                0.504248
# 22            0.580915           auto_SARIMAX                0.518207
# 25            0.638930           auto_SARIMAX                0.573150

# %% [markdown]
# ## Optimizer

# %% [markdown]
# ### Summary by Chain

# %%
full_chain_summary
# Out:
#          Chain Master  P0 Non-Opt Revenue  P0 Opt Revenue  P0 Opt Diff  \
# 0                                288801.0        285207.0      -3594.0
# 1               SPECS            208931.0        211882.0       2951.0
# 2    THE BARREL HOUSE              2357.0          2371.0         14.0
# 3  WESTERN BEV LIQ TX            103370.0        116096.0      12726.0
#
#    P0 Opt Diff Ratio  P0+Sim Non-Opt Revenue  P0+Sim Opt Revenue  \
# 0           0.987555                259775.0            298087.0
# 1           1.014124                216538.0            827315.0
# 2           1.005940                  2633.0              2813.0
# 3           1.123111                 88708.0             95793.0
#
#    P0+Sim Opt Diff  P0+Sim Opt Diff Ratio
# 0          38312.0               1.147481
# 1         610777.0               3.820646
# 2            180.0               1.068363
# 3           7085.0               1.079869

# %%
print("WRITE this value in the summary table in Git hub --->",round(full_chain_summary[full_chain_summary['Chain Master']=='']['P0+Sim Opt Diff Ratio'].item(),4))
# Out:
# WRITE this value in the summary table in Git hub ---> 1.1475

# %% [markdown]
# Link to the Git Hub Summary Table: https://github.com/ngupta23/msds_capstone/issues/84

# %% [markdown]
# ### Summary by Chain and Product

# %%
full_summary
# Out:
#           Chain Master                        Product  P0 Non-Opt Revenue  \
# 0                       JACK DANIELS BLK WHSKY  1.75L             78808.0
# 1                          JACK DANIELS BLK WHSKY  1L            162183.0
# 2                        JACK DANIELS BLK WHSKY  750M             47810.0
# 3                SPECS  JACK DANIELS BLK WHSKY  1.75L             31102.0
# 4                SPECS     JACK DANIELS BLK WHSKY  1L            163171.0
# 5                SPECS   JACK DANIELS BLK WHSKY  750M             14658.0
# 6     THE BARREL HOUSE    GENTLEMAN JACK WHSKY 6PK 1L              1157.0
# 7     THE BARREL HOUSE   GENTLEMAN JACK WHSKY OL 750M               334.0
# 8     THE BARREL HOUSE     JACK DANIELS BLK WHSKY  1L               866.0
# 9   WESTERN BEV LIQ TX  JACK DANIELS BLK WHSKY  1.75L             18820.0
# 10  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  1L             48563.0
# 11  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY  750M             35987.0
#
#     P0 Opt Revenue  P0 Opt Diff  P0 Opt Diff Ratio  P0+Sim Non-Opt Revenue  \
# 0          79490.0        682.0           1.008654                 51425.0
# 1         159256.0      -2927.0           0.981952                163994.0
# 2          46461.0      -1349.0           0.971784                 44356.0
# 3          28542.0      -2560.0           0.917690                 46794.0
# 4         162670.0       -501.0           0.996930                159399.0
# 5          20670.0       6012.0           1.410151                 10345.0
# 6           1181.0         24.0           1.020743                  1157.0
# 7            340.0          6.0           1.017964                   444.0
# 8            850.0        -16.0           0.981524                  1032.0
# 9          30927.0      12107.0           1.643305                 24646.0
# 10         48459.0       -104.0           0.997858                 53166.0
# 11         36710.0        723.0           1.020091                 10896.0
#
#     P0+Sim Opt Revenue  P0+Sim Opt Diff  P0+Sim Opt Diff Ratio
# 0              65038.0          13613.0               1.264716
# 1             170681.0           6687.0               1.040776
# 2              62368.0          18012.0               1.406078
# 3             654497.0         607703.0              13.986772
# 4             155203.0          -4196.0               0.973676
# 5              17615.0           7270.0               1.702755
# 6               1171.0             14.0               1.012100
# 7                642.0            198.0               1.445946
# 8               1000.0            -32.0               0.968992
# 9              30354.0           5708.0               1.231599
# 10             52606.0           -560.0               0.989467
# 11             12833.0           1937.0               1.177772

# %% [markdown]
# ### P0 Optimizer

# %%
full_opt[outputColsOptP0]
# Out:
#           Chain Master                        Product  Period to Last  \
# 1                       JACK DANIELS BLK WHSKY  1.75L               1
# 4                       JACK DANIELS BLK WHSKY  1.75L               2
# 7                       JACK DANIELS BLK WHSKY  1.75L               3
# 0                          JACK DANIELS BLK WHSKY  1L               1
# 3                          JACK DANIELS BLK WHSKY  1L               2
# 6                          JACK DANIELS BLK WHSKY  1L               3
# 2                        JACK DANIELS BLK WHSKY  750M               1
# 5                        JACK DANIELS BLK WHSKY  750M               2
# 8                        JACK DANIELS BLK WHSKY  750M               3
# 28               SPECS  JACK DANIELS BLK WHSKY  1.75L               1
# 31               SPECS  JACK DANIELS BLK WHSKY  1.75L               2
# 34               SPECS  JACK DANIELS BLK WHSKY  1.75L               3
# 27               SPECS     JACK DANIELS BLK WHSKY  1L               1
# 30               SPECS     JACK DANIELS BLK WHSKY  1L               2
# 33               SPECS     JACK DANIELS BLK WHSKY  1L               3
# 29               SPECS   JACK DANIELS BLK WHSKY  750M               1
# 32               SPECS   JACK DANIELS BLK WHSKY  750M               2
# 35               SPECS   JACK DANIELS BLK WHSKY  750M               3
# 11    THE BARREL HOUSE    GENTLEMAN JACK WHSKY 6PK 1L               1
# 14    THE BARREL HOUSE    GENTLEMAN JACK WHSKY 6PK 1L               2
# 17    THE BARREL HOUSE    GENTLEMAN JACK WHSKY 6PK 1L               3
# 10    THE BARREL HOUSE   GENTLEMAN JACK WHSKY OL 750M               1
# 13    THE BARREL HOUSE   GENTLEMAN JACK WHSKY OL 750M               2
# 16    THE BARREL HOUSE   GENTLEMAN JACK WHSKY OL 750M               3
# 9     THE BARREL HOUSE     JACK DANIELS BLK WHSKY  1L               1
# 12    THE BARREL HOUSE     JACK DANIELS BLK WHSKY  1L               2
# 15    THE BARREL HOUSE     JACK DANIELS BLK WHSKY  1L               3
# 18  WESTERN BEV LIQ TX  JACK DANIELS BLK WHSKY  1.75L               1
# 21  WESTERN BEV LIQ TX  JACK DANIELS BLK WHSKY  1.75L               2
# 24  WESTERN BEV LIQ TX  JACK DANIELS BLK WHSKY  1.75L               3
# 20  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  1L               1
# 23  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  1L               2
# 26  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  1L               3
# 19  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY  750M               1
# 22  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY  750M               2
# 25  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY  750M               3
#
#     P0 Non-Opt Price  P0 Non-Opt Demand  P0 Non-Opt Revenue  \
# 1             185.65                224               41518
# 4             184.71                 91               16867
# 7             182.45                112               20423
# 0             229.81                310               71287
# 3             229.69                196               45027
# 6             230.09                199               45869
# 2             222.36                159               35308
# 5             222.36                 45               10052
# 8             222.36                 11                2450
# 28            185.59                 51                9481
# 31            184.56                 61               11168
# 34            184.94                 57               10453
# 27            229.53                239               54868
# 30            229.53                236               54108
# 33            229.53                236               54195
# 29            222.36                 20                4519
# 32            222.36                 23                5072
# 35            222.36                 23                5067
# 11            286.87                  1                 426
# 14            292.57                  2                 457
# 17            298.08                  1                 274
# 10            274.14                  0                  34
# 13            291.93                  0                  37
# 16            291.93                  1                 263
# 9             239.01                  1                 287
# 12            239.01                  1                 287
# 15            234.05                  1                 292
# 18            185.59                 96               17837
# 21            185.59                  4                 706
# 24            180.46                  2                 277
# 20            230.79                 59               13543
# 23            229.89                 59               13491
# 26            230.98                 93               21529
# 19            222.36                148               32964
# 22            222.36                  8                1783
# 25            222.36                  6                1240
#
#     P0 Non-Opt Chain Master Revenue  P0 Optimal Price  P0 Demand  P0 Revenue  \
# 1                            148113            184.51        218       40243
# 4                             71946            186.17         94       17552
# 7                             68742            186.18        117       21695
# 0                            148113            229.20        305       69999
# 3                             71946            225.75        196       44255
# 6                             68742            225.73        199       45002
# 2                            148113            219.15        153       33580
# 5                             71946            223.21         46       10321
# 8                             68742            223.21         11        2560
# 28                            68868            177.62         43        7589
# 31                            70348            183.63         59       10882
# 34                            69716            183.61         55       10071
# 27                            68868            229.44        238       54715
# 30                            70348            228.80        236       53934
# 33                            69716            228.80        236       54021
# 29                            68868            207.11         52       10736
# 32                            70348            217.89         23        4970
# 35                            69716            217.82         23        4964
# 11                              747            297.92          1         442
# 14                              781            297.92          2         465
# 17                              830            297.34          1         274
# 10                              747            294.64          0          37
# 13                              781            294.64          0          37
# 16                              830            302.61          1         266
# 9                               747            232.97          1         280
# 12                              781            232.97          1         280
# 15                              830            232.14          1         290
# 18                            64344            191.16        154       29368
# 21                            15980            190.38          5        1045
# 24                            23047            190.37          3         514
# 20                            64344            228.66         59       13418
# 23                            15980            230.85         59       13547
# 26                            23047            230.85         93       21494
# 19                            64344            217.14        156       33798
# 22                            15980            210.37          8        1740
# 25                            23047            210.18          6        1172
#
#     P0 Chain Master Revenue
# 1                    143822
# 4                     72128
# 7                     69257
# 0                    143822
# 3                     72128
# 6                     69257
# 2                    143822
# 5                     72128
# 8                     69257
# 28                    73040
# 31                    69787
# 34                    69056
# 27                    73040
# 30                    69787
# 33                    69056
# 29                    73040
# 32                    69787
# 35                    69056
# 11                      759
# 14                      782
# 17                      830
# 10                      759
# 13                      782
# 16                      830
# 9                       759
# 12                      782
# 15                      830
# 18                    76584
# 21                    16332
# 24                    23181
# 20                    76584
# 23                    16332
# 26                    23181
# 19                    76584
# 22                    16332
# 25                    23181

# %% [markdown]
# ### P0+Sim Optimizer

# %%
full_opt[outputColsOptP0Sim]
# Out:
#           Chain Master                        Product  Period to Last  \
# 1                       JACK DANIELS BLK WHSKY  1.75L               1
# 4                       JACK DANIELS BLK WHSKY  1.75L               2
# 7                       JACK DANIELS BLK WHSKY  1.75L               3
# 0                          JACK DANIELS BLK WHSKY  1L               1
# 3                          JACK DANIELS BLK WHSKY  1L               2
# 6                          JACK DANIELS BLK WHSKY  1L               3
# 2                        JACK DANIELS BLK WHSKY  750M               1
# 5                        JACK DANIELS BLK WHSKY  750M               2
# 8                        JACK DANIELS BLK WHSKY  750M               3
# 28               SPECS  JACK DANIELS BLK WHSKY  1.75L               1
# 31               SPECS  JACK DANIELS BLK WHSKY  1.75L               2
# 34               SPECS  JACK DANIELS BLK WHSKY  1.75L               3
# 27               SPECS     JACK DANIELS BLK WHSKY  1L               1
# 30               SPECS     JACK DANIELS BLK WHSKY  1L               2
# 33               SPECS     JACK DANIELS BLK WHSKY  1L               3
# 29               SPECS   JACK DANIELS BLK WHSKY  750M               1
# 32               SPECS   JACK DANIELS BLK WHSKY  750M               2
# 35               SPECS   JACK DANIELS BLK WHSKY  750M               3
# 11    THE BARREL HOUSE    GENTLEMAN JACK WHSKY 6PK 1L               1
# 14    THE BARREL HOUSE    GENTLEMAN JACK WHSKY 6PK 1L               2
# 17    THE BARREL HOUSE    GENTLEMAN JACK WHSKY 6PK 1L               3
# 10    THE BARREL HOUSE   GENTLEMAN JACK WHSKY OL 750M               1
# 13    THE BARREL HOUSE   GENTLEMAN JACK WHSKY OL 750M               2
# 16    THE BARREL HOUSE   GENTLEMAN JACK WHSKY OL 750M               3
# 9     THE BARREL HOUSE     JACK DANIELS BLK WHSKY  1L               1
# 12    THE BARREL HOUSE     JACK DANIELS BLK WHSKY  1L               2
# 15    THE BARREL HOUSE     JACK DANIELS BLK WHSKY  1L               3
# 18  WESTERN BEV LIQ TX  JACK DANIELS BLK WHSKY  1.75L               1
# 21  WESTERN BEV LIQ TX  JACK DANIELS BLK WHSKY  1.75L               2
# 24  WESTERN BEV LIQ TX  JACK DANIELS BLK WHSKY  1.75L               3
# 20  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  1L               1
# 23  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  1L               2
# 26  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  1L               3
# 19  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY  750M               1
# 22  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY  750M               2
# 25  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY  750M               3
#
#     P0+Sim Non-Opt Price  P0+Sim Non-Opt Demand  P0+Sim Non-Opt Revenue  \
# 1                 185.65                    149                   27660
# 4                 184.71                     82                   15073
# 7                 182.45                     48                    8692
# 0                 229.81                    318                   73098
# 3                 229.69                    196                   45027
# 6                 230.09                    199                   45869
# 2                 222.36                     94                   21010
# 5                 222.36                     47                   10373
# 8                 222.36                     58                   12973
# 28                185.59                     65                   12072
# 31                184.56                    101                   18571
# 34                184.94                     87                   16151
# 27                229.53                    241                   55425
# 30                229.53                    226                   51924
# 33                229.53                    227                   52050
# 29                222.36                     17                    3886
# 32                222.36                     21                    4581
# 35                222.36                      8                    1878
# 11                286.87                      1                     426
# 14                292.57                      2                     457
# 17                298.08                      1                     274
# 10                274.14                      0                      35
# 13                291.93                      0                      37
# 16                291.93                      1                     372
# 9                 239.01                      2                     407
# 12                239.01                      1                     297
# 15                234.05                      1                     328
# 18                185.59                    129                   23867
# 21                185.59                      2                     458
# 24                180.46                      2                     321
# 20                230.79                     59                   13548
# 23                229.89                     59                   13496
# 26                230.98                    113                   26122
# 19                222.36                     32                    7166
# 22                222.36                     11                    2351
# 25                222.36                      6                    1379
#
#     P0+Sim Non-Opt Chain Master Revenue  P0+Sim Optimal Price  P0+Sim Demand  \
# 1                                121768                169.93            208
# 4                                 70473                172.68            125
# 7                                 67535                169.77             48
# 0                                121768                228.75            352
# 3                                 70473                227.03            196
# 6                                 67535                228.74            199
# 2                                121768                224.13            136
# 5                                 70473                208.80             70
# 8                                 67535                224.15             77
# 28                                71382                167.58            167
# 31                                75076                167.40           2001
# 34                                70078                167.22           1743
# 27                                71382                228.33            227
# 30                                75076                228.33            226
# 33                                70078                228.33            227
# 29                                71382                224.05             47
# 32                                75076                224.05             10
# 35                                70078                224.05             22
# 11                                  868                296.48              1
# 14                                  791                297.92              2
# 17                                  974                289.30              1
# 10                                  868                290.57              0
# 13                                  791                294.64              0
# 16                                  974                302.16              2
# 9                                   868                234.65              2
# 12                                  791                232.97              1
# 15                                  974                223.06              1
# 18                                44582                187.68            160
# 21                                16305                174.77              1
# 24                                27822                177.47              1
# 20                                44582                229.90             59
# 23                                16305                218.26             59
# 26                                27822                229.92            114
# 19                                44582                224.54             34
# 22                                16305                224.27             17
# 25                                27822                221.01              6
#
#     P0+Sim Revenue  P0+Sim Chain Master Revenue
# 1            35336                       146379
# 4            21614                        80706
# 7             8088                        71002
# 0            80574                       146379
# 3            44506                        80706
# 6            45601                        71002
# 2            30469                       146379
# 5            14586                        80706
# 8            17313                        71002
# 28           27980                        90185
# 31          334985                       388965
# 34          291532                       348164
# 27           51776                        90185
# 30           51651                       388965
# 33           51776                       348164
# 29           10430                        90185
# 32            2329                       388965
# 35            4856                       348164
# 11             440                          876
# 14             465                          792
# 17             266                         1146
# 10              37                          876
# 13              37                          792
# 16             568                         1146
# 9              399                          876
# 12             289                          792
# 15             312                         1146
# 18           30056                        51183
# 21              91                        16708
# 24             207                        27902
# 20           13496                        51183
# 23           12813                        16708
# 26           26297                        27902
# 19            7631                        51183
# 22            3804                        16708
# 25            1398                        27902

# %% [markdown]
# ### Naive

# %%
full_opt[outputColsOptNaive]
# Out:
#           Chain Master                        Product  Period to Last  \
# 1                       JACK DANIELS BLK WHSKY  1.75L               1
# 4                       JACK DANIELS BLK WHSKY  1.75L               2
# 7                       JACK DANIELS BLK WHSKY  1.75L               3
# 0                          JACK DANIELS BLK WHSKY  1L               1
# 3                          JACK DANIELS BLK WHSKY  1L               2
# 6                          JACK DANIELS BLK WHSKY  1L               3
# 2                        JACK DANIELS BLK WHSKY  750M               1
# 5                        JACK DANIELS BLK WHSKY  750M               2
# 8                        JACK DANIELS BLK WHSKY  750M               3
# 28               SPECS  JACK DANIELS BLK WHSKY  1.75L               1
# 31               SPECS  JACK DANIELS BLK WHSKY  1.75L               2
# 34               SPECS  JACK DANIELS BLK WHSKY  1.75L               3
# 27               SPECS     JACK DANIELS BLK WHSKY  1L               1
# 30               SPECS     JACK DANIELS BLK WHSKY  1L               2
# 33               SPECS     JACK DANIELS BLK WHSKY  1L               3
# 29               SPECS   JACK DANIELS BLK WHSKY  750M               1
# 32               SPECS   JACK DANIELS BLK WHSKY  750M               2
# 35               SPECS   JACK DANIELS BLK WHSKY  750M               3
# 11    THE BARREL HOUSE    GENTLEMAN JACK WHSKY 6PK 1L               1
# 14    THE BARREL HOUSE    GENTLEMAN JACK WHSKY 6PK 1L               2
# 17    THE BARREL HOUSE    GENTLEMAN JACK WHSKY 6PK 1L               3
# 10    THE BARREL HOUSE   GENTLEMAN JACK WHSKY OL 750M               1
# 13    THE BARREL HOUSE   GENTLEMAN JACK WHSKY OL 750M               2
# 16    THE BARREL HOUSE   GENTLEMAN JACK WHSKY OL 750M               3
# 9     THE BARREL HOUSE     JACK DANIELS BLK WHSKY  1L               1
# 12    THE BARREL HOUSE     JACK DANIELS BLK WHSKY  1L               2
# 15    THE BARREL HOUSE     JACK DANIELS BLK WHSKY  1L               3
# 18  WESTERN BEV LIQ TX  JACK DANIELS BLK WHSKY  1.75L               1
# 21  WESTERN BEV LIQ TX  JACK DANIELS BLK WHSKY  1.75L               2
# 24  WESTERN BEV LIQ TX  JACK DANIELS BLK WHSKY  1.75L               3
# 20  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  1L               1
# 23  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  1L               2
# 26  WESTERN BEV LIQ TX     JACK DANIELS BLK WHSKY  1L               3
# 19  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY  750M               1
# 22  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY  750M               2
# 25  WESTERN BEV LIQ TX   JACK DANIELS BLK WHSKY  750M               3
#
#     Actual Price  Actual Demand  Actual Revenue  Actual Chain Master Revenue  \
# 1     185.650112         389.61        72331.14                    257764.62
# 4     184.710623          40.95         7563.90                     83579.58
# 7     182.449915         263.25        48029.94                    125308.26
# 0     229.811232         589.19       135402.48                    257764.62
# 3     229.687258         301.91        69344.88                     83579.58
# 6     230.085045         316.54        72831.12                    125308.26
# 2     222.360000         225.00        50031.00                    257764.62
# 5     222.360000          30.00         6670.80                     83579.58
# 8     222.360000          20.00         4447.20                    125308.26
# 28    185.589744         176.67        32788.14                    157421.22
# 31    184.564103          35.10         6478.20                     64846.92
# 34    184.935385         117.00        21637.44                     79840.32
# 27    229.533835         476.14       109290.24                    157421.22
# 30    229.533835         240.73        55255.68                     64846.92
# 33    229.533835         238.07        54645.12                     79840.32
# 29    222.360000          69.00        15342.84                    157421.22
# 32    222.360000          14.00         3113.04                     64846.92
# 35    222.360000          16.00         3557.76                     79840.32
# 11    286.874200           4.69         1345.44                      5545.08
# 14    292.567164           1.34          392.04                      1027.80
# 17    298.080000           0.00            0.00                      4669.20
# 10    274.144615          13.00         3563.88                      5545.08
# 13    291.927711           0.00            0.00                      1027.80
# 16    291.927711           0.00            0.00                      4669.20
# 9     239.007519           2.66          635.76                      5545.08
# 12    239.007519           2.66          635.76                      1027.80
# 15    234.045113          19.95         4669.20                      4669.20
# 18    185.589744         210.60        39085.20                     99027.48
# 21    185.589744           5.85         1085.70                     18096.90
# 24    180.461538         146.25        26392.50                     40798.74
# 20    230.786122         110.39        25476.48                     99027.48
# 23    229.894737          58.52        13453.44                     18096.90
# 26    230.977444          58.52        13516.80                     40798.74
# 19    222.360000         155.00        34465.80                     99027.48
# 22    222.360000          16.00         3557.76                     18096.90
# 25    222.360000           4.00          889.44                     40798.74
#
#     Naive Prices  Naive Demand  Naive Revenue  Naive Chain Master Revenue
# 1     185.650112     40.950000    7602.372072                90321.715676
# 4     184.710623    157.916707   29168.893345               111933.270259
# 7     182.449915    156.616296   28574.629873               111524.523882
# 0     229.811232    292.610723   67245.230832                90321.715676
# 3     229.687258    292.497317   67182.906670               111933.270259
# 6     230.085045    292.200494   67230.963638               111524.523882
# 2     222.360000     69.590361   15474.112771                90321.715676
# 5     222.360000     70.073171   15581.470244               111933.270259
# 8     222.360000     70.691358   15718.930370               111524.523882
# 28    185.589744     44.962771    8344.629157                63726.848507
# 31    184.564103     45.083049    8320.712439                63666.511049
# 34    184.935385     44.195185    8173.253570                63483.779571
# 27    229.533835    217.722084   49974.584892                63726.848507
# 30    229.533835    217.441500   49910.181293                63666.511049
# 33    229.533835    217.186827   49851.725260                63483.779571
# 29    222.360000     24.319277    5407.634458                63726.848507
# 32    222.360000     24.445122    5435.617317                63666.511049
# 35    222.360000     24.549383    5458.800741                63483.779571
# 11    286.874200      1.169049     335.370107                 2534.360223
# 14    292.567164      1.166913     341.400281                 5109.600281
# 17    298.080000      0.000000       0.000000                 4669.200000
# 10    274.144615      0.000000       0.000000                 2534.360223
# 13    291.927711      0.000000       0.000000                 5109.600281
# 16    291.927711      0.000000       0.000000                 4669.200000
# 9     239.007519      9.200506    2198.990116                 2534.360223
# 12    239.007519     19.950000    4768.200000                 5109.600281
# 15    234.045113     19.950000    4669.200000                 4669.200000
# 18    185.589744    110.560063   20518.813797                44989.509807
# 21    185.589744    111.902500   20767.956282                45271.604932
# 24    180.461538      0.000000       0.000000                24704.176532
# 20    230.786122     66.489207   15344.786307                44989.509807
# 23    229.894737     66.587593   15308.137076                45271.604932
# 26    230.977444     66.688437   15403.524812                24704.176532
# 19    222.360000     41.041148    9125.909702                44989.509807
# 22    222.360000     41.354163    9195.511573                45271.604932
# 25    222.360000     41.827000    9300.651720                24704.176532
