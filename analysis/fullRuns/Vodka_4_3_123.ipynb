# %% [markdown]
# # Init

# %%
# %load_ext autoreload
# %autoreload 2

# %%
print("CURRENT FOLDER:")
# %pwd
# Out:
# CURRENT FOLDER:
# 'c:\\max\\Google Drive Max\\Max Shared\\Master Data Science\\2020-05 Capstone A\\msds_capstone\\analysis\\fullRuns'

# %%
import os
import glob
import sys
sys.path.append(os.environ['DEV_AUTOTS'])
sys.path.append(os.environ['CAPSTONE_PYTHON_SOURCE'])
folder = os.environ['CAPSTONE_DATA']

# %%
## Sourcing the .py with all the code##
t='"'+os.environ['CAPSTONE_PYTHON_SOURCE']+'\\fullRun\\fullRun.py'+'"'
# %run -i $t
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# Running Auto Timeseries version: 0.0.24

# %% [markdown]
# # Parameters

# %%
#Parameters

ProdCats = ['ECONOMY VODKA']
TOP_PRODUCTS = 4  # How many products to consider in the category
TOP_SIMILAR = 3  # Get TOP_SIMILAR most similar products
RUN_PERIODS = [1,2,3] # this will run AutoTS and Optimzer for speicfic periods (1 = last, 2 = second to last)

CV_NUM = 10         # number of Cross Valudations  10
OPT_CALLS = 100     # number of calls for the optimizer process   100
OPT_RND_STARTS = 20 # number of random calls for the optimizer process  20

LOG_TRANSFORM = True # Take log of 9L cases to smooth out peaks and valleys
ZERO_ADDER = 0.1 

RESAMPLE_FREQ = 'M'


# Pricing changes every 4 weeks
if RESAMPLE_FREQ == 'M':    FORECAST_PERIOD = 1 #last 4 months as test 
if RESAMPLE_FREQ == 'W':    FORECAST_PERIOD = 4 
if RESAMPLE_FREQ == '2W':   FORECAST_PERIOD = 2 

# Seasonal Period
if RESAMPLE_FREQ == 'M':    SEASONAL_PERIOD = 12  # Yearly
if RESAMPLE_FREQ == 'W':    SEASONAL_PERIOD = 13 # Quarterly (we can also take yearly = 52, but SARIMAX becomes too slow)
if RESAMPLE_FREQ == '2W':   SEASONAL_PERIOD = 13 # This becomes problematic --> for quarterly, should we take 6 biweekly periods or 7 bi-weekly periods. Instead I just took half yearly period  

COL_TIME = 'WeekDate'
COL_PREDS = ['9L Cases'] #Demand
COL_PRICE= ['Dollar Sales per 9L Case'] #Price

# %% [markdown]
# # Full Run

# %%
dataRaw = loadDataset(version=4)
ProdCat =ProdCats[0]
ChainMasters =  [''] +  dataRaw['Chain Master'].unique().tolist() 
display(ChainMasters,ProdCats)
# Out:
# ['', 'THE BARREL HOUSE', 'WESTERN BEV LIQ TX', 'SPECS']
# ['ECONOMY VODKA']

# %%
(full_models,full_opt,full_summary,full_chain_summary)  = fullRun(ProdCat = ProdCat
                                                           ,ChainMasters = ChainMasters
                                                           ,dataRaw = dataRaw
                                                           ,savePKL=True
                                                           ,saveXLS=True)
# Out:
# ==================================================
# Parameters being used...
# ==================================================
# TOP_PRODUCTS = 4
# TOP_SIMILAR = 3
# RUN_PERIODS = [1, 2, 3]
# ProdCat: ECONOMY VODKA
# ChainMasters: ['', 'THE BARREL HOUSE', 'WESTERN BEV LIQ TX', 'SPECS']
#
#
# ======================== (2020-09-13 18:46:26.359850)
# ==== Products List  ====
# ==== ECONOMY VODKA =====
# ===========  ===========
# ========================
#
#
#
# ======================= (2020-09-13 18:46:30.851849)
# ======= AUTO-TS =======
# ==== ECONOMY VODKA ====
# ==========  ===========
# ========== 1 ==========
# =======================
#
#
#
# ================== (2020-09-13 18:46:30.852849)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 BLUE PET 375M', '2': 'TEXAS SPIRIT VODKA 80  1.75L', '3': 'TAAKA VODKA 80 PET 1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '1', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3', '0', '2']
# % of weeks without a purchase: 1.1904761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '3', '0', '1']
# % of weeks without a purchase: 69.04761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1', '2']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
#
#
# ===================== (2020-09-13 18:47:46.180905)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#        lb_stat     lb_pvalue
# 12  248.948794  2.266370e-46
# 24  282.763358  4.861676e-46
# 48  368.538254  5.288988e-51
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  584.901182  1.773645e-117
# 24  743.424992  1.784213e-141
# 48  947.167628  2.940142e-167
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  474.857092   4.940599e-94
# 24  562.831143  1.385783e-103
# 48  697.054286  5.309923e-116
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  148.350039  1.225106e-25
# 24  166.824771  2.330111e-23
# 48  349.230594  2.409071e-47
#
# Is Data White Noise: False
#
#
# ==================== (2020-09-13 18:47:46.222904)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (83, 6) (1, 6)
# (83, 6) (1, 6)
# (83, 6) (1, 6)
# (83, 6) (1, 6)
#
#
# =============== (2020-09-13 18:47:46.228904)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.083730         []
# 1  1      last   0.050920         []
# 2  2      last   0.000000         []
# 3  3      mean   0.080436         []
#
#                                            All RMSEs  \
# 0  [[0.08522395141312492, 0.11059590470983931, 0....
# 1  [[0.050919719560484134, 0.058483693505752464, ...
# 2                                  [[0.0, 0.0, 0.0]]
# 3  [[0.08442928271847924, 0.10271666862052284, 0....
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 2  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-13 18:47:47.506904)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 20.2min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 20.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-13 19:07:57.129940)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 19.0min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 19.0min finished
# =================== (2020-09-13 19:26:58.089014)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-13 19:26:58.112015)
# ====== OPTIMIZER ======
# ==== ECONOMY VODKA ====
# ==========  ===========
# ========== 1 ==========
# =======================
#
#
#
# =========================== (2020-09-13 19:26:58.112015)
# ==== Running Optimizer ====
# ====== ECONOMY VODKA ======
# ============  =============
# ============ 1 ============
# ===========================
#
#
#
# ================== (2020-09-13 19:26:58.117014)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 BLUE PET 375M', '2': 'TEXAS SPIRIT VODKA 80  1.75L', '3': 'TAAKA VODKA 80 PET 1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '1', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3', '0', '2']
# % of weeks without a purchase: 1.1904761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '3', '0', '1']
# % of weeks without a purchase: 69.04761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1', '2']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
#
#
# ==================== (2020-09-13 19:28:03.077055)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (83, 6) (1, 6)
# (83, 6) (1, 6)
# (83, 6) (1, 6)
# (83, 6) (1, 6)
#
#
# ======================== (2020-09-13 19:28:03.085053)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-13 19:28:03.112055)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False, False]
#
#
# =============== (2020-09-13 19:28:03.116057)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-13 19:28:03.127059)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-13 19:28:03.140056)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-13 19:28:03.141055)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-13 19:28:03.426057)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-13 19:28:03.433055)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-13 19:30:13.186054)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-13 19:30:13.564054)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-13 19:30:13.565054)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-13 19:30:13.767052)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-13 19:30:13.772053)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-13 19:32:21.113052)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-13 19:32:21.439054)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-13 19:32:21.444056)
# ======= AUTO-TS =======
# ==== ECONOMY VODKA ====
# ==========  ===========
# ========== 2 ==========
# =======================
#
#
#
# ================== (2020-09-13 19:32:21.445054)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 BLUE PET 375M', '2': 'TEXAS SPIRIT VODKA 80  1.75L', '3': 'TAAKA VODKA 80 PET 1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '1', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3', '0', '2']
# % of weeks without a purchase: 1.2048192771084338
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '3', '0', '1']
# % of weeks without a purchase: 68.67469879518072
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1', '2']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
#
#
# ===================== (2020-09-13 19:33:24.203058)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#        lb_stat     lb_pvalue
# 12  247.379998  4.812566e-46
# 24  281.567711  8.439708e-46
# 48  366.781603  1.141278e-50
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  574.606302  2.792191e-115
# 24  727.477625  4.083848e-138
# 48  944.375636  1.109735e-166
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  468.018038   1.404414e-92
# 24  554.010494  9.591640e-102
# 48  696.468177  6.982057e-116
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  144.742513  6.589309e-25
# 24  162.572274  1.476101e-22
# 48  338.164450  2.919586e-45
#
# Is Data White Noise: False
#
#
# ==================== (2020-09-13 19:33:24.229055)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (82, 6) (1, 6)
# (82, 6) (1, 6)
# (82, 6) (1, 6)
# (82, 6) (1, 6)
#
#
# =============== (2020-09-13 19:33:24.236054)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.077936         []
# 1  1      last   0.049104         []
# 2  2      last   0.000000         []
# 3  3      mean   0.087216         []
#
#                                            All RMSEs  \
# 0  [[0.08907681622057902, 0.11385458510024087, 0....
# 1  [[0.04910363192681037, 0.05961976914518541, 0....
# 2                                  [[0.0, 0.0, 0.0]]
# 3  [[0.09339313017889535, 0.10233695646087668, 0....
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 2  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-13 19:33:24.729056)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 17.0min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 17.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-13 19:50:25.962054)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 16.3min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 16.3min finished
# =================== (2020-09-13 20:06:41.269056)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-13 20:06:41.316057)
# ====== OPTIMIZER ======
# ==== ECONOMY VODKA ====
# ==========  ===========
# ========== 2 ==========
# =======================
#
#
#
# =========================== (2020-09-13 20:06:41.316057)
# ==== Running Optimizer ====
# ====== ECONOMY VODKA ======
# ============  =============
# ============ 2 ============
# ===========================
#
#
#
# ================== (2020-09-13 20:06:41.325053)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 BLUE PET 375M', '2': 'TEXAS SPIRIT VODKA 80  1.75L', '3': 'TAAKA VODKA 80 PET 1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '1', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3', '0', '2']
# % of weeks without a purchase: 1.2048192771084338
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '3', '0', '1']
# % of weeks without a purchase: 68.67469879518072
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1', '2']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
#
#
# ==================== (2020-09-13 20:07:34.124052)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (82, 6) (1, 6)
# (82, 6) (1, 6)
# (82, 6) (1, 6)
# (82, 6) (1, 6)
#
#
# ======================== (2020-09-13 20:07:34.131052)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-13 20:07:34.149054)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False, False]
#
#
# =============== (2020-09-13 20:07:34.152055)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-13 20:07:34.163054)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-13 20:07:34.165056)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-13 20:07:34.166053)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-13 20:07:35.512052)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-13 20:07:35.517053)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-13 20:15:40.559053)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-13 20:15:44.117054)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-13 20:15:44.118054)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-13 20:15:46.711054)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-13 20:15:46.718054)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-13 20:21:08.809053)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-13 20:21:11.416053)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-13 20:21:11.424053)
# ======= AUTO-TS =======
# ==== ECONOMY VODKA ====
# ==========  ===========
# ========== 3 ==========
# =======================
#
#
#
# ================== (2020-09-13 20:21:11.424053)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 BLUE PET 375M', '2': 'TEXAS SPIRIT VODKA 80  1.75L', '3': 'TAAKA VODKA 80 PET 1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '1', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3', '0', '2']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '3', '0', '1']
# % of weeks without a purchase: 68.29268292682927
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1', '2']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
#
#
# ===================== (2020-09-13 20:22:00.623056)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#        lb_stat     lb_pvalue
# 12  243.950101  2.495194e-45
# 24  277.452128  5.626127e-45
# 48  363.173548  5.530118e-50
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  563.083839  8.020215e-113
# 24  710.497889  1.533447e-134
# 48  939.687445  1.031921e-165
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  461.149000   4.046888e-91
# 24  545.150471  6.746748e-100
# 48  696.525463  6.797717e-116
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  141.032457  3.706001e-24
# 24  158.246146  9.582502e-22
# 48  325.345702  7.337201e-43
#
# Is Data White Noise: False
#
#
# ==================== (2020-09-13 20:22:00.651056)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (81, 6) (1, 6)
# (81, 6) (1, 6)
# (81, 6) (1, 6)
# (81, 6) (1, 6)
#
#
# =============== (2020-09-13 20:22:00.660057)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.078022         []
# 1  1      last   0.044826         []
# 2  2      last   0.000000         []
# 3  3      mean   0.076948         []
#
#                                            All RMSEs  \
# 0  [[0.10614956572430416, 0.1364306802567358, 0.0...
# 1  [[0.04482627686032599, 0.061881124720379786, 0...
# 2                                  [[0.0, 0.0, 0.0]]
# 3  [[0.0987077256986276, 0.10351490018633347, 0.0...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 2  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-13 20:22:01.155051)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 11.6min finished
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 11.6min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-13 20:33:35.748056)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 19.1min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 19.1min finished
# =================== (2020-09-13 20:52:42.046676)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-13 20:52:42.106674)
# ====== OPTIMIZER ======
# ==== ECONOMY VODKA ====
# ==========  ===========
# ========== 3 ==========
# =======================
#
#
#
# =========================== (2020-09-13 20:52:42.107675)
# ==== Running Optimizer ====
# ====== ECONOMY VODKA ======
# ============  =============
# ============ 3 ============
# ===========================
#
#
#
# ================== (2020-09-13 20:52:42.116674)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 BLUE PET 375M', '2': 'TEXAS SPIRIT VODKA 80  1.75L', '3': 'TAAKA VODKA 80 PET 1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3', '1', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3', '0', '2']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '3', '0', '1']
# % of weeks without a purchase: 68.29268292682927
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '1', '2']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
#
#
# ==================== (2020-09-13 20:53:37.004675)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (81, 6) (1, 6)
# (81, 6) (1, 6)
# (81, 6) (1, 6)
# (81, 6) (1, 6)
#
#
# ======================== (2020-09-13 20:53:37.012675)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-13 20:53:37.041675)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False, False]
#
#
# =============== (2020-09-13 20:53:37.044679)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-13 20:53:37.056676)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-13 20:53:37.058676)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-13 20:53:37.059675)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-13 20:53:38.026675)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-13 20:53:38.032677)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-13 20:58:28.343676)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-13 20:58:28.830673)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-13 20:58:28.831675)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-13 20:58:29.408676)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-13 20:58:29.415673)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-13 21:06:09.599673)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-13 21:06:10.911674)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-13 21:06:10.921677)
# ===== Products List  =====
# ===== ECONOMY VODKA ======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 21:06:12.179677)
# ======== AUTO-TS =========
# ===== ECONOMY VODKA ======
# ==== THE BARREL HOUSE ====
# =========== 1 ============
# ==========================
#
#
#
# ========================== (2020-09-13 21:06:12.180679)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80 BLUE PET 375M', '1': 'TAAKA VODKA 80 BLUE PET 200M', '2': 'TAAKA VODKA 80  1L', '3': 'DOBRA VODKA  1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2', '3']
# % of weeks without a purchase: 1.694915254237288
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 200M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '3']
# % of weeks without a purchase: 1.694915254237288
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1', '3']
# % of weeks without a purchase: 6.779661016949152
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: DOBRA VODKA  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2', '1']
# % of weeks without a purchase: 28.57142857142857
# Log Transforming
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TAAKA VODKA 80 BLUE PET 200M
# 	Product: TAAKA VODKA 80  1L
# 	Product: DOBRA VODKA  1.75L
#
#
# ========================== (2020-09-13 21:07:00.430675)
# ====== WHITE NOISE =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#        lb_stat     lb_pvalue
# 12  141.970557  2.395431e-24
# 24  144.452747  3.527878e-19
# 48  320.340879  6.288716e-42
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  21.978242   0.037764
# 24  27.494357   0.281943
# 48  52.638641   0.299248
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12   44.122049  1.455748e-05
# 24   45.996717  4.431043e-03
# 48  112.281342  4.570812e-07
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  105.152166  5.416764e-17
# 24  119.277224  1.304825e-14
# 48  154.987549  3.429672e-13
#
# Is Data White Noise: False
#
#
# ========================== (2020-09-13 21:07:00.451676)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (58, 6) (1, 6)
# (58, 6) (1, 6)
# (58, 6) (1, 6)
# (83, 6) (1, 6)
#
#
# ========================== (2020-09-13 21:07:00.458675)
# ========= NAIVE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      last   0.068911         []
# 1  1      mean   0.165948         []
# 2  2      mean   0.099268         []
# 3  3      mean   0.531778         []
#
#                                            All RMSEs  \
# 0  [[0.06891113023575937, 0.09474241449242278, 0....
# 1  [[0.2390439979625162, 0.25545500613475297, 0.1...
# 2  [[0.12248442676716172, 0.18448330474563132, 0....
# 3  [[0.5549559305354916, 0.5833145410737691, 0.53...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ========================== (2020-09-13 21:07:00.990676)
# ====== Multivar P0 =======
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 15.3min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 15.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================== (2020-09-13 21:22:20.031827)
# ==== Multivar P0+Sim =====
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 14.7min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 14.7min finished
# ========================== (2020-09-13 21:37:01.000827)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 21:37:01.081826)
# ======= OPTIMIZER ========
# ===== ECONOMY VODKA ======
# ==== THE BARREL HOUSE ====
# =========== 1 ============
# ==========================
#
#
#
# =========================== (2020-09-13 21:37:01.082828)
# ==== Running Optimizer ====
# ====== ECONOMY VODKA ======
# ==== THE BARREL HOUSE =====
# ============ 1 ============
# ===========================
#
#
#
# ========================== (2020-09-13 21:37:01.089826)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80 BLUE PET 375M', '1': 'TAAKA VODKA 80 BLUE PET 200M', '2': 'TAAKA VODKA 80  1L', '3': 'DOBRA VODKA  1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2', '3']
# % of weeks without a purchase: 1.694915254237288
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 200M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '3']
# % of weeks without a purchase: 1.694915254237288
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1', '3']
# % of weeks without a purchase: 6.779661016949152
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: DOBRA VODKA  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2', '1']
# % of weeks without a purchase: 28.57142857142857
# Log Transforming
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TAAKA VODKA 80 BLUE PET 200M
# 	Product: TAAKA VODKA 80  1L
# 	Product: DOBRA VODKA  1.75L
#
#
# ========================== (2020-09-13 21:37:53.779827)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (58, 6) (1, 6)
# (58, 6) (1, 6)
# (58, 6) (1, 6)
# (83, 6) (1, 6)
#
#
# ========================== (2020-09-13 21:37:53.786826)
# ===== NAIVE FORECAST =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 21:37:53.807829)
# ========== MASK ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
# Mask: [False, False, False, False]
#
#
# ========================== (2020-09-13 21:37:53.810826)
# ========= SPACE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 21:37:53.825827)
# ======= Test Index =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 21:37:53.827827)
# ==== GET FUNCTION P0 =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ====================================== (2020-09-13 21:37:53.828827)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ========== THE BARREL HOUSE ==========
# ======================================
#
#
#
# ========================== (2020-09-13 21:37:54.002827)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 21:37:54.009827)
# ===== OPTIMIZING P0 ======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 21:40:53.426827)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ============================= (2020-09-13 21:40:53.578828)
# ==== GET FUNCTION P0+Sim ====
# ===== THE BARREL HOUSE ======
# =============================
#
#
#
# ========================================== (2020-09-13 21:40:53.579828)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ============ THE BARREL HOUSE ============
# ==========================================
#
#
#
# ========================== (2020-09-13 21:40:53.713826)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# =========================== (2020-09-13 21:40:53.728827)
# ==== OPTIMIZING P0+Sim ====
# ==== THE BARREL HOUSE =====
# ===========================
#
#
#
# ========================== (2020-09-13 21:44:27.449826)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 21:44:27.574825)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 21:44:27.585825)
# ======== AUTO-TS =========
# ===== ECONOMY VODKA ======
# ==== THE BARREL HOUSE ====
# =========== 2 ============
# ==========================
#
#
#
# ========================== (2020-09-13 21:44:27.585825)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80 BLUE PET 375M', '1': 'TAAKA VODKA 80 BLUE PET 200M', '2': 'TAAKA VODKA 80  1L', '3': 'DOBRA VODKA  1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2', '3']
# % of weeks without a purchase: 1.7241379310344827
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 200M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '3']
# % of weeks without a purchase: 1.7241379310344827
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1', '3']
# % of weeks without a purchase: 6.896551724137931
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: DOBRA VODKA  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2', '1']
# % of weeks without a purchase: 28.915662650602407
# Log Transforming
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TAAKA VODKA 80 BLUE PET 200M
# 	Product: TAAKA VODKA 80  1L
# 	Product: DOBRA VODKA  1.75L
#
#
# ========================== (2020-09-13 21:45:17.503828)
# ====== WHITE NOISE =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#        lb_stat     lb_pvalue
# 12  137.410866  1.993797e-23
# 24  139.910786  2.418875e-18
# 48  322.778598  2.210050e-42
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  21.669742   0.041392
# 24  27.152575   0.297392
# 48  52.791525   0.294182
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12   42.786664  2.453685e-05
# 24   44.707020  6.307408e-03
# 48  111.872160  5.168754e-07
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  104.052037  8.917711e-17
# 24  118.103635  2.109057e-14
# 48  153.752344  5.308252e-13
#
# Is Data White Noise: False
#
#
# ========================== (2020-09-13 21:45:17.533828)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (57, 6) (1, 6)
# (57, 6) (1, 6)
# (57, 6) (1, 6)
# (82, 6) (1, 6)
#
#
# ========================== (2020-09-13 21:45:17.542824)
# ========= NAIVE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      last   0.055124         []
# 1  1      mean   0.206669         []
# 2  2      mean   0.094367         []
# 3  3      last   0.583315         []
#
#                                            All RMSEs  \
# 0  [[0.055123576776570093, 0.0992941627475532, 0....
# 1  [[0.2776588463567642, 0.2832827480917138, 0.20...
# 2  [[0.1282258925607897, 0.17212401268673627, 0.0...
# 3  [[0.5833145410737691, 0.6936949131693646, 0.59...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 3  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
#
#
# ========================== (2020-09-13 21:45:18.164831)
# ====== Multivar P0 =======
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 20.4min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 20.4min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================== (2020-09-13 22:05:42.368824)
# ==== Multivar P0+Sim =====
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 13.8min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 13.8min finished
# ========================== (2020-09-13 22:19:29.206351)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:19:29.286360)
# ======= OPTIMIZER ========
# ===== ECONOMY VODKA ======
# ==== THE BARREL HOUSE ====
# =========== 2 ============
# ==========================
#
#
#
# =========================== (2020-09-13 22:19:29.286360)
# ==== Running Optimizer ====
# ====== ECONOMY VODKA ======
# ==== THE BARREL HOUSE =====
# ============ 2 ============
# ===========================
#
#
#
# ========================== (2020-09-13 22:19:29.309351)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80 BLUE PET 375M', '1': 'TAAKA VODKA 80 BLUE PET 200M', '2': 'TAAKA VODKA 80  1L', '3': 'DOBRA VODKA  1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2', '3']
# % of weeks without a purchase: 1.7241379310344827
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 200M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '3']
# % of weeks without a purchase: 1.7241379310344827
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1', '3']
# % of weeks without a purchase: 6.896551724137931
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: DOBRA VODKA  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2', '1']
# % of weeks without a purchase: 28.915662650602407
# Log Transforming
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TAAKA VODKA 80 BLUE PET 200M
# 	Product: TAAKA VODKA 80  1L
# 	Product: DOBRA VODKA  1.75L
#
#
# ========================== (2020-09-13 22:20:26.339353)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (57, 6) (1, 6)
# (57, 6) (1, 6)
# (57, 6) (1, 6)
# (82, 6) (1, 6)
#
#
# ========================== (2020-09-13 22:20:26.346353)
# ===== NAIVE FORECAST =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:20:26.369352)
# ========== MASK ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
# Mask: [False, False, False, False]
#
#
# ========================== (2020-09-13 22:20:26.371352)
# ========= SPACE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:20:26.386353)
# ======= Test Index =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:20:26.387352)
# ==== GET FUNCTION P0 =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ====================================== (2020-09-13 22:20:26.388353)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ========== THE BARREL HOUSE ==========
# ======================================
#
#
#
# ========================== (2020-09-13 22:20:26.597357)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:20:26.606357)
# ===== OPTIMIZING P0 ======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:24:27.940359)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ============================= (2020-09-13 22:24:28.093353)
# ==== GET FUNCTION P0+Sim ====
# ===== THE BARREL HOUSE ======
# =============================
#
#
#
# ========================================== (2020-09-13 22:24:28.094351)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ============ THE BARREL HOUSE ============
# ==========================================
#
#
#
# ========================== (2020-09-13 22:24:28.250362)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# =========================== (2020-09-13 22:24:28.257353)
# ==== OPTIMIZING P0+Sim ====
# ==== THE BARREL HOUSE =====
# ===========================
#
#
#
# ========================== (2020-09-13 22:27:41.276352)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:27:41.432351)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:27:41.449351)
# ======== AUTO-TS =========
# ===== ECONOMY VODKA ======
# ==== THE BARREL HOUSE ====
# =========== 3 ============
# ==========================
#
#
#
# ========================== (2020-09-13 22:27:41.450353)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80 BLUE PET 375M', '1': 'TAAKA VODKA 80 BLUE PET 200M', '2': 'TAAKA VODKA 80  1L', '3': 'DOBRA VODKA  1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2', '3']
# % of weeks without a purchase: 1.7543859649122806
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 200M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '3']
# % of weeks without a purchase: 1.7543859649122806
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0', '1', '3']
# % of weeks without a purchase: 7.017543859649122
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: DOBRA VODKA  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0', '2', '1']
# % of weeks without a purchase: 28.04878048780488
# Log Transforming
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TAAKA VODKA 80 BLUE PET 200M
# 	Product: TAAKA VODKA 80  1L
# 	Product: DOBRA VODKA  1.75L
#
#
# ========================== (2020-09-13 22:28:33.885352)
# ====== WHITE NOISE =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#        lb_stat     lb_pvalue
# 12  132.810279  1.682218e-22
# 24  135.478653  1.566072e-17
# 48  325.313018  7.441001e-43
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  21.595536   0.042311
# 24  27.028344   0.303134
# 48  54.622321   0.237474
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12   41.613403  3.867933e-05
# 24   43.560865  8.577393e-03
# 48  112.343700  4.485858e-07
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  106.751532  2.621607e-17
# 24  118.126523  2.089419e-14
# 48  160.415924  4.948674e-14
#
# Is Data White Noise: False
#
#
# ========================== (2020-09-13 22:28:33.912354)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (56, 6) (1, 6)
# (56, 6) (1, 6)
# (56, 6) (1, 6)
# (81, 6) (1, 6)
#
#
# ========================== (2020-09-13 22:28:33.919353)
# ========= NAIVE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      last   0.065992         []
# 1  1      mean   0.199992         []
# 2  2      mean   0.093113         []
# 3  3      last   0.472934         []
#
#                                            All RMSEs  \
# 0  [[0.06599226033424141, 0.10595455079040401, 0....
# 1  [[0.24204599505427557, 0.28850466087251886, 0....
# 2  [[0.1186954439315259, 0.17141527417502248, 0.0...
# 3  [[0.4729341689781733, 0.6653363026310875, 0.51...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 3  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
#
#
# ========================== (2020-09-13 22:28:34.363356)
# ====== Multivar P0 =======
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 16.5min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 16.5min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================== (2020-09-13 22:45:04.400356)
# ==== Multivar P0+Sim =====
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 16.8min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 16.8min finished
# ========================== (2020-09-13 23:01:54.974733)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 23:01:55.030731)
# ======= OPTIMIZER ========
# ===== ECONOMY VODKA ======
# ==== THE BARREL HOUSE ====
# =========== 3 ============
# ==========================
#
#
#
# =========================== (2020-09-13 23:01:55.030731)
# ==== Running Optimizer ====
# ====== ECONOMY VODKA ======
# ==== THE BARREL HOUSE =====
# ============ 3 ============
# ===========================
#
#
#
# ========================== (2020-09-13 23:01:55.038731)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80 BLUE PET 375M', '1': 'TAAKA VODKA 80 BLUE PET 200M', '2': 'TAAKA VODKA 80  1L', '3': 'DOBRA VODKA  1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '2', '3']
# % of weeks without a purchase: 1.7543859649122806
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 200M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0', '2', '3']
# % of weeks without a purchase: 1.7543859649122806
# resampling to  M
#
#
#
# ...
#
#
# ============================= (2020-09-14 01:08:01.879943)
# ==== GET FUNCTION P0+Sim ====
# ==== WESTERN BEV LIQ TX =====
# =============================
#
#
#
# ========================================== (2020-09-14 01:08:01.880943)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# =========== WESTERN BEV LIQ TX ===========
# ==========================================
#
#
#
# ============================ (2020-09-14 01:08:02.256944)
# ======== OUTPUT P0 =========
# ==== WESTERN BEV LIQ TX ====
# ============================
#
#
#
# ============================ (2020-09-14 01:08:02.263943)
# ==== OPTIMIZING P0+Sim =====
# ==== WESTERN BEV LIQ TX ====
# ============================
#
#
#
# ============================ (2020-09-14 01:12:35.576004)
# ======== OUTPUT P0 =========
# ==== WESTERN BEV LIQ TX ====
# ============================
#
#
#
# ============================ (2020-09-14 01:12:36.030000)
# ======== COMPLETED =========
# ==== WESTERN BEV LIQ TX ====
# ============================
#
#
#
# ============================ (2020-09-14 01:12:36.040002)
# ========= AUTO-TS ==========
# ====== ECONOMY VODKA =======
# ==== WESTERN BEV LIQ TX ====
# ============ 3 =============
# ============================
#
#
#
# ============================ (2020-09-14 01:12:36.041001)
# ========= GET DATA =========
# ==== WESTERN BEV LIQ TX ====
# ============================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80 BLUE PET 375M', '1': 'TAAKA VODKA 80  1L', '2': 'TEXAS SPIRIT VODKA 80  1.75L', '3': 'TAAKA VODKA 80 PET 1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '3', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3', '0', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '3', '1', '0']
# % of weeks without a purchase: 68.29268292682927
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '1', '0', '2']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TAAKA VODKA 80  1L
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
#
#
# ============================ (2020-09-14 01:13:41.105561)
# ======= WHITE NOISE ========
# ==== WESTERN BEV LIQ TX ====
# ============================
#
#        lb_stat     lb_pvalue
# 12  251.523615  6.582281e-47
# 24  265.340842  1.474347e-42
# 48  520.398043  1.501597e-80
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  205.104978  2.877757e-37
# 24  227.899968  3.788775e-35
# 48  300.807010  2.609150e-38
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  461.149000   4.046888e-91
# 24  545.150471  6.746748e-100
# 48  696.525463  6.797717e-116
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  193.458472  7.285037e-35
# 24  227.500653  4.538485e-35
# 48  301.703393  1.783794e-38
#
# Is Data White Noise: False
#
#
# ============================ (2020-09-14 01:13:41.137557)
# ======== TEST/TRAIN ========
# ==== WESTERN BEV LIQ TX ====
# ============================
#
# (60, 6) (1, 6)
# (81, 6) (1, 6)
# (81, 6) (1, 6)
# (81, 6) (1, 6)
#
#
# ============================ (2020-09-14 01:13:41.142557)
# ========== NAIVE ===========
# ==== WESTERN BEV LIQ TX ====
# ============================
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      last   0.055440         []
# 1  1      last   0.126205         []
# 2  2      last   0.000000         []
# 3  3      mean   0.137258         []
#
#                                            All RMSEs  \
# 0  [[0.055440396299136795, 0.07932033357679338, 0...
# 1  [[0.1262049073251357, 0.1766633572716995, 0.14...
# 2                                  [[0.0, 0.0, 0.0]]
# 3  [[0.15350339758642795, 0.15073459382621, 0.137...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 1  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 2  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ============================ (2020-09-14 01:13:41.802558)
# ======= Multivar P0 ========
# ==== WESTERN BEV LIQ TX ====
# ============================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 22.5min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 22.5min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ============================ (2020-09-14 01:36:12.204468)
# ===== Multivar P0+Sim ======
# ==== WESTERN BEV LIQ TX ====
# ============================
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 22.6min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed: 22.6min finished
# ============================ (2020-09-14 01:58:47.591623)
# ======== COMPLETED =========
# ==== WESTERN BEV LIQ TX ====
# ============================
#
#
#
# ============================ (2020-09-14 01:58:47.667622)
# ======== OPTIMIZER =========
# ====== ECONOMY VODKA =======
# ==== WESTERN BEV LIQ TX ====
# ============ 3 =============
# ============================
#
#
#
# ============================ (2020-09-14 01:58:47.668623)
# ==== Running Optimizer =====
# ====== ECONOMY VODKA =======
# ==== WESTERN BEV LIQ TX ====
# ============ 3 =============
# ============================
#
#
#
# ============================ (2020-09-14 01:58:47.675624)
# ========= GET DATA =========
# ==== WESTERN BEV LIQ TX ====
# ============================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80 BLUE PET 375M', '1': 'TAAKA VODKA 80  1L', '2': 'TEXAS SPIRIT VODKA 80  1.75L', '3': 'TAAKA VODKA 80 PET 1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1', '3', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3', '0', '2']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '3', '1', '0']
# % of weeks without a purchase: 68.29268292682927
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '1', '0', '2']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TAAKA VODKA 80  1L
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
#
#
# ============================ (2020-09-14 01:59:42.749625)
# ======== TEST/TRAIN ========
# ==== WESTERN BEV LIQ TX ====
# ============================
#
# (60, 6) (1, 6)
# (81, 6) (1, 6)
# (81, 6) (1, 6)
# (81, 6) (1, 6)
#
#
# ============================ (2020-09-14 01:59:42.758625)
# ====== NAIVE FORECAST ======
# ==== WESTERN BEV LIQ TX ====
# ============================
#
#
#
# ============================ (2020-09-14 01:59:42.776624)
# =========== MASK ===========
# ==== WESTERN BEV LIQ TX ====
# ============================
#
# Mask: [False, False, False, False]
#
#
# ============================ (2020-09-14 01:59:42.779623)
# ========== SPACE ===========
# ==== WESTERN BEV LIQ TX ====
# ============================
#
#
#
# ============================ (2020-09-14 01:59:42.790625)
# ======== Test Index ========
# ==== WESTERN BEV LIQ TX ====
# ============================
#
#
#
# ============================ (2020-09-14 01:59:42.791624)
# ===== GET FUNCTION P0 ======
# ==== WESTERN BEV LIQ TX ====
# ============================
#
#
#
# ====================================== (2020-09-14 01:59:42.793624)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ========= WESTERN BEV LIQ TX =========
# ======================================
#
#
#
# ============================ (2020-09-14 01:59:44.505623)
# ======== OUTPUT P0 =========
# ==== WESTERN BEV LIQ TX ====
# ============================
#
#
#
# ============================ (2020-09-14 01:59:44.511623)
# ====== OPTIMIZING P0 =======
# ==== WESTERN BEV LIQ TX ====
# ============================
#
#
#
# ============================ (2020-09-14 02:03:05.291667)
# ======== OUTPUT P0 =========
# ==== WESTERN BEV LIQ TX ====
# ============================
#
#
#
# ============================= (2020-09-14 02:03:05.737668)
# ==== GET FUNCTION P0+Sim ====
# ==== WESTERN BEV LIQ TX =====
# =============================
#
#
#
# ========================================== (2020-09-14 02:03:05.739668)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# =========== WESTERN BEV LIQ TX ===========
# ==========================================
#
#
#
# ============================ (2020-09-14 02:03:06.686667)
# ======== OUTPUT P0 =========
# ==== WESTERN BEV LIQ TX ====
# ============================
#
#
#
# ============================ (2020-09-14 02:03:06.693668)
# ==== OPTIMIZING P0+Sim =====
# ==== WESTERN BEV LIQ TX ====
# ============================
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\source\python\fullRun\fullRun.py in <module>
#       3                                                            ,dataRaw = dataRaw
#       4                                                            ,savePKL=True
# ----> 5                                                            ,saveXLS=True)
#
# C:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\source\python\fullRun\fullRun.py in fullRun(ProdCat, ChainMasters, dataRaw, savePKL, saveXLS)
#     799                                    ,modelsStats=modelsStats
#     800                                    ,verbose=0
# --> 801                                    ,leaveOutLastPeriods=(period-1))
#     802
#     803             opt_stats['Period to Last']=period
#
# C:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\source\python\fullRun\fullRun.py in runOptimizer(ProductsList, dataRaw, ChainMaster, modelsStats, leaveOutLastPeriods, verbose)
#     734         out=opt_optimize(masked_complex_objective=masked_complex_objective
#     735                          ,space=space
# --> 736                          ,ChainMaster=ChainMaster)
#     737         opt_stats = pd.concat([opt_stats,out],axis=1)
#     738
#
# C:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\source\python\fullRun\fullRun.py in opt_optimize(masked_complex_objective, space, ChainMaster)
#     505                       ,n_calls=OPT_CALLS
#     506                       ,n_random_starts=OPT_RND_STARTS
# --> 507                       ,random_state=42)
#     508
#     509     ## GET OUTPUT DATA ##
#
# ~\Anaconda3\lib\site-packages\skopt\optimizer\gp.py in gp_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, noise, n_jobs, model_queue_size)
#     266         n_restarts_optimizer=n_restarts_optimizer,
#     267         x0=x0, y0=y0, random_state=rng, verbose=verbose,
# --> 268         callback=callback, n_jobs=n_jobs, model_queue_size=model_queue_size)
#
# ~\Anaconda3\lib\site-packages\skopt\optimizer\base.py in base_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, n_jobs, model_queue_size)
#     300         next_x = optimizer.ask()
#     301         next_y = func(next_x)
# --> 302         result = optimizer.tell(next_x, next_y)
#     303         result.specs = specs
#     304         if eval_callbacks(callbacks, result):
#
# ~\Anaconda3\lib\site-packages\skopt\optimizer\optimizer.py in tell(self, x, y, fit)
#     491                 y[1] = log(y[1])
#     492
# --> 493         return self._tell(x, y, fit=fit)
#     494
#     495     def _tell(self, x, y, fit=True):
#
# ~\Anaconda3\lib\site-packages\skopt\optimizer\optimizer.py in _tell(self, x, y, fit)
#     534             with warnings.catch_warnings():
#     535                 warnings.simplefilter("ignore")
# --> 536                 est.fit(self.space.transform(self.Xi), self.yi)
#     537
#     538             if hasattr(self, "next_xs_") and self.acq_func == "gp_hedge":
#
# ~\Anaconda3\lib\site-packages\skopt\learning\gaussian_process\gpr.py in fit(self, X, y)
#     193                 noise_level=self.noise, noise_level_bounds="fixed"
#     194             )
# --> 195         super(GaussianProcessRegressor, self).fit(X, y)
#     196
#     197         self.noise_ = None
#
# ~\Anaconda3\lib\site-packages\sklearn\gaussian_process\_gpr.py in fit(self, X, y)
#     188         if self.kernel_.requires_vector_input:
#     189             X, y = self._validate_data(X, y, multi_output=True, y_numeric=True,
# --> 190                                        ensure_2d=True, dtype="numeric")
#     191         else:
#     192             X, y = self._validate_data(X, y, multi_output=True, y_numeric=True,
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     803     if multi_output:
#     804         y = check_array(y, accept_sparse='csr', force_all_finite=True,
# --> 805                         ensure_2d=False, dtype=None)
#     806     else:
#     807         y = column_or_1d(y, warn=True)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     643         if force_all_finite:
#     644             _assert_all_finite(array,
# --> 645                                allow_nan=force_all_finite == 'allow-nan')
#     646
#     647     if ensure_min_samples > 0:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      97                     msg_err.format
#      98                     (type_err,
# ---> 99                      msg_dtype if msg_dtype is not None else X.dtype)
#     100             )
#     101     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %% [markdown]
# # Print out

# %% [markdown]
# ## Models

# %%
full_models[outputColsModels]

# %% [markdown]
# ## Optimizer

# %% [markdown]
# ### Summary by Chain

# %%
full_chain_summary

# %%
print("WRITE this value in the summary table in Git hub --->",round(full_chain_summary[full_chain_summary['Chain Master']=='']['P0+Sim Opt Diff Ratio'].item(),4))

# %% [markdown]
# Link to the Git Hub Summary Table: https://github.com/ngupta23/msds_capstone/issues/84

# %% [markdown]
# ### Summary by Chain and Product

# %%
full_summary

# %% [markdown]
# ### P0 Optimizer

# %%
full_opt[outputColsOptP0]

# %% [markdown]
# ### P0+Sim Optimizer

# %%
full_opt[outputColsOptP0Sim]

# %% [markdown]
# ### Naive

# %%
full_opt[outputColsOptNaive]
