# %% [markdown]
# # Init

# %%
# %load_ext autoreload
# %autoreload 2

# %%
print("CURRENT FOLDER:")
# %pwd
# Out:
# CURRENT FOLDER:
# 'c:\\max\\Google Drive Max\\Max Shared\\Master Data Science\\2020-05 Capstone A\\msds_capstone\\analysis\\fullRuns'

# %%
import os
import glob
import sys
sys.path.append(os.environ['DEV_AUTOTS'])
sys.path.append(os.environ['CAPSTONE_PYTHON_SOURCE'])
folder = os.environ['CAPSTONE_DATA']

# %%
## Sourcing the .py with all the code##
t='"'+os.environ['CAPSTONE_PYTHON_SOURCE']+'\\fullRun\\fullRun.py'+'"'
# %run -i $t
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# Running Auto Timeseries version: 0.0.24

# %% [markdown]
# # Parameters

# %%
#Parameters

ProdCats = ['ECONOMY VODKA']
TOP_PRODUCTS = 5  # How many products to consider in the category
TOP_SIMILAR = 1  # Get TOP_SIMILAR most similar products
RUN_PERIODS = [1,2,3] # this will run AutoTS and Optimzer for speicfic periods (1 = last, 2 = second to last)

CV_NUM = 10         # number of Cross Valudations  10
OPT_CALLS = 100     # number of calls for the optimizer process   100
OPT_RND_STARTS = 20 # number of random calls for the optimizer process  20

LOG_TRANSFORM = True # Take log of 9L cases to smooth out peaks and valleys
ZERO_ADDER = 0.1 

RESAMPLE_FREQ = 'M'


# Pricing changes every 4 weeks
if RESAMPLE_FREQ == 'M':    FORECAST_PERIOD = 1 #last 4 months as test 
if RESAMPLE_FREQ == 'W':    FORECAST_PERIOD = 4 
if RESAMPLE_FREQ == '2W':   FORECAST_PERIOD = 2 

# Seasonal Period
if RESAMPLE_FREQ == 'M':    SEASONAL_PERIOD = 12  # Yearly
if RESAMPLE_FREQ == 'W':    SEASONAL_PERIOD = 13 # Quarterly (we can also take yearly = 52, but SARIMAX becomes too slow)
if RESAMPLE_FREQ == '2W':   SEASONAL_PERIOD = 13 # This becomes problematic --> for quarterly, should we take 6 biweekly periods or 7 bi-weekly periods. Instead I just took half yearly period  

COL_TIME = 'WeekDate'
COL_PREDS = ['9L Cases'] #Demand
COL_PRICE= ['Dollar Sales per 9L Case'] #Price

# %% [markdown]
# # Full Run

# %%
dataRaw = loadDataset(version=4)
ProdCat =ProdCats[0]
ChainMasters =  [''] +  dataRaw['Chain Master'].unique().tolist() 
display(ChainMasters,ProdCats)
# Out:
# ['', 'THE BARREL HOUSE', 'WESTERN BEV LIQ TX', 'SPECS']
# ['ECONOMY VODKA']

# %%
(full_models,full_opt,full_summary,full_chain_summary)  = fullRun(ProdCat = ProdCat
                                                           ,ChainMasters = ChainMasters
                                                           ,dataRaw = dataRaw
                                                           ,savePKL=True
                                                           ,saveXLS=True)
# Out:
# ==================================================
# Parameters being used...
# ==================================================
# TOP_PRODUCTS = 5
# TOP_SIMILAR = 1
# RUN_PERIODS = [1, 2, 3]
# ProdCat: ECONOMY VODKA
# ChainMasters: ['', 'THE BARREL HOUSE', 'WESTERN BEV LIQ TX', 'SPECS']
#
#
# ======================== (2020-09-13 18:46:29.613851)
# ==== Products List  ====
# ==== ECONOMY VODKA =====
# ===========  ===========
# ========================
#
#
#
# ======================= (2020-09-13 18:46:34.644850)
# ======= AUTO-TS =======
# ==== ECONOMY VODKA ====
# ==========  ===========
# ========== 1 ==========
# =======================
#
#
#
# ================== (2020-09-13 18:46:34.645850)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 BLUE PET 375M', '2': 'TEXAS SPIRIT VODKA 80  1.75L', '3': 'TAAKA VODKA 80 PET 1.75L', '4': 'TEXAS SPIRIT VODKA 80 SAZ NL 1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3']
# % of weeks without a purchase: 1.1904761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '3']
# % of weeks without a purchase: 69.04761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
# 	Product: TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
#
#
# ===================== (2020-09-13 18:48:00.286904)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#        lb_stat     lb_pvalue
# 12  248.948794  2.266370e-46
# 24  282.763358  4.861676e-46
# 48  368.538254  5.288988e-51
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  584.901182  1.773645e-117
# 24  743.424992  1.784213e-141
# 48  947.167628  2.940142e-167
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  474.857092   4.940599e-94
# 24  562.831143  1.385783e-103
# 48  697.054286  5.309923e-116
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  148.350039  1.225106e-25
# 24  166.824771  2.330111e-23
# 48  349.230594  2.409071e-47
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  15.781393   0.201455
# 24  33.696053   0.090218
# 48  44.059529   0.635010
#
# Is Data White Noise: True
#
#
# ==================== (2020-09-13 18:48:00.352906)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (83, 4) (1, 4)
# (83, 4) (1, 4)
# (83, 4) (1, 4)
# (83, 4) (1, 4)
# (58, 4) (1, 4)
#
#
# =============== (2020-09-13 18:48:00.363902)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.083730         []
# 1  1      last   0.050920         []
# 2  2      last   0.000000         []
# 3  3      mean   0.080436         []
# 4  4      mean   0.069793         []
#
#                                            All RMSEs  \
# 0  [[0.08522395141312492, 0.11059590470983931, 0....
# 1  [[0.050919719560484134, 0.058483693505752464, ...
# 2                                  [[0.0, 0.0, 0.0]]
# 3  [[0.08442928271847924, 0.10271666862052284, 0....
# 4  [[0.0816329202384487, 0.10985594998750277, 0.0...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 2  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 4  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-13 18:48:01.273905)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed: 11.0min remaining: 16.4min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed: 20.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-13 19:08:13.813939)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed: 13.2min remaining: 19.9min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed: 18.0min finished
# =================== (2020-09-13 19:26:13.111013)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-13 19:26:13.131013)
# ====== OPTIMIZER ======
# ==== ECONOMY VODKA ====
# ==========  ===========
# ========== 1 ==========
# =======================
#
#
#
# =========================== (2020-09-13 19:26:13.131013)
# ==== Running Optimizer ====
# ====== ECONOMY VODKA ======
# ============  =============
# ============ 1 ============
# ===========================
#
#
#
# ================== (2020-09-13 19:26:13.137012)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 BLUE PET 375M', '2': 'TEXAS SPIRIT VODKA 80  1.75L', '3': 'TAAKA VODKA 80 PET 1.75L', '4': 'TEXAS SPIRIT VODKA 80 SAZ NL 1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3']
# % of weeks without a purchase: 1.1904761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '3']
# % of weeks without a purchase: 69.04761904761905
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
# 	Product: TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
#
#
# ==================== (2020-09-13 19:27:23.495054)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (83, 4) (1, 4)
# (83, 4) (1, 4)
# (83, 4) (1, 4)
# (83, 4) (1, 4)
# (58, 4) (1, 4)
#
#
# ======================== (2020-09-13 19:27:23.507060)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-13 19:27:23.536056)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False, False, False]
#
#
# =============== (2020-09-13 19:27:23.541057)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-13 19:27:23.567058)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-13 19:27:23.569057)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-13 19:27:23.570056)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-13 19:27:24.125057)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-13 19:27:24.131055)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-13 19:30:08.659055)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-13 19:30:08.892054)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-13 19:30:08.893054)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-13 19:30:09.124052)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-13 19:30:09.132053)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-13 19:33:05.152054)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-13 19:33:05.454054)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-13 19:33:05.462052)
# ======= AUTO-TS =======
# ==== ECONOMY VODKA ====
# ==========  ===========
# ========== 2 ==========
# =======================
#
#
#
# ================== (2020-09-13 19:33:05.462052)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 BLUE PET 375M', '2': 'TEXAS SPIRIT VODKA 80  1.75L', '3': 'TAAKA VODKA 80 PET 1.75L', '4': 'TEXAS SPIRIT VODKA 80 SAZ NL 1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3']
# % of weeks without a purchase: 1.2048192771084338
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '3']
# % of weeks without a purchase: 68.67469879518072
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
# 	Product: TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
#
#
# ===================== (2020-09-13 19:34:05.126052)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#        lb_stat     lb_pvalue
# 12  247.379998  4.812566e-46
# 24  281.567711  8.439708e-46
# 48  366.781603  1.141278e-50
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  574.606302  2.792191e-115
# 24  727.477625  4.083848e-138
# 48  944.375636  1.109735e-166
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  468.018038   1.404414e-92
# 24  554.010494  9.591640e-102
# 48  696.468177  6.982057e-116
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  144.742513  6.589309e-25
# 24  162.572274  1.476101e-22
# 48  338.164450  2.919586e-45
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  15.557680   0.212345
# 24  33.693867   0.090259
# 48  45.714515   0.566979
#
# Is Data White Noise: True
#
#
# ==================== (2020-09-13 19:34:05.158056)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (82, 4) (1, 4)
# (82, 4) (1, 4)
# (82, 4) (1, 4)
# (82, 4) (1, 4)
# (57, 4) (1, 4)
#
#
# =============== (2020-09-13 19:34:05.174056)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.077936         []
# 1  1      last   0.049104         []
# 2  2      last   0.000000         []
# 3  3      mean   0.087216         []
# 4  4      mean   0.067484         []
#
#                                            All RMSEs  \
# 0  [[0.08907681622057902, 0.11385458510024087, 0....
# 1  [[0.04910363192681037, 0.05961976914518541, 0....
# 2                                  [[0.0, 0.0, 0.0]]
# 3  [[0.09339313017889535, 0.10233695646087668, 0....
# 4  [[0.09617536421503817, 0.10367899808494474, 0....
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 2  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 4  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-13 19:34:05.943055)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  9.7min remaining: 14.5min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed: 18.7min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-13 19:52:48.258060)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed: 11.6min remaining: 17.3min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed: 19.9min finished
# =================== (2020-09-13 20:12:40.861052)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-13 20:12:40.873054)
# ====== OPTIMIZER ======
# ==== ECONOMY VODKA ====
# ==========  ===========
# ========== 2 ==========
# =======================
#
#
#
# =========================== (2020-09-13 20:12:40.873054)
# ==== Running Optimizer ====
# ====== ECONOMY VODKA ======
# ============  =============
# ============ 2 ============
# ===========================
#
#
#
# ================== (2020-09-13 20:12:40.877053)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 BLUE PET 375M', '2': 'TEXAS SPIRIT VODKA 80  1.75L', '3': 'TAAKA VODKA 80 PET 1.75L', '4': 'TEXAS SPIRIT VODKA 80 SAZ NL 1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3']
# % of weeks without a purchase: 1.2048192771084338
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '3']
# % of weeks without a purchase: 68.67469879518072
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
# 	Product: TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
#
#
# ==================== (2020-09-13 20:13:33.676054)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (82, 4) (1, 4)
# (82, 4) (1, 4)
# (82, 4) (1, 4)
# (82, 4) (1, 4)
# (57, 4) (1, 4)
#
#
# ======================== (2020-09-13 20:13:33.688053)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-13 20:13:33.710052)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False, False, False]
#
#
# =============== (2020-09-13 20:13:33.713059)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-13 20:13:33.726054)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-13 20:13:33.727052)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-13 20:13:33.728054)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-13 20:13:37.685056)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-13 20:13:37.691052)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-13 20:20:25.945058)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-13 20:20:27.426055)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-13 20:20:27.427056)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-13 20:20:28.457053)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-13 20:20:28.464055)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-13 20:26:23.704056)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-13 20:26:24.237054)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-13 20:26:24.245054)
# ======= AUTO-TS =======
# ==== ECONOMY VODKA ====
# ==========  ===========
# ========== 3 ==========
# =======================
#
#
#
# ================== (2020-09-13 20:26:24.245054)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 BLUE PET 375M', '2': 'TEXAS SPIRIT VODKA 80  1.75L', '3': 'TAAKA VODKA 80 PET 1.75L', '4': 'TEXAS SPIRIT VODKA 80 SAZ NL 1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '3']
# % of weeks without a purchase: 68.29268292682927
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
# 	Product: TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
#
#
# ===================== (2020-09-13 20:27:21.218056)
# ==== WHITE NOISE ====
# =========  ==========
# =====================
#
#        lb_stat     lb_pvalue
# 12  243.950101  2.495194e-45
# 24  277.452128  5.626127e-45
# 48  363.173548  5.530118e-50
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  563.083839  8.020215e-113
# 24  710.497889  1.533447e-134
# 48  939.687445  1.031921e-165
#
# Is Data White Noise: False
#        lb_stat      lb_pvalue
# 12  461.149000   4.046888e-91
# 24  545.150471  6.746748e-100
# 48  696.525463  6.797717e-116
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  141.032457  3.706001e-24
# 24  158.246146  9.582502e-22
# 48  325.345702  7.337201e-43
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  15.076991   0.237253
# 24  32.806008   0.108233
# 48  43.730748   0.648301
#
# Is Data White Noise: True
#
#
# ==================== (2020-09-13 20:27:21.247056)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (81, 4) (1, 4)
# (81, 4) (1, 4)
# (81, 4) (1, 4)
# (81, 4) (1, 4)
# (56, 4) (1, 4)
#
#
# =============== (2020-09-13 20:27:21.252053)
# ==== NAIVE ====
# ======  =======
# ===============
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      mean   0.078022         []
# 1  1      last   0.044826         []
# 2  2      last   0.000000         []
# 3  3      mean   0.076948         []
# 4  4      mean   0.075211         []
#
#                                            All RMSEs  \
# 0  [[0.10614956572430416, 0.1364306802567358, 0.0...
# 1  [[0.04482627686032599, 0.061881124720379786, 0...
# 2                                  [[0.0, 0.0, 0.0]]
# 3  [[0.0987077256986276, 0.10351490018633347, 0.0...
# 4  [[0.10202854443437681, 0.11030437140568901, 0....
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 1  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 2  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 4  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-13 20:27:21.878051)
# ==== Multivar P0 ====
# =========  ==========
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed: 12.5min remaining: 18.8min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed: 18.4min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-13 20:45:48.038055)
# ==== Multivar P0+Sim ====
# ===========  ============
# =========================
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed: 12.5min remaining: 18.8min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed: 17.9min finished
# =================== (2020-09-13 21:03:44.089678)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-13 21:03:44.117677)
# ====== OPTIMIZER ======
# ==== ECONOMY VODKA ====
# ==========  ===========
# ========== 3 ==========
# =======================
#
#
#
# =========================== (2020-09-13 21:03:44.118677)
# ==== Running Optimizer ====
# ====== ECONOMY VODKA ======
# ============  =============
# ============ 3 ============
# ===========================
#
#
#
# ================== (2020-09-13 21:03:44.124676)
# ==== GET DATA ====
# ========  ========
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 BLUE PET 375M', '2': 'TEXAS SPIRIT VODKA 80  1.75L', '3': 'TAAKA VODKA 80 PET 1.75L', '4': 'TEXAS SPIRIT VODKA 80 SAZ NL 1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '3']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '3']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '3']
# % of weeks without a purchase: 68.29268292682927
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0']
# % of weeks without a purchase: 0.0
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TEXAS SPIRIT VODKA 80  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
# 	Product: TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
#
#
# ==================== (2020-09-13 21:04:42.786676)
# ==== TEST/TRAIN ====
# =========  =========
# ====================
#
# (81, 4) (1, 4)
# (81, 4) (1, 4)
# (81, 4) (1, 4)
# (81, 4) (1, 4)
# (56, 4) (1, 4)
#
#
# ======================== (2020-09-13 21:04:42.797674)
# ==== NAIVE FORECAST ====
# ===========  ===========
# ========================
#
#
#
# ============== (2020-09-13 21:04:42.820674)
# ==== MASK ====
# ======  ======
# ==============
#
# Mask: [False, False, False, False, False]
#
#
# =============== (2020-09-13 21:04:42.824676)
# ==== SPACE ====
# ======  =======
# ===============
#
#
#
# ==================== (2020-09-13 21:04:42.837676)
# ==== Test Index ====
# =========  =========
# ====================
#
#
#
# ========================= (2020-09-13 21:04:42.839676)
# ==== GET FUNCTION P0 ====
# ===========  ============
# =========================
#
#
#
# ====================================== (2020-09-13 21:04:42.840675)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ==================  ==================
# ======================================
#
#
#
# =================== (2020-09-13 21:04:48.538675)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ======================= (2020-09-13 21:04:48.543674)
# ==== OPTIMIZING P0 ====
# ==========  ===========
# =======================
#
#
#
# =================== (2020-09-13 21:11:00.846795)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# ============================= (2020-09-13 21:11:01.475794)
# ==== GET FUNCTION P0+Sim ====
# =============  ==============
# =============================
#
#
#
# ========================================== (2020-09-13 21:11:01.476793)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ====================  ====================
# ==========================================
#
#
#
# =================== (2020-09-13 21:11:01.897794)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =========================== (2020-09-13 21:11:01.905792)
# ==== OPTIMIZING P0+Sim ====
# ============  =============
# ===========================
#
#
#
# =================== (2020-09-13 21:18:29.152825)
# ==== OUTPUT P0 ====
# ========  =========
# ===================
#
#
#
# =================== (2020-09-13 21:18:30.816826)
# ==== COMPLETED ====
# ========  =========
# ===================
#
#
#
# ========================== (2020-09-13 21:18:30.826824)
# ===== Products List  =====
# ===== ECONOMY VODKA ======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 21:18:32.162826)
# ======== AUTO-TS =========
# ===== ECONOMY VODKA ======
# ==== THE BARREL HOUSE ====
# =========== 1 ============
# ==========================
#
#
#
# ========================== (2020-09-13 21:18:32.163823)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80 BLUE PET 375M', '1': 'TAAKA VODKA 80 BLUE PET 200M', '2': 'TAAKA VODKA 80  1L', '3': 'DOBRA VODKA  1.75L', '4': 'TAAKA VODKA 80 PET 1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 1.694915254237288
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 200M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 1.694915254237288
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 6.779661016949152
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: DOBRA VODKA  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0']
# % of weeks without a purchase: 28.57142857142857
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0']
# % of weeks without a purchase: 4.761904761904762
# Log Transforming
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TAAKA VODKA 80 BLUE PET 200M
# 	Product: TAAKA VODKA 80  1L
# 	Product: DOBRA VODKA  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
#
#
# ========================== (2020-09-13 21:19:25.509826)
# ====== WHITE NOISE =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#        lb_stat     lb_pvalue
# 12  141.970557  2.395431e-24
# 24  144.452747  3.527878e-19
# 48  320.340879  6.288716e-42
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  21.978242   0.037764
# 24  27.494357   0.281943
# 48  52.638641   0.299248
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12   44.122049  1.455748e-05
# 24   45.996717  4.431043e-03
# 48  112.281342  4.570812e-07
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  105.152166  5.416764e-17
# 24  119.277224  1.304825e-14
# 48  154.987549  3.429672e-13
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  44.506454   0.000013
# 24  59.456046   0.000076
#
# Is Data White Noise: False
#
#
# ========================== (2020-09-13 21:19:25.537827)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (58, 4) (1, 4)
# (58, 4) (1, 4)
# (58, 4) (1, 4)
# (83, 4) (1, 4)
# (41, 4) (1, 4)
#
#
# ========================== (2020-09-13 21:19:25.541824)
# ========= NAIVE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      last   0.068911         []
# 1  1      mean   0.165948         []
# 2  2      mean   0.099268         []
# 3  3      mean   0.531778         []
# 4  4      mean   0.170241         []
#
#                                            All RMSEs  \
# 0  [[0.06891113023575937, 0.09474241449242278, 0....
# 1  [[0.2390439979625162, 0.25545500613475297, 0.1...
# 2  [[0.12248442676716172, 0.18448330474563132, 0....
# 3  [[0.5549559305354916, 0.5833145410737691, 0.53...
# 4  [[0.2540382357442957, 0.19871113167781246, 0.1...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 3  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 4  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ========================== (2020-09-13 21:19:26.136826)
# ====== Multivar P0 =======
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  9.9min remaining: 14.8min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed: 15.4min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================== (2020-09-13 21:34:50.123826)
# ==== Multivar P0+Sim =====
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed: 13.3min remaining: 19.9min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed: 19.1min finished
# ========================== (2020-09-13 21:53:55.042823)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 21:53:55.128825)
# ======= OPTIMIZER ========
# ===== ECONOMY VODKA ======
# ==== THE BARREL HOUSE ====
# =========== 1 ============
# ==========================
#
#
#
# =========================== (2020-09-13 21:53:55.129825)
# ==== Running Optimizer ====
# ====== ECONOMY VODKA ======
# ==== THE BARREL HOUSE =====
# ============ 1 ============
# ===========================
#
#
#
# ========================== (2020-09-13 21:53:55.135832)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80 BLUE PET 375M', '1': 'TAAKA VODKA 80 BLUE PET 200M', '2': 'TAAKA VODKA 80  1L', '3': 'DOBRA VODKA  1.75L', '4': 'TAAKA VODKA 80 PET 1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 1.694915254237288
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 200M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 1.694915254237288
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 6.779661016949152
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: DOBRA VODKA  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0']
# % of weeks without a purchase: 28.57142857142857
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0']
# % of weeks without a purchase: 4.761904761904762
# Log Transforming
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TAAKA VODKA 80 BLUE PET 200M
# 	Product: TAAKA VODKA 80  1L
# 	Product: DOBRA VODKA  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
#
#
# ========================== (2020-09-13 21:54:56.546827)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (58, 4) (1, 4)
# (58, 4) (1, 4)
# (58, 4) (1, 4)
# (83, 4) (1, 4)
# (41, 4) (1, 4)
#
#
# ========================== (2020-09-13 21:54:56.558827)
# ===== NAIVE FORECAST =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 21:54:56.584827)
# ========== MASK ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
# Mask: [False, False, False, False, False]
#
#
# ========================== (2020-09-13 21:54:56.589825)
# ========= SPACE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
# Min Limit is >= than Max Limit, setting them near median (+-5%)
#
#
# ========================== (2020-09-13 21:54:56.604825)
# ======= Test Index =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 21:54:56.605825)
# ==== GET FUNCTION P0 =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ====================================== (2020-09-13 21:54:56.606825)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ========== THE BARREL HOUSE ==========
# ======================================
#
#
#
# ========================== (2020-09-13 21:54:56.830830)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 21:54:56.836825)
# ===== OPTIMIZING P0 ======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:01:02.170824)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ============================= (2020-09-13 22:01:02.356824)
# ==== GET FUNCTION P0+Sim ====
# ===== THE BARREL HOUSE ======
# =============================
#
#
#
# ========================================== (2020-09-13 22:01:02.357824)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ============ THE BARREL HOUSE ============
# ==========================================
#
#
#
# ========================== (2020-09-13 22:01:02.533826)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# =========================== (2020-09-13 22:01:02.541823)
# ==== OPTIMIZING P0+Sim ====
# ==== THE BARREL HOUSE =====
# ===========================
#
#
#
# ========================== (2020-09-13 22:06:47.313825)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:06:47.514828)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:06:47.524826)
# ======== AUTO-TS =========
# ===== ECONOMY VODKA ======
# ==== THE BARREL HOUSE ====
# =========== 2 ============
# ==========================
#
#
#
# ========================== (2020-09-13 22:06:47.525826)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80 BLUE PET 375M', '1': 'TAAKA VODKA 80 BLUE PET 200M', '2': 'TAAKA VODKA 80  1L', '3': 'DOBRA VODKA  1.75L', '4': 'TAAKA VODKA 80 PET 1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 1.7241379310344827
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 200M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 1.7241379310344827
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 6.896551724137931
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: DOBRA VODKA  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0']
# % of weeks without a purchase: 28.915662650602407
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0']
# % of weeks without a purchase: 4.878048780487805
# Log Transforming
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TAAKA VODKA 80 BLUE PET 200M
# 	Product: TAAKA VODKA 80  1L
# 	Product: DOBRA VODKA  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
#
#
# ========================== (2020-09-13 22:07:48.946827)
# ====== WHITE NOISE =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#        lb_stat     lb_pvalue
# 12  137.410866  1.993797e-23
# 24  139.910786  2.418875e-18
# 48  322.778598  2.210050e-42
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  21.669742   0.041392
# 24  27.152575   0.297392
# 48  52.791525   0.294182
#
# Is Data White Noise: True
#        lb_stat     lb_pvalue
# 12   42.786664  2.453685e-05
# 24   44.707020  6.307408e-03
# 48  111.872160  5.168754e-07
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  104.052037  8.917711e-17
# 24  118.103635  2.109057e-14
# 48  153.752344  5.308252e-13
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  42.697012   0.000025
# 24  58.885104   0.000092
#
# Is Data White Noise: False
#
#
# ========================== (2020-09-13 22:07:48.987828)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (57, 4) (1, 4)
# (57, 4) (1, 4)
# (57, 4) (1, 4)
# (82, 4) (1, 4)
# (40, 4) (1, 4)
#
#
# ========================== (2020-09-13 22:07:48.999827)
# ========= NAIVE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
#   ID Best Type  Best RMSE All Naives  \
# 0  0      last   0.055124         []
# 1  1      mean   0.206669         []
# 2  2      mean   0.094367         []
# 3  3      last   0.583315         []
# 4  4      mean   0.169375         []
#
#                                            All RMSEs  \
# 0  [[0.055123576776570093, 0.0992941627475532, 0....
# 1  [[0.2776588463567642, 0.2832827480917138, 0.20...
# 2  [[0.1282258925607897, 0.17212401268673627, 0.0...
# 3  [[0.5833145410737691, 0.6936949131693646, 0.59...
# 4  [[0.2528394494374266, 0.19871113167781249, 0.1...
#
#                        All Types                              Best Naive
# 0  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 1  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 2  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
# 3  [[last, seasonal_last, mean]]                   NaiveForecaster(sp=4)
# 4  [[last, seasonal_last, mean]]  NaiveForecaster(sp=4, strategy='mean')
#
#
# ========================== (2020-09-13 22:07:49.653825)
# ====== Multivar P0 =======
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed: 12.4min remaining: 18.7min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed: 18.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================== (2020-09-13 22:25:47.482356)
# ==== Multivar P0+Sim =====
# ==== THE BARREL HOUSE ====
# ==========================
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed: 10.3min remaining: 15.4min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed: 16.2min finished
# ========================== (2020-09-13 22:41:58.233352)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:41:58.316352)
# ======= OPTIMIZER ========
# ===== ECONOMY VODKA ======
# ==== THE BARREL HOUSE ====
# =========== 2 ============
# ==========================
#
#
#
# =========================== (2020-09-13 22:41:58.317351)
# ==== Running Optimizer ====
# ====== ECONOMY VODKA ======
# ==== THE BARREL HOUSE =====
# ============ 2 ============
# ===========================
#
#
#
# ========================== (2020-09-13 22:41:58.325353)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80 BLUE PET 375M', '1': 'TAAKA VODKA 80 BLUE PET 200M', '2': 'TAAKA VODKA 80  1L', '3': 'DOBRA VODKA  1.75L', '4': 'TAAKA VODKA 80 PET 1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 1.7241379310344827
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 200M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 1.7241379310344827
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 6.896551724137931
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: DOBRA VODKA  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0']
# % of weeks without a purchase: 28.915662650602407
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0']
# % of weeks without a purchase: 4.878048780487805
# Log Transforming
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: TAAKA VODKA 80 BLUE PET 200M
# 	Product: TAAKA VODKA 80  1L
# 	Product: DOBRA VODKA  1.75L
# 	Product: TAAKA VODKA 80 PET 1.75L
#
#
# ========================== (2020-09-13 22:42:53.811353)
# ======= TEST/TRAIN =======
# ==== THE BARREL HOUSE ====
# ==========================
#
# (57, 4) (1, 4)
# (57, 4) (1, 4)
# (57, 4) (1, 4)
# (82, 4) (1, 4)
# (40, 4) (1, 4)
#
#
# ========================== (2020-09-13 22:42:53.818353)
# ===== NAIVE FORECAST =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:42:53.843353)
# ========== MASK ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
# Mask: [False, False, False, False, False]
#
#
# ========================== (2020-09-13 22:42:53.846353)
# ========= SPACE ==========
# ==== THE BARREL HOUSE ====
# ==========================
#
# Min Limit is >= than Max Limit, setting them near median (+-5%)
#
#
# ========================== (2020-09-13 22:42:53.862352)
# ======= Test Index =======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:42:53.863353)
# ==== GET FUNCTION P0 =====
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ====================================== (2020-09-13 22:42:53.863353)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# ========== THE BARREL HOUSE ==========
# ======================================
#
#
#
# ========================== (2020-09-13 22:42:54.070352)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:42:54.077352)
# ===== OPTIMIZING P0 ======
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:47:29.052353)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ============================= (2020-09-13 22:47:29.301352)
# ==== GET FUNCTION P0+Sim ====
# ===== THE BARREL HOUSE ======
# =============================
#
#
#
# ========================================== (2020-09-13 22:47:29.302352)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ============ THE BARREL HOUSE ============
# ==========================================
#
#
#
# ========================== (2020-09-13 22:47:29.541353)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# =========================== (2020-09-13 22:47:29.548353)
# ==== OPTIMIZING P0+Sim ====
# ==== THE BARREL HOUSE =====
# ===========================
#
#
#
# ========================== (2020-09-13 22:51:30.761182)
# ======= OUTPUT P0 ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:51:30.981181)
# ======= COMPLETED ========
# ==== THE BARREL HOUSE ====
# ==========================
#
#
#
# ========================== (2020-09-13 22:51:30.997182)
# ======== AUTO-TS =========
# ===== ECONOMY VODKA ======
# ==== THE BARREL HOUSE ====
# =========== 3 ============
# ==========================
#
#
#
# ========================== (2020-09-13 22:51:30.998181)
# ======== GET DATA ========
# ==== THE BARREL HOUSE ====
# ==========================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80 BLUE PET 375M', '1': 'TAAKA VODKA 80 BLUE PET 200M', '2': 'TAAKA VODKA 80  1L', '3': 'DOBRA VODKA  1.75L', '4': 'TAAKA VODKA 80 PET 1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 1.7543859649122806
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 200M
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 1.7543859649122806
# resampling to  M
#
#
#
# --------------------------------------------------
# ...
# ==== OPTIMIZING P0 ====
# ======== SPECS ========
# =======================
#
#
#
# =================== (2020-09-14 04:46:05.968794)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ============================= (2020-09-14 04:46:07.454794)
# ==== GET FUNCTION P0+Sim ====
# =========== SPECS ===========
# =============================
#
#
#
# ========================================== (2020-09-14 04:46:07.454794)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ================= SPECS ==================
# ==========================================
#
#
#
# =================== (2020-09-14 04:46:08.038794)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =========================== (2020-09-14 04:46:08.046795)
# ==== OPTIMIZING P0+Sim ====
# ========== SPECS ==========
# ===========================
#
#
#
# =================== (2020-09-14 04:48:31.681445)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =================== (2020-09-14 04:48:32.587444)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ======================= (2020-09-14 04:48:32.616445)
# ======= AUTO-TS =======
# ==== ECONOMY VODKA ====
# ======== SPECS ========
# ========== 3 ==========
# =======================
#
#
#
# ================== (2020-09-14 04:48:32.616445)
# ==== GET DATA ====
# ===== SPECS ======
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 PET 1.75L', '2': 'TAAKA VODKA 80 BLUE PET 375M', '3': 'MCCORMICK CHERRY VODKA 60  1L', '4': 'DOBRA VODKA  1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: MCCORMICK CHERRY VODKA 60  1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0']
# % of weeks without a purchase: 28.39506172839506
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: DOBRA VODKA  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0']
# % of weeks without a purchase: 14.814814814814813
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 PET 1.75L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: MCCORMICK CHERRY VODKA 60  1L
# 	Product: DOBRA VODKA  1.75L
#
#
# ===================== (2020-09-14 04:49:43.535967)
# ==== WHITE NOISE ====
# ======= SPECS =======
# =====================
#
#        lb_stat     lb_pvalue
# 12  163.850364  8.614761e-29
# 24  202.851035  2.932294e-30
# 48  302.430383  1.310197e-38
#
# Is Data White Noise: False
#        lb_stat     lb_pvalue
# 12  203.867388  5.185416e-37
# 24  249.138534  2.445714e-39
# 48  386.780036  1.745507e-54
#
# Is Data White Noise: False
#        lb_stat  lb_pvalue
# 12   41.146569   0.000046
# 24   60.607680   0.000052
# 48  103.105730   0.000007
#
# Is Data White Noise: False
#       lb_stat  lb_pvalue
# 12  12.395058   0.414496
# 24  22.052180   0.576152
# 48  51.642102   0.333451
#
# Is Data White Noise: True
#       lb_stat  lb_pvalue
# 12  24.341688   0.018270
# 24  33.409284   0.095728
# 48  82.146329   0.001561
#
# Is Data White Noise: True
#
#
# ==================== (2020-09-14 04:49:43.565967)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (81, 4) (1, 4)
# (81, 4) (1, 4)
# (81, 4) (1, 4)
# (80, 4) (1, 4)
# (80, 4) (1, 4)
#
#
# =============== (2020-09-14 04:49:43.570966)
# ==== NAIVE ====
# ==== SPECS ====
# ===============
#
#   ID      Best Type  Best RMSE All Naives  \
# 0  0           mean   0.107768         []
# 1  1           mean   0.136330         []
# 2  2           mean   0.121653         []
# 3  3  seasonal_last   0.432273         []
# 4  4           mean   0.360263         []
#
#                                            All RMSEs  \
# 0  [[0.13456120941276825, 0.187951813296838, 0.10...
# 1  [[0.21541297336857784, 0.22034399791646134, 0....
# 2  [[0.17742034252670738, 0.1589870135780978, 0.1...
# 3  [[0.49069171944604034, 0.4322727246195653, 0.6...
# 4  [[0.46158729599658893, 0.4079241449775477, 0.3...
#
#                        All Types  \
# 0  [[last, seasonal_last, mean]]
# 1  [[last, seasonal_last, mean]]
# 2  [[last, seasonal_last, mean]]
# 3  [[last, seasonal_last, mean]]
# 4  [[last, seasonal_last, mean]]
#
#                                         Best Naive
# 0           NaiveForecaster(sp=4, strategy='mean')
# 1           NaiveForecaster(sp=4, strategy='mean')
# 2           NaiveForecaster(sp=4, strategy='mean')
# 3  NaiveForecaster(sp=4, strategy='seasonal_last')
# 4           NaiveForecaster(sp=4, strategy='mean')
#
#
# ===================== (2020-09-14 04:49:44.404967)
# ==== Multivar P0 ====
# ======= SPECS =======
# =====================
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  9.2min remaining: 13.7min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed: 10.5min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ========================= (2020-09-14 05:00:12.417991)
# ==== Multivar P0+Sim ====
# ========= SPECS =========
# =========================
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  5.2min remaining:  7.8min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  6.2min finished
# =================== (2020-09-14 05:06:27.032328)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ======================= (2020-09-14 05:06:27.141328)
# ====== OPTIMIZER ======
# ==== ECONOMY VODKA ====
# ======== SPECS ========
# ========== 3 ==========
# =======================
#
#
#
# =========================== (2020-09-14 05:06:27.142330)
# ==== Running Optimizer ====
# ====== ECONOMY VODKA ======
# ========== SPECS ==========
# ============ 3 ============
# ===========================
#
#
#
# ================== (2020-09-14 05:06:27.150327)
# ==== GET DATA ====
# ===== SPECS ======
# ==================
#
# resampling to  M
# Decoder: {'0': 'TAAKA VODKA 80  1L', '1': 'TAAKA VODKA 80 PET 1.75L', '2': 'TAAKA VODKA 80 BLUE PET 375M', '3': 'MCCORMICK CHERRY VODKA 60  1L', '4': 'DOBRA VODKA  1.75L'}
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 PET 1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 0.0
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: TAAKA VODKA 80 BLUE PET 375M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '0']
# % of weeks without a purchase: 1.2195121951219512
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: MCCORMICK CHERRY VODKA 60  1L
# --------------------------------------------------
# Exogenous Price Columns: ['3', '0']
# % of weeks without a purchase: 28.39506172839506
# resampling to  M
#
#
#
# --------------------------------------------------
# Product: DOBRA VODKA  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['4', '0']
# % of weeks without a purchase: 14.814814814814813
# Log Transforming
# 	Product: TAAKA VODKA 80  1L
# 	Product: TAAKA VODKA 80 PET 1.75L
# 	Product: TAAKA VODKA 80 BLUE PET 375M
# 	Product: MCCORMICK CHERRY VODKA 60  1L
# 	Product: DOBRA VODKA  1.75L
#
#
# ==================== (2020-09-14 05:07:44.237885)
# ==== TEST/TRAIN ====
# ====== SPECS =======
# ====================
#
# (81, 4) (1, 4)
# (81, 4) (1, 4)
# (81, 4) (1, 4)
# (80, 4) (1, 4)
# (80, 4) (1, 4)
#
#
# ======================== (2020-09-14 05:07:44.249884)
# ==== NAIVE FORECAST ====
# ======== SPECS =========
# ========================
#
#
#
# =============== (2020-09-14 05:07:44.282890)
# ==== MASK =====
# ==== SPECS ====
# ===============
#
# Mask: [False, False, False, False, False]
#
#
# =============== (2020-09-14 05:07:44.286886)
# ==== SPACE ====
# ==== SPECS ====
# ===============
#
# Min Limit is >= than Max Limit, setting them near median (+-5%)
#
#
# ==================== (2020-09-14 05:07:44.302884)
# ==== Test Index ====
# ====== SPECS =======
# ====================
#
#
#
# ========================= (2020-09-14 05:07:44.303884)
# ==== GET FUNCTION P0 ====
# ========= SPECS =========
# =========================
#
#
#
# ====================================== (2020-09-14 05:07:44.304884)
# ==== GET NON-OPTIMIZED REVENUE P0 ====
# =============== SPECS ================
# ======================================
#
# Building Forecast dataframe. Forecast Period = 1
#
#
# =================== (2020-09-14 05:07:48.091889)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# ======================= (2020-09-14 05:07:48.119884)
# ==== OPTIMIZING P0 ====
# ======== SPECS ========
# =======================
#
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
# Building Forecast dataframe. Forecast Period = 1
#
#
# =================== (2020-09-14 05:17:42.195693)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
# Building Forecast dataframe. Forecast Period = 1
#
#
# ============================= (2020-09-14 05:17:46.043691)
# ==== GET FUNCTION P0+Sim ====
# =========== SPECS ===========
# =============================
#
#
#
# ========================================== (2020-09-14 05:17:46.044691)
# ==== GET NON-OPTIMIZED REVENUE P0+Sim ====
# ================= SPECS ==================
# ==========================================
#
#
#
# =================== (2020-09-14 05:17:46.965692)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =========================== (2020-09-14 05:17:46.972690)
# ==== OPTIMIZING P0+Sim ====
# ========== SPECS ==========
# ===========================
#
#
#
# =================== (2020-09-14 05:22:26.707692)
# ==== OUTPUT P0 ====
# ====== SPECS ======
# ===================
#
#
#
# =================== (2020-09-14 05:22:26.989692)
# ==== COMPLETED ====
# ====== SPECS ======
# ===================
#
#
#
# ========================== (2020-09-14 05:22:27.011695)
# ==== Saving to PICKLE ====
# ===== ECONOMY VODKA ======
# ==========================
#
# Pickle File  full_models_ECONOMY VODKA_Prod5_Sim1_Per123.pkl  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns
# Pickle File  full_opt_ECONOMY VODKA_Prod5_Sim1_Per123.pkl  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns
#
#
# ========================= (2020-09-14 05:22:27.392694)
# ==== Saving to EXCEL ====
# ===== ECONOMY VODKA =====
# =========================
#
# EXCEL File  Output_ECONOMY VODKA_Prod5_Sim1_Per123.xlsx  saved in filder:  c:\max\Google Drive Max\Max Shared\Master Data Science\2020-05 Capstone A\msds_capstone\analysis\fullRuns

# %% [markdown]
# # Print out

# %% [markdown]
# ## Models

# %%
full_models[outputColsModels]
# Out:
#           Chain Master                             Product  Period to Last  \
# 0                                       TAAKA VODKA 80  1L               1
# 5                                       TAAKA VODKA 80  1L               2
# 10                                      TAAKA VODKA 80  1L               3
# 1                             TAAKA VODKA 80 BLUE PET 375M               1
# 6                             TAAKA VODKA 80 BLUE PET 375M               2
# 11                            TAAKA VODKA 80 BLUE PET 375M               3
# 3                                 TAAKA VODKA 80 PET 1.75L               1
# 8                                 TAAKA VODKA 80 PET 1.75L               2
# 13                                TAAKA VODKA 80 PET 1.75L               3
# 2                             TEXAS SPIRIT VODKA 80  1.75L               1
# 7                             TEXAS SPIRIT VODKA 80  1.75L               2
# 12                            TEXAS SPIRIT VODKA 80  1.75L               3
# 4                       TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               1
# 9                       TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               2
# 14                      TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               3
# 49               SPECS                  DOBRA VODKA  1.75L               1
# 54               SPECS                  DOBRA VODKA  1.75L               2
# 59               SPECS                  DOBRA VODKA  1.75L               3
# 48               SPECS       MCCORMICK CHERRY VODKA 60  1L               1
# 53               SPECS       MCCORMICK CHERRY VODKA 60  1L               2
# 58               SPECS       MCCORMICK CHERRY VODKA 60  1L               3
# 45               SPECS                  TAAKA VODKA 80  1L               1
# 50               SPECS                  TAAKA VODKA 80  1L               2
# 55               SPECS                  TAAKA VODKA 80  1L               3
# 47               SPECS        TAAKA VODKA 80 BLUE PET 375M               1
# 52               SPECS        TAAKA VODKA 80 BLUE PET 375M               2
# 57               SPECS        TAAKA VODKA 80 BLUE PET 375M               3
# 46               SPECS            TAAKA VODKA 80 PET 1.75L               1
# 51               SPECS            TAAKA VODKA 80 PET 1.75L               2
# 56               SPECS            TAAKA VODKA 80 PET 1.75L               3
# 18    THE BARREL HOUSE                  DOBRA VODKA  1.75L               1
# 23    THE BARREL HOUSE                  DOBRA VODKA  1.75L               2
# 28    THE BARREL HOUSE                  DOBRA VODKA  1.75L               3
# 17    THE BARREL HOUSE                  TAAKA VODKA 80  1L               1
# 22    THE BARREL HOUSE                  TAAKA VODKA 80  1L               2
# 27    THE BARREL HOUSE                  TAAKA VODKA 80  1L               3
# 16    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 200M               1
# 21    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 200M               2
# 26    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 200M               3
# 15    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 375M               1
# 20    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 375M               2
# 25    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 375M               3
# 19    THE BARREL HOUSE            TAAKA VODKA 80 PET 1.75L               1
# 24    THE BARREL HOUSE            TAAKA VODKA 80 PET 1.75L               2
# 29    THE BARREL HOUSE            TAAKA VODKA 80 PET 1.75L               3
# 31  WESTERN BEV LIQ TX                  TAAKA VODKA 80  1L               1
# 36  WESTERN BEV LIQ TX                  TAAKA VODKA 80  1L               2
# 41  WESTERN BEV LIQ TX                  TAAKA VODKA 80  1L               3
# 30  WESTERN BEV LIQ TX        TAAKA VODKA 80 BLUE PET 375M               1
# 35  WESTERN BEV LIQ TX        TAAKA VODKA 80 BLUE PET 375M               2
# 40  WESTERN BEV LIQ TX        TAAKA VODKA 80 BLUE PET 375M               3
# 33  WESTERN BEV LIQ TX            TAAKA VODKA 80 PET 1.75L               1
# 38  WESTERN BEV LIQ TX            TAAKA VODKA 80 PET 1.75L               2
# 43  WESTERN BEV LIQ TX            TAAKA VODKA 80 PET 1.75L               3
# 32  WESTERN BEV LIQ TX        TEXAS SPIRIT VODKA 80  1.75L               1
# 37  WESTERN BEV LIQ TX        TEXAS SPIRIT VODKA 80  1.75L               2
# 42  WESTERN BEV LIQ TX        TEXAS SPIRIT VODKA 80  1.75L               3
# 34  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               1
# 39  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               2
# 44  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               3
#
#     White Noise Naive Best Type  Naive Best RMSE P0 Best Model Name  \
# 0         False            mean         0.083730                 ML
# 5         False            mean         0.077936                 ML
# 10        False            mean         0.078022                 ML
# 1         False            last         0.050920                 ML
# 6         False            last         0.049104            SARIMAX
# 11        False            last         0.044826       auto_SARIMAX
# 3         False            mean         0.080436                 ML
# 8         False            mean         0.087216            SARIMAX
# 13        False            mean         0.076948            SARIMAX
# 2         False            last         0.000000            SARIMAX
# 7         False            last         0.000000            SARIMAX
# 12        False            last         0.000000            SARIMAX
# 4          True            mean         0.069793            SARIMAX
# 9          True            mean         0.067484            SARIMAX
# 14         True            mean         0.075211            SARIMAX
# 49         True            mean         0.421833                 ML
# 54         True            mean         0.344666                 ML
# 59         True            mean         0.360263                 ML
# 48         True   seasonal_last         0.288182       auto_SARIMAX
# 53         True   seasonal_last         0.432273       auto_SARIMAX
# 58         True   seasonal_last         0.432273                 ML
# 45        False            last         0.109601                 ML
# 50        False            last         0.116424                 ML
# 55        False            mean         0.107768                 ML
# 47        False            mean         0.113808            SARIMAX
# 52        False            mean         0.104293            SARIMAX
# 57        False            mean         0.121653       auto_SARIMAX
# 46        False            mean         0.113211            SARIMAX
# 51        False            mean         0.120084                 ML
# 56        False            mean         0.136330            Prophet
# 18        False            mean         0.531778                 ML
# 23        False            last         0.583315                 ML
# 28        False            last         0.472934            SARIMAX
# 17        False            mean         0.099268                 ML
# 22        False            mean         0.094367                 ML
# 27        False            mean         0.093113                 ML
# 16         True            mean         0.165948                 ML
# 21         True            mean         0.206669                 ML
# 26         True            mean         0.199992                 ML
# 15        False            last         0.068911       auto_SARIMAX
# 20        False            last         0.055124       auto_SARIMAX
# 25        False            last         0.065992       auto_SARIMAX
# 19        False            mean         0.170241                 ML
# 24        False            mean         0.169375                 ML
# 29        False            mean         0.186769                 ML
# 31        False            last         0.113461            Prophet
# 36        False            last         0.107550            Prophet
# 41        False            last         0.126205                 ML
# 30        False            last         0.064357                 ML
# 35        False            last         0.062996                 ML
# 40        False            last         0.055440                 ML
# 33        False            last         0.109374       auto_SARIMAX
# 38        False            last         0.122087       auto_SARIMAX
# 43        False            mean         0.137258       auto_SARIMAX
# 32        False            last         0.000000            SARIMAX
# 37        False            last         0.000000            SARIMAX
# 42        False            last         0.000000            SARIMAX
# 34         True            mean         0.069793            SARIMAX
# 39         True            mean         0.067484            SARIMAX
# 44         True            mean         0.075211            SARIMAX
#
#     P0 Best Model RMSE P0+Sim Best Model Name  P0+Sim Best Model RMSE
# 0             0.074880                     ML                0.074880
# 5             0.069895           auto_SARIMAX                0.067138
# 10            0.064195                     ML                0.065978
# 1             0.055895                     ML                0.055895
# 6             0.057594                SARIMAX                0.046335
# 11            0.058057                SARIMAX                0.051133
# 3             0.048723                     ML                0.049192
# 8             0.056825           auto_SARIMAX                0.059088
# 13            0.050590           auto_SARIMAX                0.057322
# 2             0.001320                SARIMAX                0.001305
# 7             0.001044                SARIMAX                0.001303
# 12            0.001135                SARIMAX                0.001458
# 4             0.056888                SARIMAX                0.058062
# 9             0.054461           auto_SARIMAX                0.057156
# 14            0.072678                SARIMAX                0.075017
# 49            0.131512                     ML                0.135167
# 54            0.131576                     ML                0.123505
# 59            0.131003                     ML                0.126296
# 48            0.049483                     ML                0.102028
# 53            0.050417                     ML                0.103419
# 58            0.077907                     ML                0.082187
# 45            0.114726                     ML                0.114726
# 50            0.097598                     ML                0.097598
# 55            0.082030                     ML                0.082030
# 47            0.110920                SARIMAX                0.121613
# 52            0.122456                SARIMAX                0.131562
# 57            0.121268           auto_SARIMAX                0.129285
# 46            0.112525           auto_SARIMAX                0.119632
# 51            0.128680                     ML                0.128494
# 56            0.106713                     ML                0.128970
# 18            0.110073                     ML                0.099492
# 23            0.110073                     ML                0.099492
# 28            0.106258                     ML                0.101958
# 17            0.141781                SARIMAX                0.127688
# 22            0.141624                     ML                0.140611
# 27            0.130413                     ML                0.127396
# 16            0.188430                     ML                0.188429
# 21            0.204441                     ML                0.204441
# 26            0.205818                     ML                0.205817
# 15            0.070390                SARIMAX                0.083409
# 20            0.066565                SARIMAX                0.084708
# 25            0.056497                SARIMAX                0.086670
# 19            0.159083                     ML                0.162003
# 24            0.194023                     ML                0.194023
# 29            0.187915                     ML                0.187915
# 31            0.089950           auto_SARIMAX                0.104125
# 36            0.105715                Prophet                0.112139
# 41            0.098518                     ML                0.098546
# 30            0.061341                     ML                0.061554
# 35            0.063986                     ML                0.066194
# 40            0.082589           auto_SARIMAX                0.065067
# 33            0.064250           auto_SARIMAX                0.065172
# 38            0.091435           auto_SARIMAX                0.074501
# 43            0.076854                SARIMAX                0.054291
# 32            0.001320                SARIMAX                0.001138
# 37            0.001044                SARIMAX                0.001140
# 42            0.001135                SARIMAX                0.001012
# 34            0.056888                SARIMAX                0.058062
# 39            0.054461           auto_SARIMAX                0.057143
# 44            0.072678                SARIMAX                0.074361

# %% [markdown]
# ## Optimizer

# %% [markdown]
# ### Summary by Chain

# %%
full_chain_summary
# Out:
#          Chain Master  P0 Non-Opt Revenue  P0 Opt Revenue  P0 Opt Diff  \
# 0                                 34918.0         34892.0        -26.0
# 1               SPECS             15956.0         17778.0       1822.0
# 2    THE BARREL HOUSE              6806.0          6861.0         55.0
# 3  WESTERN BEV LIQ TX             13267.0         22059.0       8792.0
#
#    P0 Opt Diff Ratio  P0+Sim Non-Opt Revenue  P0+Sim Opt Revenue  \
# 0           0.999255                 40226.0             49142.0
# 1           1.114189                 14541.0             18416.0
# 2           1.008081                  7651.0              7786.0
# 3           1.662697                 14800.0             21638.0
#
#    P0+Sim Opt Diff  P0+Sim Opt Diff Ratio
# 0           8916.0               1.221648
# 1           3875.0               1.266488
# 2            135.0               1.017645
# 3           6838.0               1.462027

# %%
print("WRITE this value in the summary table in Git hub --->",round(full_chain_summary[full_chain_summary['Chain Master']=='']['P0+Sim Opt Diff Ratio'].item(),4))
# Out:
# WRITE this value in the summary table in Git hub ---> 1.2216

# %% [markdown]
# Link to the Git Hub Summary Table: https://github.com/ngupta23/msds_capstone/issues/84

# %% [markdown]
# ### Summary by Chain and Product

# %%
full_summary
# Out:
#           Chain Master                             Product  \
# 0                                       TAAKA VODKA 80  1L
# 1                             TAAKA VODKA 80 BLUE PET 375M
# 2                                 TAAKA VODKA 80 PET 1.75L
# 3                             TEXAS SPIRIT VODKA 80  1.75L
# 4                       TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
# 5                SPECS                  DOBRA VODKA  1.75L
# 6                SPECS       MCCORMICK CHERRY VODKA 60  1L
# 7                SPECS                  TAAKA VODKA 80  1L
# 8                SPECS        TAAKA VODKA 80 BLUE PET 375M
# 9                SPECS            TAAKA VODKA 80 PET 1.75L
# 10    THE BARREL HOUSE                  DOBRA VODKA  1.75L
# 11    THE BARREL HOUSE                  TAAKA VODKA 80  1L
# 12    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 200M
# 13    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 375M
# 14    THE BARREL HOUSE            TAAKA VODKA 80 PET 1.75L
# 15  WESTERN BEV LIQ TX                  TAAKA VODKA 80  1L
# 16  WESTERN BEV LIQ TX        TAAKA VODKA 80 BLUE PET 375M
# 17  WESTERN BEV LIQ TX            TAAKA VODKA 80 PET 1.75L
# 18  WESTERN BEV LIQ TX        TEXAS SPIRIT VODKA 80  1.75L
# 19  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L
#
#     P0 Non-Opt Revenue  P0 Opt Revenue  P0 Opt Diff  P0 Opt Diff Ratio  \
# 0              16812.0         16772.0        -40.0           0.997621
# 1              10119.0         10119.0          0.0           1.000000
# 2               5568.0          5568.0          0.0           1.000000
# 3                 15.0            29.0         14.0           1.933333
# 4               2404.0          2404.0          0.0           1.000000
# 5                328.0           338.0         10.0           1.030488
# 6                242.0           269.0         27.0           1.111570
# 7              12144.0         12144.0          0.0           1.000000
# 8               1057.0          1150.0         93.0           1.087985
# 9               2185.0          3877.0       1692.0           1.774371
# 10               828.0           850.0         22.0           1.026570
# 11              1573.0          1595.0         22.0           1.013986
# 12              1034.0          1036.0          2.0           1.001934
# 13              3085.0          3085.0          0.0           1.000000
# 14               286.0           295.0          9.0           1.031469
# 15              7507.0         15175.0       7668.0           2.021447
# 16              1202.0          1202.0          0.0           1.000000
# 17              2139.0          3249.0       1110.0           1.518934
# 18                15.0            29.0         14.0           1.933333
# 19              2404.0          2404.0          0.0           1.000000
#
#     P0+Sim Non-Opt Revenue  P0+Sim Opt Revenue  P0+Sim Opt Diff  \
# 0                  21433.0             28996.0           7563.0
# 1                  10659.0             10659.0              0.0
# 2                   5750.0              5232.0           -518.0
# 3                     15.0              1876.0           1861.0
# 4                   2369.0              2379.0             10.0
# 5                    339.0               344.0              5.0
# 6                    320.0               397.0             77.0
# 7                  12144.0             12098.0            -46.0
# 8                   1088.0              4918.0           3830.0
# 9                    650.0               659.0              9.0
# 10                  1078.0              1111.0             33.0
# 11                  1729.0              1769.0             40.0
# 12                  1034.0              1035.0              1.0
# 13                  3525.0              3576.0             51.0
# 14                   285.0               295.0             10.0
# 15                  6565.0              8781.0           2216.0
# 16                  3448.0              5513.0           2065.0
# 17                  2388.0              3041.0            653.0
# 18                    15.0              1872.0           1857.0
# 19                  2384.0              2431.0             47.0
#
#     P0+Sim Opt Diff Ratio
# 0                1.352867
# 1                1.000000
# 2                0.909913
# 3              125.066667
# 4                1.004221
# 5                1.014749
# 6                1.240625
# 7                0.996212
# 8                4.520221
# 9                1.013846
# 10               1.030612
# 11               1.023135
# 12               1.000967
# 13               1.014468
# 14               1.035088
# 15               1.337548
# 16               1.598898
# 17               1.273451
# 18             124.800000
# 19               1.019715

# %% [markdown]
# ### P0 Optimizer

# %%
full_opt[outputColsOptP0]
# Out:
#           Chain Master                             Product  Period to Last  \
# 0                                       TAAKA VODKA 80  1L               1
# 5                                       TAAKA VODKA 80  1L               2
# 10                                      TAAKA VODKA 80  1L               3
# 1                             TAAKA VODKA 80 BLUE PET 375M               1
# 6                             TAAKA VODKA 80 BLUE PET 375M               2
# 11                            TAAKA VODKA 80 BLUE PET 375M               3
# 3                                 TAAKA VODKA 80 PET 1.75L               1
# 8                                 TAAKA VODKA 80 PET 1.75L               2
# 13                                TAAKA VODKA 80 PET 1.75L               3
# 2                             TEXAS SPIRIT VODKA 80  1.75L               1
# 7                             TEXAS SPIRIT VODKA 80  1.75L               2
# 12                            TEXAS SPIRIT VODKA 80  1.75L               3
# 4                       TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               1
# 9                       TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               2
# 14                      TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               3
# 49               SPECS                  DOBRA VODKA  1.75L               1
# 54               SPECS                  DOBRA VODKA  1.75L               2
# 59               SPECS                  DOBRA VODKA  1.75L               3
# 48               SPECS       MCCORMICK CHERRY VODKA 60  1L               1
# 53               SPECS       MCCORMICK CHERRY VODKA 60  1L               2
# 58               SPECS       MCCORMICK CHERRY VODKA 60  1L               3
# 45               SPECS                  TAAKA VODKA 80  1L               1
# 50               SPECS                  TAAKA VODKA 80  1L               2
# 55               SPECS                  TAAKA VODKA 80  1L               3
# 47               SPECS        TAAKA VODKA 80 BLUE PET 375M               1
# 52               SPECS        TAAKA VODKA 80 BLUE PET 375M               2
# 57               SPECS        TAAKA VODKA 80 BLUE PET 375M               3
# 46               SPECS            TAAKA VODKA 80 PET 1.75L               1
# 51               SPECS            TAAKA VODKA 80 PET 1.75L               2
# 56               SPECS            TAAKA VODKA 80 PET 1.75L               3
# 18    THE BARREL HOUSE                  DOBRA VODKA  1.75L               1
# 23    THE BARREL HOUSE                  DOBRA VODKA  1.75L               2
# 28    THE BARREL HOUSE                  DOBRA VODKA  1.75L               3
# 17    THE BARREL HOUSE                  TAAKA VODKA 80  1L               1
# 22    THE BARREL HOUSE                  TAAKA VODKA 80  1L               2
# 27    THE BARREL HOUSE                  TAAKA VODKA 80  1L               3
# 16    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 200M               1
# 21    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 200M               2
# 26    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 200M               3
# 15    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 375M               1
# 20    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 375M               2
# 25    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 375M               3
# 19    THE BARREL HOUSE            TAAKA VODKA 80 PET 1.75L               1
# 24    THE BARREL HOUSE            TAAKA VODKA 80 PET 1.75L               2
# 29    THE BARREL HOUSE            TAAKA VODKA 80 PET 1.75L               3
# 31  WESTERN BEV LIQ TX                  TAAKA VODKA 80  1L               1
# 36  WESTERN BEV LIQ TX                  TAAKA VODKA 80  1L               2
# 41  WESTERN BEV LIQ TX                  TAAKA VODKA 80  1L               3
# 30  WESTERN BEV LIQ TX        TAAKA VODKA 80 BLUE PET 375M               1
# 35  WESTERN BEV LIQ TX        TAAKA VODKA 80 BLUE PET 375M               2
# 40  WESTERN BEV LIQ TX        TAAKA VODKA 80 BLUE PET 375M               3
# 33  WESTERN BEV LIQ TX            TAAKA VODKA 80 PET 1.75L               1
# 38  WESTERN BEV LIQ TX            TAAKA VODKA 80 PET 1.75L               2
# 43  WESTERN BEV LIQ TX            TAAKA VODKA 80 PET 1.75L               3
# 32  WESTERN BEV LIQ TX        TEXAS SPIRIT VODKA 80  1.75L               1
# 37  WESTERN BEV LIQ TX        TEXAS SPIRIT VODKA 80  1.75L               2
# 42  WESTERN BEV LIQ TX        TEXAS SPIRIT VODKA 80  1.75L               3
# 34  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               1
# 39  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               2
# 44  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               3
#
#     P0 Non-Opt Price  P0 Non-Opt Demand  P0 Non-Opt Revenue  \
# 0              44.42                115                5103
# 5              44.30                107                4750
# 10             44.47                156                6959
# 1              58.56                  3                 189
# 6              58.56                 92                5394
# 11             58.56                 77                4536
# 3              47.03                 49                2298
# 8              47.03                 38                1782
# 13             47.03                 32                1488
# 2              51.18                  0                   5
# 7              51.18                  0                   5
# 12             51.18                  0                   5
# 4              46.97                 18                 865
# 9              46.97                 17                 780
# 14             46.97                 16                 759
# 49             49.27                  2                 112
# 54             47.03                  2                 107
# 59             47.03                  2                 109
# 48             45.74                  1                  65
# 53             45.74                  1                  66
# 58             45.74                  2                 111
# 45             44.30                 98                4348
# 50             44.30                 85                3780
# 55             44.30                 91                4016
# 47             58.56                  6                 370
# 52             58.56                  6                 335
# 57             58.56                  6                 352
# 46             47.03                 13                 594
# 51             47.03                  3                 119
# 56             47.03                 31                1472
# 18             47.03                  8                 361
# 23             49.27                  8                 376
# 28             47.03                  2                  91
# 17             46.89                 11                 519
# 22             44.30                 11                 508
# 27             47.63                 11                 546
# 16             62.80                  6                 378
# 21             62.80                  4                 278
# 26             62.80                  6                 378
# 15             58.56                 18                1055
# 20             58.56                 18                1058
# 25             58.56                 17                 972
# 19             47.03                  2                  73
# 24             47.03                  2                 105
# 29             47.03                  2                 108
# 31             44.30                 74                3275
# 36             44.30                 54                2378
# 41             44.30                 42                1854
# 30             58.56                  6                 368
# 35             58.56                  7                 423
# 40             58.56                  7                 411
# 33             47.03                 16                 760
# 38             47.03                 16                 773
# 43             47.03                 13                 606
# 32             51.18                  0                   5
# 37             51.18                  0                   5
# 42             51.18                  0                   5
# 34             46.97                 18                 865
# 39             46.97                 17                 780
# 44             46.97                 16                 759
#
#     P0 Non-Opt Chain Master Revenue  P0 Optimal Price  P0 Demand  P0 Revenue  \
# 0                              8461             44.30        115        5089
# 5                             12711             44.30        107        4750
# 10                            13747             44.30        156        6933
# 1                              8461             58.56          3         189
# 6                             12711             58.56         92        5394
# 11                            13747             58.56         77        4536
# 3                              8461             47.03         49        2298
# 8                             12711             47.03         38        1782
# 13                            13747             47.03         32        1488
# 2                              8461             46.03          0          10
# 7                             12711             46.03          0           9
# 12                            13747             46.03          0          10
# 4                              8461             46.97         18         865
# 9                             12711             46.97         17         780
# 14                            13747             46.97         16         759
# 49                             5488             49.27          2         112
# 54                             4407             49.27          2         112
# 59                             6060             49.27          2         114
# 48                             5488             45.69          1          65
# 53                             4407             45.69          1          67
# 58                             6060             56.61          2         137
# 45                             5488             44.30         98        4348
# 50                             4407             44.30         85        3780
# 55                             6060             44.30         91        4016
# 47                             5488             61.49          7         409
# 52                             4407             61.49          6         371
# 57                             6060             61.49          6         370
# 46                             5488             47.03         13         594
# 51                             4407             46.98          3         119
# 56                             6060             46.98         67        3164
# 18                             2386             49.27          8         378
# 23                             2325             49.27          8         376
# 28                             2095             46.98          2          96
# 17                             2386             47.04         11         521
# 22                             2325             46.77         11         536
# 27                             2095             46.89         11         538
# 16                             2386             62.93          6         379
# 21                             2325             62.93          4         278
# 26                             2095             62.93          6         379
# 15                             2386             58.56         18        1055
# 20                             2325             58.56         18        1058
# 25                             2095             58.56         17         972
# 19                             2386             49.38          2          76
# 24                             2325             49.38          2         111
# 29                             2095             47.03          2         108
# 31                             5273             43.80        176        7691
# 36                             4359             43.80        129        5630
# 41                             3634             44.30         42        1854
# 30                             5273             58.56          6         368
# 35                             4359             58.56          7         423
# 40                             3634             58.56          7         411
# 33                             5273             46.98         25        1154
# 38                             4359             46.98         25        1175
# 43                             3634             46.98         20         920
# 32                             5273             46.03          0          10
# 37                             4359             46.03          0           9
# 42                             3634             46.03          0          10
# 34                             5273             46.97         18         865
# 39                             4359             46.97         17         780
# 44                             3634             46.97         16         759
#
#     P0 Chain Master Revenue
# 0                      8451
# 5                     12715
# 10                    13726
# 1                      8451
# 6                     12715
# 11                    13726
# 3                      8451
# 8                     12715
# 13                    13726
# 2                      8451
# 7                     12715
# 12                    13726
# 4                      8451
# 9                     12715
# 14                    13726
# 49                     5528
# 54                     4448
# 59                     7801
# 48                     5528
# 53                     4448
# 58                     7801
# 45                     5528
# 50                     4448
# 55                     7801
# 47                     5528
# 52                     4448
# 57                     7801
# 46                     5528
# 51                     4448
# 56                     7801
# 18                     2409
# 23                     2359
# 28                     2092
# 17                     2409
# 22                     2359
# 27                     2092
# 16                     2409
# 21                     2359
# 26                     2092
# 15                     2409
# 20                     2359
# 25                     2092
# 19                     2409
# 24                     2359
# 29                     2092
# 31                    10088
# 36                     8017
# 41                     3953
# 30                    10088
# 35                     8017
# 40                     3953
# 33                    10088
# 38                     8017
# 43                     3953
# 32                    10088
# 37                     8017
# 42                     3953
# 34                    10088
# 39                     8017
# 44                     3953

# %% [markdown]
# ### P0+Sim Optimizer

# %%
full_opt[outputColsOptP0Sim]
# Out:
#           Chain Master                             Product  Period to Last  \
# 0                                       TAAKA VODKA 80  1L               1
# 5                                       TAAKA VODKA 80  1L               2
# 10                                      TAAKA VODKA 80  1L               3
# 1                             TAAKA VODKA 80 BLUE PET 375M               1
# 6                             TAAKA VODKA 80 BLUE PET 375M               2
# 11                            TAAKA VODKA 80 BLUE PET 375M               3
# 3                                 TAAKA VODKA 80 PET 1.75L               1
# 8                                 TAAKA VODKA 80 PET 1.75L               2
# 13                                TAAKA VODKA 80 PET 1.75L               3
# 2                             TEXAS SPIRIT VODKA 80  1.75L               1
# 7                             TEXAS SPIRIT VODKA 80  1.75L               2
# 12                            TEXAS SPIRIT VODKA 80  1.75L               3
# 4                       TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               1
# 9                       TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               2
# 14                      TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               3
# 49               SPECS                  DOBRA VODKA  1.75L               1
# 54               SPECS                  DOBRA VODKA  1.75L               2
# 59               SPECS                  DOBRA VODKA  1.75L               3
# 48               SPECS       MCCORMICK CHERRY VODKA 60  1L               1
# 53               SPECS       MCCORMICK CHERRY VODKA 60  1L               2
# 58               SPECS       MCCORMICK CHERRY VODKA 60  1L               3
# 45               SPECS                  TAAKA VODKA 80  1L               1
# 50               SPECS                  TAAKA VODKA 80  1L               2
# 55               SPECS                  TAAKA VODKA 80  1L               3
# 47               SPECS        TAAKA VODKA 80 BLUE PET 375M               1
# 52               SPECS        TAAKA VODKA 80 BLUE PET 375M               2
# 57               SPECS        TAAKA VODKA 80 BLUE PET 375M               3
# 46               SPECS            TAAKA VODKA 80 PET 1.75L               1
# 51               SPECS            TAAKA VODKA 80 PET 1.75L               2
# 56               SPECS            TAAKA VODKA 80 PET 1.75L               3
# 18    THE BARREL HOUSE                  DOBRA VODKA  1.75L               1
# 23    THE BARREL HOUSE                  DOBRA VODKA  1.75L               2
# 28    THE BARREL HOUSE                  DOBRA VODKA  1.75L               3
# 17    THE BARREL HOUSE                  TAAKA VODKA 80  1L               1
# 22    THE BARREL HOUSE                  TAAKA VODKA 80  1L               2
# 27    THE BARREL HOUSE                  TAAKA VODKA 80  1L               3
# 16    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 200M               1
# 21    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 200M               2
# 26    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 200M               3
# 15    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 375M               1
# 20    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 375M               2
# 25    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 375M               3
# 19    THE BARREL HOUSE            TAAKA VODKA 80 PET 1.75L               1
# 24    THE BARREL HOUSE            TAAKA VODKA 80 PET 1.75L               2
# 29    THE BARREL HOUSE            TAAKA VODKA 80 PET 1.75L               3
# 31  WESTERN BEV LIQ TX                  TAAKA VODKA 80  1L               1
# 36  WESTERN BEV LIQ TX                  TAAKA VODKA 80  1L               2
# 41  WESTERN BEV LIQ TX                  TAAKA VODKA 80  1L               3
# 30  WESTERN BEV LIQ TX        TAAKA VODKA 80 BLUE PET 375M               1
# 35  WESTERN BEV LIQ TX        TAAKA VODKA 80 BLUE PET 375M               2
# 40  WESTERN BEV LIQ TX        TAAKA VODKA 80 BLUE PET 375M               3
# 33  WESTERN BEV LIQ TX            TAAKA VODKA 80 PET 1.75L               1
# 38  WESTERN BEV LIQ TX            TAAKA VODKA 80 PET 1.75L               2
# 43  WESTERN BEV LIQ TX            TAAKA VODKA 80 PET 1.75L               3
# 32  WESTERN BEV LIQ TX        TEXAS SPIRIT VODKA 80  1.75L               1
# 37  WESTERN BEV LIQ TX        TEXAS SPIRIT VODKA 80  1.75L               2
# 42  WESTERN BEV LIQ TX        TEXAS SPIRIT VODKA 80  1.75L               3
# 34  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               1
# 39  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               2
# 44  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               3
#
#     P0+Sim Non-Opt Price  P0+Sim Non-Opt Demand  P0+Sim Non-Opt Revenue  \
# 0                  44.42                    115                    5103
# 5                  44.30                    213                    9423
# 10                 44.47                    155                    6907
# 1                  58.56                      3                     191
# 6                  58.56                     94                    5504
# 11                 58.56                     85                    4964
# 3                  47.03                     51                    2385
# 8                  47.03                     37                    1722
# 13                 47.03                     35                    1643
# 2                  51.18                      0                       5
# 7                  51.18                      0                       5
# 12                 51.18                      0                       5
# 4                  46.97                     19                     879
# 9                  46.97                     15                     728
# 14                 46.97                     16                     762
# 49                 49.27                      2                     116
# 54                 47.03                      2                     111
# 59                 47.03                      2                     112
# 48                 45.74                      2                     106
# 53                 45.74                      2                     106
# 58                 45.74                      2                     108
# 45                 44.30                     98                    4348
# 50                 44.30                     85                    3780
# 55                 44.30                     91                    4016
# 47                 58.56                      6                     355
# 52                 58.56                      6                     334
# 57                 58.56                      7                     399
# 46                 47.03                      9                     418
# 51                 47.03                      2                     117
# 56                 47.03                      2                     115
# 18                 47.03                      7                     353
# 23                 49.27                      7                     368
# 28                 47.03                      8                     357
# 17                 46.89                     14                     658
# 22                 44.30                     12                     514
# 27                 47.63                     12                     557
# 16                 62.80                      6                     378
# 21                 62.80                      4                     278
# 26                 62.80                      6                     378
# 15                 58.56                     23                    1373
# 20                 58.56                     18                    1065
# 25                 58.56                     19                    1087
# 19                 47.03                      2                      72
# 24                 47.03                      2                     105
# 29                 47.03                      2                     108
# 31                 44.30                     74                    3270
# 36                 44.30                     33                    1441
# 41                 44.30                     42                    1854
# 30                 58.56                      7                     381
# 35                 58.56                      7                     413
# 40                 58.56                     45                    2654
# 33                 47.03                     17                     813
# 38                 47.03                     18                     856
# 43                 47.03                     15                     719
# 32                 51.18                      0                       5
# 37                 51.18                      0                       5
# 42                 51.18                      0                       5
# 34                 46.97                     19                     881
# 39                 46.97                     15                     728
# 44                 46.97                     17                     775
#
#     P0+Sim Non-Opt Chain Master Revenue  P0+Sim Optimal Price  P0+Sim Demand  \
# 0                                  8563                 44.30            115
# 5                                 17381                 43.80            389
# 10                                14281                 44.30            155
# 1                                  8563                 58.56              3
# 6                                 17381                 58.56             94
# 11                                14281                 58.56             85
# 3                                  8563                 47.03             51
# 8                                 17381                 47.03             28
# 13                                14281                 47.03             32
# 2                                  8563                 46.03             14
# 7                                 17381                 46.03             14
# 12                                14281                 46.03             13
# 4                                  8563                 46.97             19
# 9                                 17381                 46.97             16
# 14                                14281                 46.97             16
# 49                                 5344                 49.27              2
# 54                                 4448                 46.98              2
# 59                                 4750                 49.27              2
# 48                                 5344                 56.61              2
# 53                                 4448                 56.61              2
# 58                                 4750                 56.61              2
# 45                                 5344                 44.30             98
# 50                                 4448                 44.30             85
# 55                                 4750                 43.80             91
# 47                                 5344                 55.63             32
# 52                                 4448                 55.63             33
# 57                                 4750                 61.49             21
# 46                                 5344                 46.98              9
# 51                                 4448                 47.03              2
# 56                                 4750                 47.03              2
# 18                                 2834                 49.27              7
# 23                                 2330                 49.27              7
# 28                                 2486                 49.27              8
# 17                                 2834                 47.04             14
# 22                                 2330                 46.77             12
# 27                                 2486                 46.89             12
# 16                                 2834                 62.93              6
# 21                                 2330                 62.93              4
# 26                                 2486                 62.80              6
# 15                                 2834                 58.56             24
# 20                                 2330                 58.56             19
# 25                                 2486                 58.56             19
# 19                                 2834                 49.38              2
# 24                                 2330                 49.38              2
# 29                                 2486                 47.03              2
# 31                                 5350                 43.80            123
# 36                                 3443                 43.80             35
# 41                                 6007                 43.80             42
# 30                                 5350                 58.56              7
# 35                                 3443                 58.56              7
# 40                                 6007                 58.56             81
# 33                                 5350                 47.03             20
# 38                                 3443                 47.03             21
# 43                                 6007                 47.03             24
# 32                                 5350                 46.03             14
# 37                                 3443                 46.03             14
# 42                                 6007                 46.03             13
# 34                                 5350                 46.97             19
# 39                                 3443                 46.97             16
# 44                                 6007                 46.97             17
#
#     P0+Sim Revenue  P0+Sim Chain Master Revenue
# 0             5089                         9184
# 5            17026                        25220
# 10            6881                        14739
# 1              191                         9184
# 6             5504                        25220
# 11            4964                        14739
# 3             2385                         9184
# 8             1334                        25220
# 13            1513                        14739
# 2              635                         9184
# 7              625                        25220
# 12             616                        14739
# 4              884                         9184
# 9              731                        25220
# 14             764                        14739
# 49             116                         6776
# 54             111                         6000
# 59             117                         5641
# 48             132                         6776
# 53             132                         6000
# 58             133                         5641
# 45            4348                         6776
# 50            3780                         6000
# 55            3970                         5641
# 47            1753                         6776
# 52            1860                         6000
# 57            1305                         5641
# 46             427                         6776
# 51             117                         6000
# 56             115                         5641
# 18             369                         2892
# 23             368                         2398
# 28             374                         2495
# 17             677                         2892
# 22             543                         2398
# 27             549                         2495
# 16             379                         2892
# 21             278                         2398
# 26             378                         2495
# 15            1390                         2892
# 20            1099                         2398
# 25            1087                         2495
# 19              76                         2892
# 24             111                         2398
# 29             108                         2495
# 31            5401                         8238
# 36            1547                         4300
# 41            1833                         9101
# 30             381                         8238
# 35             413                         4300
# 40            4719                         9101
# 33             918                         8238
# 38             980                         4300
# 43            1143                         9101
# 32             634                         8238
# 37             626                         4300
# 42             612                         9101
# 34             903                         8238
# 39             733                         4300
# 44             795                         9101

# %% [markdown]
# ### Naive

# %%
full_opt[outputColsOptNaive]
# Out:
#           Chain Master                             Product  Period to Last  \
# 0                                       TAAKA VODKA 80  1L               1
# 5                                       TAAKA VODKA 80  1L               2
# 10                                      TAAKA VODKA 80  1L               3
# 1                             TAAKA VODKA 80 BLUE PET 375M               1
# 6                             TAAKA VODKA 80 BLUE PET 375M               2
# 11                            TAAKA VODKA 80 BLUE PET 375M               3
# 3                                 TAAKA VODKA 80 PET 1.75L               1
# 8                                 TAAKA VODKA 80 PET 1.75L               2
# 13                                TAAKA VODKA 80 PET 1.75L               3
# 2                             TEXAS SPIRIT VODKA 80  1.75L               1
# 7                             TEXAS SPIRIT VODKA 80  1.75L               2
# 12                            TEXAS SPIRIT VODKA 80  1.75L               3
# 4                       TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               1
# 9                       TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               2
# 14                      TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               3
# 49               SPECS                  DOBRA VODKA  1.75L               1
# 54               SPECS                  DOBRA VODKA  1.75L               2
# 59               SPECS                  DOBRA VODKA  1.75L               3
# 48               SPECS       MCCORMICK CHERRY VODKA 60  1L               1
# 53               SPECS       MCCORMICK CHERRY VODKA 60  1L               2
# 58               SPECS       MCCORMICK CHERRY VODKA 60  1L               3
# 45               SPECS                  TAAKA VODKA 80  1L               1
# 50               SPECS                  TAAKA VODKA 80  1L               2
# 55               SPECS                  TAAKA VODKA 80  1L               3
# 47               SPECS        TAAKA VODKA 80 BLUE PET 375M               1
# 52               SPECS        TAAKA VODKA 80 BLUE PET 375M               2
# 57               SPECS        TAAKA VODKA 80 BLUE PET 375M               3
# 46               SPECS            TAAKA VODKA 80 PET 1.75L               1
# 51               SPECS            TAAKA VODKA 80 PET 1.75L               2
# 56               SPECS            TAAKA VODKA 80 PET 1.75L               3
# 18    THE BARREL HOUSE                  DOBRA VODKA  1.75L               1
# 23    THE BARREL HOUSE                  DOBRA VODKA  1.75L               2
# 28    THE BARREL HOUSE                  DOBRA VODKA  1.75L               3
# 17    THE BARREL HOUSE                  TAAKA VODKA 80  1L               1
# 22    THE BARREL HOUSE                  TAAKA VODKA 80  1L               2
# 27    THE BARREL HOUSE                  TAAKA VODKA 80  1L               3
# 16    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 200M               1
# 21    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 200M               2
# 26    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 200M               3
# 15    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 375M               1
# 20    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 375M               2
# 25    THE BARREL HOUSE        TAAKA VODKA 80 BLUE PET 375M               3
# 19    THE BARREL HOUSE            TAAKA VODKA 80 PET 1.75L               1
# 24    THE BARREL HOUSE            TAAKA VODKA 80 PET 1.75L               2
# 29    THE BARREL HOUSE            TAAKA VODKA 80 PET 1.75L               3
# 31  WESTERN BEV LIQ TX                  TAAKA VODKA 80  1L               1
# 36  WESTERN BEV LIQ TX                  TAAKA VODKA 80  1L               2
# 41  WESTERN BEV LIQ TX                  TAAKA VODKA 80  1L               3
# 30  WESTERN BEV LIQ TX        TAAKA VODKA 80 BLUE PET 375M               1
# 35  WESTERN BEV LIQ TX        TAAKA VODKA 80 BLUE PET 375M               2
# 40  WESTERN BEV LIQ TX        TAAKA VODKA 80 BLUE PET 375M               3
# 33  WESTERN BEV LIQ TX            TAAKA VODKA 80 PET 1.75L               1
# 38  WESTERN BEV LIQ TX            TAAKA VODKA 80 PET 1.75L               2
# 43  WESTERN BEV LIQ TX            TAAKA VODKA 80 PET 1.75L               3
# 32  WESTERN BEV LIQ TX        TEXAS SPIRIT VODKA 80  1.75L               1
# 37  WESTERN BEV LIQ TX        TEXAS SPIRIT VODKA 80  1.75L               2
# 42  WESTERN BEV LIQ TX        TEXAS SPIRIT VODKA 80  1.75L               3
# 34  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               1
# 39  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               2
# 44  WESTERN BEV LIQ TX  TEXAS SPIRIT VODKA 80 SAZ NL 1.75L               3
#
#     Actual Price  Actual Demand  Actual Revenue  Actual Chain Master Revenue  \
# 0      44.420127         172.90         7680.24                     15253.50
# 5      44.300752         195.51         8661.24                     15806.82
# 10     44.467025         186.20         8279.76                     16314.54
# 1      58.560000          88.00         5153.28                     15253.50
# 6      58.560000          76.00         4450.56                     15806.82
# 11     58.560000          94.00         5504.64                     16314.54
# 3      47.025641          33.93         1595.58                     15253.50
# 8      47.025641          38.61         1815.66                     15806.82
# 13     47.025641          38.61         1815.66                     16314.54
# 2      51.179487           0.00            0.00                     15253.50
# 7      51.179487           0.00            0.00                     15806.82
# 12     51.179487           0.00            0.00                     16314.54
# 4      46.974359          17.55          824.40                     15253.50
# 9      46.974359          18.72          879.36                     15806.82
# 14     46.974359          15.21          714.48                     16314.54
# 49     49.268571           0.00            0.00                      5754.06
# 54     47.025641           1.17           55.02                      6202.38
# 59     47.025641           1.17           55.02                      5620.26
# 48     45.744361           1.33           60.84                      5754.06
# 53     45.744361           1.33           60.84                      6202.38
# 58     45.744361           1.33           60.84                      5620.26
# 45     44.300752         113.05         5008.20                      5754.06
# 50     44.300752         117.04         5184.96                      6202.38
# 55     44.300752         103.74         4595.76                      5620.26
# 47     58.560000           7.00          409.92                      5754.06
# 52     58.560000           6.00          351.36                      6202.38
# 57     58.560000           8.00          468.48                      5620.26
# 46     47.025641           5.85          275.10                      5754.06
# 51     47.025641          11.70          550.20                      6202.38
# 56     47.025641           9.36          440.16                      5620.26
# 18     47.025641           1.17           55.02                      2204.40
# 23     49.268571           0.00            0.00                      2016.36
# 28     47.025641           1.17           55.02                      2919.36
# 17     46.887218           7.98          374.16                      2204.40
# 22     44.300752           6.65          294.60                      2016.36
# 27     47.626208           9.31          443.40                      2919.36
# 16     62.803738           5.35          336.00                      2204.40
# 21     62.803738           6.42          403.20                      2016.36
# 26     62.803738           6.42          403.20                      2919.36
# 15     58.560000          18.00         1054.08                      2204.40
# 20     58.560000          15.00          878.40                      2016.36
# 25     58.560000          26.00         1522.56                      2919.36
# 19     47.025641           8.19          385.14                      2204.40
# 24     47.025641           9.36          440.16                      2016.36
# 29     47.025641          10.53          495.18                      2919.36
# 31     44.300752          51.87         2297.88                      7746.90
# 36     44.300752          71.82         3181.68                      8107.14
# 41     44.300752          73.15         3240.60                      8349.00
# 30     58.560000          63.00         3689.28                      7746.90
# 35     58.560000          55.00         3220.80                      8107.14
# 40     58.560000          60.00         3513.60                      8349.00
# 33     47.025641          19.89          935.34                      7746.90
# 38     47.025641          17.55          825.30                      8107.14
# 43     47.025641          18.72          880.32                      8349.00
# 32     51.179487           0.00            0.00                      7746.90
# 37     51.179487           0.00            0.00                      8107.14
# 42     51.179487           0.00            0.00                      8349.00
# 34     46.974359          17.55          824.40                      7746.90
# 39     46.974359          18.72          879.36                      8107.14
# 44     46.974359          15.21          714.48                      8349.00
#
#     Naive Prices  Naive Demand  Naive Revenue  Naive Chain Master Revenue
# 0      44.420127    199.948711    8881.747177                15449.881619
# 5      44.300752    200.002841    8860.276255                16474.881017
# 10     44.467025    200.173247    8901.108716                14754.039668
# 1      58.560000     76.000000    4450.560000                15449.881619
# 6      58.560000     94.000000    5504.640000                16474.881017
# 11     58.560000     64.000000    3747.840000                14754.039668
# 3      47.025641     28.587470    1344.344096                15449.881619
# 8      47.025641     28.465244    1338.596341                16474.881017
# 13     47.025641     28.340000    1332.706667                14754.039668
# 2      51.179487      0.000000       0.000000                15449.881619
# 7      51.179487      0.000000       0.000000                16474.881017
# 12     51.179487      0.000000       0.000000                14754.039668
# 4      46.974359     16.460690     773.230345                15449.881619
# 9      46.974359     16.421053     771.368421                16474.881017
# 14     46.974359     16.442679     772.384286                14754.039668
# 49     49.268571      2.268659     111.773565                 5834.722481
# 54     47.025641      2.282222     107.322963                 5235.896134
# 59     47.025641      2.296125     107.976750                 7227.427120
# 48     45.744361      1.330000      60.840000                 5834.722481
# 53     45.744361      1.330000      60.840000                 5235.896134
# 58     45.744361      0.000000       0.000000                 7227.427120
# 45     44.300752    117.040000    5184.960000                 5834.722481
# 50     44.300752    103.740000    4595.760000                 5235.896134
# 55     44.300752    150.175062    6652.868148                 7227.427120
# 47     58.560000      3.801205     222.598554                 5834.722481
# 52     58.560000      3.774390     221.028293                 5235.896134
# 57     58.560000      3.722222     217.973333                 7227.427120
# 46     47.025641      5.413012     254.550361                 5834.722481
# 51     47.025641      5.336341     250.944878                 5235.896134
# 56     47.025641      5.286667     248.608889                 7227.427120
# 18     47.025641      2.974337     139.870120                 2044.938906
# 23     49.268571      1.170000      57.644229                 2584.075791
# 28     47.025641      1.170000      55.020000                 1954.785755
# 17     46.887218      7.452586     349.431034                 2044.938906
# 22     44.300752      7.466667     330.778947                 2584.075791
# 27     47.626208      7.433750     354.041327                 1954.785755
# 16     62.803738      6.403086     402.137751                 2044.938906
# 21     62.803738      6.402789     402.119115                 2584.075791
# 26     62.803738      6.402482     402.099813                 1954.785755
# 15     58.560000     15.000000     878.400000                 2044.938906
# 20     58.560000     26.000000    1522.560000                 2584.075791
# 25     58.560000     15.000000     878.400000                 1954.785755
# 19     47.025641      5.850000     275.100000                 2044.938906
# 24     47.025641      5.762250     270.973500                 2584.075791
# 29     47.025641      5.640000     265.224615                 1954.785755
# 31     44.300752     71.820000    3181.680000                 8001.010345
# 36     44.300752     73.150000    3240.600000                 8405.888421
# 41     44.300752     58.520000    2592.480000                 6780.781323
# 30     58.560000     55.000000    3220.800000                 8001.010345
# 35     58.560000     60.000000    3513.600000                 8405.888421
# 40     58.560000     42.000000    2459.520000                 6780.781323
# 33     47.025641     17.550000     825.300000                 8001.010345
# 38     47.025641     18.720000     880.320000                 8405.888421
# 43     47.025641     20.337778     956.397037                 6780.781323
# 32     51.179487      0.000000       0.000000                 8001.010345
# 37     51.179487      0.000000       0.000000                 8405.888421
# 42     51.179487      0.000000       0.000000                 6780.781323
# 34     46.974359     16.460690     773.230345                 8001.010345
# 39     46.974359     16.421053     771.368421                 8405.888421
# 44     46.974359     16.442679     772.384286                 6780.781323
