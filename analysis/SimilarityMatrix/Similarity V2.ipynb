# %% [markdown]
# # Init

# %%
import pandas as pd
import numpy as np
import os
import math
import matplotlib.pyplot as plt
import glob
from scipy.spatial.distance import euclidean, pdist, squareform
import sys
sys.path.append(os.environ['CAPSTONE_PYTHON_SOURCE'])
#setting path to the env variable
folder = os.environ['CAPSTONE_DATA']
folder
# Out:
# 'C:\\max\\Google Drive Max\\Max Shared\\Master Data Science\\2020-05 Capstone A\\msds_capstone\\data\\'

# %% [markdown]
# # Create Similarity Dataframe

# %%
from similarity.similarity import calcSimilarity, getMatrix
from ETL.ETL import loadDataset

# %%
import spacy 
import spacy.cli
### SPACY INITIAL SETUP ###
#run in terminal:  python -m spacy download en_core_web_lg
spacy.cli.download("en_core_web_lg")

### load NLP ###
nlp = spacy.load('en_core_web_lg')
# Out:
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_lg')

# %% [markdown]
# ## Loading and filtering

# %%
#dataRaw= pd.read_pickle(os.path.join(folder,'tidy_data/Transactions_v2/Transactions.pkl'))
dataRaw= loadDataset(version=2)
data=dataRaw[dataRaw['Category (CatMan)'].isin(['SUP PREM WHISKEY','ECONOMY VODKA'])]
print(data.shape)
plt.style.use('default')
data.head(1)
# Out:
# (25722, 50)
#        Month  Chain Master ID Chain Master  Customer ID  \
# 4 2015-05-01          1000325        SPECS    300001740
#
#                       Customer Beverage Type        Vendor  Vendor ID  \
# 4  COWTOWN DISC LIQUOR SPF LTD       SPIRITS  BROWN FORMAN          5
#
#                             Brand                   Label  ... Alcohol Proof  \
# 4  JACK DANIELS TENNESSEE WHISKEY  JACK DANIELS BLK WHSKY  ...          80.0
#
#   Metrics  STD. Cases Dollar Sales 9L Cases  Dollar Sales per Case  \
# 4     NaN       197.0     56483.88   262.01             286.720203
#
#   Dollar Sales per 9L Case Size Liters Bottles Transactions
# 4                 215.5791         0.1  2364.0            1
#
# [1 rows x 50 columns]

# %%
datat= data[(data['Category (CatMan)'] == 'SUP PREM WHISKEY') & (data['Chain Master']=='SPECS')] 
datat.shape
# Out:
# (6034, 50)

# %% [markdown]
# ## Similarity Matrix
#
# Based on how many times two products have been bought together in the same month

# %% [markdown]
# ### Testing text similarity

# %%
import textdistance #https://pypi.org/project/textdistance/
from similarity.similarity import spacy_similarity
t1='MCCORMICK APPLE VODKA 60  1L'
t2= 'TAAKA APL VODKA  1L'
print('Levenshtein: ',textdistance.levenshtein.normalized_similarity(t1,t2))
print('Cosine:      ',textdistance.cosine.normalized_similarity(t1,t2))
print('Jaccard:     ',textdistance.jaccard.normalized_similarity(t1,t2))
print('NLP Spacy:   ',spacy_similarity(t1,t2,nlp))
# Out:
# Levenshtein:  0.5
# Cosine:       0.65033247714309
# Jaccard:      0.46875
# NLP Spacy:    0.7222400280225594

# %% [markdown]
# **Testing Matrix**

# %%
t=data[(data['Chain Master']=='WESTERN BEV LIQ TX') & (data['Category (CatMan)']=='ECONOMY VODKA')]
##getting just the matrix##
m=getMatrix(t)
m.head(5)
# Out:
# 22    0.005781       0    0.000000    0.633866  0.464286  0.807412
# 23    0.005757       0    0.000000    0.692935  0.416667  0.613123
# 24    0.005731       0    0.000000    0.642540  0.321429  0.660436
# 25    0.005731       0    0.000000    0.667124  0.321429  0.648854
# 26    0.005700       0    0.000000    0.759072  0.366667  0.669916
# 27    0.005588       0    0.000000    0.655562  0.400000  0.755785
# 28    0.005523       0    0.000000    0.630488  0.392857  0.806116
# 29    0.005492       0    0.000000    0.676123  0.464286  0.801731
# 30    0.005483       0    0.000000    0.604743  0.392857  0.810439
# 31    0.005461       0    0.000000    0.642540  0.392857  0.768183
# 32    0.005461       0    0.000000    0.650332  0.464286  0.723798

# %% [markdown]
# ## Running for entire DataFrame
# by Chain and Category

# %%
dfSimilarity = data.groupby(['Chain Master','Category (CatMan)']).apply(calcSimilarity,doNLP=True,nlp=nlp).reset_index()
dfSimilarity['Events_NLP'] = dfSimilarity['EventsNorm'] *  dfSimilarity['TextNLP']
dfSimilarity=dfSimilarity.drop('level_2',axis=1)

# %%
#testing
dfSimilarity[(dfSimilarity['Chain Master']=='WESTERN BEV LIQ TX') & (dfSimilarity['Product']=='MCCORMICK APPLE VODKA 60  1L')].sort_values(by='Events_NLP',ascending=False).head(10)

#to do
#save the outpu to a file then use a function to read the topn based on a maetrics
#fun(prodname, topn, similarityField=TxtNLP*EventNorm, ascending = False) returns top n products based on a similarity
#create heat map for matrix
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-718448e84701> in <module>
#       1 #testing
# ----> 2 dfSimilarity[(dfSimilarity['Chain Master']=='WESTERN BEV LIQ TX') & (dfSimilarity['Product']=='MCCORMICK APPLE VODKA 60  1L')].sort_values(by='Events_NLP',ascending=False).head(10)
#       3
#       4 #to do
#       5 #save the outpu to a file then use a function to read the topn based on a maetrics
#
# NameError: name 'dfSimilarity' is not defined

# %% [markdown]
# ## Saving to file

# %%
dfSimilarity.to_pickle(os.path.join(folder,'tidy_data/Transactions_v2/Similarity.pkl'))
dfSimilarity.to_csv(os.path.join(folder,'tidy_data/Transactions_v2/Similarity.csv'))

# %% [markdown]
# # Read Similarity Dataframe

# %%
import sys, os
sys.path.append(os.environ['CAPSTONE_PYTHON_SOURCE'])
from similarity.similarity import loadSimilarity

dfSimilarity = loadSimilarity(version=2)

# %% [markdown]
# # Top N similar Products

# %%
from similarity.similarity import topSimilar
topSimilar(dfSimilarity,ChainMaster='WESTERN BEV LIQ TX',Product='MCCORMICK APPLE VODKA 60  1L',topn=10)
# Out:
#              Chain Master Category (CatMan)                       Product  \
# 40613  WESTERN BEV LIQ TX     ECONOMY VODKA  MCCORMICK APPLE VODKA 60  1L
# 40614  WESTERN BEV LIQ TX     ECONOMY VODKA  MCCORMICK APPLE VODKA 60  1L
# 40616  WESTERN BEV LIQ TX     ECONOMY VODKA  MCCORMICK APPLE VODKA 60  1L
# 40615  WESTERN BEV LIQ TX     ECONOMY VODKA  MCCORMICK APPLE VODKA 60  1L
# 40619  WESTERN BEV LIQ TX     ECONOMY VODKA  MCCORMICK APPLE VODKA 60  1L
# 40617  WESTERN BEV LIQ TX     ECONOMY VODKA  MCCORMICK APPLE VODKA 60  1L
# 40621  WESTERN BEV LIQ TX     ECONOMY VODKA  MCCORMICK APPLE VODKA 60  1L
# 40622  WESTERN BEV LIQ TX     ECONOMY VODKA  MCCORMICK APPLE VODKA 60  1L
# 40618  WESTERN BEV LIQ TX     ECONOMY VODKA  MCCORMICK APPLE VODKA 60  1L
# 40620  WESTERN BEV LIQ TX     ECONOMY VODKA  MCCORMICK APPLE VODKA 60  1L
#
#                                   Product2  Similarity  Events  EventsNorm  \
# 40613         MCCORMICK APPLE VODKA 60  1L    1.000000      51    1.000000
# 40614        MCCORMICK CHERRY VODKA 60  1L    1.000000      51    1.000000
# 40616    MCCORMICK WATERMELON VODKA 60  1L    1.000000      51    1.000000
# 40615        MCCORMICK CITRUS VODKA 60  1L    1.000000      51    1.000000
# 40619         MCCORMICK PEACH VODKA 60  1L    0.210897      50    0.980392
# 40617                   TAAKA VODKA 80  1L    0.008396      51    1.000000
# 40621  MCCORMICK WHIPPED CREAM VODKA 60 1L    0.091747      48    0.941176
# 40622         MCCORMICK GRAPE VODKA 60  1L    0.040719      44    0.862745
# 40618             TAAKA VODKA 80 PET 1.75L    0.008396      51    1.000000
# 40620    TAAKA FRUIT PUNCH VODKA PET 1.75L    0.131006      50    0.980392
#
#        TextCosine   TextLev   TextNLP  Events_NLP
# 40613    1.000000  1.000000  1.000000    1.000000
# 40614    0.842235  0.793103  0.940141    0.940141
# 40616    0.855337  0.757576  0.933619    0.933619
# 40615    0.807142  0.793103  0.923805    0.923805
# 40619    0.928571  0.821429  0.942061    0.923589
# 40617    0.623610  0.500000  0.831466    0.831466
# 40621    0.862483  0.685714  0.867760    0.816715
# 40622    0.928571  0.857143  0.928584    0.801131
# 40618    0.617213  0.285714  0.633556    0.633556
# 40620    0.657952  0.363636  0.631844    0.619455

# %% [markdown]
# # Heatmap

# %%
from similarity.similarity import getHeatmap
from similarity.similarity import loadSimilarity
dfSimilarity = loadSimilarity(version=2)
maxc = dfSimilarity['Chain Master'].nunique()
maxp = dfSimilarity['Category (CatMan)'].nunique()
plt.figure(figsize=(20,10*maxc*maxp))
import seaborn as sns
for ic,c in enumerate(dfSimilarity['Chain Master'].unique()):
    for ip,p in enumerate( dfSimilarity['Category (CatMan)'].unique()):
        plt.subplot(maxc*maxp,1,(ic)*maxp+(ip)+1)
        ax=getHeatmap(dfSimilarity,ChainMaster = c,prodCat = p,size=15,norm=True)
        cbar = ax.collections[0].colorbar
        cbar.ax.tick_params(labelsize=16)
        plt.title('Chain: ' + c +'  Product: ' + p,size=20)
        plt.tick_params(axis='y',labelsize=14)
        plt.tick_params(axis='x',labelsize=14)
        plt.xlabel('')
        plt.ylabel('')
plt.tight_layout()
