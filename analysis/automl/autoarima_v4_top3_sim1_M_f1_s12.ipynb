# %% [markdown]
# # Init

# %%
try:
    import os
    import glob
    import sys
    import math
    from typing import List, Optional
    from functools import partial
    import itertools
    from time import time
except Exception as e:
    print(e)
    print("Some of the libraries needed to run this script were not installed or were not loaded. Please install the libraries before proceeding.")

# %%
sys.path.append(os.environ['DEV_AUTOTS'])
sys.path.append(os.environ['CAPSTONE_PYTHON_SOURCE'])
folder = os.environ['CAPSTONE_DATA']

# %%
try:
    # Data Tables
    import pandas as pd
    import numpy as np

    # Plotting
    import matplotlib.pyplot as plt
    import plotly.offline as py
    from plotly.offline import plot
    py.init_notebook_mode(connected=True)

    # EDA and Feature Engineering
    from scipy.spatial.distance import euclidean, pdist, squareform
    from pmdarima.arima import ADFTest

    # Auto Time Series
    import auto_ts as AT
    from pmdarima.arima import auto_arima

    # Optimizer
    from skopt import gp_minimize
    from skopt.space import Real, Integer
    from skopt.plots import plot_convergence
except Exception as e:
    print(e)
    print("Some of the libraries needed to run this script were not installed or were not loaded. Please install the libraries before proceeding.")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# %load_ext autoreload
# %autoreload 2

# %%
try:
    from ETL.ETL import loadDataset, getTopProducts
    from similarity.similarity import mergeTopSimilar, loadSimilarity
    from charting.charting import surface3DChart
except Exception as e:
    print(e)
    print("Some of the libraries needed to run this script were not installed or were not loaded. Please install the libraries before proceeding.")

# %%
dataRaw= loadDataset(version=4)
dfSimilarity = loadSimilarity(version=4)

# %% [markdown]
# # Prep Data

# %%
#Parameters
ChainMaster = 'SPECS'
ProdCat='SUP PREM WHISKEY'
TOP_PRODUCTS = 3  # How many products to consider in the category
TOP_SIMILAR = 1  # Get TOP_SIMILAR most similar products

RESAMPLE_FREQ = 'M'

# Pricing changes every 4 weeks
if RESAMPLE_FREQ == 'M':
    FORECAST_PERIOD = 1
if RESAMPLE_FREQ == 'W':
    FORECAST_PERIOD = 4 
if RESAMPLE_FREQ == '2W':
    FORECAST_PERIOD = 2 

# Seasonal Period
if RESAMPLE_FREQ == 'M':
    SEASONAL_PERIOD = 12  # Yearly
if RESAMPLE_FREQ == 'W':
    SEASONAL_PERIOD = 13 # Quarterly (we can also take yearly = 52, but SARIMAX becomes too slow)
if RESAMPLE_FREQ == '2W':
    SEASONAL_PERIOD = 13 # This becomes problematic --> for quarterly, should we take 6 biweekly periods or 7 bi-weekly periods. Instead I just took half yearly period  

print("="*50)
print("Parameters being used...")
print("="*50)
print(f"Resample Frequency = {RESAMPLE_FREQ}")
print(f"Forecast Period = {FORECAST_PERIOD}")
print(f"Seasonal Period = {SEASONAL_PERIOD}")
print(f"Chain: {ChainMaster}")
print(f"Product Category: {ProdCat}")
# Out:
# ==================================================
# Parameters being used...
# ==================================================
# Resample Frequency = M
# Forecast Period = 1
# Seasonal Period = 12
# Chain: SPECS
# Product Category: SUP PREM WHISKEY

# %%
ProductsList = getTopProducts(dataRaw, ChainMaster=ChainMaster, ProdCat=ProdCat, topN=TOP_PRODUCTS, timeCol='WeekDate')
ProductsList
# Out:
# ['JACK DANIELS BLK WHSKY  1L',
#  'JACK DANIELS BLK WHSKY  1.75L',
#  'JACK DANIELS BLK WHSKY  750M']

# %%
all_data = []

for i, Product in enumerate(ProductsList):
    # Product = ProductsList[0]
    colTime = 'WeekDate'
    colPreds = ['9L Cases'] #Demand
    colPrice = ['Dollar Sales per 9L Case'] #Price

    #TO DO:
    #Merge top similar only looking at a list of products  DONE
    #Encode before the merge? (same prods same code) DONE
    #one chain, top three products, top 1 similar DONE
    #Impute the price DONE
    (dataModel,colExog,colEnc,colDec) = mergeTopSimilar(dataRaw, dfSimilarity
                                                        ,ChainMaster=ChainMaster
                                                        ,Product=Product
                                                        ,ProductsList=ProductsList
                                                        ,topn=TOP_SIMILAR 
                                                        ,periodCol = colTime
                                                        ,resampleFreq=RESAMPLE_FREQ
                                                        ,encodeCols=True)
                                                                            
    
    if i == 0:
        print(f"Decoder: {colDec}")

    print("\n\n")
    print("-"*50)
    print(f"Product: {colDec.get(str(i))}")
    print("-"*50)
    
    #colExog = colExog + colEndog
    print(f"Exogenous Price Columns: {colExog}")
    
    allCols=[colTime]+colPreds+ colExog
    data=dataModel[allCols]
    print(f"% of weeks without a purchase: {sum(data['9L Cases'] == 0)/data.shape[0]*100}")
    # print(data.tail(5))
    data.iloc[:][data.columns[-(TOP_SIMILAR+2):]].plot()
    all_data.append(data)
    plt.show()
# Out:
# Decoder: {'0': 'JACK DANIELS BLK WHSKY  1L', '1': 'JACK DANIELS BLK WHSKY  1.75L', '2': 'JACK DANIELS BLK WHSKY  750M'}
#
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Exogenous Price Columns: ['0', '1']
# % of weeks without a purchase: 0.0
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Exogenous Price Columns: ['1', '0']
# % of weeks without a purchase: 8.333333333333332
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Exogenous Price Columns: ['2', '1']
# % of weeks without a purchase: 2.380952380952381

# %% [markdown]
# # Model
#
# ## AutoArima (standalone)

# %%
# ?ADFTest.should_diff

# %%
# ?auto_arima

# %%
all_train_autoarima = []
all_test_autoarima = []
all_models_autoarima = []

start = time()
for i, data in enumerate(all_data):
    data_with_index = data.copy(deep=True)
    data_with_index.set_index('WeekDate', inplace=True)

    # Test for stationarity
    adf_test = ADFTest(alpha=0.05)
    print(adf_test.should_diff(data_with_index['9L Cases']))

    train = data_with_index.iloc[:-FORECAST_PERIOD]
    test = data_with_index.iloc[-FORECAST_PERIOD:]
    all_train_autoarima.append(train)
    all_test_autoarima.append(test)
    print(train.shape,test.shape)
    # print(train.columns)
    # print(test.columns)
    # print(train.info(),test.info())

    # TODO: See if we need to make d and D dependent on the output of the ADF test
    arima_model =  auto_arima(
        y=train['9L Cases'],
        exogenous=train.drop(columns='9L Cases', inplace=False),
        out_of_sample_size=FORECAST_PERIOD,
        scoring='mse', # only supports 'mse' or 'mae'
        start_p=0, d=1, start_q=0, max_p=5, max_d=5, max_q=5,  # AR Parameters
        start_P=0, D=1, start_Q=0, max_P=5, max_D=5, max_Q=5, m=SEASONAL_PERIOD, seasonal=True,  # Seasonal Parameters  
        stepwise = True, random_state=20, n_fits = 50, n_jobs=1,  # Hyperparameer Search
        error_action='warn', trace = True, supress_warnings=True 
    )

    print(arima_model.summary())
    _ = arima_model.plot_diagnostics()
    all_models_autoarima.append(arima_model)

print(f"Time taken: {time() - start}")
# Out:
# 075, Time=0.599 seconds
# Near non-invertible roots for order (3, 1, 1)(0, 1, 0, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.999)
# Fit ARIMA(3,1,1)x(1,1,1,12) [intercept=True]; AIC=804.525, BIC=827.010, Time=1.655 seconds
# Near non-invertible roots for order (3, 1, 1)(1, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.999)
# Fit ARIMA(3,1,1)x(0,1,2,12) [intercept=True]; AIC=805.020, BIC=827.505, Time=3.657 seconds
# Near non-invertible roots for order (3, 1, 1)(0, 1, 2, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.998)
# Fit ARIMA(3,1,1)x(1,1,0,12) [intercept=True]; AIC=805.180, BIC=825.416, Time=1.560 seconds
# Near non-invertible roots for order (3, 1, 1)(1, 1, 0, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.996)
# Fit ARIMA(3,1,1)x(1,1,2,12) [intercept=True]; AIC=808.530, BIC=833.264, Time=4.141 seconds
# Near non-invertible roots for order (3, 1, 1)(1, 1, 2, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA(2,1,1)x(0,1,1,12) [intercept=True]; AIC=805.501, BIC=823.489, Time=1.483 seconds
# Fit ARIMA(3,1,2)x(0,1,1,12) [intercept=True]; AIC=802.216, BIC=824.701, Time=1.942 seconds
# Fit ARIMA(3,1,2)x(0,1,0,12) [intercept=True]; AIC=831.085, BIC=851.322, Time=0.737 seconds
# Fit ARIMA(3,1,2)x(1,1,1,12) [intercept=True]; AIC=809.232, BIC=833.965, Time=1.717 seconds
# Near non-invertible roots for order (3, 1, 2)(1, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA(3,1,2)x(0,1,2,12) [intercept=True]; AIC=809.476, BIC=834.209, Time=3.846 seconds
# Near non-invertible roots for order (3, 1, 2)(0, 1, 2, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA(3,1,2)x(1,1,0,12) [intercept=True]; AIC=811.600, BIC=834.085, Time=1.773 seconds
# Near non-invertible roots for order (3, 1, 2)(1, 1, 0, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA(3,1,2)x(1,1,2,12) [intercept=True]; AIC=811.226, BIC=838.208, Time=4.677 seconds
# Near non-invertible roots for order (3, 1, 2)(1, 1, 2, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA(2,1,2)x(0,1,1,12) [intercept=True]; AIC=809.448, BIC=829.685, Time=1.683 seconds
# Near non-invertible roots for order (2, 1, 2)(0, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA(4,1,2)x(0,1,1,12) [intercept=True]; AIC=808.468, BIC=833.202, Time=1.860 seconds
# Near non-invertible roots for order (4, 1, 2)(0, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA(3,1,3)x(0,1,1,12) [intercept=True]; AIC=821.217, BIC=845.950, Time=2.241 seconds
# Near non-invertible roots for order (3, 1, 3)(0, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.994)
# Fit ARIMA(2,1,3)x(0,1,1,12) [intercept=True]; AIC=812.272, BIC=834.757, Time=2.631 seconds
# Near non-invertible roots for order (2, 1, 3)(0, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.999)
# Fit ARIMA(4,1,3)x(0,1,1,12) [intercept=True]; AIC=818.544, BIC=845.526, Time=2.346 seconds
# Near non-invertible roots for order (4, 1, 3)(0, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.991)
# Total fit time: 111.908 seconds
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                   83
# Model:             SARIMAX(3, 1, 2)x(0, 1, [1], 12)   Log Likelihood                -391.108
# Date:                              Thu, 09 Jul 2020   AIC                            802.216
# Time:                                      05:21:06   BIC                            824.701
# Sample:                                           0   HQIC                           811.147
#                                                - 83
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     -0.6385      0.279     -2.291      0.022      -1.185      -0.092
# x1             1.4339      1.387      1.034      0.301      -1.284       4.152
# x2            -6.6265      2.077     -3.191      0.001     -10.697      -2.556
# ar.L1          0.3850      0.196      1.966      0.049       0.001       0.769
# ar.L2         -0.1735      0.177     -0.980      0.327      -0.520       0.173
# ar.L3         -0.0139      0.163     -0.085      0.932      -0.333       0.305
# ma.L1         -1.9617      0.371     -5.288      0.000      -2.689      -1.235
# ma.L2          0.9708      0.361      2.688      0.007       0.263       1.679
# ma.S.L12      -0.8541      0.355     -2.405      0.016      -1.550      -0.158
# sigma2      3362.5847   1405.579      2.392      0.017     607.700    6117.470
# ===================================================================================
# Ljung-Box (Q):                       31.62   Jarque-Bera (JB):                 3.51
# Prob(Q):                              0.83   Prob(JB):                         0.17
# Heteroskedasticity (H):               0.87   Skew:                             0.47
# Prob(H) (two-sided):                  0.74   Kurtosis:                         3.55
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# (0.1145957797237808, True)
# (83, 3) (1, 3)
# Performing stepwise search to minimize aic
# Fit ARIMA(0,1,0)x(0,1,0,12) [intercept=True]; AIC=761.696, BIC=770.690, Time=0.135 seconds
# Fit ARIMA(1,1,0)x(1,1,0,12) [intercept=True]; AIC=741.515, BIC=755.006, Time=0.726 seconds
# Fit ARIMA(0,1,1)x(0,1,1,12) [intercept=True]; AIC=698.031, BIC=711.522, Time=1.078 seconds
# Near non-invertible roots for order (0, 1, 1)(0, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA(0,1,0)x(0,1,0,12) [intercept=False]; AIC=759.696, BIC=766.442, Time=0.196 seconds
# Fit ARIMA(1,1,0)x(0,1,0,12) [intercept=True]; AIC=751.425, BIC=762.667, Time=0.260 seconds
# Fit ARIMA(1,1,0)x(2,1,0,12) [intercept=True]; AIC=742.289, BIC=758.028, Time=2.299 seconds
# Fit ARIMA(1,1,0)x(1,1,1,12) [intercept=True]; AIC=741.873, BIC=757.612, Time=0.797 seconds
# Fit ARIMA(1,1,0)x(0,1,1,12) [intercept=True]; AIC=739.827, BIC=753.318, Time=0.546 seconds
# Fit ARIMA(1,1,0)x(0,1,2,12) [intercept=True]; AIC=741.886, BIC=757.625, Time=1.600 seconds
# Fit ARIMA(1,1,0)x(1,1,2,12) [intercept=True]; AIC=743.412, BIC=761.400, Time=2.801 seconds
# Near non-invertible roots for order (1, 1, 0)(1, 1, 2, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.998)
# Fit ARIMA(0,1,0)x(0,1,1,12) [intercept=True]; AIC=754.809, BIC=766.051, Time=0.492 seconds
# Fit ARIMA(2,1,0)x(0,1,1,12) [intercept=True]; AIC=710.498, BIC=726.237, Time=0.876 seconds
# Fit ARIMA(2,1,0)x(0,1,0,12) [intercept=True]; AIC=719.850, BIC=733.341, Time=0.406 seconds
# Fit ARIMA(2,1,0)x(1,1,1,12) [intercept=True]; AIC=712.475, BIC=730.463, Time=1.190 seconds
# Fit ARIMA(2,1,0)x(0,1,2,12) [intercept=True]; AIC=712.473, BIC=730.461, Time=2.304 seconds
# Fit ARIMA(2,1,0)x(1,1,0,12) [intercept=True]; AIC=713.031, BIC=728.770, Time=1.041 seconds
# Fit ARIMA(2,1,0)x(1,1,2,12) [intercept=True]; AIC=714.472, BIC=734.709, Time=3.168 seconds
# Fit ARIMA(3,1,0)x(0,1,1,12) [intercept=True]; AIC=709.650, BIC=727.638, Time=0.968 seconds
# Fit ARIMA(3,1,0)x(0,1,0,12) [intercept=True]; AIC=718.416, BIC=734.155, Time=0.391 seconds
# Fit ARIMA(3,1,0)x(1,1,1,12) [intercept=True]; AIC=711.266, BIC=731.503, Time=1.341 seconds
# Fit ARIMA(3,1,0)x(0,1,2,12) [intercept=True]; AIC=711.114, BIC=731.351, Time=2.815 seconds
# Fit ARIMA(3,1,0)x(1,1,0,12) [intercept=True]; AIC=713.211, BIC=731.199, Time=0.987 seconds
# Fit ARIMA(3,1,0)x(1,1,2,12) [intercept=True]; AIC=713.049, BIC=735.534, Time=3.599 seconds
# Fit ARIMA(4,1,0)x(0,1,1,12) [intercept=True]; AIC=699.602, BIC=719.839, Time=1.453 seconds
# Fit ARIMA(4,1,0)x(0,1,0,12) [intercept=True]; AIC=709.556, BIC=727.544, Time=0.505 seconds
# Fit ARIMA(4,1,0)x(1,1,1,12) [intercept=True]; AIC=701.506, BIC=723.991, Time=1.834 seconds
# Fit ARIMA(4,1,0)x(0,1,2,12) [intercept=True]; AIC=701.450, BIC=723.935, Time=3.584 seconds
# Fit ARIMA(4,1,0)x(1,1,0,12) [intercept=True]; AIC=703.371, BIC=723.607, Time=1.566 seconds
# Fit ARIMA(4,1,0)x(1,1,2,12) [intercept=True]; AIC=703.261, BIC=727.994, Time=3.820 seconds
# Fit ARIMA(5,1,0)x(0,1,1,12) [intercept=True]; AIC=698.158, BIC=720.643, Time=1.428 seconds
# Fit ARIMA(5,1,0)x(0,1,0,12) [intercept=True]; AIC=707.225, BIC=727.461, Time=0.806 seconds
# Fit ARIMA(5,1,0)x(1,1,1,12) [intercept=True]; AIC=700.111, BIC=724.845, Time=2.103 seconds
# Fit ARIMA(5,1,0)x(0,1,2,12) [intercept=True]; AIC=700.055, BIC=724.788, Time=3.790 seconds
# Fit ARIMA(5,1,0)x(1,1,0,12) [intercept=True]; AIC=701.469, BIC=723.954, Time=1.782 seconds
# Fit ARIMA(5,1,0)x(1,1,2,12) [intercept=True]; AIC=701.918, BIC=728.900, Time=4.307 seconds
# Fit ARIMA(5,1,1)x(0,1,1,12) [intercept=True]; AIC=676.894, BIC=701.627, Time=1.456 seconds
# Near non-invertible roots for order (5, 1, 1)(0, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.996)
# Fit ARIMA(4,1,1)x(0,1,1,12) [intercept=True]; AIC=676.294, BIC=698.779, Time=1.310 seconds
# Near non-invertible roots for order (4, 1, 1)(0, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.997)
# Total fit time: 59.799 seconds
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                   83
# Model:             SARIMAX(4, 1, 1)x(0, 1, 1, 12)   Log Likelihood                -328.147
# Date:                            Thu, 09 Jul 2020   AIC                            676.294
# Time:                                    05:22:06   BIC                            698.779
# Sample:                                         0   HQIC                           685.225
#                                              - 83
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.3767      0.245      1.538      0.124      -0.103       0.857
# x1            -0.9884      1.129     -0.875      0.381      -3.202       1.225
# x2             1.1743      0.632      1.858      0.063      -0.064       2.413
# ar.L1         -0.4565      0.137     -3.336      0.001      -0.725      -0.188
# ar.L2         -0.6645      0.135     -4.910      0.000      -0.930      -0.399
# ar.L3         -0.2156      0.162     -1.334      0.182      -0.532       0.101
# ar.L4         -0.3694      0.127     -2.914      0.004      -0.618      -0.121
# ma.L1         -0.9972      2.888     -0.345      0.730      -6.657       4.662
# ma.S.L12      -0.5378      0.194     -2.773      0.006      -0.918      -0.158
# sigma2       581.1258   1655.511      0.351      0.726   -2663.616    3825.868
# ===================================================================================
# Ljung-Box (Q):                       30.62   Jarque-Bera (JB):                 5.86
# Prob(Q):                              0.86   Prob(JB):                         0.05
# Heteroskedasticity (H):               0.80   Skew:                             0.18
# Prob(H) (two-sided):                  0.60   Kurtosis:                         4.37
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# (0.01, False)
# (83, 3) (1, 3)
# Performing stepwise search to minimize aic
# Fit ARIMA(0,1,0)x(0,1,0,12) [intercept=True]; AIC=659.807, BIC=668.801, Time=0.126 seconds
# Fit ARIMA(1,1,0)x(1,1,0,12) [intercept=True]; AIC=630.847, BIC=644.338, Time=0.596 seconds
# Fit ARIMA(0,1,1)x(0,1,1,12) [intercept=True]; AIC=600.056, BIC=613.547, Time=1.111 seconds
# Near non-invertible roots for order (0, 1, 1)(0, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA(0,1,0)x(0,1,0,12) [intercept=False]; AIC=657.810, BIC=664.555, Time=0.189 seconds
# Fit ARIMA(1,1,0)x(0,1,0,12) [intercept=True]; AIC=634.925, BIC=646.167, Time=0.209 seconds
# Fit ARIMA(1,1,0)x(2,1,0,12) [intercept=True]; AIC=627.784, BIC=643.524, Time=1.691 seconds
# Fit ARIMA(1,1,0)x(3,1,0,12) [intercept=True]; AIC=626.670, BIC=644.658, Time=3.246 seconds
# Fit ARIMA(1,1,0)x(4,1,0,12) [intercept=True]; AIC=623.877, BIC=644.113, Time=6.238 seconds
# Near non-invertible roots for order (1, 1, 0)(4, 1, 0, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.994)
# Fit ARIMA(1,1,0)x(3,1,1,12) [intercept=True]; AIC=627.498, BIC=647.735, Time=4.840 seconds
# Near non-invertible roots for order (1, 1, 0)(3, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.997)
# Fit ARIMA(1,1,0)x(2,1,1,12) [intercept=True]; AIC=625.666, BIC=643.654, Time=3.324 seconds
# Near non-invertible roots for order (1, 1, 0)(2, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.999)
# Fit ARIMA(1,1,0)x(4,1,1,12) [intercept=True]; AIC=625.647, BIC=648.132, Time=8.293 seconds
# Fit ARIMA(1,1,0)x(5,1,1,12) [intercept=True]; AIC=626.757, BIC=651.490, Time=12.086 seconds
# Fit ARIMA(1,1,0)x(4,1,2,12) [intercept=True]; AIC=627.760, BIC=652.494, Time=8.968 seconds
# Fit ARIMA(1,1,0)x(3,1,2,12) [intercept=True]; AIC=629.324, BIC=651.809, Time=5.650 seconds
# Fit ARIMA(1,1,0)x(5,1,0,12) [intercept=True]; AIC=624.723, BIC=647.208, Time=10.702 seconds
# Near non-invertible roots for order (1, 1, 0)(5, 1, 0, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.998)
# Fit ARIMA(1,1,0)x(5,1,2,12) [intercept=True]; AIC=628.807, BIC=655.789, Time=13.917 seconds
# Fit ARIMA(0,1,0)x(4,1,1,12) [intercept=True]; AIC=640.389, BIC=660.625, Time=6.904 seconds
# Fit ARIMA(2,1,0)x(4,1,1,12) [intercept=True]; AIC=606.623, BIC=631.357, Time=9.033 seconds
# Fit ARIMA(2,1,0)x(3,1,1,12) [intercept=True]; AIC=607.704, BIC=630.189, Time=5.740 seconds
# Near non-invertible roots for order (2, 1, 0)(3, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.996)
# Fit ARIMA(2,1,0)x(4,1,0,12) [intercept=True]; AIC=604.588, BIC=627.072, Time=6.545 seconds
# Near non-invertible roots for order (2, 1, 0)(4, 1, 0, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.992)
# Fit ARIMA(2,1,0)x(5,1,1,12) [intercept=True]; AIC=608.597, BIC=635.579, Time=15.136 seconds
# Fit ARIMA(2,1,0)x(4,1,2,12) [intercept=True]; AIC=608.460, BIC=635.442, Time=10.759 seconds
# Fit ARIMA(2,1,0)x(3,1,0,12) [intercept=True]; AIC=608.060, BIC=628.296, Time=4.898 seconds
# Fit ARIMA(2,1,0)x(3,1,2,12) [intercept=True]; AIC=609.417, BIC=634.150, Time=7.012 seconds
# Fit ARIMA(2,1,0)x(5,1,0,12) [intercept=True]; AIC=606.605, BIC=631.339, Time=14.352 seconds
# Near non-invertible roots for order (2, 1, 0)(5, 1, 0, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.993)
# Fit ARIMA(2,1,0)x(5,1,2,12) [intercept=True]; AIC=610.522, BIC=639.753, Time=21.542 seconds
# Fit ARIMA(3,1,0)x(4,1,1,12) [intercept=True]; AIC=606.847, BIC=633.829, Time=12.210 seconds
# Fit ARIMA(2,1,1)x(4,1,1,12) [intercept=True]; AIC=597.360, BIC=624.342, Time=12.299 seconds
# Near non-invertible roots for order (2, 1, 1)(4, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.993)
# Fit ARIMA(1,1,1)x(4,1,1,12) [intercept=True]; AIC=602.444, BIC=627.177, Time=11.512 seconds
# Near non-invertible roots for order (1, 1, 1)(4, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.999)
# Fit ARIMA(3,1,1)x(4,1,1,12) [intercept=True]; AIC=599.370, BIC=628.601, Time=12.895 seconds
# Near non-invertible roots for order (3, 1, 1)(4, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.990)
# Total fit time: 232.083 seconds
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                   83
# Model:             SARIMAX(2, 1, 1)x(4, 1, 1, 12)   Log Likelihood                -286.680
# Date:                            Thu, 09 Jul 2020   AIC                            597.360
# Time:                                    05:25:58   BIC                            624.342
# Sample:                                         0   HQIC                           608.077
#                                              - 83
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     -1.6858      2.216     -0.761      0.447      -6.029       2.657
# x1            -0.6956      0.344     -2.020      0.043      -1.370      -0.021
# x2             0.2137      0.879      0.243      0.808      -1.510       1.937
# ar.L1         -0.4492      0.163     -2.759      0.006      -0.768      -0.130
# ar.L2         -0.3696      0.139     -2.661      0.008      -0.642      -0.097
# ma.L1         -0.9856      0.498     -1.978      0.048      -1.962      -0.009
# ar.S.L12      -1.5341      2.391     -0.642      0.521      -6.221       3.152
# ar.S.L24      -1.2361      1.558     -0.794      0.427      -4.289       1.817
# ar.S.L36      -1.0764      1.331     -0.809      0.419      -3.685       1.532
# ar.S.L48      -0.5946      0.951     -0.625      0.532      -2.458       1.269
# ma.S.L12       0.9231      8.851      0.104      0.917     -16.424      18.270
# sigma2       125.6519    782.369      0.161      0.872   -1407.764    1659.068
# ===================================================================================
# Ljung-Box (Q):                       29.82   Jarque-Bera (JB):                 8.52
# Prob(Q):                              0.88   Prob(JB):                         0.01
# Heteroskedasticity (H):               0.94   Skew:                             0.19
# Prob(H) (two-sided):                  0.89   Kurtosis:                         4.67
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Time taken: 404.1875002384186

# %% [markdown]
# ### Validation Set Predictions

# %%
for i in np.arange(len(all_data)):
    print("\n")
    print("-"*50)
    print(f"Product: {colDec.get(str(i))}")
    print("-"*50)
    print(f"Best Model AIC: {all_models_autoarima[i].aic()}")
    print(f"Validation Set: \n{all_train_autoarima[i].tail(1)['9L Cases']}")
    print(f"Validation Set Predictions: {all_models_autoarima[i].oob_preds_}")  
    print(f"Validation Set MSE: {all_models_autoarima[i].oob()}")
    print(f"Validation Set RMSE: {math.sqrt(all_models_autoarima[i].oob())}")
# Out:
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
# Best Model AIC: 802.2159494814434
# Validation Set:
# WeekDate
# 2019-11-30    240.73
# Name: 9L Cases, dtype: float64
# Validation Set Predictions: [249.93634159]
# Validation Set MSE: 84.7567254848932
# Validation Set RMSE: 9.206341590713066
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
# Best Model AIC: 676.2936029247545
# Validation Set:
# WeekDate
# 2019-11-30    35.1
# Name: 9L Cases, dtype: float64
# Validation Set Predictions: [64.50160289]
# Validation Set MSE: 864.4542525197278
# Validation Set RMSE: 29.401602890314123
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
# Best Model AIC: 597.3598408125155
# Validation Set:
# WeekDate
# 2019-11-30    14.0
# Name: 9L Cases, dtype: float64
# Validation Set Predictions: [30.20971046]
# Validation Set MSE: 262.7547133470052
# Validation Set RMSE: 16.209710464625985

# %% [markdown]
# ### Test Set Predictions

# %%
for i in np.arange(len(all_data)):
    print("\n")
    print("-"*50)
    print(f"Product: {colDec.get(str(i))}")
    print("-"*50)
    print("\nTest Data")
    print(all_test_autoarima[i])
    test_predictions = all_models_autoarima[i].predict(
        n_periods=FORECAST_PERIOD,
        exogenous=all_test_autoarima[i].drop(columns='9L Cases', inplace=False)
    )  
    print("\nBest Prediction")
    print(test_predictions)
# Out:
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
#
# Test Data
#             9L Cases           0           1
# WeekDate
# 2019-12-31    476.14  229.533835  185.589744
#
# Best Prediction
# [268.3610528]
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
#
# Test Data
#             9L Cases           1           0
# WeekDate
# 2019-12-31    176.67  185.589744  229.533835
#
# Best Prediction
# [67.1766551]
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
#
# Test Data
#             9L Cases       2           1
# WeekDate
# 2019-12-31      69.0  222.36  185.589744
#
# Best Prediction
# [33.14007246]

# %%
# arima_model.get_params()

# %%
# ?arima_model.predict

# %% [markdown]
# ## AutoTimeSeries

# %%
for i, data in enumerate(all_data):
    train = data.iloc[:-FORECAST_PERIOD]
    test = data.iloc[-FORECAST_PERIOD:]
    all_train.append(train)
    all_test.append(test)
    print(train.shape,test.shape)

    automl_model = AT.AutoTimeSeries(
        score_type='rmse', forecast_period=FORECAST_PERIOD, # time_interval='Week',
        non_seasonal_pdq=None, seasonality=True, seasonal_period=SEASONAL_PERIOD,
        model_type=['SARIMAX','ML'],
        verbose=0)
    automl_model.fit(train, 'WeekDate', '9L Cases', ',')
    automl_model.get_leaderboard()
    all_models.append(automl_model)
# Out:
# (83, 4) (1, 4)
# Start of Fit.....
#     Target variable = 9L Cases
# Start of loading of data.....
# Input is data frame. Performing Time Series Analysis
#     Dataframe loaded successfully. Shape of data set = (83, 3)
# Time Interval of obserations has not been provided. Program will try to figure this out now...
# Time series input in days = 28
# It is a Monthly time series.
#
#
# ==================================================
# Building SARIMAX Model
# ==================================================
#
#
#
# Running Seasonal SARIMAX Model...
# Building a Seasonal Model...
#
#     Finding best Non-Seasonal pdq Parameters:
#
# Differencing = 0 with Seasonality = False
#     Iteration 0 completed...
#     Best AR order p = 0, MA order q = 3, Interim metric = 863.907
#
# Differencing = 1 with Seasonality = True
#     D = 1 results in an empty ARMA set. Setting Seasonality to False since model might overfit
#
#     Finding best Seasonal PDQ Model Parameters:
#
# Differencing = 0 with Seasonality = True
#     Iteration 0 completed...
#     Best AR order p = 0, MA order q = 3, Interim metric = 473.791
#
# Differencing = 1 with Seasonality = True
#     Best AR order p = 0, MA order q = 3, Interim metric = 344.192
#
# Best model is a Seasonal SARIMAX(0,0,3)*(0,1,3,12), aic = 344.192
# Fitting best SARIMAX model
#     Best aic metric = 348.6
# Refitting data with previously found best parameters
#     Best aic metric = 361.5
# Dynamic 1-Period Forecast:
#     RMSE = 90.85
#     Std Deviation of Originals = 65.11
#     Normalized RMSE = 140%
#
#
# ==================================================
# Building ML Model
# ==================================================
#
#
#
# Running Machine Learning Models...
#     Shifting 2 predictors by lag=0 to align prior predictor with current target...
# Running multiple models...
#     RMSE = 53.36
#     Std Deviation of Originals = 64.71
#     Normalized RMSE = 82%
#
# Best Model is: ML
#     Best Model Score: 53.36
#     Best Model Forecasts (Validation Set):
# WeekDate
# 2019-11-30    187.371667
# Name: mean, dtype: float64
#
#
# --------------------------------------------------
# Total time taken: 112.70724773406982 seconds.
# --------------------------------------------------
#
#
# (83, 4) (1, 4)
# Start of Fit.....
#     Target variable = 9L Cases
# Start of loading of data.....
# Input is data frame. Performing Time Series Analysis
#     Dataframe loaded successfully. Shape of data set = (83, 3)
# Time Interval of obserations has not been provided. Program will try to figure this out now...
# Time series input in days = 28
# It is a Monthly time series.
#
#
# ==================================================
# Building SARIMAX Model
# ==================================================
#
#
#
# Running Seasonal SARIMAX Model...
# Building a Seasonal Model...
#
#     Finding best Non-Seasonal pdq Parameters:
#
# Differencing = 0 with Seasonality = False
#     Iteration 0 completed...
#     Best AR order p = 1, MA order q = 3, Interim metric = 740.896
#
# Differencing = 1 with Seasonality = True
#     D = 1 results in an empty ARMA set. Setting Seasonality to False since model might overfit
#
#     Finding best Seasonal PDQ Model Parameters:
#
# Differencing = 0 with Seasonality = True
#     Iteration 0 completed...
#     Best AR order p = 0, MA order q = 3, Interim metric = 390.123
#
# Differencing = 1 with Seasonality = True
#     Best AR order p = 2, MA order q = 3, Interim metric = 283.097
#
# Best model is a Seasonal SARIMAX(1,0,3)*(2,1,3,12), aic = 283.097
# Fitting best SARIMAX model
#     Best aic metric = 285.6
# Refitting data with previously found best parameters
#     Best aic metric = 296.9
# Dynamic 1-Period Forecast:
#     RMSE = 64.38
#     Std Deviation of Originals = 30.86
#     Normalized RMSE = 209%
#
#
# ==================================================
# Building ML Model
# ==================================================
#
#
#
# Running Machine Learning Models...
#     Shifting 2 predictors by lag=0 to align prior predictor with current target...
# Running multiple models...
#     RMSE = 15.54
#     Std Deviation of Originals = 30.67
#     Normalized RMSE = 51%
#
# Best Model is: ML
#     Best Model Score: 15.54
#     Best Model Forecasts (Validation Set):
# WeekDate
# 2019-11-30    50.6376
# Name: mean, dtype: float64
#
#
# --------------------------------------------------
# Total time taken: 108.26087403297424 seconds.
# --------------------------------------------------
#
#
# (83, 4) (1, 4)
# Start of Fit.....
#     Target variable = 9L Cases
# Start of loading of data.....
# Input is data frame. Performing Time Series Analysis
#     Dataframe loaded successfully. Shape of data set = (83, 3)
# Time Interval of obserations has not been provided. Program will try to figure this out now...
# Time series input in days = 28
# It is a Monthly time series.
#
#
# ==================================================
# Building SARIMAX Model
# ==================================================
#
#
#
# Running Seasonal SARIMAX Model...
# Building a Seasonal Model...
#
#     Finding best Non-Seasonal pdq Parameters:
#
# Differencing = 0 with Seasonality = False
#     Iteration 0 completed...
#     Best AR order p = 1, MA order q = 3, Interim metric = 639.451
#
# Differencing = 1 with Seasonality = True
#     D = 1 results in an empty ARMA set. Setting Seasonality to False since model might overfit
#
#     Finding best Seasonal PDQ Model Parameters:
#
# Differencing = 0 with Seasonality = True
#     Iteration 0 completed...
#     Best AR order p = 0, MA order q = 3, Interim metric = 343.506
#
# Differencing = 1 with Seasonality = True
#     Best AR order p = 2, MA order q = 3, Interim metric = 253.096
#
# Best model is a Seasonal SARIMAX(1,0,3)*(2,1,3,12), aic = 253.096
# Fitting best SARIMAX model
#     Best aic metric = 243.0
# Refitting data with previously found best parameters
#     Best aic metric = 252.5
# Dynamic 1-Period Forecast:
#     RMSE = 18.19
#     Std Deviation of Originals = 15.82
#     Normalized RMSE = 115%
#
#
# ==================================================
# Building ML Model
# ==================================================
#
#
#
# Running Machine Learning Models...
#     Shifting 2 predictors by lag=0 to align prior predictor with current target...
# Running multiple models...
#     RMSE = 19.90
#     Std Deviation of Originals = 15.72
#     Normalized RMSE = 127%
#
# Best Model is: SARIMAX
#     Best Model Score: 18.19
#     Best Model Forecasts (Validation Set):
# 9L Cases         mean   mean_se  mean_ci_lower  mean_ci_upper
# 2019-11-30  32.187691  8.099777      16.312421      48.062962
#
#
# --------------------------------------------------
# Total time taken: 110.55359745025635 seconds.
# --------------------------------------------------

# %%
for i in np.arange(len(all_data)):
    print("\n")
    print("-"*50)
    print(f"Product: {colDec.get(str(i))}")
    print("-"*50)
    print("\nLeaderboard")
    print(all_models[i].get_leaderboard())
# Out:
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
#
# Leaderboard
#       name       rmse
# 1       ML  53.358333
# 0  SARIMAX  90.847675
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
#
# Leaderboard
#       name      rmse
# 1       ML  15.53760
# 0  SARIMAX  64.37819
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
#
# Leaderboard
#       name       rmse
# 0  SARIMAX  18.187691
# 1       ML  19.900000

# %% [markdown]
# # Prediction

# %%
for i in np.arange(len(all_data)):
    print("\n")
    print("-"*50)
    print(f"Product: {colDec.get(str(i))}")
    print("-"*50)
    print("\nTest Data")
    print(all_test[i])
    test_predictions = all_models[i].predict(X_exogen = all_test[i])  
    print("\nBest Prediction")
    print(test_predictions)
    print("\nML Predictions")
    test_predictions = all_models[i].predict(X_exogen = all_test[i], model='ML')  
    print(test_predictions)
    print("\nSARIMAX Predictions")
    test_predictions = all_models[i].predict(X_exogen = all_test[i], model='SARIMAX')  
    print(test_predictions)
# Out:
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1L
# --------------------------------------------------
#
# Test Data
#      WeekDate  9L Cases           0           1
# 83 2019-12-31    476.14  229.533835  185.589744
#
# Best Prediction
# 83    187.371667
# Name: mean, dtype: float64
#
# ML Predictions
# 83    187.371667
# Name: mean, dtype: float64
#
# SARIMAX Predictions
# 369.3102790439557
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  1.75L
# --------------------------------------------------
#
# Test Data
#      WeekDate  9L Cases           1           0
# 83 2019-12-31    176.67  185.589744  229.533835
#
# Best Prediction
# 83    50.6376
# Name: mean, dtype: float64
#
# ML Predictions
# 83    50.6376
# Name: mean, dtype: float64
#
# SARIMAX Predictions
# 87.47481903667469
#
#
# --------------------------------------------------
# Product: JACK DANIELS BLK WHSKY  750M
# --------------------------------------------------
#
# Test Data
#      WeekDate  9L Cases       2           1
# 83 2019-12-31      69.0  222.36  185.589744
#
# Best Prediction
# 32.83599216616835
#
# ML Predictions
# 83    33.9
# Name: mean, dtype: float64
#
# SARIMAX Predictions
# 32.83599216616835

# %% [markdown]
# # Optimizer

# %%
def complex_objective(x: List, mask: Optional[List[bool]] = None, verbose: int = 0, return_individual: bool = False):
    """
    :param x A list of product pricing for which the revenue has to be computed
    :type x List
    :param mask: If the customer is not going to purchase a product in a period, we can choose to omit it from the revenue calculation in the optimizer.
                 Default = None (considers all products in revenue calculation)
    :type mask  Optional[List[bool]]
    :param return_individual If True, this returns the individual revenue values as well
                             Used mainly when this function is called standalone. Set of False for optimization
    :type return_individual bool
    :param verbose Level of verbosity (Default: 0). This is set to 1 or 2 (mainly for debug purposes)
    """

    index = [str(i) for i in np.arange(len(x))]
    x_df = pd.DataFrame(x, index = index)
    x_df = x_df.T

    # If mask is not provided, use all
    if mask is None:
        mask = [False for item in x] 

    if verbose >= 2:
        print(x_df.info())
        print(x_df.columns)

    total_revenue = 0
    revenue = []

    for i in np.arange(len(all_data)):
        if verbose >= 1:
            print("\n" + "-"*50)
            print(f"Product Index: {i}")
        
        if not mask[i]:
            columns = all_data[i].columns[-(TOP_SIMILAR+1):].values
            if verbose >= 2:
                print(f"All Columns in Test Data: {columns}")

            test_data = x_df[columns]
            prediction = all_models[i].predict(X_exogen = test_data)
            
            if verbose >= 2:
                print(f"Prediction Type: {type(prediction)}")
            if verbose >= 1:
                print(f"Demand Prediction: {prediction}")
                
            product_revenue = prediction * x[i]

            # TODO: Clamping - Fix later (this gives an error with pandas. We need to pluck it out as a value)
            # product_revenue = max(product_revenue, 0)  # Clamp at min value of 0 for predictions that are negative

            if verbose >= 1:
                print(f"Product Revenue: ${round(product_revenue)}")
                                
            if isinstance(product_revenue, pd.Series):
                product_revenue = product_revenue.iloc[0]
            revenue.append(product_revenue)
                
            # total_revenue = total_revenue + product_revenue
        else:
            if verbose >= 1:
                print("This product's revenue was not included since it was not ordered by the customer in this period.")
            product_revenue = 0
            revenue.append(product_revenue)

        if verbose >= 1:
            print("-"*50 + "\n")
        
    total_revenue = sum(revenue)

    if verbose >= 1:
        print("\n\n" + "="*50)
        print(f"Total Revenue: ${round(total_revenue)}")
        print("="*50 + "\n\n")

    if return_individual is True:
        return -total_revenue, revenue      

    return -total_revenue

# %%
# Did the customer actually want to but products in that period?
# Only include the revenue in the objective if they actually ordered it
# This model is not trying to predict if they would purchase a product when they were not going to purchase it earlier.
# That requires a lot of human psychology and may not be captured in the model

INCLUDE_MASKING = True

mask: List[bool] = []
for index in np.arange(len(all_data)):
    if INCLUDE_MASKING:
        if all_test[index].iloc[0]['9L Cases'] == 0:
            mask.append(True)
        else:
            mask.append(False)
    else:
        mask.append(False)

print(f"Mask: {mask}")
# Out:
# Mask: [False, False, False]

# %%
MARGIN = 0.0 # How much to go over or under the min and max price respectively during the search for optimial revenue
space = []

for index in np.arange(len(all_data)):
    min_val = all_data[index][str(index)].min()
    max_val = all_data[index][str(index)].max()
    min_limit = min_val*(1-MARGIN)
    max_limit = max_val*(1+MARGIN)
    # print(min_val, max_val)
    # print(min_limit, max_limit)
    space.append(Real(low=min_limit, high=max_limit, prior='uniform'))

space
# Out:
# [Real(low=196.51221804511277, high=238.29562345169282, prior='uniform', transform='identity'),
#  Real(low=158.86324786324786, high=189.49694749694748, prior='uniform', transform='identity'),
#  Real(low=193.91, high=229.32, prior='uniform', transform='identity')]

# %%
# create a new function with mask
masked_complex_objective = partial(complex_objective, mask=mask)
print(f"Revenue without masking: ${-round(complex_objective([266.51, 195.06, 205.3]))}")
print(f"Revenue with masking: ${-round(masked_complex_objective([266.51, 195.06, 205.3]))}")
# Out:
# Revenue without masking: $68888.0
# Revenue with masking: $68888.0

# %%
res = gp_minimize(masked_complex_objective,   
                  space,                      
                  acq_func="EI",              
                  n_calls=200,                
                  n_random_starts=20,  
                  random_state=42)

# %%
print(f"Optimal Price for All Products ($): {[round(price, 2) for price in res.x]} \nMaximum Revenue Expected: ${round(-res.fun)}")
_, all_revenue = masked_complex_objective(res.x, return_individual=True)
print(f"Individual Optimized Revenue: {all_revenue}")
# Out:
# Optimal Price for All Products ($): [236.35, 186.4, 222.6]
# Maximum Revenue Expected: $61201.0
# Individual Optimized Revenue: [44285.77579545259, 9439.048450944343, 7475.679592914672]

# %%
# 3. Reserve a test set - compute revenue from test set and compare to the one from the optimizer
# This is only for the 1st entry in the test set

total_test_data_revenue = 0
for index in np.arange(len(all_data)):
    product_price = all_test[index].iloc[0][str(index)]
    product_demand = all_test[index].iloc[0]['9L Cases']
    product_revenue = product_price * product_demand
    print(f"Product {index} Price 9L Case: ${round(product_price,2)} Revenue: ${round(product_revenue)}")
    total_test_data_revenue = total_test_data_revenue + product_revenue
    
print(f"Total Revenue: ${round(total_test_data_revenue)}")

# Also, some things dont make sense.
# The models are grosely underestimating the demand (as can be seen by the predictions above)
# Out:
# Product 0 Price 9L Case: $229.53 Revenue: $109290.0
# Product 1 Price 9L Case: $185.59 Revenue: $32788.0
# Product 2 Price 9L Case: $222.36 Revenue: $15343.0
# Total Revenue: $157421.0

# %%
plot_convergence(res)

# %% [markdown]
# # TODO
#
# 1. Build a baseline model for all products (maybe average of last 2 years (same period) and Compare the performance of automl models to baseline models
# 2. Compute revenue expected with baseline models and compare to the one from the optimizer
# 3. [DONE] Reserve a test set - compute revenue from test set and compare to the one from the optimizer
# 4. [DONE] If using test set, add masking option in optimizer (i.e. if the customer has not purchased a product in that period, then maybe mask out that revenue instead of taking what the model is giving. That should give us a more reasonable estimate.)
# 5. Add 3D surface plot of revenue vs product pricing (plotly)
# 6. Consider taking more "similar" products into consideration

# %%
math.ceil(space[0].low)
math.floor(space[0].high)
xs = np.arange(math.ceil(space[0].low), math.floor(space[0].high), step=5)
ys = np.arange(math.ceil(space[1].low), math.floor(space[1].high), step=5)

print(xs)
print(ys)
# Out:
# [197 202 207 212 217 222 227 232 237]
# [159 164 169 174 179 184]

# %%
verbose =  1
STEPS = 5

allp = [np.arange(math.ceil(space[i].low), math.floor(space[i].high), step=STEPS) for i in np.arange(len(all_data))] 

if verbose >= 1:
    print("-"*100)
    print(f"Price intervals for product 0: {allp[0]}")
    print(f"Price intervals for product 1: {allp[1]}")
    print(f"Price intervals for product 2: {allp[2]}")
    print("-"*100, "\n")

for i in np.arange(len(all_data)):
    print("\n\n")
    mask_plot = [False if i == j else True for j in np.arange(len(all_data))]
    if verbose >= 1:
        print(f"Product {i} --> Mask: {mask_plot}")

    columns = all_data[i].columns[-(TOP_SIMILAR+1):].values
    if verbose >= 1:
        print(f"Products used in Model: {columns}")
        
    masked_complex_objective_plot = partial(complex_objective, mask=mask_plot, verbose=0)

    finalx = []
    finaly = []
    finalrev = []

    xs = allp[int(columns[0])]  # Main Product Price is in xs
    ys = allp[int(columns[1])]  # Exogenous Product Price in in ys

    if verbose >= 1:
        print(f"Price intervals used for X-axis (product {int(columns[0])}): {xs}")
        print(f"Price intervals used for Y-axis (product {int(columns[1])}): {ys}")
        
    for x, y in itertools.product(xs, ys):
        price_list = [0, 0, 0]
        
        # Fix price for product 0
        if int(columns[0]) == 0:  # If the main product is product 0
            price_list[0] = x
        elif int(columns[1]) == 0: # If exogenous product is product 0
            price_list[0] = y
        else:
            price_list[0] = 0

        # Fix price for product 1
        if int(columns[0]) == 1:  # If the main product is product 1
            price_list[1] = x
        elif int(columns[1]) == 1: # If exogenous product is product 1
            price_list[1] = y
        else:
            price_list[1] = 0

        # Fix price for product 2
        if int(columns[0]) == 2:  # If the main product is product 2
            price_list[2] = x
        elif int(columns[1]) == 2: # If exogenous product is product 2
            price_list[2] = y
        else:
            price_list[2] = 0
       
        rev = -masked_complex_objective_plot(price_list)
        finalx.append(x)
        finaly.append(y)
        finalrev.append(rev)   

    fig = surface3DChart(
        x=finalx, y=finaly, z=finalrev,
        title= 'Product ' + columns[0] + ' Revenue',
        xTitle= 'Product ' + columns[0] + ' Price',
        yTitle= 'Product ' + columns[1] + ' Price',
        width=1200,
        height=800            
        )
    py.plot(fig, filename='rev_product_' + str(i) + "_" + str(RESAMPLE_FREQ) + "_f" + str(FORECAST_PERIOD) + "_s" + str(SEASONAL_PERIOD) + ".html")
# Out:
# ----------------------------------------------------------------------------------------------------
# Price intervals for product 0: [197 202 207 212 217 222 227 232 237]
# Price intervals for product 1: [159 164 169 174 179 184]
# Price intervals for product 2: [194 199 204 209 214 219 224]
# ----------------------------------------------------------------------------------------------------
#
#
#
#
# Product 0 --> Mask: [False, True, True]
# Products used in Model: ['0' '1']
# Price intervals used for X-axis (product 0): [197 202 207 212 217 222 227 232 237]
# Price intervals used for Y-axis (product 1): [159 164 169 174 179 184]
#
#
#
# Product 1 --> Mask: [True, False, True]
# Products used in Model: ['1' '0']
# Price intervals used for X-axis (product 1): [159 164 169 174 179 184]
# Price intervals used for Y-axis (product 0): [197 202 207 212 217 222 227 232 237]
#
#
#
# Product 2 --> Mask: [True, True, False]
# Products used in Model: ['2' '1']
# Price intervals used for X-axis (product 2): [194 199 204 209 214 219 224]
# Price intervals used for Y-axis (product 1): [159 164 169 174 179 184]
